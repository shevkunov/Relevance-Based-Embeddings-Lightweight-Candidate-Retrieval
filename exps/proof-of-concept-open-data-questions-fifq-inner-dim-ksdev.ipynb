# %% [markdown]
# ### setup

# %%
# !pip install -U sentence-transformers
# !pip install datasets
# !pip install tensorflow_ranking

# %%
import pickle
import numpy as np
import os
import tqdm
import torch
import gc

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

from importlib import reload
from matplotlib import pyplot as plt

import matrix_approx_zeshel

matrix_approx_zeshel = reload(matrix_approx_zeshel)

# !ls  | grep matrix_approx_zeshel
# Out:
# 2024-03-28 14:47:22.519191: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/shevkunov/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# matrix_approx_zeshel.py

# %%
import collections
import pickle
import numpy as np
import tqdm
import os
import gc

import matplotlib.pyplot as plt


def load(limit, raw_path = "stand/log.local.logtime2.txt", path = "log.local.logtime2.bin", key_games = None, seed = 17, det_attempts = 0, key_size = 100):
    readvector = lambda s : np.array(list(map(float, s.strip()[1:-2].split(","))))
    requests = list()
    docembs = collections.defaultdict(dict)

    if os.path.isfile(path):
        with open(path, "rb") as f:
            flimit, frequests, fdocembs = pickle.load(f)
            if flimit == limit:
                requests, docembs = frequests, fdocembs
            else:
                print(f"WARN: buffered limit is different, {flimit} != {limit}, reloading...")

    if not requests:
        with open(raw_path) as f:
            req = list()
            reqid = None
            models = list()
            prevreqmodel = None
            reqmodel = dict()
            prevmodelid = -1
            bannermodelid = -1
            for i, line in tqdm.tqdm_notebook(enumerate(f)):
                if line.startswith("Model = 6;"):
                    prevreqmodel = reqmodel
                    reqmodel = dict()

                if line.startswith("Model = "):
                    spl = line.split(" ")
                    prevmodelid = int(spl[2][:-1])
                    bannermodelid = max(bannermodelid , prevmodelid)
                    reqmodel[prevmodelid] = readvector(spl[3])
                elif line.startswith("dbid"):
                    spl = line.split(" ")
                    dbid = int(spl[1][:-1])
                    docembs[bannermodelid][dbid] = readvector(spl[2])
                elif line.startswith("seed"):
                    if len(requests) >= limit:
                        break
                    if req:
                        requests.append((reqid, prevreqmodel, sorted(req)))
                        req = list()
                    reqid = "$_" + (line.split()[1] + "_" + line.split()[3])
                else:
                    req.append(
                        (int(line.split()[0]), float(line.split()[1]))
                    )
        
        with open(path, "wb") as f:
            pickle.dump((limit, requests, docembs), f)

    games_count = len(requests[0][2])
    assert games_count == 16514
    requests = [r for r in requests if len(r[2]) == games_count]
    
    print([(i, len(docembs[i].keys())) for i in docembs])  # should be equal
    docblocks = {
        mid : np.array([x[1] for x in sorted(list(docembs[mid].items()))])
        for mid in docembs
    }
    
    class EvalContext:
        def __init__(self, games_count = games_count, key_size = key_size, train_size = 0.7, key_games = None, seed = 17, det_attempts = 0):
            self.games_count = games_count
            
            self.key_size = key_size
            self.key_games = (
                np.random.choice(np.arange(games_count), key_size, replace=False)
                if key_games is None else
                key_games
            )

            self.requests = requests
            np.random.seed(seed)
            np.random.shuffle(self.requests)
            
            self.try_det_attempts(det_attempts)

            self.key_reqs = self.requests[:key_size + 1]
            self.key_reqs_idx = np.arange(key_size + 1)

            self.train_split = int(len(self.requests) * train_size)

            assert key_size + 1 < self.train_split

            self.train_reqs = self.requests[key_size + 1: self.train_split]
            self.test_reqs = self.requests[self.train_split:]

            self.slices = ["key", "train", "test"]
            print(len(self.key_reqs), len(self.train_reqs), len(self.test_reqs))

            self.docblocks = docblocks
            self.relevs = dict()
            
        def get_top_games(self):
            if not hasattr(self, "top_games"):
                embed_games = np.array([
                    np.array([r[2][g_i][1] for r in self.get_requests("train")])
                    for g_i in range(self.games_count)
                ])

                self.embed_games_mean = embed_games.mean(axis=1)
                self.top_games_all = (-self.embed_games_mean).argsort()
                self.top_games = self.top_games_all[:len(self.key_games)]

            return self.top_games
        
        def set_top_games_as_key(self):
            self.key_games = self.get_top_games()
            return self
        
        def get_kmeans_games(self, all_from_labels=True):
            X = self.get_relevs("train").T

            k_func = (
                (lambda C : euclidean_distances(X, C.cluster_centers_).argmin(axis=0))
                if not all_from_labels else
                (lambda C : from_labels(X, C.labels_))
            )
            K_KMeans = k_func(
                KMeans(n_clusters=self.key_size, random_state=0).fit(X)  #, n_init="auto").fit(X)
            )

            return K_KMeans

        def set_kmeans_games_as_key(self, *args, **kwargs):
            self.key_games = self.get_kmeans_games(*args, **kwargs)
            return self

        def try_det_attempts(self, det_attempts, model_id = 6):
            def get_det(r, r_i_array):
                kr = np.array([
                    r[r_i][1][model_id][:self.key_size]
                    for r_i in r_i_array[:self.key_size]
                ])
                return np.abs(np.linalg.det(kr[:kr.shape[1], :]))

            best_i_array = np.arange(len(self.requests))

            for _ in range(det_attempts):
                # print("try update key_reqs...")
                
                r_i_array = np.arange(len(self.requests))
                np.random.shuffle(r_i_array)
                
                n, o = get_det(self.requests, r_i_array), get_det(self.requests, best_i_array)
                # print(n, o)
                if n > o:
                    best_i_array = r_i_array
                    # print("updated!")

            print("Best det = ", get_det(self.requests, best_i_array))
            
            new_requests = [
                self.requests[i]
                for i in best_i_array
            ]
            
            del self.requests
            gc.collect()

            self.requests = new_requests
            print(get_det(self.requests, np.arange(len(self.requests))))

        def get_relevs(self, t = "train"):
            if t not in self.relevs:
                self.relevs[t] = np.array([
                    np.array([g_i[1] for g_i in r[2]])
                    for r in self.get_requests(t)
                ])
                
            return self.relevs[t]

        def get_requests(self, t = "train"):
            if t == "train":
                return self.train_reqs
            elif t == "key":
                return self.key_reqs
            elif t == "test":
                return self.test_reqs
            else:
                assert False

    return EvalContext(key_games = key_games, seed = seed, det_attempts = det_attempts)

# %%
def load_ment_to_ent_scores(directory = "yugioh", shuffle_rows = 0, full = True):
    data = list()

    for file in os.listdir(directory):
        path = f"{directory}/{file}"
        print(f"Loading file {path}")
        with open(path, "rb") as f:
            data.append(
                pickle.load(f)
            )
    data = sorted(data, key = lambda x: x["arg_dict"]["n_ment_start"])

    for i in range(len(data) - 1):
        if full:
            assert data[i]["arg_dict"]["n_ment_start"] + data[i]["arg_dict"]["n_ment"] == data[i + 1]["arg_dict"]["n_ment_start"]
        else:
            assert data[i]["arg_dict"]["n_ment_start"] + data[i]["arg_dict"]["n_ment"] <= data[i + 1]["arg_dict"]["n_ment_start"]
        
    ment_to_ent_scores = list(map(lambda x: x["ment_to_ent_scores"], data))
    ment_to_ent_scores = np.vstack(ment_to_ent_scores)
    print("Loaded shape = ", ment_to_ent_scores.shape)
    
    if shuffle_rows:
        print(f"Shuffling... (seed = {shuffle_rows})")
        np.random.seed(shuffle_rows)
        np.random.shuffle(ment_to_ent_scores)
    
    return ment_to_ent_scores

# %%
from sklearn.cluster import KMeans
import numpy as np
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import euclidean_distances


def from_labels(X, labels):
    K = list()
    for i in range(100):
        sl_i = np.arange(X.shape[0])[labels == i]
        sl = X[labels == i]
        
        if len(sl_i) == 0:
            # bug-mode
            while True:
                chosen = np.random.choice(np.arange(X.shape[0])[labels < i], size=1)[0]
                if chosen not in K:
                    K.append(chosen)
                    break
            continue
            
        center = sl.mean(axis=0).reshape(1, -1)
        best = euclidean_distances(sl, center).argmin()
        K.append(sl_i[best])
        assert labels[K[-1]] == i
    return K

class EvalContextRelevs:
    def __init__(self, relevs, key_size = 100, train_size = 0.7, key_games = None, seed = 17, shuffle=False, det_attempts = 0):
        self.relevs = np.array(relevs)
        self.reqs_count = self.relevs.shape[0]
        self.games_count = self.relevs.shape[1]
        
        self.key_size = key_size
        self.key_games = (
            np.random.choice(np.arange(self.games_count), key_size, replace=False)
            if key_games is None else
            key_games
        )
        np.random.seed(seed)
        if shuffle:
            np.random.shuffle(self.relevs)

        self.try_det_attempts(det_attempts)
        self.train_split = int(self.reqs_count * train_size)

        assert key_size + 1 < self.train_split


        self.key_relevs = self.relevs[:key_size]
        self.train_relevs = self.relevs[key_size + 1: self.train_split]
        self.test_relevs = self.relevs[self.train_split:]

        self.slices = ["key", "train", "test"]
        print(len(self.key_relevs), len(self.train_relevs), len(self.test_relevs))

    def get_top_games(self):
        return self.relevs.mean(axis=0).argsort()[:self.key_size]

    def set_top_games_as_key(self):
        self.key_games = self.get_top_games()
        return self

    def get_kmeans_games(self, all_from_labels=True):
        X = self.get_relevs("train").T

        k_func = (
            (lambda C : euclidean_distances(X, C.cluster_centers_).argmin(axis=0))
            if not all_from_labels else
            (lambda C : from_labels(X, C.labels_))
        )
        K_KMeans = k_func(
            KMeans(n_clusters=self.key_size, random_state=0).fit(X)  #, n_init="auto").fit(X)
        )
        
        return K_KMeans
    
    def set_kmeans_games_as_key(self, *args, **kwargs):
        self.key_games = self.get_kmeans_games(*args, **kwargs)
        return self
    

    def try_det_attempts(self, det_attempts):
        def get_det(r):
            kr = r[:self.key_size, self.key_games] - r.mean()
            return np.abs(np.linalg.det(kr))

        best_i_array = np.arange(len(self.relevs))

        for i in range(det_attempts):

            r_i_array = np.arange(len(self.relevs))
            np.random.shuffle(r_i_array)

            n, o = get_det(self.relevs[r_i_array, :]), get_det(self.relevs[best_i_array, :])
            
            # print(f"try update key_reqs ({o} vs {n}...")
            if n > o:
                best_i_array = r_i_array
                print(f"updated det ({i}, {o} -> {n})")

        print("Best det = ", get_det(self.relevs[best_i_array, :]))

        self.relevs = self.relevs[best_i_array, :]
        print("Current de = ", get_det(self.relevs))
        
    def get_relevs(self, t = "train"):
        if t == "train":
            return self.train_relevs
        elif t == "key":
            return self.key_relevs
        elif t == "test":
            return self.test_relevs
        else:
            assert False
            
    def get_requests(self, t = "train"):
        if t == "train":
            return self.train_reqs
        elif t == "key":
            return self.key_reqs
        elif t == "test":
            return self.test_reqs
        else:
            assert False

# %%
import tensorflow as tf
import copy
import tensorflow_ranking as tfr

class Popular:
    def __init__(self, ctx):
        self.ctx = ctx
        self.game_avg_scores = {
            t : self.get_user_scores(t).mean(axis = 0)
            for t in self.ctx.slices
        }
        self.trus_top = dict()
        
    def get_user_scores(self, t):
        return self.ctx.get_relevs(t)
    
    def get_user_embs(self, t):
        assert False
    
    def get_game_embs(self):
        assert False

    def fit(self, t = "train"):
        self.top_logits = self.game_avg_scores[t]
        self.top = np.argsort(-self.top_logits)

    def recommend(self, t):
        return [self.top_logits for _ in self.get_user_scores(t)]
    
    def get_score(self, t, topsize = 100):    
        recs = self.recommend(t)
        
        if isinstance(recs, list):
            recs = np.array(recs)
        
        mse = np.mean((recs - self.get_user_scores(t)) ** 2)
        
        if isinstance(recs, tf.Tensor):
            recs = tf.argsort(-recs, axis=1)[:, :topsize].numpy()
        else:
            recs = np.argsort(-recs, axis=1)[:, :topsize]
        
        if (t, topsize) not in self.trus_top:
            trus = self.get_user_scores(t)
            trus = np.argsort(-trus, axis=1)[:, :topsize]
            self.trus_top[(t, topsize)] = trus
            
        trus = self.trus_top[(t, topsize)]

        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
            
        results = [
            ev(rec, tru) / float(topsize)
            for rec, tru in zip(recs,trus)
        ]

        print("np.mean(results), mse, len(results) = ",
              np.mean(results), mse, len(results))

        return np.mean(results)
    
import tensorflow as tf
import copy
import tensorflow_ranking as tfr

DEFAULT_FIT_KWARGS = {
    "learning_rate": 0.001,
    "n": 500,
    "c": 5000,
    "matrix_l2": 0,
    "dssm_l2": 0,
    "train_popbias": False,
    "train_bias": False,
    "train_vbias": False,
    "verbose": True,
    "train_matrix": True,
    "train_dssm": False,
    "loss": "mse",
    "ubatch": 1e9,
    "activation": "relu",
    "score_verbose": 0,
    "trainable_items": False,
    "use_keys_in_train": False,
    "Winit": "glorot0.01",
    "Wfreeze": False,
    "TEinit": "legacy",
    "normalize_embs": True,
    "save_callback": None,
    "inner_dim": None
}

class CBKnnV0(Popular):
    def __init__(self, ctx, fit_kwargs = dict()):
        super().__init__(ctx)
        
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(fit_kwargs)
        self.fit_kwargs = p
        
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(self.fit_kwargs)
        
        self.embed_users = {
            t : np.array([
                    np.array([r_i[i] for i in sorted(ctx.key_games)])
                    for r_i in ctx.get_relevs(t)
                ])
            for t in ctx.slices
        }
        self.embed_users_mean = {
            t : self.embed_users[t].mean(axis = 0)
            for t in ctx.slices
        }
        # embed_users = embed_users - embed_users_mean
        print("self.embed_users['train'].shape = ", self.embed_users['train'].shape )
        
        self.embed_games = np.array([
            np.array([r[g_i] for r in ctx.get_relevs("key")])
            for g_i in range(ctx.games_count)
        ])
        
        self.embed_games_mean = self.embed_games.mean(axis = 0)
        
        # embed_games = embed_games - embed_games_mean
        print("self.embed_games.shape = ", self.embed_games.shape)
        
        
        if self.fit_kwargs["trainable_items"]:
            if self.fit_kwargs["TEinit"] == "legacy":
                value = self.embed_games
            elif self.fit_kwargs["TEinit"] == "anncur":
                key_cols_idx = np.array(sorted(ctx.key_games))
                value = (
                    np.linalg.pinv(ctx.get_relevs("train")[:, key_cols_idx])
                    @ ctx.get_relevs("train")
                ).T
                print(type(value))
            else:
                assert False, "unknown TEinit: " + str(self.fit_kwargs["TEinit"])
                
            self.trainable_games = tf.Variable(
                tf.convert_to_tensor(value, dtype=tf.float32),
                trainable=True
            )
        else:
            if self.fit_kwargs["TEinit"] == "anncur":
                key_cols_idx = np.array(sorted(ctx.key_games))
                self.embed_games = (
                    np.linalg.pinv(ctx.get_relevs("train")[:, key_cols_idx])
                    @ ctx.get_relevs("train")
                ).T
                print("ANNCur init")
            
        
        self.games_top_key = self.embed_games.mean(axis = 1)
        
        self.games2users = np.array([
            self.embed_games[g_i]
            for g_i in ctx.key_games
        ])
        print("self.games2users.shape = ", self.games2users.shape)
        
        self.core_users_scores = ctx.get_relevs("key")
        print("self.core_users_scores.shape = ", self.core_users_scores.shape)
        
        self.core_users_embs = self.embed_users["key"]
        print("self.core_users_embs.shape = ", self.core_users_embs.shape)
        
        self.ge_users = (
            (self.embed_users["train"].T / self.embed_users["train"].mean(axis=1)).T @ self.games2users
        )
        # ge_users = embed_users @ games2users
        print("self.ge_users.shape = ", self.ge_users.shape)
        
        self.slice2best = {
            t : 0
            for t in ctx.slices
        }
    
    def __repr__(self):
        return "CbKnn(" + str(self.fit_kwargs) + ")"
        
    # inherited   
    # def get_user_scores(self, t):
    
    def get_user_embs(self, t):
        if self.fit_kwargs["normalize_embs"]:
            return (self.embed_users[t] - self.embed_users_mean["train"]) / self.embed_users[t].std(axis=0)
        else:
            return self.embed_users[t]
    
    def get_game_embs(self):
        if not self.fit_kwargs["trainable_items"]:
            if self.fit_kwargs["normalize_embs"]:
                return (self.embed_games - self.embed_games.mean(axis=0)) / self.embed_games.std(axis=0)
            else:
                return self.embed_games 
        else:
            return self.trainable_games

    def fit(self, **kwargs):
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(self.fit_kwargs)
        p.update(kwargs)

        self.p = p
        self.train_bias = p["train_bias"]
        self.train_vbias = p["train_vbias"]
        self.train_popbias = p["train_popbias"]
        self.train_matrix = p["train_matrix"]
        self.train_dssm = p["train_dssm"]
        self.loss = p["loss"]

        if p["use_keys_in_train"]:
            train_user_scores = np.vstack([
                self.get_user_scores("key"),
                self.get_user_scores("train")
            ])
            train_user_embs = np.vstack([
                self.get_user_embs("key"),
                self.get_user_embs("train")
            ])
        else:
            train_user_scores = self.get_user_scores("train")
            train_user_embs = self.get_user_embs("train")

        game_embs = self.get_game_embs()
        
        
        
        if self.p["Winit"] == "glorot0.01":
            initializer = tf.keras.initializers.GlorotUniform()
            values = initializer(shape=(train_user_embs.shape[1], game_embs.shape[1]))
            values = values / 100.  
        elif self.p["Winit"] == "glorot":
            initializer = tf.keras.initializers.GlorotUniform()
            values = initializer(shape=(train_user_embs.shape[1], game_embs.shape[1]))
        elif self.p["Winit"] == "eye":
            values = np.eye(train_user_embs.shape[1], game_embs.shape[1])
        else:
            assert False, "init is not known:" + str(self.p["init"])
            
        self.W = tf.Variable(values, trainable = True) 
        self.pb = tf.Variable(1., trainable = True) 
        self.b = tf.Variable(0., trainable = True) 
        
        if p["verbose"]:
            print("self.W = ", self.W)
            print("0-loss = ", tf.reduce_mean((train_user_scores - 0) ** 2))
    
        opt =  tf.keras.optimizers.Adam(learning_rate=p["learning_rate"])

        if self.train_dssm:
            self.train_dssm = True

            dim = game_embs.shape[1]
            inner_dim = p["inner_dim"] if p.get("inner_dim", None) is not None else dim
            print(f"dssm_dim = {dim}, inner_dim={inner_dim}")
            self.g_dssm = tf.keras.Sequential([
                tf.keras.layers.Dense(dim, activation=p["activation"]),
                tf.keras.layers.Dense(inner_dim, activation=None)
            ])
            self.g_dssm(game_embs)
            
            # dim = train_user_embs.shape[1]
            self.u_dssm = tf.keras.Sequential([
                tf.keras.layers.Dense(dim, activation=p["activation"]),
                tf.keras.layers.Dense(inner_dim, activation=None)
            ])
            self.u_dssm(train_user_embs)
            
        if self.train_vbias:
            self.vb = tf.Variable(
                np.zeros_like(self.game_avg_scores["train"], dtype=np.float32),
                trainable = True
            ) 
        
        
        for i in range(p["n"]):
            def loss():
                def get_logits_scores(loss_batch = 1e9):
                    game_slice = None
                    
                    ubatch = p["ubatch"]
                    if ubatch >= train_user_scores.shape[0]:
                        train_user_embs_ = train_user_embs
                        scores_ = train_user_scores
                    else:
                        u_slice = np.random.choice(np.arange(train_user_scores.shape[0]), ubatch, replace = True)
                        train_user_embs_ = train_user_embs[u_slice]
                        scores_ = train_user_scores[u_slice]
                    
                    if loss_batch >= game_embs.shape[0]:
                        game_embs_ = game_embs
                        scores_ = scores_
                    else:
                        game_slice = np.random.choice(np.arange(game_embs.shape[0]), loss_batch, replace = True)
                        game_embs_ = (
                            game_embs[game_slice]
                            if isinstance(game_embs, np.ndarray) else
                            tf.gather(game_embs, game_slice)
                        )
                        scores_ = scores_[:, game_slice]
                        
                    
                    logits = 0
                    
                    if self.train_matrix:
                        logits += train_user_embs_ @ self.W @ tf.transpose(game_embs_)

                    if self.train_dssm:
                        logits += self.u_dssm(train_user_embs_) @ tf.transpose(self.g_dssm(game_embs_))
                    
                    if self.train_popbias:
                        if loss_batch >= game_embs.shape[0]:
                            logits += self.pb * self.game_avg_scores["train"]
                        else:
                            logits += self.pb * self.game_avg_scores["train"][game_slice]
                        
                    if self.train_vbias:
                        if loss_batch >= game_embs.shape[0]:
                            logits += self.vb
                        else:
                            logits += tf.gather(self.vb, game_slice)
                        
                    if self.train_bias:
                        logits += self.b
                        
                    return logits, scores_
                        
                if self.loss == "mse":
                    logits, scores = get_logits_scores(
                        loss_batch = (1e9 if "loss_batch" not in p else p["loss_batch"]))
                    v = tf.reduce_mean((scores - logits) ** 2)
                elif self.loss == "qmse":
                    logits, scores = get_logits_scores(
                        loss_batch = (1e9 if "loss_batch" not in p else p["loss_batch"]))
                    q_mean = scores.mean(axis=1)
                    v = tf.reduce_mean(((scores.T - q_mean).T - logits) ** 2)
                elif self.loss == "ApproxNDCGLoss":
                    while True:
                        logits, scores = get_logits_scores(
                            loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))

                        v = tfr.keras.losses.ApproxNDCGLoss()(
                            scores.astype(np.float32),
                            logits
                        )
                    
                        if not tf.math.is_nan(v).numpy().any():
                            break
                        else:
                            if p["verbose"]:
                                print("nanloss ignored")
                elif self.loss == "softmax":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        tf.nn.softmax(logits, axis=1),
                        0
                    ))
                elif self.loss == "softmax_signed":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    sf = tf.nn.softmax(logits, axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        sf,
                        -sf
                    ))
                elif self.loss == "softmax_weighted":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        tf.nn.softmax(logits, axis=1),
                        0
                    ) * scores)
                elif self.loss == "sigmoid_top_100":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    mask = np.argsort(-scores, axis=1) < 100
                    v = -tf.reduce_sum(
                        tf.math.log_sigmoid((2 * mask - 1) * logits)
                    )
                elif self.loss == "KL100":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    mask = np.argsort(-scores, axis=1) < 100
                    v = tf.keras.losses.KLDivergence()((scores.T >= qs.T).T, logits)
                else:
                    assert False
                    
                if self.p["c"]:
                    v += tf.reduce_mean(self.W * self.W) * p["c"]
                    
                if self.p["dssm_l2"]:
                    for weights_ in [self.u_dssm.weights, self.g_dssm.weights]:
                        for weight_ in weights_:
                            v += tf.reduce_sum(weight_ * weight_) * self.p["dssm_l2"]
                
                if self.p["matrix_l2"]:
                    v += tf.reduce_sum(self.W * self.W) * self.p["matrix_l2"]
                
                if p["verbose"]:
                    print(v.numpy())
                
                return v

            weights = list()
            
            if self.train_matrix and (not self.p["Wfreeze"]):
                weights += [self.W]

            if self.train_dssm:
                weights += self.u_dssm.weights
                weights += self.g_dssm.weights
            
            if self.train_popbias:
                weights += [self.pb]

            if self.train_vbias:
                weights += [self.vb]   
                
            if self.train_bias:
                weights += [self.b]   
                
            
            if self.p["trainable_items"]:
                weights += [self.trainable_games]
                
                
            opt.minimize(loss, weights)
            
            if p["score_verbose"] and (i % p["score_verbose"] == 0):
                print(f"\n=== Iteration {i} ===")
                score = dict()
                for sl in self.ctx.slices:
                    score[sl] = self.get_score(sl)
                    print(f"slice = {sl}, score = {score[sl]}")
                    
                if score["train"] > self.slice2best["train"]:
                    self.slice2best = score
                    if p["save_callback"] is not None:
                        p["save_callback"](self)
                
        print("last loss = ", loss())

    def recommend(self, t):
        logits = 0
                    
        if self.train_matrix:
            logits += self.get_user_embs(t) @ self.W @ tf.transpose(self.get_game_embs())

        if self.train_dssm:
            logits += self.u_dssm(self.get_user_embs(t)) @ tf.transpose(self.g_dssm(self.get_game_embs()))

        if self.train_popbias:
            logits += self.pb * self.game_avg_scores["train"]       
            
        if self.train_vbias:
            logits += self.vb
            
        if self.train_bias:
            logits += self.b
            
        return logits
    
    # inherited
    # def get_score(self, t, topsize = 100):
    
class DssmKnn(CBKnnV0):
    def __init__(self, ctx, modelid, fit_kwargs=dict()):
        super().__init__(ctx, fit_kwargs=fit_kwargs)
        self.modelid = modelid
        self.embed_games = ctx.docblocks[modelid]
        
    def __repr__(self):
        return "DssmKnn(" + str(self.modelid) + "," + str(self.fit_kwargs) + ")"
        
    def get_user_embs(self, t):
        return np.array([r[1][self.modelid] for r in self.ctx.get_requests(t)])
    
    def get_game_embs(self):
        return self.embed_games
    
def ev(mds, logs=None):
    for i in range(len(mds)):
        print("\n\n\n=======")
        print("model = ", mds[i])
        mds[i].fit()
        tr, te = mds[i].get_score("train"), mds[i].get_score("test")
        print(tr, te)
        if logs is not None:
            logs.append((
                repr(mds[i]),
                tr,
                te
            ))
            
class DssmKnn(CBKnnV0):
    def __init__(self, ctx, modelid, fit_kwargs=dict()):
        super().__init__(ctx, fit_kwargs=fit_kwargs)
        self.modelid = modelid
        self.embed_games = ctx.docblocks[modelid]
        
    def __repr__(self):
        return "DssmKnn(" + str(self.modelid) + "," + str(self.fit_kwargs) + ")"
        
    def get_user_embs(self, t):
        return np.array([r[1][self.modelid] for r in self.ctx.get_requests(t)])
    
    def get_game_embs(self):
        return self.embed_games
    
def ev(mds, logs=None):
    for i in range(len(mds)):
        print("\n\n\n=======")
        print("model = ", mds[i])
        mds[i].fit()
        tr, te = mds[i].get_score("train"), mds[i].get_score("test")
        print(tr, te)
        if logs is not None:
            logs.append((
                repr(mds[i]),
                tr,
                te
            ))
            
class AnnCUR(Popular):
    def __init__(self, ctx, oracle=False, key_games=None, name=None):
        super().__init__(ctx)
        self.oracle = oracle
        self.ctx = ctx
        self.name = name

        self.key_cols_idx = np.array(sorted(ctx.key_games if key_games is None else key_games))
        rows_idx = np.arange(ctx.get_relevs("train").shape[0])
        
        self.cur = matrix_approx_zeshel.CURApprox(
            rows=torch.from_numpy(ctx.get_relevs("train")),
            cols=torch.from_numpy(ctx.get_relevs("train")[:, self.key_cols_idx]),
            row_idxs=rows_idx,
            col_idxs=self.key_cols_idx,
            approx_preference="rows",
            A=(torch.from_numpy(ctx.get_relevs("train")) if oracle else None)
        )        
        
    def __repr__(self):
        if self.name is None:
            return f"AnnCur({id(self)})"
        else:
            return f"AnnCur({self.name} - {id(self)})"
        
    def get_user_scores(self, t):
        return self.ctx.get_relevs(t)
    
    def get_user_embs(self, t):
        assert False
    
    def get_game_embs(self):
        return self.cur.latent_cols.T

    def fit(self, t = "train"):
        self.top_logits = self.game_avg_scores[t]
        self.top = np.argsort(-self.top_logits)

    def recommend(self, t):
        key_relevs = torch.from_numpy(self.ctx.get_relevs(t)[:, self.key_cols_idx])
        return self.cur.get_complete_row(key_relevs)
    
    def get_score(self, t, topsize = 100):       
        recs = np.array(self.recommend(t))
        trus = self.get_user_scores(t)

        mse = np.mean((recs - trus) ** 2)

        recs = np.argsort(-recs, axis=1)[:, :topsize]
        trus = np.argsort(-trus, axis=1)[:, :topsize]

        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
            
        results = [
            ev(rec, tru) / float(topsize)
            for rec, tru in zip(recs,trus)
        ]

        print("np.mean(results), mse, len(results) = ",
              np.mean(results), mse, len(results))

        return np.mean(results)

# %%
def coitem_algorithm(n_support, candidate_items, target_items, min_item_rel_norm=1e-5, eps=1e-6):
    support_items = []
    support_items_scores = []
    n_c, n_q = candidate_items.shape
    n_t = target_items.shape[0]

    candidate_item_squared_norms = (candidate_items ** 2).sum(axis=1)
    min_item_norm = min_item_rel_norm * np.sqrt(candidate_item_squared_norms.mean())
    
    candidate_coitems = candidate_items.dot(
        target_items.T.dot(target_items)
    )
    orthonormed_support_items = np.zeros((n_support, n_q))
    remaining_items = np.ones(candidate_items.shape[0], dtype="bool")
    for t in tqdm.tqdm_notebook(range(n_support)):
        scores = (candidate_coitems * candidate_items).sum(axis=1)
        remaining_items &= (candidate_item_squared_norms >= min_item_norm ** 2)
        scores[remaining_items] /= candidate_item_squared_norms[remaining_items]
        scores[~remaining_items] = 0
        
        new_item_id = np.argmax(scores)
        assert remaining_items[new_item_id]
        support_items.append(new_item_id)
        support_items_scores.append(scores[new_item_id] / (n_t * n_q))
        remaining_items[new_item_id] = False
        
        new_item = candidate_items[new_item_id].copy()
        new_item -= orthonormed_support_items[:t].T.dot(
            orthonormed_support_items[:t].dot(new_item)
        )
        assert np.allclose((new_item ** 2).sum(), candidate_item_squared_norms[new_item_id], atol=eps)
        new_item /= np.sqrt((new_item ** 2).sum())
        orthonormed_support_items[t] = new_item
        new_coitem = candidate_coitems[new_item_id] / np.sqrt(candidate_item_squared_norms[new_item_id])
        
        coefs = (candidate_items * new_item).sum(axis=1)
        candidate_item_squared_norms -= coefs ** 2
        assert np.all(candidate_item_squared_norms[remaining_items] > -eps)
        
        candidate_coitems -= coefs.reshape((-1, 1)).dot(new_coitem.reshape((1, -1)))
        cocoefs = (candidate_coitems * new_item).sum(axis=1, keepdims=True)
        candidate_coitems -= cocoefs.dot(new_item.reshape((1, -1)))
    return np.array(support_items, dtype=np.int64), np.array(support_items_scores)

# %% [markdown]
# # Preparate

# %%
def do(ctx, name, coitem=True, kmeans=True, top=True, random=True):
    if coitem:
        t = ctx.get_relevs("train").T
        t = (t - t.mean()) / t.std()  # like in other comparisons with RBE
        ctx.key_games = list(coitem_algorithm(ctx.key_size, t, t, 1e-8, eps=1e9)[0])

        ma = AnnCUR(ctx, key_games=ctx.key_games)

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")

        GE = ma.get_game_embs()
        QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

        fname = f"./GE_QE_AnnCURxCoItem_{name}_{str(round(te, 4))[2:]}.npz"
        np.savez_compressed(fname, QE=QE.numpy(), GE=GE.numpy())
        print(fname)
        
    if kmeans:
        ctx.set_kmeans_games_as_key()
        ma = AnnCUR(ctx, key_games=ctx.key_games)

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")

        GE = ma.get_game_embs()
        QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

        fname = f"./GE_QE_AnnCURxKMeans_{name}_{str(round(te, 4))[2:]}.npz"
        np.savez_compressed(fname, QE=QE.numpy(), GE=GE.numpy())
        print(fname)
        
    if top:
        ctx.set_top_games_as_key()
        ma = AnnCUR(ctx, key_games=ctx.key_games)

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")

        GE = ma.get_game_embs()
        QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

        fname = f"./GE_QE_AnnCURxTop_{name}_{str(round(te, 4))[2:]}.npz"
        np.savez_compressed(fname, QE=QE.numpy(), GE=GE.numpy())
        print(fname)
        
    if random:
        ctx.key_games = np.random.choice(np.arange(ctx.games_count), ctx.key_size, replace=False)
        ma = AnnCUR(ctx, key_games=ctx.key_games)

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")

        GE = ma.get_game_embs()
        QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

        fname = f"./GE_QE_AnnCURxRandom_{name}_{str(round(te, 4))[2:]}.npz"
        np.savez_compressed(fname, QE=QE.numpy(), GE=GE.numpy())
        print(fname)

# %%
m_ = None
def do_RBE(ctx, name, coitem=True, kmeans=True, top=True, random=True, N = 100000, LR = 0.0005, train_matrix=True, inner_dim=None):
    def get_save_callback(t, fname):
        def save_callback(m):
            global m_
            m_ = m
            GE_ = m.get_game_embs()
            GE = np.hstack([
                GE_,
                m.g_dssm(GE_),
                m.vb.numpy().reshape((-1, 1)) ,  # Vertical bias
                ctx.get_relevs("train").mean(axis=0).reshape((-1, 1))  # popbias
            ])

            R_All = ctx.get_relevs(t)
            QE_ = m.get_user_embs(t)
            QE = np.hstack([
                QE_ @ m.W,
                m.u_dssm(QE_),
                np.ones((R_All.shape[0], 1)),
                np.ones((R_All.shape[0], 1)) * m.pb
            ])
            
            l, r = fname.split(".npz")
            
            train_score = m.get_score("train")
            score = m.get_score(t)
            fname_ = l + f"_{str(round(train_score, 4))}_{str(round(score, 4))}.npz" + r
            print(f"Saving {fname_} ...")
            np.savez_compressed(fname_, QE=QE, GE=GE)
        return save_callback
            
    if coitem:
        t = ctx.get_relevs("train").T
        t = (t - t.mean()) / t.std()  # like in other comparisons with RBE
        ctx.key_games = list(coitem_algorithm(100, t, t, 1e-8, eps=1e9)[0])

        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': train_matrix,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "inner_dim": inner_dim,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExCoItem_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if kmeans:
        ctx.set_kmeans_games_as_key()
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': train_matrix,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "inner_dim": inner_dim,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExKMeans_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if top:
        ctx.set_top_games_as_key()
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': train_matrix,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "inner_dim": inner_dim,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExTop_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if random:
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': train_matrix,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "inner_dim": inner_dim,
            "save_callback": get_save_callback("test", f"./GE_QE_{name}_RBExRandom.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)

# %%
def get_Rp_basic(GE, A, R, QE_i, L):
    Ae = GE[A]

    u = np.linalg.pinv(Ae.T @ Ae) @ Ae.T @ R
    assert u.shape == QE_i.shape
    Rp = GE @ (u * L + QE_i * (1 - L))
    
    return Rp


def do_AXN(ctx, loaded, get_Rp, Z="test", STRIP = 0.05, Ls=np.linspace(0, 1, 11), Ks=[25], T_TS_s = [(200, 100)], not_deduplicate = False):
    # q = ctx.get_requests(Z)
    R_All = ctx.get_relevs(Z)

    GE, QE = loaded["GE"], loaded["QE"]

    best = 0
    best_arg = None

    for randomFirst in [False]:
        for K in Ks:
            for L in Ls:
                for T, TS in T_TS_s:
                    results = list()


                    As = list()
                    for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                        A = (
                            ctx.key_games[:K]
                            if randomFirst else
                            (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                        )
                        Rt = R_All[i]
                        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                        for _ in range(T // K - 1):
                            Rp = get_Rp(GE, A, Rt[A], QE[i], L)

                            An = list(A)
                            for ai in Rp.argsort()[::-1]:
                                if not_deduplicate or (ai not in An):
                                    An.append(ai)
                                if len(An) == len(A) + K:
                                    break
                            A = np.array(An)

                        assert len(A) == T
                        As.append(A)


                        A = sorted([
                            (-Rt[ai], ai)
                            for ai in A
                        ])[:TS]
                        A = [ai for _, ai in A]

                        pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                        results.append(ev(pred_top, gt_top) / float(TS))

                    if np.mean(results) > best:
                        best = np.mean(results)
                        best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                        best_arg_d = {
                            "K": K,
                            "L": L,
                            "randomFirst": randomFirst,
                            "score": np.mean(results)
                        }
                    print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)} best = {best}")

    return best_arg

# %% [markdown]
# ## RecSys LT

# %%
L = 7000
N = 1000
DA = 50

# %%
ctx = load(L, raw_path = "stand/log.local.logtime2.txt",
           path="log.local.logtime2.true.bin", seed=17, det_attempts=DA, key_size=100)

# %%
do_RBE(ctx, "RecSysLT_noW_", N=300000, kmeans=False, top=False, random=False, train_matrix=False)

# %% [markdown]
# ## RecSys PairWise

# %%
del ctx
gc.collect()

# %%
L = 7000
N = 1000
DA = 50


ctx = load(L, raw_path = "//dev/null/stand/log.local.txt",
           path="log.local.bin.old", seed=17, det_attempts=DA, key_size=100)
print("LOADED")

# %%
do_RBE(ctx, "RecSysLT_noW_", N=300000, kmeans=False, top=False, random=False, train_matrix=False)

# %% [markdown]
# # ZESHEL

# %%
DATASETS = ["yugioh", "pro_wrestling", "star_trek", "doctor_who", "military"]

# %%
del ctx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 del ctx
#
# NameError: name 'ctx' is not defined

# %%
gc.collect()

# %%
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100,
        key_size=100
    )

    print("LOADED")
    
    do_RBE(ctx, "RecSysLT_noW_", N=200000, kmeans=False, top=False, random=False, train_matrix=False, inner_dim=200)
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (4, 6.137885635798218e+30 -> 2.524378507319208e+32)
# updated det (8, 2.524378507319208e+32 -> 5.48097506735188e+34)
# updated det (11, 5.48097506735188e+34 -> 4.6749692824069873e+36)
# Best det =  4.6749693e+36
# Current de =  4.6749693e+36
# 100 2260 1013
# LOADED
# /var/tmp/ipykernel_3814892/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# self.embed_users['train'].shape =  (2260, 100)
# self.embed_games.shape =  (10031, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 10031)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (2260, 100)
# dssm_dim = 100, inner_dim=200
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.030400000000000003 tf.Tensor(42.316044, shape=(), dtype=float32) 100
# slice = key, score = 0.030400000000000003
# np.mean(results), mse, len(results) =  0.027969026548672563 tf.Tensor(42.17529, shape=(), dtype=float32) 2260
# slice = train, score = 0.027969026548672563
# np.mean(results), mse, len(results) =  0.028460019743336624 tf.Tensor(42.525887, shape=(), dtype=float32) 1013
# slice = test, score = 0.028460019743336624
# np.mean(results), mse, len(results) =  0.027969026548672563 tf.Tensor(42.17529, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.028460019743336624 tf.Tensor(42.525887, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.028_0.0285.npz ...
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.5375000000000001 tf.Tensor(130.34486, shape=(), dtype=float32) 100
# slice = key, score = 0.5375000000000001
# np.mean(results), mse, len(results) =  0.5485398230088495 tf.Tensor(128.82112, shape=(), dtype=float32) 2260
# slice = train, score = 0.5485398230088495
# np.mean(results), mse, len(results) =  0.5179664363277394 tf.Tensor(128.9487, shape=(), dtype=float32) 1013
# slice = test, score = 0.5179664363277394
# np.mean(results), mse, len(results) =  0.5485398230088495 tf.Tensor(128.82112, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5179664363277394 tf.Tensor(128.9487, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5485_0.518.npz ...
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5635 tf.Tensor(215.34454, shape=(), dtype=float32) 100
# slice = key, score = 0.5635
# np.mean(results), mse, len(results) =  0.5746769911504425 tf.Tensor(210.31436, shape=(), dtype=float32) 2260
# slice = train, score = 0.5746769911504425
# np.mean(results), mse, len(results) =  0.53786771964462 tf.Tensor(210.27448, shape=(), dtype=float32) 1013
# slice = test, score = 0.53786771964462
# np.mean(results), mse, len(results) =  0.5746769911504425 tf.Tensor(210.31436, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.53786771964462 tf.Tensor(210.27448, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5747_0.5379.npz ...
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.5697 tf.Tensor(301.31302, shape=(), dtype=float32) 100
# slice = key, score = 0.5697
# np.mean(results), mse, len(results) =  0.5849911504424778 tf.Tensor(291.2777, shape=(), dtype=float32) 2260
# slice = train, score = 0.5849911504424778
# np.mean(results), mse, len(results) =  0.5453504442250741 tf.Tensor(291.98978, shape=(), dtype=float32) 1013
# slice = test, score = 0.5453504442250741
# np.mean(results), mse, len(results) =  0.5849911504424778 tf.Tensor(291.2777, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5453504442250741 tf.Tensor(291.98978, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.585_0.5454.npz ...
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.5856 tf.Tensor(405.96417, shape=(), dtype=float32) 100
# slice = key, score = 0.5856
# np.mean(results), mse, len(results) =  0.5929690265486726 tf.Tensor(390.30573, shape=(), dtype=float32) 2260
# slice = train, score = 0.5929690265486726
# np.mean(results), mse, len(results) =  0.5525271470878579 tf.Tensor(391.1633, shape=(), dtype=float32) 1013
# slice = test, score = 0.5525271470878579
# np.mean(results), mse, len(results) =  0.5929690265486726 tf.Tensor(390.30573, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5525271470878579 tf.Tensor(391.1633, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.593_0.5525.npz ...
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.5866999999999999 tf.Tensor(496.948, shape=(), dtype=float32) 100
# slice = key, score = 0.5866999999999999
# np.mean(results), mse, len(results) =  0.5962743362831858 tf.Tensor(486.37933, shape=(), dtype=float32) 2260
# slice = train, score = 0.5962743362831858
# np.mean(results), mse, len(results) =  0.5524975320829221 tf.Tensor(487.41013, shape=(), dtype=float32) 1013
# slice = test, score = 0.5524975320829221
# np.mean(results), mse, len(results) =  0.5962743362831858 tf.Tensor(486.37933, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5524975320829221 tf.Tensor(487.41013, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5963_0.5525.npz ...
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.5852 tf.Tensor(646.681, shape=(), dtype=float32) 100
# slice = key, score = 0.5852
# np.mean(results), mse, len(results) =  0.598570796460177 tf.Tensor(627.76575, shape=(), dtype=float32) 2260
# slice = train, score = 0.598570796460177
# np.mean(results), mse, len(results) =  0.555725567620928 tf.Tensor(634.0692, shape=(), dtype=float32) 1013
# slice = test, score = 0.555725567620928
# np.mean(results), mse, len(results) =  0.598570796460177 tf.Tensor(627.76575, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.555725567620928 tf.Tensor(634.0692, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5986_0.5557.npz ...
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.5933 tf.Tensor(765.0936, shape=(), dtype=float32) 100
# slice = key, score = 0.5933
# np.mean(results), mse, len(results) =  0.6048805309734513 tf.Tensor(744.4723, shape=(), dtype=float32) 2260
# slice = train, score = 0.6048805309734513
# np.mean(results), mse, len(results) =  0.558736426456071 tf.Tensor(750.63605, shape=(), dtype=float32) 1013
# slice = test, score = 0.558736426456071
# np.mean(results), mse, len(results) =  0.6048805309734513 tf.Tensor(744.4723, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.558736426456071 tf.Tensor(750.63605, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6049_0.5587.npz ...
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.5951 tf.Tensor(890.7835, shape=(), dtype=float32) 100
# slice = key, score = 0.5951
# np.mean(results), mse, len(results) =  0.6071725663716814 tf.Tensor(872.17993, shape=(), dtype=float32) 2260
# slice = train, score = 0.6071725663716814
# np.mean(results), mse, len(results) =  0.5590029615004936 tf.Tensor(875.88794, shape=(), dtype=float32) 1013
# slice = test, score = 0.5590029615004936
# np.mean(results), mse, len(results) =  0.6071725663716814 tf.Tensor(872.17993, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5590029615004936 tf.Tensor(875.88794, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6072_0.559.npz ...
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.5976 tf.Tensor(1026.2343, shape=(), dtype=float32) 100
# slice = key, score = 0.5976
# np.mean(results), mse, len(results) =  0.6065176991150443 tf.Tensor(999.3119, shape=(), dtype=float32) 2260
# slice = train, score = 0.6065176991150443
# np.mean(results), mse, len(results) =  0.559634748272458 tf.Tensor(1010.74084, shape=(), dtype=float32) 1013
# slice = test, score = 0.559634748272458
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.6019 tf.Tensor(1127.1671, shape=(), dtype=float32) 100
# slice = key, score = 0.6019
# np.mean(results), mse, len(results) =  0.6105530973451327 tf.Tensor(1098.1498, shape=(), dtype=float32) 2260
# slice = train, score = 0.6105530973451327
# np.mean(results), mse, len(results) =  0.5624086870681145 tf.Tensor(1103.6504, shape=(), dtype=float32) 1013
# slice = test, score = 0.5624086870681145
# np.mean(results), mse, len(results) =  0.6105530973451327 tf.Tensor(1098.1498, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5624086870681145 tf.Tensor(1103.6504, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6106_0.5624.npz ...
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.5982 tf.Tensor(1311.9431, shape=(), dtype=float32) 100
# slice = key, score = 0.5982
# np.mean(results), mse, len(results) =  0.6110132743362832 tf.Tensor(1285.7921, shape=(), dtype=float32) 2260
# slice = train, score = 0.6110132743362832
# np.mean(results), mse, len(results) =  0.5618558736426456 tf.Tensor(1295.5402, shape=(), dtype=float32) 1013
# slice = test, score = 0.5618558736426456
# np.mean(results), mse, len(results) =  0.6110132743362832 tf.Tensor(1285.7921, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5618558736426456 tf.Tensor(1295.5402, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.611_0.5619.npz ...
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.6013000000000001 tf.Tensor(1485.8715, shape=(), dtype=float32) 100
# slice = key, score = 0.6013000000000001
# np.mean(results), mse, len(results) =  0.6090309734513275 tf.Tensor(1458.6881, shape=(), dtype=float32) 2260
# slice = train, score = 0.6090309734513275
# np.mean(results), mse, len(results) =  0.5587857847976309 tf.Tensor(1463.4451, shape=(), dtype=float32) 1013
# slice = test, score = 0.5587857847976309
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.6063999999999999 tf.Tensor(1635.5808, shape=(), dtype=float32) 100
# slice = key, score = 0.6063999999999999
# np.mean(results), mse, len(results) =  0.6145973451327433 tf.Tensor(1587.2538, shape=(), dtype=float32) 2260
# slice = train, score = 0.6145973451327433
# np.mean(results), mse, len(results) =  0.5643731490621915 tf.Tensor(1597.0415, shape=(), dtype=float32) 1013
# slice = test, score = 0.5643731490621915
# np.mean(results), mse, len(results) =  0.6145973451327433 tf.Tensor(1587.2538, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5643731490621915 tf.Tensor(1597.0415, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6146_0.5644.npz ...
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.6077999999999999 tf.Tensor(1761.0692, shape=(), dtype=float32) 100
# slice = key, score = 0.6077999999999999
# np.mean(results), mse, len(results) =  0.6161681415929203 tf.Tensor(1739.1796, shape=(), dtype=float32) 2260
# slice = train, score = 0.6161681415929203
# np.mean(results), mse, len(results) =  0.5654294175715696 tf.Tensor(1739.706, shape=(), dtype=float32) 1013
# slice = test, score = 0.5654294175715696
# np.mean(results), mse, len(results) =  0.6161681415929203 tf.Tensor(1739.1796, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5654294175715696 tf.Tensor(1739.706, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6162_0.5654.npz ...
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6075 tf.Tensor(1964.4928, shape=(), dtype=float32) 100
# slice = key, score = 0.6075
# np.mean(results), mse, len(results) =  0.6167566371681417 tf.Tensor(1932.2102, shape=(), dtype=float32) 2260
# slice = train, score = 0.6167566371681417
# np.mean(results), mse, len(results) =  0.5645804540967423 tf.Tensor(1944.5752, shape=(), dtype=float32) 1013
# slice = test, score = 0.5645804540967423
# np.mean(results), mse, len(results) =  0.6167566371681417 tf.Tensor(1932.2102, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5645804540967423 tf.Tensor(1944.5752, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6168_0.5646.npz ...
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6068 tf.Tensor(2097.0166, shape=(), dtype=float32) 100
# slice = key, score = 0.6068
# np.mean(results), mse, len(results) =  0.6159867256637168 tf.Tensor(2088.693, shape=(), dtype=float32) 2260
# slice = train, score = 0.6159867256637168
# np.mean(results), mse, len(results) =  0.5639585389930898 tf.Tensor(2106.7422, shape=(), dtype=float32) 1013
# slice = test, score = 0.5639585389930898
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6087 tf.Tensor(2296.774, shape=(), dtype=float32) 100
# slice = key, score = 0.6087
# np.mean(results), mse, len(results) =  0.6160884955752213 tf.Tensor(2229.9583, shape=(), dtype=float32) 2260
# slice = train, score = 0.6160884955752213
# np.mean(results), mse, len(results) =  0.5649457058242843 tf.Tensor(2247.665, shape=(), dtype=float32) 1013
# slice = test, score = 0.5649457058242843
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6077 tf.Tensor(2445.3435, shape=(), dtype=float32) 100
# slice = key, score = 0.6077
# np.mean(results), mse, len(results) =  0.6185663716814159 tf.Tensor(2416.377, shape=(), dtype=float32) 2260
# slice = train, score = 0.6185663716814159
# np.mean(results), mse, len(results) =  0.5670088845014808 tf.Tensor(2439.7336, shape=(), dtype=float32) 1013
# slice = test, score = 0.5670088845014808
# np.mean(results), mse, len(results) =  0.6185663716814159 tf.Tensor(2416.377, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5670088845014808 tf.Tensor(2439.7336, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6186_0.567.npz ...
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.6052000000000001 tf.Tensor(2623.1677, shape=(), dtype=float32) 100
# slice = key, score = 0.6052000000000001
# np.mean(results), mse, len(results) =  0.6180132743362832 tf.Tensor(2587.0964, shape=(), dtype=float32) 2260
# slice = train, score = 0.6180132743362832
# np.mean(results), mse, len(results) =  0.5659921026653505 tf.Tensor(2605.5332, shape=(), dtype=float32) 1013
# slice = test, score = 0.5659921026653505
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.6098 tf.Tensor(2849.9329, shape=(), dtype=float32) 100
# slice = key, score = 0.6098
# np.mean(results), mse, len(results) =  0.619278761061947 tf.Tensor(2811.5273, shape=(), dtype=float32) 2260
# slice = train, score = 0.619278761061947
# np.mean(results), mse, len(results) =  0.5664659427443237 tf.Tensor(2842.5059, shape=(), dtype=float32) 1013
# slice = test, score = 0.5664659427443237
# np.mean(results), mse, len(results) =  0.619278761061947 tf.Tensor(2811.5273, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5664659427443237 tf.Tensor(2842.5059, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6193_0.5665.npz ...
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.6111 tf.Tensor(3132.015, shape=(), dtype=float32) 100
# slice = key, score = 0.6111
# np.mean(results), mse, len(results) =  0.6191150442477877 tf.Tensor(3089.1777, shape=(), dtype=float32) 2260
# slice = train, score = 0.6191150442477877
# np.mean(results), mse, len(results) =  0.5658341559723594 tf.Tensor(3108.4482, shape=(), dtype=float32) 1013
# slice = test, score = 0.5658341559723594
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.6092 tf.Tensor(3157.9165, shape=(), dtype=float32) 100
# slice = key, score = 0.6092
# np.mean(results), mse, len(results) =  0.6204203539823009 tf.Tensor(3142.779, shape=(), dtype=float32) 2260
# slice = train, score = 0.6204203539823009
# np.mean(results), mse, len(results) =  0.5676406712734452 tf.Tensor(3164.2576, shape=(), dtype=float32) 1013
# slice = test, score = 0.5676406712734452
# np.mean(results), mse, len(results) =  0.6204203539823009 tf.Tensor(3142.779, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5676406712734452 tf.Tensor(3164.2576, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6204_0.5676.npz ...
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.6109999999999999 tf.Tensor(3478.5386, shape=(), dtype=float32) 100
# slice = key, score = 0.6109999999999999
# np.mean(results), mse, len(results) =  0.6232212389380531 tf.Tensor(3420.0596, shape=(), dtype=float32) 2260
# slice = train, score = 0.6232212389380531
# np.mean(results), mse, len(results) =  0.5692793682132281 tf.Tensor(3438.2441, shape=(), dtype=float32) 1013
# slice = test, score = 0.5692793682132281
# np.mean(results), mse, len(results) =  0.6232212389380531 tf.Tensor(3420.0596, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5692793682132281 tf.Tensor(3438.2441, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6232_0.5693.npz ...
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.6082 tf.Tensor(3699.943, shape=(), dtype=float32) 100
# slice = key, score = 0.6082
# np.mean(results), mse, len(results) =  0.6243053097345131 tf.Tensor(3631.9634, shape=(), dtype=float32) 2260
# slice = train, score = 0.6243053097345131
# np.mean(results), mse, len(results) =  0.5692497532082922 tf.Tensor(3666.012, shape=(), dtype=float32) 1013
# slice = test, score = 0.5692497532082922
# np.mean(results), mse, len(results) =  0.6243053097345131 tf.Tensor(3631.9634, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5692497532082922 tf.Tensor(3666.012, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6243_0.5692.npz ...
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.6173000000000002 tf.Tensor(3965.4236, shape=(), dtype=float32) 100
# slice = key, score = 0.6173000000000002
# np.mean(results), mse, len(results) =  0.6234159292035398 tf.Tensor(3871.5127, shape=(), dtype=float32) 2260
# slice = train, score = 0.6234159292035398
# np.mean(results), mse, len(results) =  0.5679170779861796 tf.Tensor(3915.205, shape=(), dtype=float32) 1013
# slice = test, score = 0.5679170779861796
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.6153 tf.Tensor(4048.1978, shape=(), dtype=float32) 100
# slice = key, score = 0.6153
# np.mean(results), mse, len(results) =  0.6226946902654867 tf.Tensor(3984.9321, shape=(), dtype=float32) 2260
# slice = train, score = 0.6226946902654867
# np.mean(results), mse, len(results) =  0.5690128331688055 tf.Tensor(4003.6882, shape=(), dtype=float32) 1013
# slice = test, score = 0.5690128331688055
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6143000000000001 tf.Tensor(4368.4536, shape=(), dtype=float32) 100
# slice = key, score = 0.6143000000000001
# np.mean(results), mse, len(results) =  0.620637168141593 tf.Tensor(4316.248, shape=(), dtype=float32) 2260
# slice = train, score = 0.620637168141593
# np.mean(results), mse, len(results) =  0.5663277393879567 tf.Tensor(4346.9834, shape=(), dtype=float32) 1013
# slice = test, score = 0.5663277393879567
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.6202 tf.Tensor(4516.352, shape=(), dtype=float32) 100
# slice = key, score = 0.6202
# np.mean(results), mse, len(results) =  0.6262035398230088 tf.Tensor(4468.535, shape=(), dtype=float32) 2260
# slice = train, score = 0.6262035398230088
# np.mean(results), mse, len(results) =  0.5703257650542942 tf.Tensor(4498.0186, shape=(), dtype=float32) 1013
# slice = test, score = 0.5703257650542942
# np.mean(results), mse, len(results) =  0.6262035398230088 tf.Tensor(4468.535, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5703257650542942 tf.Tensor(4498.0186, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6262_0.5703.npz ...
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.6134999999999999 tf.Tensor(4838.9575, shape=(), dtype=float32) 100
# slice = key, score = 0.6134999999999999
# np.mean(results), mse, len(results) =  0.6253053097345133 tf.Tensor(4704.166, shape=(), dtype=float32) 2260
# slice = train, score = 0.6253053097345133
# np.mean(results), mse, len(results) =  0.5683909180651531 tf.Tensor(4743.332, shape=(), dtype=float32) 1013
# slice = test, score = 0.5683909180651531
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.6178000000000001 tf.Tensor(5098.616, shape=(), dtype=float32) 100
# slice = key, score = 0.6178000000000001
# np.mean(results), mse, len(results) =  0.6245929203539823 tf.Tensor(5005.3228, shape=(), dtype=float32) 2260
# slice = train, score = 0.6245929203539823
# np.mean(results), mse, len(results) =  0.5683711747285292 tf.Tensor(5063.2417, shape=(), dtype=float32) 1013
# slice = test, score = 0.5683711747285292
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.6197 tf.Tensor(5229.2236, shape=(), dtype=float32) 100
# slice = key, score = 0.6197
# np.mean(results), mse, len(results) =  0.6253451327433629 tf.Tensor(5174.0854, shape=(), dtype=float32) 2260
# slice = train, score = 0.6253451327433629
# np.mean(results), mse, len(results) =  0.5681145113524185 tf.Tensor(5234.288, shape=(), dtype=float32) 1013
# slice = test, score = 0.5681145113524185
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.6144000000000002 tf.Tensor(5492.722, shape=(), dtype=float32) 100
# slice = key, score = 0.6144000000000002
# np.mean(results), mse, len(results) =  0.6263672566371681 tf.Tensor(5437.9346, shape=(), dtype=float32) 2260
# slice = train, score = 0.6263672566371681
# np.mean(results), mse, len(results) =  0.5682428430404738 tf.Tensor(5498.573, shape=(), dtype=float32) 1013
# slice = test, score = 0.5682428430404738
# np.mean(results), mse, len(results) =  0.6263672566371681 tf.Tensor(5437.9346, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5682428430404738 tf.Tensor(5498.573, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6264_0.5682.npz ...
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.622 tf.Tensor(5821.336, shape=(), dtype=float32) 100
# slice = key, score = 0.622
# np.mean(results), mse, len(results) =  0.6256283185840709 tf.Tensor(5711.5674, shape=(), dtype=float32) 2260
# slice = train, score = 0.6256283185840709
# np.mean(results), mse, len(results) =  0.5717966436327739 tf.Tensor(5767.2637, shape=(), dtype=float32) 1013
# slice = test, score = 0.5717966436327739
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.6190999999999999 tf.Tensor(5974.3286, shape=(), dtype=float32) 100
# slice = key, score = 0.6190999999999999
# np.mean(results), mse, len(results) =  0.6263805309734514 tf.Tensor(5886.8516, shape=(), dtype=float32) 2260
# slice = train, score = 0.6263805309734514
# np.mean(results), mse, len(results) =  0.5694373149062192 tf.Tensor(5904.074, shape=(), dtype=float32) 1013
# slice = test, score = 0.5694373149062192
# np.mean(results), mse, len(results) =  0.6263805309734514 tf.Tensor(5886.8516, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5694373149062192 tf.Tensor(5904.074, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6264_0.5694.npz ...
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.6175999999999999 tf.Tensor(6427.4565, shape=(), dtype=float32) 100
# slice = key, score = 0.6175999999999999
# np.mean(results), mse, len(results) =  0.6263672566371681 tf.Tensor(6287.3247, shape=(), dtype=float32) 2260
# slice = train, score = 0.6263672566371681
# np.mean(results), mse, len(results) =  0.5693583415597235 tf.Tensor(6355.644, shape=(), dtype=float32) 1013
# slice = test, score = 0.5693583415597235
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.6131000000000001 tf.Tensor(6711.0923, shape=(), dtype=float32) 100
# slice = key, score = 0.6131000000000001
# np.mean(results), mse, len(results) =  0.6241858407079647 tf.Tensor(6628.6597, shape=(), dtype=float32) 2260
# slice = train, score = 0.6241858407079647
# np.mean(results), mse, len(results) =  0.565883514313919 tf.Tensor(6650.36, shape=(), dtype=float32) 1013
# slice = test, score = 0.565883514313919
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.6205 tf.Tensor(6954.798, shape=(), dtype=float32) 100
# slice = key, score = 0.6205
# np.mean(results), mse, len(results) =  0.6284823008849557 tf.Tensor(6808.7466, shape=(), dtype=float32) 2260
# slice = train, score = 0.6284823008849557
# np.mean(results), mse, len(results) =  0.5702665350444225 tf.Tensor(6841.046, shape=(), dtype=float32) 1013
# slice = test, score = 0.5702665350444225
# np.mean(results), mse, len(results) =  0.6284823008849557 tf.Tensor(6808.7466, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5702665350444225 tf.Tensor(6841.046, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6285_0.5703.npz ...
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.6174000000000001 tf.Tensor(7163.041, shape=(), dtype=float32) 100
# slice = key, score = 0.6174000000000001
# np.mean(results), mse, len(results) =  0.6265132743362832 tf.Tensor(6913.059, shape=(), dtype=float32) 2260
# slice = train, score = 0.6265132743362832
# np.mean(results), mse, len(results) =  0.5678084896347482 tf.Tensor(6991.4062, shape=(), dtype=float32) 1013
# slice = test, score = 0.5678084896347482
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.6244 tf.Tensor(7496.6475, shape=(), dtype=float32) 100
# slice = key, score = 0.6244
# np.mean(results), mse, len(results) =  0.6288362831858407 tf.Tensor(7315.969, shape=(), dtype=float32) 2260
# slice = train, score = 0.6288362831858407
# np.mean(results), mse, len(results) =  0.5691214215202369 tf.Tensor(7396.207, shape=(), dtype=float32) 1013
# slice = test, score = 0.5691214215202369
# np.mean(results), mse, len(results) =  0.6288362831858407 tf.Tensor(7315.969, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5691214215202369 tf.Tensor(7396.207, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6288_0.5691.npz ...
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.618 tf.Tensor(7729.5806, shape=(), dtype=float32) 100
# slice = key, score = 0.618
# np.mean(results), mse, len(results) =  0.6274911504424778 tf.Tensor(7432.8994, shape=(), dtype=float32) 2260
# slice = train, score = 0.6274911504424778
# np.mean(results), mse, len(results) =  0.5686377097729516 tf.Tensor(7516.7476, shape=(), dtype=float32) 1013
# slice = test, score = 0.5686377097729516
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.6159000000000001 tf.Tensor(8004.7134, shape=(), dtype=float32) 100
# slice = key, score = 0.6159000000000001
# np.mean(results), mse, len(results) =  0.6299159292035398 tf.Tensor(7709.0483, shape=(), dtype=float32) 2260
# slice = train, score = 0.6299159292035398
# np.mean(results), mse, len(results) =  0.5697038499506417 tf.Tensor(7786.094, shape=(), dtype=float32) 1013
# slice = test, score = 0.5697038499506417
# np.mean(results), mse, len(results) =  0.6299159292035398 tf.Tensor(7709.0483, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5697038499506417 tf.Tensor(7786.094, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6299_0.5697.npz ...
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.6196999999999999 tf.Tensor(8249.405, shape=(), dtype=float32) 100
# slice = key, score = 0.6196999999999999
# np.mean(results), mse, len(results) =  0.6300973451327434 tf.Tensor(8098.0225, shape=(), dtype=float32) 2260
# slice = train, score = 0.6300973451327434
# np.mean(results), mse, len(results) =  0.5705824284304047 tf.Tensor(8161.8213, shape=(), dtype=float32) 1013
# slice = test, score = 0.5705824284304047
# np.mean(results), mse, len(results) =  0.6300973451327434 tf.Tensor(8098.0225, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5705824284304047 tf.Tensor(8161.8213, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6301_0.5706.npz ...
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.6206 tf.Tensor(8434.139, shape=(), dtype=float32) 100
# slice = key, score = 0.6206
# np.mean(results), mse, len(results) =  0.6303938053097345 tf.Tensor(8236.072, shape=(), dtype=float32) 2260
# slice = train, score = 0.6303938053097345
# np.mean(results), mse, len(results) =  0.5709575518262587 tf.Tensor(8345.256, shape=(), dtype=float32) 1013
# slice = test, score = 0.5709575518262587
# np.mean(results), mse, len(results) =  0.6303938053097345 tf.Tensor(8236.072, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5709575518262587 tf.Tensor(8345.256, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6304_0.571.npz ...
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.6216 tf.Tensor(9159.321, shape=(), dtype=float32) 100
# slice = key, score = 0.6216
# np.mean(results), mse, len(results) =  0.6271902654867256 tf.Tensor(8832.543, shape=(), dtype=float32) 2260
# slice = train, score = 0.6271902654867256
# np.mean(results), mse, len(results) =  0.5681441263573543 tf.Tensor(8896.409, shape=(), dtype=float32) 1013
# slice = test, score = 0.5681441263573543
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.6242 tf.Tensor(9290.0625, shape=(), dtype=float32) 100
# slice = key, score = 0.6242
# np.mean(results), mse, len(results) =  0.6281504424778761 tf.Tensor(9028.551, shape=(), dtype=float32) 2260
# slice = train, score = 0.6281504424778761
# np.mean(results), mse, len(results) =  0.5708094768015795 tf.Tensor(9122.371, shape=(), dtype=float32) 1013
# slice = test, score = 0.5708094768015795
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.6204 tf.Tensor(9371.514, shape=(), dtype=float32) 100
# slice = key, score = 0.6204
# np.mean(results), mse, len(results) =  0.6285221238938054 tf.Tensor(9218.713, shape=(), dtype=float32) 2260
# slice = train, score = 0.6285221238938054
# np.mean(results), mse, len(results) =  0.5712240868706813 tf.Tensor(9277.918, shape=(), dtype=float32) 1013
# slice = test, score = 0.5712240868706813
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.6271 tf.Tensor(9781.489, shape=(), dtype=float32) 100
# slice = key, score = 0.6271
# np.mean(results), mse, len(results) =  0.6312433628318583 tf.Tensor(9552.936, shape=(), dtype=float32) 2260
# slice = train, score = 0.6312433628318583
# np.mean(results), mse, len(results) =  0.57319842053307 tf.Tensor(9670.27, shape=(), dtype=float32) 1013
# slice = test, score = 0.57319842053307
# np.mean(results), mse, len(results) =  0.6312433628318583 tf.Tensor(9552.936, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.57319842053307 tf.Tensor(9670.27, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6312_0.5732.npz ...
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.6223 tf.Tensor(10013.877, shape=(), dtype=float32) 100
# slice = key, score = 0.6223
# np.mean(results), mse, len(results) =  0.6321769911504425 tf.Tensor(9711.611, shape=(), dtype=float32) 2260
# slice = train, score = 0.6321769911504425
# np.mean(results), mse, len(results) =  0.5718460019743337 tf.Tensor(9781.925, shape=(), dtype=float32) 1013
# slice = test, score = 0.5718460019743337
# np.mean(results), mse, len(results) =  0.6321769911504425 tf.Tensor(9711.611, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5718460019743337 tf.Tensor(9781.925, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6322_0.5718.npz ...
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.6233000000000001 tf.Tensor(10170.254, shape=(), dtype=float32) 100
# slice = key, score = 0.6233000000000001
# np.mean(results), mse, len(results) =  0.6296194690265488 tf.Tensor(9969.191, shape=(), dtype=float32) 2260
# slice = train, score = 0.6296194690265488
# np.mean(results), mse, len(results) =  0.5706219151036525 tf.Tensor(10047.795, shape=(), dtype=float32) 1013
# slice = test, score = 0.5706219151036525
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.6238999999999999 tf.Tensor(10837.28, shape=(), dtype=float32) 100
# slice = key, score = 0.6238999999999999
# np.mean(results), mse, len(results) =  0.6289867256637168 tf.Tensor(10413.7, shape=(), dtype=float32) 2260
# slice = train, score = 0.6289867256637168
# np.mean(results), mse, len(results) =  0.5704540967423496 tf.Tensor(10464.404, shape=(), dtype=float32) 1013
# slice = test, score = 0.5704540967423496
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.6291000000000001 tf.Tensor(11182.9795, shape=(), dtype=float32) 100
# slice = key, score = 0.6291000000000001
# np.mean(results), mse, len(results) =  0.6323805309734513 tf.Tensor(11002.731, shape=(), dtype=float32) 2260
# slice = train, score = 0.6323805309734513
# np.mean(results), mse, len(results) =  0.5718262586377098 tf.Tensor(11065.223, shape=(), dtype=float32) 1013
# slice = test, score = 0.5718262586377098
# np.mean(results), mse, len(results) =  0.6323805309734513 tf.Tensor(11002.731, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5718262586377098 tf.Tensor(11065.223, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6324_0.5718.npz ...
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.6236999999999999 tf.Tensor(11476.097, shape=(), dtype=float32) 100
# slice = key, score = 0.6236999999999999
# np.mean(results), mse, len(results) =  0.6317079646017699 tf.Tensor(11313.07, shape=(), dtype=float32) 2260
# slice = train, score = 0.6317079646017699
# np.mean(results), mse, len(results) =  0.572852912142152 tf.Tensor(11395.684, shape=(), dtype=float32) 1013
# slice = test, score = 0.572852912142152
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.6228 tf.Tensor(11608.717, shape=(), dtype=float32) 100
# slice = key, score = 0.6228
# np.mean(results), mse, len(results) =  0.6286194690265486 tf.Tensor(11337.828, shape=(), dtype=float32) 2260
# slice = train, score = 0.6286194690265486
# np.mean(results), mse, len(results) =  0.5692102665350444 tf.Tensor(11426.76, shape=(), dtype=float32) 1013
# slice = test, score = 0.5692102665350444
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.629 tf.Tensor(12151.79, shape=(), dtype=float32) 100
# slice = key, score = 0.629
# np.mean(results), mse, len(results) =  0.6311017699115045 tf.Tensor(11827.133, shape=(), dtype=float32) 2260
# slice = train, score = 0.6311017699115045
# np.mean(results), mse, len(results) =  0.5726061204343534 tf.Tensor(11912.198, shape=(), dtype=float32) 1013
# slice = test, score = 0.5726061204343534
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.6244000000000001 tf.Tensor(12467.279, shape=(), dtype=float32) 100
# slice = key, score = 0.6244000000000001
# np.mean(results), mse, len(results) =  0.6293097345132743 tf.Tensor(12365.337, shape=(), dtype=float32) 2260
# slice = train, score = 0.6293097345132743
# np.mean(results), mse, len(results) =  0.5689239881539979 tf.Tensor(12439.105, shape=(), dtype=float32) 1013
# slice = test, score = 0.5689239881539979
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6292000000000001 tf.Tensor(12706.868, shape=(), dtype=float32) 100
# slice = key, score = 0.6292000000000001
# np.mean(results), mse, len(results) =  0.631141592920354 tf.Tensor(12460.925, shape=(), dtype=float32) 2260
# slice = train, score = 0.631141592920354
# np.mean(results), mse, len(results) =  0.5694768015794669 tf.Tensor(12576.828, shape=(), dtype=float32) 1013
# slice = test, score = 0.5694768015794669
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.6259 tf.Tensor(13678.83, shape=(), dtype=float32) 100
# slice = key, score = 0.6259
# np.mean(results), mse, len(results) =  0.6320486725663718 tf.Tensor(13263.06, shape=(), dtype=float32) 2260
# slice = train, score = 0.6320486725663718
# np.mean(results), mse, len(results) =  0.5712438302073051 tf.Tensor(13493.944, shape=(), dtype=float32) 1013
# slice = test, score = 0.5712438302073051
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.6225 tf.Tensor(13611.743, shape=(), dtype=float32) 100
# slice = key, score = 0.6225
# np.mean(results), mse, len(results) =  0.630933628318584 tf.Tensor(13502.996, shape=(), dtype=float32) 2260
# slice = train, score = 0.630933628318584
# np.mean(results), mse, len(results) =  0.5697729516288254 tf.Tensor(13643.297, shape=(), dtype=float32) 1013
# slice = test, score = 0.5697729516288254
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6265 tf.Tensor(13632.897, shape=(), dtype=float32) 100
# slice = key, score = 0.6265
# np.mean(results), mse, len(results) =  0.6319424778761062 tf.Tensor(13674.783, shape=(), dtype=float32) 2260
# slice = train, score = 0.6319424778761062
# np.mean(results), mse, len(results) =  0.569101678183613 tf.Tensor(13761.035, shape=(), dtype=float32) 1013
# slice = test, score = 0.569101678183613
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6245 tf.Tensor(14426.2295, shape=(), dtype=float32) 100
# slice = key, score = 0.6245
# np.mean(results), mse, len(results) =  0.6327787610619469 tf.Tensor(14106.669, shape=(), dtype=float32) 2260
# slice = train, score = 0.6327787610619469
# np.mean(results), mse, len(results) =  0.5706416584402764 tf.Tensor(14244.669, shape=(), dtype=float32) 1013
# slice = test, score = 0.5706416584402764
# np.mean(results), mse, len(results) =  0.6327787610619469 tf.Tensor(14106.669, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5706416584402764 tf.Tensor(14244.669, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6328_0.5706.npz ...
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.6229 tf.Tensor(14764.843, shape=(), dtype=float32) 100
# slice = key, score = 0.6229
# np.mean(results), mse, len(results) =  0.6300973451327434 tf.Tensor(14427.689, shape=(), dtype=float32) 2260
# slice = train, score = 0.6300973451327434
# np.mean(results), mse, len(results) =  0.569634748272458 tf.Tensor(14617.269, shape=(), dtype=float32) 1013
# slice = test, score = 0.569634748272458
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.6265999999999999 tf.Tensor(14836.8545, shape=(), dtype=float32) 100
# slice = key, score = 0.6265999999999999
# np.mean(results), mse, len(results) =  0.6334070796460177 tf.Tensor(14540.849, shape=(), dtype=float32) 2260
# slice = train, score = 0.6334070796460177
# np.mean(results), mse, len(results) =  0.5706515301085883 tf.Tensor(14702.911, shape=(), dtype=float32) 1013
# slice = test, score = 0.5706515301085883
# np.mean(results), mse, len(results) =  0.6334070796460177 tf.Tensor(14540.849, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5706515301085883 tf.Tensor(14702.911, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6334_0.5707.npz ...
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.6282000000000001 tf.Tensor(15661.23, shape=(), dtype=float32) 100
# slice = key, score = 0.6282000000000001
# np.mean(results), mse, len(results) =  0.6329070796460177 tf.Tensor(15215.988, shape=(), dtype=float32) 2260
# slice = train, score = 0.6329070796460177
# np.mean(results), mse, len(results) =  0.5718361303060217 tf.Tensor(15448.676, shape=(), dtype=float32) 1013
# slice = test, score = 0.5718361303060217
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.6247 tf.Tensor(16410.365, shape=(), dtype=float32) 100
# slice = key, score = 0.6247
# np.mean(results), mse, len(results) =  0.6289867256637168 tf.Tensor(15769.994, shape=(), dtype=float32) 2260
# slice = train, score = 0.6289867256637168
# np.mean(results), mse, len(results) =  0.5681145113524185 tf.Tensor(15880.521, shape=(), dtype=float32) 1013
# slice = test, score = 0.5681145113524185
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.6278999999999999 tf.Tensor(16723.312, shape=(), dtype=float32) 100
# slice = key, score = 0.6278999999999999
# np.mean(results), mse, len(results) =  0.6314424778761062 tf.Tensor(16263.55, shape=(), dtype=float32) 2260
# slice = train, score = 0.6314424778761062
# np.mean(results), mse, len(results) =  0.5716979269496545 tf.Tensor(16381.86, shape=(), dtype=float32) 1013
# slice = test, score = 0.5716979269496545
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.6216999999999999 tf.Tensor(17016.117, shape=(), dtype=float32) 100
# slice = key, score = 0.6216999999999999
# np.mean(results), mse, len(results) =  0.6325442477876106 tf.Tensor(16584.01, shape=(), dtype=float32) 2260
# slice = train, score = 0.6325442477876106
# np.mean(results), mse, len(results) =  0.5697433366238895 tf.Tensor(16862.627, shape=(), dtype=float32) 1013
# slice = test, score = 0.5697433366238895
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.6222000000000001 tf.Tensor(17875.863, shape=(), dtype=float32) 100
# slice = key, score = 0.6222000000000001
# np.mean(results), mse, len(results) =  0.6292300884955752 tf.Tensor(17518.674, shape=(), dtype=float32) 2260
# slice = train, score = 0.6292300884955752
# np.mean(results), mse, len(results) =  0.5691312931885489 tf.Tensor(17730.754, shape=(), dtype=float32) 1013
# slice = test, score = 0.5691312931885489
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.6229 tf.Tensor(18278.133, shape=(), dtype=float32) 100
# slice = key, score = 0.6229
# np.mean(results), mse, len(results) =  0.6355088495575221 tf.Tensor(17613.26, shape=(), dtype=float32) 2260
# slice = train, score = 0.6355088495575221
# np.mean(results), mse, len(results) =  0.5723494570582428 tf.Tensor(17865.787, shape=(), dtype=float32) 1013
# slice = test, score = 0.5723494570582428
# np.mean(results), mse, len(results) =  0.6355088495575221 tf.Tensor(17613.26, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5723494570582428 tf.Tensor(17865.787, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6355_0.5723.npz ...
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.6259 tf.Tensor(18340.432, shape=(), dtype=float32) 100
# slice = key, score = 0.6259
# np.mean(results), mse, len(results) =  0.6311769911504425 tf.Tensor(17887.455, shape=(), dtype=float32) 2260
# slice = train, score = 0.6311769911504425
# np.mean(results), mse, len(results) =  0.5703948667324777 tf.Tensor(18157.516, shape=(), dtype=float32) 1013
# slice = test, score = 0.5703948667324777
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.627 tf.Tensor(19208.906, shape=(), dtype=float32) 100
# slice = key, score = 0.627
# np.mean(results), mse, len(results) =  0.6342566371681416 tf.Tensor(18752.027, shape=(), dtype=float32) 2260
# slice = train, score = 0.6342566371681416
# np.mean(results), mse, len(results) =  0.5709476801579468 tf.Tensor(19020.484, shape=(), dtype=float32) 1013
# slice = test, score = 0.5709476801579468
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6266999999999999 tf.Tensor(19016.03, shape=(), dtype=float32) 100
# slice = key, score = 0.6266999999999999
# np.mean(results), mse, len(results) =  0.6321814159292035 tf.Tensor(18462.916, shape=(), dtype=float32) 2260
# slice = train, score = 0.6321814159292035
# np.mean(results), mse, len(results) =  0.5692892398815399 tf.Tensor(18700.584, shape=(), dtype=float32) 1013
# slice = test, score = 0.5692892398815399
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.6263 tf.Tensor(19876.03, shape=(), dtype=float32) 100
# slice = key, score = 0.6263
# np.mean(results), mse, len(results) =  0.6293053097345133 tf.Tensor(19405.246, shape=(), dtype=float32) 2260
# slice = train, score = 0.6293053097345133
# np.mean(results), mse, len(results) =  0.5692694965449162 tf.Tensor(19764.219, shape=(), dtype=float32) 1013
# slice = test, score = 0.5692694965449162
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.6274 tf.Tensor(20608.133, shape=(), dtype=float32) 100
# slice = key, score = 0.6274
# np.mean(results), mse, len(results) =  0.633287610619469 tf.Tensor(20055.906, shape=(), dtype=float32) 2260
# slice = train, score = 0.633287610619469
# np.mean(results), mse, len(results) =  0.5706515301085883 tf.Tensor(20290.158, shape=(), dtype=float32) 1013
# slice = test, score = 0.5706515301085883
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.6260999999999999 tf.Tensor(20935.613, shape=(), dtype=float32) 100
# slice = key, score = 0.6260999999999999
# np.mean(results), mse, len(results) =  0.632920353982301 tf.Tensor(20593.176, shape=(), dtype=float32) 2260
# slice = train, score = 0.632920353982301
# np.mean(results), mse, len(results) =  0.5685093780848963 tf.Tensor(20774.205, shape=(), dtype=float32) 1013
# slice = test, score = 0.5685093780848963
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.6271 tf.Tensor(21905.29, shape=(), dtype=float32) 100
# slice = key, score = 0.6271
# np.mean(results), mse, len(results) =  0.630787610619469 tf.Tensor(21422.053, shape=(), dtype=float32) 2260
# slice = train, score = 0.630787610619469
# np.mean(results), mse, len(results) =  0.5699012833168806 tf.Tensor(21673.303, shape=(), dtype=float32) 1013
# slice = test, score = 0.5699012833168806
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6306999999999999 tf.Tensor(21692.43, shape=(), dtype=float32) 100
# slice = key, score = 0.6306999999999999
# np.mean(results), mse, len(results) =  0.6345884955752212 tf.Tensor(21003.93, shape=(), dtype=float32) 2260
# slice = train, score = 0.6345884955752212
# np.mean(results), mse, len(results) =  0.5713030602171767 tf.Tensor(21248.334, shape=(), dtype=float32) 1013
# slice = test, score = 0.5713030602171767
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.628 tf.Tensor(22633.244, shape=(), dtype=float32) 100
# slice = key, score = 0.628
# np.mean(results), mse, len(results) =  0.632070796460177 tf.Tensor(22063.232, shape=(), dtype=float32) 2260
# slice = train, score = 0.632070796460177
# np.mean(results), mse, len(results) =  0.5708094768015795 tf.Tensor(22294.955, shape=(), dtype=float32) 1013
# slice = test, score = 0.5708094768015795
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6287 tf.Tensor(22999.498, shape=(), dtype=float32) 100
# slice = key, score = 0.6287
# np.mean(results), mse, len(results) =  0.6312433628318584 tf.Tensor(22428.666, shape=(), dtype=float32) 2260
# slice = train, score = 0.6312433628318584
# np.mean(results), mse, len(results) =  0.5694373149062192 tf.Tensor(22713.33, shape=(), dtype=float32) 1013
# slice = test, score = 0.5694373149062192
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6286999999999999 tf.Tensor(24011.395, shape=(), dtype=float32) 100
# slice = key, score = 0.6286999999999999
# np.mean(results), mse, len(results) =  0.6324380530973451 tf.Tensor(23253.885, shape=(), dtype=float32) 2260
# slice = train, score = 0.6324380530973451
# np.mean(results), mse, len(results) =  0.5693188548864758 tf.Tensor(23591.32, shape=(), dtype=float32) 1013
# slice = test, score = 0.5693188548864758
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.6262000000000001 tf.Tensor(24372.973, shape=(), dtype=float32) 100
# slice = key, score = 0.6262000000000001
# np.mean(results), mse, len(results) =  0.6337831858407079 tf.Tensor(23452.986, shape=(), dtype=float32) 2260
# slice = train, score = 0.6337831858407079
# np.mean(results), mse, len(results) =  0.5710858835143139 tf.Tensor(23806.547, shape=(), dtype=float32) 1013
# slice = test, score = 0.5710858835143139
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.6251000000000001 tf.Tensor(24527.732, shape=(), dtype=float32) 100
# slice = key, score = 0.6251000000000001
# np.mean(results), mse, len(results) =  0.6322035398230088 tf.Tensor(23825.576, shape=(), dtype=float32) 2260
# slice = train, score = 0.6322035398230088
# np.mean(results), mse, len(results) =  0.5695853899308984 tf.Tensor(24187.812, shape=(), dtype=float32) 1013
# slice = test, score = 0.5695853899308984
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.6265999999999999 tf.Tensor(25366.842, shape=(), dtype=float32) 100
# slice = key, score = 0.6265999999999999
# np.mean(results), mse, len(results) =  0.6343849557522124 tf.Tensor(24712.566, shape=(), dtype=float32) 2260
# slice = train, score = 0.6343849557522124
# np.mean(results), mse, len(results) =  0.5715695952615992 tf.Tensor(25141.17, shape=(), dtype=float32) 1013
# slice = test, score = 0.5715695952615992
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.6287999999999999 tf.Tensor(25831.316, shape=(), dtype=float32) 100
# slice = key, score = 0.6287999999999999
# np.mean(results), mse, len(results) =  0.6340000000000001 tf.Tensor(25286.682, shape=(), dtype=float32) 2260
# slice = train, score = 0.6340000000000001
# np.mean(results), mse, len(results) =  0.5711549851924975 tf.Tensor(25725.303, shape=(), dtype=float32) 1013
# slice = test, score = 0.5711549851924975
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.6308 tf.Tensor(26780.543, shape=(), dtype=float32) 100
# slice = key, score = 0.6308
# np.mean(results), mse, len(results) =  0.634995575221239 tf.Tensor(26184.945, shape=(), dtype=float32) 2260
# slice = train, score = 0.634995575221239
# np.mean(results), mse, len(results) =  0.5726653504442251 tf.Tensor(26778.488, shape=(), dtype=float32) 1013
# slice = test, score = 0.5726653504442251

# %%
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100,
        key_size=100
    )

    print("LOADED")
    
    do_RBE(ctx, "RecSysLT_noW_", N=200000, kmeans=False, top=False, random=False, train_matrix=False, inner_dim=200)
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (4, 6.137885635798218e+30 -> 2.524378507319208e+32)
# updated det (8, 2.524378507319208e+32 -> 5.48097506735188e+34)
# updated det (11, 5.48097506735188e+34 -> 4.6749692824069873e+36)
# Best det =  4.6749693e+36
# Current de =  4.6749693e+36
# 100 2260 1013
# LOADED
# /var/tmp/ipykernel_5766/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# self.embed_users['train'].shape =  (2260, 100)
# self.embed_games.shape =  (10031, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 10031)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (2260, 100)
# dssm_dim = 100, inner_dim=200
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.029099999999999997 tf.Tensor(32.82392, shape=(), dtype=float32) 100
# slice = key, score = 0.029099999999999997
# np.mean(results), mse, len(results) =  0.03211504424778761 tf.Tensor(33.266846, shape=(), dtype=float32) 2260
# slice = train, score = 0.03211504424778761
# np.mean(results), mse, len(results) =  0.03151036525172755 tf.Tensor(33.651577, shape=(), dtype=float32) 1013
# slice = test, score = 0.03151036525172755
# np.mean(results), mse, len(results) =  0.03211504424778761 tf.Tensor(33.266846, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.03151036525172755 tf.Tensor(33.651577, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.0321_0.0315.npz ...
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.5396 tf.Tensor(126.73498, shape=(), dtype=float32) 100
# slice = key, score = 0.5396
# np.mean(results), mse, len(results) =  0.5544823008849558 tf.Tensor(124.77125, shape=(), dtype=float32) 2260
# slice = train, score = 0.5544823008849558
# np.mean(results), mse, len(results) =  0.5249753208292202 tf.Tensor(125.165306, shape=(), dtype=float32) 1013
# slice = test, score = 0.5249753208292202
# np.mean(results), mse, len(results) =  0.5544823008849558 tf.Tensor(124.77125, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5249753208292202 tf.Tensor(125.165306, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5545_0.525.npz ...
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5601 tf.Tensor(209.13312, shape=(), dtype=float32) 100
# slice = key, score = 0.5601
# np.mean(results), mse, len(results) =  0.5744999999999999 tf.Tensor(209.78685, shape=(), dtype=float32) 2260
# slice = train, score = 0.5744999999999999
# np.mean(results), mse, len(results) =  0.5413228035538006 tf.Tensor(209.89293, shape=(), dtype=float32) 1013
# slice = test, score = 0.5413228035538006
# np.mean(results), mse, len(results) =  0.5744999999999999 tf.Tensor(209.78685, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5413228035538006 tf.Tensor(209.89293, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5745_0.5413.npz ...
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.5672 tf.Tensor(292.77878, shape=(), dtype=float32) 100
# slice = key, score = 0.5672
# np.mean(results), mse, len(results) =  0.5851681415929204 tf.Tensor(293.19135, shape=(), dtype=float32) 2260
# slice = train, score = 0.5851681415929204
# np.mean(results), mse, len(results) =  0.5469200394866732 tf.Tensor(293.55582, shape=(), dtype=float32) 1013
# slice = test, score = 0.5469200394866732
# np.mean(results), mse, len(results) =  0.5851681415929204 tf.Tensor(293.19135, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5469200394866732 tf.Tensor(293.55582, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5852_0.5469.npz ...
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.5812999999999999 tf.Tensor(401.7578, shape=(), dtype=float32) 100
# slice = key, score = 0.5812999999999999
# np.mean(results), mse, len(results) =  0.5938805309734514 tf.Tensor(404.19427, shape=(), dtype=float32) 2260
# slice = train, score = 0.5938805309734514
# np.mean(results), mse, len(results) =  0.554274432379072 tf.Tensor(403.71774, shape=(), dtype=float32) 1013
# slice = test, score = 0.554274432379072
# np.mean(results), mse, len(results) =  0.5938805309734514 tf.Tensor(404.19427, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.554274432379072 tf.Tensor(403.71774, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5939_0.5543.npz ...
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.5889 tf.Tensor(495.68015, shape=(), dtype=float32) 100
# slice = key, score = 0.5889
# np.mean(results), mse, len(results) =  0.597783185840708 tf.Tensor(501.31595, shape=(), dtype=float32) 2260
# slice = train, score = 0.597783185840708
# np.mean(results), mse, len(results) =  0.5574136229022706 tf.Tensor(500.78543, shape=(), dtype=float32) 1013
# slice = test, score = 0.5574136229022706
# np.mean(results), mse, len(results) =  0.597783185840708 tf.Tensor(501.31595, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5574136229022706 tf.Tensor(500.78543, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5978_0.5574.npz ...
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.5848 tf.Tensor(640.3449, shape=(), dtype=float32) 100
# slice = key, score = 0.5848
# np.mean(results), mse, len(results) =  0.598849557522124 tf.Tensor(648.0329, shape=(), dtype=float32) 2260
# slice = train, score = 0.598849557522124
# np.mean(results), mse, len(results) =  0.5577591312931885 tf.Tensor(649.4226, shape=(), dtype=float32) 1013
# slice = test, score = 0.5577591312931885
# np.mean(results), mse, len(results) =  0.598849557522124 tf.Tensor(648.0329, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5577591312931885 tf.Tensor(649.4226, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.5988_0.5578.npz ...
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.5955 tf.Tensor(760.93207, shape=(), dtype=float32) 100
# slice = key, score = 0.5955
# np.mean(results), mse, len(results) =  0.6043318584070796 tf.Tensor(756.6826, shape=(), dtype=float32) 2260
# slice = train, score = 0.6043318584070796
# np.mean(results), mse, len(results) =  0.5611056268509378 tf.Tensor(755.6437, shape=(), dtype=float32) 1013
# slice = test, score = 0.5611056268509378
# np.mean(results), mse, len(results) =  0.6043318584070796 tf.Tensor(756.6826, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5611056268509378 tf.Tensor(755.6437, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6043_0.5611.npz ...
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.5915 tf.Tensor(888.75604, shape=(), dtype=float32) 100
# slice = key, score = 0.5915
# np.mean(results), mse, len(results) =  0.6042787610619469 tf.Tensor(904.0557, shape=(), dtype=float32) 2260
# slice = train, score = 0.6042787610619469
# np.mean(results), mse, len(results) =  0.5622606120434352 tf.Tensor(899.9919, shape=(), dtype=float32) 1013
# slice = test, score = 0.5622606120434352
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.5945 tf.Tensor(1012.12054, shape=(), dtype=float32) 100
# slice = key, score = 0.5945
# np.mean(results), mse, len(results) =  0.6055530973451327 tf.Tensor(1020.69666, shape=(), dtype=float32) 2260
# slice = train, score = 0.6055530973451327
# np.mean(results), mse, len(results) =  0.5614610069101678 tf.Tensor(1022.4092, shape=(), dtype=float32) 1013
# slice = test, score = 0.5614610069101678
# np.mean(results), mse, len(results) =  0.6055530973451327 tf.Tensor(1020.69666, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5614610069101678 tf.Tensor(1022.4092, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6056_0.5615.npz ...
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.601 tf.Tensor(1226.0752, shape=(), dtype=float32) 100
# slice = key, score = 0.601
# np.mean(results), mse, len(results) =  0.6079823008849558 tf.Tensor(1213.4839, shape=(), dtype=float32) 2260
# slice = train, score = 0.6079823008849558
# np.mean(results), mse, len(results) =  0.5645310957551827 tf.Tensor(1210.0293, shape=(), dtype=float32) 1013
# slice = test, score = 0.5645310957551827
# np.mean(results), mse, len(results) =  0.6079823008849558 tf.Tensor(1213.4839, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5645310957551827 tf.Tensor(1210.0293, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.608_0.5645.npz ...
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.6012000000000001 tf.Tensor(1311.1885, shape=(), dtype=float32) 100
# slice = key, score = 0.6012000000000001
# np.mean(results), mse, len(results) =  0.6103495575221238 tf.Tensor(1321.355, shape=(), dtype=float32) 2260
# slice = train, score = 0.6103495575221238
# np.mean(results), mse, len(results) =  0.5630700888450147 tf.Tensor(1318.4381, shape=(), dtype=float32) 1013
# slice = test, score = 0.5630700888450147
# np.mean(results), mse, len(results) =  0.6103495575221238 tf.Tensor(1321.355, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5630700888450147 tf.Tensor(1318.4381, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6103_0.5631.npz ...
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.5990999999999999 tf.Tensor(1527.1091, shape=(), dtype=float32) 100
# slice = key, score = 0.5990999999999999
# np.mean(results), mse, len(results) =  0.6085088495575222 tf.Tensor(1528.327, shape=(), dtype=float32) 2260
# slice = train, score = 0.6085088495575222
# np.mean(results), mse, len(results) =  0.5631293188548865 tf.Tensor(1529.6271, shape=(), dtype=float32) 1013
# slice = test, score = 0.5631293188548865
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.5997 tf.Tensor(1627.4824, shape=(), dtype=float32) 100
# slice = key, score = 0.5997
# np.mean(results), mse, len(results) =  0.6134867256637169 tf.Tensor(1652.4824, shape=(), dtype=float32) 2260
# slice = train, score = 0.6134867256637169
# np.mean(results), mse, len(results) =  0.5644027640671273 tf.Tensor(1653.4459, shape=(), dtype=float32) 1013
# slice = test, score = 0.5644027640671273
# np.mean(results), mse, len(results) =  0.6134867256637169 tf.Tensor(1652.4824, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5644027640671273 tf.Tensor(1653.4459, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6135_0.5644.npz ...
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.5996 tf.Tensor(1824.9008, shape=(), dtype=float32) 100
# slice = key, score = 0.5996
# np.mean(results), mse, len(results) =  0.614650442477876 tf.Tensor(1829.39, shape=(), dtype=float32) 2260
# slice = train, score = 0.614650442477876
# np.mean(results), mse, len(results) =  0.5652122408687068 tf.Tensor(1829.3184, shape=(), dtype=float32) 1013
# slice = test, score = 0.5652122408687068
# np.mean(results), mse, len(results) =  0.614650442477876 tf.Tensor(1829.39, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5652122408687068 tf.Tensor(1829.3184, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6147_0.5652.npz ...
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6047 tf.Tensor(1990.5444, shape=(), dtype=float32) 100
# slice = key, score = 0.6047
# np.mean(results), mse, len(results) =  0.6166194690265486 tf.Tensor(1992.3878, shape=(), dtype=float32) 2260
# slice = train, score = 0.6166194690265486
# np.mean(results), mse, len(results) =  0.5680454096742349 tf.Tensor(1994.6558, shape=(), dtype=float32) 1013
# slice = test, score = 0.5680454096742349
# np.mean(results), mse, len(results) =  0.6166194690265486 tf.Tensor(1992.3878, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5680454096742349 tf.Tensor(1994.6558, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6166_0.568.npz ...
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.603 tf.Tensor(2190.956, shape=(), dtype=float32) 100
# slice = key, score = 0.603
# np.mean(results), mse, len(results) =  0.6149955752212389 tf.Tensor(2175.5278, shape=(), dtype=float32) 2260
# slice = train, score = 0.6149955752212389
# np.mean(results), mse, len(results) =  0.5648568608094768 tf.Tensor(2182.7014, shape=(), dtype=float32) 1013
# slice = test, score = 0.5648568608094768
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6025999999999999 tf.Tensor(2375.588, shape=(), dtype=float32) 100
# slice = key, score = 0.6025999999999999
# np.mean(results), mse, len(results) =  0.6168097345132744 tf.Tensor(2336.9924, shape=(), dtype=float32) 2260
# slice = train, score = 0.6168097345132744
# np.mean(results), mse, len(results) =  0.5665251727541954 tf.Tensor(2344.0747, shape=(), dtype=float32) 1013
# slice = test, score = 0.5665251727541954
# np.mean(results), mse, len(results) =  0.6168097345132744 tf.Tensor(2336.9924, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5665251727541954 tf.Tensor(2344.0747, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6168_0.5665.npz ...
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6079000000000001 tf.Tensor(2553.4648, shape=(), dtype=float32) 100
# slice = key, score = 0.6079000000000001
# np.mean(results), mse, len(results) =  0.6200486725663716 tf.Tensor(2558.4895, shape=(), dtype=float32) 2260
# slice = train, score = 0.6200486725663716
# np.mean(results), mse, len(results) =  0.569634748272458 tf.Tensor(2546.7424, shape=(), dtype=float32) 1013
# slice = test, score = 0.569634748272458
# np.mean(results), mse, len(results) =  0.6200486725663716 tf.Tensor(2558.4895, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.569634748272458 tf.Tensor(2546.7424, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.62_0.5696.npz ...
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.6067 tf.Tensor(2769.234, shape=(), dtype=float32) 100
# slice = key, score = 0.6067
# np.mean(results), mse, len(results) =  0.6186946902654867 tf.Tensor(2759.7307, shape=(), dtype=float32) 2260
# slice = train, score = 0.6186946902654867
# np.mean(results), mse, len(results) =  0.5677986179664364 tf.Tensor(2750.7568, shape=(), dtype=float32) 1013
# slice = test, score = 0.5677986179664364
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.6096 tf.Tensor(2949.1555, shape=(), dtype=float32) 100
# slice = key, score = 0.6096
# np.mean(results), mse, len(results) =  0.6198318584070797 tf.Tensor(2966.664, shape=(), dtype=float32) 2260
# slice = train, score = 0.6198318584070797
# np.mean(results), mse, len(results) =  0.5681046396841066 tf.Tensor(2964.0776, shape=(), dtype=float32) 1013
# slice = test, score = 0.5681046396841066
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.6038 tf.Tensor(3274.3967, shape=(), dtype=float32) 100
# slice = key, score = 0.6038
# np.mean(results), mse, len(results) =  0.6196858407079646 tf.Tensor(3229.2053, shape=(), dtype=float32) 2260
# slice = train, score = 0.6196858407079646
# np.mean(results), mse, len(results) =  0.5680157946692991 tf.Tensor(3241.1455, shape=(), dtype=float32) 1013
# slice = test, score = 0.5680157946692991
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.6046 tf.Tensor(3360.645, shape=(), dtype=float32) 100
# slice = key, score = 0.6046
# np.mean(results), mse, len(results) =  0.6183362831858408 tf.Tensor(3354.0503, shape=(), dtype=float32) 2260
# slice = train, score = 0.6183362831858408
# np.mean(results), mse, len(results) =  0.5662191510365252 tf.Tensor(3356.5498, shape=(), dtype=float32) 1013
# slice = test, score = 0.5662191510365252
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.601 tf.Tensor(3588.9304, shape=(), dtype=float32) 100
# slice = key, score = 0.601
# np.mean(results), mse, len(results) =  0.6184867256637169 tf.Tensor(3576.4812, shape=(), dtype=float32) 2260
# slice = train, score = 0.6184867256637169
# np.mean(results), mse, len(results) =  0.5671569595261599 tf.Tensor(3584.9834, shape=(), dtype=float32) 1013
# slice = test, score = 0.5671569595261599
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.6034 tf.Tensor(3757.8713, shape=(), dtype=float32) 100
# slice = key, score = 0.6034
# np.mean(results), mse, len(results) =  0.6206061946902656 tf.Tensor(3727.7668, shape=(), dtype=float32) 2260
# slice = train, score = 0.6206061946902656
# np.mean(results), mse, len(results) =  0.567522211253702 tf.Tensor(3742.2622, shape=(), dtype=float32) 1013
# slice = test, score = 0.567522211253702
# np.mean(results), mse, len(results) =  0.6206061946902656 tf.Tensor(3727.7668, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.567522211253702 tf.Tensor(3742.2622, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6206_0.5675.npz ...
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.6126999999999999 tf.Tensor(4058.162, shape=(), dtype=float32) 100
# slice = key, score = 0.6126999999999999
# np.mean(results), mse, len(results) =  0.6229292035398231 tf.Tensor(4029.1997, shape=(), dtype=float32) 2260
# slice = train, score = 0.6229292035398231
# np.mean(results), mse, len(results) =  0.5698617966436328 tf.Tensor(4051.396, shape=(), dtype=float32) 1013
# slice = test, score = 0.5698617966436328
# np.mean(results), mse, len(results) =  0.6229292035398231 tf.Tensor(4029.1997, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5698617966436328 tf.Tensor(4051.396, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6229_0.5699.npz ...
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.6097 tf.Tensor(4202.851, shape=(), dtype=float32) 100
# slice = key, score = 0.6097
# np.mean(results), mse, len(results) =  0.6219115044247787 tf.Tensor(4170.21, shape=(), dtype=float32) 2260
# slice = train, score = 0.6219115044247787
# np.mean(results), mse, len(results) =  0.5691312931885488 tf.Tensor(4167.917, shape=(), dtype=float32) 1013
# slice = test, score = 0.5691312931885488
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6144999999999999 tf.Tensor(4412.225, shape=(), dtype=float32) 100
# slice = key, score = 0.6144999999999999
# np.mean(results), mse, len(results) =  0.6239380530973451 tf.Tensor(4386.4907, shape=(), dtype=float32) 2260
# slice = train, score = 0.6239380530973451
# np.mean(results), mse, len(results) =  0.5699111549851925 tf.Tensor(4389.3657, shape=(), dtype=float32) 1013
# slice = test, score = 0.5699111549851925
# np.mean(results), mse, len(results) =  0.6239380530973451 tf.Tensor(4386.4907, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5699111549851925 tf.Tensor(4389.3657, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6239_0.5699.npz ...
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.6112 tf.Tensor(4670.4253, shape=(), dtype=float32) 100
# slice = key, score = 0.6112
# np.mean(results), mse, len(results) =  0.6240309734513274 tf.Tensor(4652.8115, shape=(), dtype=float32) 2260
# slice = train, score = 0.6240309734513274
# np.mean(results), mse, len(results) =  0.5710463968410662 tf.Tensor(4655.047, shape=(), dtype=float32) 1013
# slice = test, score = 0.5710463968410662
# np.mean(results), mse, len(results) =  0.6240309734513274 tf.Tensor(4652.8115, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5710463968410662 tf.Tensor(4655.047, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.624_0.571.npz ...
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.6112000000000001 tf.Tensor(4957.242, shape=(), dtype=float32) 100
# slice = key, score = 0.6112000000000001
# np.mean(results), mse, len(results) =  0.6247699115044247 tf.Tensor(4917.5513, shape=(), dtype=float32) 2260
# slice = train, score = 0.6247699115044247
# np.mean(results), mse, len(results) =  0.5691411648568607 tf.Tensor(4913.623, shape=(), dtype=float32) 1013
# slice = test, score = 0.5691411648568607
# np.mean(results), mse, len(results) =  0.6247699115044247 tf.Tensor(4917.5513, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5691411648568607 tf.Tensor(4913.623, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6248_0.5691.npz ...
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.6142 tf.Tensor(5165.192, shape=(), dtype=float32) 100
# slice = key, score = 0.6142
# np.mean(results), mse, len(results) =  0.6266150442477877 tf.Tensor(5122.7983, shape=(), dtype=float32) 2260
# slice = train, score = 0.6266150442477877
# np.mean(results), mse, len(results) =  0.5735241855873643 tf.Tensor(5135.313, shape=(), dtype=float32) 1013
# slice = test, score = 0.5735241855873643
# np.mean(results), mse, len(results) =  0.6266150442477877 tf.Tensor(5122.7983, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5735241855873643 tf.Tensor(5135.313, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6266_0.5735.npz ...
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.612 tf.Tensor(5391.1978, shape=(), dtype=float32) 100
# slice = key, score = 0.612
# np.mean(results), mse, len(results) =  0.6251017699115045 tf.Tensor(5390.7676, shape=(), dtype=float32) 2260
# slice = train, score = 0.6251017699115045
# np.mean(results), mse, len(results) =  0.5693682132280355 tf.Tensor(5401.2397, shape=(), dtype=float32) 1013
# slice = test, score = 0.5693682132280355
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.6128 tf.Tensor(5780.507, shape=(), dtype=float32) 100
# slice = key, score = 0.6128
# np.mean(results), mse, len(results) =  0.6260044247787611 tf.Tensor(5758.876, shape=(), dtype=float32) 2260
# slice = train, score = 0.6260044247787611
# np.mean(results), mse, len(results) =  0.5717571569595262 tf.Tensor(5772.519, shape=(), dtype=float32) 1013
# slice = test, score = 0.5717571569595262
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.6168 tf.Tensor(5928.598, shape=(), dtype=float32) 100
# slice = key, score = 0.6168
# np.mean(results), mse, len(results) =  0.6270088495575221 tf.Tensor(5888.4336, shape=(), dtype=float32) 2260
# slice = train, score = 0.6270088495575221
# np.mean(results), mse, len(results) =  0.5727936821322803 tf.Tensor(5901.111, shape=(), dtype=float32) 1013
# slice = test, score = 0.5727936821322803
# np.mean(results), mse, len(results) =  0.6270088495575221 tf.Tensor(5888.4336, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5727936821322803 tf.Tensor(5901.111, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.627_0.5728.npz ...
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.6138999999999999 tf.Tensor(6140.2935, shape=(), dtype=float32) 100
# slice = key, score = 0.6138999999999999
# np.mean(results), mse, len(results) =  0.6235088495575222 tf.Tensor(6112.3955, shape=(), dtype=float32) 2260
# slice = train, score = 0.6235088495575222
# np.mean(results), mse, len(results) =  0.5686080947680158 tf.Tensor(6122.6543, shape=(), dtype=float32) 1013
# slice = test, score = 0.5686080947680158
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.6119 tf.Tensor(6340.3613, shape=(), dtype=float32) 100
# slice = key, score = 0.6119
# np.mean(results), mse, len(results) =  0.6251858407079646 tf.Tensor(6412.777, shape=(), dtype=float32) 2260
# slice = train, score = 0.6251858407079646
# np.mean(results), mse, len(results) =  0.569486673247779 tf.Tensor(6434.5264, shape=(), dtype=float32) 1013
# slice = test, score = 0.569486673247779
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.6153 tf.Tensor(6728.318, shape=(), dtype=float32) 100
# slice = key, score = 0.6153
# np.mean(results), mse, len(results) =  0.6277610619469025 tf.Tensor(6675.3076, shape=(), dtype=float32) 2260
# slice = train, score = 0.6277610619469025
# np.mean(results), mse, len(results) =  0.5710266535044423 tf.Tensor(6694.2383, shape=(), dtype=float32) 1013
# slice = test, score = 0.5710266535044423
# np.mean(results), mse, len(results) =  0.6277610619469025 tf.Tensor(6675.3076, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5710266535044423 tf.Tensor(6694.2383, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6278_0.571.npz ...
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.6101 tf.Tensor(6917.0483, shape=(), dtype=float32) 100
# slice = key, score = 0.6101
# np.mean(results), mse, len(results) =  0.626504424778761 tf.Tensor(6938.1816, shape=(), dtype=float32) 2260
# slice = train, score = 0.626504424778761
# np.mean(results), mse, len(results) =  0.5691214215202369 tf.Tensor(6967.9736, shape=(), dtype=float32) 1013
# slice = test, score = 0.5691214215202369
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.6124 tf.Tensor(7067.271, shape=(), dtype=float32) 100
# slice = key, score = 0.6124
# np.mean(results), mse, len(results) =  0.626429203539823 tf.Tensor(7095.0547, shape=(), dtype=float32) 2260
# slice = train, score = 0.626429203539823
# np.mean(results), mse, len(results) =  0.5713129318854887 tf.Tensor(7102.3574, shape=(), dtype=float32) 1013
# slice = test, score = 0.5713129318854887
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.6108 tf.Tensor(7545.862, shape=(), dtype=float32) 100
# slice = key, score = 0.6108
# np.mean(results), mse, len(results) =  0.6285663716814159 tf.Tensor(7435.5093, shape=(), dtype=float32) 2260
# slice = train, score = 0.6285663716814159
# np.mean(results), mse, len(results) =  0.5710463968410661 tf.Tensor(7454.3647, shape=(), dtype=float32) 1013
# slice = test, score = 0.5710463968410661
# np.mean(results), mse, len(results) =  0.6285663716814159 tf.Tensor(7435.5093, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5710463968410661 tf.Tensor(7454.3647, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6286_0.571.npz ...
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.6134999999999999 tf.Tensor(7693.8525, shape=(), dtype=float32) 100
# slice = key, score = 0.6134999999999999
# np.mean(results), mse, len(results) =  0.6288230088495576 tf.Tensor(7648.1313, shape=(), dtype=float32) 2260
# slice = train, score = 0.6288230088495576
# np.mean(results), mse, len(results) =  0.5725370187561698 tf.Tensor(7653.555, shape=(), dtype=float32) 1013
# slice = test, score = 0.5725370187561698
# np.mean(results), mse, len(results) =  0.6288230088495576 tf.Tensor(7648.1313, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5725370187561698 tf.Tensor(7653.555, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6288_0.5725.npz ...
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.6154000000000002 tf.Tensor(7775.0, shape=(), dtype=float32) 100
# slice = key, score = 0.6154000000000002
# np.mean(results), mse, len(results) =  0.6278938053097345 tf.Tensor(7825.2095, shape=(), dtype=float32) 2260
# slice = train, score = 0.6278938053097345
# np.mean(results), mse, len(results) =  0.5699605133267522 tf.Tensor(7806.0825, shape=(), dtype=float32) 1013
# slice = test, score = 0.5699605133267522
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.6141000000000001 tf.Tensor(8411.095, shape=(), dtype=float32) 100
# slice = key, score = 0.6141000000000001
# np.mean(results), mse, len(results) =  0.6294601769911505 tf.Tensor(8394.247, shape=(), dtype=float32) 2260
# slice = train, score = 0.6294601769911505
# np.mean(results), mse, len(results) =  0.571954590325765 tf.Tensor(8461.002, shape=(), dtype=float32) 1013
# slice = test, score = 0.571954590325765
# np.mean(results), mse, len(results) =  0.6294601769911505 tf.Tensor(8394.247, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.571954590325765 tf.Tensor(8461.002, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6295_0.572.npz ...
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.6152 tf.Tensor(8602.315, shape=(), dtype=float32) 100
# slice = key, score = 0.6152
# np.mean(results), mse, len(results) =  0.6293893805309735 tf.Tensor(8608.45, shape=(), dtype=float32) 2260
# slice = train, score = 0.6293893805309735
# np.mean(results), mse, len(results) =  0.5709772951628826 tf.Tensor(8621.162, shape=(), dtype=float32) 1013
# slice = test, score = 0.5709772951628826
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.6122000000000001 tf.Tensor(8909.851, shape=(), dtype=float32) 100
# slice = key, score = 0.6122000000000001
# np.mean(results), mse, len(results) =  0.6266150442477877 tf.Tensor(8823.351, shape=(), dtype=float32) 2260
# slice = train, score = 0.6266150442477877
# np.mean(results), mse, len(results) =  0.5674728529121422 tf.Tensor(8872.487, shape=(), dtype=float32) 1013
# slice = test, score = 0.5674728529121422
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.6113999999999999 tf.Tensor(9498.245, shape=(), dtype=float32) 100
# slice = key, score = 0.6113999999999999
# np.mean(results), mse, len(results) =  0.6269601769911504 tf.Tensor(9368.97, shape=(), dtype=float32) 2260
# slice = train, score = 0.6269601769911504
# np.mean(results), mse, len(results) =  0.5699012833168805 tf.Tensor(9409.395, shape=(), dtype=float32) 1013
# slice = test, score = 0.5699012833168805
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.6205999999999999 tf.Tensor(9702.602, shape=(), dtype=float32) 100
# slice = key, score = 0.6205999999999999
# np.mean(results), mse, len(results) =  0.6290132743362833 tf.Tensor(9644.666, shape=(), dtype=float32) 2260
# slice = train, score = 0.6290132743362833
# np.mean(results), mse, len(results) =  0.5688450148075025 tf.Tensor(9657.566, shape=(), dtype=float32) 1013
# slice = test, score = 0.5688450148075025
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.6206 tf.Tensor(10147.553, shape=(), dtype=float32) 100
# slice = key, score = 0.6206
# np.mean(results), mse, len(results) =  0.6298716814159292 tf.Tensor(10104.615, shape=(), dtype=float32) 2260
# slice = train, score = 0.6298716814159292
# np.mean(results), mse, len(results) =  0.5704738400789732 tf.Tensor(10181.53, shape=(), dtype=float32) 1013
# slice = test, score = 0.5704738400789732
# np.mean(results), mse, len(results) =  0.6298716814159292 tf.Tensor(10104.615, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5704738400789732 tf.Tensor(10181.53, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6299_0.5705.npz ...
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.6148 tf.Tensor(10169.435, shape=(), dtype=float32) 100
# slice = key, score = 0.6148
# np.mean(results), mse, len(results) =  0.6290309734513275 tf.Tensor(10236.6, shape=(), dtype=float32) 2260
# slice = train, score = 0.6290309734513275
# np.mean(results), mse, len(results) =  0.5706219151036525 tf.Tensor(10229.05, shape=(), dtype=float32) 1013
# slice = test, score = 0.5706219151036525
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.6178 tf.Tensor(10299.105, shape=(), dtype=float32) 100
# slice = key, score = 0.6178
# np.mean(results), mse, len(results) =  0.6298274336283185 tf.Tensor(10308.1, shape=(), dtype=float32) 2260
# slice = train, score = 0.6298274336283185
# np.mean(results), mse, len(results) =  0.569486673247779 tf.Tensor(10347.785, shape=(), dtype=float32) 1013
# slice = test, score = 0.569486673247779
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.6172 tf.Tensor(10819.373, shape=(), dtype=float32) 100
# slice = key, score = 0.6172
# np.mean(results), mse, len(results) =  0.6304513274336284 tf.Tensor(10712.308, shape=(), dtype=float32) 2260
# slice = train, score = 0.6304513274336284
# np.mean(results), mse, len(results) =  0.5702270483711749 tf.Tensor(10738.986, shape=(), dtype=float32) 1013
# slice = test, score = 0.5702270483711749
# np.mean(results), mse, len(results) =  0.6304513274336284 tf.Tensor(10712.308, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5702270483711749 tf.Tensor(10738.986, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6305_0.5702.npz ...
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.6115999999999999 tf.Tensor(11364.605, shape=(), dtype=float32) 100
# slice = key, score = 0.6115999999999999
# np.mean(results), mse, len(results) =  0.627070796460177 tf.Tensor(11233.687, shape=(), dtype=float32) 2260
# slice = train, score = 0.627070796460177
# np.mean(results), mse, len(results) =  0.5686179664363278 tf.Tensor(11295.318, shape=(), dtype=float32) 1013
# slice = test, score = 0.5686179664363278
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.6209 tf.Tensor(11475.282, shape=(), dtype=float32) 100
# slice = key, score = 0.6209
# np.mean(results), mse, len(results) =  0.6313495575221238 tf.Tensor(11491.726, shape=(), dtype=float32) 2260
# slice = train, score = 0.6313495575221238
# np.mean(results), mse, len(results) =  0.5710562685093781 tf.Tensor(11513.024, shape=(), dtype=float32) 1013
# slice = test, score = 0.5710562685093781
# np.mean(results), mse, len(results) =  0.6313495575221238 tf.Tensor(11491.726, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5710562685093781 tf.Tensor(11513.024, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6313_0.5711.npz ...
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.6182 tf.Tensor(12057.172, shape=(), dtype=float32) 100
# slice = key, score = 0.6182
# np.mean(results), mse, len(results) =  0.6315929203539823 tf.Tensor(11981.75, shape=(), dtype=float32) 2260
# slice = train, score = 0.6315929203539823
# np.mean(results), mse, len(results) =  0.5711154985192497 tf.Tensor(11992.451, shape=(), dtype=float32) 1013
# slice = test, score = 0.5711154985192497
# np.mean(results), mse, len(results) =  0.6315929203539823 tf.Tensor(11981.75, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5711154985192497 tf.Tensor(11992.451, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6316_0.5711.npz ...
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.6187999999999999 tf.Tensor(12067.458, shape=(), dtype=float32) 100
# slice = key, score = 0.6187999999999999
# np.mean(results), mse, len(results) =  0.6290973451327434 tf.Tensor(12159.599, shape=(), dtype=float32) 2260
# slice = train, score = 0.6290973451327434
# np.mean(results), mse, len(results) =  0.5710365251727542 tf.Tensor(12165.218, shape=(), dtype=float32) 1013
# slice = test, score = 0.5710365251727542
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.6148 tf.Tensor(12865.991, shape=(), dtype=float32) 100
# slice = key, score = 0.6148
# np.mean(results), mse, len(results) =  0.6288451327433628 tf.Tensor(12981.831, shape=(), dtype=float32) 2260
# slice = train, score = 0.6288451327433628
# np.mean(results), mse, len(results) =  0.5685982230997039 tf.Tensor(12964.026, shape=(), dtype=float32) 1013
# slice = test, score = 0.5685982230997039
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6182 tf.Tensor(12938.517, shape=(), dtype=float32) 100
# slice = key, score = 0.6182
# np.mean(results), mse, len(results) =  0.6314557522123894 tf.Tensor(12978.427, shape=(), dtype=float32) 2260
# slice = train, score = 0.6314557522123894
# np.mean(results), mse, len(results) =  0.571263573543929 tf.Tensor(12959.586, shape=(), dtype=float32) 1013
# slice = test, score = 0.571263573543929
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.6175999999999999 tf.Tensor(13602.01, shape=(), dtype=float32) 100
# slice = key, score = 0.6175999999999999
# np.mean(results), mse, len(results) =  0.6312610619469027 tf.Tensor(13463.442, shape=(), dtype=float32) 2260
# slice = train, score = 0.6312610619469027
# np.mean(results), mse, len(results) =  0.569832181638697 tf.Tensor(13517.319, shape=(), dtype=float32) 1013
# slice = test, score = 0.569832181638697
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.6167 tf.Tensor(13911.171, shape=(), dtype=float32) 100
# slice = key, score = 0.6167
# np.mean(results), mse, len(results) =  0.6291991150442477 tf.Tensor(13777.622, shape=(), dtype=float32) 2260
# slice = train, score = 0.6291991150442477
# np.mean(results), mse, len(results) =  0.5698025666337612 tf.Tensor(13887.167, shape=(), dtype=float32) 1013
# slice = test, score = 0.5698025666337612
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6164000000000001 tf.Tensor(14411.109, shape=(), dtype=float32) 100
# slice = key, score = 0.6164000000000001
# np.mean(results), mse, len(results) =  0.6294734513274337 tf.Tensor(14428.636, shape=(), dtype=float32) 2260
# slice = train, score = 0.6294734513274337
# np.mean(results), mse, len(results) =  0.5700888450148075 tf.Tensor(14505.092, shape=(), dtype=float32) 1013
# slice = test, score = 0.5700888450148075
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6199999999999999 tf.Tensor(14474.509, shape=(), dtype=float32) 100
# slice = key, score = 0.6199999999999999
# np.mean(results), mse, len(results) =  0.6305707964601771 tf.Tensor(14308.645, shape=(), dtype=float32) 2260
# slice = train, score = 0.6305707964601771
# np.mean(results), mse, len(results) =  0.5702171767028629 tf.Tensor(14400.77, shape=(), dtype=float32) 1013
# slice = test, score = 0.5702171767028629
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.6181000000000001 tf.Tensor(15044.443, shape=(), dtype=float32) 100
# slice = key, score = 0.6181000000000001
# np.mean(results), mse, len(results) =  0.6296017699115045 tf.Tensor(14972.279, shape=(), dtype=float32) 2260
# slice = train, score = 0.6296017699115045
# np.mean(results), mse, len(results) =  0.5694373149062192 tf.Tensor(15021.316, shape=(), dtype=float32) 1013
# slice = test, score = 0.5694373149062192
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.6162 tf.Tensor(15032.709, shape=(), dtype=float32) 100
# slice = key, score = 0.6162
# np.mean(results), mse, len(results) =  0.6310929203539823 tf.Tensor(15070.926, shape=(), dtype=float32) 2260
# slice = train, score = 0.6310929203539823
# np.mean(results), mse, len(results) =  0.5705133267522212 tf.Tensor(15157.944, shape=(), dtype=float32) 1013
# slice = test, score = 0.5705133267522212
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.6161 tf.Tensor(16092.057, shape=(), dtype=float32) 100
# slice = key, score = 0.6161
# np.mean(results), mse, len(results) =  0.6315486725663717 tf.Tensor(16026.416, shape=(), dtype=float32) 2260
# slice = train, score = 0.6315486725663717
# np.mean(results), mse, len(results) =  0.5710069101678183 tf.Tensor(16097.0, shape=(), dtype=float32) 1013
# slice = test, score = 0.5710069101678183
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.6193000000000001 tf.Tensor(16696.531, shape=(), dtype=float32) 100
# slice = key, score = 0.6193000000000001
# np.mean(results), mse, len(results) =  0.6324867256637169 tf.Tensor(16460.809, shape=(), dtype=float32) 2260
# slice = train, score = 0.6324867256637169
# np.mean(results), mse, len(results) =  0.5714215202369202 tf.Tensor(16598.896, shape=(), dtype=float32) 1013
# slice = test, score = 0.5714215202369202
# np.mean(results), mse, len(results) =  0.6324867256637169 tf.Tensor(16460.809, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5714215202369202 tf.Tensor(16598.896, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6325_0.5714.npz ...
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.6202 tf.Tensor(16756.453, shape=(), dtype=float32) 100
# slice = key, score = 0.6202
# np.mean(results), mse, len(results) =  0.6336283185840708 tf.Tensor(16600.262, shape=(), dtype=float32) 2260
# slice = train, score = 0.6336283185840708
# np.mean(results), mse, len(results) =  0.5723593287265547 tf.Tensor(16683.47, shape=(), dtype=float32) 1013
# slice = test, score = 0.5723593287265547
# np.mean(results), mse, len(results) =  0.6336283185840708 tf.Tensor(16600.262, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5723593287265547 tf.Tensor(16683.47, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6336_0.5724.npz ...
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.6197 tf.Tensor(16897.936, shape=(), dtype=float32) 100
# slice = key, score = 0.6197
# np.mean(results), mse, len(results) =  0.6325929203539823 tf.Tensor(16824.988, shape=(), dtype=float32) 2260
# slice = train, score = 0.6325929203539823
# np.mean(results), mse, len(results) =  0.5722704837117473 tf.Tensor(16957.814, shape=(), dtype=float32) 1013
# slice = test, score = 0.5722704837117473
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.6194 tf.Tensor(17424.992, shape=(), dtype=float32) 100
# slice = key, score = 0.6194
# np.mean(results), mse, len(results) =  0.6329380530973452 tf.Tensor(17384.344, shape=(), dtype=float32) 2260
# slice = train, score = 0.6329380530973452
# np.mean(results), mse, len(results) =  0.5727541954590325 tf.Tensor(17467.615, shape=(), dtype=float32) 1013
# slice = test, score = 0.5727541954590325
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.6131000000000001 tf.Tensor(18322.41, shape=(), dtype=float32) 100
# slice = key, score = 0.6131000000000001
# np.mean(results), mse, len(results) =  0.6303938053097345 tf.Tensor(18074.564, shape=(), dtype=float32) 2260
# slice = train, score = 0.6303938053097345
# np.mean(results), mse, len(results) =  0.5706219151036525 tf.Tensor(18315.924, shape=(), dtype=float32) 1013
# slice = test, score = 0.5706219151036525
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.6187999999999999 tf.Tensor(19049.008, shape=(), dtype=float32) 100
# slice = key, score = 0.6187999999999999
# np.mean(results), mse, len(results) =  0.6317566371681416 tf.Tensor(18852.488, shape=(), dtype=float32) 2260
# slice = train, score = 0.6317566371681416
# np.mean(results), mse, len(results) =  0.5709772951628826 tf.Tensor(19052.725, shape=(), dtype=float32) 1013
# slice = test, score = 0.5709772951628826
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.6185 tf.Tensor(19102.951, shape=(), dtype=float32) 100
# slice = key, score = 0.6185
# np.mean(results), mse, len(results) =  0.6310353982300885 tf.Tensor(18991.049, shape=(), dtype=float32) 2260
# slice = train, score = 0.6310353982300885
# np.mean(results), mse, len(results) =  0.5678183613030603 tf.Tensor(19127.387, shape=(), dtype=float32) 1013
# slice = test, score = 0.5678183613030603
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6174 tf.Tensor(19829.592, shape=(), dtype=float32) 100
# slice = key, score = 0.6174
# np.mean(results), mse, len(results) =  0.6339070796460177 tf.Tensor(19626.752, shape=(), dtype=float32) 2260
# slice = train, score = 0.6339070796460177
# np.mean(results), mse, len(results) =  0.5708489634748273 tf.Tensor(19768.455, shape=(), dtype=float32) 1013
# slice = test, score = 0.5708489634748273
# np.mean(results), mse, len(results) =  0.6339070796460177 tf.Tensor(19626.752, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5708489634748273 tf.Tensor(19768.455, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6339_0.5708.npz ...
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.6184999999999999 tf.Tensor(20149.994, shape=(), dtype=float32) 100
# slice = key, score = 0.6184999999999999
# np.mean(results), mse, len(results) =  0.632853982300885 tf.Tensor(19900.723, shape=(), dtype=float32) 2260
# slice = train, score = 0.632853982300885
# np.mean(results), mse, len(results) =  0.5733859822309969 tf.Tensor(20037.305, shape=(), dtype=float32) 1013
# slice = test, score = 0.5733859822309969
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.6202000000000001 tf.Tensor(21581.725, shape=(), dtype=float32) 100
# slice = key, score = 0.6202000000000001
# np.mean(results), mse, len(results) =  0.6334292035398231 tf.Tensor(21163.602, shape=(), dtype=float32) 2260
# slice = train, score = 0.6334292035398231
# np.mean(results), mse, len(results) =  0.5713820335636722 tf.Tensor(21121.846, shape=(), dtype=float32) 1013
# slice = test, score = 0.5713820335636722
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.6185 tf.Tensor(22493.754, shape=(), dtype=float32) 100
# slice = key, score = 0.6185
# np.mean(results), mse, len(results) =  0.6342566371681415 tf.Tensor(21871.58, shape=(), dtype=float32) 2260
# slice = train, score = 0.6342566371681415
# np.mean(results), mse, len(results) =  0.5712833168805529 tf.Tensor(22060.994, shape=(), dtype=float32) 1013
# slice = test, score = 0.5712833168805529
# np.mean(results), mse, len(results) =  0.6342566371681415 tf.Tensor(21871.58, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5712833168805529 tf.Tensor(22060.994, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6343_0.5713.npz ...
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.619 tf.Tensor(22070.7, shape=(), dtype=float32) 100
# slice = key, score = 0.619
# np.mean(results), mse, len(results) =  0.6334115044247789 tf.Tensor(21533.408, shape=(), dtype=float32) 2260
# slice = train, score = 0.6334115044247789
# np.mean(results), mse, len(results) =  0.5690621915103653 tf.Tensor(21610.95, shape=(), dtype=float32) 1013
# slice = test, score = 0.5690621915103653
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6215999999999999 tf.Tensor(22629.797, shape=(), dtype=float32) 100
# slice = key, score = 0.6215999999999999
# np.mean(results), mse, len(results) =  0.6341681415929203 tf.Tensor(22237.943, shape=(), dtype=float32) 2260
# slice = train, score = 0.6341681415929203
# np.mean(results), mse, len(results) =  0.5701382033563673 tf.Tensor(22468.002, shape=(), dtype=float32) 1013
# slice = test, score = 0.5701382033563673
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(23547.182, shape=(), dtype=float32) 100
# slice = key, score = 0.6203
# np.mean(results), mse, len(results) =  0.6344336283185841 tf.Tensor(22849.008, shape=(), dtype=float32) 2260
# slice = train, score = 0.6344336283185841
# np.mean(results), mse, len(results) =  0.5723593287265547 tf.Tensor(22971.828, shape=(), dtype=float32) 1013
# slice = test, score = 0.5723593287265547
# np.mean(results), mse, len(results) =  0.6344336283185841 tf.Tensor(22849.008, shape=(), dtype=float32) 2260
# np.mean(results), mse, len(results) =  0.5723593287265547 tf.Tensor(22971.828, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6344_0.5724.npz ...
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6211 tf.Tensor(24070.312, shape=(), dtype=float32) 100
# slice = key, score = 0.6211
# np.mean(results), mse, len(results) =  0.6321504424778761 tf.Tensor(23402.273, shape=(), dtype=float32) 2260
# slice = train, score = 0.6321504424778761
# np.mean(results), mse, len(results) =  0.5693287265547877 tf.Tensor(23506.42, shape=(), dtype=float32) 1013
# slice = test, score = 0.5693287265547877
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6235 tf.Tensor(24383.844, shape=(), dtype=float32) 100
# slice = key, score = 0.6235
# np.mean(results), mse, len(results) =  0.6354070796460176 tf.Tensor(23782.9, shape=(), dtype=float32) 2260
# slice = train, score = 0.6354070796460176
# ...
# slice = test, score = 0.3681954294720252
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.3806000000000001 tf.Tensor(14057.732, shape=(), dtype=float32) 100
# slice = key, score = 0.3806000000000001
# np.mean(results), mse, len(results) =  0.4070388519425971 tf.Tensor(13614.529, shape=(), dtype=float32) 2857
# slice = train, score = 0.4070388519425971
# np.mean(results), mse, len(results) =  0.3686524822695036 tf.Tensor(13545.819, shape=(), dtype=float32) 1269
# slice = test, score = 0.3686524822695036
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.3685 tf.Tensor(14892.998, shape=(), dtype=float32) 100
# slice = key, score = 0.3685
# np.mean(results), mse, len(results) =  0.40291914595729783 tf.Tensor(13886.061, shape=(), dtype=float32) 2857
# slice = train, score = 0.40291914595729783
# np.mean(results), mse, len(results) =  0.3669109535066982 tf.Tensor(13857.418, shape=(), dtype=float32) 1269
# slice = test, score = 0.3669109535066982
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.37929999999999997 tf.Tensor(15442.983, shape=(), dtype=float32) 100
# slice = key, score = 0.37929999999999997
# np.mean(results), mse, len(results) =  0.40968848442422123 tf.Tensor(14343.31, shape=(), dtype=float32) 2857
# slice = train, score = 0.40968848442422123
# np.mean(results), mse, len(results) =  0.37122143420015763 tf.Tensor(14290.128, shape=(), dtype=float32) 1269
# slice = test, score = 0.37122143420015763
# np.mean(results), mse, len(results) =  0.40968848442422123 tf.Tensor(14343.31, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.37122143420015763 tf.Tensor(14290.128, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.4097_0.3712.npz ...
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.3757 tf.Tensor(15954.057, shape=(), dtype=float32) 100
# slice = key, score = 0.3757
# np.mean(results), mse, len(results) =  0.4059397969898495 tf.Tensor(14916.675, shape=(), dtype=float32) 2857
# slice = train, score = 0.4059397969898495
# np.mean(results), mse, len(results) =  0.3683451536643026 tf.Tensor(14828.465, shape=(), dtype=float32) 1269
# slice = test, score = 0.3683451536643026
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.3759 tf.Tensor(16177.7295, shape=(), dtype=float32) 100
# slice = key, score = 0.3759
# np.mean(results), mse, len(results) =  0.4067238361918096 tf.Tensor(15417.207, shape=(), dtype=float32) 2857
# slice = train, score = 0.4067238361918096
# np.mean(results), mse, len(results) =  0.37010244286840027 tf.Tensor(15356.943, shape=(), dtype=float32) 1269
# slice = test, score = 0.37010244286840027
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.37060000000000015 tf.Tensor(16650.244, shape=(), dtype=float32) 100
# slice = key, score = 0.37060000000000015
# np.mean(results), mse, len(results) =  0.40187259362968153 tf.Tensor(16038.413, shape=(), dtype=float32) 2857
# slice = train, score = 0.40187259362968153
# np.mean(results), mse, len(results) =  0.3639558707643814 tf.Tensor(15917.583, shape=(), dtype=float32) 1269
# slice = test, score = 0.3639558707643814
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.37739999999999996 tf.Tensor(16451.133, shape=(), dtype=float32) 100
# slice = key, score = 0.37739999999999996
# np.mean(results), mse, len(results) =  0.40610430521526075 tf.Tensor(15355.926, shape=(), dtype=float32) 2857
# slice = train, score = 0.40610430521526075
# np.mean(results), mse, len(results) =  0.3679590228526398 tf.Tensor(15296.744, shape=(), dtype=float32) 1269
# slice = test, score = 0.3679590228526398
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.3721999999999999 tf.Tensor(17917.941, shape=(), dtype=float32) 100
# slice = key, score = 0.3721999999999999
# np.mean(results), mse, len(results) =  0.40323766188309423 tf.Tensor(16464.639, shape=(), dtype=float32) 2857
# slice = train, score = 0.40323766188309423
# np.mean(results), mse, len(results) =  0.3668794326241135 tf.Tensor(16448.4, shape=(), dtype=float32) 1269
# slice = test, score = 0.3668794326241135
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.3837000000000001 tf.Tensor(18987.373, shape=(), dtype=float32) 100
# slice = key, score = 0.3837000000000001
# np.mean(results), mse, len(results) =  0.4131431571578579 tf.Tensor(17628.365, shape=(), dtype=float32) 2857
# slice = train, score = 0.4131431571578579
# np.mean(results), mse, len(results) =  0.37334121355397953 tf.Tensor(17578.117, shape=(), dtype=float32) 1269
# slice = test, score = 0.37334121355397953
# np.mean(results), mse, len(results) =  0.4131431571578579 tf.Tensor(17628.365, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.37334121355397953 tf.Tensor(17578.117, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.4131_0.3733.npz ...
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.37060000000000004 tf.Tensor(18554.008, shape=(), dtype=float32) 100
# slice = key, score = 0.37060000000000004
# np.mean(results), mse, len(results) =  0.40622331116555827 tf.Tensor(17753.957, shape=(), dtype=float32) 2857
# slice = train, score = 0.40622331116555827
# np.mean(results), mse, len(results) =  0.36769897557131603 tf.Tensor(17720.28, shape=(), dtype=float32) 1269
# slice = test, score = 0.36769897557131603
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.3762 tf.Tensor(18508.783, shape=(), dtype=float32) 100
# slice = key, score = 0.3762
# np.mean(results), mse, len(results) =  0.4082009100455023 tf.Tensor(17839.83, shape=(), dtype=float32) 2857
# slice = train, score = 0.4082009100455023
# np.mean(results), mse, len(results) =  0.3703940110323089 tf.Tensor(17691.275, shape=(), dtype=float32) 1269
# slice = test, score = 0.3703940110323089
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.3801 tf.Tensor(20028.992, shape=(), dtype=float32) 100
# slice = key, score = 0.3801
# np.mean(results), mse, len(results) =  0.4083899194959748 tf.Tensor(18806.668, shape=(), dtype=float32) 2857
# slice = train, score = 0.4083899194959748
# np.mean(results), mse, len(results) =  0.369204097714736 tf.Tensor(18587.514, shape=(), dtype=float32) 1269
# slice = test, score = 0.369204097714736
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.3756999999999999 tf.Tensor(20012.285, shape=(), dtype=float32) 100
# slice = key, score = 0.3756999999999999
# np.mean(results), mse, len(results) =  0.40702135106755344 tf.Tensor(19144.46, shape=(), dtype=float32) 2857
# slice = train, score = 0.40702135106755344
# np.mean(results), mse, len(results) =  0.36889676910953506 tf.Tensor(18994.795, shape=(), dtype=float32) 1269
# slice = test, score = 0.36889676910953506
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.37760000000000005 tf.Tensor(20423.936, shape=(), dtype=float32) 100
# slice = key, score = 0.37760000000000005
# np.mean(results), mse, len(results) =  0.4062723136156808 tf.Tensor(19787.799, shape=(), dtype=float32) 2857
# slice = train, score = 0.4062723136156808
# np.mean(results), mse, len(results) =  0.3669582348305752 tf.Tensor(19566.787, shape=(), dtype=float32) 1269
# slice = test, score = 0.3669582348305752
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.3753 tf.Tensor(20633.54, shape=(), dtype=float32) 100
# slice = key, score = 0.3753
# np.mean(results), mse, len(results) =  0.4068078403920196 tf.Tensor(19881.074, shape=(), dtype=float32) 2857
# slice = train, score = 0.4068078403920196
# np.mean(results), mse, len(results) =  0.36851063829787234 tf.Tensor(19708.424, shape=(), dtype=float32) 1269
# slice = test, score = 0.36851063829787234
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.37309999999999993 tf.Tensor(20719.945, shape=(), dtype=float32) 100
# slice = key, score = 0.37309999999999993
# np.mean(results), mse, len(results) =  0.40295764788239413 tf.Tensor(19559.916, shape=(), dtype=float32) 2857
# slice = train, score = 0.40295764788239413
# np.mean(results), mse, len(results) =  0.36481481481481487 tf.Tensor(19519.355, shape=(), dtype=float32) 1269
# slice = test, score = 0.36481481481481487
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.3808 tf.Tensor(22126.023, shape=(), dtype=float32) 100
# slice = key, score = 0.3808
# np.mean(results), mse, len(results) =  0.408022401120056 tf.Tensor(20898.406, shape=(), dtype=float32) 2857
# slice = train, score = 0.408022401120056
# np.mean(results), mse, len(results) =  0.37077226162332544 tf.Tensor(20850.186, shape=(), dtype=float32) 1269
# slice = test, score = 0.37077226162332544
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.37279999999999996 tf.Tensor(22888.05, shape=(), dtype=float32) 100
# slice = key, score = 0.37279999999999996
# np.mean(results), mse, len(results) =  0.4050507525376269 tf.Tensor(21518.041, shape=(), dtype=float32) 2857
# slice = train, score = 0.4050507525376269
# np.mean(results), mse, len(results) =  0.36730496453900713 tf.Tensor(21314.07, shape=(), dtype=float32) 1269
# slice = test, score = 0.36730496453900713
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.37320000000000014 tf.Tensor(22641.795, shape=(), dtype=float32) 100
# slice = key, score = 0.37320000000000014
# np.mean(results), mse, len(results) =  0.4066853342667134 tf.Tensor(21320.7, shape=(), dtype=float32) 2857
# slice = train, score = 0.4066853342667134
# np.mean(results), mse, len(results) =  0.36988179669030735 tf.Tensor(21156.031, shape=(), dtype=float32) 1269
# slice = test, score = 0.36988179669030735
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.37300000000000005 tf.Tensor(24415.848, shape=(), dtype=float32) 100
# slice = key, score = 0.37300000000000005
# np.mean(results), mse, len(results) =  0.40498074903745185 tf.Tensor(22948.582, shape=(), dtype=float32) 2857
# slice = train, score = 0.40498074903745185
# np.mean(results), mse, len(results) =  0.36646178092986603 tf.Tensor(22739.771, shape=(), dtype=float32) 1269
# slice = test, score = 0.36646178092986603
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.3768 tf.Tensor(24454.97, shape=(), dtype=float32) 100
# slice = key, score = 0.3768
# np.mean(results), mse, len(results) =  0.40717885894294714 tf.Tensor(22887.02, shape=(), dtype=float32) 2857
# slice = train, score = 0.40717885894294714
# np.mean(results), mse, len(results) =  0.36842395587076443 tf.Tensor(22626.56, shape=(), dtype=float32) 1269
# slice = test, score = 0.36842395587076443
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.3807 tf.Tensor(25081.79, shape=(), dtype=float32) 100
# slice = key, score = 0.3807
# np.mean(results), mse, len(results) =  0.4073608680434022 tf.Tensor(23720.473, shape=(), dtype=float32) 2857
# slice = train, score = 0.4073608680434022
# np.mean(results), mse, len(results) =  0.36981875492513794 tf.Tensor(23674.41, shape=(), dtype=float32) 1269
# slice = test, score = 0.36981875492513794
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.3727000000000001 tf.Tensor(24971.238, shape=(), dtype=float32) 100
# slice = key, score = 0.3727000000000001
# np.mean(results), mse, len(results) =  0.4041302065103255 tf.Tensor(23773.807, shape=(), dtype=float32) 2857
# slice = train, score = 0.4041302065103255
# np.mean(results), mse, len(results) =  0.3672025216706068 tf.Tensor(23723.293, shape=(), dtype=float32) 1269
# slice = test, score = 0.3672025216706068
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.3824 tf.Tensor(26676.402, shape=(), dtype=float32) 100
# slice = key, score = 0.3824
# np.mean(results), mse, len(results) =  0.409957997899895 tf.Tensor(24753.217, shape=(), dtype=float32) 2857
# slice = train, score = 0.409957997899895
# np.mean(results), mse, len(results) =  0.3715839243498818 tf.Tensor(24654.895, shape=(), dtype=float32) 1269
# slice = test, score = 0.3715839243498818
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.37260000000000004 tf.Tensor(26495.205, shape=(), dtype=float32) 100
# slice = key, score = 0.37260000000000004
# np.mean(results), mse, len(results) =  0.4075813790689535 tf.Tensor(24762.635, shape=(), dtype=float32) 2857
# slice = train, score = 0.4075813790689535
# np.mean(results), mse, len(results) =  0.3697399527186761 tf.Tensor(24476.424, shape=(), dtype=float32) 1269
# slice = test, score = 0.3697399527186761
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.37139999999999995 tf.Tensor(26154.29, shape=(), dtype=float32) 100
# slice = key, score = 0.37139999999999995
# np.mean(results), mse, len(results) =  0.4072978648932447 tf.Tensor(25088.8, shape=(), dtype=float32) 2857
# slice = train, score = 0.4072978648932447
# np.mean(results), mse, len(results) =  0.36792750197005514 tf.Tensor(24889.322, shape=(), dtype=float32) 1269
# slice = test, score = 0.36792750197005514
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.37810000000000005 tf.Tensor(26765.467, shape=(), dtype=float32) 100
# slice = key, score = 0.37810000000000005
# np.mean(results), mse, len(results) =  0.4072838641932097 tf.Tensor(26078.533, shape=(), dtype=float32) 2857
# slice = train, score = 0.4072838641932097
# np.mean(results), mse, len(results) =  0.36895193065405835 tf.Tensor(25934.596, shape=(), dtype=float32) 1269
# slice = test, score = 0.36895193065405835
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.3766 tf.Tensor(27471.555, shape=(), dtype=float32) 100
# slice = key, score = 0.3766
# np.mean(results), mse, len(results) =  0.40918795939796987 tf.Tensor(26068.834, shape=(), dtype=float32) 2857
# slice = train, score = 0.40918795939796987
# np.mean(results), mse, len(results) =  0.37058313632781714 tf.Tensor(25745.467, shape=(), dtype=float32) 1269
# slice = test, score = 0.37058313632781714
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.37989999999999996 tf.Tensor(29208.117, shape=(), dtype=float32) 100
# slice = key, score = 0.37989999999999996
# np.mean(results), mse, len(results) =  0.4075603780189009 tf.Tensor(28050.455, shape=(), dtype=float32) 2857
# slice = train, score = 0.4075603780189009
# np.mean(results), mse, len(results) =  0.37 tf.Tensor(27712.111, shape=(), dtype=float32) 1269
# slice = test, score = 0.37
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.37839999999999996 tf.Tensor(28058.793, shape=(), dtype=float32) 100
# slice = key, score = 0.37839999999999996
# np.mean(results), mse, len(results) =  0.4077773888694435 tf.Tensor(27163.998, shape=(), dtype=float32) 2857
# slice = train, score = 0.4077773888694435
# np.mean(results), mse, len(results) =  0.36929078014184397 tf.Tensor(26841.56, shape=(), dtype=float32) 1269
# slice = test, score = 0.36929078014184397
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.3793000000000001 tf.Tensor(29943.402, shape=(), dtype=float32) 100
# slice = key, score = 0.3793000000000001
# np.mean(results), mse, len(results) =  0.4089639481974099 tf.Tensor(28042.17, shape=(), dtype=float32) 2857
# slice = train, score = 0.4089639481974099
# np.mean(results), mse, len(results) =  0.36981875492513794 tf.Tensor(27689.086, shape=(), dtype=float32) 1269
# slice = test, score = 0.36981875492513794
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.3789000000000001 tf.Tensor(33511.848, shape=(), dtype=float32) 100
# slice = key, score = 0.3789000000000001
# np.mean(results), mse, len(results) =  0.4103885194259713 tf.Tensor(31061.744, shape=(), dtype=float32) 2857
# slice = train, score = 0.4103885194259713
# np.mean(results), mse, len(results) =  0.37154452324665094 tf.Tensor(30685.848, shape=(), dtype=float32) 1269
# slice = test, score = 0.37154452324665094
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.3782 tf.Tensor(31388.746, shape=(), dtype=float32) 100
# slice = key, score = 0.3782
# np.mean(results), mse, len(results) =  0.41037451872593633 tf.Tensor(29702.438, shape=(), dtype=float32) 2857
# slice = train, score = 0.41037451872593633
# np.mean(results), mse, len(results) =  0.37167060677698976 tf.Tensor(29434.936, shape=(), dtype=float32) 1269
# slice = test, score = 0.37167060677698976

# %%
Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6364_0.5711.npz .. yugioh

Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.6228_0.5164.npz ... pro_wrestling

Saving ./GE_QE_RBExCoItem_RecSysLT_noW__0.4131_0.3733.npz ... star_trek ip
Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4119_0.3713.npz ...
Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4121_0.3715.npz ...

Saving ./GE_QE_RBExCoItem_doctor_who_noW__0.2951_0.2682.npz ..
Saving ./GE_QE_RBExCoItem_doctor_who_noW__0.3193_0.2866.npz ..

# %%
for dataset in DATASETS[2:]:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100,
        key_size=100
    )

    print("LOADED")
    
    do_RBE(ctx, f"{dataset}_noW_", N=200000, kmeans=False, top=False, random=False, train_matrix=False, inner_dim=200)
    
    del ctx
    gc.collect()
# Out:
# DATASET =  star_trek
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False4000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False0.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_27_n_e_34430_all_layers_False4200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1200.pkl
# Loaded shape =  (4227, 34430)
# Shuffling... (seed = 42)
# updated det (0, 1.2314701061114986e-33 -> 2.964262348140887e-30)
# updated det (3, 2.964262348140887e-30 -> 8.32734456022628e-28)
# updated det (5, 8.32734456022628e-28 -> 3.501918032693322e-27)
# updated det (7, 3.501918032693322e-27 -> 1.781987943310876e-26)
# updated det (11, 1.781987943310876e-26 -> 3.658797620704755e-24)
# Best det =  3.6587976e-24
# Current de =  3.6587976e-24
# 100 2857 1269
# LOADED
# /var/tmp/ipykernel_3238/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# self.embed_users['train'].shape =  (2857, 100)
# self.embed_games.shape =  (34430, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 34430)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (2857, 100)
# dssm_dim = 100, inner_dim=200
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.0165 tf.Tensor(35.388237, shape=(), dtype=float32) 100
# slice = key, score = 0.0165
# np.mean(results), mse, len(results) =  0.014700735036751837 tf.Tensor(33.817978, shape=(), dtype=float32) 2857
# slice = train, score = 0.014700735036751837
# np.mean(results), mse, len(results) =  0.014452324665090626 tf.Tensor(33.574436, shape=(), dtype=float32) 1269
# slice = test, score = 0.014452324665090626
# np.mean(results), mse, len(results) =  0.014700735036751837 tf.Tensor(33.817978, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.014452324665090626 tf.Tensor(33.574436, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.0147_0.0145.npz ...
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.3041 tf.Tensor(141.54605, shape=(), dtype=float32) 100
# slice = key, score = 0.3041
# np.mean(results), mse, len(results) =  0.34967798389919497 tf.Tensor(125.68036, shape=(), dtype=float32) 2857
# slice = train, score = 0.34967798389919497
# np.mean(results), mse, len(results) =  0.32945626477541373 tf.Tensor(127.50773, shape=(), dtype=float32) 1269
# slice = test, score = 0.32945626477541373
# np.mean(results), mse, len(results) =  0.34967798389919497 tf.Tensor(125.68036, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.32945626477541373 tf.Tensor(127.50773, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.3497_0.3295.npz ...
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.322 tf.Tensor(202.77664, shape=(), dtype=float32) 100
# slice = key, score = 0.322
# np.mean(results), mse, len(results) =  0.3629261463073154 tf.Tensor(184.63986, shape=(), dtype=float32) 2857
# slice = train, score = 0.3629261463073154
# np.mean(results), mse, len(results) =  0.3384003152088259 tf.Tensor(186.25273, shape=(), dtype=float32) 1269
# slice = test, score = 0.3384003152088259
# np.mean(results), mse, len(results) =  0.3629261463073154 tf.Tensor(184.63986, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.3384003152088259 tf.Tensor(186.25273, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.3629_0.3384.npz ...
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.3382 tf.Tensor(262.63144, shape=(), dtype=float32) 100
# slice = key, score = 0.3382
# np.mean(results), mse, len(results) =  0.37309765488274416 tf.Tensor(249.58241, shape=(), dtype=float32) 2857
# slice = train, score = 0.37309765488274416
# np.mean(results), mse, len(results) =  0.34535066981875495 tf.Tensor(251.24872, shape=(), dtype=float32) 1269
# slice = test, score = 0.34535066981875495
# np.mean(results), mse, len(results) =  0.37309765488274416 tf.Tensor(249.58241, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.34535066981875495 tf.Tensor(251.24872, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.3731_0.3454.npz ...
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.3446000000000001 tf.Tensor(337.34967, shape=(), dtype=float32) 100
# slice = key, score = 0.3446000000000001
# np.mean(results), mse, len(results) =  0.38089954497724887 tf.Tensor(324.6574, shape=(), dtype=float32) 2857
# slice = train, score = 0.38089954497724887
# np.mean(results), mse, len(results) =  0.3541055949566588 tf.Tensor(323.2146, shape=(), dtype=float32) 1269
# slice = test, score = 0.3541055949566588
# np.mean(results), mse, len(results) =  0.38089954497724887 tf.Tensor(324.6574, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.3541055949566588 tf.Tensor(323.2146, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.3809_0.3541.npz ...
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.34279999999999994 tf.Tensor(414.4374, shape=(), dtype=float32) 100
# slice = key, score = 0.34279999999999994
# np.mean(results), mse, len(results) =  0.37915995799789987 tf.Tensor(400.277, shape=(), dtype=float32) 2857
# slice = train, score = 0.37915995799789987
# np.mean(results), mse, len(results) =  0.3533963750985028 tf.Tensor(398.35318, shape=(), dtype=float32) 1269
# slice = test, score = 0.3533963750985028
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.34430000000000016 tf.Tensor(505.15433, shape=(), dtype=float32) 100
# slice = key, score = 0.34430000000000016
# np.mean(results), mse, len(results) =  0.3775078753937697 tf.Tensor(490.54868, shape=(), dtype=float32) 2857
# slice = train, score = 0.3775078753937697
# np.mean(results), mse, len(results) =  0.3495429472025217 tf.Tensor(488.86392, shape=(), dtype=float32) 1269
# slice = test, score = 0.3495429472025217
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.3515 tf.Tensor(606.4243, shape=(), dtype=float32) 100
# slice = key, score = 0.3515
# np.mean(results), mse, len(results) =  0.38732236611830595 tf.Tensor(584.0168, shape=(), dtype=float32) 2857
# slice = train, score = 0.38732236611830595
# np.mean(results), mse, len(results) =  0.35703703703703704 tf.Tensor(582.3687, shape=(), dtype=float32) 1269
# slice = test, score = 0.35703703703703704
# np.mean(results), mse, len(results) =  0.38732236611830595 tf.Tensor(584.0168, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.35703703703703704 tf.Tensor(582.3687, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.3873_0.357.npz ...
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.3602 tf.Tensor(670.8152, shape=(), dtype=float32) 100
# slice = key, score = 0.3602
# np.mean(results), mse, len(results) =  0.3907770388519426 tf.Tensor(660.7486, shape=(), dtype=float32) 2857
# slice = train, score = 0.3907770388519426
# np.mean(results), mse, len(results) =  0.36120567375886525 tf.Tensor(653.4737, shape=(), dtype=float32) 1269
# slice = test, score = 0.36120567375886525
# np.mean(results), mse, len(results) =  0.3907770388519426 tf.Tensor(660.7486, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36120567375886525 tf.Tensor(653.4737, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.3908_0.3612.npz ...
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.3542 tf.Tensor(831.3033, shape=(), dtype=float32) 100
# slice = key, score = 0.3542
# np.mean(results), mse, len(results) =  0.38789989499474975 tf.Tensor(795.6337, shape=(), dtype=float32) 2857
# slice = train, score = 0.38789989499474975
# np.mean(results), mse, len(results) =  0.35855003940110325 tf.Tensor(792.26013, shape=(), dtype=float32) 1269
# slice = test, score = 0.35855003940110325
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.359 tf.Tensor(891.81775, shape=(), dtype=float32) 100
# slice = key, score = 0.359
# np.mean(results), mse, len(results) =  0.3936296814840742 tf.Tensor(864.95154, shape=(), dtype=float32) 2857
# slice = train, score = 0.3936296814840742
# np.mean(results), mse, len(results) =  0.36254531126871553 tf.Tensor(858.6711, shape=(), dtype=float32) 1269
# slice = test, score = 0.36254531126871553
# np.mean(results), mse, len(results) =  0.3936296814840742 tf.Tensor(864.95154, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36254531126871553 tf.Tensor(858.6711, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.3936_0.3625.npz ...
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.35940000000000005 tf.Tensor(1017.6178, shape=(), dtype=float32) 100
# slice = key, score = 0.35940000000000005
# np.mean(results), mse, len(results) =  0.39259362968148404 tf.Tensor(965.94434, shape=(), dtype=float32) 2857
# slice = train, score = 0.39259362968148404
# np.mean(results), mse, len(results) =  0.3607171000788022 tf.Tensor(963.13104, shape=(), dtype=float32) 1269
# slice = test, score = 0.3607171000788022
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.3625 tf.Tensor(1102.6101, shape=(), dtype=float32) 100
# slice = key, score = 0.3625
# np.mean(results), mse, len(results) =  0.39497024851242557 tf.Tensor(1073.0378, shape=(), dtype=float32) 2857
# slice = train, score = 0.39497024851242557
# np.mean(results), mse, len(results) =  0.36380614657210397 tf.Tensor(1060.2533, shape=(), dtype=float32) 1269
# slice = test, score = 0.36380614657210397
# np.mean(results), mse, len(results) =  0.39497024851242557 tf.Tensor(1073.0378, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36380614657210397 tf.Tensor(1060.2533, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.395_0.3638.npz ...
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.3666 tf.Tensor(1184.0039, shape=(), dtype=float32) 100
# slice = key, score = 0.3666
# np.mean(results), mse, len(results) =  0.39857192859642976 tf.Tensor(1139.1669, shape=(), dtype=float32) 2857
# slice = train, score = 0.39857192859642976
# np.mean(results), mse, len(results) =  0.36445232466509064 tf.Tensor(1129.6132, shape=(), dtype=float32) 1269
# slice = test, score = 0.36445232466509064
# np.mean(results), mse, len(results) =  0.39857192859642976 tf.Tensor(1139.1669, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36445232466509064 tf.Tensor(1129.6132, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.3986_0.3645.npz ...
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.3617 tf.Tensor(1372.5308, shape=(), dtype=float32) 100
# slice = key, score = 0.3617
# np.mean(results), mse, len(results) =  0.3933461673083654 tf.Tensor(1323.3522, shape=(), dtype=float32) 2857
# slice = train, score = 0.3933461673083654
# np.mean(results), mse, len(results) =  0.3605043341213554 tf.Tensor(1314.365, shape=(), dtype=float32) 1269
# slice = test, score = 0.3605043341213554
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.3663 tf.Tensor(1458.2014, shape=(), dtype=float32) 100
# slice = key, score = 0.3663
# np.mean(results), mse, len(results) =  0.39781239061953105 tf.Tensor(1388.4565, shape=(), dtype=float32) 2857
# slice = train, score = 0.39781239061953105
# np.mean(results), mse, len(results) =  0.36526398739164695 tf.Tensor(1389.1396, shape=(), dtype=float32) 1269
# slice = test, score = 0.36526398739164695
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.3633000000000001 tf.Tensor(1558.482, shape=(), dtype=float32) 100
# slice = key, score = 0.3633000000000001
# np.mean(results), mse, len(results) =  0.394109205460273 tf.Tensor(1491.4236, shape=(), dtype=float32) 2857
# slice = train, score = 0.394109205460273
# np.mean(results), mse, len(results) =  0.3601182033096927 tf.Tensor(1482.1793, shape=(), dtype=float32) 1269
# slice = test, score = 0.3601182033096927
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.37199999999999994 tf.Tensor(1705.0723, shape=(), dtype=float32) 100
# slice = key, score = 0.37199999999999994
# np.mean(results), mse, len(results) =  0.3999789989499475 tf.Tensor(1640.0809, shape=(), dtype=float32) 2857
# slice = train, score = 0.3999789989499475
# np.mean(results), mse, len(results) =  0.36520094562647754 tf.Tensor(1629.3247, shape=(), dtype=float32) 1269
# slice = test, score = 0.36520094562647754
# np.mean(results), mse, len(results) =  0.3999789989499475 tf.Tensor(1640.0809, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36520094562647754 tf.Tensor(1629.3247, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4_0.3652.npz ...
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.36950000000000005 tf.Tensor(1830.4703, shape=(), dtype=float32) 100
# slice = key, score = 0.36950000000000005
# np.mean(results), mse, len(results) =  0.401991599579979 tf.Tensor(1752.3705, shape=(), dtype=float32) 2857
# slice = train, score = 0.401991599579979
# np.mean(results), mse, len(results) =  0.3685894405043341 tf.Tensor(1741.7734, shape=(), dtype=float32) 1269
# slice = test, score = 0.3685894405043341
# np.mean(results), mse, len(results) =  0.401991599579979 tf.Tensor(1752.3705, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.3685894405043341 tf.Tensor(1741.7734, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.402_0.3686.npz ...
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.36719999999999997 tf.Tensor(1916.4268, shape=(), dtype=float32) 100
# slice = key, score = 0.36719999999999997
# np.mean(results), mse, len(results) =  0.39851942597129864 tf.Tensor(1812.8005, shape=(), dtype=float32) 2857
# slice = train, score = 0.39851942597129864
# np.mean(results), mse, len(results) =  0.36468085106382975 tf.Tensor(1807.4727, shape=(), dtype=float32) 1269
# slice = test, score = 0.36468085106382975
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.36959999999999993 tf.Tensor(2121.6973, shape=(), dtype=float32) 100
# slice = key, score = 0.36959999999999993
# np.mean(results), mse, len(results) =  0.4019320966048303 tf.Tensor(2005.743, shape=(), dtype=float32) 2857
# slice = train, score = 0.4019320966048303
# np.mean(results), mse, len(results) =  0.36697399527186764 tf.Tensor(1996.3523, shape=(), dtype=float32) 1269
# slice = test, score = 0.36697399527186764
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.3683000000000001 tf.Tensor(2206.8818, shape=(), dtype=float32) 100
# slice = key, score = 0.3683000000000001
# np.mean(results), mse, len(results) =  0.40043752187609377 tf.Tensor(2101.493, shape=(), dtype=float32) 2857
# slice = train, score = 0.40043752187609377
# np.mean(results), mse, len(results) =  0.3651221434200158 tf.Tensor(2086.79, shape=(), dtype=float32) 1269
# slice = test, score = 0.3651221434200158
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.37290000000000006 tf.Tensor(2271.2585, shape=(), dtype=float32) 100
# slice = key, score = 0.37290000000000006
# np.mean(results), mse, len(results) =  0.40311165558277917 tf.Tensor(2196.953, shape=(), dtype=float32) 2857
# slice = train, score = 0.40311165558277917
# np.mean(results), mse, len(results) =  0.36797478329393224 tf.Tensor(2182.418, shape=(), dtype=float32) 1269
# slice = test, score = 0.36797478329393224
# np.mean(results), mse, len(results) =  0.40311165558277917 tf.Tensor(2196.953, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36797478329393224 tf.Tensor(2182.418, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4031_0.368.npz ...
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.3761 tf.Tensor(2484.7236, shape=(), dtype=float32) 100
# slice = key, score = 0.3761
# np.mean(results), mse, len(results) =  0.4048792439621981 tf.Tensor(2322.4272, shape=(), dtype=float32) 2857
# slice = train, score = 0.4048792439621981
# np.mean(results), mse, len(results) =  0.36922773837667455 tf.Tensor(2311.3667, shape=(), dtype=float32) 1269
# slice = test, score = 0.36922773837667455
# np.mean(results), mse, len(results) =  0.4048792439621981 tf.Tensor(2322.4272, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36922773837667455 tf.Tensor(2311.3667, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4049_0.3692.npz ...
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.3775 tf.Tensor(2511.5112, shape=(), dtype=float32) 100
# slice = key, score = 0.3775
# np.mean(results), mse, len(results) =  0.40497724886244313 tf.Tensor(2376.774, shape=(), dtype=float32) 2857
# slice = train, score = 0.40497724886244313
# np.mean(results), mse, len(results) =  0.36868400315208827 tf.Tensor(2356.2388, shape=(), dtype=float32) 1269
# slice = test, score = 0.36868400315208827
# np.mean(results), mse, len(results) =  0.40497724886244313 tf.Tensor(2376.774, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36868400315208827 tf.Tensor(2356.2388, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.405_0.3687.npz ...
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.36650000000000005 tf.Tensor(2513.2314, shape=(), dtype=float32) 100
# slice = key, score = 0.36650000000000005
# np.mean(results), mse, len(results) =  0.3979173958697935 tf.Tensor(2356.5195, shape=(), dtype=float32) 2857
# slice = train, score = 0.3979173958697935
# np.mean(results), mse, len(results) =  0.36279747832939324 tf.Tensor(2332.2507, shape=(), dtype=float32) 1269
# slice = test, score = 0.36279747832939324
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.36830000000000007 tf.Tensor(2429.3167, shape=(), dtype=float32) 100
# slice = key, score = 0.36830000000000007
# np.mean(results), mse, len(results) =  0.39910745537276865 tf.Tensor(2249.6084, shape=(), dtype=float32) 2857
# slice = train, score = 0.39910745537276865
# np.mean(results), mse, len(results) =  0.3611111111111111 tf.Tensor(2212.9734, shape=(), dtype=float32) 1269
# slice = test, score = 0.3611111111111111
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.3728 tf.Tensor(2656.2952, shape=(), dtype=float32) 100
# slice = key, score = 0.3728
# np.mean(results), mse, len(results) =  0.4023451172558628 tf.Tensor(2421.938, shape=(), dtype=float32) 2857
# slice = train, score = 0.4023451172558628
# np.mean(results), mse, len(results) =  0.36530338849487787 tf.Tensor(2379.6702, shape=(), dtype=float32) 1269
# slice = test, score = 0.36530338849487787
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.35969999999999996 tf.Tensor(2684.5486, shape=(), dtype=float32) 100
# slice = key, score = 0.35969999999999996
# np.mean(results), mse, len(results) =  0.39440672033601687 tf.Tensor(2488.018, shape=(), dtype=float32) 2857
# slice = train, score = 0.39440672033601687
# np.mean(results), mse, len(results) =  0.3581166272655634 tf.Tensor(2450.6145, shape=(), dtype=float32) 1269
# slice = test, score = 0.3581166272655634
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.36449999999999994 tf.Tensor(2765.1418, shape=(), dtype=float32) 100
# slice = key, score = 0.36449999999999994
# np.mean(results), mse, len(results) =  0.39619880994049705 tf.Tensor(2591.7205, shape=(), dtype=float32) 2857
# slice = train, score = 0.39619880994049705
# np.mean(results), mse, len(results) =  0.3597714736012608 tf.Tensor(2546.9492, shape=(), dtype=float32) 1269
# slice = test, score = 0.3597714736012608
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.3733000000000001 tf.Tensor(3058.3975, shape=(), dtype=float32) 100
# slice = key, score = 0.3733000000000001
# np.mean(results), mse, len(results) =  0.40560028001400067 tf.Tensor(2863.2732, shape=(), dtype=float32) 2857
# slice = train, score = 0.40560028001400067
# np.mean(results), mse, len(results) =  0.3679117415287628 tf.Tensor(2827.7834, shape=(), dtype=float32) 1269
# slice = test, score = 0.3679117415287628
# np.mean(results), mse, len(results) =  0.40560028001400067 tf.Tensor(2863.2732, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.3679117415287628 tf.Tensor(2827.7834, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4056_0.3679.npz ...
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.37099999999999994 tf.Tensor(3227.9766, shape=(), dtype=float32) 100
# slice = key, score = 0.37099999999999994
# np.mean(results), mse, len(results) =  0.4025866293314666 tf.Tensor(3044.2466, shape=(), dtype=float32) 2857
# slice = train, score = 0.4025866293314666
# np.mean(results), mse, len(results) =  0.36449960598896775 tf.Tensor(3024.466, shape=(), dtype=float32) 1269
# slice = test, score = 0.36449960598896775
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.36640000000000006 tf.Tensor(3435.2788, shape=(), dtype=float32) 100
# slice = key, score = 0.36640000000000006
# np.mean(results), mse, len(results) =  0.3979593979698985 tf.Tensor(3167.4668, shape=(), dtype=float32) 2857
# slice = train, score = 0.3979593979698985
# np.mean(results), mse, len(results) =  0.36041765169424744 tf.Tensor(3141.2354, shape=(), dtype=float32) 1269
# slice = test, score = 0.36041765169424744
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.37459999999999993 tf.Tensor(3595.8794, shape=(), dtype=float32) 100
# slice = key, score = 0.37459999999999993
# np.mean(results), mse, len(results) =  0.4048267413370669 tf.Tensor(3432.1343, shape=(), dtype=float32) 2857
# slice = train, score = 0.4048267413370669
# np.mean(results), mse, len(results) =  0.3668321513002364 tf.Tensor(3382.7007, shape=(), dtype=float32) 1269
# slice = test, score = 0.3668321513002364
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.37120000000000003 tf.Tensor(3920.6968, shape=(), dtype=float32) 100
# slice = key, score = 0.37120000000000003
# np.mean(results), mse, len(results) =  0.40153307665383264 tf.Tensor(3691.8625, shape=(), dtype=float32) 2857
# slice = train, score = 0.40153307665383264
# np.mean(results), mse, len(results) =  0.365177304964539 tf.Tensor(3655.8264, shape=(), dtype=float32) 1269
# slice = test, score = 0.365177304964539
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.37410000000000004 tf.Tensor(4307.1006, shape=(), dtype=float32) 100
# slice = key, score = 0.37410000000000004
# np.mean(results), mse, len(results) =  0.40342667133356674 tf.Tensor(3963.055, shape=(), dtype=float32) 2857
# slice = train, score = 0.40342667133356674
# np.mean(results), mse, len(results) =  0.3673758865248227 tf.Tensor(3914.0613, shape=(), dtype=float32) 1269
# slice = test, score = 0.3673758865248227
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.37050000000000005 tf.Tensor(4676.8086, shape=(), dtype=float32) 100
# slice = key, score = 0.37050000000000005
# np.mean(results), mse, len(results) =  0.4019250962548128 tf.Tensor(4386.2773, shape=(), dtype=float32) 2857
# slice = train, score = 0.4019250962548128
# np.mean(results), mse, len(results) =  0.3638534278959811 tf.Tensor(4294.7114, shape=(), dtype=float32) 1269
# slice = test, score = 0.3638534278959811
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.37190000000000006 tf.Tensor(4705.5156, shape=(), dtype=float32) 100
# slice = key, score = 0.37190000000000006
# np.mean(results), mse, len(results) =  0.4048582429121456 tf.Tensor(4454.3213, shape=(), dtype=float32) 2857
# slice = train, score = 0.4048582429121456
# np.mean(results), mse, len(results) =  0.36730496453900713 tf.Tensor(4404.838, shape=(), dtype=float32) 1269
# slice = test, score = 0.36730496453900713
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.3707000000000001 tf.Tensor(4949.7173, shape=(), dtype=float32) 100
# slice = key, score = 0.3707000000000001
# np.mean(results), mse, len(results) =  0.4008400420021001 tf.Tensor(4673.693, shape=(), dtype=float32) 2857
# slice = train, score = 0.4008400420021001
# np.mean(results), mse, len(results) =  0.3623167848699763 tf.Tensor(4615.2266, shape=(), dtype=float32) 1269
# slice = test, score = 0.3623167848699763
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.37 tf.Tensor(5272.364, shape=(), dtype=float32) 100
# slice = key, score = 0.37
# np.mean(results), mse, len(results) =  0.4025201260063003 tf.Tensor(5115.5195, shape=(), dtype=float32) 2857
# slice = train, score = 0.4025201260063003
# np.mean(results), mse, len(results) =  0.3634909377462569 tf.Tensor(5067.793, shape=(), dtype=float32) 1269
# slice = test, score = 0.3634909377462569
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.37270000000000003 tf.Tensor(5484.3267, shape=(), dtype=float32) 100
# slice = key, score = 0.37270000000000003
# np.mean(results), mse, len(results) =  0.4044382219110956 tf.Tensor(5309.4365, shape=(), dtype=float32) 2857
# slice = train, score = 0.4044382219110956
# np.mean(results), mse, len(results) =  0.3668715524034673 tf.Tensor(5235.7065, shape=(), dtype=float32) 1269
# slice = test, score = 0.3668715524034673
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.3713 tf.Tensor(5675.8403, shape=(), dtype=float32) 100
# slice = key, score = 0.3713
# np.mean(results), mse, len(results) =  0.40474623731186554 tf.Tensor(5593.578, shape=(), dtype=float32) 2857
# slice = train, score = 0.40474623731186554
# np.mean(results), mse, len(results) =  0.36705279747832936 tf.Tensor(5515.521, shape=(), dtype=float32) 1269
# slice = test, score = 0.36705279747832936
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.37250000000000005 tf.Tensor(6216.0605, shape=(), dtype=float32) 100
# slice = key, score = 0.37250000000000005
# np.mean(results), mse, len(results) =  0.4012950647532377 tf.Tensor(5974.366, shape=(), dtype=float32) 2857
# slice = train, score = 0.4012950647532377
# np.mean(results), mse, len(results) =  0.36411347517730497 tf.Tensor(5909.717, shape=(), dtype=float32) 1269
# slice = test, score = 0.36411347517730497
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.3758999999999999 tf.Tensor(6435.308, shape=(), dtype=float32) 100
# slice = key, score = 0.3758999999999999
# np.mean(results), mse, len(results) =  0.4053622681134057 tf.Tensor(6176.6685, shape=(), dtype=float32) 2857
# slice = train, score = 0.4053622681134057
# np.mean(results), mse, len(results) =  0.36577620173364855 tf.Tensor(6083.551, shape=(), dtype=float32) 1269
# slice = test, score = 0.36577620173364855
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.3759 tf.Tensor(6743.4995, shape=(), dtype=float32) 100
# slice = key, score = 0.3759
# np.mean(results), mse, len(results) =  0.40468673433671687 tf.Tensor(6542.878, shape=(), dtype=float32) 2857
# slice = train, score = 0.40468673433671687
# np.mean(results), mse, len(results) =  0.36723404255319153 tf.Tensor(6449.1836, shape=(), dtype=float32) 1269
# slice = test, score = 0.36723404255319153
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.3736 tf.Tensor(7075.1465, shape=(), dtype=float32) 100
# slice = key, score = 0.3736
# np.mean(results), mse, len(results) =  0.4036996849842492 tf.Tensor(6855.2607, shape=(), dtype=float32) 2857
# slice = train, score = 0.4036996849842492
# np.mean(results), mse, len(results) =  0.36625689519306537 tf.Tensor(6723.6353, shape=(), dtype=float32) 1269
# slice = test, score = 0.36625689519306537
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.3795 tf.Tensor(7599.508, shape=(), dtype=float32) 100
# slice = key, score = 0.3795
# np.mean(results), mse, len(results) =  0.40697584879243964 tf.Tensor(7241.9653, shape=(), dtype=float32) 2857
# slice = train, score = 0.40697584879243964
# np.mean(results), mse, len(results) =  0.368849487785658 tf.Tensor(7106.5425, shape=(), dtype=float32) 1269
# slice = test, score = 0.368849487785658
# np.mean(results), mse, len(results) =  0.40697584879243964 tf.Tensor(7241.9653, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.368849487785658 tf.Tensor(7106.5425, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.407_0.3688.npz ...
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.3746 tf.Tensor(7900.5137, shape=(), dtype=float32) 100
# slice = key, score = 0.3746
# np.mean(results), mse, len(results) =  0.4034301715085754 tf.Tensor(7529.608, shape=(), dtype=float32) 2857
# slice = train, score = 0.4034301715085754
# np.mean(results), mse, len(results) =  0.3648936170212766 tf.Tensor(7403.019, shape=(), dtype=float32) 1269
# slice = test, score = 0.3648936170212766
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.38109999999999994 tf.Tensor(8150.0103, shape=(), dtype=float32) 100
# slice = key, score = 0.38109999999999994
# np.mean(results), mse, len(results) =  0.40625831291564574 tf.Tensor(7882.145, shape=(), dtype=float32) 2857
# slice = train, score = 0.40625831291564574
# np.mean(results), mse, len(results) =  0.3658234830575256 tf.Tensor(7772.076, shape=(), dtype=float32) 1269
# slice = test, score = 0.3658234830575256
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.3718000000000001 tf.Tensor(8457.353, shape=(), dtype=float32) 100
# slice = key, score = 0.3718000000000001
# np.mean(results), mse, len(results) =  0.4019810990549528 tf.Tensor(8290.267, shape=(), dtype=float32) 2857
# slice = train, score = 0.4019810990549528
# np.mean(results), mse, len(results) =  0.36304964539007095 tf.Tensor(8124.199, shape=(), dtype=float32) 1269
# slice = test, score = 0.36304964539007095
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.37420000000000003 tf.Tensor(8479.126, shape=(), dtype=float32) 100
# slice = key, score = 0.37420000000000003
# np.mean(results), mse, len(results) =  0.40251662583129166 tf.Tensor(8199.823, shape=(), dtype=float32) 2857
# slice = train, score = 0.40251662583129166
# np.mean(results), mse, len(results) =  0.3644050433412136 tf.Tensor(8072.5166, shape=(), dtype=float32) 1269
# slice = test, score = 0.3644050433412136
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.3833 tf.Tensor(9504.136, shape=(), dtype=float32) 100
# slice = key, score = 0.3833
# np.mean(results), mse, len(results) =  0.40924396219810993 tf.Tensor(9184.631, shape=(), dtype=float32) 2857
# slice = train, score = 0.40924396219810993
# np.mean(results), mse, len(results) =  0.3707249802994484 tf.Tensor(9041.706, shape=(), dtype=float32) 1269
# slice = test, score = 0.3707249802994484
# np.mean(results), mse, len(results) =  0.40924396219810993 tf.Tensor(9184.631, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.3707249802994484 tf.Tensor(9041.706, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4092_0.3707.npz ...
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.3746000000000001 tf.Tensor(10485.544, shape=(), dtype=float32) 100
# slice = key, score = 0.3746000000000001
# np.mean(results), mse, len(results) =  0.40697234861743087 tf.Tensor(10003.298, shape=(), dtype=float32) 2857
# slice = train, score = 0.40697234861743087
# np.mean(results), mse, len(results) =  0.36910165484633567 tf.Tensor(9781.183, shape=(), dtype=float32) 1269
# slice = test, score = 0.36910165484633567
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.3731000000000001 tf.Tensor(10470.098, shape=(), dtype=float32) 100
# slice = key, score = 0.3731000000000001
# np.mean(results), mse, len(results) =  0.4017185859292965 tf.Tensor(10068.764, shape=(), dtype=float32) 2857
# slice = train, score = 0.4017185859292965
# np.mean(results), mse, len(results) =  0.36245074862096144 tf.Tensor(9883.993, shape=(), dtype=float32) 1269
# slice = test, score = 0.36245074862096144
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.3807 tf.Tensor(10449.35, shape=(), dtype=float32) 100
# slice = key, score = 0.3807
# np.mean(results), mse, len(results) =  0.4086244312215611 tf.Tensor(10042.274, shape=(), dtype=float32) 2857
# slice = train, score = 0.4086244312215611
# np.mean(results), mse, len(results) =  0.3701733648542159 tf.Tensor(9871.854, shape=(), dtype=float32) 1269
# slice = test, score = 0.3701733648542159
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.38 tf.Tensor(10855.462, shape=(), dtype=float32) 100
# slice = key, score = 0.38
# np.mean(results), mse, len(results) =  0.40739586979348963 tf.Tensor(10471.929, shape=(), dtype=float32) 2857
# slice = train, score = 0.40739586979348963
# np.mean(results), mse, len(results) =  0.3696769109535067 tf.Tensor(10316.179, shape=(), dtype=float32) 1269
# slice = test, score = 0.3696769109535067
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.37860000000000005 tf.Tensor(11144.718, shape=(), dtype=float32) 100
# slice = key, score = 0.37860000000000005
# np.mean(results), mse, len(results) =  0.4077738886944348 tf.Tensor(10860.507, shape=(), dtype=float32) 2857
# slice = train, score = 0.4077738886944348
# np.mean(results), mse, len(results) =  0.3676516942474389 tf.Tensor(10654.061, shape=(), dtype=float32) 1269
# slice = test, score = 0.3676516942474389
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.37799999999999995 tf.Tensor(11920.245, shape=(), dtype=float32) 100
# slice = key, score = 0.37799999999999995
# np.mean(results), mse, len(results) =  0.4090759537976899 tf.Tensor(11246.207, shape=(), dtype=float32) 2857
# slice = train, score = 0.4090759537976899
# np.mean(results), mse, len(results) =  0.37043341213553976 tf.Tensor(11027.819, shape=(), dtype=float32) 1269
# slice = test, score = 0.37043341213553976
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.3775 tf.Tensor(11594.689, shape=(), dtype=float32) 100
# slice = key, score = 0.3775
# np.mean(results), mse, len(results) =  0.40902695134756734 tf.Tensor(11145.749, shape=(), dtype=float32) 2857
# slice = train, score = 0.40902695134756734
# np.mean(results), mse, len(results) =  0.3692592592592593 tf.Tensor(10923.951, shape=(), dtype=float32) 1269
# slice = test, score = 0.3692592592592593
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.38000000000000006 tf.Tensor(12555.214, shape=(), dtype=float32) 100
# slice = key, score = 0.38000000000000006
# np.mean(results), mse, len(results) =  0.4094609730486524 tf.Tensor(12084.457, shape=(), dtype=float32) 2857
# slice = train, score = 0.4094609730486524
# np.mean(results), mse, len(results) =  0.36918833727344363 tf.Tensor(11800.676, shape=(), dtype=float32) 1269
# slice = test, score = 0.36918833727344363
# np.mean(results), mse, len(results) =  0.4094609730486524 tf.Tensor(12084.457, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36918833727344363 tf.Tensor(11800.676, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4095_0.3692.npz ...
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.376 tf.Tensor(12311.706, shape=(), dtype=float32) 100
# slice = key, score = 0.376
# np.mean(results), mse, len(results) =  0.4067378368918447 tf.Tensor(12064.661, shape=(), dtype=float32) 2857
# slice = train, score = 0.4067378368918447
# np.mean(results), mse, len(results) =  0.3673286052009456 tf.Tensor(11710.891, shape=(), dtype=float32) 1269
# slice = test, score = 0.3673286052009456
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.3748 tf.Tensor(13548.283, shape=(), dtype=float32) 100
# slice = key, score = 0.3748
# np.mean(results), mse, len(results) =  0.40955197759888 tf.Tensor(13027.962, shape=(), dtype=float32) 2857
# slice = train, score = 0.40955197759888
# np.mean(results), mse, len(results) =  0.36916469661150514 tf.Tensor(12774.212, shape=(), dtype=float32) 1269
# slice = test, score = 0.36916469661150514
# np.mean(results), mse, len(results) =  0.40955197759888 tf.Tensor(13027.962, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.36916469661150514 tf.Tensor(12774.212, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4096_0.3692.npz ...
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.3754 tf.Tensor(13322.16, shape=(), dtype=float32) 100
# slice = key, score = 0.3754
# np.mean(results), mse, len(results) =  0.4068533426671334 tf.Tensor(12768.246, shape=(), dtype=float32) 2857
# slice = train, score = 0.4068533426671334
# np.mean(results), mse, len(results) =  0.36734436564223794 tf.Tensor(12522.458, shape=(), dtype=float32) 1269
# slice = test, score = 0.36734436564223794
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.37459999999999993 tf.Tensor(14329.678, shape=(), dtype=float32) 100
# slice = key, score = 0.37459999999999993
# np.mean(results), mse, len(results) =  0.4080644032201611 tf.Tensor(14057.319, shape=(), dtype=float32) 2857
# slice = train, score = 0.4080644032201611
# np.mean(results), mse, len(results) =  0.36974783293932234 tf.Tensor(13725.682, shape=(), dtype=float32) 1269
# slice = test, score = 0.36974783293932234
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.3736 tf.Tensor(14052.303, shape=(), dtype=float32) 100
# slice = key, score = 0.3736
# np.mean(results), mse, len(results) =  0.4083374168708435 tf.Tensor(13481.781, shape=(), dtype=float32) 2857
# slice = train, score = 0.4083374168708435
# np.mean(results), mse, len(results) =  0.3680220646178093 tf.Tensor(13183.104, shape=(), dtype=float32) 1269
# slice = test, score = 0.3680220646178093
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.3788 tf.Tensor(14972.456, shape=(), dtype=float32) 100
# slice = key, score = 0.3788
# np.mean(results), mse, len(results) =  0.40969898494924745 tf.Tensor(14561.292, shape=(), dtype=float32) 2857
# slice = train, score = 0.40969898494924745
# np.mean(results), mse, len(results) =  0.3690464933018125 tf.Tensor(14219.342, shape=(), dtype=float32) 1269
# slice = test, score = 0.3690464933018125
# np.mean(results), mse, len(results) =  0.40969898494924745 tf.Tensor(14561.292, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.3690464933018125 tf.Tensor(14219.342, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4097_0.369.npz ...
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.3788 tf.Tensor(15439.285, shape=(), dtype=float32) 100
# slice = key, score = 0.3788
# np.mean(results), mse, len(results) =  0.4077353867693385 tf.Tensor(14695.934, shape=(), dtype=float32) 2857
# slice = train, score = 0.4077353867693385
# np.mean(results), mse, len(results) =  0.36803782505910165 tf.Tensor(14361.653, shape=(), dtype=float32) 1269
# slice = test, score = 0.36803782505910165
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.37370000000000014 tf.Tensor(16335.744, shape=(), dtype=float32) 100
# slice = key, score = 0.37370000000000014
# np.mean(results), mse, len(results) =  0.40764088204410226 tf.Tensor(15262.006, shape=(), dtype=float32) 2857
# slice = train, score = 0.40764088204410226
# np.mean(results), mse, len(results) =  0.36709219858156034 tf.Tensor(14974.061, shape=(), dtype=float32) 1269
# slice = test, score = 0.36709219858156034
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.37529999999999997 tf.Tensor(16323.741, shape=(), dtype=float32) 100
# slice = key, score = 0.37529999999999997
# np.mean(results), mse, len(results) =  0.40937346867343366 tf.Tensor(15891.83, shape=(), dtype=float32) 2857
# slice = train, score = 0.40937346867343366
# np.mean(results), mse, len(results) =  0.36810086682427107 tf.Tensor(15535.671, shape=(), dtype=float32) 1269
# slice = test, score = 0.36810086682427107
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.3771000000000001 tf.Tensor(16889.328, shape=(), dtype=float32) 100
# slice = key, score = 0.3771000000000001
# np.mean(results), mse, len(results) =  0.4085334266713335 tf.Tensor(16221.4, shape=(), dtype=float32) 2857
# slice = train, score = 0.4085334266713335
# np.mean(results), mse, len(results) =  0.36921197793538224 tf.Tensor(15976.766, shape=(), dtype=float32) 1269
# slice = test, score = 0.36921197793538224
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.37799999999999995 tf.Tensor(17435.973, shape=(), dtype=float32) 100
# slice = key, score = 0.37799999999999995
# np.mean(results), mse, len(results) =  0.40683234161708093 tf.Tensor(16666.775, shape=(), dtype=float32) 2857
# slice = train, score = 0.40683234161708093
# np.mean(results), mse, len(results) =  0.36807722616233257 tf.Tensor(16365.215, shape=(), dtype=float32) 1269
# slice = test, score = 0.36807722616233257
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.37440000000000007 tf.Tensor(18368.621, shape=(), dtype=float32) 100
# slice = key, score = 0.37440000000000007
# np.mean(results), mse, len(results) =  0.40695484774238716 tf.Tensor(17531.232, shape=(), dtype=float32) 2857
# slice = train, score = 0.40695484774238716
# np.mean(results), mse, len(results) =  0.3668163908589441 tf.Tensor(17196.14, shape=(), dtype=float32) 1269
# slice = test, score = 0.3668163908589441
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.37560000000000004 tf.Tensor(18927.21, shape=(), dtype=float32) 100
# slice = key, score = 0.37560000000000004
# np.mean(results), mse, len(results) =  0.4093874693734687 tf.Tensor(18181.63, shape=(), dtype=float32) 2857
# slice = train, score = 0.4093874693734687
# np.mean(results), mse, len(results) =  0.36879432624113473 tf.Tensor(17992.973, shape=(), dtype=float32) 1269
# slice = test, score = 0.36879432624113473
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.37689999999999985 tf.Tensor(19305.549, shape=(), dtype=float32) 100
# slice = key, score = 0.37689999999999985
# np.mean(results), mse, len(results) =  0.41049002450122507 tf.Tensor(18294.66, shape=(), dtype=float32) 2857
# slice = train, score = 0.41049002450122507
# np.mean(results), mse, len(results) =  0.37133175728920415 tf.Tensor(17976.264, shape=(), dtype=float32) 1269
# slice = test, score = 0.37133175728920415
# np.mean(results), mse, len(results) =  0.41049002450122507 tf.Tensor(18294.66, shape=(), dtype=float32) 2857
# np.mean(results), mse, len(results) =  0.37133175728920415 tf.Tensor(17976.264, shape=(), dtype=float32) 1269
# Saving ./GE_QE_RBExCoItem_star_trek_noW__0.4105_0.3713.npz ...
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.37440000000000007 tf.Tensor(18239.602, shape=(), dtype=float32) 100
# slice = key, score = 0.37440000000000007
# np.mean(results), mse, len(results) =  0.4036751837591879 tf.Tensor(17741.812, shape=(), dtype=float32) 2857
# slice = train, score = 0.4036751837591879
# np.mean(results), mse, len(results) =  0.36366430260047283 tf.Tensor(17377.934, shape=(), dtype=float32) 1269
# slice = test, score = 0.36366430260047283
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.37139999999999995 tf.Tensor(19352.604, shape=(), dtype=float32) 100
# slice = key, score = 0.37139999999999995
# np.mean(results), mse, len(results) =  0.40440672033601677 tf.Tensor(18505.75, shape=(), dtype=float32) 2857
# slice = train, score = 0.40440672033601677
# np.mean(results), mse, len(results) =  0.3660835303388495 tf.Tensor(18190.846, shape=(), dtype=float32) 1269
# slice = test, score = 0.3660835303388495
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.3726 tf.Tensor(20722.252, shape=(), dtype=float32) 100
# slice = key, score = 0.3726
# np.mean(results), mse, len(results) =  0.4070248512425621 tf.Tensor(19797.795, shape=(), dtype=float32) 2857
# slice = train, score = 0.4070248512425621
# np.mean(results), mse, len(results) =  0.36639085894405043 tf.Tensor(19496.768, shape=(), dtype=float32) 1269
# slice = test, score = 0.36639085894405043
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.3707999999999999 tf.Tensor(20288.512, shape=(), dtype=float32) 100
# slice = key, score = 0.3707999999999999
# np.mean(results), mse, len(results) =  0.4055862793139657 tf.Tensor(19697.06, shape=(), dtype=float32) 2857
# slice = train, score = 0.4055862793139657
# np.mean(results), mse, len(results) =  0.36552403467297084 tf.Tensor(19471.408, shape=(), dtype=float32) 1269
# slice = test, score = 0.36552403467297084
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.37790000000000007 tf.Tensor(19579.967, shape=(), dtype=float32) 100
# slice = key, score = 0.37790000000000007
# np.mean(results), mse, len(results) =  0.4070668533426671 tf.Tensor(18599.832, shape=(), dtype=float32) 2857
# slice = train, score = 0.4070668533426671
# np.mean(results), mse, len(results) =  0.36775413711583926 tf.Tensor(18271.953, shape=(), dtype=float32) 1269
# slice = test, score = 0.36775413711583926
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.3753000000000001 tf.Tensor(21686.324, shape=(), dtype=float32) 100
# slice = key, score = 0.3753000000000001
# np.mean(results), mse, len(results) =  0.405148757437872 tf.Tensor(20681.01, shape=(), dtype=float32) 2857
# slice = train, score = 0.405148757437872
# np.mean(results), mse, len(results) =  0.366327817178881 tf.Tensor(20356.508, shape=(), dtype=float32) 1269
# slice = test, score = 0.366327817178881
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.3812 tf.Tensor(21742.88, shape=(), dtype=float32) 100
# slice = key, score = 0.3812
# np.mean(results), mse, len(results) =  0.4087049352467624 tf.Tensor(20667.574, shape=(), dtype=float32) 2857
# slice = train, score = 0.4087049352467624
# np.mean(results), mse, len(results) =  0.37048857368006305 tf.Tensor(20318.732, shape=(), dtype=float32) 1269
# slice = test, score = 0.37048857368006305
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.37620000000000003 tf.Tensor(22144.82, shape=(), dtype=float32) 100
# slice = key, score = 0.37620000000000003
# np.mean(results), mse, len(results) =  0.40827441372068607 tf.Tensor(21591.465, shape=(), dtype=float32) 2857
# slice = train, score = 0.40827441372068607
# np.mean(results), mse, len(results) =  0.3685894405043341 tf.Tensor(21104.904, shape=(), dtype=float32) 1269
# slice = test, score = 0.3685894405043341
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.3799 tf.Tensor(22436.627, shape=(), dtype=float32) 100
# slice = key, score = 0.3799
# np.mean(results), mse, len(results) =  0.40674833741687083 tf.Tensor(22077.59, shape=(), dtype=float32) 2857
# slice = train, score = 0.40674833741687083
# np.mean(results), mse, len(results) =  0.3668636721828212 tf.Tensor(21651.363, shape=(), dtype=float32) 1269
# slice = test, score = 0.3668636721828212
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.37910000000000005 tf.Tensor(23482.164, shape=(), dtype=float32) 100
# slice = key, score = 0.37910000000000005
# ...
# slice = key, score = 0.26870000000000005
# np.mean(results), mse, len(results) =  0.3355414819506016 tf.Tensor(155213.06, shape=(), dtype=float32) 1579
# slice = train, score = 0.3355414819506016
# np.mean(results), mse, len(results) =  0.28838888888888886 tf.Tensor(157522.08, shape=(), dtype=float32) 720
# slice = test, score = 0.28838888888888886
#
# === Iteration 121000 ===
# np.mean(results), mse, len(results) =  0.28099999999999997 tf.Tensor(169079.89, shape=(), dtype=float32) 100
# slice = key, score = 0.28099999999999997
# np.mean(results), mse, len(results) =  0.348777707409753 tf.Tensor(153443.81, shape=(), dtype=float32) 1579
# slice = train, score = 0.348777707409753
# np.mean(results), mse, len(results) =  0.3015416666666667 tf.Tensor(154681.72, shape=(), dtype=float32) 720
# slice = test, score = 0.3015416666666667
#
# === Iteration 122000 ===
# np.mean(results), mse, len(results) =  0.282 tf.Tensor(178637.34, shape=(), dtype=float32) 100
# slice = key, score = 0.282
# np.mean(results), mse, len(results) =  0.343204559848005 tf.Tensor(158051.14, shape=(), dtype=float32) 1579
# slice = train, score = 0.343204559848005
# np.mean(results), mse, len(results) =  0.2989722222222222 tf.Tensor(159548.4, shape=(), dtype=float32) 720
# slice = test, score = 0.2989722222222222
#
# === Iteration 123000 ===
# np.mean(results), mse, len(results) =  0.28309999999999996 tf.Tensor(167715.1, shape=(), dtype=float32) 100
# slice = key, score = 0.28309999999999996
# np.mean(results), mse, len(results) =  0.35019632678910706 tf.Tensor(153025.06, shape=(), dtype=float32) 1579
# slice = train, score = 0.35019632678910706
# np.mean(results), mse, len(results) =  0.3022777777777778 tf.Tensor(153522.16, shape=(), dtype=float32) 720
# slice = test, score = 0.3022777777777778
#
# === Iteration 124000 ===
# np.mean(results), mse, len(results) =  0.2772 tf.Tensor(177861.3, shape=(), dtype=float32) 100
# slice = key, score = 0.2772
# np.mean(results), mse, len(results) =  0.3424255858138062 tf.Tensor(161297.38, shape=(), dtype=float32) 1579
# slice = train, score = 0.3424255858138062
# np.mean(results), mse, len(results) =  0.296875 tf.Tensor(161766.64, shape=(), dtype=float32) 720
# slice = test, score = 0.296875
#
# === Iteration 125000 ===
# np.mean(results), mse, len(results) =  0.2861 tf.Tensor(183731.78, shape=(), dtype=float32) 100
# slice = key, score = 0.2861
# np.mean(results), mse, len(results) =  0.3485877137428752 tf.Tensor(165723.02, shape=(), dtype=float32) 1579
# slice = train, score = 0.3485877137428752
# np.mean(results), mse, len(results) =  0.3005555555555556 tf.Tensor(167035.03, shape=(), dtype=float32) 720
# slice = test, score = 0.3005555555555556
#
# === Iteration 126000 ===
# np.mean(results), mse, len(results) =  0.2846 tf.Tensor(184436.08, shape=(), dtype=float32) 100
# slice = key, score = 0.2846
# np.mean(results), mse, len(results) =  0.34635845471817606 tf.Tensor(164689.72, shape=(), dtype=float32) 1579
# slice = train, score = 0.34635845471817606
# np.mean(results), mse, len(results) =  0.3023194444444445 tf.Tensor(166255.22, shape=(), dtype=float32) 720
# slice = test, score = 0.3023194444444445
#
# === Iteration 127000 ===
# np.mean(results), mse, len(results) =  0.2827 tf.Tensor(184120.94, shape=(), dtype=float32) 100
# slice = key, score = 0.2827
# np.mean(results), mse, len(results) =  0.3483597213426219 tf.Tensor(169120.47, shape=(), dtype=float32) 1579
# slice = train, score = 0.3483597213426219
# np.mean(results), mse, len(results) =  0.3019305555555556 tf.Tensor(170014.73, shape=(), dtype=float32) 720
# slice = test, score = 0.3019305555555556
#
# === Iteration 128000 ===
# np.mean(results), mse, len(results) =  0.2836 tf.Tensor(188078.52, shape=(), dtype=float32) 100
# slice = key, score = 0.2836
# np.mean(results), mse, len(results) =  0.3488347055098163 tf.Tensor(170611.39, shape=(), dtype=float32) 1579
# slice = train, score = 0.3488347055098163
# np.mean(results), mse, len(results) =  0.30147222222222225 tf.Tensor(170627.48, shape=(), dtype=float32) 720
# slice = test, score = 0.30147222222222225
#
# === Iteration 129000 ===
# np.mean(results), mse, len(results) =  0.2805 tf.Tensor(187871.55, shape=(), dtype=float32) 100
# slice = key, score = 0.2805
# np.mean(results), mse, len(results) =  0.343863204559848 tf.Tensor(171857.73, shape=(), dtype=float32) 1579
# slice = train, score = 0.343863204559848
# np.mean(results), mse, len(results) =  0.2989305555555556 tf.Tensor(172500.86, shape=(), dtype=float32) 720
# slice = test, score = 0.2989305555555556
#
# === Iteration 130000 ===
# np.mean(results), mse, len(results) =  0.2861 tf.Tensor(193630.03, shape=(), dtype=float32) 100
# slice = key, score = 0.2861
# np.mean(results), mse, len(results) =  0.3455414819506016 tf.Tensor(174426.67, shape=(), dtype=float32) 1579
# slice = train, score = 0.3455414819506016
# np.mean(results), mse, len(results) =  0.2969722222222222 tf.Tensor(175333.17, shape=(), dtype=float32) 720
# slice = test, score = 0.2969722222222222
#
# === Iteration 131000 ===
# np.mean(results), mse, len(results) =  0.27870000000000006 tf.Tensor(195852.06, shape=(), dtype=float32) 100
# slice = key, score = 0.27870000000000006
# np.mean(results), mse, len(results) =  0.34286890436985434 tf.Tensor(177577.95, shape=(), dtype=float32) 1579
# slice = train, score = 0.34286890436985434
# np.mean(results), mse, len(results) =  0.2997916666666667 tf.Tensor(177947.86, shape=(), dtype=float32) 720
# slice = test, score = 0.2997916666666667
#
# === Iteration 132000 ===
# np.mean(results), mse, len(results) =  0.2837 tf.Tensor(198713.11, shape=(), dtype=float32) 100
# slice = key, score = 0.2837
# np.mean(results), mse, len(results) =  0.35071564281190626 tf.Tensor(179535.39, shape=(), dtype=float32) 1579
# slice = train, score = 0.35071564281190626
# np.mean(results), mse, len(results) =  0.2987083333333333 tf.Tensor(181145.44, shape=(), dtype=float32) 720
# slice = test, score = 0.2987083333333333
#
# === Iteration 133000 ===
# np.mean(results), mse, len(results) =  0.28380000000000005 tf.Tensor(206372.9, shape=(), dtype=float32) 100
# slice = key, score = 0.28380000000000005
# np.mean(results), mse, len(results) =  0.3436352121595947 tf.Tensor(187278.78, shape=(), dtype=float32) 1579
# slice = train, score = 0.3436352121595947
# np.mean(results), mse, len(results) =  0.2980138888888889 tf.Tensor(188396.75, shape=(), dtype=float32) 720
# slice = test, score = 0.2980138888888889
#
# === Iteration 134000 ===
# np.mean(results), mse, len(results) =  0.2844 tf.Tensor(199883.95, shape=(), dtype=float32) 100
# slice = key, score = 0.2844
# np.mean(results), mse, len(results) =  0.34718809373020904 tf.Tensor(182684.3, shape=(), dtype=float32) 1579
# slice = train, score = 0.34718809373020904
# np.mean(results), mse, len(results) =  0.302625 tf.Tensor(183618.16, shape=(), dtype=float32) 720
# slice = test, score = 0.302625
#
# === Iteration 135000 ===
# np.mean(results), mse, len(results) =  0.2795 tf.Tensor(215375.08, shape=(), dtype=float32) 100
# slice = key, score = 0.2795
# np.mean(results), mse, len(results) =  0.33742875237492087 tf.Tensor(194763.23, shape=(), dtype=float32) 1579
# slice = train, score = 0.33742875237492087
# np.mean(results), mse, len(results) =  0.2934027777777778 tf.Tensor(195903.9, shape=(), dtype=float32) 720
# slice = test, score = 0.2934027777777778
#
# === Iteration 136000 ===
# np.mean(results), mse, len(results) =  0.28850000000000003 tf.Tensor(207424.78, shape=(), dtype=float32) 100
# slice = key, score = 0.28850000000000003
# np.mean(results), mse, len(results) =  0.3512919569347689 tf.Tensor(190785.19, shape=(), dtype=float32) 1579
# slice = train, score = 0.3512919569347689
# np.mean(results), mse, len(results) =  0.30318055555555556 tf.Tensor(191144.75, shape=(), dtype=float32) 720
# slice = test, score = 0.30318055555555556
#
# === Iteration 137000 ===
# np.mean(results), mse, len(results) =  0.2762 tf.Tensor(217537.39, shape=(), dtype=float32) 100
# slice = key, score = 0.2762
# np.mean(results), mse, len(results) =  0.34404053198226725 tf.Tensor(195215.66, shape=(), dtype=float32) 1579
# slice = train, score = 0.34404053198226725
# np.mean(results), mse, len(results) =  0.2975416666666667 tf.Tensor(196775.9, shape=(), dtype=float32) 720
# slice = test, score = 0.2975416666666667
#
# === Iteration 138000 ===
# np.mean(results), mse, len(results) =  0.28600000000000003 tf.Tensor(219226.42, shape=(), dtype=float32) 100
# slice = key, score = 0.28600000000000003
# np.mean(results), mse, len(results) =  0.3501013299556681 tf.Tensor(199110.5, shape=(), dtype=float32) 1579
# slice = train, score = 0.3501013299556681
# np.mean(results), mse, len(results) =  0.30519444444444443 tf.Tensor(199603.3, shape=(), dtype=float32) 720
# slice = test, score = 0.30519444444444443
#
# === Iteration 139000 ===
# np.mean(results), mse, len(results) =  0.27759999999999996 tf.Tensor(228238.11, shape=(), dtype=float32) 100
# slice = key, score = 0.27759999999999996
# np.mean(results), mse, len(results) =  0.34468651044965165 tf.Tensor(205150.47, shape=(), dtype=float32) 1579
# slice = train, score = 0.34468651044965165
# np.mean(results), mse, len(results) =  0.2972222222222222 tf.Tensor(205447.6, shape=(), dtype=float32) 720
# slice = test, score = 0.2972222222222222
#
# === Iteration 140000 ===
# np.mean(results), mse, len(results) =  0.282 tf.Tensor(230327.27, shape=(), dtype=float32) 100
# slice = key, score = 0.282
# np.mean(results), mse, len(results) =  0.3461747941735275 tf.Tensor(206258.73, shape=(), dtype=float32) 1579
# slice = train, score = 0.3461747941735275
# np.mean(results), mse, len(results) =  0.30123611111111115 tf.Tensor(209057.81, shape=(), dtype=float32) 720
# slice = test, score = 0.30123611111111115
#
# === Iteration 141000 ===
# np.mean(results), mse, len(results) =  0.2775 tf.Tensor(224128.88, shape=(), dtype=float32) 100
# slice = key, score = 0.2775
# np.mean(results), mse, len(results) =  0.34230525649145027 tf.Tensor(205850.9, shape=(), dtype=float32) 1579
# slice = train, score = 0.34230525649145027
# np.mean(results), mse, len(results) =  0.29470833333333335 tf.Tensor(207443.73, shape=(), dtype=float32) 720
# slice = test, score = 0.29470833333333335
#
# === Iteration 142000 ===
# np.mean(results), mse, len(results) =  0.2722 tf.Tensor(238929.56, shape=(), dtype=float32) 100
# slice = key, score = 0.2722
# np.mean(results), mse, len(results) =  0.33543381887270424 tf.Tensor(211436.81, shape=(), dtype=float32) 1579
# slice = train, score = 0.33543381887270424
# np.mean(results), mse, len(results) =  0.2906944444444444 tf.Tensor(213683.27, shape=(), dtype=float32) 720
# slice = test, score = 0.2906944444444444
#
# === Iteration 143000 ===
# np.mean(results), mse, len(results) =  0.28340000000000004 tf.Tensor(234258.3, shape=(), dtype=float32) 100
# slice = key, score = 0.28340000000000004
# np.mean(results), mse, len(results) =  0.3488347055098163 tf.Tensor(208421.9, shape=(), dtype=float32) 1579
# slice = train, score = 0.3488347055098163
# np.mean(results), mse, len(results) =  0.2991666666666667 tf.Tensor(210929.75, shape=(), dtype=float32) 720
# slice = test, score = 0.2991666666666667
#
# === Iteration 144000 ===
# np.mean(results), mse, len(results) =  0.2801 tf.Tensor(243292.58, shape=(), dtype=float32) 100
# slice = key, score = 0.2801
# np.mean(results), mse, len(results) =  0.3463584547181761 tf.Tensor(214977.17, shape=(), dtype=float32) 1579
# slice = train, score = 0.3463584547181761
# np.mean(results), mse, len(results) =  0.2984027777777778 tf.Tensor(216755.48, shape=(), dtype=float32) 720
# slice = test, score = 0.2984027777777778
#
# === Iteration 145000 ===
# np.mean(results), mse, len(results) =  0.28640000000000004 tf.Tensor(233410.39, shape=(), dtype=float32) 100
# slice = key, score = 0.28640000000000004
# np.mean(results), mse, len(results) =  0.3492210259658012 tf.Tensor(210944.06, shape=(), dtype=float32) 1579
# slice = train, score = 0.3492210259658012
# np.mean(results), mse, len(results) =  0.30141666666666667 tf.Tensor(212692.27, shape=(), dtype=float32) 720
# slice = test, score = 0.30141666666666667
#
# === Iteration 146000 ===
# np.mean(results), mse, len(results) =  0.27769999999999995 tf.Tensor(249626.84, shape=(), dtype=float32) 100
# slice = key, score = 0.27769999999999995
# np.mean(results), mse, len(results) =  0.3402469917669411 tf.Tensor(219377.64, shape=(), dtype=float32) 1579
# slice = train, score = 0.3402469917669411
# np.mean(results), mse, len(results) =  0.2954444444444445 tf.Tensor(221985.97, shape=(), dtype=float32) 720
# slice = test, score = 0.2954444444444445
#
# === Iteration 147000 ===
# np.mean(results), mse, len(results) =  0.2842 tf.Tensor(249486.7, shape=(), dtype=float32) 100
# slice = key, score = 0.2842
# np.mean(results), mse, len(results) =  0.3449651678277391 tf.Tensor(221238.67, shape=(), dtype=float32) 1579
# slice = train, score = 0.3449651678277391
# np.mean(results), mse, len(results) =  0.30054166666666665 tf.Tensor(222193.23, shape=(), dtype=float32) 720
# slice = test, score = 0.30054166666666665
#
# === Iteration 148000 ===
# np.mean(results), mse, len(results) =  0.2743999999999999 tf.Tensor(259028.8, shape=(), dtype=float32) 100
# slice = key, score = 0.2743999999999999
# np.mean(results), mse, len(results) =  0.33766307789740346 tf.Tensor(228327.44, shape=(), dtype=float32) 1579
# slice = train, score = 0.33766307789740346
# np.mean(results), mse, len(results) =  0.29175 tf.Tensor(230747.9, shape=(), dtype=float32) 720
# slice = test, score = 0.29175
#
# === Iteration 149000 ===
# np.mean(results), mse, len(results) =  0.27769999999999995 tf.Tensor(259315.11, shape=(), dtype=float32) 100
# slice = key, score = 0.27769999999999995
# np.mean(results), mse, len(results) =  0.347384420519316 tf.Tensor(228329.47, shape=(), dtype=float32) 1579
# slice = train, score = 0.347384420519316
# np.mean(results), mse, len(results) =  0.298 tf.Tensor(230329.05, shape=(), dtype=float32) 720
# slice = test, score = 0.298
#
# === Iteration 150000 ===
# np.mean(results), mse, len(results) =  0.27740000000000004 tf.Tensor(248789.75, shape=(), dtype=float32) 100
# slice = key, score = 0.27740000000000004
# np.mean(results), mse, len(results) =  0.3407219759341355 tf.Tensor(223610.44, shape=(), dtype=float32) 1579
# slice = train, score = 0.3407219759341355
# np.mean(results), mse, len(results) =  0.29565277777777776 tf.Tensor(224583.03, shape=(), dtype=float32) 720
# slice = test, score = 0.29565277777777776
#
# === Iteration 151000 ===
# np.mean(results), mse, len(results) =  0.278 tf.Tensor(265859.47, shape=(), dtype=float32) 100
# slice = key, score = 0.278
# np.mean(results), mse, len(results) =  0.342298923369221 tf.Tensor(233991.22, shape=(), dtype=float32) 1579
# slice = train, score = 0.342298923369221
# np.mean(results), mse, len(results) =  0.2976388888888889 tf.Tensor(235919.98, shape=(), dtype=float32) 720
# slice = test, score = 0.2976388888888889
#
# === Iteration 152000 ===
# np.mean(results), mse, len(results) =  0.27130000000000004 tf.Tensor(262812.75, shape=(), dtype=float32) 100
# slice = key, score = 0.27130000000000004
# np.mean(results), mse, len(results) =  0.3419442685243826 tf.Tensor(231146.8, shape=(), dtype=float32) 1579
# slice = train, score = 0.3419442685243826
# np.mean(results), mse, len(results) =  0.2955833333333333 tf.Tensor(233975.67, shape=(), dtype=float32) 720
# slice = test, score = 0.2955833333333333
#
# === Iteration 153000 ===
# np.mean(results), mse, len(results) =  0.27940000000000004 tf.Tensor(263267.47, shape=(), dtype=float32) 100
# slice = key, score = 0.27940000000000004
# np.mean(results), mse, len(results) =  0.34411019632678913 tf.Tensor(236474.34, shape=(), dtype=float32) 1579
# slice = train, score = 0.34411019632678913
# np.mean(results), mse, len(results) =  0.29650000000000004 tf.Tensor(239032.64, shape=(), dtype=float32) 720
# slice = test, score = 0.29650000000000004
#
# === Iteration 154000 ===
# np.mean(results), mse, len(results) =  0.2763 tf.Tensor(277145.28, shape=(), dtype=float32) 100
# slice = key, score = 0.2763
# np.mean(results), mse, len(results) =  0.3400759974667511 tf.Tensor(247272.36, shape=(), dtype=float32) 1579
# slice = train, score = 0.3400759974667511
# np.mean(results), mse, len(results) =  0.2958055555555556 tf.Tensor(248676.5, shape=(), dtype=float32) 720
# slice = test, score = 0.2958055555555556

# %%
+InnerDim + E + H
