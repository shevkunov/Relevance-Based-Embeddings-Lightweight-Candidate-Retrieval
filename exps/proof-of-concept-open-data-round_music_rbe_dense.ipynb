# %%
import requests
import json
import time

import yt
from yt.wrapper import YtClient, TablePath

from yql.api.v1.client import YqlClient

from IPython.display import clear_output
import tqdm
import os
import collections

import numpy as np
import pickle

from pathlib import Path

# %%
home_dir = Path.home()
with open(str(home_dir) + "/.yt/token") as f:
    YT_TOKEN = f.read().strip()
    os.environ["YT_TOKEN"] = YT_TOKEN
    
with open(str(home_dir) + "/.yql/token") as f:
    YQL_TOKEN = f.read().strip()
    # os.environ["YQL_TOKEN"] = YQL_TOKEN
    
client = YtClient("hahn")
yql_client = YqlClient(db="hahn", token=YQL_TOKEN)

# %% [markdown]
# https://yt.yandex-team.ru/hahn/navigation?path=//home/ads/users/shevkunov/music_rbe_transformer_tracks
#
# https://yt.yandex-team.ru/hahn/navigation?path=//home/ads/users/shevkunov/music_rbe_users_transformer-2024-07-31
#
# https://yql.yandex-team.ru/Operations/Zu01GNa9TD7VxVVs01nT9vc_NdYabRnkdBHSPBbR2x0=

# %%
top_tracks = client.read_table(TablePath("//home/ads/users/shevkunov/music_rbe__tracks_count", columns=["Cnt", "track"]))
min_users = 8000
track_wl = set()
for track in top_tracks:
    if track["Cnt"] >= min_users:
        track_wl.add(track["track"])
    else:
        break
        
track_wl_map = dict()
for track_i in track_wl:
    track_wl_map[track_i] = len(track_wl_map)

with open("music_rbe__track_wl__v1.pickle", "wb") as f:
    pickle.dump(track_wl, f)
    
len(track_wl)  #, track_wl_map
# Out:
# 8950

# %%
REQ = f"""
PRAGMA yt.InferSchema = "1";

$track_wl = [{', '.join(map(str, track_wl))}];

SELECT * FROM `//home/ads/users/shevkunov/music_rbe_multimod_transformer_tracks` WHERE `id` in $track_wl;
"""
r = yql_client.query(REQ, syntax_version=1)
r = r.run()
tracks_df = r.full_dataframe

tracks_emb = dict()
for i, row in tracks_df.iterrows():
    tracks_emb[row.id] = row.embedding

with open("music_rbe__tracks_emb__v1.pickle", "wb") as f:
    pickle.dump(tracks_emb, f)

len(tracks_emb)
# Out:
# Execution is in progress \ 2 minutes and 10 seconds elapsed
# 8950

# %%
REQ = f"""
PRAGMA yt.InferSchema = "1";

$track_wl = [{', '.join(map(str, track_wl))}];

SELECT * FROM `//home/ads/users/shevkunov/music_rbe_transformer_tracks` WHERE `id` in $track_wl;
"""
r = yql_client.query(REQ, syntax_version=1)
r = r.run()
tracks_df = r.full_dataframe

nomm_tracks_emb = dict()
for i, row in tracks_df.iterrows():
    nomm_tracks_emb[row.id] = row.embedding

with open("music_rbe__nomm_tracks_emb__v1.pickle", "wb") as f:
    pickle.dump(nomm_tracks_emb, f)

len(nomm_tracks_emb)
# Out:
# Execution is in progress \ 3 minutes and 2 seconds elapsed
# 8950

# %%
table_reader = client.read_table("//home/ads/users/shevkunov/music_rbe__formula-apply__score-tracks__result__sorted")

user2track2score = collections.defaultdict(dict)
lastuser = None

for i, row in tqdm.tqdm(enumerate(table_reader)):
    if len(user2track2score) > 1e9:
        if lastuser is None:
            lastuser = row["user"]
        elif lastuser != row["user"]:
            break
    if row["track"] in track_wl:
        user2track2score[row["user"]][row["track"]] = row["score"]
    #print(row)
    
with open("music_rbe__user2track2score__v1.pickle", "wb") as f:
    pickle.dump(user2track2score, f)
# Out:
# 129180862it [07:48, 369504.17it/s]2024-09-20 12:17:47,388	WARNING	Read request failed with error: timed out
# 2024-09-20 12:17:47,388	WARNING	Sleep for 2.09 seconds before next retry
# 2024-09-20 12:17:49,478	WARNING	New retry (1) ...
# 2024-09-20 12:17:49,479	INFO	Proxy sas6-1209-proxy-hahn.sas.yp-c.yandex.net unbanned
# 2024-09-20 12:18:51,617	WARNING	Read request failed with error: timed out
# 2024-09-20 12:18:51,618	WARNING	Sleep for 5.00 seconds before next retry
# 2024-09-20 12:18:56,619	WARNING	New retry (2) ...
# 988196296it [1:08:09, 241667.90it/s]

# %%
with open("music_rbe__user2track2score__v1.pickle", "rb") as f:
    user2track2score = pickle.load(f)

# %%
user2track2score_clean = dict()
for user_id, tracks in user2track2score.items():
    if len(track_wl.intersection(set(tracks.keys()))) >= 0.5 * len(track_wl):
        user2track2score_clean[user_id] = tracks
        

with open("music_rbe__user2track2score_clean__v1.pickle", "wb") as f:
    pickle.dump(user2track2score, f)
    
len(user2track2score_clean)
# Out:
# 10179

# %%
REQ = f"""
PRAGMA yt.InferSchema = "1";

$user_id = [{', '.join(map(str, user2track2score_clean.keys()))}];

SELECT * FROM `//home/ads/users/shevkunov/music_rbe_users_multimod_transformer-2024-07-31` WHERE `recent.uid.last` in $user_id;
"""
r = yql_client.query(REQ, syntax_version=1)
r = r.run()
users_df = r.full_dataframe

users_emb = dict()
for i, row in users_df.iterrows():
    users_emb[row["recent.uid.last"]] = row.recent
    

with open("music_rbe__users_emb_v1.pickle", "wb") as f:
    pickle.dump(users_emb, f)
    
len(users_emb)
# Out:
# Execution is in progress \ 5 minutes and 26 seconds elapsed
# 10179

# %%
REQ = f"""
PRAGMA yt.InferSchema = "1";

$user_id = [{', '.join(map(str, user2track2score_clean.keys()))}];

SELECT * FROM `//home/ads/users/shevkunov/music_rbe_users_transformer-2024-07-31` WHERE `recent.uid.last` in $user_id;
"""
r = yql_client.query(REQ, syntax_version=1)
r = r.run()
users_df = r.full_dataframe

nomm_users_emb = dict()
for i, row in users_df.iterrows():
    nomm_users_emb[row["recent.uid.last"]] = row.recent
    

with open("music_rbe__nomm_users_emb_v1.pickle", "wb") as f:
    pickle.dump(nomm_users_emb, f)
    
len(nomm_users_emb)
# Out:
# Execution is in progress / 16.09 seconds elapsed
# 9759

# %%
len(users_emb[325785555]), len(tracks_emb[115806632])
# Out:
# (1024, 256)

# %%
len(nomm_users_emb[325785555]), len(nomm_tracks_emb[115806632])
# Out:
# (768, 256)

# %%
Ue_mean = np.array(list(users_emb.values())).mean(axis=0)
Ge_mean = np.array(list(tracks_emb.values())).mean(axis=0)
Ue_mean.shape, Ge_mean.shape
# Out:
# ((1024,), (256,))

# %%
R = np.zeros((len(user2track2score_clean), len(track_wl_map)))
vs = list()

Ue = list()
Ge = [[]] * len(track_wl_map)

for track_id in track_wl_map:
    Ge[track_wl_map[track_id]] = tracks_emb.get(track_id, Ge_mean)

for user_id, real_user_id in enumerate(user2track2score_clean):
    Ue.append(users_emb.get(real_user_id, Ue_mean))
    for track_id, score in user2track2score[real_user_id].items():
        if track_id in track_wl_map:
            R[user_id, track_wl_map[track_id]] = score
            
            vs.append(score)
            
Ue = np.array(Ue)
Ge = np.array(Ge)
            
R[R == 0] = np.mean(vs)
R
# Out:
# array([[-0.31619492, -0.31619492,  2.28163106, ..., -0.31619492,
#          2.19785737,  2.10689082],
#        [ 0.05558677, -0.31619492, -0.31619492, ..., -0.31619492,
#         -0.31619492, -0.31619492],
#        [-0.31619492, -0.31619492,  1.68303014, ..., -0.31619492,
#         -0.31619492,  1.67687085],
#        ...,
#        [-0.7106882 , -0.31619492, -0.62269729, ..., -0.31619492,
#         -0.31619492, -0.31619492],
#        [ 5.06037174, -0.31619492,  5.19142489, ..., -0.31619492,
#         -0.31619492,  5.09818687],
#        [ 2.28674911, -0.31619492,  2.37860108, ..., -0.31619492,
#          2.22571627, -0.31619492]])

# %%
R.shape, Ue.shape, Ge.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 R.shape, Ue.shape, Ge.shape
#
# NameError: name 'R' is not defined

# %%
import pickle
import numpy as np
import os
import tqdm
import torch
import gc

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

from importlib import reload
from matplotlib import pyplot as plt

import matrix_approx_zeshel

matrix_approx_zeshel = reload(matrix_approx_zeshel)

# !ls  | grep matrix_approx_zeshel
# Out:
# matrix_approx_zeshel.py

# %% [markdown]
# # Open Data loader & context

# %%
def load_ment_to_ent_scores(directory = "yugioh", shuffle_rows = 0, full = True):
    data = list()

    for file in os.listdir(directory):
        path = f"{directory}/{file}"
        print(f"Loading file {path}")
        with open(path, "rb") as f:
            data.append(
                pickle.load(f)
            )
    data = sorted(data, key = lambda x: x["arg_dict"]["n_ment_start"])

    for i in range(len(data) - 1):
        if full:
            assert data[i]["arg_dict"]["n_ment_start"] + data[i]["arg_dict"]["n_ment"] == data[i + 1]["arg_dict"]["n_ment_start"]
        else:
            assert data[i]["arg_dict"]["n_ment_start"] + data[i]["arg_dict"]["n_ment"] <= data[i + 1]["arg_dict"]["n_ment_start"]
        
    ment_to_ent_scores = list(map(lambda x: x["ment_to_ent_scores"], data))
    ment_to_ent_scores = np.vstack(ment_to_ent_scores)
    print("Loaded shape = ", ment_to_ent_scores.shape)
    
    if shuffle_rows:
        print(f"Shuffling... (seed = {shuffle_rows})")
        np.random.seed(shuffle_rows)
        np.random.shuffle(ment_to_ent_scores)
    
    return ment_to_ent_scores

# %%
from sklearn.cluster import KMeans

def from_labels(X, labels):
    K = list()
    for i in range(100):
        sl_i = np.arange(X.shape[0])[labels == i]
        sl = X[labels == i]
        
        if len(sl_i) == 0:
            # bug-mode
            while True:
                chosen = np.random.choice(np.arange(X.shape[0])[labels < i], size=1)[0]
                if chosen not in K:
                    K.append(chosen)
                    break
            continue
            
        center = sl.mean(axis=0).reshape(1, -1)
        best = euclidean_distances(sl, center).argmin()
        K.append(sl_i[best])
        assert labels[K[-1]] == i
    return K

class EvalContextRelevs:
    def __init__(self, relevs, key_size = 100, train_size = 0.7, key_games = None, seed = 17, shuffle=False, det_attempts = 0):
        self.relevs = np.array(relevs)
        self.reqs_count = self.relevs.shape[0]
        self.games_count = self.relevs.shape[1]
        
        self.key_size = key_size
        self.key_games = (
            np.random.choice(np.arange(self.games_count), key_size, replace=False)
            if key_games is None else
            key_games
        )
        np.random.seed(seed)
        if shuffle:
            np.random.shuffle(self.relevs)

        self.try_det_attempts(det_attempts)
        self.train_split = int(self.reqs_count * train_size)

        assert key_size + 1 < self.train_split


        self.key_relevs = self.relevs[:key_size]
        self.train_relevs = self.relevs[key_size + 1: self.train_split]
        self.test_relevs = self.relevs[self.train_split:]

        self.slices = ["key", "train", "test"]
        print(len(self.key_relevs), len(self.train_relevs), len(self.test_relevs))

    def get_top_games(self):
        return self.relevs.mean(axis=0).argsort()[:100]

    def set_top_games_as_key(self):
        self.key_games = self.get_top_games()
        return self

    def get_kmeans_games(self, all_from_labels=True):
        X = self.get_relevs("train").T

        k_func = (
            (lambda C : euclidean_distances(X, C.cluster_centers_).argmin(axis=0))
            if not all_from_labels else
            (lambda C : from_labels(X, C.labels_))
        )
        K_KMeans = k_func(
            KMeans(n_clusters=self.key_size, random_state=0).fit(X)  #, n_init="auto").fit(X)
        )
        
        return K_KMeans
    
    def set_kmeans_games_as_key(self, *args, **kwargs):
        self.key_games = self.get_kmeans_games(*args, **kwargs)
        return self
    

    def try_det_attempts(self, det_attempts):
        def get_det(r):
            kr = r[:self.key_size, self.key_games] - r.mean()
            return np.abs(np.linalg.det(kr))

        best_i_array = np.arange(len(self.relevs))

        for i in range(det_attempts):

            r_i_array = np.arange(len(self.relevs))
            np.random.shuffle(r_i_array)

            n, o = get_det(self.relevs[r_i_array, :]), get_det(self.relevs[best_i_array, :])
            
            # print(f"try update key_reqs ({o} vs {n}...")
            if n > o:
                best_i_array = r_i_array
                print(f"updated det ({i}, {o} -> {n})")

        print("Best det = ", get_det(self.relevs[best_i_array, :]))

        self.relevs = self.relevs[best_i_array, :]
        print("Current de = ", get_det(self.relevs))
        
    def get_relevs(self, t = "train"):
        if t == "train":
            return self.train_relevs
        elif t == "key":
            return self.key_relevs
        elif t == "test":
            return self.test_relevs
        else:
            assert False
            
    def get_requests(self, t = "train"):
        if t == "train":
            return self.train_reqs
        elif t == "key":
            return self.key_reqs
        elif t == "test":
            return self.test_reqs
        else:
            assert False

# %% [markdown]
# # Games Data loader & context

# %%
import collections
import pickle
import numpy as np
import tqdm
import os
import gc

import matplotlib.pyplot as plt


def load(limit, raw_path = "stand/log.local.logtime2.txt", path = "log.local.logtime2.bin", key_games = None, seed = 17, det_attempts = 0):
    readvector = lambda s : np.array(list(map(float, s.strip()[1:-2].split(","))))
    requests = list()
    docembs = collections.defaultdict(dict)

    if os.path.isfile(path):
        with open(path, "rb") as f:
            flimit, frequests, fdocembs = pickle.load(f)
            if flimit == limit:
                requests, docembs = frequests, fdocembs
            else:
                print(f"WARN: buffered limit is different, {flimit} != {limit}, reloading...")

    if not requests:
        with open(raw_path) as f:
            req = list()
            reqid = None
            models = list()
            prevreqmodel = None
            reqmodel = dict()
            prevmodelid = -1
            bannermodelid = -1
            for i, line in tqdm.tqdm_notebook(enumerate(f)):
                if line.startswith("Model = 6;"):
                    prevreqmodel = reqmodel
                    reqmodel = dict()

                if line.startswith("Model = "):
                    spl = line.split(" ")
                    prevmodelid = int(spl[2][:-1])
                    bannermodelid = max(bannermodelid , prevmodelid)
                    reqmodel[prevmodelid] = readvector(spl[3])
                elif line.startswith("dbid"):
                    spl = line.split(" ")
                    dbid = int(spl[1][:-1])
                    docembs[bannermodelid][dbid] = readvector(spl[2])
                elif line.startswith("seed"):
                    if len(requests) >= limit:
                        break
                    if req:
                        requests.append((reqid, prevreqmodel, sorted(req)))
                        req = list()
                    reqid = "$_" + (line.split()[1] + "_" + line.split()[3])
                else:
                    req.append(
                        (int(line.split()[0]), float(line.split()[1]))
                    )
        
        with open(path, "wb") as f:
            pickle.dump((limit, requests, docembs), f)

    games_count = len(requests[0][2])
    assert games_count == 16514
    requests = [r for r in requests if len(r[2]) == games_count]
    
    print([(i, len(docembs[i].keys())) for i in docembs])  # should be equal
    docblocks = {
        mid : np.array([x[1] for x in sorted(list(docembs[mid].items()))])
        for mid in docembs
    }
    
    class EvalContext:
        def __init__(self, games_count = games_count, key_size = 100, train_size = 0.7, key_games = None, seed = 17, det_attempts = 0):
            self.games_count = games_count
            
            self.key_size = key_size
            self.key_games = (
                np.random.choice(np.arange(games_count), key_size, replace=False)
                if key_games is None else
                key_games
            )

            self.requests = requests
            np.random.seed(seed)
            np.random.shuffle(self.requests)
            
            self.try_det_attempts(det_attempts)

            self.key_reqs = self.requests[:key_size + 1]
            self.key_reqs_idx = np.arange(key_size + 1)

            self.train_split = int(len(self.requests) * train_size)

            assert key_size + 1 < self.train_split

            self.train_reqs = self.requests[key_size + 1: self.train_split]
            self.test_reqs = self.requests[self.train_split:]

            self.slices = ["key", "train", "test"]
            print(len(self.key_reqs), len(self.train_reqs), len(self.test_reqs))

            self.docblocks = docblocks
            self.relevs = dict()
            
        def get_top_games(self):
            if not hasattr(self, "top_games"):
                embed_games = np.array([
                    np.array([r[2][g_i][1] for r in self.get_requests("train")])
                    for g_i in range(self.games_count)
                ])

                self.embed_games_mean = embed_games.mean(axis=1)
                self.top_games_all = (-self.embed_games_mean).argsort()
                self.top_games = self.top_games_all[:len(self.key_games)]

            return self.top_games
        
        def set_top_games_as_key(self):
            self.key_games = self.get_top_games()
            return self
        
        def get_kmeans_games(self, all_from_labels=True):
            X = self.get_relevs("train").T

            k_func = (
                (lambda C : euclidean_distances(X, C.cluster_centers_).argmin(axis=0))
                if not all_from_labels else
                (lambda C : from_labels(X, C.labels_))
            )
            K_KMeans = k_func(
                KMeans(n_clusters=self.key_size, random_state=0).fit(X)  #, n_init="auto").fit(X)
            )

            return K_KMeans

        def set_kmeans_games_as_key(self, *args, **kwargs):
            self.key_games = self.get_kmeans_games(*args, **kwargs)
            return self

        def try_det_attempts(self, det_attempts, model_id = 6):
            def get_det(r, r_i_array):
                kr = np.array([
                    r[r_i][1][model_id]
                    for r_i in r_i_array[:100]
                ])
                return np.abs(np.linalg.det(kr[:kr.shape[1], :]))

            best_i_array = np.arange(len(self.requests))

            for _ in range(det_attempts):
                # print("try update key_reqs...")
                
                r_i_array = np.arange(len(self.requests))
                np.random.shuffle(r_i_array)
                
                n, o = get_det(self.requests, r_i_array), get_det(self.requests, best_i_array)
                # print(n, o)
                if n > o:
                    best_i_array = r_i_array
                    # print("updated!")

            print("Best det = ", get_det(self.requests, best_i_array))
            
            new_requests = [
                self.requests[i]
                for i in best_i_array
            ]
            
            del self.requests
            gc.collect()

            self.requests = new_requests
            print(get_det(self.requests, np.arange(len(self.requests))))

        def get_relevs(self, t = "train"):
            if t not in self.relevs:
                self.relevs[t] = np.array([
                    np.array([g_i[1] for g_i in r[2]])
                    for r in self.get_requests(t)
                ])
                
            return self.relevs[t]

        def get_requests(self, t = "train"):
            if t == "train":
                return self.train_reqs
            elif t == "key":
                return self.key_reqs
            elif t == "test":
                return self.test_reqs
            else:
                assert False

    return EvalContext(key_games = key_games, seed = seed, det_attempts = det_attempts)

# %% [markdown]
# # Models

# %%
class Popular:
    def __init__(self, ctx):
        self.ctx = ctx
        self.game_avg_scores = {
            t : self.get_user_scores(t).mean(axis = 0)
            for t in self.ctx.slices
        }
        self.trus_top = dict()
        
    def get_user_scores(self, t):
        return self.ctx.get_relevs(t)
    
    def get_user_embs(self, t):
        assert False
    
    def get_game_embs(self):
        assert False

    def fit(self, t = "train"):
        self.top_logits = self.game_avg_scores[t]
        self.top = np.argsort(-self.top_logits)

    def recommend(self, t):
        return [self.top_logits for _ in self.get_user_scores(t)]
    
    def get_score(self, t, topsize = 100):    
        recs = self.recommend(t)
        
        if isinstance(recs, list):
            recs = np.array(recs)
        
        mse = np.mean((recs - self.get_user_scores(t)) ** 2)
        
        if isinstance(recs, tf.Tensor):
            recs = tf.argsort(-recs, axis=1)[:, :topsize].numpy()
        else:
            recs = np.argsort(-recs, axis=1)[:, :topsize]
        
        if (t, topsize) not in self.trus_top:
            trus = self.get_user_scores(t)
            trus = np.argsort(-trus, axis=1)[:, :topsize]
            self.trus_top[(t, topsize)] = trus
            
        trus = self.trus_top[(t, topsize)]

        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
            
        results = [
            ev(rec, tru) / float(topsize)
            for rec, tru in zip(recs,trus)
        ]

        print("np.mean(results), mse, len(results) = ",
              np.mean(results), mse, len(results))

        return np.mean(results)

# %%
import tensorflow as tf
import copy
import tensorflow_ranking as tfr

DEFAULT_FIT_KWARGS = {
    "learning_rate": 0.001,
    "n": 500,
    "c": 5000,
    "matrix_l2": 0,
    "dssm_l2": 0,
    "train_popbias": False,
    "train_bias": False,
    "train_vbias": False,
    "verbose": True,
    "train_matrix": True,
    "train_dssm": False,
    "loss": "mse",
    "ubatch": 1e9,
    "activation": "relu",
    "score_verbose": 0,
    "trainable_items": False,
    "use_keys_in_train": False,
    "Winit": "glorot0.01",
    "Wfreeze": False,
    "TEinit": "legacy",
    "normalize_embs": True
}

class CBKnnV0(Popular):
    def __init__(self, ctx, fit_kwargs = dict()):
        super().__init__(ctx)
        
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(fit_kwargs)
        self.fit_kwargs = p
        
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(self.fit_kwargs)
        
        self.embed_users = {
            t : np.array([
                    np.array([r_i[i] for i in sorted(ctx.key_games)])
                    for r_i in ctx.get_relevs(t)
                ])
            for t in ctx.slices
        }
        self.embed_users_mean = {
            t : self.embed_users[t].mean(axis = 0)
            for t in ctx.slices
        }
        # embed_users = embed_users - embed_users_mean
        print("self.embed_users['train'].shape = ", self.embed_users['train'].shape )
        
        self.embed_games = np.array([
            np.array([r[g_i] for r in ctx.get_relevs("key")])
            for g_i in range(ctx.games_count)
        ])
        
        self.embed_games_mean = self.embed_games.mean(axis = 0)
        
        # embed_games = embed_games - embed_games_mean
        print("self.embed_games.shape = ", self.embed_games.shape)
        
        
        if self.fit_kwargs["trainable_items"]:
            if self.fit_kwargs["TEinit"] == "legacy":
                value = self.embed_games
            elif self.fit_kwargs["TEinit"] == "anncur":
                key_cols_idx = np.array(sorted(ctx.key_games))
                value = (
                    np.linalg.pinv(ctx.get_relevs("train")[:, key_cols_idx])
                    @ ctx.get_relevs("train")
                ).T
                print(type(value))
            else:
                assert False, "unknown TEinit: " + str(self.fit_kwargs["TEinit"])
                
            self.trainable_games = tf.Variable(
                tf.convert_to_tensor(value, dtype=tf.float32),
                trainable=True
            )
        else:
            if self.fit_kwargs["TEinit"] == "anncur":
                key_cols_idx = np.array(sorted(ctx.key_games))
                self.embed_games = (
                    np.linalg.pinv(ctx.get_relevs("train")[:, key_cols_idx])
                    @ ctx.get_relevs("train")
                ).T
                print("ANNCur init")
            
        
        self.games_top_key = self.embed_games.mean(axis = 1)
        
        self.games2users = np.array([
            self.embed_games[g_i]
            for g_i in ctx.key_games
        ])
        print("self.games2users.shape = ", self.games2users.shape)
        
        self.core_users_scores = ctx.get_relevs("key")
        print("self.core_users_scores.shape = ", self.core_users_scores.shape)
        
        self.core_users_embs = self.embed_users["key"]
        print("self.core_users_embs.shape = ", self.core_users_embs.shape)
        
        self.ge_users = (
            (self.embed_users["train"].T / self.embed_users["train"].mean(axis=1)).T @ self.games2users
        )
        # ge_users = embed_users @ games2users
        print("self.ge_users.shape = ", self.ge_users.shape)
    
    def __repr__(self):
        return "CbKnn(" + str(self.fit_kwargs) + ")"
        
    # inherited   
    # def get_user_scores(self, t):
    
    def get_user_embs(self, t):
        if self.fit_kwargs["normalize_embs"]:
            return (self.embed_users[t] - self.embed_users_mean["train"]) / self.embed_users[t].std(axis=0)
        else:
            return self.embed_users[t]
    
    def get_game_embs(self):
        if not self.fit_kwargs["trainable_items"]:
            if self.fit_kwargs["normalize_embs"]:
                return (self.embed_games - self.embed_games.mean(axis=0)) / self.embed_games.std(axis=0)
            else:
                return self.embed_games 
        else:
            return self.trainable_games

    def fit(self, **kwargs):
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(self.fit_kwargs)
        p.update(kwargs)

        self.p = p
        self.train_bias = p["train_bias"]
        self.train_vbias = p["train_vbias"]
        self.train_popbias = p["train_popbias"]
        self.train_matrix = p["train_matrix"]
        self.train_dssm = p["train_dssm"]
        self.loss = p["loss"]

        if p["use_keys_in_train"]:
            train_user_scores = np.vstack([
                self.get_user_scores("key"),
                self.get_user_scores("train")
            ])
            train_user_embs = np.vstack([
                self.get_user_embs("key"),
                self.get_user_embs("train")
            ])
        else:
            train_user_scores = self.get_user_scores("train")
            train_user_embs = self.get_user_embs("train")

        game_embs = self.get_game_embs()
        
        
        
        if self.p["Winit"] == "glorot0.01":
            initializer = tf.keras.initializers.GlorotUniform()
            values = initializer(shape=(train_user_embs.shape[1], game_embs.shape[1]))
            values = values / 100.  
        elif self.p["Winit"] == "glorot":
            initializer = tf.keras.initializers.GlorotUniform()
            values = initializer(shape=(train_user_embs.shape[1], game_embs.shape[1]))
        elif self.p["Winit"] == "eye":
            values = np.eye(train_user_embs.shape[1], game_embs.shape[1])
        else:
            assert False, "init is not known:" + str(self.p["init"])
            
        self.W = tf.Variable(values, trainable = True) 
        self.pb = tf.Variable(1., trainable = True) 
        self.b = tf.Variable(0., trainable = True) 
        
        if p["verbose"]:
            print("self.W = ", self.W)
            print("0-loss = ", tf.reduce_mean((train_user_scores - 0) ** 2))
    
        opt =  tf.keras.optimizers.Adam(learning_rate=p["learning_rate"])

        if self.train_dssm:
            self.train_dssm = True

            dim = game_embs.shape[1]
            self.g_dssm = tf.keras.Sequential([
                tf.keras.layers.Dense(dim, activation=p["activation"]),
                tf.keras.layers.Dense(dim, activation=None)
            ])
            self.g_dssm(game_embs)
            
            # dim = train_user_embs.shape[1]
            self.u_dssm = tf.keras.Sequential([
                tf.keras.layers.Dense(dim, activation=p["activation"]),
                tf.keras.layers.Dense(dim, activation=None)
            ])
            self.u_dssm(train_user_embs)
            
        if self.train_vbias:
            self.vb = tf.Variable(
                np.zeros_like(self.game_avg_scores["train"], dtype=np.float32),
                trainable = True
            ) 
        
        
        for i in range(p["n"]):
            def loss():
                def get_logits_scores(loss_batch = 1e9):
                    game_slice = None
                    
                    ubatch = p["ubatch"]
                    if ubatch >= train_user_scores.shape[0]:
                        train_user_embs_ = train_user_embs
                        scores_ = train_user_scores
                    else:
                        u_slice = np.random.choice(np.arange(train_user_scores.shape[0]), ubatch, replace = True)
                        train_user_embs_ = train_user_embs[u_slice]
                        scores_ = train_user_scores[u_slice]
                    
                    if loss_batch >= game_embs.shape[0]:
                        game_embs_ = game_embs
                        scores_ = scores_
                    else:
                        game_slice = np.random.choice(np.arange(game_embs.shape[0]), loss_batch, replace = True)
                        game_embs_ = (
                            game_embs[game_slice]
                            if isinstance(game_embs, np.ndarray) else
                            tf.gather(game_embs, game_slice)
                        )
                        scores_ = scores_[:, game_slice]
                        
                    
                    logits = 0
                    
                    if self.train_matrix:
                        logits += train_user_embs_ @ self.W @ tf.transpose(game_embs_)

                    if self.train_dssm:
                        logits += self.u_dssm(train_user_embs_) @ tf.transpose(self.g_dssm(game_embs_))
                    
                    if self.train_popbias:
                        if loss_batch >= game_embs.shape[0]:
                            logits += self.pb * self.game_avg_scores["train"]
                        else:
                            logits += self.pb * self.game_avg_scores["train"][game_slice]
                        
                    if self.train_vbias:
                        if loss_batch >= game_embs.shape[0]:
                            logits += self.vb
                        else:
                            logits += tf.gather(self.vb, game_slice)
                        
                    if self.train_bias:
                        logits += self.b
                        
                    return logits, scores_
                        
                if self.loss == "mse":
                    logits, scores = get_logits_scores(
                        loss_batch = (1e9 if "loss_batch" not in p else p["loss_batch"]))
                    v = tf.reduce_mean((scores - logits) ** 2)
                elif self.loss == "qmse":
                    logits, scores = get_logits_scores(
                        loss_batch = (1e9 if "loss_batch" not in p else p["loss_batch"]))
                    q_mean = scores.mean(axis=1)
                    v = tf.reduce_mean(((scores.T - q_mean).T - logits) ** 2)
                elif self.loss == "ApproxNDCGLoss":
                    while True:
                        logits, scores = get_logits_scores(
                            loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))

                        v = tfr.keras.losses.ApproxNDCGLoss()(
                            scores.astype(np.float32),
                            logits
                        )
                    
                        if not tf.math.is_nan(v).numpy().any():
                            break
                        else:
                            if p["verbose"]:
                                print("nanloss ignored")
                elif self.loss == "softmax":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        tf.nn.softmax(logits, axis=1),
                        0
                    ))
                elif self.loss == "softmax_signed":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    sf = tf.nn.softmax(logits, axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        sf,
                        -sf
                    ))
                elif self.loss == "softmax_weighted":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        tf.nn.softmax(logits, axis=1),
                        0
                    ) * scores)
                elif self.loss == "sigmoid_top_100":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    mask = np.argsort(-scores, axis=1) < 100
                    v = -tf.reduce_sum(
                        tf.math.log_sigmoid((2 * mask - 1) * logits)
                    )
                elif self.loss == "KL100":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    mask = np.argsort(-scores, axis=1) < 100
                    v = tf.keras.losses.KLDivergence()((scores.T >= qs.T).T, logits)
                else:
                    assert False
                    
                if self.p["c"]:
                    v += tf.reduce_mean(self.W * self.W) * p["c"]
                    
                if self.p["dssm_l2"]:
                    for weights_ in [self.u_dssm.weights, self.g_dssm.weights]:
                        for weight_ in weights_:
                            v += tf.reduce_sum(weight_ * weight_) * self.p["dssm_l2"]
                
                if self.p["matrix_l2"]:
                    v += tf.reduce_sum(self.W * self.W) * self.p["matrix_l2"]
                
                if p["verbose"]:
                    print(v.numpy())
                
                return v

            weights = list()
            
            if self.train_matrix and (not self.p["Wfreeze"]):
                weights += [self.W]

            if self.train_dssm:
                weights += self.u_dssm.weights
                weights += self.g_dssm.weights
            
            if self.train_popbias:
                weights += [self.pb]

            if self.train_vbias:
                weights += [self.vb]   
                
            if self.train_bias:
                weights += [self.b]   
                
            
            if self.p["trainable_items"]:
                weights += [self.trainable_games]
                
                
            opt.minimize(loss, weights)
            
            if p["score_verbose"] and (i % p["score_verbose"] == 0):
                print(f"\n=== Iteration {i} ===")
                for sl in self.ctx.slices:
                    print(f"slice = {sl}, score = {self.get_score(sl)}")
        print("last loss = ", loss())

    def recommend(self, t):
        logits = 0
                    
        if self.train_matrix:
            logits += self.get_user_embs(t) @ self.W @ tf.transpose(self.get_game_embs())

        if self.train_dssm:
            logits += self.u_dssm(self.get_user_embs(t)) @ tf.transpose(self.g_dssm(self.get_game_embs()))

        if self.train_popbias:
            logits += self.pb * self.game_avg_scores["train"]       
            
        if self.train_vbias:
            logits += self.vb
            
        if self.train_bias:
            logits += self.b
            
        return logits
    
    # inherited
    # def get_score(self, t, topsize = 100):
    
class DssmKnn(CBKnnV0):
    def __init__(self, ctx, modelid, fit_kwargs=dict()):
        super().__init__(ctx, fit_kwargs=fit_kwargs)
        self.modelid = modelid
        self.embed_games = ctx.docblocks[modelid]
        
    def __repr__(self):
        return "DssmKnn(" + str(self.modelid) + "," + str(self.fit_kwargs) + ")"
        
    def get_user_embs(self, t):
        return np.array([r[1][self.modelid] for r in self.ctx.get_requests(t)])
    
    def get_game_embs(self):
        return self.embed_games
    
def ev(mds, logs=None):
    for i in range(len(mds)):
        print("\n\n\n=======")
        print("model = ", mds[i])
        mds[i].fit()
        tr, te = mds[i].get_score("train"), mds[i].get_score("test")
        print(tr, te)
        if logs is not None:
            logs.append((
                repr(mds[i]),
                tr,
                te
            ))

# %%
class DssmKnn(CBKnnV0):
    def __init__(self, ctx, modelid, fit_kwargs=dict()):
        super().__init__(ctx, fit_kwargs=fit_kwargs)
        self.modelid = modelid
        self.embed_games = ctx.docblocks[modelid]
        
    def __repr__(self):
        return "DssmKnn(" + str(self.modelid) + "," + str(self.fit_kwargs) + ")"
        
    def get_user_embs(self, t):
        return np.array([r[1][self.modelid] for r in self.ctx.get_requests(t)])
    
    def get_game_embs(self):
        return self.embed_games
    
def ev(mds, logs=None):
    for i in range(len(mds)):
        print("\n\n\n=======")
        print("model = ", mds[i])
        mds[i].fit()
        tr, te = mds[i].get_score("train"), mds[i].get_score("test")
        print(tr, te)
        if logs is not None:
            logs.append((
                repr(mds[i]),
                tr,
                te
            ))

# %%
class AnnCUR(Popular):
    def __init__(self, ctx, oracle=False, key_games=None, name=None):
        super().__init__(ctx)
        self.oracle = oracle
        self.ctx = ctx
        self.name = name

        self.key_cols_idx = np.array(sorted(ctx.key_games if key_games is None else key_games))
        rows_idx = np.arange(ctx.get_relevs("train").shape[0])
        
        self.cur = matrix_approx_zeshel.CURApprox(
            rows=torch.from_numpy(ctx.get_relevs("train")),
            cols=torch.from_numpy(ctx.get_relevs("train")[:, self.key_cols_idx]),
            row_idxs=rows_idx,
            col_idxs=self.key_cols_idx,
            approx_preference="rows",
            A=(torch.from_numpy(ctx.get_relevs("train")) if oracle else None)
        )        
        
    def __repr__(self):
        if self.name is None:
            return f"AnnCur({id(self)})"
        else:
            return f"AnnCur({self.name} - {id(self)})"
        
    def get_user_scores(self, t):
        return self.ctx.get_relevs(t)
    
    def get_user_embs(self, t):
        assert False
    
    def get_game_embs(self):
        assert False

    def fit(self, t = "train"):
        self.top_logits = self.game_avg_scores[t]
        self.top = np.argsort(-self.top_logits)

    def recommend(self, t):
        key_relevs = torch.from_numpy(self.ctx.get_relevs(t)[:, self.key_cols_idx])
        return self.cur.get_complete_row(key_relevs)
    
    def get_score(self, t, topsize = 100):       
        recs = np.array(self.recommend(t))
        trus = self.get_user_scores(t)

        mse = np.mean((recs - trus) ** 2)

        recs = np.argsort(-recs, axis=1)[:, :topsize]
        trus = np.argsort(-trus, axis=1)[:, :topsize]

        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
            
        results = [
            ev(rec, tru) / float(topsize)
            for rec, tru in zip(recs,trus)
        ]

        print("np.mean(results), mse, len(results) = ",
              np.mean(results), mse, len(results))

        return np.mean(results)

# %% [markdown]
# # Evals

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import euclidean_distances

def from_labels(X, labels):
    K = list()
    for i in range(100):
        sl_i = np.arange(X.shape[0])[labels == i]
        sl = X[labels == i]
        
        if len(sl_i) == 0:
            # bug-mode
            while True:
                chosen = np.random.choice(np.arange(X.shape[0])[labels < i], size=1)[0]
                if chosen not in K:
                    K.append(chosen)
                    break
            continue
            
        center = sl.mean(axis=0).reshape(1, -1)
        best = euclidean_distances(sl, center).argmin()
        K.append(sl_i[best])
        assert labels[K[-1]] == i
    return K

def K_by_min(X):
    center = X.mean(axis=0)
    K = [euclidean_distances(X, center.reshape(1, -1)).argmax()]

    while len(K) < 100:
        K.append(euclidean_distances(X, X[K]).min(axis=1).argmax())
    return K


def eval_clustering(ctx, all_from_labels=False):
    X = ctx.get_relevs("train").T
    from sklearn.cluster import KMeans
    
    k_func = (
        (lambda C : euclidean_distances(X, C.cluster_centers_).argmin(axis=0))
        if not all_from_labels else
        (lambda C : from_labels(X, C.labels_))
    )
    
    K_KMeans = k_func(
        KMeans(n_clusters=100, random_state=0).fit(X)  #, n_init="auto").fit(X)
    )


    from sklearn.cluster import BisectingKMeans
    K_BisectingKMeans = k_func(
        BisectingKMeans(n_clusters=100, random_state=0).fit(X)
    )


    from sklearn.cluster import MiniBatchKMeans
    K_MiniBatchKMeans = from_labels(
        X,
        MiniBatchKMeans(n_clusters=100, random_state=0).fit(X).labels_
    )

    from sklearn.cluster import AgglomerativeClustering
    K_AgglomerativeClustering = from_labels(
        X,
        AgglomerativeClustering(n_clusters=100).fit(X).labels_
    )

    from sklearn.cluster import SpectralCoclustering
    K_SpectralCoclustering = from_labels(
        X,
        SpectralCoclustering(n_clusters=100, random_state=0).fit(X).row_labels_
    )

    from sklearn.cluster import SpectralBiclustering
    K_SpectralBiclustering = from_labels(
        X,
        SpectralBiclustering(n_clusters=100, random_state=0).fit(X).row_labels_
    )

    from sklearn.cluster import SpectralClustering
    K_SpectralClusteringNN = from_labels(
        X,
        SpectralClustering(n_clusters=100, random_state=0, affinity="nearest_neighbors", n_jobs=-1).fit(X).labels_
    )

    K_ByMin = K_by_min(X)

    ev([
        Popular(ctx),
        AnnCUR(ctx),
        AnnCUR(ctx, key_games=np.arange(100), name="key_games=np.arange(100)"),
        AnnCUR(ctx, key_games=np.random.choice(np.arange(X.shape[0]), size=100, replace=False), name="random"),
        AnnCUR(ctx, key_games=K_KMeans, name="K_KMeans"),
        AnnCUR(ctx, key_games=K_BisectingKMeans, name="K_BisectingKMeans"),
        AnnCUR(ctx, key_games=K_MiniBatchKMeans, name="K_MiniBatchKMeans"),
        AnnCUR(ctx, key_games=K_AgglomerativeClustering, name="K_AgglomerativeClustering"),
        AnnCUR(ctx, key_games=K_SpectralCoclustering, name="K_SpectralCoclustering"),
        AnnCUR(ctx, key_games=K_SpectralBiclustering, name="K_SpectralBiclustering"),
        AnnCUR(ctx, key_games=K_SpectralClusteringNN, name="K_SpectralClusteringNN"),
        AnnCUR(ctx, key_games=K_ByMin, name="K_ByMin"),
    ])

# %%
DATASETS = ["yugioh", "pro_wrestling", "star_trek", "doctor_who", "military"]

# %% [markdown]
# # support items choice

# %%
# setup:
# 1000 items, 1000 + 1000 queries
recall_k = 5
n_runs = 10
n_items_per_run = 1000
test_item_cnt = 100
item_cnt_range = list(range(5, 101, 5))
assert test_item_cnt in item_cnt_range

# %%
from collections import defaultdict
from itertools import combinations

from matplotlib import pyplot as plt
import numpy as np
import os
from sklearn.metrics import top_k_accuracy_score
from sklearn.cluster import KMeans
from scipy.stats import mannwhitneyu, ttest_rel

# %%
#with open("collections_10000_items/test.npy", "rb") as fin:
#    all_test = np.load(fin)
#with open("collections_10000_items/train.npy", "rb") as fin:
#    all_train = np.load(fin)

#assert all_train.shape[0] == n_runs * n_items_per_run
#assert all_test.shape[0] == n_runs * n_items_per_run

# %%
def eval_items(items, train, test):
    item_embeds = train.dot(np.linalg.pinv(train[items]))
    approx_test_rel = item_embeds.dot(test[items])
    approx_train_rel = item_embeds.dot(train[items])
    best_items = np.argsort(test, axis=0)[-1]
    recall = top_k_accuracy_score(best_items, approx_test_rel.T, k=recall_k, labels=np.arange(train.shape[0]))
    test_mse = np.mean((test - approx_test_rel) ** 2)
    train_mse = np.mean((train - approx_train_rel) ** 2)
    return recall, test_mse, train_mse

def get_rnd_items(n_items, train):
    return np.random.choice(train.shape[0], n_items, replace=False)

def get_kmeans_items(n_items, train):
    kmeans = KMeans(n_clusters=n_items, n_init="auto").fit(train)
    items = []
    for center in kmeans.cluster_centers_:
        distances = ((train - center) ** 2).sum(axis=1)
        assert distances.shape == (train.shape[0],)
        for item_id in np.argsort(distances):
            if item_id not in items:
                items.append(item_id)
                break
    return np.array(items, dtype=np.int64)

greedy_items = []
def get_greedy(n_items, train, lazy=True):
    global greedy_items
    if not lazy:
        greedy_items = []
    if len(greedy_items) >= n_items:
        return np.array(greedy_items[:n_items], dtype=np.int64)
    
    gram = train.dot(train.T)
    gram /= gram.mean()
    items = []
    remaining_items = np.ones(train.shape[0], dtype="bool")
    for t in range(n_items):
        scores = (gram ** 2).sum(axis=1)
        assert np.allclose(scores[~remaining_items], np.zeros_like(scores[~remaining_items])), (
            t, scores[~remaining_items]
        )
        scores[remaining_items] /= gram[remaining_items, remaining_items]
        if max(scores) < 1e-9:
            break
        new_item = scores.argmax()
        assert remaining_items[new_item]
        coefs = gram[new_item] / np.sqrt(gram[new_item, new_item])
        diff = coefs.reshape(-1, 1).dot(coefs.reshape(1, -1))
        gram -= diff
        assert np.allclose(gram[new_item], np.zeros_like(gram[new_item]), atol=1e-6), (
            t, gram[new_item].std()
        )
        items.append(new_item)
        remaining_items[new_item] = False
    assert len(items) == n_items
    greedy_items.clear()
    greedy_items.extend(items)
    return np.array(items, dtype=np.int64)

# %% [markdown]
# ### fast-a

# %%
def coitem_algorithm(n_support, candidate_items, target_items, min_item_rel_norm=1e-5, eps=1e-6):
    support_items = []
    support_items_scores = []
    n_c, n_q = candidate_items.shape
    n_t = target_items.shape[0]

    candidate_item_squared_norms = (candidate_items ** 2).sum(axis=1)
    min_item_norm = min_item_rel_norm * np.sqrt(candidate_item_squared_norms.mean())
    
    candidate_coitems = candidate_items.dot(
        target_items.T.dot(target_items)
    )
    orthonormed_support_items = np.zeros((n_support, n_q))
    remaining_items = np.ones(candidate_items.shape[0], dtype="bool")
    for t in tqdm.tqdm_notebook(range(n_support)):
        scores = (candidate_coitems * candidate_items).sum(axis=1)
        remaining_items &= (candidate_item_squared_norms >= min_item_norm ** 2)
        scores[remaining_items] /= candidate_item_squared_norms[remaining_items]
        scores[~remaining_items] = 0
        
        new_item_id = np.argmax(scores)
        assert remaining_items[new_item_id]
        support_items.append(new_item_id)
        support_items_scores.append(scores[new_item_id] / (n_t * n_q))
        remaining_items[new_item_id] = False
        
        new_item = candidate_items[new_item_id].copy()
        new_item -= orthonormed_support_items[:t].T.dot(
            orthonormed_support_items[:t].dot(new_item)
        )
        assert np.allclose((new_item ** 2).sum(), candidate_item_squared_norms[new_item_id], atol=eps)
        new_item /= np.sqrt((new_item ** 2).sum())
        orthonormed_support_items[t] = new_item
        new_coitem = candidate_coitems[new_item_id] / np.sqrt(candidate_item_squared_norms[new_item_id])
        
        coefs = (candidate_items * new_item).sum(axis=1)
        candidate_item_squared_norms -= coefs ** 2
        assert np.all(candidate_item_squared_norms[remaining_items] > -eps)
        
        candidate_coitems -= coefs.reshape((-1, 1)).dot(new_coitem.reshape((1, -1)))
        cocoefs = (candidate_coitems * new_item).sum(axis=1, keepdims=True)
        candidate_coitems -= cocoefs.dot(new_item.reshape((1, -1)))
    return np.array(support_items, dtype=np.int64), np.array(support_items_scores)

# %%
R.shape
# Out:
# (10179, 8950)

# %%
with open("rbe_music_10179_8950.npz", "wb") as f:
    np.savez(f, R)

# %%
R.shape
# Out:
# (10179, 8950)

# %%
ctx = EvalContextRelevs(
    R,
    det_attempts=0
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ctx = EvalContextRelevs(
#       2     R,
#       3     det_attempts=0
#       4 )
#
# NameError: name 'EvalContextRelevs' is not defined

# %%
class DssmKnnUGe(CBKnnV0):
    def __init__(self, ctx, ge, ue, fit_kwargs=dict()):
        super().__init__(ctx, fit_kwargs=fit_kwargs)
        self.ge = ge
        self.ue = ue
        
    def __repr__(self):
        return "DssmKnnUGe"
        
    def get_user_embs(self, t):
        return self.ue[t]
    
    def get_game_embs(self):
        return self.ge

# %%
ma = Popular(ctx)

ma.fit()
ma.get_score("train"), ma.get_score("test")
# Out:
# np.mean(results), mse, len(results) =  0.01625996583143508 3.0031844921742272 7024
# np.mean(results), mse, len(results) =  0.015582842174197774 3.312783094057841 3054
# (0.01625996583143508, 0.015582842174197774)

# %%
t = ctx.get_relevs("train").T
ctx.key_games = list(coitem_algorithm(100, t, t, 1e-8, eps=1e9)[0])

print("KEY_SET")

ma = AnnCUR(ctx, key_games=ctx.key_games)

ma.fit()
ma.get_score("train"), ma.get_score("test")
# Out:
# /tmp/ipykernel_131116/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# KEY_SET
# np.mean(results), mse, len(results) =  0.08292141230068338 0.6352993196478236 7024
# np.mean(results), mse, len(results) =  0.08001637197118534 0.7627728107746592 3054
# (0.08292141230068338, 0.08001637197118534)

# %%
eval_clustering(ctx, all_from_labels=True)
# Out:
# /home/shevkunov/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/shevkunov/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/shevkunov/anaconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# =======
# model =  <__main__.Popular object at 0x7fea2e794040>
# np.mean(results), mse, len(results) =  0.01625996583143508 3.0031844921742272 7024
# np.mean(results), mse, len(results) =  0.015582842174197774 3.312783094057841 3054
# 0.01625996583143508 0.015582842174197774
#
#
#
# =======
# model =  AnnCur(140643778773584)
# np.mean(results), mse, len(results) =  0.08292141230068338 0.6352993196478236 7024
# np.mean(results), mse, len(results) =  0.08001637197118534 0.7627728107746592 3054
# 0.08292141230068338 0.08001637197118534
#
#
#
# =======
# model =  AnnCur(key_games=np.arange(100) - 140645000719296)
# np.mean(results), mse, len(results) =  0.08357915717539864 0.6843669793305022 7024
# np.mean(results), mse, len(results) =  0.07724950884086444 0.8152554819129131 3054
# 0.08357915717539864 0.07724950884086444
#
#
#
# =======
# model =  AnnCur(random - 140645000719440)
# np.mean(results), mse, len(results) =  0.08086417995444191 0.6762199293521317 7024
# np.mean(results), mse, len(results) =  0.07862802881466928 0.8063285684341726 3054
# 0.08086417995444191 0.07862802881466928
#
#
#
# =======
# model =  AnnCur(K_KMeans - 140645000717664)
# np.mean(results), mse, len(results) =  0.07953730068337131 0.6569932556033377 7024
# np.mean(results), mse, len(results) =  0.07947609692206942 0.786594450922724 3054
# 0.07953730068337131 0.07947609692206942
#
#
#
# =======
# model =  AnnCur(K_BisectingKMeans - 140645000723568)
# np.mean(results), mse, len(results) =  0.0778132118451025 0.6632662862493823 7024
# np.mean(results), mse, len(results) =  0.07659462999345122 0.7941929778040155 3054
# 0.0778132118451025 0.07659462999345122
#
#
#
# =======
# model =  AnnCur(K_MiniBatchKMeans - 140645000714736)
# np.mean(results), mse, len(results) =  0.09255267653758545 0.6649921881984696 7024
# np.mean(results), mse, len(results) =  0.08947282252783235 0.791304904274431 3054
# 0.09255267653758545 0.08947282252783235
#
#
#
# =======
# model =  AnnCur(K_AgglomerativeClustering - 140645000101168)
# np.mean(results), mse, len(results) =  0.08055808656036449 0.6600278620367152 7024
# np.mean(results), mse, len(results) =  0.07854944335297971 0.7901532585534093 3054
# 0.08055808656036449 0.07854944335297971
#
#
#
# =======
# model =  AnnCur(K_SpectralCoclustering - 140645000094256)
# np.mean(results), mse, len(results) =  0.07546697038724373 0.6666374210923437 7024
# np.mean(results), mse, len(results) =  0.07405697445972495 0.7995735436981481 3054
# 0.07546697038724373 0.07405697445972495
#
#
#
# =======
# model =  AnnCur(K_SpectralBiclustering - 140645000097232)
# np.mean(results), mse, len(results) =  0.0684239749430524 0.672183279446827 7024
# np.mean(results), mse, len(results) =  0.06687295350360184 0.8050213819063747 3054
# 0.0684239749430524 0.06687295350360184
#
#
#
# =======
# model =  AnnCur(K_SpectralClusteringNN - 140645000099632)
# np.mean(results), mse, len(results) =  0.10505267653758543 0.6732942241235055 7024
# np.mean(results), mse, len(results) =  0.09846430910281599 0.8049626886978455 3054
# 0.10505267653758543 0.09846430910281599
#
#
#
# =======
# model =  AnnCur(K_ByMin - 140645000099536)
# np.mean(results), mse, len(results) =  0.047706435079726654 0.6951993049623938 7024
# np.mean(results), mse, len(results) =  0.0475442043222004 0.8307747081304712 3054
# 0.047706435079726654 0.0475442043222004

# %%
Ue_ = {
    "key": Ue[:ctx.key_size][:, :256],
    "train": Ue[ctx.key_size + 1: ctx.train_split][:, :256],
    "test": Ue[ctx.train_split:][:, :256], 
}

N = 1 # 1 # 100000 #
d = DssmKnnUGe(ctx, Ge, Ue_, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': False,
    'train_vbias': True,
    'train_popbias': True, 'train_bias': True,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.001
})
d.fit()
d.get_score("train"), d.get_score("test")
# Out:
# self.embed_users['train'].shape =  (7024, 100)
# self.embed_games.shape =  (8950, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8950)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (7024, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.021199999999999997 tf.Tensor(2.7508086111111427, shape=(), dtype=float64) 100
# slice = key, score = 0.021199999999999997
# np.mean(results), mse, len(results) =  0.023382687927107064 tf.Tensor(3.0614081678703267, shape=(), dtype=float64) 7024
# slice = train, score = 0.023382687927107064
# np.mean(results), mse, len(results) =  0.022459070072036673 tf.Tensor(3.489094120775516, shape=(), dtype=float64) 3054
# slice = test, score = 0.022459070072036673
# last loss =  tf.Tensor(0.00428468350974365, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.023382687927107064 tf.Tensor(3.0614081678703267, shape=(), dtype=float64) 7024
# np.mean(results), mse, len(results) =  0.022459070072036673 tf.Tensor(3.489094120775516, shape=(), dtype=float64) 3054
# (0.023382687927107064, 0.022459070072036673)

# %%
select_head = 0
Ue_ = {
    "key": Ue[:ctx.key_size][:, select_head*256:(select_head + 1) * 256],
    "train": Ue[ctx.key_size + 1: ctx.train_split][:, select_head*256:(select_head + 1) * 256],
    "test": Ue[ctx.train_split:][:, select_head*256:(select_head + 1) * 256], 
}

N = 1 # 1 # 100000 #
d = DssmKnnUGe(ctx, Ge, Ue_, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': False,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.001
})
d.fit()
d.get_score("train"), d.get_score("test")
# Out:
# self.embed_users['train'].shape =  (7024, 100)
# self.embed_games.shape =  (8950, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8950)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (7024, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.1433 tf.Tensor(2.6705411310176665, shape=(), dtype=float64) 100
# slice = key, score = 0.1433
# np.mean(results), mse, len(results) =  0.13704014806378131 tf.Tensor(3.037295377147487, shape=(), dtype=float64) 7024
# slice = train, score = 0.13704014806378131
# np.mean(results), mse, len(results) =  0.13259986902423052 tf.Tensor(3.288704347326712, shape=(), dtype=float64) 3054
# slice = test, score = 0.13259986902423052
# last loss =  tf.Tensor(0.004527863848134114, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.13704014806378131 tf.Tensor(3.037295377147487, shape=(), dtype=float64) 7024
# np.mean(results), mse, len(results) =  0.13259986902423052 tf.Tensor(3.288704347326712, shape=(), dtype=float64) 3054
# (0.13704014806378131, 0.13259986902423052)

# %%
select_head = 1
Ue_ = {
    "key": Ue[:ctx.key_size][:, select_head*256:(select_head + 1) * 256],
    "train": Ue[ctx.key_size + 1: ctx.train_split][:, select_head*256:(select_head + 1) * 256],
    "test": Ue[ctx.train_split:][:, select_head*256:(select_head + 1) * 256], 
}

N = 1 # 1 # 100000 #
d = DssmKnnUGe(ctx, Ge, Ue_, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': False,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.001
})
d.fit()
d.get_score("train"), d.get_score("test")
# Out:
# self.embed_users['train'].shape =  (7024, 100)
# self.embed_games.shape =  (8950, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8950)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (7024, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.13999999999999999 tf.Tensor(2.6858903931916296, shape=(), dtype=float64) 100
# slice = key, score = 0.13999999999999999
# np.mean(results), mse, len(results) =  0.13665859908883826 tf.Tensor(3.0662832957267856, shape=(), dtype=float64) 7024
# slice = train, score = 0.13665859908883826
# np.mean(results), mse, len(results) =  0.13380484610347085 tf.Tensor(3.283229757476671, shape=(), dtype=float64) 3054
# slice = test, score = 0.13380484610347085
# last loss =  tf.Tensor(0.004671197097350585, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.13665859908883826 tf.Tensor(3.0662832957267856, shape=(), dtype=float64) 7024
# np.mean(results), mse, len(results) =  0.13380484610347085 tf.Tensor(3.283229757476671, shape=(), dtype=float64) 3054
# (0.13665859908883826, 0.13380484610347085)

# %%
select_head = 2
Ue_ = {
    "key": Ue[:ctx.key_size][:, select_head*256:(select_head + 1) * 256],
    "train": Ue[ctx.key_size + 1: ctx.train_split][:, select_head*256:(select_head + 1) * 256],
    "test": Ue[ctx.train_split:][:, select_head*256:(select_head + 1) * 256], 
}

N = 1 # 1 # 100000 #
d = DssmKnnUGe(ctx, Ge, Ue_, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': False,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.001
})
d.fit()
d.get_score("train"), d.get_score("test")
# Out:
# self.embed_users['train'].shape =  (7024, 100)
# self.embed_games.shape =  (8950, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8950)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (7024, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.039700000000000006 tf.Tensor(3.4511051337902185, shape=(), dtype=float64) 100
# slice = key, score = 0.039700000000000006
# np.mean(results), mse, len(results) =  0.04925541002277905 tf.Tensor(3.94265798756022, shape=(), dtype=float64) 7024
# slice = train, score = 0.04925541002277905
# np.mean(results), mse, len(results) =  0.06599214145383105 tf.Tensor(3.86828519985425, shape=(), dtype=float64) 3054
# slice = test, score = 0.06599214145383105
# last loss =  tf.Tensor(0.00448987767859459, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.04925541002277905 tf.Tensor(3.94265798756022, shape=(), dtype=float64) 7024
# np.mean(results), mse, len(results) =  0.06599214145383105 tf.Tensor(3.86828519985425, shape=(), dtype=float64) 3054
# (0.04925541002277905, 0.06599214145383105)

# %%
select_head = 0
Ue_ = {
    "key": Ue[:ctx.key_size][:, select_head*256:(select_head + 1) * 256],
    "train": Ue[ctx.key_size + 1: ctx.train_split][:, select_head*256:(select_head + 1) * 256],
    "test": Ue[ctx.train_split:][:, select_head*256:(select_head + 1) * 256], 
}

N = 100000 #
d = DssmKnnUGe(ctx, Ge, Ue_, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.001
})
d.fit()
d.get_score("train"), d.get_score("test")
# Out:
# self.embed_users['train'].shape =  (1674, 100)
# self.embed_games.shape =  (8127, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8127)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (1674, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.0706 tf.Tensor(2.724939639973357, shape=(), dtype=float64) 100
# slice = key, score = 0.0706
# np.mean(results), mse, len(results) =  0.06381123058542414 tf.Tensor(2.902961548307981, shape=(), dtype=float64) 1674
# slice = train, score = 0.06381123058542414
# np.mean(results), mse, len(results) =  0.06291721419185282 tf.Tensor(2.8361906550438674, shape=(), dtype=float64) 761
# slice = test, score = 0.06291721419185282
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.021399999999999995 tf.Tensor(8305.048319422396, shape=(), dtype=float64) 100
# slice = key, score = 0.021399999999999995
# np.mean(results), mse, len(results) =  0.017007168458781363 tf.Tensor(8296.723533791122, shape=(), dtype=float64) 1674
# slice = train, score = 0.017007168458781363
# np.mean(results), mse, len(results) =  0.016859395532194482 tf.Tensor(8242.043221436537, shape=(), dtype=float64) 761
# slice = test, score = 0.016859395532194482
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.0207 tf.Tensor(818.8042392467383, shape=(), dtype=float64) 100
# slice = key, score = 0.0207
# np.mean(results), mse, len(results) =  0.018560334528076462 tf.Tensor(750.0137552037914, shape=(), dtype=float64) 1674
# slice = train, score = 0.018560334528076462
# np.mean(results), mse, len(results) =  0.015584756898817345 tf.Tensor(718.2650963038334, shape=(), dtype=float64) 761
# slice = test, score = 0.015584756898817345
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.029699999999999997 tf.Tensor(572.2329623045605, shape=(), dtype=float64) 100
# slice = key, score = 0.029699999999999997
# np.mean(results), mse, len(results) =  0.03192951015531661 tf.Tensor(736.2209634804534, shape=(), dtype=float64) 1674
# slice = train, score = 0.03192951015531661
# np.mean(results), mse, len(results) =  0.021419185282523 tf.Tensor(736.7163786685237, shape=(), dtype=float64) 761
# slice = test, score = 0.021419185282523
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.0356 tf.Tensor(465.8078171565173, shape=(), dtype=float64) 100
# slice = key, score = 0.0356
# np.mean(results), mse, len(results) =  0.04080645161290323 tf.Tensor(509.0680313728094, shape=(), dtype=float64) 1674
# slice = train, score = 0.04080645161290323
# np.mean(results), mse, len(results) =  0.027910643889618926 tf.Tensor(515.162318973714, shape=(), dtype=float64) 761
# slice = test, score = 0.027910643889618926
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.0525 tf.Tensor(694.9577709897814, shape=(), dtype=float64) 100
# slice = key, score = 0.0525
# np.mean(results), mse, len(results) =  0.047001194743130234 tf.Tensor(748.3665075617417, shape=(), dtype=float64) 1674
# slice = train, score = 0.047001194743130234
# np.mean(results), mse, len(results) =  0.029342969776609728 tf.Tensor(787.7951274581761, shape=(), dtype=float64) 761
# slice = test, score = 0.029342969776609728
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.06019999999999999 tf.Tensor(1090.9137624508683, shape=(), dtype=float64) 100
# slice = key, score = 0.06019999999999999
# np.mean(results), mse, len(results) =  0.053524492234169656 tf.Tensor(994.7345322715214, shape=(), dtype=float64) 1674
# slice = train, score = 0.053524492234169656
# np.mean(results), mse, len(results) =  0.03620236530880421 tf.Tensor(957.2542699037897, shape=(), dtype=float64) 761
# slice = test, score = 0.03620236530880421
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.06239999999999999 tf.Tensor(1046.164630228736, shape=(), dtype=float64) 100
# slice = key, score = 0.06239999999999999
# np.mean(results), mse, len(results) =  0.05850059737156512 tf.Tensor(979.7491700953201, shape=(), dtype=float64) 1674
# slice = train, score = 0.05850059737156512
# np.mean(results), mse, len(results) =  0.039369250985545334 tf.Tensor(954.1591333563026, shape=(), dtype=float64) 761
# slice = test, score = 0.039369250985545334
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.06339999999999998 tf.Tensor(1460.6944539395993, shape=(), dtype=float64) 100
# slice = key, score = 0.06339999999999998
# np.mean(results), mse, len(results) =  0.061338112305854245 tf.Tensor(1412.6737882118034, shape=(), dtype=float64) 1674
# slice = train, score = 0.061338112305854245
# np.mean(results), mse, len(results) =  0.03657030223390276 tf.Tensor(1408.897790185914, shape=(), dtype=float64) 761
# slice = test, score = 0.03657030223390276
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.0679 tf.Tensor(2017.984722281177, shape=(), dtype=float64) 100
# slice = key, score = 0.0679
# np.mean(results), mse, len(results) =  0.06676224611708484 tf.Tensor(1871.2402627547197, shape=(), dtype=float64) 1674
# slice = train, score = 0.06676224611708484
# np.mean(results), mse, len(results) =  0.04065703022339028 tf.Tensor(1759.9615817020376, shape=(), dtype=float64) 761
# slice = test, score = 0.04065703022339028
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.0683 tf.Tensor(2637.031459462263, shape=(), dtype=float64) 100
# slice = key, score = 0.0683
# np.mean(results), mse, len(results) =  0.06894265232974911 tf.Tensor(2623.2009912439416, shape=(), dtype=float64) 1674
# slice = train, score = 0.06894265232974911
# np.mean(results), mse, len(results) =  0.04002628120893561 tf.Tensor(2559.9494056018357, shape=(), dtype=float64) 761
# slice = test, score = 0.04002628120893561
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.07190000000000002 tf.Tensor(2634.2791057990316, shape=(), dtype=float64) 100
# slice = key, score = 0.07190000000000002
# np.mean(results), mse, len(results) =  0.07039426523297491 tf.Tensor(2654.5192083697016, shape=(), dtype=float64) 1674
# slice = train, score = 0.07039426523297491
# np.mean(results), mse, len(results) =  0.03960578186596584 tf.Tensor(2690.7366475389354, shape=(), dtype=float64) 761
# slice = test, score = 0.03960578186596584
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.0726 tf.Tensor(3641.3877197430143, shape=(), dtype=float64) 100
# slice = key, score = 0.0726
# np.mean(results), mse, len(results) =  0.0728673835125448 tf.Tensor(3854.6750264216075, shape=(), dtype=float64) 1674
# slice = train, score = 0.0728673835125448
# np.mean(results), mse, len(results) =  0.04293035479632063 tf.Tensor(4093.4844021363447, shape=(), dtype=float64) 761
# slice = test, score = 0.04293035479632063
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.0765 tf.Tensor(7489.08779481053, shape=(), dtype=float64) 100
# slice = key, score = 0.0765
# np.mean(results), mse, len(results) =  0.07371565113500597 tf.Tensor(7876.946737516752, shape=(), dtype=float64) 1674
# slice = train, score = 0.07371565113500597
# np.mean(results), mse, len(results) =  0.042312746386333776 tf.Tensor(8099.832905496487, shape=(), dtype=float64) 761
# slice = test, score = 0.042312746386333776
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.07440000000000001 tf.Tensor(7273.201619434892, shape=(), dtype=float64) 100
# slice = key, score = 0.07440000000000001
# np.mean(results), mse, len(results) =  0.0763978494623656 tf.Tensor(7667.569364631682, shape=(), dtype=float64) 1674
# slice = train, score = 0.0763978494623656
# np.mean(results), mse, len(results) =  0.04268068331143233 tf.Tensor(8040.330375798011, shape=(), dtype=float64) 761
# slice = test, score = 0.04268068331143233
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.08170000000000002 tf.Tensor(8478.031412466471, shape=(), dtype=float64) 100
# slice = key, score = 0.08170000000000002
# np.mean(results), mse, len(results) =  0.08064516129032258 tf.Tensor(8602.4663332197, shape=(), dtype=float64) 1674
# slice = train, score = 0.08064516129032258
# np.mean(results), mse, len(results) =  0.0483311432325887 tf.Tensor(8760.333365923432, shape=(), dtype=float64) 761
# slice = test, score = 0.0483311432325887
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.0825 tf.Tensor(9436.348242324786, shape=(), dtype=float64) 100
# slice = key, score = 0.0825
# np.mean(results), mse, len(results) =  0.08072281959378733 tf.Tensor(10042.399471456065, shape=(), dtype=float64) 1674
# slice = train, score = 0.08072281959378733
# np.mean(results), mse, len(results) =  0.046241787122207625 tf.Tensor(10258.5560911192, shape=(), dtype=float64) 761
# slice = test, score = 0.046241787122207625
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.0791 tf.Tensor(12212.875561587547, shape=(), dtype=float64) 100
# slice = key, score = 0.0791
# np.mean(results), mse, len(results) =  0.08096774193548388 tf.Tensor(12589.498210095946, shape=(), dtype=float64) 1674
# slice = train, score = 0.08096774193548388
# np.mean(results), mse, len(results) =  0.04287779237844941 tf.Tensor(12690.650682241192, shape=(), dtype=float64) 761
# slice = test, score = 0.04287779237844941
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.0827 tf.Tensor(14493.38085659656, shape=(), dtype=float64) 100
# slice = key, score = 0.0827
# np.mean(results), mse, len(results) =  0.08241935483870967 tf.Tensor(14485.910785881422, shape=(), dtype=float64) 1674
# slice = train, score = 0.08241935483870967
# np.mean(results), mse, len(results) =  0.043968462549277276 tf.Tensor(14585.222586189955, shape=(), dtype=float64) 761
# slice = test, score = 0.043968462549277276
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.0863 tf.Tensor(14512.835331151682, shape=(), dtype=float64) 100
# slice = key, score = 0.0863
# np.mean(results), mse, len(results) =  0.08630227001194743 tf.Tensor(14540.834879945782, shape=(), dtype=float64) 1674
# slice = train, score = 0.08630227001194743
# np.mean(results), mse, len(results) =  0.051590013140604477 tf.Tensor(14354.265903845444, shape=(), dtype=float64) 761
# slice = test, score = 0.051590013140604477
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.08960000000000001 tf.Tensor(15637.06235734233, shape=(), dtype=float64) 100
# slice = key, score = 0.08960000000000001
# np.mean(results), mse, len(results) =  0.08688769414575866 tf.Tensor(15857.878794848079, shape=(), dtype=float64) 1674
# slice = train, score = 0.08688769414575866
# np.mean(results), mse, len(results) =  0.04781865965834428 tf.Tensor(16242.063324913881, shape=(), dtype=float64) 761
# slice = test, score = 0.04781865965834428
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.08560000000000001 tf.Tensor(22150.834625218915, shape=(), dtype=float64) 100
# slice = key, score = 0.08560000000000001
# np.mean(results), mse, len(results) =  0.08816009557945043 tf.Tensor(23313.273624453745, shape=(), dtype=float64) 1674
# slice = train, score = 0.08816009557945043
# np.mean(results), mse, len(results) =  0.04851511169513798 tf.Tensor(24153.030035928183, shape=(), dtype=float64) 761
# slice = test, score = 0.04851511169513798
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.08739999999999998 tf.Tensor(25062.271193140667, shape=(), dtype=float64) 100
# slice = key, score = 0.08739999999999998
# np.mean(results), mse, len(results) =  0.08773596176821984 tf.Tensor(25905.635778623797, shape=(), dtype=float64) 1674
# slice = train, score = 0.08773596176821984
# np.mean(results), mse, len(results) =  0.049237844940867276 tf.Tensor(26898.104516831943, shape=(), dtype=float64) 761
# slice = test, score = 0.049237844940867276
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.092 tf.Tensor(28449.321152341025, shape=(), dtype=float64) 100
# slice = key, score = 0.092
# np.mean(results), mse, len(results) =  0.09116487455197134 tf.Tensor(28906.769454787187, shape=(), dtype=float64) 1674
# slice = train, score = 0.09116487455197134
# np.mean(results), mse, len(results) =  0.04911957950065703 tf.Tensor(28632.6149367758, shape=(), dtype=float64) 761
# slice = test, score = 0.04911957950065703
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.0933 tf.Tensor(34028.5704786632, shape=(), dtype=float64) 100
# slice = key, score = 0.0933
# np.mean(results), mse, len(results) =  0.09079450418160095 tf.Tensor(35828.44757008217, shape=(), dtype=float64) 1674
# slice = train, score = 0.09079450418160095
# np.mean(results), mse, len(results) =  0.04906701708278581 tf.Tensor(36561.433783434426, shape=(), dtype=float64) 761
# slice = test, score = 0.04906701708278581
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.0933 tf.Tensor(55521.80064430027, shape=(), dtype=float64) 100
# slice = key, score = 0.0933
# np.mean(results), mse, len(results) =  0.09149342891278377 tf.Tensor(53016.19412489291, shape=(), dtype=float64) 1674
# slice = train, score = 0.09149342891278377
# np.mean(results), mse, len(results) =  0.050525624178712224 tf.Tensor(51586.80184159143, shape=(), dtype=float64) 761
# slice = test, score = 0.050525624178712224
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.0908 tf.Tensor(44390.68247024331, shape=(), dtype=float64) 100
# slice = key, score = 0.0908
# np.mean(results), mse, len(results) =  0.09048984468339308 tf.Tensor(41763.78777529736, shape=(), dtype=float64) 1674
# slice = train, score = 0.09048984468339308
# np.mean(results), mse, len(results) =  0.04804204993429698 tf.Tensor(39525.08317809949, shape=(), dtype=float64) 761
# slice = test, score = 0.04804204993429698
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.09050000000000001 tf.Tensor(42342.77170132504, shape=(), dtype=float64) 100
# slice = key, score = 0.09050000000000001
# np.mean(results), mse, len(results) =  0.09105137395459977 tf.Tensor(40565.17114641097, shape=(), dtype=float64) 1674
# slice = train, score = 0.09105137395459977
# np.mean(results), mse, len(results) =  0.049211563731931675 tf.Tensor(38631.56872754569, shape=(), dtype=float64) 761
# slice = test, score = 0.049211563731931675
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.09910000000000001 tf.Tensor(58492.985634579316, shape=(), dtype=float64) 100
# slice = key, score = 0.09910000000000001
# np.mean(results), mse, len(results) =  0.093805256869773 tf.Tensor(56484.975843933724, shape=(), dtype=float64) 1674
# slice = train, score = 0.093805256869773
# np.mean(results), mse, len(results) =  0.05161629434954008 tf.Tensor(54230.6166821646, shape=(), dtype=float64) 761
# slice = test, score = 0.05161629434954008
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.09449999999999999 tf.Tensor(59075.47274929765, shape=(), dtype=float64) 100
# slice = key, score = 0.09449999999999999
# np.mean(results), mse, len(results) =  0.09375746714456393 tf.Tensor(55250.33478169995, shape=(), dtype=float64) 1674
# slice = train, score = 0.09375746714456393
# np.mean(results), mse, len(results) =  0.0511563731931669 tf.Tensor(51789.50478834623, shape=(), dtype=float64) 761
# slice = test, score = 0.0511563731931669
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.0959 tf.Tensor(74620.59158864703, shape=(), dtype=float64) 100
# slice = key, score = 0.0959
# np.mean(results), mse, len(results) =  0.09363201911589009 tf.Tensor(69685.6885002655, shape=(), dtype=float64) 1674
# slice = train, score = 0.09363201911589009
# np.mean(results), mse, len(results) =  0.04914586070959265 tf.Tensor(65841.24712132297, shape=(), dtype=float64) 761
# slice = test, score = 0.04914586070959265
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.09729999999999998 tf.Tensor(63547.32395892906, shape=(), dtype=float64) 100
# slice = key, score = 0.09729999999999998
# np.mean(results), mse, len(results) =  0.09586021505376344 tf.Tensor(61247.5354949806, shape=(), dtype=float64) 1674
# slice = train, score = 0.09586021505376344
# np.mean(results), mse, len(results) =  0.05216819973718791 tf.Tensor(57701.28723777796, shape=(), dtype=float64) 761
# slice = test, score = 0.05216819973718791
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.09910000000000001 tf.Tensor(111837.19504772694, shape=(), dtype=float64) 100
# slice = key, score = 0.09910000000000001
# np.mean(results), mse, len(results) =  0.09732377538829153 tf.Tensor(107507.31129980354, shape=(), dtype=float64) 1674
# slice = train, score = 0.09732377538829153
# np.mean(results), mse, len(results) =  0.05296977660972406 tf.Tensor(101346.29937860291, shape=(), dtype=float64) 761
# slice = test, score = 0.05296977660972406
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.09849999999999999 tf.Tensor(93289.60397979795, shape=(), dtype=float64) 100
# slice = key, score = 0.09849999999999999
# np.mean(results), mse, len(results) =  0.09541218637992832 tf.Tensor(92256.97504955066, shape=(), dtype=float64) 1674
# slice = train, score = 0.09541218637992832
# np.mean(results), mse, len(results) =  0.050249671484888306 tf.Tensor(89336.52972053621, shape=(), dtype=float64) 761
# slice = test, score = 0.050249671484888306
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.09759999999999999 tf.Tensor(87256.2455831317, shape=(), dtype=float64) 100
# slice = key, score = 0.09759999999999999
# np.mean(results), mse, len(results) =  0.09430704898446834 tf.Tensor(87105.47332931623, shape=(), dtype=float64) 1674
# slice = train, score = 0.09430704898446834
# np.mean(results), mse, len(results) =  0.048449408672798955 tf.Tensor(85642.11526419866, shape=(), dtype=float64) 761
# slice = test, score = 0.048449408672798955
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.10159999999999998 tf.Tensor(88738.56256714684, shape=(), dtype=float64) 100
# slice = key, score = 0.10159999999999998
# np.mean(results), mse, len(results) =  0.09683990442054959 tf.Tensor(84760.63052516681, shape=(), dtype=float64) 1674
# slice = train, score = 0.09683990442054959
# np.mean(results), mse, len(results) =  0.05002628120893562 tf.Tensor(81118.73819129614, shape=(), dtype=float64) 761
# slice = test, score = 0.05002628120893562
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.09989999999999999 tf.Tensor(110993.77334351407, shape=(), dtype=float64) 100
# slice = key, score = 0.09989999999999999
# np.mean(results), mse, len(results) =  0.09949820788530465 tf.Tensor(111795.45822227633, shape=(), dtype=float64) 1674
# slice = train, score = 0.09949820788530465
# np.mean(results), mse, len(results) =  0.053534822601839685 tf.Tensor(108007.6030243204, shape=(), dtype=float64) 761
# slice = test, score = 0.053534822601839685
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.10360000000000001 tf.Tensor(113877.40954720351, shape=(), dtype=float64) 100
# slice = key, score = 0.10360000000000001
# np.mean(results), mse, len(results) =  0.100442054958184 tf.Tensor(111984.30202792109, shape=(), dtype=float64) 1674
# slice = train, score = 0.100442054958184
# np.mean(results), mse, len(results) =  0.05528252299605783 tf.Tensor(110508.6238893252, shape=(), dtype=float64) 761
# slice = test, score = 0.05528252299605783
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.10129999999999999 tf.Tensor(122997.01059502714, shape=(), dtype=float64) 100
# slice = key, score = 0.10129999999999999
# np.mean(results), mse, len(results) =  0.0971326164874552 tf.Tensor(122060.36876858881, shape=(), dtype=float64) 1674
# slice = train, score = 0.0971326164874552
# np.mean(results), mse, len(results) =  0.054862023653088045 tf.Tensor(121508.27751922155, shape=(), dtype=float64) 761
# slice = test, score = 0.054862023653088045
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.10439999999999999 tf.Tensor(153941.85186411082, shape=(), dtype=float64) 100
# slice = key, score = 0.10439999999999999
# np.mean(results), mse, len(results) =  0.10044205495818398 tf.Tensor(147133.3040828085, shape=(), dtype=float64) 1674
# slice = train, score = 0.10044205495818398
# np.mean(results), mse, len(results) =  0.052444152431011824 tf.Tensor(137642.03304874146, shape=(), dtype=float64) 761
# slice = test, score = 0.052444152431011824
# 2024-09-13 14:33:45,107	WARNING	HTTP POST request http://hahn.yt.yandex.net/api/v3/ping_tx has failed with error <class 'yt.packages.requests.exceptions.ConnectionError'>, message: '('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))', headers: {'User-Agent': 'Python wrapper 0.8.38', 'Accept-Encoding': 'gzip, identity', 'X-Started-By': b'{"pid"=108813;"user"="shevkunov";}', 'X-YT-Header-Format': '<format=text>yson', 'Content-Type': 'application/x-yt-yson-text', 'X-YT-Correlation-Id': '985696a4-891ce827-b63be98c-e3018829'}
# 2024-09-13 14:33:45,108	WARNING	Sleep for 4.98 seconds before next retry
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.10529999999999998 tf.Tensor(159365.58109686378, shape=(), dtype=float64) 100
# slice = key, score = 0.10529999999999998
# np.mean(results), mse, len(results) =  0.09992234169653526 tf.Tensor(161150.83169808582, shape=(), dtype=float64) 1674
# slice = train, score = 0.09992234169653526
# np.mean(results), mse, len(results) =  0.049526938239159005 tf.Tensor(156236.3980739144, shape=(), dtype=float64) 761
# slice = test, score = 0.049526938239159005
# 2024-09-13 14:33:50,088	WARNING	New retry (2) ...
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.1061 tf.Tensor(155220.87011699803, shape=(), dtype=float64) 100
# slice = key, score = 0.1061
# np.mean(results), mse, len(results) =  0.1009020310633214 tf.Tensor(148045.4950731399, shape=(), dtype=float64) 1674
# slice = train, score = 0.1009020310633214
# np.mean(results), mse, len(results) =  0.05149802890932983 tf.Tensor(141658.9490635973, shape=(), dtype=float64) 761
# slice = test, score = 0.05149802890932983
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.10749999999999998 tf.Tensor(165837.3489107189, shape=(), dtype=float64) 100
# slice = key, score = 0.10749999999999998
# np.mean(results), mse, len(results) =  0.10145758661887697 tf.Tensor(168760.75624347132, shape=(), dtype=float64) 1674
# slice = train, score = 0.10145758661887697
# np.mean(results), mse, len(results) =  0.05300919842312747 tf.Tensor(169304.5202108642, shape=(), dtype=float64) 761
# slice = test, score = 0.05300919842312747
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 30
#       8 N = 100000 #
#       9 d = DssmKnnUGe(ctx, Ge, Ue_, fit_kwargs={
#      10     'c': 0,
#      11     'train_matrix': True,
#    (...)
#      28     "learning_rate": 0.001
#      29 })
# ---> 30 d.fit()
#      31 d.get_score("train"), d.get_score("test")
#
# Cell In[32], line 373, in CBKnnV0.fit(self, **kwargs)
#     369 if self.p["trainable_items"]:
#     370     weights += [self.trainable_games]
# --> 373 opt.minimize(loss, weights)
#     375 if p["score_verbose"] and (i % p["score_verbose"] == 0):
#     376     print(f"\n=== Iteration {i} ===")
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/optimizers/optimizer.py:542, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     521 def minimize(self, loss, var_list, tape=None):
#     522     """Minimize `loss` by updating `var_list`.
#     523
#     524     This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     540       None
#     541     """
# --> 542     grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     543     self.apply_gradients(grads_and_vars)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/optimizers/optimizer.py:271, in _BaseOptimizer.compute_gradients(self, loss, var_list, tape)
#     269 if not callable(var_list):
#     270     tape.watch(var_list)
# --> 271 loss = loss()
#     272 if callable(var_list):
#     273     var_list = var_list()
#
# Cell In[32], line 296, in CBKnnV0.fit.<locals>.loss()
#     290     v = -tf.reduce_mean(tf.where(
#     291         (scores.T >= qs.T).T,
#     292         tf.nn.softmax(logits, axis=1),
#     293         0
#     294     ))
#     295 elif self.loss == "softmax_signed":
# --> 296     logits, scores = get_logits_scores(
#     297         loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
#     299     qs = np.quantile(scores, p["loss_q"], axis=1)
#     300     sf = tf.nn.softmax(logits, axis=1)
#
# Cell In[32], line 242, in CBKnnV0.fit.<locals>.loss.<locals>.get_logits_scores(loss_batch)
#     239     logits += train_user_embs_ @ self.W @ tf.transpose(game_embs_)
#     241 if self.train_dssm:
# --> 242     logits += self.u_dssm(train_user_embs_) @ tf.transpose(self.g_dssm(game_embs_))
#     244 if self.train_popbias:
#     245     if loss_batch >= game_embs.shape[0]:
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/engine/training.py:558, in Model.__call__(self, *args, **kwargs)
#     554         super().__call__(inputs, *copied_args, **copied_kwargs)
#     556     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 558 return super().__call__(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/engine/sequential.py:412, in Sequential.call(self, inputs, training, mask)
#     410     if not self.built:
#     411         self._init_graph_network(self.inputs, self.outputs)
# --> 412     return super().call(inputs, training=training, mask=mask)
#     414 outputs = inputs  # handle the corner case where self.layers is empty
#     415 for layer in self.layers:
#     416     # During each iteration, `inputs` are the inputs to `layer`, and
#     417     # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     418     # end of each iteration `inputs` is set to `outputs` to prepare for
#     419     # the next layer.
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/engine/functional.py:512, in Functional.call(self, inputs, training, mask)
#     493 @doc_controls.do_not_doc_inheritable
#     494 def call(self, inputs, training=None, mask=None):
#     495     """Calls the model on new inputs.
#     496
#     497     In this case `call` just reapplies
#    (...)
#     510         a list of tensors if there are more than one outputs.
#     511     """
# --> 512     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/engine/functional.py:669, in Functional._run_internal_graph(self, inputs, training, mask)
#     666     continue  # Node is not computable, try skipping.
#     668 args, kwargs = node.map_arguments(tensor_dict)
# --> 669 outputs = node.layer(*args, **kwargs)
#     671 # Update tensor_dict.
#     672 for x_id, y in zip(
#     673     node.flat_output_ids, tf.nest.flatten(outputs)
#     674 ):
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/layers/core/dense.py:241, in Dense.call(self, inputs)
#     237         outputs = tf.nn.embedding_lookup_sparse(
#     238             self.kernel, ids, weights, combiner="sum"
#     239         )
#     240     else:
# --> 241         outputs = tf.matmul(a=inputs, b=self.kernel)
#     242 # Broadcast kernel to inputs.
#     243 else:
#     244     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:140, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     138 def error_handler(*args, **kwargs):
#     139   try:
# --> 140     if not is_traceback_filtering_enabled():
#     141       return fn(*args, **kwargs)
#     142   except NameError:
#     143     # In some very rare cases,
#     144     # `is_traceback_filtering_enabled` (from the outer scope) may not be
#     145     # accessible from inside this function
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:32, in is_traceback_filtering_enabled()
#      26 _ENABLE_TRACEBACK_FILTERING = threading.local()
#      27 _EXCLUDED_PATHS = (
#      28     os.path.abspath(os.path.join(__file__, '..', '..')),
#      29 )
# ---> 32 @tf_export('debugging.is_traceback_filtering_enabled')
#      33 def is_traceback_filtering_enabled():
#      34   """Check whether traceback filtering is currently enabled.
#      35
#      36   See also `tf.debugging.enable_traceback_filtering()` and
#    (...)
#      45     was called).
#      46   """
#      47   value = getattr(_ENABLE_TRACEBACK_FILTERING, 'value', True)
#
# KeyboardInterrupt:

# %%
select_head = 0
Ue_ = {
    "key": Ue[:ctx.key_size][:, select_head*256:(select_head + 1) * 256],
    "train": Ue[ctx.key_size + 1: ctx.train_split][:, select_head*256:(select_head + 1) * 256],
    "test": Ue[ctx.train_split:][:, select_head*256:(select_head + 1) * 256], 
}

N = 100000 #
d = DssmKnnUGe(ctx, Ge, Ue_, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.0001
})
d.fit()
d.get_score("train"), d.get_score("test")
# Out:
# self.embed_users['train'].shape =  (1674, 100)
# self.embed_games.shape =  (8127, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8127)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (1674, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.08739999999999998 tf.Tensor(2.7711234146303028, shape=(), dtype=float64) 100
# slice = key, score = 0.08739999999999998
# np.mean(results), mse, len(results) =  0.07157706093189965 tf.Tensor(2.9371004253020923, shape=(), dtype=float64) 1674
# slice = train, score = 0.07157706093189965
# np.mean(results), mse, len(results) =  0.06254927726675429 tf.Tensor(2.8955841717445443, shape=(), dtype=float64) 761
# slice = test, score = 0.06254927726675429
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.0179 tf.Tensor(440.90273014933746, shape=(), dtype=float64) 100
# slice = key, score = 0.0179
# np.mean(results), mse, len(results) =  0.015065710872162484 tf.Tensor(451.1798434975142, shape=(), dtype=float64) 1674
# slice = train, score = 0.015065710872162484
# np.mean(results), mse, len(results) =  0.014954007884362679 tf.Tensor(448.20159242182245, shape=(), dtype=float64) 761
# slice = test, score = 0.014954007884362679
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.0227 tf.Tensor(708.9788805389153, shape=(), dtype=float64) 100
# slice = key, score = 0.0227
# np.mean(results), mse, len(results) =  0.01759856630824373 tf.Tensor(726.3075659759576, shape=(), dtype=float64) 1674
# slice = train, score = 0.01759856630824373
# np.mean(results), mse, len(results) =  0.017266754270696454 tf.Tensor(723.6119494807812, shape=(), dtype=float64) 761
# slice = test, score = 0.017266754270696454
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.023299999999999998 tf.Tensor(738.5306524704288, shape=(), dtype=float64) 100
# slice = key, score = 0.023299999999999998
# np.mean(results), mse, len(results) =  0.017532855436081244 tf.Tensor(755.9559770053871, shape=(), dtype=float64) 1674
# slice = train, score = 0.017532855436081244
# np.mean(results), mse, len(results) =  0.016727989487516425 tf.Tensor(753.1572097974758, shape=(), dtype=float64) 761
# slice = test, score = 0.016727989487516425
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.023000000000000003 tf.Tensor(1177.068666448118, shape=(), dtype=float64) 100
# slice = key, score = 0.023000000000000003
# np.mean(results), mse, len(results) =  0.018076463560334526 tf.Tensor(1202.4205300473232, shape=(), dtype=float64) 1674
# slice = train, score = 0.018076463560334526
# np.mean(results), mse, len(results) =  0.01721419185282523 tf.Tensor(1199.7033432962971, shape=(), dtype=float64) 761
# slice = test, score = 0.01721419185282523
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.023299999999999998 tf.Tensor(996.3710098613111, shape=(), dtype=float64) 100
# slice = key, score = 0.023299999999999998
# np.mean(results), mse, len(results) =  0.017813620071684588 tf.Tensor(1028.217080340704, shape=(), dtype=float64) 1674
# slice = train, score = 0.017813620071684588
# np.mean(results), mse, len(results) =  0.01730617608409987 tf.Tensor(1030.3108012430223, shape=(), dtype=float64) 761
# slice = test, score = 0.01730617608409987
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.0231 tf.Tensor(540.8764148363405, shape=(), dtype=float64) 100
# slice = key, score = 0.0231
# np.mean(results), mse, len(results) =  0.01824372759856631 tf.Tensor(588.671594580361, shape=(), dtype=float64) 1674
# slice = train, score = 0.01824372759856631
# np.mean(results), mse, len(results) =  0.016911957950065705 tf.Tensor(602.9483348723713, shape=(), dtype=float64) 761
# slice = test, score = 0.016911957950065705
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.0197 tf.Tensor(323.5288283877805, shape=(), dtype=float64) 100
# slice = key, score = 0.0197
# np.mean(results), mse, len(results) =  0.018727598566308245 tf.Tensor(369.61706426866795, shape=(), dtype=float64) 1674
# slice = train, score = 0.018727598566308245
# np.mean(results), mse, len(results) =  0.01578186596583443 tf.Tensor(389.4256385856559, shape=(), dtype=float64) 761
# slice = test, score = 0.01578186596583443
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.0174 tf.Tensor(323.82369973328366, shape=(), dtype=float64) 100
# slice = key, score = 0.0174
# np.mean(results), mse, len(results) =  0.01996415770609319 tf.Tensor(367.31497515968033, shape=(), dtype=float64) 1674
# slice = train, score = 0.01996415770609319
# np.mean(results), mse, len(results) =  0.01533508541392904 tf.Tensor(386.9671403478956, shape=(), dtype=float64) 761
# slice = test, score = 0.01533508541392904
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.0174 tf.Tensor(296.05437139065276, shape=(), dtype=float64) 100
# slice = key, score = 0.0174
# np.mean(results), mse, len(results) =  0.02215651135005974 tf.Tensor(343.5549073981768, shape=(), dtype=float64) 1674
# slice = train, score = 0.02215651135005974
# np.mean(results), mse, len(results) =  0.016938239159001316 tf.Tensor(365.45712946800205, shape=(), dtype=float64) 761
# slice = test, score = 0.016938239159001316
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.021499999999999995 tf.Tensor(304.31647185631994, shape=(), dtype=float64) 100
# slice = key, score = 0.021499999999999995
# np.mean(results), mse, len(results) =  0.023524492234169653 tf.Tensor(360.2575811623436, shape=(), dtype=float64) 1674
# slice = train, score = 0.023524492234169653
# np.mean(results), mse, len(results) =  0.017253613666228646 tf.Tensor(386.3599211699583, shape=(), dtype=float64) 761
# slice = test, score = 0.017253613666228646
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.021499999999999995 tf.Tensor(295.7948326777889, shape=(), dtype=float64) 100
# slice = key, score = 0.021499999999999995
# np.mean(results), mse, len(results) =  0.025824372759856634 tf.Tensor(349.47978485653107, shape=(), dtype=float64) 1674
# slice = train, score = 0.025824372759856634
# np.mean(results), mse, len(results) =  0.01938239159001314 tf.Tensor(374.38976211905646, shape=(), dtype=float64) 761
# slice = test, score = 0.01938239159001314
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.024 tf.Tensor(330.3358114250633, shape=(), dtype=float64) 100
# slice = key, score = 0.024
# np.mean(results), mse, len(results) =  0.028178016726403823 tf.Tensor(366.29669869764865, shape=(), dtype=float64) 1674
# slice = train, score = 0.028178016726403823
# np.mean(results), mse, len(results) =  0.020538764783180025 tf.Tensor(387.79067064051344, shape=(), dtype=float64) 761
# slice = test, score = 0.020538764783180025
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.024699999999999996 tf.Tensor(342.5565794517627, shape=(), dtype=float64) 100
# slice = key, score = 0.024699999999999996
# np.mean(results), mse, len(results) =  0.03183393070489845 tf.Tensor(351.9516437284722, shape=(), dtype=float64) 1674
# slice = train, score = 0.03183393070489845
# np.mean(results), mse, len(results) =  0.023206307490144552 tf.Tensor(364.1865416611343, shape=(), dtype=float64) 761
# slice = test, score = 0.023206307490144552
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.023899999999999998 tf.Tensor(351.60364262093736, shape=(), dtype=float64) 100
# slice = key, score = 0.023899999999999998
# np.mean(results), mse, len(results) =  0.03483870967741936 tf.Tensor(336.00464266682513, shape=(), dtype=float64) 1674
# slice = train, score = 0.03483870967741936
# np.mean(results), mse, len(results) =  0.02545335085413929 tf.Tensor(341.5104697047411, shape=(), dtype=float64) 761
# slice = test, score = 0.02545335085413929
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.024399999999999995 tf.Tensor(382.35157785881785, shape=(), dtype=float64) 100
# slice = key, score = 0.024399999999999995
# np.mean(results), mse, len(results) =  0.03642771804062127 tf.Tensor(339.46662621638336, shape=(), dtype=float64) 1674
# slice = train, score = 0.03642771804062127
# np.mean(results), mse, len(results) =  0.025729303547963208 tf.Tensor(336.7694190930229, shape=(), dtype=float64) 761
# slice = test, score = 0.025729303547963208
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.024599999999999997 tf.Tensor(375.6293447403159, shape=(), dtype=float64) 100
# slice = key, score = 0.024599999999999997
# np.mean(results), mse, len(results) =  0.03881720430107527 tf.Tensor(328.8198299959288, shape=(), dtype=float64) 1674
# slice = train, score = 0.03881720430107527
# np.mean(results), mse, len(results) =  0.027818659658344284 tf.Tensor(325.08512878785746, shape=(), dtype=float64) 761
# slice = test, score = 0.027818659658344284
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.0249 tf.Tensor(420.95018010101836, shape=(), dtype=float64) 100
# slice = key, score = 0.0249
# np.mean(results), mse, len(results) =  0.03966547192353644 tf.Tensor(342.7841168589239, shape=(), dtype=float64) 1674
# slice = train, score = 0.03966547192353644
# np.mean(results), mse, len(results) =  0.028002628120893564 tf.Tensor(326.1525122182831, shape=(), dtype=float64) 761
# slice = test, score = 0.028002628120893564
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.024699999999999996 tf.Tensor(483.04902295813423, shape=(), dtype=float64) 100
# slice = key, score = 0.024699999999999996
# np.mean(results), mse, len(results) =  0.04110513739545998 tf.Tensor(373.9262741343465, shape=(), dtype=float64) 1674
# slice = train, score = 0.04110513739545998
# np.mean(results), mse, len(results) =  0.028501971090670177 tf.Tensor(350.2199601847504, shape=(), dtype=float64) 761
# slice = test, score = 0.028501971090670177
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.0256 tf.Tensor(446.8370580110439, shape=(), dtype=float64) 100
# slice = key, score = 0.0256
# np.mean(results), mse, len(results) =  0.042120669056152936 tf.Tensor(344.1361701338357, shape=(), dtype=float64) 1674
# slice = train, score = 0.042120669056152936
# np.mean(results), mse, len(results) =  0.02956636005256242 tf.Tensor(321.3953629250928, shape=(), dtype=float64) 761
# slice = test, score = 0.02956636005256242
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.0272 tf.Tensor(554.3752949581836, shape=(), dtype=float64) 100
# slice = key, score = 0.0272
# np.mean(results), mse, len(results) =  0.043405017921146954 tf.Tensor(410.63471811865173, shape=(), dtype=float64) 1674
# slice = train, score = 0.043405017921146954
# np.mean(results), mse, len(results) =  0.030420499342969774 tf.Tensor(374.21775569180295, shape=(), dtype=float64) 761
# slice = test, score = 0.030420499342969774
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.0265 tf.Tensor(518.3989569874938, shape=(), dtype=float64) 100
# slice = key, score = 0.0265
# np.mean(results), mse, len(results) =  0.04410394265232976 tf.Tensor(388.9320515891064, shape=(), dtype=float64) 1674
# slice = train, score = 0.04410394265232976
# np.mean(results), mse, len(results) =  0.029671484888304865 tf.Tensor(360.8344244598386, shape=(), dtype=float64) 761
# slice = test, score = 0.029671484888304865
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.028900000000000002 tf.Tensor(587.0655666500535, shape=(), dtype=float64) 100
# slice = key, score = 0.028900000000000002
# np.mean(results), mse, len(results) =  0.045274790919952214 tf.Tensor(435.92420049599576, shape=(), dtype=float64) 1674
# slice = train, score = 0.045274790919952214
# np.mean(results), mse, len(results) =  0.03015768725361367 tf.Tensor(402.04498976763216, shape=(), dtype=float64) 761
# slice = test, score = 0.03015768725361367
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.03270000000000001 tf.Tensor(578.1839089481987, shape=(), dtype=float64) 100
# slice = key, score = 0.03270000000000001
# np.mean(results), mse, len(results) =  0.04733572281959379 tf.Tensor(434.7180277952524, shape=(), dtype=float64) 1674
# slice = train, score = 0.04733572281959379
# np.mean(results), mse, len(results) =  0.032601839684625496 tf.Tensor(396.28719624099665, shape=(), dtype=float64) 761
# slice = test, score = 0.032601839684625496
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.0363 tf.Tensor(628.1184068667892, shape=(), dtype=float64) 100
# slice = key, score = 0.0363
# np.mean(results), mse, len(results) =  0.04902031063321386 tf.Tensor(461.1479338655779, shape=(), dtype=float64) 1674
# slice = train, score = 0.04902031063321386
# np.mean(results), mse, len(results) =  0.033442838370565046 tf.Tensor(416.2070371619081, shape=(), dtype=float64) 761
# slice = test, score = 0.033442838370565046
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.0378 tf.Tensor(606.2497177197819, shape=(), dtype=float64) 100
# slice = key, score = 0.0378
# np.mean(results), mse, len(results) =  0.0503405017921147 tf.Tensor(448.352976047485, shape=(), dtype=float64) 1674
# slice = train, score = 0.0503405017921147
# np.mean(results), mse, len(results) =  0.03388961892247044 tf.Tensor(408.78813125955315, shape=(), dtype=float64) 761
# slice = test, score = 0.03388961892247044
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.0412 tf.Tensor(582.4139142672333, shape=(), dtype=float64) 100
# slice = key, score = 0.0412
# np.mean(results), mse, len(results) =  0.05244324970131422 tf.Tensor(436.8708393973599, shape=(), dtype=float64) 1674
# slice = train, score = 0.05244324970131422
# np.mean(results), mse, len(results) =  0.03416557161629435 tf.Tensor(401.2057496569228, shape=(), dtype=float64) 761
# slice = test, score = 0.03416557161629435
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.0416 tf.Tensor(702.7738072810043, shape=(), dtype=float64) 100
# slice = key, score = 0.0416
# np.mean(results), mse, len(results) =  0.05266427718040622 tf.Tensor(526.7231933416567, shape=(), dtype=float64) 1674
# slice = train, score = 0.05266427718040622
# np.mean(results), mse, len(results) =  0.033718791064388964 tf.Tensor(479.75796855898693, shape=(), dtype=float64) 761
# slice = test, score = 0.033718791064388964
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.045799999999999993 tf.Tensor(856.7385906545347, shape=(), dtype=float64) 100
# slice = key, score = 0.045799999999999993
# np.mean(results), mse, len(results) =  0.054259259259259264 tf.Tensor(647.9975311341954, shape=(), dtype=float64) 1674
# slice = train, score = 0.054259259259259264
# np.mean(results), mse, len(results) =  0.03465177398160316 tf.Tensor(587.244222674865, shape=(), dtype=float64) 761
# slice = test, score = 0.03465177398160316
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.047 tf.Tensor(796.3012304543903, shape=(), dtype=float64) 100
# slice = key, score = 0.047
# np.mean(results), mse, len(results) =  0.05514336917562724 tf.Tensor(609.4560621322707, shape=(), dtype=float64) 1674
# slice = train, score = 0.05514336917562724
# np.mean(results), mse, len(results) =  0.03453350854139291 tf.Tensor(555.677324466481, shape=(), dtype=float64) 761
# slice = test, score = 0.03453350854139291
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.0475 tf.Tensor(849.5866967677941, shape=(), dtype=float64) 100
# slice = key, score = 0.0475
# np.mean(results), mse, len(results) =  0.05626642771804063 tf.Tensor(653.543527330138, shape=(), dtype=float64) 1674
# slice = train, score = 0.05626642771804063
# np.mean(results), mse, len(results) =  0.03486202365308804 tf.Tensor(602.1248097012704, shape=(), dtype=float64) 761
# slice = test, score = 0.03486202365308804
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.050300000000000004 tf.Tensor(943.8987031036265, shape=(), dtype=float64) 100
# slice = key, score = 0.050300000000000004
# np.mean(results), mse, len(results) =  0.05792712066905615 tf.Tensor(725.6344440268941, shape=(), dtype=float64) 1674
# slice = train, score = 0.05792712066905615
# np.mean(results), mse, len(results) =  0.03685939553219448 tf.Tensor(662.7655865031672, shape=(), dtype=float64) 761
# slice = test, score = 0.03685939553219448
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.04870000000000001 tf.Tensor(1078.8206736234285, shape=(), dtype=float64) 100
# slice = key, score = 0.04870000000000001
# np.mean(results), mse, len(results) =  0.058327359617682206 tf.Tensor(824.5837769182225, shape=(), dtype=float64) 1674
# slice = train, score = 0.058327359617682206
# np.mean(results), mse, len(results) =  0.03658344283837057 tf.Tensor(746.5193146910576, shape=(), dtype=float64) 761
# slice = test, score = 0.03658344283837057
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.05050000000000001 tf.Tensor(895.0169856445979, shape=(), dtype=float64) 100
# slice = key, score = 0.05050000000000001
# np.mean(results), mse, len(results) =  0.06016726403823179 tf.Tensor(687.7870351488808, shape=(), dtype=float64) 1674
# slice = train, score = 0.06016726403823179
# np.mean(results), mse, len(results) =  0.037818659658344286 tf.Tensor(632.455375928921, shape=(), dtype=float64) 761
# slice = test, score = 0.037818659658344286
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.05200000000000001 tf.Tensor(1044.2197380141013, shape=(), dtype=float64) 100
# slice = key, score = 0.05200000000000001
# np.mean(results), mse, len(results) =  0.06222819593787337 tf.Tensor(769.1828356025906, shape=(), dtype=float64) 1674
# slice = train, score = 0.06222819593787337
# np.mean(results), mse, len(results) =  0.03996057818659659 tf.Tensor(693.8725736700791, shape=(), dtype=float64) 761
# slice = test, score = 0.03996057818659659
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.052600000000000015 tf.Tensor(1149.2195462733919, shape=(), dtype=float64) 100
# slice = key, score = 0.052600000000000015
# np.mean(results), mse, len(results) =  0.06274193548387098 tf.Tensor(844.9010362900535, shape=(), dtype=float64) 1674
# slice = train, score = 0.06274193548387098
# np.mean(results), mse, len(results) =  0.03914586070959264 tf.Tensor(760.7342651536102, shape=(), dtype=float64) 761
# slice = test, score = 0.03914586070959264
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.053500000000000006 tf.Tensor(1102.3451100897248, shape=(), dtype=float64) 100
# slice = key, score = 0.053500000000000006
# np.mean(results), mse, len(results) =  0.0636021505376344 tf.Tensor(813.3737884160547, shape=(), dtype=float64) 1674
# slice = train, score = 0.0636021505376344
# np.mean(results), mse, len(results) =  0.039250985545335085 tf.Tensor(746.0710671951397, shape=(), dtype=float64) 761
# slice = test, score = 0.039250985545335085
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.0537 tf.Tensor(1190.39821557993, shape=(), dtype=float64) 100
# slice = key, score = 0.0537
# np.mean(results), mse, len(results) =  0.06447431302270012 tf.Tensor(875.1237297456793, shape=(), dtype=float64) 1674
# slice = train, score = 0.06447431302270012
# np.mean(results), mse, len(results) =  0.03919842312746386 tf.Tensor(806.5264710837095, shape=(), dtype=float64) 761
# slice = test, score = 0.03919842312746386
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.05380000000000001 tf.Tensor(1297.6441948766146, shape=(), dtype=float64) 100
# slice = key, score = 0.05380000000000001
# np.mean(results), mse, len(results) =  0.064778972520908 tf.Tensor(952.7406219625544, shape=(), dtype=float64) 1674
# slice = train, score = 0.064778972520908
# np.mean(results), mse, len(results) =  0.03896189224704337 tf.Tensor(876.486770836373, shape=(), dtype=float64) 761
# slice = test, score = 0.03896189224704337
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.05489999999999999 tf.Tensor(1355.283798385867, shape=(), dtype=float64) 100
# slice = key, score = 0.05489999999999999
# np.mean(results), mse, len(results) =  0.06575268817204301 tf.Tensor(995.9880964099984, shape=(), dtype=float64) 1674
# slice = train, score = 0.06575268817204301
# np.mean(results), mse, len(results) =  0.04028909329829173 tf.Tensor(910.653652049301, shape=(), dtype=float64) 761
# slice = test, score = 0.04028909329829173
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.0558 tf.Tensor(1440.8819835606405, shape=(), dtype=float64) 100
# slice = key, score = 0.0558
# np.mean(results), mse, len(results) =  0.06640979689366787 tf.Tensor(1071.5841093131703, shape=(), dtype=float64) 1674
# slice = train, score = 0.06640979689366787
# np.mean(results), mse, len(results) =  0.04006570302233903 tf.Tensor(983.5687412953486, shape=(), dtype=float64) 761
# slice = test, score = 0.04006570302233903
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.0552 tf.Tensor(1493.47331576419, shape=(), dtype=float64) 100
# slice = key, score = 0.0552
# np.mean(results), mse, len(results) =  0.06698924731182797 tf.Tensor(1118.5376322658876, shape=(), dtype=float64) 1674
# slice = train, score = 0.06698924731182797
# np.mean(results), mse, len(results) =  0.039053876478318005 tf.Tensor(1035.275820584494, shape=(), dtype=float64) 761
# slice = test, score = 0.039053876478318005
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.0567 tf.Tensor(1540.4975790279993, shape=(), dtype=float64) 100
# slice = key, score = 0.0567
# np.mean(results), mse, len(results) =  0.06805256869772999 tf.Tensor(1168.931505988331, shape=(), dtype=float64) 1674
# slice = train, score = 0.06805256869772999
# np.mean(results), mse, len(results) =  0.03965834428383706 tf.Tensor(1091.7624708743442, shape=(), dtype=float64) 761
# slice = test, score = 0.03965834428383706
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.0581 tf.Tensor(1711.5703792133495, shape=(), dtype=float64) 100
# slice = key, score = 0.0581
# np.mean(results), mse, len(results) =  0.06907407407407407 tf.Tensor(1325.9476520804571, shape=(), dtype=float64) 1674
# slice = train, score = 0.06907407407407407
# np.mean(results), mse, len(results) =  0.041235216819973726 tf.Tensor(1234.0484607502847, shape=(), dtype=float64) 761
# slice = test, score = 0.041235216819973726
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.05800000000000001 tf.Tensor(1516.280124160906, shape=(), dtype=float64) 100
# slice = key, score = 0.05800000000000001
# np.mean(results), mse, len(results) =  0.0697610513739546 tf.Tensor(1186.5998005968747, shape=(), dtype=float64) 1674
# slice = train, score = 0.0697610513739546
# np.mean(results), mse, len(results) =  0.040670170827858086 tf.Tensor(1117.7180019320779, shape=(), dtype=float64) 761
# slice = test, score = 0.040670170827858086
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.0591 tf.Tensor(1645.745713194578, shape=(), dtype=float64) 100
# slice = key, score = 0.0591
# np.mean(results), mse, len(results) =  0.07088410991636798 tf.Tensor(1320.6414888559966, shape=(), dtype=float64) 1674
# slice = train, score = 0.07088410991636798
# np.mean(results), mse, len(results) =  0.04126149802890933 tf.Tensor(1248.7476265234304, shape=(), dtype=float64) 761
# slice = test, score = 0.04126149802890933
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.059300000000000005 tf.Tensor(1554.1737835066915, shape=(), dtype=float64) 100
# slice = key, score = 0.059300000000000005
# np.mean(results), mse, len(results) =  0.07166069295101553 tf.Tensor(1252.6586158458035, shape=(), dtype=float64) 1674
# slice = train, score = 0.07166069295101553
# np.mean(results), mse, len(results) =  0.04229960578186597 tf.Tensor(1177.9285256537278, shape=(), dtype=float64) 761
# slice = test, score = 0.04229960578186597
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.06 tf.Tensor(1473.690627187049, shape=(), dtype=float64) 100
# slice = key, score = 0.06
# np.mean(results), mse, len(results) =  0.07190561529271207 tf.Tensor(1228.7882454389646, shape=(), dtype=float64) 1674
# slice = train, score = 0.07190561529271207
# np.mean(results), mse, len(results) =  0.04169513797634691 tf.Tensor(1179.4206872234163, shape=(), dtype=float64) 761
# slice = test, score = 0.04169513797634691
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.0627 tf.Tensor(1568.941185586654, shape=(), dtype=float64) 100
# slice = key, score = 0.0627
# np.mean(results), mse, len(results) =  0.07203703703703704 tf.Tensor(1283.300151978058, shape=(), dtype=float64) 1674
# slice = train, score = 0.07203703703703704
# np.mean(results), mse, len(results) =  0.040670170827858086 tf.Tensor(1224.6028514802683, shape=(), dtype=float64) 761
# slice = test, score = 0.040670170827858086
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.0625 tf.Tensor(1668.0421647818966, shape=(), dtype=float64) 100
# slice = key, score = 0.0625
# np.mean(results), mse, len(results) =  0.07359617682198327 tf.Tensor(1390.506215108392, shape=(), dtype=float64) 1674
# slice = train, score = 0.07359617682198327
# np.mean(results), mse, len(results) =  0.04294349540078844 tf.Tensor(1327.8686828995017, shape=(), dtype=float64) 761
# slice = test, score = 0.04294349540078844
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.06330000000000001 tf.Tensor(1696.5613675596346, shape=(), dtype=float64) 100
# slice = key, score = 0.06330000000000001
# np.mean(results), mse, len(results) =  0.07336320191158902 tf.Tensor(1420.1154464624988, shape=(), dtype=float64) 1674
# slice = train, score = 0.07336320191158902
# np.mean(results), mse, len(results) =  0.04063074901445467 tf.Tensor(1353.4844606107654, shape=(), dtype=float64) 761
# slice = test, score = 0.04063074901445467
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.064 tf.Tensor(1596.5069935472172, shape=(), dtype=float64) 100
# slice = key, score = 0.064
# np.mean(results), mse, len(results) =  0.07366786140979689 tf.Tensor(1375.3892667529547, shape=(), dtype=float64) 1674
# slice = train, score = 0.07366786140979689
# np.mean(results), mse, len(results) =  0.04169513797634692 tf.Tensor(1336.9619283003815, shape=(), dtype=float64) 761
# slice = test, score = 0.04169513797634692
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.0648 tf.Tensor(1687.2614781253315, shape=(), dtype=float64) 100
# slice = key, score = 0.0648
# np.mean(results), mse, len(results) =  0.07508363201911589 tf.Tensor(1470.9275280691531, shape=(), dtype=float64) 1674
# slice = train, score = 0.07508363201911589
# np.mean(results), mse, len(results) =  0.042996057818659665 tf.Tensor(1434.3364289971626, shape=(), dtype=float64) 761
# slice = test, score = 0.042996057818659665
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.06539999999999999 tf.Tensor(1746.4694878993596, shape=(), dtype=float64) 100
# slice = key, score = 0.06539999999999999
# np.mean(results), mse, len(results) =  0.07533452807646356 tf.Tensor(1541.6746626725978, shape=(), dtype=float64) 1674
# slice = train, score = 0.07533452807646356
# np.mean(results), mse, len(results) =  0.04374507227332458 tf.Tensor(1504.1891686169072, shape=(), dtype=float64) 761
# slice = test, score = 0.04374507227332458
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.067 tf.Tensor(1944.4751708255287, shape=(), dtype=float64) 100
# slice = key, score = 0.067
# np.mean(results), mse, len(results) =  0.0757825567502987 tf.Tensor(1688.9504420880346, shape=(), dtype=float64) 1674
# slice = train, score = 0.0757825567502987
# np.mean(results), mse, len(results) =  0.04289093298291721 tf.Tensor(1617.6718929957904, shape=(), dtype=float64) 761
# slice = test, score = 0.04289093298291721
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.0681 tf.Tensor(1981.3913676649438, shape=(), dtype=float64) 100
# slice = key, score = 0.0681
# np.mean(results), mse, len(results) =  0.07682795698924733 tf.Tensor(1766.4424209287265, shape=(), dtype=float64) 1674
# slice = train, score = 0.07682795698924733
# np.mean(results), mse, len(results) =  0.04310118265440211 tf.Tensor(1710.523302841592, shape=(), dtype=float64) 761
# slice = test, score = 0.04310118265440211
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.068 tf.Tensor(2007.1895467581985, shape=(), dtype=float64) 100
# slice = key, score = 0.068
# np.mean(results), mse, len(results) =  0.07712066905615292 tf.Tensor(1806.729775579866, shape=(), dtype=float64) 1674
# slice = train, score = 0.07712066905615292
# np.mean(results), mse, len(results) =  0.043955321944809465 tf.Tensor(1762.4103111219238, shape=(), dtype=float64) 761
# slice = test, score = 0.043955321944809465
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.06949999999999999 tf.Tensor(2069.050093902016, shape=(), dtype=float64) 100
# slice = key, score = 0.06949999999999999
# np.mean(results), mse, len(results) =  0.07780764635603345 tf.Tensor(1906.8764617672455, shape=(), dtype=float64) 1674
# slice = train, score = 0.07780764635603345
# np.mean(results), mse, len(results) =  0.04452036793692511 tf.Tensor(1862.0139781153864, shape=(), dtype=float64) 761
# slice = test, score = 0.04452036793692511
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.0696 tf.Tensor(2150.7988813495194, shape=(), dtype=float64) 100
# slice = key, score = 0.0696
# np.mean(results), mse, len(results) =  0.07851851851851852 tf.Tensor(1945.663470844304, shape=(), dtype=float64) 1674
# slice = train, score = 0.07851851851851852
# np.mean(results), mse, len(results) =  0.04501971090670172 tf.Tensor(1882.0041413982553, shape=(), dtype=float64) 761
# slice = test, score = 0.04501971090670172
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.0693 tf.Tensor(2115.5938611484216, shape=(), dtype=float64) 100
# slice = key, score = 0.0693
# np.mean(results), mse, len(results) =  0.07907407407407407 tf.Tensor(1947.348275228815, shape=(), dtype=float64) 1674
# slice = train, score = 0.07907407407407407
# np.mean(results), mse, len(results) =  0.0450065703022339 tf.Tensor(1898.0763040544123, shape=(), dtype=float64) 761
# slice = test, score = 0.0450065703022339
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.0698 tf.Tensor(2380.8104051224554, shape=(), dtype=float64) 100
# slice = key, score = 0.0698
# np.mean(results), mse, len(results) =  0.07924731182795701 tf.Tensor(2190.343514768906, shape=(), dtype=float64) 1674
# slice = train, score = 0.07924731182795701
# np.mean(results), mse, len(results) =  0.043955321944809465 tf.Tensor(2123.099896649672, shape=(), dtype=float64) 761
# slice = test, score = 0.043955321944809465
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.06920000000000001 tf.Tensor(2164.88078285542, shape=(), dtype=float64) 100
# slice = key, score = 0.06920000000000001
# np.mean(results), mse, len(results) =  0.07959976105137395 tf.Tensor(2040.0518932976772, shape=(), dtype=float64) 1674
# slice = train, score = 0.07959976105137395
# np.mean(results), mse, len(results) =  0.04421813403416558 tf.Tensor(2001.45552093965, shape=(), dtype=float64) 761
# slice = test, score = 0.04421813403416558
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.071 tf.Tensor(2337.7389175965295, shape=(), dtype=float64) 100
# slice = key, score = 0.071
# np.mean(results), mse, len(results) =  0.08079450418160096 tf.Tensor(2204.0527439986517, shape=(), dtype=float64) 1674
# slice = train, score = 0.08079450418160096
# np.mean(results), mse, len(results) =  0.04614980289093299 tf.Tensor(2167.2777141255706, shape=(), dtype=float64) 761
# slice = test, score = 0.04614980289093299
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.0709 tf.Tensor(2630.0449050375814, shape=(), dtype=float64) 100
# slice = key, score = 0.0709
# np.mean(results), mse, len(results) =  0.08066308243727599 tf.Tensor(2426.507517532702, shape=(), dtype=float64) 1674
# slice = train, score = 0.08066308243727599
# np.mean(results), mse, len(results) =  0.04501971090670172 tf.Tensor(2335.1689960649887, shape=(), dtype=float64) 761
# slice = test, score = 0.04501971090670172
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.07119999999999999 tf.Tensor(2554.4321358474417, shape=(), dtype=float64) 100
# slice = key, score = 0.07119999999999999
# np.mean(results), mse, len(results) =  0.0815531660692951 tf.Tensor(2387.5780546080064, shape=(), dtype=float64) 1674
# slice = train, score = 0.0815531660692951
# np.mean(results), mse, len(results) =  0.045755584756898816 tf.Tensor(2310.279518490574, shape=(), dtype=float64) 761
# slice = test, score = 0.045755584756898816
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.0725 tf.Tensor(2532.4809808994546, shape=(), dtype=float64) 100
# slice = key, score = 0.0725
# np.mean(results), mse, len(results) =  0.08166069295101552 tf.Tensor(2382.0454482072228, shape=(), dtype=float64) 1674
# slice = train, score = 0.08166069295101552
# np.mean(results), mse, len(results) =  0.04566360052562418 tf.Tensor(2307.530968483368, shape=(), dtype=float64) 761
# slice = test, score = 0.04566360052562418
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.07239999999999999 tf.Tensor(2391.9486609030864, shape=(), dtype=float64) 100
# slice = key, score = 0.07239999999999999
# np.mean(results), mse, len(results) =  0.08250298685782557 tf.Tensor(2298.3031295669516, shape=(), dtype=float64) 1674
# slice = train, score = 0.08250298685782557
# np.mean(results), mse, len(results) =  0.04601839684625493 tf.Tensor(2245.1314519737925, shape=(), dtype=float64) 761
# slice = test, score = 0.04601839684625493
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.07339999999999999 tf.Tensor(2637.3934714183583, shape=(), dtype=float64) 100
# slice = key, score = 0.07339999999999999
# np.mean(results), mse, len(results) =  0.08241338112305854 tf.Tensor(2464.459121279583, shape=(), dtype=float64) 1674
# slice = train, score = 0.08241338112305854
# np.mean(results), mse, len(results) =  0.045072273324572934 tf.Tensor(2381.1275557020426, shape=(), dtype=float64) 761
# slice = test, score = 0.045072273324572934
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.07440000000000001 tf.Tensor(2621.2806199625466, shape=(), dtype=float64) 100
# slice = key, score = 0.07440000000000001
# np.mean(results), mse, len(results) =  0.08234767025089607 tf.Tensor(2513.265176342021, shape=(), dtype=float64) 1674
# slice = train, score = 0.08234767025089607
# np.mean(results), mse, len(results) =  0.0450065703022339 tf.Tensor(2458.2905273133665, shape=(), dtype=float64) 761
# slice = test, score = 0.0450065703022339
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.07590000000000001 tf.Tensor(2777.668371576676, shape=(), dtype=float64) 100
# slice = key, score = 0.07590000000000001
# np.mean(results), mse, len(results) =  0.08369175627240144 tf.Tensor(2611.8923229211705, shape=(), dtype=float64) 1674
# slice = train, score = 0.08369175627240144
# np.mean(results), mse, len(results) =  0.04630749014454665 tf.Tensor(2521.655166993896, shape=(), dtype=float64) 761
# slice = test, score = 0.04630749014454665
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.07519999999999999 tf.Tensor(2588.900526377582, shape=(), dtype=float64) 100
# slice = key, score = 0.07519999999999999
# np.mean(results), mse, len(results) =  0.08400836320191159 tf.Tensor(2470.2594208923374, shape=(), dtype=float64) 1674
# slice = train, score = 0.08400836320191159
# np.mean(results), mse, len(results) =  0.04576872536136663 tf.Tensor(2413.2085426295516, shape=(), dtype=float64) 761
# slice = test, score = 0.04576872536136663
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.07659999999999999 tf.Tensor(2526.936045398934, shape=(), dtype=float64) 100
# slice = key, score = 0.07659999999999999
# np.mean(results), mse, len(results) =  0.0843488649940263 tf.Tensor(2419.7190985643465, shape=(), dtype=float64) 1674
# slice = train, score = 0.0843488649940263
# np.mean(results), mse, len(results) =  0.046044678055190545 tf.Tensor(2377.1869157194365, shape=(), dtype=float64) 761
# slice = test, score = 0.046044678055190545
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.0778 tf.Tensor(2505.992558408668, shape=(), dtype=float64) 100
# slice = key, score = 0.0778
# np.mean(results), mse, len(results) =  0.08488649940262845 tf.Tensor(2376.1950880828986, shape=(), dtype=float64) 1674
# slice = train, score = 0.08488649940262845
# np.mean(results), mse, len(results) =  0.046675427069645205 tf.Tensor(2336.2830831570195, shape=(), dtype=float64) 761
# slice = test, score = 0.046675427069645205
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.077 tf.Tensor(2646.0106403959026, shape=(), dtype=float64) 100
# slice = key, score = 0.077
# np.mean(results), mse, len(results) =  0.08479689366786142 tf.Tensor(2521.6697085507594, shape=(), dtype=float64) 1674
# slice = train, score = 0.08479689366786142
# np.mean(results), mse, len(results) =  0.04612352168199736 tf.Tensor(2472.9617491838308, shape=(), dtype=float64) 761
# slice = test, score = 0.04612352168199736
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.0769 tf.Tensor(2761.514139903339, shape=(), dtype=float64) 100
# slice = key, score = 0.0769
# np.mean(results), mse, len(results) =  0.08536439665471923 tf.Tensor(2695.1105507612883, shape=(), dtype=float64) 1674
# slice = train, score = 0.08536439665471923
# np.mean(results), mse, len(results) =  0.04721419185282524 tf.Tensor(2665.5284735493005, shape=(), dtype=float64) 761
# slice = test, score = 0.04721419185282524
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.07799999999999999 tf.Tensor(2808.9682111619773, shape=(), dtype=float64) 100
# slice = key, score = 0.07799999999999999
# np.mean(results), mse, len(results) =  0.08563918757467145 tf.Tensor(2756.1974699922534, shape=(), dtype=float64) 1674
# slice = train, score = 0.08563918757467145
# np.mean(results), mse, len(results) =  0.04654402102496715 tf.Tensor(2722.074115732341, shape=(), dtype=float64) 761
# slice = test, score = 0.04654402102496715
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.07809999999999999 tf.Tensor(2706.408527809255, shape=(), dtype=float64) 100
# slice = key, score = 0.07809999999999999
# np.mean(results), mse, len(results) =  0.08630824372759857 tf.Tensor(2615.671293363326, shape=(), dtype=float64) 1674
# slice = train, score = 0.08630824372759857
# np.mean(results), mse, len(results) =  0.047187910643889615 tf.Tensor(2591.66807940133, shape=(), dtype=float64) 761
# slice = test, score = 0.047187910643889615
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.0791 tf.Tensor(2939.834612294249, shape=(), dtype=float64) 100
# slice = key, score = 0.0791
# np.mean(results), mse, len(results) =  0.08663082437275986 tf.Tensor(2855.3911269638015, shape=(), dtype=float64) 1674
# slice = train, score = 0.08663082437275986
# np.mean(results), mse, len(results) =  0.04776609724047307 tf.Tensor(2830.3714971867867, shape=(), dtype=float64) 761
# slice = test, score = 0.04776609724047307
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.07819999999999999 tf.Tensor(3023.3848132134503, shape=(), dtype=float64) 100
# slice = key, score = 0.07819999999999999
# np.mean(results), mse, len(results) =  0.08691756272401434 tf.Tensor(2899.171112894224, shape=(), dtype=float64) 1674
# slice = train, score = 0.08691756272401434
# np.mean(results), mse, len(results) =  0.0468856767411301 tf.Tensor(2866.916920547876, shape=(), dtype=float64) 761
# slice = test, score = 0.0468856767411301
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.07839999999999998 tf.Tensor(2974.2748184072693, shape=(), dtype=float64) 100
# slice = key, score = 0.07839999999999998
# np.mean(results), mse, len(results) =  0.08667861409796895 tf.Tensor(2880.6094475569475, shape=(), dtype=float64) 1674
# slice = train, score = 0.08667861409796895
# np.mean(results), mse, len(results) =  0.04591327201051249 tf.Tensor(2869.988187018968, shape=(), dtype=float64) 761
# slice = test, score = 0.04591327201051249
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.0799 tf.Tensor(2848.2047564317995, shape=(), dtype=float64) 100
# slice = key, score = 0.0799
# np.mean(results), mse, len(results) =  0.08795698924731184 tf.Tensor(2789.6835825192584, shape=(), dtype=float64) 1674
# slice = train, score = 0.08795698924731184
# np.mean(results), mse, len(results) =  0.047437582128777925 tf.Tensor(2802.500727488937, shape=(), dtype=float64) 761
# slice = test, score = 0.047437582128777925
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.07979999999999998 tf.Tensor(3103.4837733811883, shape=(), dtype=float64) 100
# slice = key, score = 0.07979999999999998
# np.mean(results), mse, len(results) =  0.0882258064516129 tf.Tensor(2990.0969035461244, shape=(), dtype=float64) 1674
# slice = train, score = 0.0882258064516129
# np.mean(results), mse, len(results) =  0.047910643889618916 tf.Tensor(2978.0968010267575, shape=(), dtype=float64) 761
# slice = test, score = 0.047910643889618916
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.0799 tf.Tensor(2856.9150506165247, shape=(), dtype=float64) 100
# slice = key, score = 0.0799
# np.mean(results), mse, len(results) =  0.08827956989247314 tf.Tensor(2760.6291919019636, shape=(), dtype=float64) 1674
# slice = train, score = 0.08827956989247314
# np.mean(results), mse, len(results) =  0.04788436268068331 tf.Tensor(2775.6573898333436, shape=(), dtype=float64) 761
# slice = test, score = 0.04788436268068331
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.08059999999999999 tf.Tensor(3140.4104355199124, shape=(), dtype=float64) 100
# slice = key, score = 0.08059999999999999
# np.mean(results), mse, len(results) =  0.08884109916367981 tf.Tensor(3031.30710884553, shape=(), dtype=float64) 1674
# slice = train, score = 0.08884109916367981
# np.mean(results), mse, len(results) =  0.04741130091984231 tf.Tensor(3032.557487727683, shape=(), dtype=float64) 761
# slice = test, score = 0.04741130091984231
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.07999999999999999 tf.Tensor(3416.1279587745175, shape=(), dtype=float64) 100
# slice = key, score = 0.07999999999999999
# np.mean(results), mse, len(results) =  0.08867980884109916 tf.Tensor(3316.386536146376, shape=(), dtype=float64) 1674
# slice = train, score = 0.08867980884109916
# np.mean(results), mse, len(results) =  0.047647831800262816 tf.Tensor(3299.695079807375, shape=(), dtype=float64) 761
# slice = test, score = 0.047647831800262816
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.08119999999999998 tf.Tensor(3413.405961590472, shape=(), dtype=float64) 100
# slice = key, score = 0.08119999999999998
# np.mean(results), mse, len(results) =  0.08894862604540024 tf.Tensor(3389.585643731772, shape=(), dtype=float64) 1674
# slice = train, score = 0.08894862604540024
# np.mean(results), mse, len(results) =  0.047332457293035486 tf.Tensor(3421.780651276702, shape=(), dtype=float64) 761
# slice = test, score = 0.047332457293035486
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.0808 tf.Tensor(3332.199815440262, shape=(), dtype=float64) 100
# slice = key, score = 0.0808
# np.mean(results), mse, len(results) =  0.08885304659498208 tf.Tensor(3271.315154472726, shape=(), dtype=float64) 1674
# slice = train, score = 0.08885304659498208
# np.mean(results), mse, len(results) =  0.04727989487516426 tf.Tensor(3299.0870004581952, shape=(), dtype=float64) 761
# slice = test, score = 0.04727989487516426
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.08099999999999997 tf.Tensor(3347.9361780656636, shape=(), dtype=float64) 100
# slice = key, score = 0.08099999999999997
# np.mean(results), mse, len(results) =  0.08919354838709677 tf.Tensor(3243.541621319237, shape=(), dtype=float64) 1674
# slice = train, score = 0.08919354838709677
# np.mean(results), mse, len(results) =  0.04662286465177399 tf.Tensor(3250.9719509679985, shape=(), dtype=float64) 761
# slice = test, score = 0.04662286465177399
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.0822 tf.Tensor(3602.5346588501657, shape=(), dtype=float64) 100
# slice = key, score = 0.0822
# np.mean(results), mse, len(results) =  0.08925328554360813 tf.Tensor(3476.6814879739354, shape=(), dtype=float64) 1674
# slice = train, score = 0.08925328554360813
# np.mean(results), mse, len(results) =  0.04706964520367937 tf.Tensor(3489.57068160513, shape=(), dtype=float64) 761
# slice = test, score = 0.04706964520367937
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.08239999999999999 tf.Tensor(3557.512450639142, shape=(), dtype=float64) 100
# slice = key, score = 0.08239999999999999
# np.mean(results), mse, len(results) =  0.09025686977299881 tf.Tensor(3431.262649325794, shape=(), dtype=float64) 1674
# slice = train, score = 0.09025686977299881
# np.mean(results), mse, len(results) =  0.04842312746386334 tf.Tensor(3462.1272738020084, shape=(), dtype=float64) 761
# slice = test, score = 0.04842312746386334
#
# === Iteration 90000 ===
# np.mean(results), mse, len(results) =  0.0819 tf.Tensor(3504.9144921697457, shape=(), dtype=float64) 100
# slice = key, score = 0.0819
# np.mean(results), mse, len(results) =  0.09007168458781364 tf.Tensor(3437.7603888823387, shape=(), dtype=float64) 1674
# slice = train, score = 0.09007168458781364
# np.mean(results), mse, len(results) =  0.047647831800262816 tf.Tensor(3497.3823734393322, shape=(), dtype=float64) 761
# slice = test, score = 0.047647831800262816
#
# === Iteration 91000 ===
# np.mean(results), mse, len(results) =  0.0827 tf.Tensor(3651.856607021168, shape=(), dtype=float64) 100
# slice = key, score = 0.0827
# np.mean(results), mse, len(results) =  0.0904062126642772 tf.Tensor(3572.8903540901338, shape=(), dtype=float64) 1674
# slice = train, score = 0.0904062126642772
# np.mean(results), mse, len(results) =  0.0483311432325887 tf.Tensor(3616.7016761033115, shape=(), dtype=float64) 761
# slice = test, score = 0.0483311432325887
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.08159999999999998 tf.Tensor(3901.736741400523, shape=(), dtype=float64) 100
# slice = key, score = 0.08159999999999998
# np.mean(results), mse, len(results) =  0.09113500597371565 tf.Tensor(3837.607576571707, shape=(), dtype=float64) 1674
# slice = train, score = 0.09113500597371565
# np.mean(results), mse, len(results) =  0.04776609724047307 tf.Tensor(3898.4911093060996, shape=(), dtype=float64) 761
# slice = test, score = 0.04776609724047307
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.0827 tf.Tensor(3660.1524506748533, shape=(), dtype=float64) 100
# slice = key, score = 0.0827
# np.mean(results), mse, len(results) =  0.09069892473118281 tf.Tensor(3643.862022478186, shape=(), dtype=float64) 1674
# slice = train, score = 0.09069892473118281
# np.mean(results), mse, len(results) =  0.04681997371879107 tf.Tensor(3738.610927272101, shape=(), dtype=float64) 761
# slice = test, score = 0.04681997371879107
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.083 tf.Tensor(3808.7910525319785, shape=(), dtype=float64) 100
# slice = key, score = 0.083
# np.mean(results), mse, len(results) =  0.09172640382317802 tf.Tensor(3709.037266921764, shape=(), dtype=float64) 1674
# slice = train, score = 0.09172640382317802
# np.mean(results), mse, len(results) =  0.049329829172141924 tf.Tensor(3762.1251511750443, shape=(), dtype=float64) 761
# slice = test, score = 0.049329829172141924
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.08259999999999999 tf.Tensor(3893.0788571627295, shape=(), dtype=float64) 100
# slice = key, score = 0.08259999999999999
# np.mean(results), mse, len(results) =  0.09154121863799283 tf.Tensor(3849.8519332101764, shape=(), dtype=float64) 1674
# slice = train, score = 0.09154121863799283
# np.mean(results), mse, len(results) =  0.04730617608409987 tf.Tensor(3928.383414947309, shape=(), dtype=float64) 761
# slice = test, score = 0.04730617608409987
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.0832 tf.Tensor(3649.369261029247, shape=(), dtype=float64) 100
# slice = key, score = 0.0832
# np.mean(results), mse, len(results) =  0.09164277180406215 tf.Tensor(3637.1082887999014, shape=(), dtype=float64) 1674
# slice = train, score = 0.09164277180406215
# np.mean(results), mse, len(results) =  0.047726675427069654 tf.Tensor(3754.5750483190236, shape=(), dtype=float64) 761
# slice = test, score = 0.047726675427069654
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.08399999999999999 tf.Tensor(3708.274566533239, shape=(), dtype=float64) 100
# slice = key, score = 0.08399999999999999
# np.mean(results), mse, len(results) =  0.09201911589008364 tf.Tensor(3644.0653133647547, shape=(), dtype=float64) 1674
# slice = train, score = 0.09201911589008364
# np.mean(results), mse, len(results) =  0.04804204993429698 tf.Tensor(3742.0429538722733, shape=(), dtype=float64) 761
# slice = test, score = 0.04804204993429698
#
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.0836 tf.Tensor(4000.81246402108, shape=(), dtype=float64) 100
# slice = key, score = 0.0836
# np.mean(results), mse, len(results) =  0.09254480286738352 tf.Tensor(3952.874602272283, shape=(), dtype=float64) 1674
# slice = train, score = 0.09254480286738352
# np.mean(results), mse, len(results) =  0.049645203679369254 tf.Tensor(4060.6500342281483, shape=(), dtype=float64) 761
# slice = test, score = 0.049645203679369254
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.085 tf.Tensor(3942.121732994483, shape=(), dtype=float64) 100
# slice = key, score = 0.085
# np.mean(results), mse, len(results) =  0.09295698924731184 tf.Tensor(3975.52719828356, shape=(), dtype=float64) 1674
# slice = train, score = 0.09295698924731184
# np.mean(results), mse, len(results) =  0.04934296977660973 tf.Tensor(4136.69998507317, shape=(), dtype=float64) 761
# slice = test, score = 0.04934296977660973
# last loss =  tf.Tensor(-0.0007346368384858139, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.09314814814814815 tf.Tensor(3962.8443146969603, shape=(), dtype=float64) 1674
# np.mean(results), mse, len(results) =  0.048607095926412616 tf.Tensor(4128.35431732535, shape=(), dtype=float64) 761
# (0.09314814814814815, 0.048607095926412616)

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': True,
    'train_popbias': True, 'train_bias': True,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.001
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (7024, 100)
# self.embed_games.shape =  (8950, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8950)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (7024, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.061799999999999994 tf.Tensor(1.0542533109888488, shape=(), dtype=float64) 100
# slice = key, score = 0.061799999999999994
# np.mean(results), mse, len(results) =  0.06740888382687928 tf.Tensor(1.1319883991891893, shape=(), dtype=float64) 7024
# slice = train, score = 0.06740888382687928
# np.mean(results), mse, len(results) =  0.06105108055009824 tf.Tensor(1.278974683494607, shape=(), dtype=float64) 3054
# slice = test, score = 0.06105108055009824
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.13269999999999998 tf.Tensor(2956.2890609643046, shape=(), dtype=float64) 100
# slice = key, score = 0.13269999999999998
# np.mean(results), mse, len(results) =  0.1346739749430524 tf.Tensor(2989.944987625547, shape=(), dtype=float64) 7024
# slice = train, score = 0.1346739749430524
# np.mean(results), mse, len(results) =  0.14057301899148658 tf.Tensor(3291.6723629689536, shape=(), dtype=float64) 3054
# slice = test, score = 0.14057301899148658
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.1413 tf.Tensor(4920.164385635226, shape=(), dtype=float64) 100
# slice = key, score = 0.1413
# np.mean(results), mse, len(results) =  0.15377989749430526 tf.Tensor(5371.872117746042, shape=(), dtype=float64) 7024
# slice = train, score = 0.15377989749430526
# np.mean(results), mse, len(results) =  0.160347085789129 tf.Tensor(5606.406604826572, shape=(), dtype=float64) 3054
# slice = test, score = 0.160347085789129
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.1454 tf.Tensor(10032.786736229938, shape=(), dtype=float64) 100
# slice = key, score = 0.1454
# np.mean(results), mse, len(results) =  0.16170415717539863 tf.Tensor(11025.394853713444, shape=(), dtype=float64) 7024
# slice = train, score = 0.16170415717539863
# np.mean(results), mse, len(results) =  0.16894237066142764 tf.Tensor(10859.022702661427, shape=(), dtype=float64) 3054
# slice = test, score = 0.16894237066142764
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.1508 tf.Tensor(15213.989905330485, shape=(), dtype=float64) 100
# slice = key, score = 0.1508
# np.mean(results), mse, len(results) =  0.16261958997722095 tf.Tensor(16933.379478237275, shape=(), dtype=float64) 7024
# slice = train, score = 0.16261958997722095
# np.mean(results), mse, len(results) =  0.1688375900458415 tf.Tensor(16970.128293232712, shape=(), dtype=float64) 3054
# slice = test, score = 0.1688375900458415
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.1536 tf.Tensor(18762.225361994268, shape=(), dtype=float64) 100
# slice = key, score = 0.1536
# np.mean(results), mse, len(results) =  0.16822323462414582 tf.Tensor(20924.59697503233, shape=(), dtype=float64) 7024
# slice = train, score = 0.16822323462414582
# np.mean(results), mse, len(results) =  0.17596267190569745 tf.Tensor(20745.025963540727, shape=(), dtype=float64) 3054
# slice = test, score = 0.17596267190569745
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.15810000000000002 tf.Tensor(24496.761012754407, shape=(), dtype=float64) 100
# slice = key, score = 0.15810000000000002
# np.mean(results), mse, len(results) =  0.1692369020501139 tf.Tensor(27920.52659691058, shape=(), dtype=float64) 7024
# slice = train, score = 0.1692369020501139
# np.mean(results), mse, len(results) =  0.1768402095612312 tf.Tensor(26708.86712008736, shape=(), dtype=float64) 3054
# slice = test, score = 0.1768402095612312
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.16070000000000004 tf.Tensor(32569.267384608927, shape=(), dtype=float64) 100
# slice = key, score = 0.16070000000000004
# np.mean(results), mse, len(results) =  0.17381833712984057 tf.Tensor(37595.875024440844, shape=(), dtype=float64) 7024
# slice = train, score = 0.17381833712984057
# np.mean(results), mse, len(results) =  0.18048133595284874 tf.Tensor(35717.766286779195, shape=(), dtype=float64) 3054
# slice = test, score = 0.18048133595284874
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.16280000000000006 tf.Tensor(36250.4670863474, shape=(), dtype=float64) 100
# slice = key, score = 0.16280000000000006
# np.mean(results), mse, len(results) =  0.17527050113895215 tf.Tensor(41250.37173194477, shape=(), dtype=float64) 7024
# slice = train, score = 0.17527050113895215
# np.mean(results), mse, len(results) =  0.1820694171578258 tf.Tensor(38946.77163411509, shape=(), dtype=float64) 3054
# slice = test, score = 0.1820694171578258
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.16140000000000002 tf.Tensor(44690.806683956594, shape=(), dtype=float64) 100
# slice = key, score = 0.16140000000000002
# np.mean(results), mse, len(results) =  0.17269504555808657 tf.Tensor(51210.96955956316, shape=(), dtype=float64) 7024
# slice = train, score = 0.17269504555808657
# np.mean(results), mse, len(results) =  0.18006548788474136 tf.Tensor(48248.586429409996, shape=(), dtype=float64) 3054
# slice = test, score = 0.18006548788474136

# %% [markdown]
# # EOF

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': False,
    'train_vbias': True,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'mse',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (599, 100)
# self.embed_games.shape =  (8223, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8223)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (599, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.6704000000000001 tf.Tensor(0.0013085468222526315, shape=(), dtype=float64) 100
# slice = key, score = 0.6704000000000001
# np.mean(results), mse, len(results) =  0.7360601001669449 tf.Tensor(0.0008644753498525569, shape=(), dtype=float64) 599
# slice = train, score = 0.7360601001669449
# np.mean(results), mse, len(results) =  0.6599333333333334 tf.Tensor(0.001296546580314037, shape=(), dtype=float64) 300
# slice = test, score = 0.6599333333333334
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.6705000000000001 tf.Tensor(0.0013080316202927387, shape=(), dtype=float64) 100
# slice = key, score = 0.6705000000000001
# np.mean(results), mse, len(results) =  0.7351585976627714 tf.Tensor(0.0008670167673310961, shape=(), dtype=float64) 599
# slice = train, score = 0.7351585976627714
# np.mean(results), mse, len(results) =  0.6584333333333334 tf.Tensor(0.0012989727191370269, shape=(), dtype=float64) 300
# slice = test, score = 0.6584333333333334
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.6702000000000001 tf.Tensor(0.0013080077885282498, shape=(), dtype=float64) 100
# slice = key, score = 0.6702000000000001
# np.mean(results), mse, len(results) =  0.7360434056761268 tf.Tensor(0.0008671838752859685, shape=(), dtype=float64) 599
# slice = train, score = 0.7360434056761268
# np.mean(results), mse, len(results) =  0.6591666666666668 tf.Tensor(0.001299458453312949, shape=(), dtype=float64) 300
# slice = test, score = 0.6591666666666668
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.6701 tf.Tensor(0.0013079388079995787, shape=(), dtype=float64) 100
# slice = key, score = 0.6701
# np.mean(results), mse, len(results) =  0.7359599332220368 tf.Tensor(0.0008672559513263286, shape=(), dtype=float64) 599
# slice = train, score = 0.7359599332220368
# np.mean(results), mse, len(results) =  0.6593333333333333 tf.Tensor(0.0012993457977206774, shape=(), dtype=float64) 300
# slice = test, score = 0.6593333333333333
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.6720000000000002 tf.Tensor(0.0013080072607952722, shape=(), dtype=float64) 100
# slice = key, score = 0.6720000000000002
# np.mean(results), mse, len(results) =  0.736060100166945 tf.Tensor(0.0008673047237406182, shape=(), dtype=float64) 599
# slice = train, score = 0.736060100166945
# np.mean(results), mse, len(results) =  0.6586000000000001 tf.Tensor(0.001299228142187536, shape=(), dtype=float64) 300
# slice = test, score = 0.6586000000000001
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6701 tf.Tensor(0.0013077647923463581, shape=(), dtype=float64) 100
# slice = key, score = 0.6701
# np.mean(results), mse, len(results) =  0.7361769616026712 tf.Tensor(0.0008672371333901646, shape=(), dtype=float64) 599
# slice = train, score = 0.7361769616026712
# np.mean(results), mse, len(results) =  0.6592 tf.Tensor(0.0012991959800070585, shape=(), dtype=float64) 300
# slice = test, score = 0.6592
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6718 tf.Tensor(0.0013080869830249919, shape=(), dtype=float64) 100
# slice = key, score = 0.6718
# np.mean(results), mse, len(results) =  0.7354590984974959 tf.Tensor(0.0008673005585407158, shape=(), dtype=float64) 599
# slice = train, score = 0.7354590984974959
# np.mean(results), mse, len(results) =  0.6594333333333334 tf.Tensor(0.0012995597700266575, shape=(), dtype=float64) 300
# slice = test, score = 0.6594333333333334
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6706 tf.Tensor(0.0013079645148514896, shape=(), dtype=float64) 100
# slice = key, score = 0.6706
# np.mean(results), mse, len(results) =  0.7358597662771285 tf.Tensor(0.0008671411377223625, shape=(), dtype=float64) 599
# slice = train, score = 0.7358597662771285
# np.mean(results), mse, len(results) =  0.6591 tf.Tensor(0.0012989946678478666, shape=(), dtype=float64) 300
# slice = test, score = 0.6591
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.6706 tf.Tensor(0.0013078443839725329, shape=(), dtype=float64) 100
# slice = key, score = 0.6706
# np.mean(results), mse, len(results) =  0.736093489148581 tf.Tensor(0.0008671834768754775, shape=(), dtype=float64) 599
# slice = train, score = 0.736093489148581
# np.mean(results), mse, len(results) =  0.6600666666666666 tf.Tensor(0.0012993765257965015, shape=(), dtype=float64) 300
# slice = test, score = 0.6600666666666666
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.6705999999999999 tf.Tensor(0.0013079577591432962, shape=(), dtype=float64) 100
# slice = key, score = 0.6705999999999999
# np.mean(results), mse, len(results) =  0.7353422370617697 tf.Tensor(0.0008672683456905446, shape=(), dtype=float64) 599
# slice = train, score = 0.7353422370617697
# np.mean(results), mse, len(results) =  0.6596333333333334 tf.Tensor(0.0012993252164761112, shape=(), dtype=float64) 300
# slice = test, score = 0.6596333333333334
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.6688 tf.Tensor(0.0013082753344655059, shape=(), dtype=float64) 100
# slice = key, score = 0.6688
# np.mean(results), mse, len(results) =  0.7362771285475792 tf.Tensor(0.0008673113692833014, shape=(), dtype=float64) 599
# slice = train, score = 0.7362771285475792
# np.mean(results), mse, len(results) =  0.6597999999999999 tf.Tensor(0.0012992272941380438, shape=(), dtype=float64) 300
# slice = test, score = 0.6597999999999999
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.6705 tf.Tensor(0.0013080845285614606, shape=(), dtype=float64) 100
# slice = key, score = 0.6705
# np.mean(results), mse, len(results) =  0.7360934891485811 tf.Tensor(0.0008673166290151323, shape=(), dtype=float64) 599
# slice = train, score = 0.7360934891485811
# np.mean(results), mse, len(results) =  0.6597333333333334 tf.Tensor(0.0012994130178494696, shape=(), dtype=float64) 300
# slice = test, score = 0.6597333333333334
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.6698999999999999 tf.Tensor(0.001307760232938354, shape=(), dtype=float64) 100
# slice = key, score = 0.6698999999999999
# np.mean(results), mse, len(results) =  0.7359599332220367 tf.Tensor(0.0008671976624812435, shape=(), dtype=float64) 599
# slice = train, score = 0.7359599332220367
# np.mean(results), mse, len(results) =  0.6585666666666666 tf.Tensor(0.001299356965605491, shape=(), dtype=float64) 300
# slice = test, score = 0.6585666666666666
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.67 tf.Tensor(0.001307601506445376, shape=(), dtype=float64) 100
# slice = key, score = 0.67
# np.mean(results), mse, len(results) =  0.7362103505843072 tf.Tensor(0.000867022227919506, shape=(), dtype=float64) 599
# slice = train, score = 0.7362103505843072
# np.mean(results), mse, len(results) =  0.6596666666666667 tf.Tensor(0.0012989268367460875, shape=(), dtype=float64) 300
# slice = test, score = 0.6596666666666667
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.6712999999999998 tf.Tensor(0.0013078676518375435, shape=(), dtype=float64) 100
# slice = key, score = 0.6712999999999998
# np.mean(results), mse, len(results) =  0.7353756260434057 tf.Tensor(0.0008673175302406121, shape=(), dtype=float64) 599
# slice = train, score = 0.7353756260434057
# np.mean(results), mse, len(results) =  0.6600666666666668 tf.Tensor(0.0012992516594796653, shape=(), dtype=float64) 300
# slice = test, score = 0.6600666666666668
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6695 tf.Tensor(0.001307756332874546, shape=(), dtype=float64) 100
# slice = key, score = 0.6695
# np.mean(results), mse, len(results) =  0.7360434056761268 tf.Tensor(0.0008670047547216065, shape=(), dtype=float64) 599
# slice = train, score = 0.7360434056761268
# np.mean(results), mse, len(results) =  0.6595000000000001 tf.Tensor(0.0012990250770835265, shape=(), dtype=float64) 300
# slice = test, score = 0.6595000000000001
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6703 tf.Tensor(0.0013077723000890168, shape=(), dtype=float64) 100
# slice = key, score = 0.6703
# np.mean(results), mse, len(results) =  0.7357762938230384 tf.Tensor(0.0008672065285095216, shape=(), dtype=float64) 599
# slice = train, score = 0.7357762938230384
# np.mean(results), mse, len(results) =  0.6599333333333334 tf.Tensor(0.001299111864223921, shape=(), dtype=float64) 300
# slice = test, score = 0.6599333333333334
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6707 tf.Tensor(0.0013076398381858432, shape=(), dtype=float64) 100
# slice = key, score = 0.6707
# np.mean(results), mse, len(results) =  0.7356260434056761 tf.Tensor(0.0008670399965183635, shape=(), dtype=float64) 599
# slice = train, score = 0.7356260434056761
# np.mean(results), mse, len(results) =  0.6593333333333333 tf.Tensor(0.001298896595390865, shape=(), dtype=float64) 300
# slice = test, score = 0.6593333333333333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [25], in <cell line: 24>()
#       1 N = 100000
#       2 m = CBKnnV0(ctx, fit_kwargs={
#       3     'c': 0,
#       4     'train_matrix': True,
#    (...)
#      21     "learning_rate": 0.0005
#      22 })
# ---> 24 m.fit()
#      25 m.get_score("train"), m.get_score("test")
#
# Input In [6], in CBKnnV0.fit(self, **kwargs)
#     369 if self.p["trainable_items"]:
#     370     weights += [self.trainable_games]
# --> 373 opt.minimize(loss, weights)
#     375 if p["score_verbose"] and (i % p["score_verbose"] == 0):
#     376     print(f"\n=== Iteration {i} ===")
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:543, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     522 def minimize(self, loss, var_list, tape=None):
#     523     """Minimize `loss` by updating `var_list`.
#     524
#     525     This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     541       None
#     542     """
# --> 543     grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     544     self.apply_gradients(grads_and_vars)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:272, in _BaseOptimizer.compute_gradients(self, loss, var_list, tape)
#     270 if not callable(var_list):
#     271     tape.watch(var_list)
# --> 272 loss = loss()
#     273 if callable(var_list):
#     274     var_list = var_list()
#
# Input In [6], in CBKnnV0.fit.<locals>.loss()
#     259     return logits, scores_
#     261 if self.loss == "mse":
# --> 262     logits, scores = get_logits_scores(
#     263         loss_batch = (1e9 if "loss_batch" not in p else p["loss_batch"]))
#     264     v = tf.reduce_mean((scores - logits) ** 2)
#     265 elif self.loss == "qmse":
#
# Input In [6], in CBKnnV0.fit.<locals>.loss.<locals>.get_logits_scores(loss_batch)
#     236 logits = 0
#     238 if self.train_matrix:
# --> 239     logits += train_user_embs_ @ self.W @ tf.transpose(game_embs_)
#     241 if self.train_dssm:
#     242     logits += self.u_dssm(train_user_embs_) @ tf.transpose(self.g_dssm(game_embs_))
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1501, in _OverrideBinaryOperatorHelper.<locals>.r_binary_op_wrapper(y, x)
#    1497 with ops.name_scope(None, op_name, [x, y]) as name:
#    1498   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1499   #   r_binary_op_wrapper use different force_same_dtype values.
#    1500   y, x = maybe_promote_tensors(y, x, force_same_dtype=True)
# -> 1501   return func(x, y, name=name)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1837, in _add_dispatch(x, y, name)
#    1835   return gen_math_ops.add(x, y, name=name)
#    1836 else:
# -> 1837   return gen_math_ops.add_v2(x, y, name=name)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_math_ops.py:462, in add_v2(x, y, name)
#     460 if tld.is_eager:
#     461   try:
# --> 462     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     463       _ctx, "AddV2", name, x, y)
#     464     return _result
#     465   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': False,
    'train_dssm': True,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'mse',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (599, 100)
# self.embed_games.shape =  (8223, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8223)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (599, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.0079 tf.Tensor(0.011844911, shape=(), dtype=float32) 100
# slice = key, score = 0.0079
# np.mean(results), mse, len(results) =  0.013055091819699499 tf.Tensor(0.012485181, shape=(), dtype=float32) 599
# slice = train, score = 0.013055091819699499
# np.mean(results), mse, len(results) =  0.013166666666666667 tf.Tensor(0.012034644, shape=(), dtype=float32) 300
# slice = test, score = 0.013166666666666667
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.6396000000000001 tf.Tensor(0.0014336883, shape=(), dtype=float32) 100
# slice = key, score = 0.6396000000000001
# np.mean(results), mse, len(results) =  0.6795325542570951 tf.Tensor(0.0011860357, shape=(), dtype=float32) 599
# slice = train, score = 0.6795325542570951
# np.mean(results), mse, len(results) =  0.6089666666666667 tf.Tensor(0.0015870397, shape=(), dtype=float32) 300
# slice = test, score = 0.6089666666666667
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.6677999999999998 tf.Tensor(0.0012782663, shape=(), dtype=float32) 100
# slice = key, score = 0.6677999999999998
# np.mean(results), mse, len(results) =  0.7118363939899833 tf.Tensor(0.0009981056, shape=(), dtype=float32) 599
# slice = train, score = 0.7118363939899833
# np.mean(results), mse, len(results) =  0.6374666666666667 tf.Tensor(0.0014146129, shape=(), dtype=float32) 300
# slice = test, score = 0.6374666666666667
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.6770999999999999 tf.Tensor(0.0012314135, shape=(), dtype=float32) 100
# slice = key, score = 0.6770999999999999
# np.mean(results), mse, len(results) =  0.7230717863105175 tf.Tensor(0.00093531574, shape=(), dtype=float32) 599
# slice = train, score = 0.7230717863105175
# np.mean(results), mse, len(results) =  0.6485333333333333 tf.Tensor(0.0013565356, shape=(), dtype=float32) 300
# slice = test, score = 0.6485333333333333
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.6797 tf.Tensor(0.0012065973, shape=(), dtype=float32) 100
# slice = key, score = 0.6797
# np.mean(results), mse, len(results) =  0.7282136894824708 tf.Tensor(0.00090833526, shape=(), dtype=float32) 599
# slice = train, score = 0.7282136894824708
# np.mean(results), mse, len(results) =  0.6535333333333333 tf.Tensor(0.0013374474, shape=(), dtype=float32) 300
# slice = test, score = 0.6535333333333333
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6831999999999999 tf.Tensor(0.0011850436, shape=(), dtype=float32) 100
# slice = key, score = 0.6831999999999999
# np.mean(results), mse, len(results) =  0.7307679465776294 tf.Tensor(0.0008874997, shape=(), dtype=float32) 599
# slice = train, score = 0.7307679465776294
# np.mean(results), mse, len(results) =  0.6555333333333333 tf.Tensor(0.0013262548, shape=(), dtype=float32) 300
# slice = test, score = 0.6555333333333333
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6859999999999998 tf.Tensor(0.0011705863, shape=(), dtype=float32) 100
# slice = key, score = 0.6859999999999998
# np.mean(results), mse, len(results) =  0.7339899833055092 tf.Tensor(0.0008715414, shape=(), dtype=float32) 599
# slice = train, score = 0.7339899833055092
# np.mean(results), mse, len(results) =  0.6554333333333333 tf.Tensor(0.0013272879, shape=(), dtype=float32) 300
# slice = test, score = 0.6554333333333333
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6886 tf.Tensor(0.0011565712, shape=(), dtype=float32) 100
# slice = key, score = 0.6886
# np.mean(results), mse, len(results) =  0.7361101836393991 tf.Tensor(0.000856583, shape=(), dtype=float32) 599
# slice = train, score = 0.7361101836393991
# np.mean(results), mse, len(results) =  0.6570666666666666 tf.Tensor(0.0013287083, shape=(), dtype=float32) 300
# slice = test, score = 0.6570666666666666
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.6906 tf.Tensor(0.0011477899, shape=(), dtype=float32) 100
# slice = key, score = 0.6906
# np.mean(results), mse, len(results) =  0.7379632721202004 tf.Tensor(0.0008458039, shape=(), dtype=float32) 599
# slice = train, score = 0.7379632721202004
# np.mean(results), mse, len(results) =  0.6548333333333333 tf.Tensor(0.0013315786, shape=(), dtype=float32) 300
# slice = test, score = 0.6548333333333333
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.6914 tf.Tensor(0.0011383583, shape=(), dtype=float32) 100
# slice = key, score = 0.6914
# np.mean(results), mse, len(results) =  0.7390317195325543 tf.Tensor(0.00083615433, shape=(), dtype=float32) 599
# slice = train, score = 0.7390317195325543
# np.mean(results), mse, len(results) =  0.6545666666666666 tf.Tensor(0.0013378169, shape=(), dtype=float32) 300
# slice = test, score = 0.6545666666666666
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.6916999999999999 tf.Tensor(0.0011318369, shape=(), dtype=float32) 100
# slice = key, score = 0.6916999999999999
# np.mean(results), mse, len(results) =  0.7399666110183639 tf.Tensor(0.00083109847, shape=(), dtype=float32) 599
# slice = train, score = 0.7399666110183639
# np.mean(results), mse, len(results) =  0.6546333333333333 tf.Tensor(0.0013431812, shape=(), dtype=float32) 300
# slice = test, score = 0.6546333333333333
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.6931 tf.Tensor(0.0011247349, shape=(), dtype=float32) 100
# slice = key, score = 0.6931
# np.mean(results), mse, len(results) =  0.7409015025041736 tf.Tensor(0.000826102, shape=(), dtype=float32) 599
# slice = train, score = 0.7409015025041736
# np.mean(results), mse, len(results) =  0.6528666666666667 tf.Tensor(0.0013486852, shape=(), dtype=float32) 300
# slice = test, score = 0.6528666666666667
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.6953 tf.Tensor(0.0011196713, shape=(), dtype=float32) 100
# slice = key, score = 0.6953
# np.mean(results), mse, len(results) =  0.7422537562604341 tf.Tensor(0.0008218197, shape=(), dtype=float32) 599
# slice = train, score = 0.7422537562604341
# np.mean(results), mse, len(results) =  0.6529333333333334 tf.Tensor(0.0013547112, shape=(), dtype=float32) 300
# slice = test, score = 0.6529333333333334
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.6942999999999998 tf.Tensor(0.0011145326, shape=(), dtype=float32) 100
# slice = key, score = 0.6942999999999998
# np.mean(results), mse, len(results) =  0.7427045075125208 tf.Tensor(0.0008175212, shape=(), dtype=float32) 599
# slice = train, score = 0.7427045075125208
# np.mean(results), mse, len(results) =  0.6518333333333334 tf.Tensor(0.00135873, shape=(), dtype=float32) 300
# slice = test, score = 0.6518333333333334
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.6955 tf.Tensor(0.0011148952, shape=(), dtype=float32) 100
# slice = key, score = 0.6955
# np.mean(results), mse, len(results) =  0.743355592654424 tf.Tensor(0.0008179649, shape=(), dtype=float32) 599
# slice = train, score = 0.743355592654424
# np.mean(results), mse, len(results) =  0.6517 tf.Tensor(0.0013588449, shape=(), dtype=float32) 300
# slice = test, score = 0.6517
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6969000000000001 tf.Tensor(0.0011072679, shape=(), dtype=float32) 100
# slice = key, score = 0.6969000000000001
# np.mean(results), mse, len(results) =  0.7440233722871453 tf.Tensor(0.00080977246, shape=(), dtype=float32) 599
# slice = train, score = 0.7440233722871453
# np.mean(results), mse, len(results) =  0.6511333333333332 tf.Tensor(0.0013676337, shape=(), dtype=float32) 300
# slice = test, score = 0.6511333333333332
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6959000000000001 tf.Tensor(0.0011002889, shape=(), dtype=float32) 100
# slice = key, score = 0.6959000000000001
# np.mean(results), mse, len(results) =  0.7457095158597662 tf.Tensor(0.0008038424, shape=(), dtype=float32) 599
# slice = train, score = 0.7457095158597662
# np.mean(results), mse, len(results) =  0.6500666666666666 tf.Tensor(0.0013665434, shape=(), dtype=float32) 300
# slice = test, score = 0.6500666666666666
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6973999999999999 tf.Tensor(0.0011005008, shape=(), dtype=float32) 100
# slice = key, score = 0.6973999999999999
# np.mean(results), mse, len(results) =  0.7464273789649415 tf.Tensor(0.00080342806, shape=(), dtype=float32) 599
# slice = train, score = 0.7464273789649415
# np.mean(results), mse, len(results) =  0.65 tf.Tensor(0.0013723474, shape=(), dtype=float32) 300
# slice = test, score = 0.65
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 24>()
#       1 N = 100000
#       2 m = CBKnnV0(ctx, fit_kwargs={
#       3     'c': 0,
#       4     'train_matrix': False,
#    (...)
#      21     "learning_rate": 0.0005
#      22 })
# ---> 24 m.fit()
#      25 m.get_score("train"), m.get_score("test")
#
# Input In [6], in CBKnnV0.fit(self, **kwargs)
#     369 if self.p["trainable_items"]:
#     370     weights += [self.trainable_games]
# --> 373 opt.minimize(loss, weights)
#     375 if p["score_verbose"] and (i % p["score_verbose"] == 0):
#     376     print(f"\n=== Iteration {i} ===")
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:544, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     523 """Minimize `loss` by updating `var_list`.
#     524
#     525 This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     541   None
#     542 """
#     543 grads_and_vars = self.compute_gradients(loss, var_list, tape)
# --> 544 self.apply_gradients(grads_and_vars)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1230, in Optimizer.apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1228 if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1229     grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1230 return super().apply_gradients(grads_and_vars, name=name)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:652, in _BaseOptimizer.apply_gradients(self, grads_and_vars, name)
#     650 self._apply_weight_decay(trainable_variables)
#     651 grads_and_vars = list(zip(grads, trainable_variables))
# --> 652 iteration = self._internal_apply_gradients(grads_and_vars)
#     654 # Apply variable constraints after applying gradients.
#     655 for variable in trainable_variables:
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1260, in Optimizer._internal_apply_gradients(self, grads_and_vars)
#    1256 if self._mesh or self._run_with_dtensor:
#    1257     # Skip any usage of strategy logic for DTensor
#    1258     return super()._internal_apply_gradients(grads_and_vars)
# -> 1260 return tf.__internal__.distribute.interim.maybe_merge_call(
#    1261     self._distributed_apply_gradients_fn,
#    1262     self._distribution_strategy,
#    1263     grads_and_vars,
#    1264 )
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1352, in Optimizer._distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1349         return self._update_step(grad, var)
#    1351 for grad, var in grads_and_vars:
# -> 1352     distribution.extended.update(
#    1353         var, apply_grad_to_update_var, args=(grad,), group=False
#    1354     )
#    1356 if self.use_ema:
#    1357     _, var_list = zip(*grads_and_vars)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:2992, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2989   fn = autograph.tf_convert(
#    2990       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2991   with self._container_strategy().scope():
# -> 2992     return self._update(var, fn, args, kwargs, group)
#    2993 else:
#    2994   return self._replica_ctx_update(
#    2995       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4062, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4059 def _update(self, var, fn, args, kwargs, group):
#    4060   # The implementations of _update() and _update_non_slot() are identical
#    4061   # except _update() passes `var` as the first argument to `fn()`.
# -> 4062   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4068, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4064 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4065   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4066   # once that value is used for something.
#    4067   with UpdateContext(colocate_with):
# -> 4068     result = fn(*args, **kwargs)
#    4069     if should_group:
#    4070       return result
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:596, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     594 def wrapper(*args, **kwargs):
#     595   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596     return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1349, in Optimizer._distributed_apply_gradients_fn.<locals>.apply_grad_to_update_var(var, grad)
#    1347     return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1348 else:
# -> 1349     return self._update_step(grad, var)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:241, in _BaseOptimizer._update_step(self, gradient, variable)
#     232 if self._var_key(variable) not in self._index_dict:
#     233     raise KeyError(
#     234         f"The optimizer cannot recognize variable {variable.name}. "
#     235         "This usually means you are trying to call the optimizer to "
#    (...)
#     239         f"`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     240     )
# --> 241 self.update_step(gradient, variable)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/adam.py:174, in Adam.update_step(self, gradient, variable)
#     171 m = self._momentums[self._index_dict[var_key]]
#     172 v = self._velocities[self._index_dict[var_key]]
# --> 174 alpha = lr * tf.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     176 if isinstance(gradient, tf.IndexedSlices):
#     177     # Sparse gradients.
#     178     m.assign_add(-m * (1 - self.beta_1))
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1501, in _OverrideBinaryOperatorHelper.<locals>.r_binary_op_wrapper(y, x)
#    1497 with ops.name_scope(None, op_name, [x, y]) as name:
#    1498   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1499   #   r_binary_op_wrapper use different force_same_dtype values.
#    1500   y, x = maybe_promote_tensors(y, x, force_same_dtype=True)
# -> 1501   return func(x, y, name=name)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:549, in subtract(x, y, name)
#     545 @tf_export("math.subtract", "subtract")
#     546 @dispatch.register_binary_elementwise_api
#     547 @dispatch.add_dispatch_support
#     548 def subtract(x, y, name=None):
# --> 549   return gen_math_ops.sub(x, y, name)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_math_ops.py:11559, in sub(x, y, name)
#   11557 if tld.is_eager:
#   11558   try:
# > 11559     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   11560       _ctx, "Sub", name, x, y)
#   11561     return _result
#   11562   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': False,
    'train_dssm': True,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (599, 100)
# self.embed_games.shape =  (8223, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8223)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (599, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.015100000000000002 tf.Tensor(0.013193638, shape=(), dtype=float32) 100
# slice = key, score = 0.015100000000000002
# np.mean(results), mse, len(results) =  0.014590984974958265 tf.Tensor(0.013282064, shape=(), dtype=float32) 599
# slice = train, score = 0.014590984974958265
# np.mean(results), mse, len(results) =  0.013000000000000001 tf.Tensor(0.012977752, shape=(), dtype=float32) 300
# slice = test, score = 0.013000000000000001
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.29949999999999993 tf.Tensor(39.121723, shape=(), dtype=float32) 100
# slice = key, score = 0.29949999999999993
# np.mean(results), mse, len(results) =  0.31225375626043406 tf.Tensor(41.619648, shape=(), dtype=float32) 599
# slice = train, score = 0.31225375626043406
# np.mean(results), mse, len(results) =  0.24926666666666666 tf.Tensor(36.911777, shape=(), dtype=float32) 300
# slice = test, score = 0.24926666666666666
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.43640000000000007 tf.Tensor(91.691414, shape=(), dtype=float32) 100
# slice = key, score = 0.43640000000000007
# np.mean(results), mse, len(results) =  0.45767946577629376 tf.Tensor(97.30496, shape=(), dtype=float32) 599
# slice = train, score = 0.45767946577629376
# np.mean(results), mse, len(results) =  0.3721 tf.Tensor(88.724434, shape=(), dtype=float32) 300
# slice = test, score = 0.3721
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.4846000000000001 tf.Tensor(135.77249, shape=(), dtype=float32) 100
# slice = key, score = 0.4846000000000001
# np.mean(results), mse, len(results) =  0.5070450751252086 tf.Tensor(140.59521, shape=(), dtype=float32) 599
# slice = train, score = 0.5070450751252086
# np.mean(results), mse, len(results) =  0.4147666666666667 tf.Tensor(127.842896, shape=(), dtype=float32) 300
# slice = test, score = 0.4147666666666667
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.5136 tf.Tensor(164.8321, shape=(), dtype=float32) 100
# slice = key, score = 0.5136
# np.mean(results), mse, len(results) =  0.5337228714524207 tf.Tensor(164.70366, shape=(), dtype=float32) 599
# slice = train, score = 0.5337228714524207
# np.mean(results), mse, len(results) =  0.4342666666666667 tf.Tensor(149.28893, shape=(), dtype=float32) 300
# slice = test, score = 0.4342666666666667
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.5243000000000001 tf.Tensor(188.78624, shape=(), dtype=float32) 100
# slice = key, score = 0.5243000000000001
# np.mean(results), mse, len(results) =  0.5489148580968282 tf.Tensor(185.89784, shape=(), dtype=float32) 599
# slice = train, score = 0.5489148580968282
# np.mean(results), mse, len(results) =  0.44623333333333337 tf.Tensor(168.77866, shape=(), dtype=float32) 300
# slice = test, score = 0.44623333333333337
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.5381 tf.Tensor(204.34315, shape=(), dtype=float32) 100
# slice = key, score = 0.5381
# np.mean(results), mse, len(results) =  0.5619198664440734 tf.Tensor(200.10007, shape=(), dtype=float32) 599
# slice = train, score = 0.5619198664440734
# np.mean(results), mse, len(results) =  0.45563333333333333 tf.Tensor(181.83171, shape=(), dtype=float32) 300
# slice = test, score = 0.45563333333333333
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.5483 tf.Tensor(220.49696, shape=(), dtype=float32) 100
# slice = key, score = 0.5483
# np.mean(results), mse, len(results) =  0.5721202003338899 tf.Tensor(215.81541, shape=(), dtype=float32) 599
# slice = train, score = 0.5721202003338899
# np.mean(results), mse, len(results) =  0.4654333333333333 tf.Tensor(198.09111, shape=(), dtype=float32) 300
# slice = test, score = 0.4654333333333333
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.5606 tf.Tensor(230.44063, shape=(), dtype=float32) 100
# slice = key, score = 0.5606
# np.mean(results), mse, len(results) =  0.5801502504173622 tf.Tensor(226.7203, shape=(), dtype=float32) 599
# slice = train, score = 0.5801502504173622
# np.mean(results), mse, len(results) =  0.4703666666666667 tf.Tensor(208.25983, shape=(), dtype=float32) 300
# slice = test, score = 0.4703666666666667
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.565 tf.Tensor(240.89131, shape=(), dtype=float32) 100
# slice = key, score = 0.565
# np.mean(results), mse, len(results) =  0.5890150250417362 tf.Tensor(239.80435, shape=(), dtype=float32) 599
# slice = train, score = 0.5890150250417362
# np.mean(results), mse, len(results) =  0.4788666666666668 tf.Tensor(220.7161, shape=(), dtype=float32) 300
# slice = test, score = 0.4788666666666668
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.5725000000000001 tf.Tensor(253.78293, shape=(), dtype=float32) 100
# slice = key, score = 0.5725000000000001
# np.mean(results), mse, len(results) =  0.5969616026711186 tf.Tensor(248.24445, shape=(), dtype=float32) 599
# slice = train, score = 0.5969616026711186
# np.mean(results), mse, len(results) =  0.48446666666666666 tf.Tensor(228.06651, shape=(), dtype=float32) 300
# slice = test, score = 0.48446666666666666
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.5836 tf.Tensor(268.3135, shape=(), dtype=float32) 100
# slice = key, score = 0.5836
# np.mean(results), mse, len(results) =  0.6036227045075124 tf.Tensor(266.02502, shape=(), dtype=float32) 599
# slice = train, score = 0.6036227045075124
# np.mean(results), mse, len(results) =  0.4875 tf.Tensor(242.55997, shape=(), dtype=float32) 300
# slice = test, score = 0.4875
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.5922999999999999 tf.Tensor(268.96094, shape=(), dtype=float32) 100
# slice = key, score = 0.5922999999999999
# np.mean(results), mse, len(results) =  0.6097161936560935 tf.Tensor(269.39584, shape=(), dtype=float32) 599
# slice = train, score = 0.6097161936560935
# np.mean(results), mse, len(results) =  0.4923666666666667 tf.Tensor(247.35364, shape=(), dtype=float32) 300
# slice = test, score = 0.4923666666666667
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.5951999999999998 tf.Tensor(283.6662, shape=(), dtype=float32) 100
# slice = key, score = 0.5951999999999998
# np.mean(results), mse, len(results) =  0.6143906510851419 tf.Tensor(285.30255, shape=(), dtype=float32) 599
# slice = train, score = 0.6143906510851419
# np.mean(results), mse, len(results) =  0.4973666666666667 tf.Tensor(262.6137, shape=(), dtype=float32) 300
# slice = test, score = 0.4973666666666667
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.5988999999999999 tf.Tensor(296.62378, shape=(), dtype=float32) 100
# slice = key, score = 0.5988999999999999
# np.mean(results), mse, len(results) =  0.6209515859766276 tf.Tensor(296.99142, shape=(), dtype=float32) 599
# slice = train, score = 0.6209515859766276
# np.mean(results), mse, len(results) =  0.5023666666666666 tf.Tensor(269.64496, shape=(), dtype=float32) 300
# slice = test, score = 0.5023666666666666
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6046 tf.Tensor(314.29416, shape=(), dtype=float32) 100
# slice = key, score = 0.6046
# np.mean(results), mse, len(results) =  0.6247913188647746 tf.Tensor(312.7853, shape=(), dtype=float32) 599
# slice = train, score = 0.6247913188647746
# np.mean(results), mse, len(results) =  0.5041333333333333 tf.Tensor(284.45572, shape=(), dtype=float32) 300
# slice = test, score = 0.5041333333333333
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6082 tf.Tensor(329.83978, shape=(), dtype=float32) 100
# slice = key, score = 0.6082
# np.mean(results), mse, len(results) =  0.6290818030050084 tf.Tensor(329.77167, shape=(), dtype=float32) 599
# slice = train, score = 0.6290818030050084
# np.mean(results), mse, len(results) =  0.5062666666666666 tf.Tensor(300.89105, shape=(), dtype=float32) 300
# slice = test, score = 0.5062666666666666
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6123 tf.Tensor(345.4036, shape=(), dtype=float32) 100
# slice = key, score = 0.6123
# np.mean(results), mse, len(results) =  0.6332387312186979 tf.Tensor(342.42804, shape=(), dtype=float32) 599
# slice = train, score = 0.6332387312186979
# np.mean(results), mse, len(results) =  0.5093333333333334 tf.Tensor(313.03128, shape=(), dtype=float32) 300
# slice = test, score = 0.5093333333333334
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6166 tf.Tensor(346.97757, shape=(), dtype=float32) 100
# slice = key, score = 0.6166
# np.mean(results), mse, len(results) =  0.6352253756260434 tf.Tensor(346.78094, shape=(), dtype=float32) 599
# slice = train, score = 0.6352253756260434
# np.mean(results), mse, len(results) =  0.5095333333333333 tf.Tensor(317.70096, shape=(), dtype=float32) 300
# slice = test, score = 0.5095333333333333
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.6187000000000001 tf.Tensor(356.87405, shape=(), dtype=float32) 100
# slice = key, score = 0.6187000000000001
# np.mean(results), mse, len(results) =  0.6397495826377295 tf.Tensor(356.72064, shape=(), dtype=float32) 599
# slice = train, score = 0.6397495826377295
# np.mean(results), mse, len(results) =  0.5155666666666666 tf.Tensor(328.53674, shape=(), dtype=float32) 300
# slice = test, score = 0.5155666666666666
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.622 tf.Tensor(368.64374, shape=(), dtype=float32) 100
# slice = key, score = 0.622
# np.mean(results), mse, len(results) =  0.6430383973288816 tf.Tensor(367.02875, shape=(), dtype=float32) 599
# slice = train, score = 0.6430383973288816
# np.mean(results), mse, len(results) =  0.5167666666666668 tf.Tensor(335.2425, shape=(), dtype=float32) 300
# slice = test, score = 0.5167666666666668
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.6257 tf.Tensor(384.0097, shape=(), dtype=float32) 100
# slice = key, score = 0.6257
# np.mean(results), mse, len(results) =  0.6465609348914857 tf.Tensor(388.44357, shape=(), dtype=float32) 599
# slice = train, score = 0.6465609348914857
# np.mean(results), mse, len(results) =  0.5187666666666666 tf.Tensor(355.71753, shape=(), dtype=float32) 300
# slice = test, score = 0.5187666666666666
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.6279 tf.Tensor(384.40494, shape=(), dtype=float32) 100
# slice = key, score = 0.6279
# np.mean(results), mse, len(results) =  0.6484140233722872 tf.Tensor(382.9897, shape=(), dtype=float32) 599
# slice = train, score = 0.6484140233722872
# np.mean(results), mse, len(results) =  0.5198333333333334 tf.Tensor(350.13245, shape=(), dtype=float32) 300
# slice = test, score = 0.5198333333333334
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.6317 tf.Tensor(403.35086, shape=(), dtype=float32) 100
# slice = key, score = 0.6317
# np.mean(results), mse, len(results) =  0.6510183639398999 tf.Tensor(403.96222, shape=(), dtype=float32) 599
# slice = train, score = 0.6510183639398999
# np.mean(results), mse, len(results) =  0.5228333333333333 tf.Tensor(368.1801, shape=(), dtype=float32) 300
# slice = test, score = 0.5228333333333333
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.6351 tf.Tensor(424.08105, shape=(), dtype=float32) 100
# slice = key, score = 0.6351
# np.mean(results), mse, len(results) =  0.652237061769616 tf.Tensor(422.26855, shape=(), dtype=float32) 599
# slice = train, score = 0.652237061769616
# np.mean(results), mse, len(results) =  0.5227 tf.Tensor(384.57874, shape=(), dtype=float32) 300
# slice = test, score = 0.5227
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.6347 tf.Tensor(428.0719, shape=(), dtype=float32) 100
# slice = key, score = 0.6347
# np.mean(results), mse, len(results) =  0.65449081803005 tf.Tensor(425.89697, shape=(), dtype=float32) 599
# slice = train, score = 0.65449081803005
# np.mean(results), mse, len(results) =  0.5232333333333333 tf.Tensor(388.61716, shape=(), dtype=float32) 300
# slice = test, score = 0.5232333333333333
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.6394000000000001 tf.Tensor(437.22394, shape=(), dtype=float32) 100
# slice = key, score = 0.6394000000000001
# np.mean(results), mse, len(results) =  0.6559599332220367 tf.Tensor(436.3089, shape=(), dtype=float32) 599
# slice = train, score = 0.6559599332220367
# np.mean(results), mse, len(results) =  0.5250666666666667 tf.Tensor(398.25885, shape=(), dtype=float32) 300
# slice = test, score = 0.5250666666666667
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6400999999999999 tf.Tensor(452.2518, shape=(), dtype=float32) 100
# slice = key, score = 0.6400999999999999
# np.mean(results), mse, len(results) =  0.6595826377295492 tf.Tensor(452.62708, shape=(), dtype=float32) 599
# slice = train, score = 0.6595826377295492
# np.mean(results), mse, len(results) =  0.5291 tf.Tensor(411.9624, shape=(), dtype=float32) 300
# slice = test, score = 0.5291
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.6400000000000001 tf.Tensor(468.8925, shape=(), dtype=float32) 100
# slice = key, score = 0.6400000000000001
# np.mean(results), mse, len(results) =  0.6602337228714524 tf.Tensor(470.36258, shape=(), dtype=float32) 599
# slice = train, score = 0.6602337228714524
# np.mean(results), mse, len(results) =  0.5283666666666667 tf.Tensor(432.42603, shape=(), dtype=float32) 300
# slice = test, score = 0.5283666666666667
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.643 tf.Tensor(478.6226, shape=(), dtype=float32) 100
# slice = key, score = 0.643
# np.mean(results), mse, len(results) =  0.6629215358931553 tf.Tensor(481.13034, shape=(), dtype=float32) 599
# slice = train, score = 0.6629215358931553
# np.mean(results), mse, len(results) =  0.5307666666666667 tf.Tensor(439.77866, shape=(), dtype=float32) 300
# slice = test, score = 0.5307666666666667
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.6463999999999999 tf.Tensor(475.2623, shape=(), dtype=float32) 100
# slice = key, score = 0.6463999999999999
# np.mean(results), mse, len(results) =  0.6635392320534224 tf.Tensor(480.38684, shape=(), dtype=float32) 599
# slice = train, score = 0.6635392320534224
# np.mean(results), mse, len(results) =  0.5334333333333334 tf.Tensor(441.23447, shape=(), dtype=float32) 300
# slice = test, score = 0.5334333333333334
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.6461 tf.Tensor(489.4371, shape=(), dtype=float32) 100
# slice = key, score = 0.6461
# np.mean(results), mse, len(results) =  0.6671452420701168 tf.Tensor(492.07587, shape=(), dtype=float32) 599
# slice = train, score = 0.6671452420701168
# np.mean(results), mse, len(results) =  0.5342666666666667 tf.Tensor(450.96072, shape=(), dtype=float32) 300
# slice = test, score = 0.5342666666666667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [27], in <cell line: 24>()
#       1 N = 100000
#       2 m = CBKnnV0(ctx, fit_kwargs={
#       3     'c': 0,
#       4     'train_matrix': False,
#    (...)
#      21     "learning_rate": 0.0005
#      22 })
# ---> 24 m.fit()
#      25 m.get_score("train"), m.get_score("test")
#
# Input In [6], in CBKnnV0.fit(self, **kwargs)
#     369 if self.p["trainable_items"]:
#     370     weights += [self.trainable_games]
# --> 373 opt.minimize(loss, weights)
#     375 if p["score_verbose"] and (i % p["score_verbose"] == 0):
#     376     print(f"\n=== Iteration {i} ===")
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:544, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     523 """Minimize `loss` by updating `var_list`.
#     524
#     525 This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     541   None
#     542 """
#     543 grads_and_vars = self.compute_gradients(loss, var_list, tape)
# --> 544 self.apply_gradients(grads_and_vars)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1230, in Optimizer.apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1228 if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1229     grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1230 return super().apply_gradients(grads_and_vars, name=name)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:652, in _BaseOptimizer.apply_gradients(self, grads_and_vars, name)
#     650 self._apply_weight_decay(trainable_variables)
#     651 grads_and_vars = list(zip(grads, trainable_variables))
# --> 652 iteration = self._internal_apply_gradients(grads_and_vars)
#     654 # Apply variable constraints after applying gradients.
#     655 for variable in trainable_variables:
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1260, in Optimizer._internal_apply_gradients(self, grads_and_vars)
#    1256 if self._mesh or self._run_with_dtensor:
#    1257     # Skip any usage of strategy logic for DTensor
#    1258     return super()._internal_apply_gradients(grads_and_vars)
# -> 1260 return tf.__internal__.distribute.interim.maybe_merge_call(
#    1261     self._distributed_apply_gradients_fn,
#    1262     self._distribution_strategy,
#    1263     grads_and_vars,
#    1264 )
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1352, in Optimizer._distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1349         return self._update_step(grad, var)
#    1351 for grad, var in grads_and_vars:
# -> 1352     distribution.extended.update(
#    1353         var, apply_grad_to_update_var, args=(grad,), group=False
#    1354     )
#    1356 if self.use_ema:
#    1357     _, var_list = zip(*grads_and_vars)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:2992, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2989   fn = autograph.tf_convert(
#    2990       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2991   with self._container_strategy().scope():
# -> 2992     return self._update(var, fn, args, kwargs, group)
#    2993 else:
#    2994   return self._replica_ctx_update(
#    2995       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4062, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4059 def _update(self, var, fn, args, kwargs, group):
#    4060   # The implementations of _update() and _update_non_slot() are identical
#    4061   # except _update() passes `var` as the first argument to `fn()`.
# -> 4062   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4068, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4064 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4065   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4066   # once that value is used for something.
#    4067   with UpdateContext(colocate_with):
# -> 4068     result = fn(*args, **kwargs)
#    4069     if should_group:
#    4070       return result
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:596, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     594 def wrapper(*args, **kwargs):
#     595   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596     return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1349, in Optimizer._distributed_apply_gradients_fn.<locals>.apply_grad_to_update_var(var, grad)
#    1347     return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1348 else:
# -> 1349     return self._update_step(grad, var)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:241, in _BaseOptimizer._update_step(self, gradient, variable)
#     232 if self._var_key(variable) not in self._index_dict:
#     233     raise KeyError(
#     234         f"The optimizer cannot recognize variable {variable.name}. "
#     235         "This usually means you are trying to call the optimizer to "
#    (...)
#     239         f"`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     240     )
# --> 241 self.update_step(gradient, variable)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/adam.py:174, in Adam.update_step(self, gradient, variable)
#     171 m = self._momentums[self._index_dict[var_key]]
#     172 v = self._velocities[self._index_dict[var_key]]
# --> 174 alpha = lr * tf.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     176 if isinstance(gradient, tf.IndexedSlices):
#     177     # Sparse gradients.
#     178     m.assign_add(-m * (1 - self.beta_1))
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1465, in _OverrideBinaryOperatorHelper.<locals>.binary_op_wrapper(x, y)
#    1460 with ops.name_scope(None, op_name, [x, y]) as name:
#    1461   try:
#    1462     # force_same_dtype=False to preserve existing TF behavior
#    1463     # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1464     #   r_binary_op_wrapper use different force_same_dtype values.
# -> 1465     x, y = maybe_promote_tensors(x, y)
#    1466     return func(x, y, name=name)
#    1467   except (TypeError, ValueError) as e:
#    1468     # Even if dispatching the op failed, the RHS may be a tensor aware
#    1469     # object that can implement the operator with knowledge of itself
#    (...)
#    1472     # original error from the LHS, because it may be more
#    1473     # informative.
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1435, in maybe_promote_tensors(force_same_dtype, *tensors)
#    1432     promoted_tensors.append(
#    1433         ops.convert_to_tensor(tensor, dtype, name="x"))
#    1434   return promoted_tensors
# -> 1435 result_type = np_dtypes._result_type(
#    1436     *[_maybe_get_dtype(x) for x in nest.flatten(tensors)])
#    1437 def _promote_or_cast(x):
#    1438   if isinstance(x, ops.Tensor):
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/numpy_ops/np_dtypes.py:113, in _result_type(*arrays_and_dtypes)
#     111 arrays_and_dtypes = [preprocess_float(x) for x in arrays_and_dtypes]
#     112 dtype = np.result_type(*arrays_and_dtypes)
# --> 113 return dtypes.as_dtype(canonicalize_dtype(dtype))
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/dtypes.py:819, in as_dtype(type_value)
#     787 @tf_export("dtypes.as_dtype", "as_dtype")
#     788 def as_dtype(type_value):
#     789   """Converts the given `type_value` to a `tf.DType`.
#     790
#     791   Inputs can be existing `tf.DType` objects, a [`DataType`
#    (...)
#     817     TypeError: If `type_value` cannot be converted to a `DType`.
#     818   """
# --> 819   if isinstance(type_value, DType):
#     820     if type_value._handle_data is None:  # pylint:disable=protected-access
#     821       return _INTERN_TABLE[type_value.as_datatype_enum]
#
# File ~/anaconda3/lib/python3.9/abc.py:119, in ABCMeta.__instancecheck__(cls, instance)
#     117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
# --> 119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'mse',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": True, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (599, 100)
# self.embed_games.shape =  (8223, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8223)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (599, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.37059999999999993 tf.Tensor(0.007621676759208236, shape=(), dtype=float64) 100
# slice = key, score = 0.37059999999999993
# np.mean(results), mse, len(results) =  0.3972787979966611 tf.Tensor(0.007950330600329696, shape=(), dtype=float64) 599
# slice = train, score = 0.3972787979966611
# np.mean(results), mse, len(results) =  0.36136666666666667 tf.Tensor(0.00790850133890362, shape=(), dtype=float64) 300
# slice = test, score = 0.36136666666666667
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.6762000000000001 tf.Tensor(0.0012336373137285112, shape=(), dtype=float64) 100
# slice = key, score = 0.6762000000000001
# np.mean(results), mse, len(results) =  0.7336727879799667 tf.Tensor(0.0008737123232494297, shape=(), dtype=float64) 599
# slice = train, score = 0.7336727879799667
# np.mean(results), mse, len(results) =  0.6596 tf.Tensor(0.0012948433630632836, shape=(), dtype=float64) 300
# slice = test, score = 0.6596
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.6782 tf.Tensor(0.0012127813039755602, shape=(), dtype=float64) 100
# slice = key, score = 0.6782
# np.mean(results), mse, len(results) =  0.734924874791319 tf.Tensor(0.0008682729366144502, shape=(), dtype=float64) 599
# slice = train, score = 0.734924874791319
# np.mean(results), mse, len(results) =  0.6603666666666667 tf.Tensor(0.0012873882939553704, shape=(), dtype=float64) 300
# slice = test, score = 0.6603666666666667
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.6822999999999999 tf.Tensor(0.0011916815409887917, shape=(), dtype=float64) 100
# slice = key, score = 0.6822999999999999
# np.mean(results), mse, len(results) =  0.7359098497495826 tf.Tensor(0.0008607487056304161, shape=(), dtype=float64) 599
# slice = train, score = 0.7359098497495826
# np.mean(results), mse, len(results) =  0.6609 tf.Tensor(0.0012866075755197423, shape=(), dtype=float64) 300
# slice = test, score = 0.6609
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.6864999999999999 tf.Tensor(0.0011665899499842737, shape=(), dtype=float64) 100
# slice = key, score = 0.6864999999999999
# np.mean(results), mse, len(results) =  0.7381135225375626 tf.Tensor(0.0008464687399996908, shape=(), dtype=float64) 599
# slice = train, score = 0.7381135225375626
# np.mean(results), mse, len(results) =  0.6608666666666666 tf.Tensor(0.0012923804714286842, shape=(), dtype=float64) 300
# slice = test, score = 0.6608666666666666
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6879999999999998 tf.Tensor(0.0011451450333850985, shape=(), dtype=float64) 100
# slice = key, score = 0.6879999999999998
# np.mean(results), mse, len(results) =  0.7413522537562606 tf.Tensor(0.0008320512191695471, shape=(), dtype=float64) 599
# slice = train, score = 0.7413522537562606
# np.mean(results), mse, len(results) =  0.66 tf.Tensor(0.0012994710374732833, shape=(), dtype=float64) 300
# slice = test, score = 0.66
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6914999999999999 tf.Tensor(0.0011305087745392315, shape=(), dtype=float64) 100
# slice = key, score = 0.6914999999999999
# np.mean(results), mse, len(results) =  0.7424707846410684 tf.Tensor(0.0008219086554876259, shape=(), dtype=float64) 599
# slice = train, score = 0.7424707846410684
# np.mean(results), mse, len(results) =  0.6599666666666667 tf.Tensor(0.0013114908194623678, shape=(), dtype=float64) 300
# slice = test, score = 0.6599666666666667
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6925 tf.Tensor(0.0011209929931438507, shape=(), dtype=float64) 100
# slice = key, score = 0.6925
# np.mean(results), mse, len(results) =  0.7442237061769615 tf.Tensor(0.0008120799293152668, shape=(), dtype=float64) 599
# slice = train, score = 0.7442237061769615
# np.mean(results), mse, len(results) =  0.6594333333333334 tf.Tensor(0.0013186712151553378, shape=(), dtype=float64) 300
# slice = test, score = 0.6594333333333334
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 24>()
#       1 N = 100000
#       2 m = CBKnnV0(ctx, fit_kwargs={
#       3     'c': 0,
#       4     'train_matrix': True,
#    (...)
#      21     "learning_rate": 0.0005
#      22 })
# ---> 24 m.fit()
#      25 m.get_score("train"), m.get_score("test")
#
# Input In [6], in CBKnnV0.fit(self, **kwargs)
#     369 if self.p["trainable_items"]:
#     370     weights += [self.trainable_games]
# --> 373 opt.minimize(loss, weights)
#     375 if p["score_verbose"] and (i % p["score_verbose"] == 0):
#     376     print(f"\n=== Iteration {i} ===")
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:544, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     523 """Minimize `loss` by updating `var_list`.
#     524
#     525 This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     541   None
#     542 """
#     543 grads_and_vars = self.compute_gradients(loss, var_list, tape)
# --> 544 self.apply_gradients(grads_and_vars)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1230, in Optimizer.apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1228 if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1229     grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1230 return super().apply_gradients(grads_and_vars, name=name)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:652, in _BaseOptimizer.apply_gradients(self, grads_and_vars, name)
#     650 self._apply_weight_decay(trainable_variables)
#     651 grads_and_vars = list(zip(grads, trainable_variables))
# --> 652 iteration = self._internal_apply_gradients(grads_and_vars)
#     654 # Apply variable constraints after applying gradients.
#     655 for variable in trainable_variables:
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1260, in Optimizer._internal_apply_gradients(self, grads_and_vars)
#    1256 if self._mesh or self._run_with_dtensor:
#    1257     # Skip any usage of strategy logic for DTensor
#    1258     return super()._internal_apply_gradients(grads_and_vars)
# -> 1260 return tf.__internal__.distribute.interim.maybe_merge_call(
#    1261     self._distributed_apply_gradients_fn,
#    1262     self._distribution_strategy,
#    1263     grads_and_vars,
#    1264 )
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1352, in Optimizer._distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1349         return self._update_step(grad, var)
#    1351 for grad, var in grads_and_vars:
# -> 1352     distribution.extended.update(
#    1353         var, apply_grad_to_update_var, args=(grad,), group=False
#    1354     )
#    1356 if self.use_ema:
#    1357     _, var_list = zip(*grads_and_vars)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:2992, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2989   fn = autograph.tf_convert(
#    2990       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2991   with self._container_strategy().scope():
# -> 2992     return self._update(var, fn, args, kwargs, group)
#    2993 else:
#    2994   return self._replica_ctx_update(
#    2995       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4062, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4059 def _update(self, var, fn, args, kwargs, group):
#    4060   # The implementations of _update() and _update_non_slot() are identical
#    4061   # except _update() passes `var` as the first argument to `fn()`.
# -> 4062   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4068, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4064 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4065   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4066   # once that value is used for something.
#    4067   with UpdateContext(colocate_with):
# -> 4068     result = fn(*args, **kwargs)
#    4069     if should_group:
#    4070       return result
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:596, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     594 def wrapper(*args, **kwargs):
#     595   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596     return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:1349, in Optimizer._distributed_apply_gradients_fn.<locals>.apply_grad_to_update_var(var, grad)
#    1347     return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1348 else:
# -> 1349     return self._update_step(grad, var)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/optimizer.py:241, in _BaseOptimizer._update_step(self, gradient, variable)
#     232 if self._var_key(variable) not in self._index_dict:
#     233     raise KeyError(
#     234         f"The optimizer cannot recognize variable {variable.name}. "
#     235         "This usually means you are trying to call the optimizer to "
#    (...)
#     239         f"`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     240     )
# --> 241 self.update_step(gradient, variable)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/optimizers/adam.py:204, in Adam.update_step(self, gradient, variable)
#     202     v_hat.assign(tf.maximum(v_hat, v))
#     203     v = v_hat
# --> 204 variable.assign_sub((m * alpha) / (tf.sqrt(v) + self.epsilon))
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/variables.py:1011, in Variable._OverloadOperator.<locals>._run_op(a, *args, **kwargs)
#    1009 def _run_op(a, *args, **kwargs):
#    1010   # pylint: disable=protected-access
# -> 1011   return tensor_oper(a.value(), *args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1465, in _OverrideBinaryOperatorHelper.<locals>.binary_op_wrapper(x, y)
#    1460 with ops.name_scope(None, op_name, [x, y]) as name:
#    1461   try:
#    1462     # force_same_dtype=False to preserve existing TF behavior
#    1463     # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1464     #   r_binary_op_wrapper use different force_same_dtype values.
# -> 1465     x, y = maybe_promote_tensors(x, y)
#    1466     return func(x, y, name=name)
#    1467   except (TypeError, ValueError) as e:
#    1468     # Even if dispatching the op failed, the RHS may be a tensor aware
#    1469     # object that can implement the operator with knowledge of itself
#    (...)
#    1472     # original error from the LHS, because it may be more
#    1473     # informative.
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1436, in maybe_promote_tensors(force_same_dtype, *tensors)
#    1432     promoted_tensors.append(
#    1433         ops.convert_to_tensor(tensor, dtype, name="x"))
#    1434   return promoted_tensors
#    1435 result_type = np_dtypes._result_type(
# -> 1436     *[_maybe_get_dtype(x) for x in nest.flatten(tensors)])
#    1437 def _promote_or_cast(x):
#    1438   if isinstance(x, ops.Tensor):
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1436, in <listcomp>(.0)
#    1432     promoted_tensors.append(
#    1433         ops.convert_to_tensor(tensor, dtype, name="x"))
#    1434   return promoted_tensors
#    1435 result_type = np_dtypes._result_type(
# -> 1436     *[_maybe_get_dtype(x) for x in nest.flatten(tensors)])
#    1437 def _promote_or_cast(x):
#    1438   if isinstance(x, ops.Tensor):
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1390, in _maybe_get_dtype(x)
#    1387 """Returns a numpy type if available from x. Skips if x is numpy.ndarray."""
#    1388 # Don't put np.ndarray in this list, because np.result_type looks at the
#    1389 # value (not just dtype) of np.ndarray to decide the result type.
# -> 1390 if isinstance(x, numbers.Real):
#    1391   return x
#    1392 if isinstance(x, ops.Tensor):
#
# KeyboardInterrupt:

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': False,
    'train_popbias': False, 'train_bias': False,
    'verbose': False, 'loss': 'mse',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": False, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (599, 100)
# self.embed_games.shape =  (8223, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 8223)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (599, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.3556 tf.Tensor(0.0075319774625899494, shape=(), dtype=float64) 100
# slice = key, score = 0.3556
# np.mean(results), mse, len(results) =  0.39901502504173625 tf.Tensor(0.00756115258105171, shape=(), dtype=float64) 599
# slice = train, score = 0.39901502504173625
# np.mean(results), mse, len(results) =  0.3638666666666667 tf.Tensor(0.007621635033128592, shape=(), dtype=float64) 300
# slice = test, score = 0.3638666666666667
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.6676000000000001 tf.Tensor(0.0013147807806401335, shape=(), dtype=float64) 100
# slice = key, score = 0.6676000000000001
# np.mean(results), mse, len(results) =  0.7356427378964941 tf.Tensor(0.0008680850358187107, shape=(), dtype=float64) 599
# slice = train, score = 0.7356427378964941
# np.mean(results), mse, len(results) =  0.6583 tf.Tensor(0.0013039524858837594, shape=(), dtype=float64) 300
# slice = test, score = 0.6583
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.6694000000000001 tf.Tensor(0.0013093585825996318, shape=(), dtype=float64) 100
# slice = key, score = 0.6694000000000001
# np.mean(results), mse, len(results) =  0.7369949916527546 tf.Tensor(0.0008609424932014478, shape=(), dtype=float64) 599
# slice = train, score = 0.7369949916527546
# np.mean(results), mse, len(results) =  0.6594333333333333 tf.Tensor(0.0012977979951166194, shape=(), dtype=float64) 300
# slice = test, score = 0.6594333333333333
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.6703 tf.Tensor(0.0013118568813329794, shape=(), dtype=float64) 100
# slice = key, score = 0.6703
# np.mean(results), mse, len(results) =  0.7377796327212021 tf.Tensor(0.0008511665975715391, shape=(), dtype=float64) 599
# slice = train, score = 0.7377796327212021
# np.mean(results), mse, len(results) =  0.6591666666666667 tf.Tensor(0.0013004850812534973, shape=(), dtype=float64) 300
# slice = test, score = 0.6591666666666667
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.6709999999999998 tf.Tensor(0.0013141234691360676, shape=(), dtype=float64) 100
# slice = key, score = 0.6709999999999998
# np.mean(results), mse, len(results) =  0.7412854757929883 tf.Tensor(0.0008304216546640297, shape=(), dtype=float64) 599
# slice = train, score = 0.7412854757929883
# np.mean(results), mse, len(results) =  0.6592666666666667 tf.Tensor(0.0013077691818181158, shape=(), dtype=float64) 300
# slice = test, score = 0.6592666666666667
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6698000000000001 tf.Tensor(0.0013259215711594124, shape=(), dtype=float64) 100
# slice = key, score = 0.6698000000000001
# np.mean(results), mse, len(results) =  0.7445409015025042 tf.Tensor(0.0008142161787896833, shape=(), dtype=float64) 599
# slice = train, score = 0.7445409015025042
# np.mean(results), mse, len(results) =  0.6570666666666667 tf.Tensor(0.0013189963491528362, shape=(), dtype=float64) 300
# slice = test, score = 0.6570666666666667
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6678000000000001 tf.Tensor(0.001339599792376332, shape=(), dtype=float64) 100
# slice = key, score = 0.6678000000000001
# np.mean(results), mse, len(results) =  0.7465275459098497 tf.Tensor(0.0008026596416590807, shape=(), dtype=float64) 599
# slice = train, score = 0.7465275459098497
# np.mean(results), mse, len(results) =  0.656 tf.Tensor(0.0013304846335838135, shape=(), dtype=float64) 300
# slice = test, score = 0.656
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6664 tf.Tensor(0.001351057069398929, shape=(), dtype=float64) 100
# slice = key, score = 0.6664
# np.mean(results), mse, len(results) =  0.7480801335559266 tf.Tensor(0.0007937842414656044, shape=(), dtype=float64) 599
# slice = train, score = 0.7480801335559266
# np.mean(results), mse, len(results) =  0.6536666666666666 tf.Tensor(0.0013439288455707916, shape=(), dtype=float64) 300
# slice = test, score = 0.6536666666666666
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.6649 tf.Tensor(0.001359109180166085, shape=(), dtype=float64) 100
# slice = key, score = 0.6649
# np.mean(results), mse, len(results) =  0.7490317195325543 tf.Tensor(0.0007841106681765061, shape=(), dtype=float64) 599
# slice = train, score = 0.7490317195325543
# np.mean(results), mse, len(results) =  0.6541333333333333 tf.Tensor(0.0013527321472450928, shape=(), dtype=float64) 300
# slice = test, score = 0.6541333333333333
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.6653000000000001 tf.Tensor(0.0013700772729996929, shape=(), dtype=float64) 100
# slice = key, score = 0.6653000000000001
# np.mean(results), mse, len(results) =  0.7497328881469115 tf.Tensor(0.0007789608707980134, shape=(), dtype=float64) 599
# slice = train, score = 0.7497328881469115
# np.mean(results), mse, len(results) =  0.6532 tf.Tensor(0.0013648524254228592, shape=(), dtype=float64) 300
# slice = test, score = 0.6532
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.6664 tf.Tensor(0.0013772809007122533, shape=(), dtype=float64) 100
# slice = key, score = 0.6664
# np.mean(results), mse, len(results) =  0.7497495826377296 tf.Tensor(0.0007763410155929052, shape=(), dtype=float64) 599
# slice = train, score = 0.7497495826377296
# np.mean(results), mse, len(results) =  0.6519666666666667 tf.Tensor(0.001373908922119374, shape=(), dtype=float64) 300
# slice = test, score = 0.6519666666666667
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.6625000000000001 tf.Tensor(0.0013857217518525424, shape=(), dtype=float64) 100
# slice = key, score = 0.6625000000000001
# np.mean(results), mse, len(results) =  0.75110183639399 tf.Tensor(0.0007692235068966688, shape=(), dtype=float64) 599
# slice = train, score = 0.75110183639399
# np.mean(results), mse, len(results) =  0.6499666666666667 tf.Tensor(0.0013850545225566832, shape=(), dtype=float64) 300
# slice = test, score = 0.6499666666666667
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.6648000000000001 tf.Tensor(0.0013914854422818232, shape=(), dtype=float64) 100
# slice = key, score = 0.6648000000000001
# np.mean(results), mse, len(results) =  0.7517696160267111 tf.Tensor(0.0007642349543832757, shape=(), dtype=float64) 599
# slice = train, score = 0.7517696160267111
# np.mean(results), mse, len(results) =  0.6496999999999999 tf.Tensor(0.0013920418316798956, shape=(), dtype=float64) 300
# slice = test, score = 0.6496999999999999
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.6638000000000001 tf.Tensor(0.001398134321026797, shape=(), dtype=float64) 100
# slice = key, score = 0.6638000000000001
# np.mean(results), mse, len(results) =  0.7522871452420701 tf.Tensor(0.0007632482720698632, shape=(), dtype=float64) 599
# slice = train, score = 0.7522871452420701
# np.mean(results), mse, len(results) =  0.6489999999999999 tf.Tensor(0.001401725702734681, shape=(), dtype=float64) 300
# slice = test, score = 0.6489999999999999
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.6637000000000001 tf.Tensor(0.0014070734241588367, shape=(), dtype=float64) 100
# slice = key, score = 0.6637000000000001
# np.mean(results), mse, len(results) =  0.7522537562604341 tf.Tensor(0.0007631315941961127, shape=(), dtype=float64) 599
# slice = train, score = 0.7522537562604341
# np.mean(results), mse, len(results) =  0.6492 tf.Tensor(0.001405765238557008, shape=(), dtype=float64) 300
# slice = test, score = 0.6492
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6611000000000001 tf.Tensor(0.0014119640956255265, shape=(), dtype=float64) 100
# slice = key, score = 0.6611000000000001
# np.mean(results), mse, len(results) =  0.753355592654424 tf.Tensor(0.0007564011647716655, shape=(), dtype=float64) 599
# slice = train, score = 0.753355592654424
# np.mean(results), mse, len(results) =  0.6483666666666666 tf.Tensor(0.0014103564610013438, shape=(), dtype=float64) 300
# slice = test, score = 0.6483666666666666
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6615000000000002 tf.Tensor(0.0014155202486005503, shape=(), dtype=float64) 100
# slice = key, score = 0.6615000000000002
# np.mean(results), mse, len(results) =  0.753272120200334 tf.Tensor(0.0007584964107236591, shape=(), dtype=float64) 599
# slice = train, score = 0.753272120200334
# np.mean(results), mse, len(results) =  0.6478666666666666 tf.Tensor(0.0014175884974529178, shape=(), dtype=float64) 300
# slice = test, score = 0.6478666666666666
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6607000000000001 tf.Tensor(0.0014214904289952964, shape=(), dtype=float64) 100
# slice = key, score = 0.6607000000000001
# np.mean(results), mse, len(results) =  0.7542904841402337 tf.Tensor(0.000750484499375416, shape=(), dtype=float64) 599
# slice = train, score = 0.7542904841402337
# np.mean(results), mse, len(results) =  0.6473 tf.Tensor(0.001424100624033018, shape=(), dtype=float64) 300
# slice = test, score = 0.6473
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6597 tf.Tensor(0.0014292752759138647, shape=(), dtype=float64) 100
# slice = key, score = 0.6597
# np.mean(results), mse, len(results) =  0.75440734557596 tf.Tensor(0.0007511449403255278, shape=(), dtype=float64) 599
# slice = train, score = 0.75440734557596
# np.mean(results), mse, len(results) =  0.6477666666666666 tf.Tensor(0.001430970306806647, shape=(), dtype=float64) 300
# slice = test, score = 0.6477666666666666
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.6574 tf.Tensor(0.0014398972804191793, shape=(), dtype=float64) 100
# slice = key, score = 0.6574
# np.mean(results), mse, len(results) =  0.7552086811352254 tf.Tensor(0.0007501262417537761, shape=(), dtype=float64) 599
# slice = train, score = 0.7552086811352254
# np.mean(results), mse, len(results) =  0.6465666666666666 tf.Tensor(0.0014397380849682198, shape=(), dtype=float64) 300
# slice = test, score = 0.6465666666666666
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.6568 tf.Tensor(0.0014394834251633716, shape=(), dtype=float64) 100
# slice = key, score = 0.6568
# np.mean(results), mse, len(results) =  0.7553589315525876 tf.Tensor(0.0007438439609550397, shape=(), dtype=float64) 599
# slice = train, score = 0.7553589315525876
# np.mean(results), mse, len(results) =  0.6461333333333333 tf.Tensor(0.001444094773529841, shape=(), dtype=float64) 300
# slice = test, score = 0.6461333333333333
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.6571000000000001 tf.Tensor(0.0014448526174036906, shape=(), dtype=float64) 100
# slice = key, score = 0.6571000000000001
# np.mean(results), mse, len(results) =  0.7570116861435727 tf.Tensor(0.0007401624651801, shape=(), dtype=float64) 599
# slice = train, score = 0.7570116861435727
# np.mean(results), mse, len(results) =  0.6456000000000001 tf.Tensor(0.0014469660836066715, shape=(), dtype=float64) 300
# slice = test, score = 0.6456000000000001
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.6571000000000002 tf.Tensor(0.0014455704420031554, shape=(), dtype=float64) 100
# slice = key, score = 0.6571000000000002
# np.mean(results), mse, len(results) =  0.7564941569282136 tf.Tensor(0.0007399058780251422, shape=(), dtype=float64) 599
# slice = train, score = 0.7564941569282136
# np.mean(results), mse, len(results) =  0.6457666666666667 tf.Tensor(0.0014503317609576296, shape=(), dtype=float64) 300
# slice = test, score = 0.6457666666666667
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.6548 tf.Tensor(0.001456707951441112, shape=(), dtype=float64) 100
# slice = key, score = 0.6548
# np.mean(results), mse, len(results) =  0.7575959933222037 tf.Tensor(0.0007366461902181627, shape=(), dtype=float64) 599
# slice = train, score = 0.7575959933222037
# np.mean(results), mse, len(results) =  0.6450666666666667 tf.Tensor(0.001461654979185748, shape=(), dtype=float64) 300
# slice = test, score = 0.6450666666666667
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.6555 tf.Tensor(0.0014642852173092193, shape=(), dtype=float64) 100
# slice = key, score = 0.6555
# np.mean(results), mse, len(results) =  0.7576460767946578 tf.Tensor(0.0007372654981624532, shape=(), dtype=float64) 599
# slice = train, score = 0.7576460767946578
# np.mean(results), mse, len(results) =  0.6440666666666667 tf.Tensor(0.0014681381983343194, shape=(), dtype=float64) 300
# slice = test, score = 0.6440666666666667
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.6553 tf.Tensor(0.00146125100543822, shape=(), dtype=float64) 100
# slice = key, score = 0.6553
# np.mean(results), mse, len(results) =  0.7580968280467446 tf.Tensor(0.000733473563509564, shape=(), dtype=float64) 599
# slice = train, score = 0.7580968280467446
# np.mean(results), mse, len(results) =  0.6448666666666667 tf.Tensor(0.0014640569631310229, shape=(), dtype=float64) 300
# slice = test, score = 0.6448666666666667
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.653 tf.Tensor(0.0014619168579745386, shape=(), dtype=float64) 100
# slice = key, score = 0.653
# np.mean(results), mse, len(results) =  0.7589816360601002 tf.Tensor(0.0007321596815040831, shape=(), dtype=float64) 599
# slice = train, score = 0.7589816360601002
# np.mean(results), mse, len(results) =  0.6444666666666666 tf.Tensor(0.0014670347029329582, shape=(), dtype=float64) 300
# slice = test, score = 0.6444666666666666
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6543000000000001 tf.Tensor(0.0014693148774855003, shape=(), dtype=float64) 100
# slice = key, score = 0.6543000000000001
# np.mean(results), mse, len(results) =  0.7593656093489148 tf.Tensor(0.0007267822465972029, shape=(), dtype=float64) 599
# slice = train, score = 0.7593656093489148
# np.mean(results), mse, len(results) =  0.6445333333333334 tf.Tensor(0.0014743478114661295, shape=(), dtype=float64) 300
# slice = test, score = 0.6445333333333334
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.6531 tf.Tensor(0.001476738822041714, shape=(), dtype=float64) 100
# slice = key, score = 0.6531
# np.mean(results), mse, len(results) =  0.759432387312187 tf.Tensor(0.0007257944510665825, shape=(), dtype=float64) 599
# slice = train, score = 0.759432387312187
# np.mean(results), mse, len(results) =  0.6437333333333334 tf.Tensor(0.0014833845241661748, shape=(), dtype=float64) 300
# slice = test, score = 0.6437333333333334
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.6528 tf.Tensor(0.0014791962160373205, shape=(), dtype=float64) 100
# slice = key, score = 0.6528
# np.mean(results), mse, len(results) =  0.760066777963272 tf.Tensor(0.0007230119510102297, shape=(), dtype=float64) 599
# slice = train, score = 0.760066777963272
# np.mean(results), mse, len(results) =  0.6432333333333333 tf.Tensor(0.001488219836709999, shape=(), dtype=float64) 300
# slice = test, score = 0.6432333333333333
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.6542 tf.Tensor(0.0014774573749064533, shape=(), dtype=float64) 100
# slice = key, score = 0.6542
# np.mean(results), mse, len(results) =  0.7598330550918196 tf.Tensor(0.0007262633153901054, shape=(), dtype=float64) 599
# slice = train, score = 0.7598330550918196
# np.mean(results), mse, len(results) =  0.6425333333333334 tf.Tensor(0.0014870632367671884, shape=(), dtype=float64) 300
# slice = test, score = 0.6425333333333334
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.6508999999999999 tf.Tensor(0.0014828599561883856, shape=(), dtype=float64) 100
# slice = key, score = 0.6508999999999999
# np.mean(results), mse, len(results) =  0.7597495826377296 tf.Tensor(0.0007239205869900959, shape=(), dtype=float64) 599
# slice = train, score = 0.7597495826377296
# np.mean(results), mse, len(results) =  0.6410666666666667 tf.Tensor(0.0014950946545596421, shape=(), dtype=float64) 300
# slice = test, score = 0.6410666666666667
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.6521000000000001 tf.Tensor(0.0014915963670002763, shape=(), dtype=float64) 100
# slice = key, score = 0.6521000000000001
# np.mean(results), mse, len(results) =  0.7612520868113523 tf.Tensor(0.0007166596491468142, shape=(), dtype=float64) 599
# slice = train, score = 0.7612520868113523
# np.mean(results), mse, len(results) =  0.6408666666666666 tf.Tensor(0.0015051487036408168, shape=(), dtype=float64) 300
# slice = test, score = 0.6408666666666666
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.6515000000000002 tf.Tensor(0.0014985936672709905, shape=(), dtype=float64) 100
# slice = key, score = 0.6515000000000002
# np.mean(results), mse, len(results) =  0.7617529215358931 tf.Tensor(0.0007154478328160337, shape=(), dtype=float64) 599
# slice = train, score = 0.7617529215358931
# np.mean(results), mse, len(results) =  0.6399000000000001 tf.Tensor(0.001511943741090673, shape=(), dtype=float64) 300
# slice = test, score = 0.6399000000000001
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.6515 tf.Tensor(0.0015003713359317123, shape=(), dtype=float64) 100
# slice = key, score = 0.6515
# np.mean(results), mse, len(results) =  0.7619031719532554 tf.Tensor(0.0007124800150251809, shape=(), dtype=float64) 599
# slice = train, score = 0.7619031719532554
# np.mean(results), mse, len(results) =  0.6396 tf.Tensor(0.0015126232705544391, shape=(), dtype=float64) 300
# slice = test, score = 0.6396
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.6501 tf.Tensor(0.0014967752808317367, shape=(), dtype=float64) 100
# slice = key, score = 0.6501
# np.mean(results), mse, len(results) =  0.7625542570951586 tf.Tensor(0.0007092707683464259, shape=(), dtype=float64) 599
# slice = train, score = 0.7625542570951586
# np.mean(results), mse, len(results) =  0.6407333333333334 tf.Tensor(0.0015077979723775521, shape=(), dtype=float64) 300
# slice = test, score = 0.6407333333333334
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.6496 tf.Tensor(0.0015072358683989573, shape=(), dtype=float64) 100
# slice = key, score = 0.6496
# np.mean(results), mse, len(results) =  0.76330550918197 tf.Tensor(0.0007072476773218307, shape=(), dtype=float64) 599
# slice = train, score = 0.76330550918197
# np.mean(results), mse, len(results) =  0.6394666666666666 tf.Tensor(0.0015198566750453263, shape=(), dtype=float64) 300
# slice = test, score = 0.6394666666666666
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.65 tf.Tensor(0.0015212881401862777, shape=(), dtype=float64) 100
# slice = key, score = 0.65
# np.mean(results), mse, len(results) =  0.7638063439065108 tf.Tensor(0.0007061190092293626, shape=(), dtype=float64) 599
# slice = train, score = 0.7638063439065108
# np.mean(results), mse, len(results) =  0.6393333333333334 tf.Tensor(0.0015305984746444294, shape=(), dtype=float64) 300
# slice = test, score = 0.6393333333333334
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.649 tf.Tensor(0.0015204902612493503, shape=(), dtype=float64) 100
# slice = key, score = 0.649
# np.mean(results), mse, len(results) =  0.7648414023372286 tf.Tensor(0.0007037350063911914, shape=(), dtype=float64) 599
# slice = train, score = 0.7648414023372286
# np.mean(results), mse, len(results) =  0.6387 tf.Tensor(0.0015345506670688752, shape=(), dtype=float64) 300
# slice = test, score = 0.6387
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.6474 tf.Tensor(0.0015267566203051957, shape=(), dtype=float64) 100
# slice = key, score = 0.6474
# np.mean(results), mse, len(results) =  0.7644240400667779 tf.Tensor(0.0007007990435384775, shape=(), dtype=float64) 599
# slice = train, score = 0.7644240400667779
# np.mean(results), mse, len(results) =  0.6379333333333334 tf.Tensor(0.001541140897448899, shape=(), dtype=float64) 300
# slice = test, score = 0.6379333333333334
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.6470999999999999 tf.Tensor(0.001532252260880439, shape=(), dtype=float64) 100
# slice = key, score = 0.6470999999999999
# np.mean(results), mse, len(results) =  0.7648580968280467 tf.Tensor(0.000699366924047355, shape=(), dtype=float64) 599
# slice = train, score = 0.7648580968280467
# np.mean(results), mse, len(results) =  0.6375000000000001 tf.Tensor(0.001547004799913995, shape=(), dtype=float64) 300
# slice = test, score = 0.6375000000000001
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.6478 tf.Tensor(0.0015305238512386696, shape=(), dtype=float64) 100
# slice = key, score = 0.6478
# np.mean(results), mse, len(results) =  0.7649081803005009 tf.Tensor(0.0006992013126691008, shape=(), dtype=float64) 599
# slice = train, score = 0.7649081803005009
# np.mean(results), mse, len(results) =  0.6370666666666667 tf.Tensor(0.0015436652600280903, shape=(), dtype=float64) 300
# slice = test, score = 0.6370666666666667
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.6457 tf.Tensor(0.0015406563186442575, shape=(), dtype=float64) 100
# slice = key, score = 0.6457
# np.mean(results), mse, len(results) =  0.7653589315525877 tf.Tensor(0.0006992077378845643, shape=(), dtype=float64) 599
# slice = train, score = 0.7653589315525877
# np.mean(results), mse, len(results) =  0.6361666666666667 tf.Tensor(0.0015572076765403115, shape=(), dtype=float64) 300
# slice = test, score = 0.6361666666666667
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.6445000000000001 tf.Tensor(0.0015523507636060717, shape=(), dtype=float64) 100
# slice = key, score = 0.6445000000000001
# np.mean(results), mse, len(results) =  0.7657429048414024 tf.Tensor(0.0006953429005571932, shape=(), dtype=float64) 599
# slice = train, score = 0.7657429048414024
# np.mean(results), mse, len(results) =  0.6367666666666667 tf.Tensor(0.0015621889549211326, shape=(), dtype=float64) 300
# slice = test, score = 0.6367666666666667
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.6467999999999999 tf.Tensor(0.0015443986636964604, shape=(), dtype=float64) 100
# slice = key, score = 0.6467999999999999
# np.mean(results), mse, len(results) =  0.7657429048414024 tf.Tensor(0.0006946515383573295, shape=(), dtype=float64) 599
# slice = train, score = 0.7657429048414024
# np.mean(results), mse, len(results) =  0.6356999999999999 tf.Tensor(0.0015638864844083292, shape=(), dtype=float64) 300
# slice = test, score = 0.6356999999999999
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.6463 tf.Tensor(0.0015539920149556484, shape=(), dtype=float64) 100
# slice = key, score = 0.6463
# np.mean(results), mse, len(results) =  0.7671285475792988 tf.Tensor(0.0006906437032978644, shape=(), dtype=float64) 599
# slice = train, score = 0.7671285475792988
# np.mean(results), mse, len(results) =  0.6355000000000001 tf.Tensor(0.0015732898872132162, shape=(), dtype=float64) 300
# slice = test, score = 0.6355000000000001
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.6467999999999999 tf.Tensor(0.0015599464577781298, shape=(), dtype=float64) 100
# slice = key, score = 0.6467999999999999
# np.mean(results), mse, len(results) =  0.7665108514190317 tf.Tensor(0.0006888952314569694, shape=(), dtype=float64) 599
# slice = train, score = 0.7665108514190317
# np.mean(results), mse, len(results) =  0.6356666666666666 tf.Tensor(0.0015770322889940755, shape=(), dtype=float64) 300
# slice = test, score = 0.6356666666666666
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.6454 tf.Tensor(0.0015566815527849282, shape=(), dtype=float64) 100
# slice = key, score = 0.6454
# np.mean(results), mse, len(results) =  0.767779632721202 tf.Tensor(0.0006868035182795379, shape=(), dtype=float64) 599
# slice = train, score = 0.767779632721202
# np.mean(results), mse, len(results) =  0.6355000000000001 tf.Tensor(0.0015716272309728527, shape=(), dtype=float64) 300
# slice = test, score = 0.6355000000000001
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.6442 tf.Tensor(0.0015683130042062818, shape=(), dtype=float64) 100
# slice = key, score = 0.6442
# np.mean(results), mse, len(results) =  0.7676627712854758 tf.Tensor(0.0006879414917415267, shape=(), dtype=float64) 599
# slice = train, score = 0.7676627712854758
# np.mean(results), mse, len(results) =  0.6341 tf.Tensor(0.001584966905196303, shape=(), dtype=float64) 300
# slice = test, score = 0.6341
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.6451 tf.Tensor(0.001576045005417676, shape=(), dtype=float64) 100
# slice = key, score = 0.6451
# np.mean(results), mse, len(results) =  0.7680467445742905 tf.Tensor(0.0006872578984278545, shape=(), dtype=float64) 599
# slice = train, score = 0.7680467445742905
# np.mean(results), mse, len(results) =  0.6345333333333334 tf.Tensor(0.0015871335947070784, shape=(), dtype=float64) 300
# slice = test, score = 0.6345333333333334
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.6446999999999999 tf.Tensor(0.0015711659011922105, shape=(), dtype=float64) 100
# slice = key, score = 0.6446999999999999
# np.mean(results), mse, len(results) =  0.7678631051752922 tf.Tensor(0.0006880247014219082, shape=(), dtype=float64) 599
# slice = train, score = 0.7678631051752922
# np.mean(results), mse, len(results) =  0.6341666666666667 tf.Tensor(0.0015904042130781052, shape=(), dtype=float64) 300
# slice = test, score = 0.6341666666666667
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.6446999999999999 tf.Tensor(0.001588736377822469, shape=(), dtype=float64) 100
# slice = key, score = 0.6446999999999999
# np.mean(results), mse, len(results) =  0.7687145242070117 tf.Tensor(0.0006903591092789119, shape=(), dtype=float64) 599
# slice = train, score = 0.7687145242070117
# np.mean(results), mse, len(results) =  0.6325999999999999 tf.Tensor(0.0016051984160958747, shape=(), dtype=float64) 300
# slice = test, score = 0.6325999999999999
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.6428 tf.Tensor(0.0015904054673823843, shape=(), dtype=float64) 100
# slice = key, score = 0.6428
# np.mean(results), mse, len(results) =  0.7692320534223707 tf.Tensor(0.0006803552286472921, shape=(), dtype=float64) 599
# slice = train, score = 0.7692320534223707
# np.mean(results), mse, len(results) =  0.6321666666666667 tf.Tensor(0.0016104670940645226, shape=(), dtype=float64) 300
# slice = test, score = 0.6321666666666667
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.6415000000000001 tf.Tensor(0.0015944552185328004, shape=(), dtype=float64) 100
# slice = key, score = 0.6415000000000001
# np.mean(results), mse, len(results) =  0.7693155258764608 tf.Tensor(0.0006803236528284308, shape=(), dtype=float64) 599
# slice = train, score = 0.7693155258764608
# np.mean(results), mse, len(results) =  0.6329 tf.Tensor(0.0016132549371968322, shape=(), dtype=float64) 300
# slice = test, score = 0.6329
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.6401 tf.Tensor(0.0015993664859238262, shape=(), dtype=float64) 100
# slice = key, score = 0.6401
# np.mean(results), mse, len(results) =  0.7695826377295493 tf.Tensor(0.0006780178669484793, shape=(), dtype=float64) 599
# slice = train, score = 0.7695826377295493
# np.mean(results), mse, len(results) =  0.6316 tf.Tensor(0.0016174219524918256, shape=(), dtype=float64) 300
# slice = test, score = 0.6316
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.6412 tf.Tensor(0.0016073474830271058, shape=(), dtype=float64) 100
# slice = key, score = 0.6412
# np.mean(results), mse, len(results) =  0.7697829716193656 tf.Tensor(0.000677538586014173, shape=(), dtype=float64) 599
# slice = train, score = 0.7697829716193656
# np.mean(results), mse, len(results) =  0.6309666666666667 tf.Tensor(0.001628208991179378, shape=(), dtype=float64) 300
# slice = test, score = 0.6309666666666667
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6381999999999999 tf.Tensor(0.0016131443323842574, shape=(), dtype=float64) 100
# slice = key, score = 0.6381999999999999
# np.mean(results), mse, len(results) =  0.768914858096828 tf.Tensor(0.0006855731396588097, shape=(), dtype=float64) 599
# slice = train, score = 0.768914858096828
# np.mean(results), mse, len(results) =  0.6299 tf.Tensor(0.0016294640015276955, shape=(), dtype=float64) 300
# slice = test, score = 0.6299
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.6394000000000001 tf.Tensor(0.0016130322716705673, shape=(), dtype=float64) 100
# slice = key, score = 0.6394000000000001
# np.mean(results), mse, len(results) =  0.7706343906510852 tf.Tensor(0.0006768120528438092, shape=(), dtype=float64) 599
# slice = train, score = 0.7706343906510852
# np.mean(results), mse, len(results) =  0.6306 tf.Tensor(0.0016342061151940407, shape=(), dtype=float64) 300
# slice = test, score = 0.6306
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.6386000000000001 tf.Tensor(0.0016307446663567614, shape=(), dtype=float64) 100
# slice = key, score = 0.6386000000000001
# np.mean(results), mse, len(results) =  0.769966611018364 tf.Tensor(0.0006785307006554102, shape=(), dtype=float64) 599
# slice = train, score = 0.769966611018364
# np.mean(results), mse, len(results) =  0.6296333333333333 tf.Tensor(0.001645334638891221, shape=(), dtype=float64) 300
# slice = test, score = 0.6296333333333333
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6378 tf.Tensor(0.0016212256745357996, shape=(), dtype=float64) 100
# slice = key, score = 0.6378
# np.mean(results), mse, len(results) =  0.7706010016694491 tf.Tensor(0.0006723607246226069, shape=(), dtype=float64) 599
# slice = train, score = 0.7706010016694491
# np.mean(results), mse, len(results) =  0.6308999999999999 tf.Tensor(0.0016410578882670446, shape=(), dtype=float64) 300
# slice = test, score = 0.6308999999999999
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6381 tf.Tensor(0.001630424367468259, shape=(), dtype=float64) 100
# slice = key, score = 0.6381
# np.mean(results), mse, len(results) =  0.7701335559265442 tf.Tensor(0.0006784613045105481, shape=(), dtype=float64) 599
# slice = train, score = 0.7701335559265442
# np.mean(results), mse, len(results) =  0.6294666666666666 tf.Tensor(0.0016472991629526482, shape=(), dtype=float64) 300
# slice = test, score = 0.6294666666666666
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.6371999999999999 tf.Tensor(0.0016196680632657088, shape=(), dtype=float64) 100
# slice = key, score = 0.6371999999999999
# np.mean(results), mse, len(results) =  0.7708681135225376 tf.Tensor(0.0006727601258945541, shape=(), dtype=float64) 599
# slice = train, score = 0.7708681135225376
# np.mean(results), mse, len(results) =  0.6297 tf.Tensor(0.0016441344110080947, shape=(), dtype=float64) 300
# slice = test, score = 0.6297
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.6371 tf.Tensor(0.0016403372919796986, shape=(), dtype=float64) 100
# slice = key, score = 0.6371
# np.mean(results), mse, len(results) =  0.7718530884808014 tf.Tensor(0.0006695404347768612, shape=(), dtype=float64) 599
# slice = train, score = 0.7718530884808014
# np.mean(results), mse, len(results) =  0.6284666666666666 tf.Tensor(0.0016607860100414204, shape=(), dtype=float64) 300
# slice = test, score = 0.6284666666666666
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.6383 tf.Tensor(0.001635388441231555, shape=(), dtype=float64) 100
# slice = key, score = 0.6383
# np.mean(results), mse, len(results) =  0.7708180300500835 tf.Tensor(0.000675917235622131, shape=(), dtype=float64) 599
# slice = train, score = 0.7708180300500835
# np.mean(results), mse, len(results) =  0.6291666666666667 tf.Tensor(0.0016561795248348549, shape=(), dtype=float64) 300
# slice = test, score = 0.6291666666666667
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.6377999999999999 tf.Tensor(0.0016470400917779412, shape=(), dtype=float64) 100
# slice = key, score = 0.6377999999999999
# np.mean(results), mse, len(results) =  0.7723706176961602 tf.Tensor(0.0006707150666201918, shape=(), dtype=float64) 599
# slice = train, score = 0.7723706176961602
# np.mean(results), mse, len(results) =  0.6287 tf.Tensor(0.001667164309579038, shape=(), dtype=float64) 300
# slice = test, score = 0.6287
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.6370999999999999 tf.Tensor(0.0016507200244373125, shape=(), dtype=float64) 100
# slice = key, score = 0.6370999999999999
# np.mean(results), mse, len(results) =  0.772771285475793 tf.Tensor(0.0006660943369913096, shape=(), dtype=float64) 599
# slice = train, score = 0.772771285475793
# np.mean(results), mse, len(results) =  0.6287999999999999 tf.Tensor(0.0016719312575505436, shape=(), dtype=float64) 300
# slice = test, score = 0.6287999999999999
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.6375 tf.Tensor(0.0016521207286776063, shape=(), dtype=float64) 100
# slice = key, score = 0.6375
# np.mean(results), mse, len(results) =  0.772704507512521 tf.Tensor(0.0006674271682702679, shape=(), dtype=float64) 599
# slice = train, score = 0.772704507512521
# np.mean(results), mse, len(results) =  0.6284666666666667 tf.Tensor(0.0016737056827910333, shape=(), dtype=float64) 300
# slice = test, score = 0.6284666666666667
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.6365999999999999 tf.Tensor(0.0016562194695454817, shape=(), dtype=float64) 100
# slice = key, score = 0.6365999999999999
# np.mean(results), mse, len(results) =  0.7723038397328882 tf.Tensor(0.000666020541218392, shape=(), dtype=float64) 599
# slice = train, score = 0.7723038397328882
# np.mean(results), mse, len(results) =  0.6281 tf.Tensor(0.0016775724300267829, shape=(), dtype=float64) 300
# slice = test, score = 0.6281
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.6364 tf.Tensor(0.0016546087809218304, shape=(), dtype=float64) 100
# slice = key, score = 0.6364
# np.mean(results), mse, len(results) =  0.7729549248747913 tf.Tensor(0.000666245209729196, shape=(), dtype=float64) 599
# slice = train, score = 0.7729549248747913
# np.mean(results), mse, len(results) =  0.6285333333333334 tf.Tensor(0.0016752794432300091, shape=(), dtype=float64) 300
# slice = test, score = 0.6285333333333334
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.6373 tf.Tensor(0.00166990722881152, shape=(), dtype=float64) 100
# slice = key, score = 0.6373
# np.mean(results), mse, len(results) =  0.7731051752921536 tf.Tensor(0.0006658600814935436, shape=(), dtype=float64) 599
# slice = train, score = 0.7731051752921536
# np.mean(results), mse, len(results) =  0.6278333333333334 tf.Tensor(0.0016892344396648865, shape=(), dtype=float64) 300
# slice = test, score = 0.6278333333333334
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.634 tf.Tensor(0.0016688374055079547, shape=(), dtype=float64) 100
# slice = key, score = 0.634
# np.mean(results), mse, len(results) =  0.774457429048414 tf.Tensor(0.0006624603869161906, shape=(), dtype=float64) 599
# slice = train, score = 0.774457429048414
# np.mean(results), mse, len(results) =  0.6273666666666666 tf.Tensor(0.0016920913271402474, shape=(), dtype=float64) 300
# slice = test, score = 0.6273666666666666
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6350999999999999 tf.Tensor(0.0016753662666734556, shape=(), dtype=float64) 100
# slice = key, score = 0.6350999999999999
# np.mean(results), mse, len(results) =  0.773906510851419 tf.Tensor(0.0006623880455020924, shape=(), dtype=float64) 599
# slice = train, score = 0.773906510851419
# np.mean(results), mse, len(results) =  0.6275333333333333 tf.Tensor(0.001699737182728658, shape=(), dtype=float64) 300
# slice = test, score = 0.6275333333333333
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.6345999999999999 tf.Tensor(0.0016729595339370915, shape=(), dtype=float64) 100
# slice = key, score = 0.6345999999999999
# np.mean(results), mse, len(results) =  0.7726043405676126 tf.Tensor(0.0006656871851145692, shape=(), dtype=float64) 599
# slice = train, score = 0.7726043405676126
# np.mean(results), mse, len(results) =  0.6264 tf.Tensor(0.001700486925120157, shape=(), dtype=float64) 300
# slice = test, score = 0.6264
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.6349 tf.Tensor(0.0016824209911490227, shape=(), dtype=float64) 100
# slice = key, score = 0.6349
# np.mean(results), mse, len(results) =  0.7740901502504174 tf.Tensor(0.000660634490140499, shape=(), dtype=float64) 599
# slice = train, score = 0.7740901502504174
# np.mean(results), mse, len(results) =  0.6264666666666666 tf.Tensor(0.0017056852820928818, shape=(), dtype=float64) 300
# slice = test, score = 0.6264666666666666
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.6348 tf.Tensor(0.0016842888491232148, shape=(), dtype=float64) 100
# slice = key, score = 0.6348
# np.mean(results), mse, len(results) =  0.7741736227045075 tf.Tensor(0.0006596365163611949, shape=(), dtype=float64) 599
# slice = train, score = 0.7741736227045075
# np.mean(results), mse, len(results) =  0.6264666666666666 tf.Tensor(0.00170875921745218, shape=(), dtype=float64) 300
# slice = test, score = 0.6264666666666666
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.6347 tf.Tensor(0.0016848666331446547, shape=(), dtype=float64) 100
# slice = key, score = 0.6347
# np.mean(results), mse, len(results) =  0.7739565943238732 tf.Tensor(0.0006625220418803122, shape=(), dtype=float64) 599
# slice = train, score = 0.7739565943238732
# np.mean(results), mse, len(results) =  0.6260333333333333 tf.Tensor(0.0017127227493449985, shape=(), dtype=float64) 300
# slice = test, score = 0.6260333333333333
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6364000000000001 tf.Tensor(0.0016807039030132917, shape=(), dtype=float64) 100
# slice = key, score = 0.6364000000000001
# np.mean(results), mse, len(results) =  0.7728213689482472 tf.Tensor(0.0006680171970210528, shape=(), dtype=float64) 599
# slice = train, score = 0.7728213689482472
# np.mean(results), mse, len(results) =  0.6271333333333333 tf.Tensor(0.0017078755250210646, shape=(), dtype=float64) 300
# slice = test, score = 0.6271333333333333
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6334000000000001 tf.Tensor(0.0016996793653937944, shape=(), dtype=float64) 100
# slice = key, score = 0.6334000000000001
# np.mean(results), mse, len(results) =  0.7743405676126879 tf.Tensor(0.0006592395485239071, shape=(), dtype=float64) 599
# slice = train, score = 0.7743405676126879
# np.mean(results), mse, len(results) =  0.6255666666666667 tf.Tensor(0.0017231014824708507, shape=(), dtype=float64) 300
# slice = test, score = 0.6255666666666667
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6331000000000002 tf.Tensor(0.0016966272383239004, shape=(), dtype=float64) 100
# slice = key, score = 0.6331000000000002
# np.mean(results), mse, len(results) =  0.7740567612687812 tf.Tensor(0.0006604415861586795, shape=(), dtype=float64) 599
# slice = train, score = 0.7740567612687812
# np.mean(results), mse, len(results) =  0.6253 tf.Tensor(0.00171950752517208, shape=(), dtype=float64) 300
# slice = test, score = 0.6253
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6347 tf.Tensor(0.001698750925956604, shape=(), dtype=float64) 100
# slice = key, score = 0.6347
# np.mean(results), mse, len(results) =  0.7744073455759599 tf.Tensor(0.0006580566715444466, shape=(), dtype=float64) 599
# slice = train, score = 0.7744073455759599
# np.mean(results), mse, len(results) =  0.6246333333333334 tf.Tensor(0.0017221044621810195, shape=(), dtype=float64) 300
# slice = test, score = 0.6246333333333334
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.6336 tf.Tensor(0.0017065626685651325, shape=(), dtype=float64) 100
# slice = key, score = 0.6336
# np.mean(results), mse, len(results) =  0.7745742904841402 tf.Tensor(0.0006597716953198806, shape=(), dtype=float64) 599
# slice = train, score = 0.7745742904841402
# np.mean(results), mse, len(results) =  0.6251666666666668 tf.Tensor(0.0017299174789274102, shape=(), dtype=float64) 300
# slice = test, score = 0.6251666666666668
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.6334000000000001 tf.Tensor(0.0017067736660436495, shape=(), dtype=float64) 100
# slice = key, score = 0.6334000000000001
# np.mean(results), mse, len(results) =  0.7750584307178631 tf.Tensor(0.0006556532907633422, shape=(), dtype=float64) 599
# slice = train, score = 0.7750584307178631
# np.mean(results), mse, len(results) =  0.6242333333333333 tf.Tensor(0.0017339116984839047, shape=(), dtype=float64) 300
# slice = test, score = 0.6242333333333333
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.6326 tf.Tensor(0.0017038034194732379, shape=(), dtype=float64) 100
# slice = key, score = 0.6326
# np.mean(results), mse, len(results) =  0.7748080133555927 tf.Tensor(0.0006569196422448368, shape=(), dtype=float64) 599
# slice = train, score = 0.7748080133555927
# np.mean(results), mse, len(results) =  0.6256666666666666 tf.Tensor(0.001723786231915103, shape=(), dtype=float64) 300
# slice = test, score = 0.6256666666666666
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.6318 tf.Tensor(0.0017142306128525063, shape=(), dtype=float64) 100
# slice = key, score = 0.6318
# np.mean(results), mse, len(results) =  0.7751752921535893 tf.Tensor(0.0006549637385420262, shape=(), dtype=float64) 599
# slice = train, score = 0.7751752921535893
# np.mean(results), mse, len(results) =  0.6232 tf.Tensor(0.0017423560781628636, shape=(), dtype=float64) 300
# slice = test, score = 0.6232
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.6327 tf.Tensor(0.0017143625390211806, shape=(), dtype=float64) 100
# slice = key, score = 0.6327
# np.mean(results), mse, len(results) =  0.775575959933222 tf.Tensor(0.0006538977535565673, shape=(), dtype=float64) 599
# slice = train, score = 0.775575959933222
# np.mean(results), mse, len(results) =  0.6239666666666666 tf.Tensor(0.0017427419797337858, shape=(), dtype=float64) 300
# slice = test, score = 0.6239666666666666
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.6350999999999999 tf.Tensor(0.0017099701342068831, shape=(), dtype=float64) 100
# slice = key, score = 0.6350999999999999
# np.mean(results), mse, len(results) =  0.7747245409015026 tf.Tensor(0.0006603897053333365, shape=(), dtype=float64) 599
# slice = train, score = 0.7747245409015026
# np.mean(results), mse, len(results) =  0.6252666666666666 tf.Tensor(0.001731925119858559, shape=(), dtype=float64) 300
# slice = test, score = 0.6252666666666666
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.6310000000000001 tf.Tensor(0.0017183394312403008, shape=(), dtype=float64) 100
# slice = key, score = 0.6310000000000001
# np.mean(results), mse, len(results) =  0.7756928213689482 tf.Tensor(0.0006544939216605017, shape=(), dtype=float64) 599
# slice = train, score = 0.7756928213689482
# np.mean(results), mse, len(results) =  0.6233000000000001 tf.Tensor(0.001743302044688096, shape=(), dtype=float64) 300
# slice = test, score = 0.6233000000000001
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.6319000000000001 tf.Tensor(0.0017111073931382252, shape=(), dtype=float64) 100
# slice = key, score = 0.6319000000000001
# np.mean(results), mse, len(results) =  0.7748414023372288 tf.Tensor(0.000664794201688179, shape=(), dtype=float64) 599
# slice = train, score = 0.7748414023372288
# np.mean(results), mse, len(results) =  0.6255666666666667 tf.Tensor(0.0017371822261097742, shape=(), dtype=float64) 300
# slice = test, score = 0.6255666666666667
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.6325000000000001 tf.Tensor(0.0017308257826393462, shape=(), dtype=float64) 100
# slice = key, score = 0.6325000000000001
# np.mean(results), mse, len(results) =  0.776176961602671 tf.Tensor(0.0006527253299829186, shape=(), dtype=float64) 599
# slice = train, score = 0.776176961602671
# np.mean(results), mse, len(results) =  0.6225666666666666 tf.Tensor(0.0017570329694921352, shape=(), dtype=float64) 300
# slice = test, score = 0.6225666666666666
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.6308 tf.Tensor(0.0017322804162278529, shape=(), dtype=float64) 100
# slice = key, score = 0.6308
# np.mean(results), mse, len(results) =  0.775542570951586 tf.Tensor(0.0006534426726234804, shape=(), dtype=float64) 599
# slice = train, score = 0.775542570951586
# np.mean(results), mse, len(results) =  0.6228666666666667 tf.Tensor(0.0017582207291842978, shape=(), dtype=float64) 300
# slice = test, score = 0.6228666666666667
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.6323 tf.Tensor(0.0017385629421118934, shape=(), dtype=float64) 100
# slice = key, score = 0.6323
# np.mean(results), mse, len(results) =  0.7756093489148581 tf.Tensor(0.0006524797079298027, shape=(), dtype=float64) 599
# slice = train, score = 0.7756093489148581
# np.mean(results), mse, len(results) =  0.6237666666666666 tf.Tensor(0.001759937604901936, shape=(), dtype=float64) 300
# slice = test, score = 0.6237666666666666
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.6319 tf.Tensor(0.0017229915973764642, shape=(), dtype=float64) 100
# slice = key, score = 0.6319
# np.mean(results), mse, len(results) =  0.7759766277128548 tf.Tensor(0.0006548052563322525, shape=(), dtype=float64) 599
# slice = train, score = 0.7759766277128548
# np.mean(results), mse, len(results) =  0.6243666666666666 tf.Tensor(0.0017462411872234697, shape=(), dtype=float64) 300
# slice = test, score = 0.6243666666666666
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.6299999999999999 tf.Tensor(0.001742065939636333, shape=(), dtype=float64) 100
# slice = key, score = 0.6299999999999999
# np.mean(results), mse, len(results) =  0.7754590984974958 tf.Tensor(0.0006522792772405395, shape=(), dtype=float64) 599
# slice = train, score = 0.7754590984974958
# np.mean(results), mse, len(results) =  0.6212333333333333 tf.Tensor(0.0017710231842890983, shape=(), dtype=float64) 300
# slice = test, score = 0.6212333333333333
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.6304000000000001 tf.Tensor(0.001737185605414111, shape=(), dtype=float64) 100
# slice = key, score = 0.6304000000000001
# np.mean(results), mse, len(results) =  0.7764106844741235 tf.Tensor(0.0006504007129708722, shape=(), dtype=float64) 599
# slice = train, score = 0.7764106844741235
# np.mean(results), mse, len(results) =  0.6226333333333334 tf.Tensor(0.0017672620382395742, shape=(), dtype=float64) 300
# slice = test, score = 0.6226333333333334
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.6297000000000001 tf.Tensor(0.0017511899100860228, shape=(), dtype=float64) 100
# slice = key, score = 0.6297000000000001
# np.mean(results), mse, len(results) =  0.7757595993322205 tf.Tensor(0.0006484711119984547, shape=(), dtype=float64) 599
# slice = train, score = 0.7757595993322205
# np.mean(results), mse, len(results) =  0.6211333333333332 tf.Tensor(0.0017809038416438767, shape=(), dtype=float64) 300
# slice = test, score = 0.6211333333333332
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.631 tf.Tensor(0.0017492312742598097, shape=(), dtype=float64) 100
# slice = key, score = 0.631
# np.mean(results), mse, len(results) =  0.7760267111853089 tf.Tensor(0.0006487158851256472, shape=(), dtype=float64) 599
# slice = train, score = 0.7760267111853089
# np.mean(results), mse, len(results) =  0.6202 tf.Tensor(0.0017828164727659258, shape=(), dtype=float64) 300
# slice = test, score = 0.6202
#
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.6299000000000001 tf.Tensor(0.0017546760654459216, shape=(), dtype=float64) 100
# slice = key, score = 0.6299000000000001
# np.mean(results), mse, len(results) =  0.7765776293823039 tf.Tensor(0.0006476633406257937, shape=(), dtype=float64) 599
# slice = train, score = 0.7765776293823039
# np.mean(results), mse, len(results) =  0.6204666666666666 tf.Tensor(0.0017873302234105747, shape=(), dtype=float64) 300
# slice = test, score = 0.6204666666666666
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.6306 tf.Tensor(0.0017540266592079308, shape=(), dtype=float64) 100
# slice = key, score = 0.6306
# np.mean(results), mse, len(results) =  0.7764273789649415 tf.Tensor(0.0006481429438285052, shape=(), dtype=float64) 599
# slice = train, score = 0.7764273789649415
# np.mean(results), mse, len(results) =  0.6202666666666666 tf.Tensor(0.0017841402538152566, shape=(), dtype=float64) 300
# slice = test, score = 0.6202666666666666
# last loss =  tf.Tensor(0.0006288521599775844, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.7768113522537563 tf.Tensor(0.0006470353535750144, shape=(), dtype=float64) 599
# np.mean(results), mse, len(results) =  0.6195333333333334 tf.Tensor(0.0017903066747837748, shape=(), dtype=float64) 300
# (0.7768113522537563, 0.6195333333333334)

# %%
# !ls
# Out:
# am_download_data
# doctor_who
# log.local.bin.old
# log.local.logtime2.bin
# log.local.logtime2.true.bin
# log.local.txt.old.bin
# matrix_approx_zeshel.py
# military
# proof-of-concept-open-data-round5-5-parallel.ipynb
# proof-of-concept-open-data-round5-new-key.ipynb
# proof-of-concept-open-data-round6-greedykey.ipynb
# proof-of-concept-open-data-round6-greedykey-profile.ipynb
# proof-of-concept-open-data-round7-ms-query.ipynb
# pro_wrestling
# __pycache__
# R1000train.npz
# R2000train.npz
# stand
# star_trek
# test_support_item_choice_strategies_several_subamples-open_data.ipynb
# yugioh

# %% [markdown]
# ==============

# %%
# !ls
# Out:
# am_download_data
# doctor_who
# log.local.bin.old
# log.local.logtime2.bin
# log.local.logtime2.true.bin
# log.local.txt.old.bin
# matrix_approx_zeshel.py
# military
# proof-of-concept-open-data-round5-5-parallel.ipynb
# proof-of-concept-open-data-round5-new-key.ipynb
# proof-of-concept-open-data-round6-greedykey.ipynb
# proof-of-concept-open-data-round6-greedykey-profile.ipynb
# proof-of-concept-open-data-round7-ms-query.ipynb
# pro_wrestling
# __pycache__
# R1000train.npz
# R2000train.npz
# R3000test.npz
# R3000train.npz
# R5000test.npz
# stand
# star_trek
# test_support_item_choice_strategies_several_subamples-open_data.ipynb
# yugioh

# %%
R = np.load('./R3000test.npz')
ctx = EvalContextRelevs(
    R["R"],
    det_attempts=0,
    shuffle=False
)
# Out:
# Best det =  0.0
# Current de =  0.0
# 100 1999 900

# %%
eval_clustering(ctx, all_from_labels=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 eval_clustering(ctx, all_from_labels=True)
#
# Input In [9], in eval_clustering(ctx, all_from_labels)
#      39 k_func = (
#      40     (lambda C : euclidean_distances(X, C.cluster_centers_).argmin(axis=0))
#      41     if not all_from_labels else
#      42     (lambda C : from_labels(X, C.labels_))
#      43 )
#      45 K_KMeans = k_func(
#      46     KMeans(n_clusters=100, random_state=0).fit(X)  #, n_init="auto").fit(X)
#      47 )
# ---> 50 from sklearn.cluster import BisectingKMeans
#      51 K_BisectingKMeans = k_func(
#      52     BisectingKMeans(n_clusters=100, random_state=0).fit(X)
#      53 )
#      56 from sklearn.cluster import MiniBatchKMeans
#
# ImportError: cannot import name 'BisectingKMeans' from 'sklearn.cluster' (/home/shevkunov/anaconda3/lib/python3.9/site-packages/sklearn/cluster/__init__.py)

# %%
t = ctx.get_relevs("train").T
ctx.key_games = list(coitem_algorithm(100, t, t, 1e-8, eps=1e9)[0])

print("KEY_SET")

ma = AnnCUR(ctx, key_games=ctx.key_games)

ma.fit()
ma.get_score("train"), ma.get_score("test")
# Out:
# /var/tmp/ipykernel_326286/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# KEY_SET
# np.mean(results), mse, len(results) =  0.6689094547273637 0.000980972 1999
# np.mean(results), mse, len(results) =  0.6458777777777778 0.0011021171 900
# (0.6689094547273637, 0.6458777777777778)

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': True,
    'train_popbias': False, 'train_bias': True,
    'verbose': False, 'loss': 'mse',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": False, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": True,
    "normalize_embs": False,
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (1999, 100)
# self.embed_games.shape =  (24493, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 24493)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (1999, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.2907 tf.Tensor(0.007907760550851186, shape=(), dtype=float64) 100
# slice = key, score = 0.2907
# np.mean(results), mse, len(results) =  0.33713356678339174 tf.Tensor(0.007317207780828992, shape=(), dtype=float64) 1999
# slice = train, score = 0.33713356678339174
# np.mean(results), mse, len(results) =  0.3233333333333333 tf.Tensor(0.007510761179203233, shape=(), dtype=float64) 900
# slice = test, score = 0.3233333333333333
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.6154000000000001 tf.Tensor(0.0011351383589865284, shape=(), dtype=float64) 100
# slice = key, score = 0.6154000000000001
# np.mean(results), mse, len(results) =  0.6665082541270635 tf.Tensor(0.0009952700902410491, shape=(), dtype=float64) 1999
# slice = train, score = 0.6665082541270635
# np.mean(results), mse, len(results) =  0.6425333333333333 tf.Tensor(0.001117716319266792, shape=(), dtype=float64) 900
# slice = test, score = 0.6425333333333333
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.6164999999999999 tf.Tensor(0.0011286324910580662, shape=(), dtype=float64) 100
# slice = key, score = 0.6164999999999999
# np.mean(results), mse, len(results) =  0.6673336668334167 tf.Tensor(0.0009889171819409228, shape=(), dtype=float64) 1999
# slice = train, score = 0.6673336668334167
# np.mean(results), mse, len(results) =  0.6443222222222224 tf.Tensor(0.0011114980207479824, shape=(), dtype=float64) 900
# slice = test, score = 0.6443222222222224
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.616 tf.Tensor(0.0011271544380601203, shape=(), dtype=float64) 100
# slice = key, score = 0.616
# np.mean(results), mse, len(results) =  0.6673186593296649 tf.Tensor(0.0009877826667640311, shape=(), dtype=float64) 1999
# slice = train, score = 0.6673186593296649
# np.mean(results), mse, len(results) =  0.6444888888888889 tf.Tensor(0.0011105986158014619, shape=(), dtype=float64) 900
# slice = test, score = 0.6444888888888889
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.6165999999999999 tf.Tensor(0.0011276067133202082, shape=(), dtype=float64) 100
# slice = key, score = 0.6165999999999999
# np.mean(results), mse, len(results) =  0.6672386193096548 tf.Tensor(0.0009855066781376664, shape=(), dtype=float64) 1999
# slice = train, score = 0.6672386193096548
# np.mean(results), mse, len(results) =  0.6440555555555555 tf.Tensor(0.0011098699195918058, shape=(), dtype=float64) 900
# slice = test, score = 0.6440555555555555
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6149 tf.Tensor(0.0011271500397239096, shape=(), dtype=float64) 100
# slice = key, score = 0.6149
# np.mean(results), mse, len(results) =  0.6677638819409706 tf.Tensor(0.0009815319293014326, shape=(), dtype=float64) 1999
# slice = train, score = 0.6677638819409706
# np.mean(results), mse, len(results) =  0.6447666666666667 tf.Tensor(0.001108648995844564, shape=(), dtype=float64) 900
# slice = test, score = 0.6447666666666667
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6186 tf.Tensor(0.0011255238800229675, shape=(), dtype=float64) 100
# slice = key, score = 0.6186
# np.mean(results), mse, len(results) =  0.6695447723861931 tf.Tensor(0.0009750550175428801, shape=(), dtype=float64) 1999
# slice = train, score = 0.6695447723861931
# np.mean(results), mse, len(results) =  0.645488888888889 tf.Tensor(0.0011068309642068553, shape=(), dtype=float64) 900
# slice = test, score = 0.645488888888889
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6187999999999999 tf.Tensor(0.0011250549486327738, shape=(), dtype=float64) 100
# slice = key, score = 0.6187999999999999
# np.mean(results), mse, len(results) =  0.6698249124562281 tf.Tensor(0.000968226245634457, shape=(), dtype=float64) 1999
# slice = train, score = 0.6698249124562281
# np.mean(results), mse, len(results) =  0.6455555555555555 tf.Tensor(0.0011047854495259625, shape=(), dtype=float64) 900
# slice = test, score = 0.6455555555555555
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.6184000000000001 tf.Tensor(0.0011280803958730265, shape=(), dtype=float64) 100
# slice = key, score = 0.6184000000000001
# np.mean(results), mse, len(results) =  0.6711705852926464 tf.Tensor(0.0009631231595139425, shape=(), dtype=float64) 1999
# slice = train, score = 0.6711705852926464
# np.mean(results), mse, len(results) =  0.6457222222222222 tf.Tensor(0.0011046179601357543, shape=(), dtype=float64) 900
# slice = test, score = 0.6457222222222222
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.6187999999999999 tf.Tensor(0.001128525606655139, shape=(), dtype=float64) 100
# slice = key, score = 0.6187999999999999
# np.mean(results), mse, len(results) =  0.6712956478239119 tf.Tensor(0.0009627309178445872, shape=(), dtype=float64) 1999
# slice = train, score = 0.6712956478239119
# np.mean(results), mse, len(results) =  0.645488888888889 tf.Tensor(0.0011076109020599033, shape=(), dtype=float64) 900
# slice = test, score = 0.645488888888889
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.6177 tf.Tensor(0.0011273430042046044, shape=(), dtype=float64) 100
# slice = key, score = 0.6177
# np.mean(results), mse, len(results) =  0.6724862431215608 tf.Tensor(0.0009564042437016103, shape=(), dtype=float64) 1999
# slice = train, score = 0.6724862431215608
# np.mean(results), mse, len(results) =  0.6458999999999999 tf.Tensor(0.001105051481948906, shape=(), dtype=float64) 900
# slice = test, score = 0.6458999999999999
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.6175 tf.Tensor(0.0011297832274377827, shape=(), dtype=float64) 100
# slice = key, score = 0.6175
# np.mean(results), mse, len(results) =  0.6730515257628814 tf.Tensor(0.0009537791239217996, shape=(), dtype=float64) 1999
# slice = train, score = 0.6730515257628814
# np.mean(results), mse, len(results) =  0.6464999999999999 tf.Tensor(0.00110502746247398, shape=(), dtype=float64) 900
# slice = test, score = 0.6464999999999999
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.6191 tf.Tensor(0.0011271504527920202, shape=(), dtype=float64) 100
# slice = key, score = 0.6191
# np.mean(results), mse, len(results) =  0.6732966483241621 tf.Tensor(0.0009510135921894947, shape=(), dtype=float64) 1999
# slice = train, score = 0.6732966483241621
# np.mean(results), mse, len(results) =  0.6462222222222224 tf.Tensor(0.001105651144451189, shape=(), dtype=float64) 900
# slice = test, score = 0.6462222222222224
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(0.001127514397973897, shape=(), dtype=float64) 100
# slice = key, score = 0.6203
# np.mean(results), mse, len(results) =  0.6734567283641821 tf.Tensor(0.0009486392707079461, shape=(), dtype=float64) 1999
# slice = train, score = 0.6734567283641821
# np.mean(results), mse, len(results) =  0.6459555555555554 tf.Tensor(0.0011052596040085421, shape=(), dtype=float64) 900
# slice = test, score = 0.6459555555555554
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.6176999999999999 tf.Tensor(0.001127787206313929, shape=(), dtype=float64) 100
# slice = key, score = 0.6176999999999999
# np.mean(results), mse, len(results) =  0.6732716358179089 tf.Tensor(0.0009473996320222236, shape=(), dtype=float64) 1999
# slice = train, score = 0.6732716358179089
# np.mean(results), mse, len(results) =  0.6462222222222221 tf.Tensor(0.0011062670760007898, shape=(), dtype=float64) 900
# slice = test, score = 0.6462222222222221
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6187999999999999 tf.Tensor(0.0011270239844081167, shape=(), dtype=float64) 100
# slice = key, score = 0.6187999999999999
# np.mean(results), mse, len(results) =  0.6743921960980491 tf.Tensor(0.000945851396767226, shape=(), dtype=float64) 1999
# slice = train, score = 0.6743921960980491
# np.mean(results), mse, len(results) =  0.6472111111111111 tf.Tensor(0.001106056632269181, shape=(), dtype=float64) 900
# slice = test, score = 0.6472111111111111
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6194 tf.Tensor(0.0011277702858275584, shape=(), dtype=float64) 100
# slice = key, score = 0.6194
# np.mean(results), mse, len(results) =  0.6744422211105553 tf.Tensor(0.0009437971101682594, shape=(), dtype=float64) 1999
# slice = train, score = 0.6744422211105553
# np.mean(results), mse, len(results) =  0.6468444444444444 tf.Tensor(0.001106158975578018, shape=(), dtype=float64) 900
# slice = test, score = 0.6468444444444444
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6187 tf.Tensor(0.001127937681558827, shape=(), dtype=float64) 100
# slice = key, score = 0.6187
# np.mean(results), mse, len(results) =  0.6750175087543772 tf.Tensor(0.0009428431684069343, shape=(), dtype=float64) 1999
# slice = train, score = 0.6750175087543772
# np.mean(results), mse, len(results) =  0.6473555555555555 tf.Tensor(0.0011071778359131364, shape=(), dtype=float64) 900
# slice = test, score = 0.6473555555555555
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6208 tf.Tensor(0.0011259974264312218, shape=(), dtype=float64) 100
# slice = key, score = 0.6208
# np.mean(results), mse, len(results) =  0.6758329164582292 tf.Tensor(0.0009414424534604584, shape=(), dtype=float64) 1999
# slice = train, score = 0.6758329164582292
# np.mean(results), mse, len(results) =  0.6474555555555556 tf.Tensor(0.0011060848274784855, shape=(), dtype=float64) 900
# slice = test, score = 0.6474555555555556
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.621 tf.Tensor(0.0011266456356265918, shape=(), dtype=float64) 100
# slice = key, score = 0.621
# np.mean(results), mse, len(results) =  0.6753326663331666 tf.Tensor(0.0009404274620772404, shape=(), dtype=float64) 1999
# slice = train, score = 0.6753326663331666
# np.mean(results), mse, len(results) =  0.6468444444444446 tf.Tensor(0.001107670417929898, shape=(), dtype=float64) 900
# slice = test, score = 0.6468444444444446
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.6192 tf.Tensor(0.0011252492605072547, shape=(), dtype=float64) 100
# slice = key, score = 0.6192
# np.mean(results), mse, len(results) =  0.6754227113556779 tf.Tensor(0.0009371769892390134, shape=(), dtype=float64) 1999
# slice = train, score = 0.6754227113556779
# np.mean(results), mse, len(results) =  0.6469 tf.Tensor(0.0011067913696480387, shape=(), dtype=float64) 900
# slice = test, score = 0.6469
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.6197 tf.Tensor(0.001129243456864292, shape=(), dtype=float64) 100
# slice = key, score = 0.6197
# np.mean(results), mse, len(results) =  0.675847923961981 tf.Tensor(0.000937032048261108, shape=(), dtype=float64) 1999
# slice = train, score = 0.675847923961981
# np.mean(results), mse, len(results) =  0.6452444444444445 tf.Tensor(0.001108939865583665, shape=(), dtype=float64) 900
# slice = test, score = 0.6452444444444445
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.6195999999999999 tf.Tensor(0.0011274019385655123, shape=(), dtype=float64) 100
# slice = key, score = 0.6195999999999999
# np.mean(results), mse, len(results) =  0.6754577288644322 tf.Tensor(0.000936801285500169, shape=(), dtype=float64) 1999
# slice = train, score = 0.6754577288644322
# np.mean(results), mse, len(results) =  0.646288888888889 tf.Tensor(0.0011082496559703312, shape=(), dtype=float64) 900
# slice = test, score = 0.646288888888889
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.621 tf.Tensor(0.0011281314054209911, shape=(), dtype=float64) 100
# slice = key, score = 0.621
# np.mean(results), mse, len(results) =  0.676768384192096 tf.Tensor(0.0009354200208007063, shape=(), dtype=float64) 1999
# slice = train, score = 0.676768384192096
# np.mean(results), mse, len(results) =  0.6471222222222222 tf.Tensor(0.0011073952936700748, shape=(), dtype=float64) 900
# slice = test, score = 0.6471222222222222
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.6209 tf.Tensor(0.0011255258042981767, shape=(), dtype=float64) 100
# slice = key, score = 0.6209
# np.mean(results), mse, len(results) =  0.6767783891945972 tf.Tensor(0.0009338630385343816, shape=(), dtype=float64) 1999
# slice = train, score = 0.6767783891945972
# np.mean(results), mse, len(results) =  0.6467777777777778 tf.Tensor(0.0011075567826069387, shape=(), dtype=float64) 900
# slice = test, score = 0.6467777777777778
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.6205999999999999 tf.Tensor(0.0011272124556245833, shape=(), dtype=float64) 100
# slice = key, score = 0.6205999999999999
# np.mean(results), mse, len(results) =  0.6772136068034017 tf.Tensor(0.0009333028372215807, shape=(), dtype=float64) 1999
# slice = train, score = 0.6772136068034017
# np.mean(results), mse, len(results) =  0.6468555555555554 tf.Tensor(0.0011081223962407382, shape=(), dtype=float64) 900
# slice = test, score = 0.6468555555555554
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.6196999999999999 tf.Tensor(0.0011261982735154728, shape=(), dtype=float64) 100
# slice = key, score = 0.6196999999999999
# np.mean(results), mse, len(results) =  0.6772736368184091 tf.Tensor(0.0009316403458337109, shape=(), dtype=float64) 1999
# slice = train, score = 0.6772736368184091
# np.mean(results), mse, len(results) =  0.6465777777777777 tf.Tensor(0.0011077397304025416, shape=(), dtype=float64) 900
# slice = test, score = 0.6465777777777777
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6199 tf.Tensor(0.0011245593741493988, shape=(), dtype=float64) 100
# slice = key, score = 0.6199
# np.mean(results), mse, len(results) =  0.6778289144572286 tf.Tensor(0.0009295870015673806, shape=(), dtype=float64) 1999
# slice = train, score = 0.6778289144572286
# np.mean(results), mse, len(results) =  0.6466111111111111 tf.Tensor(0.0011067979357380592, shape=(), dtype=float64) 900
# slice = test, score = 0.6466111111111111
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.6213000000000001 tf.Tensor(0.0011258866136338345, shape=(), dtype=float64) 100
# slice = key, score = 0.6213000000000001
# np.mean(results), mse, len(results) =  0.6771385692846422 tf.Tensor(0.0009295440112255685, shape=(), dtype=float64) 1999
# slice = train, score = 0.6771385692846422
# np.mean(results), mse, len(results) =  0.646 tf.Tensor(0.0011088898997991259, shape=(), dtype=float64) 900
# slice = test, score = 0.646
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.6202 tf.Tensor(0.001127456121842569, shape=(), dtype=float64) 100
# slice = key, score = 0.6202
# np.mean(results), mse, len(results) =  0.6782841420710355 tf.Tensor(0.0009285940649896259, shape=(), dtype=float64) 1999
# slice = train, score = 0.6782841420710355
# np.mean(results), mse, len(results) =  0.6469 tf.Tensor(0.0011094158978846463, shape=(), dtype=float64) 900
# slice = test, score = 0.6469
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.6186 tf.Tensor(0.001125405715156574, shape=(), dtype=float64) 100
# slice = key, score = 0.6186
# np.mean(results), mse, len(results) =  0.6779239619809906 tf.Tensor(0.0009275114648330953, shape=(), dtype=float64) 1999
# slice = train, score = 0.6779239619809906
# np.mean(results), mse, len(results) =  0.6472222222222223 tf.Tensor(0.001107803677906112, shape=(), dtype=float64) 900
# slice = test, score = 0.6472222222222223
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.6228 tf.Tensor(0.0011233635364284518, shape=(), dtype=float64) 100
# slice = key, score = 0.6228
# np.mean(results), mse, len(results) =  0.6787093546773387 tf.Tensor(0.000926073678368152, shape=(), dtype=float64) 1999
# slice = train, score = 0.6787093546773387
# np.mean(results), mse, len(results) =  0.6467333333333333 tf.Tensor(0.0011079417024860586, shape=(), dtype=float64) 900
# slice = test, score = 0.6467333333333333
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.6209 tf.Tensor(0.0011244274822448197, shape=(), dtype=float64) 100
# slice = key, score = 0.6209
# np.mean(results), mse, len(results) =  0.6792096048024011 tf.Tensor(0.0009255941094410172, shape=(), dtype=float64) 1999
# slice = train, score = 0.6792096048024011
# np.mean(results), mse, len(results) =  0.6472999999999999 tf.Tensor(0.0011081735245521472, shape=(), dtype=float64) 900
# slice = test, score = 0.6472999999999999
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.623 tf.Tensor(0.0011253312026186179, shape=(), dtype=float64) 100
# slice = key, score = 0.623
# np.mean(results), mse, len(results) =  0.678839419709855 tf.Tensor(0.0009238403481145037, shape=(), dtype=float64) 1999
# slice = train, score = 0.678839419709855
# np.mean(results), mse, len(results) =  0.646611111111111 tf.Tensor(0.0011082998631763872, shape=(), dtype=float64) 900
# slice = test, score = 0.646611111111111
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.6194000000000001 tf.Tensor(0.0011269976454026348, shape=(), dtype=float64) 100
# slice = key, score = 0.6194000000000001
# np.mean(results), mse, len(results) =  0.6782191095547774 tf.Tensor(0.0009231267967512688, shape=(), dtype=float64) 1999
# slice = train, score = 0.6782191095547774
# np.mean(results), mse, len(results) =  0.6461555555555555 tf.Tensor(0.0011096947101945046, shape=(), dtype=float64) 900
# slice = test, score = 0.6461555555555555
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.6225999999999999 tf.Tensor(0.0011243386713851193, shape=(), dtype=float64) 100
# slice = key, score = 0.6225999999999999
# np.mean(results), mse, len(results) =  0.679224612306153 tf.Tensor(0.0009216949428287204, shape=(), dtype=float64) 1999
# slice = train, score = 0.679224612306153
# np.mean(results), mse, len(results) =  0.6471 tf.Tensor(0.0011077374419365045, shape=(), dtype=float64) 900
# slice = test, score = 0.6471
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.6208 tf.Tensor(0.0011267747557431726, shape=(), dtype=float64) 100
# slice = key, score = 0.6208
# np.mean(results), mse, len(results) =  0.6796348174087045 tf.Tensor(0.0009204147241816608, shape=(), dtype=float64) 1999
# slice = train, score = 0.6796348174087045
# np.mean(results), mse, len(results) =  0.6474777777777778 tf.Tensor(0.001107928479149244, shape=(), dtype=float64) 900
# slice = test, score = 0.6474777777777778
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.6228 tf.Tensor(0.0011248954463031742, shape=(), dtype=float64) 100
# slice = key, score = 0.6228
# np.mean(results), mse, len(results) =  0.6800150075037519 tf.Tensor(0.0009190916038139137, shape=(), dtype=float64) 1999
# slice = train, score = 0.6800150075037519
# np.mean(results), mse, len(results) =  0.6482444444444444 tf.Tensor(0.0011065639769316878, shape=(), dtype=float64) 900
# slice = test, score = 0.6482444444444444
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.6231 tf.Tensor(0.0011256786370962045, shape=(), dtype=float64) 100
# slice = key, score = 0.6231
# np.mean(results), mse, len(results) =  0.6795897948974488 tf.Tensor(0.0009195035239596582, shape=(), dtype=float64) 1999
# slice = train, score = 0.6795897948974488
# np.mean(results), mse, len(results) =  0.6477222222222223 tf.Tensor(0.00110904514646277, shape=(), dtype=float64) 900
# slice = test, score = 0.6477222222222223
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.6231 tf.Tensor(0.0011247746681333028, shape=(), dtype=float64) 100
# slice = key, score = 0.6231
# np.mean(results), mse, len(results) =  0.6806203101550775 tf.Tensor(0.0009161906916220184, shape=(), dtype=float64) 1999
# slice = train, score = 0.6806203101550775
# np.mean(results), mse, len(results) =  0.6481222222222222 tf.Tensor(0.0011067948881900017, shape=(), dtype=float64) 900
# slice = test, score = 0.6481222222222222
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.6238 tf.Tensor(0.0011245049021621257, shape=(), dtype=float64) 100
# slice = key, score = 0.6238
# np.mean(results), mse, len(results) =  0.6811605802901451 tf.Tensor(0.0009152441267239135, shape=(), dtype=float64) 1999
# slice = train, score = 0.6811605802901451
# np.mean(results), mse, len(results) =  0.6486555555555555 tf.Tensor(0.00110632389919503, shape=(), dtype=float64) 900
# slice = test, score = 0.6486555555555555
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.6215 tf.Tensor(0.001127284222161692, shape=(), dtype=float64) 100
# slice = key, score = 0.6215
# np.mean(results), mse, len(results) =  0.681095547773887 tf.Tensor(0.0009142640046299937, shape=(), dtype=float64) 1999
# slice = train, score = 0.681095547773887
# np.mean(results), mse, len(results) =  0.6477666666666667 tf.Tensor(0.0011069244040165906, shape=(), dtype=float64) 900
# slice = test, score = 0.6477666666666667
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.6228 tf.Tensor(0.0011267112885528397, shape=(), dtype=float64) 100
# slice = key, score = 0.6228
# np.mean(results), mse, len(results) =  0.6798199099549775 tf.Tensor(0.0009136613956280516, shape=(), dtype=float64) 1999
# slice = train, score = 0.6798199099549775
# np.mean(results), mse, len(results) =  0.6473444444444445 tf.Tensor(0.0011083071817016954, shape=(), dtype=float64) 900
# slice = test, score = 0.6473444444444445
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.622 tf.Tensor(0.0011259296743435171, shape=(), dtype=float64) 100
# slice = key, score = 0.622
# np.mean(results), mse, len(results) =  0.6813106553276639 tf.Tensor(0.0009124246975985009, shape=(), dtype=float64) 1999
# slice = train, score = 0.6813106553276639
# np.mean(results), mse, len(results) =  0.6476222222222222 tf.Tensor(0.0011073986767645135, shape=(), dtype=float64) 900
# slice = test, score = 0.6476222222222222
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.6234999999999999 tf.Tensor(0.0011239569478489312, shape=(), dtype=float64) 100
# slice = key, score = 0.6234999999999999
# np.mean(results), mse, len(results) =  0.6814907453726864 tf.Tensor(0.0009102587177568217, shape=(), dtype=float64) 1999
# slice = train, score = 0.6814907453726864
# np.mean(results), mse, len(results) =  0.6488333333333334 tf.Tensor(0.0011060883174044953, shape=(), dtype=float64) 900
# slice = test, score = 0.6488333333333334
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.6231 tf.Tensor(0.0011263336249251053, shape=(), dtype=float64) 100
# slice = key, score = 0.6231
# np.mean(results), mse, len(results) =  0.682016008004002 tf.Tensor(0.0009104850998877308, shape=(), dtype=float64) 1999
# slice = train, score = 0.682016008004002
# np.mean(results), mse, len(results) =  0.6483111111111112 tf.Tensor(0.001107853916183058, shape=(), dtype=float64) 900
# slice = test, score = 0.6483111111111112
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.6240000000000001 tf.Tensor(0.0011233086149552611, shape=(), dtype=float64) 100
# slice = key, score = 0.6240000000000001
# np.mean(results), mse, len(results) =  0.6819409704852426 tf.Tensor(0.000908605580169827, shape=(), dtype=float64) 1999
# slice = train, score = 0.6819409704852426
# np.mean(results), mse, len(results) =  0.6483222222222222 tf.Tensor(0.0011069173935981155, shape=(), dtype=float64) 900
# slice = test, score = 0.6483222222222222
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.6233000000000001 tf.Tensor(0.0011283470406720539, shape=(), dtype=float64) 100
# slice = key, score = 0.6233000000000001
# np.mean(results), mse, len(results) =  0.6826613306653326 tf.Tensor(0.0009094414251600167, shape=(), dtype=float64) 1999
# slice = train, score = 0.6826613306653326
# np.mean(results), mse, len(results) =  0.6481666666666668 tf.Tensor(0.001108672642920085, shape=(), dtype=float64) 900
# slice = test, score = 0.6481666666666668
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.6236 tf.Tensor(0.0011269301382088954, shape=(), dtype=float64) 100
# slice = key, score = 0.6236
# np.mean(results), mse, len(results) =  0.6817658829414708 tf.Tensor(0.0009086545718679858, shape=(), dtype=float64) 1999
# slice = train, score = 0.6817658829414708
# np.mean(results), mse, len(results) =  0.6487777777777779 tf.Tensor(0.001108242430407004, shape=(), dtype=float64) 900
# slice = test, score = 0.6487777777777779
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.6216999999999999 tf.Tensor(0.0011258207747363639, shape=(), dtype=float64) 100
# slice = key, score = 0.6216999999999999
# np.mean(results), mse, len(results) =  0.6827213606803403 tf.Tensor(0.0009062481561228066, shape=(), dtype=float64) 1999
# slice = train, score = 0.6827213606803403
# np.mean(results), mse, len(results) =  0.6483444444444444 tf.Tensor(0.0011072261213025297, shape=(), dtype=float64) 900
# slice = test, score = 0.6483444444444444
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.6227999999999999 tf.Tensor(0.0011277655198668492, shape=(), dtype=float64) 100
# slice = key, score = 0.6227999999999999
# np.mean(results), mse, len(results) =  0.6832166083041521 tf.Tensor(0.0009065299632260332, shape=(), dtype=float64) 1999
# slice = train, score = 0.6832166083041521
# np.mean(results), mse, len(results) =  0.6492777777777777 tf.Tensor(0.0011089009264846623, shape=(), dtype=float64) 900
# slice = test, score = 0.6492777777777777
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.6226999999999999 tf.Tensor(0.0011298134047603764, shape=(), dtype=float64) 100
# slice = key, score = 0.6226999999999999
# np.mean(results), mse, len(results) =  0.683271635817909 tf.Tensor(0.0009069851727376039, shape=(), dtype=float64) 1999
# slice = train, score = 0.683271635817909
# np.mean(results), mse, len(results) =  0.6485888888888889 tf.Tensor(0.0011093589358177364, shape=(), dtype=float64) 900
# slice = test, score = 0.6485888888888889
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.6223000000000001 tf.Tensor(0.0011268890954078134, shape=(), dtype=float64) 100
# slice = key, score = 0.6223000000000001
# np.mean(results), mse, len(results) =  0.6829664832416208 tf.Tensor(0.00090393948905334, shape=(), dtype=float64) 1999
# slice = train, score = 0.6829664832416208
# np.mean(results), mse, len(results) =  0.6478222222222222 tf.Tensor(0.0011087888624502083, shape=(), dtype=float64) 900
# slice = test, score = 0.6478222222222222
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.6256 tf.Tensor(0.0011277342500297073, shape=(), dtype=float64) 100
# slice = key, score = 0.6256
# np.mean(results), mse, len(results) =  0.6834767383691845 tf.Tensor(0.0009034895665243639, shape=(), dtype=float64) 1999
# slice = train, score = 0.6834767383691845
# np.mean(results), mse, len(results) =  0.6488888888888888 tf.Tensor(0.0011076261355003447, shape=(), dtype=float64) 900
# slice = test, score = 0.6488888888888888
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.624 tf.Tensor(0.001127411287690716, shape=(), dtype=float64) 100
# slice = key, score = 0.624
# np.mean(results), mse, len(results) =  0.6838369184592297 tf.Tensor(0.0009021961997264104, shape=(), dtype=float64) 1999
# slice = train, score = 0.6838369184592297
# np.mean(results), mse, len(results) =  0.6484888888888889 tf.Tensor(0.001108348690194094, shape=(), dtype=float64) 900
# slice = test, score = 0.6484888888888889
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.6234000000000001 tf.Tensor(0.0011271301157881912, shape=(), dtype=float64) 100
# slice = key, score = 0.6234000000000001
# np.mean(results), mse, len(results) =  0.6837668834417208 tf.Tensor(0.0009018163620871073, shape=(), dtype=float64) 1999
# slice = train, score = 0.6837668834417208
# np.mean(results), mse, len(results) =  0.648611111111111 tf.Tensor(0.0011084602167944447, shape=(), dtype=float64) 900
# slice = test, score = 0.648611111111111
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6234000000000001 tf.Tensor(0.0011260234265299206, shape=(), dtype=float64) 100
# slice = key, score = 0.6234000000000001
# np.mean(results), mse, len(results) =  0.6844922461230615 tf.Tensor(0.000900352212641076, shape=(), dtype=float64) 1999
# slice = train, score = 0.6844922461230615
# np.mean(results), mse, len(results) =  0.6487111111111111 tf.Tensor(0.0011074755337738861, shape=(), dtype=float64) 900
# slice = test, score = 0.6487111111111111
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.6215999999999999 tf.Tensor(0.0011288180352523533, shape=(), dtype=float64) 100
# slice = key, score = 0.6215999999999999
# np.mean(results), mse, len(results) =  0.6846373186593296 tf.Tensor(0.0009004945539148206, shape=(), dtype=float64) 1999
# slice = train, score = 0.6846373186593296
# np.mean(results), mse, len(results) =  0.6489111111111111 tf.Tensor(0.0011083807302789764, shape=(), dtype=float64) 900
# slice = test, score = 0.6489111111111111
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.6239 tf.Tensor(0.0011282109881117692, shape=(), dtype=float64) 100
# slice = key, score = 0.6239
# np.mean(results), mse, len(results) =  0.685087543771886 tf.Tensor(0.0008993865019879782, shape=(), dtype=float64) 1999
# slice = train, score = 0.685087543771886
# np.mean(results), mse, len(results) =  0.6489999999999999 tf.Tensor(0.0011080294631637172, shape=(), dtype=float64) 900
# slice = test, score = 0.6489999999999999
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6236999999999999 tf.Tensor(0.0011301235558230957, shape=(), dtype=float64) 100
# slice = key, score = 0.6236999999999999
# np.mean(results), mse, len(results) =  0.6847723861930967 tf.Tensor(0.0008990578618074448, shape=(), dtype=float64) 1999
# slice = train, score = 0.6847723861930967
# np.mean(results), mse, len(results) =  0.6486888888888889 tf.Tensor(0.00110893895618464, shape=(), dtype=float64) 900
# slice = test, score = 0.6486888888888889
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6239 tf.Tensor(0.0011292626027249778, shape=(), dtype=float64) 100
# slice = key, score = 0.6239
# np.mean(results), mse, len(results) =  0.6846773386693347 tf.Tensor(0.0008975598019842474, shape=(), dtype=float64) 1999
# slice = train, score = 0.6846773386693347
# np.mean(results), mse, len(results) =  0.6485777777777778 tf.Tensor(0.0011085802064035365, shape=(), dtype=float64) 900
# slice = test, score = 0.6485777777777778
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.6239000000000001 tf.Tensor(0.0011290948486116239, shape=(), dtype=float64) 100
# slice = key, score = 0.6239000000000001
# np.mean(results), mse, len(results) =  0.6850075037518759 tf.Tensor(0.0008964340244112624, shape=(), dtype=float64) 1999
# slice = train, score = 0.6850075037518759
# np.mean(results), mse, len(results) =  0.6494888888888889 tf.Tensor(0.0011078144706084506, shape=(), dtype=float64) 900
# slice = test, score = 0.6494888888888889
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.6249999999999999 tf.Tensor(0.0011304956354821225, shape=(), dtype=float64) 100
# slice = key, score = 0.6249999999999999
# np.mean(results), mse, len(results) =  0.6847823911955978 tf.Tensor(0.0008971486503248986, shape=(), dtype=float64) 1999
# slice = train, score = 0.6847823911955978
# np.mean(results), mse, len(results) =  0.6487 tf.Tensor(0.001110225703694295, shape=(), dtype=float64) 900
# slice = test, score = 0.6487
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.6269 tf.Tensor(0.001127381784238799, shape=(), dtype=float64) 100
# slice = key, score = 0.6269
# np.mean(results), mse, len(results) =  0.6857228614307154 tf.Tensor(0.0008963409743975874, shape=(), dtype=float64) 1999
# slice = train, score = 0.6857228614307154
# np.mean(results), mse, len(results) =  0.6492666666666667 tf.Tensor(0.0011084284101912929, shape=(), dtype=float64) 900
# slice = test, score = 0.6492666666666667
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.6241 tf.Tensor(0.0011298086375127934, shape=(), dtype=float64) 100
# slice = key, score = 0.6241
# np.mean(results), mse, len(results) =  0.6853876938469236 tf.Tensor(0.0008972106520805723, shape=(), dtype=float64) 1999
# slice = train, score = 0.6853876938469236
# np.mean(results), mse, len(results) =  0.6479 tf.Tensor(0.0011101338792599037, shape=(), dtype=float64) 900
# slice = test, score = 0.6479
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.6241 tf.Tensor(0.0011304056022185605, shape=(), dtype=float64) 100
# slice = key, score = 0.6241
# np.mean(results), mse, len(results) =  0.6854977488744372 tf.Tensor(0.0008958926567006908, shape=(), dtype=float64) 1999
# slice = train, score = 0.6854977488744372
# np.mean(results), mse, len(results) =  0.6483777777777777 tf.Tensor(0.0011101537212991053, shape=(), dtype=float64) 900
# slice = test, score = 0.6483777777777777
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.6241 tf.Tensor(0.0011309372890764959, shape=(), dtype=float64) 100
# slice = key, score = 0.6241
# np.mean(results), mse, len(results) =  0.6861380690345172 tf.Tensor(0.0008944470089128605, shape=(), dtype=float64) 1999
# slice = train, score = 0.6861380690345172
# np.mean(results), mse, len(results) =  0.6496888888888888 tf.Tensor(0.0011098264325438967, shape=(), dtype=float64) 900
# slice = test, score = 0.6496888888888888
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.6212000000000001 tf.Tensor(0.0011312507108843892, shape=(), dtype=float64) 100
# slice = key, score = 0.6212000000000001
# np.mean(results), mse, len(results) =  0.685247623811906 tf.Tensor(0.0008936082678168917, shape=(), dtype=float64) 1999
# slice = train, score = 0.685247623811906
# np.mean(results), mse, len(results) =  0.6487 tf.Tensor(0.0011097956962417364, shape=(), dtype=float64) 900
# slice = test, score = 0.6487
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.6221 tf.Tensor(0.0011299566443456548, shape=(), dtype=float64) 100
# slice = key, score = 0.6221
# np.mean(results), mse, len(results) =  0.686168084042021 tf.Tensor(0.0008933515943865847, shape=(), dtype=float64) 1999
# slice = train, score = 0.686168084042021
# np.mean(results), mse, len(results) =  0.6490222222222223 tf.Tensor(0.0011101367394287095, shape=(), dtype=float64) 900
# slice = test, score = 0.6490222222222223
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.6228000000000001 tf.Tensor(0.0011303774386776726, shape=(), dtype=float64) 100
# slice = key, score = 0.6228000000000001
# np.mean(results), mse, len(results) =  0.6866233116558279 tf.Tensor(0.0008917548001551027, shape=(), dtype=float64) 1999
# slice = train, score = 0.6866233116558279
# np.mean(results), mse, len(results) =  0.6496333333333334 tf.Tensor(0.001109221580939134, shape=(), dtype=float64) 900
# slice = test, score = 0.6496333333333334
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6229 tf.Tensor(0.0011327999207070127, shape=(), dtype=float64) 100
# slice = key, score = 0.6229
# np.mean(results), mse, len(results) =  0.6860980490245121 tf.Tensor(0.0008926756820798882, shape=(), dtype=float64) 1999
# slice = train, score = 0.6860980490245121
# np.mean(results), mse, len(results) =  0.6491555555555556 tf.Tensor(0.001111116420752999, shape=(), dtype=float64) 900
# slice = test, score = 0.6491555555555556
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.6236999999999999 tf.Tensor(0.0011317558730977028, shape=(), dtype=float64) 100
# slice = key, score = 0.6236999999999999
# np.mean(results), mse, len(results) =  0.6858229114557279 tf.Tensor(0.0008911484232638599, shape=(), dtype=float64) 1999
# slice = train, score = 0.6858229114557279
# np.mean(results), mse, len(results) =  0.6492777777777778 tf.Tensor(0.0011094309752516275, shape=(), dtype=float64) 900
# slice = test, score = 0.6492777777777778
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.6256999999999999 tf.Tensor(0.0011332566417622588, shape=(), dtype=float64) 100
# slice = key, score = 0.6256999999999999
# np.mean(results), mse, len(results) =  0.6864482241120561 tf.Tensor(0.0008912332912479185, shape=(), dtype=float64) 1999
# slice = train, score = 0.6864482241120561
# np.mean(results), mse, len(results) =  0.6494555555555556 tf.Tensor(0.0011105497509830236, shape=(), dtype=float64) 900
# slice = test, score = 0.6494555555555556
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.6233000000000001 tf.Tensor(0.001134857220005509, shape=(), dtype=float64) 100
# slice = key, score = 0.6233000000000001
# np.mean(results), mse, len(results) =  0.6864632316158079 tf.Tensor(0.0008914773139730057, shape=(), dtype=float64) 1999
# slice = train, score = 0.6864632316158079
# np.mean(results), mse, len(results) =  0.6493 tf.Tensor(0.0011117223198536816, shape=(), dtype=float64) 900
# slice = test, score = 0.6493
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.6228999999999999 tf.Tensor(0.0011367493774096286, shape=(), dtype=float64) 100
# slice = key, score = 0.6228999999999999
# np.mean(results), mse, len(results) =  0.6860180090045022 tf.Tensor(0.0008920966252269117, shape=(), dtype=float64) 1999
# slice = train, score = 0.6860180090045022
# np.mean(results), mse, len(results) =  0.6488555555555556 tf.Tensor(0.0011138596491263677, shape=(), dtype=float64) 900
# slice = test, score = 0.6488555555555556
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6257999999999999 tf.Tensor(0.0011347386717446022, shape=(), dtype=float64) 100
# slice = key, score = 0.6257999999999999
# np.mean(results), mse, len(results) =  0.6862881440720361 tf.Tensor(0.0008907739655778586, shape=(), dtype=float64) 1999
# slice = train, score = 0.6862881440720361
# np.mean(results), mse, len(results) =  0.6488333333333333 tf.Tensor(0.0011107878227607799, shape=(), dtype=float64) 900
# slice = test, score = 0.6488333333333333
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6236999999999999 tf.Tensor(0.0011321998899373516, shape=(), dtype=float64) 100
# slice = key, score = 0.6236999999999999
# np.mean(results), mse, len(results) =  0.6870285142571286 tf.Tensor(0.000890230335012871, shape=(), dtype=float64) 1999
# slice = train, score = 0.6870285142571286
# np.mean(results), mse, len(results) =  0.6488777777777778 tf.Tensor(0.0011108750849822052, shape=(), dtype=float64) 900
# slice = test, score = 0.6488777777777778
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6245 tf.Tensor(0.0011336456902352142, shape=(), dtype=float64) 100
# slice = key, score = 0.6245
# np.mean(results), mse, len(results) =  0.687383691845923 tf.Tensor(0.0008887939531421606, shape=(), dtype=float64) 1999
# slice = train, score = 0.687383691845923
# np.mean(results), mse, len(results) =  0.6495666666666668 tf.Tensor(0.0011123232518597034, shape=(), dtype=float64) 900
# slice = test, score = 0.6495666666666668
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6255000000000001 tf.Tensor(0.001133009105899212, shape=(), dtype=float64) 100
# slice = key, score = 0.6255000000000001
# np.mean(results), mse, len(results) =  0.6870235117558781 tf.Tensor(0.000888692445348987, shape=(), dtype=float64) 1999
# slice = train, score = 0.6870235117558781
# np.mean(results), mse, len(results) =  0.648788888888889 tf.Tensor(0.0011112624531826843, shape=(), dtype=float64) 900
# slice = test, score = 0.648788888888889
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.6226999999999999 tf.Tensor(0.0011323390867285861, shape=(), dtype=float64) 100
# slice = key, score = 0.6226999999999999
# np.mean(results), mse, len(results) =  0.687263631815908 tf.Tensor(0.0008883250491420657, shape=(), dtype=float64) 1999
# slice = train, score = 0.687263631815908
# np.mean(results), mse, len(results) =  0.6499777777777778 tf.Tensor(0.0011125542527430673, shape=(), dtype=float64) 900
# slice = test, score = 0.6499777777777778
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.6258 tf.Tensor(0.0011306577879290512, shape=(), dtype=float64) 100
# slice = key, score = 0.6258
# np.mean(results), mse, len(results) =  0.6876138069034518 tf.Tensor(0.0008894140996054228, shape=(), dtype=float64) 1999
# slice = train, score = 0.6876138069034518
# np.mean(results), mse, len(results) =  0.6500999999999999 tf.Tensor(0.0011120496450715354, shape=(), dtype=float64) 900
# slice = test, score = 0.6500999999999999
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.624 tf.Tensor(0.0011352082546312809, shape=(), dtype=float64) 100
# slice = key, score = 0.624
# np.mean(results), mse, len(results) =  0.6872136068034017 tf.Tensor(0.0008876072813480987, shape=(), dtype=float64) 1999
# slice = train, score = 0.6872136068034017
# np.mean(results), mse, len(results) =  0.6494777777777777 tf.Tensor(0.0011113158913131703, shape=(), dtype=float64) 900
# slice = test, score = 0.6494777777777777
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.6246 tf.Tensor(0.00113276614447039, shape=(), dtype=float64) 100
# slice = key, score = 0.6246
# np.mean(results), mse, len(results) =  0.6877588794397198 tf.Tensor(0.0008868498081272304, shape=(), dtype=float64) 1999
# slice = train, score = 0.6877588794397198
# np.mean(results), mse, len(results) =  0.6507111111111112 tf.Tensor(0.0011107751533115727, shape=(), dtype=float64) 900
# slice = test, score = 0.6507111111111112
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.6271999999999999 tf.Tensor(0.0011326773091048883, shape=(), dtype=float64) 100
# slice = key, score = 0.6271999999999999
# np.mean(results), mse, len(results) =  0.6883691845922961 tf.Tensor(0.0008867404745176661, shape=(), dtype=float64) 1999
# slice = train, score = 0.6883691845922961
# np.mean(results), mse, len(results) =  0.6499666666666667 tf.Tensor(0.0011111455872031518, shape=(), dtype=float64) 900
# slice = test, score = 0.6499666666666667
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.6238 tf.Tensor(0.0011347761500350552, shape=(), dtype=float64) 100
# slice = key, score = 0.6238
# np.mean(results), mse, len(results) =  0.686863431715858 tf.Tensor(0.0008883466460459467, shape=(), dtype=float64) 1999
# slice = train, score = 0.686863431715858
# np.mean(results), mse, len(results) =  0.6488666666666667 tf.Tensor(0.0011130166620734268, shape=(), dtype=float64) 900
# slice = test, score = 0.6488666666666667
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.6254000000000001 tf.Tensor(0.00113574160435351, shape=(), dtype=float64) 100
# slice = key, score = 0.6254000000000001
# np.mean(results), mse, len(results) =  0.6881990995497749 tf.Tensor(0.0008867296573078073, shape=(), dtype=float64) 1999
# slice = train, score = 0.6881990995497749
# np.mean(results), mse, len(results) =  0.6498555555555557 tf.Tensor(0.00111337233506236, shape=(), dtype=float64) 900
# slice = test, score = 0.6498555555555557
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.6254 tf.Tensor(0.0011331927599110465, shape=(), dtype=float64) 100
# slice = key, score = 0.6254
# np.mean(results), mse, len(results) =  0.6879739869934968 tf.Tensor(0.0008857666892839995, shape=(), dtype=float64) 1999
# slice = train, score = 0.6879739869934968
# np.mean(results), mse, len(results) =  0.6496666666666667 tf.Tensor(0.0011110120284464578, shape=(), dtype=float64) 900
# slice = test, score = 0.6496666666666667
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.6254000000000001 tf.Tensor(0.0011329199971259977, shape=(), dtype=float64) 100
# slice = key, score = 0.6254000000000001
# np.mean(results), mse, len(results) =  0.6878939469734867 tf.Tensor(0.0008855141504965412, shape=(), dtype=float64) 1999
# slice = train, score = 0.6878939469734867
# np.mean(results), mse, len(results) =  0.6499777777777778 tf.Tensor(0.0011113772110633725, shape=(), dtype=float64) 900
# slice = test, score = 0.6499777777777778
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.6240999999999999 tf.Tensor(0.0011348508174274096, shape=(), dtype=float64) 100
# slice = key, score = 0.6240999999999999
# np.mean(results), mse, len(results) =  0.6883641820910456 tf.Tensor(0.0008854268796517561, shape=(), dtype=float64) 1999
# slice = train, score = 0.6883641820910456
# np.mean(results), mse, len(results) =  0.6505111111111112 tf.Tensor(0.0011113380807374542, shape=(), dtype=float64) 900
# slice = test, score = 0.6505111111111112
#
# === Iteration 90000 ===
# np.mean(results), mse, len(results) =  0.6248999999999999 tf.Tensor(0.0011347491017711163, shape=(), dtype=float64) 100
# slice = key, score = 0.6248999999999999
# np.mean(results), mse, len(results) =  0.687943971985993 tf.Tensor(0.00088474393376687, shape=(), dtype=float64) 1999
# slice = train, score = 0.687943971985993
# np.mean(results), mse, len(results) =  0.6503666666666665 tf.Tensor(0.0011122657229270993, shape=(), dtype=float64) 900
# slice = test, score = 0.6503666666666665
#
# === Iteration 91000 ===
# np.mean(results), mse, len(results) =  0.6229 tf.Tensor(0.0011382214733207006, shape=(), dtype=float64) 100
# slice = key, score = 0.6229
# np.mean(results), mse, len(results) =  0.6879489744872437 tf.Tensor(0.000886825373137108, shape=(), dtype=float64) 1999
# slice = train, score = 0.6879489744872437
# np.mean(results), mse, len(results) =  0.6488 tf.Tensor(0.001113435017582689, shape=(), dtype=float64) 900
# slice = test, score = 0.6488
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.6244999999999999 tf.Tensor(0.0011358170130103262, shape=(), dtype=float64) 100
# slice = key, score = 0.6244999999999999
# np.mean(results), mse, len(results) =  0.6878939469734868 tf.Tensor(0.0008853882672125985, shape=(), dtype=float64) 1999
# slice = train, score = 0.6878939469734868
# np.mean(results), mse, len(results) =  0.6491555555555556 tf.Tensor(0.0011125574641427424, shape=(), dtype=float64) 900
# slice = test, score = 0.6491555555555556
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.6272 tf.Tensor(0.0011351914700623458, shape=(), dtype=float64) 100
# slice = key, score = 0.6272
# np.mean(results), mse, len(results) =  0.6877788894447224 tf.Tensor(0.0008840031439166194, shape=(), dtype=float64) 1999
# slice = train, score = 0.6877788894447224
# np.mean(results), mse, len(results) =  0.6496333333333334 tf.Tensor(0.0011130801764679646, shape=(), dtype=float64) 900
# slice = test, score = 0.6496333333333334
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.6228 tf.Tensor(0.0011332197644305848, shape=(), dtype=float64) 100
# slice = key, score = 0.6228
# np.mean(results), mse, len(results) =  0.6882991495747874 tf.Tensor(0.0008833225203263431, shape=(), dtype=float64) 1999
# slice = train, score = 0.6882991495747874
# np.mean(results), mse, len(results) =  0.6494444444444445 tf.Tensor(0.0011116413899315402, shape=(), dtype=float64) 900
# slice = test, score = 0.6494444444444445
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.6228000000000001 tf.Tensor(0.0011343645632352823, shape=(), dtype=float64) 100
# slice = key, score = 0.6228000000000001
# np.mean(results), mse, len(results) =  0.6884142071035518 tf.Tensor(0.0008829960628730769, shape=(), dtype=float64) 1999
# slice = train, score = 0.6884142071035518
# np.mean(results), mse, len(results) =  0.6493888888888889 tf.Tensor(0.001112473464743358, shape=(), dtype=float64) 900
# slice = test, score = 0.6493888888888889
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.6256 tf.Tensor(0.001132818400437081, shape=(), dtype=float64) 100
# slice = key, score = 0.6256
# np.mean(results), mse, len(results) =  0.6890695347673838 tf.Tensor(0.0008824417776239483, shape=(), dtype=float64) 1999
# slice = train, score = 0.6890695347673838
# np.mean(results), mse, len(results) =  0.6496888888888889 tf.Tensor(0.001112178017731442, shape=(), dtype=float64) 900
# slice = test, score = 0.6496888888888889
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.6254000000000001 tf.Tensor(0.0011377657007296275, shape=(), dtype=float64) 100
# slice = key, score = 0.6254000000000001
# np.mean(results), mse, len(results) =  0.6885692846423211 tf.Tensor(0.0008830523955742097, shape=(), dtype=float64) 1999
# slice = train, score = 0.6885692846423211
# np.mean(results), mse, len(results) =  0.6498333333333334 tf.Tensor(0.0011129977259655129, shape=(), dtype=float64) 900
# slice = test, score = 0.6498333333333334
#
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.6252 tf.Tensor(0.0011364415264417955, shape=(), dtype=float64) 100
# slice = key, score = 0.6252
# np.mean(results), mse, len(results) =  0.6884592296148074 tf.Tensor(0.0008834369734508439, shape=(), dtype=float64) 1999
# slice = train, score = 0.6884592296148074
# np.mean(results), mse, len(results) =  0.6501666666666668 tf.Tensor(0.001113138223658651, shape=(), dtype=float64) 900
# slice = test, score = 0.6501666666666668
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.6272 tf.Tensor(0.0011346665932745598, shape=(), dtype=float64) 100
# slice = key, score = 0.6272
# np.mean(results), mse, len(results) =  0.6888894447223611 tf.Tensor(0.0008832188658734005, shape=(), dtype=float64) 1999
# slice = train, score = 0.6888894447223611
# np.mean(results), mse, len(results) =  0.6499333333333334 tf.Tensor(0.0011131992009625934, shape=(), dtype=float64) 900
# slice = test, score = 0.6499333333333334
# last loss =  tf.Tensor(0.0008628979559848392, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.6882491245622812 tf.Tensor(0.000883626155752258, shape=(), dtype=float64) 1999
# np.mean(results), mse, len(results) =  0.6489555555555556 tf.Tensor(0.0011138298863566827, shape=(), dtype=float64) 900
# (0.6882491245622812, 0.6489555555555556)

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': True,
    'train_popbias': False, 'train_bias': True,
    'verbose': False, 'loss': 'mse',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": False, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": False,
    "normalize_embs": False,
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (1999, 100)
# self.embed_games.shape =  (24493, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 24493)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (1999, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.32010000000000005 tf.Tensor(0.0073608266309495955, shape=(), dtype=float64) 100
# slice = key, score = 0.32010000000000005
# np.mean(results), mse, len(results) =  0.341295647823912 tf.Tensor(0.007283653789119284, shape=(), dtype=float64) 1999
# slice = train, score = 0.341295647823912
# np.mean(results), mse, len(results) =  0.33161111111111113 tf.Tensor(0.007654977221320613, shape=(), dtype=float64) 900
# slice = test, score = 0.33161111111111113
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.6165 tf.Tensor(0.0011313937291074167, shape=(), dtype=float64) 100
# slice = key, score = 0.6165
# np.mean(results), mse, len(results) =  0.6662931465732866 tf.Tensor(0.0009925736133933405, shape=(), dtype=float64) 1999
# slice = train, score = 0.6662931465732866
# np.mean(results), mse, len(results) =  0.6436666666666666 tf.Tensor(0.0011148129826318543, shape=(), dtype=float64) 900
# slice = test, score = 0.6436666666666666
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.6132 tf.Tensor(0.0011290053738112116, shape=(), dtype=float64) 100
# slice = key, score = 0.6132
# np.mean(results), mse, len(results) =  0.6665382691345674 tf.Tensor(0.0009891472497101502, shape=(), dtype=float64) 1999
# slice = train, score = 0.6665382691345674
# np.mean(results), mse, len(results) =  0.6442444444444444 tf.Tensor(0.0011118236865514059, shape=(), dtype=float64) 900
# slice = test, score = 0.6442444444444444
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.6145 tf.Tensor(0.0011282705429780675, shape=(), dtype=float64) 100
# slice = key, score = 0.6145
# np.mean(results), mse, len(results) =  0.6669684842421211 tf.Tensor(0.0009871694916877827, shape=(), dtype=float64) 1999
# slice = train, score = 0.6669684842421211
# np.mean(results), mse, len(results) =  0.6440777777777779 tf.Tensor(0.0011108573413216149, shape=(), dtype=float64) 900
# slice = test, score = 0.6440777777777779
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.6172000000000001 tf.Tensor(0.0011299920767021427, shape=(), dtype=float64) 100
# slice = key, score = 0.6172000000000001
# np.mean(results), mse, len(results) =  0.6672086043021511 tf.Tensor(0.0009854019321412976, shape=(), dtype=float64) 1999
# slice = train, score = 0.6672086043021511
# np.mean(results), mse, len(results) =  0.6444555555555556 tf.Tensor(0.0011117189241444231, shape=(), dtype=float64) 900
# slice = test, score = 0.6444555555555556
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6157 tf.Tensor(0.0011239442390635545, shape=(), dtype=float64) 100
# slice = key, score = 0.6157
# np.mean(results), mse, len(results) =  0.6692446223111557 tf.Tensor(0.0009769515981822522, shape=(), dtype=float64) 1999
# slice = train, score = 0.6692446223111557
# np.mean(results), mse, len(results) =  0.6449000000000001 tf.Tensor(0.0011083945912613302, shape=(), dtype=float64) 900
# slice = test, score = 0.6449000000000001
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6184 tf.Tensor(0.0011241406370404976, shape=(), dtype=float64) 100
# slice = key, score = 0.6184
# np.mean(results), mse, len(results) =  0.6700900450225113 tf.Tensor(0.0009716593980238918, shape=(), dtype=float64) 1999
# slice = train, score = 0.6700900450225113
# np.mean(results), mse, len(results) =  0.6455444444444445 tf.Tensor(0.0011092894183694839, shape=(), dtype=float64) 900
# slice = test, score = 0.6455444444444445
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6193 tf.Tensor(0.0011215178652121593, shape=(), dtype=float64) 100
# slice = key, score = 0.6193
# np.mean(results), mse, len(results) =  0.6712406203101551 tf.Tensor(0.0009650220558939356, shape=(), dtype=float64) 1999
# slice = train, score = 0.6712406203101551
# np.mean(results), mse, len(results) =  0.6466555555555555 tf.Tensor(0.001106591716736244, shape=(), dtype=float64) 900
# slice = test, score = 0.6466555555555555
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.6168 tf.Tensor(0.0011221639322890483, shape=(), dtype=float64) 100
# slice = key, score = 0.6168
# np.mean(results), mse, len(results) =  0.672151075537769 tf.Tensor(0.0009598448189489492, shape=(), dtype=float64) 1999
# slice = train, score = 0.672151075537769
# np.mean(results), mse, len(results) =  0.6462777777777777 tf.Tensor(0.0011062729535786147, shape=(), dtype=float64) 900
# slice = test, score = 0.6462777777777777
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.6186 tf.Tensor(0.0011253823841780113, shape=(), dtype=float64) 100
# slice = key, score = 0.6186
# np.mean(results), mse, len(results) =  0.673336668334167 tf.Tensor(0.0009579227158453599, shape=(), dtype=float64) 1999
# slice = train, score = 0.673336668334167
# np.mean(results), mse, len(results) =  0.6460444444444444 tf.Tensor(0.0011067029717836897, shape=(), dtype=float64) 900
# slice = test, score = 0.6460444444444444
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.6199000000000001 tf.Tensor(0.0011236615692972265, shape=(), dtype=float64) 100
# slice = key, score = 0.6199000000000001
# np.mean(results), mse, len(results) =  0.6738019009504753 tf.Tensor(0.0009539175133604277, shape=(), dtype=float64) 1999
# slice = train, score = 0.6738019009504753
# np.mean(results), mse, len(results) =  0.6463888888888889 tf.Tensor(0.0011064199204554126, shape=(), dtype=float64) 900
# slice = test, score = 0.6463888888888889
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.6196 tf.Tensor(0.0011220278005349329, shape=(), dtype=float64) 100
# slice = key, score = 0.6196
# np.mean(results), mse, len(results) =  0.6743671835917958 tf.Tensor(0.0009492962362283251, shape=(), dtype=float64) 1999
# slice = train, score = 0.6743671835917958
# np.mean(results), mse, len(results) =  0.6469555555555555 tf.Tensor(0.001103982976853564, shape=(), dtype=float64) 900
# slice = test, score = 0.6469555555555555
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.6202 tf.Tensor(0.0011220480102767732, shape=(), dtype=float64) 100
# slice = key, score = 0.6202
# np.mean(results), mse, len(results) =  0.6740070035017509 tf.Tensor(0.0009476450594015493, shape=(), dtype=float64) 1999
# slice = train, score = 0.6740070035017509
# np.mean(results), mse, len(results) =  0.6461222222222223 tf.Tensor(0.0011064414325036168, shape=(), dtype=float64) 900
# slice = test, score = 0.6461222222222223
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.6197000000000001 tf.Tensor(0.0011204971697592935, shape=(), dtype=float64) 100
# slice = key, score = 0.6197000000000001
# np.mean(results), mse, len(results) =  0.6755327663831916 tf.Tensor(0.0009432791356593674, shape=(), dtype=float64) 1999
# slice = train, score = 0.6755327663831916
# np.mean(results), mse, len(results) =  0.6461333333333333 tf.Tensor(0.0011041242477285232, shape=(), dtype=float64) 900
# slice = test, score = 0.6461333333333333
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.6193000000000001 tf.Tensor(0.0011212918081134546, shape=(), dtype=float64) 100
# slice = key, score = 0.6193000000000001
# np.mean(results), mse, len(results) =  0.6748024012006003 tf.Tensor(0.0009419794278844191, shape=(), dtype=float64) 1999
# slice = train, score = 0.6748024012006003
# np.mean(results), mse, len(results) =  0.6470777777777778 tf.Tensor(0.0011048209126203158, shape=(), dtype=float64) 900
# slice = test, score = 0.6470777777777778
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.621 tf.Tensor(0.0011225039392782487, shape=(), dtype=float64) 100
# slice = key, score = 0.621
# np.mean(results), mse, len(results) =  0.6757178589294647 tf.Tensor(0.0009397453145554504, shape=(), dtype=float64) 1999
# slice = train, score = 0.6757178589294647
# np.mean(results), mse, len(results) =  0.6472111111111111 tf.Tensor(0.0011047046576041202, shape=(), dtype=float64) 900
# slice = test, score = 0.6472111111111111
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6195999999999999 tf.Tensor(0.0011212621223691747, shape=(), dtype=float64) 100
# slice = key, score = 0.6195999999999999
# np.mean(results), mse, len(results) =  0.6766533266633317 tf.Tensor(0.0009368585977165042, shape=(), dtype=float64) 1999
# slice = train, score = 0.6766533266633317
# np.mean(results), mse, len(results) =  0.6475333333333333 tf.Tensor(0.001103645246335358, shape=(), dtype=float64) 900
# slice = test, score = 0.6475333333333333
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6208 tf.Tensor(0.0011229368370448234, shape=(), dtype=float64) 100
# slice = key, score = 0.6208
# np.mean(results), mse, len(results) =  0.6763231615807904 tf.Tensor(0.000937161074297256, shape=(), dtype=float64) 1999
# slice = train, score = 0.6763231615807904
# np.mean(results), mse, len(results) =  0.6465111111111111 tf.Tensor(0.0011061714581556627, shape=(), dtype=float64) 900
# slice = test, score = 0.6465111111111111
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6204999999999999 tf.Tensor(0.0011237570737152435, shape=(), dtype=float64) 100
# slice = key, score = 0.6204999999999999
# np.mean(results), mse, len(results) =  0.6764832416208104 tf.Tensor(0.0009354819408883139, shape=(), dtype=float64) 1999
# slice = train, score = 0.6764832416208104
# np.mean(results), mse, len(results) =  0.6470666666666667 tf.Tensor(0.0011059182013320886, shape=(), dtype=float64) 900
# slice = test, score = 0.6470666666666667
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.6196 tf.Tensor(0.0011217731332273059, shape=(), dtype=float64) 100
# slice = key, score = 0.6196
# np.mean(results), mse, len(results) =  0.6768134067033515 tf.Tensor(0.0009327975382379292, shape=(), dtype=float64) 1999
# slice = train, score = 0.6768134067033515
# np.mean(results), mse, len(results) =  0.6472111111111111 tf.Tensor(0.0011056607216417041, shape=(), dtype=float64) 900
# slice = test, score = 0.6472111111111111
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.6187 tf.Tensor(0.0011269004737660157, shape=(), dtype=float64) 100
# slice = key, score = 0.6187
# np.mean(results), mse, len(results) =  0.6778689344672336 tf.Tensor(0.0009306929340967638, shape=(), dtype=float64) 1999
# slice = train, score = 0.6778689344672336
# np.mean(results), mse, len(results) =  0.6475444444444444 tf.Tensor(0.0011041772089829252, shape=(), dtype=float64) 900
# slice = test, score = 0.6475444444444444
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.6218 tf.Tensor(0.001122743144542975, shape=(), dtype=float64) 100
# slice = key, score = 0.6218
# np.mean(results), mse, len(results) =  0.6779189594797398 tf.Tensor(0.0009286731710994938, shape=(), dtype=float64) 1999
# slice = train, score = 0.6779189594797398
# np.mean(results), mse, len(results) =  0.6480111111111112 tf.Tensor(0.0011044484843374378, shape=(), dtype=float64) 900
# slice = test, score = 0.6480111111111112
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.621 tf.Tensor(0.0011247881295976662, shape=(), dtype=float64) 100
# slice = key, score = 0.621
# np.mean(results), mse, len(results) =  0.6780690345172586 tf.Tensor(0.0009284514356987991, shape=(), dtype=float64) 1999
# slice = train, score = 0.6780690345172586
# np.mean(results), mse, len(results) =  0.6469888888888888 tf.Tensor(0.0011053867784262706, shape=(), dtype=float64) 900
# slice = test, score = 0.6469888888888888
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.6206999999999999 tf.Tensor(0.001127389598967425, shape=(), dtype=float64) 100
# slice = key, score = 0.6206999999999999
# np.mean(results), mse, len(results) =  0.6774937468734367 tf.Tensor(0.0009281649353359228, shape=(), dtype=float64) 1999
# slice = train, score = 0.6774937468734367
# np.mean(results), mse, len(results) =  0.6466999999999999 tf.Tensor(0.0011074654534379003, shape=(), dtype=float64) 900
# slice = test, score = 0.6466999999999999
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.6205 tf.Tensor(0.0011244167398406551, shape=(), dtype=float64) 100
# slice = key, score = 0.6205
# np.mean(results), mse, len(results) =  0.6785242621310654 tf.Tensor(0.0009250710392096319, shape=(), dtype=float64) 1999
# slice = train, score = 0.6785242621310654
# np.mean(results), mse, len(results) =  0.6480777777777778 tf.Tensor(0.0011042978410472398, shape=(), dtype=float64) 900
# slice = test, score = 0.6480777777777778
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.6197 tf.Tensor(0.001122729314258474, shape=(), dtype=float64) 100
# slice = key, score = 0.6197
# np.mean(results), mse, len(results) =  0.6788594297148575 tf.Tensor(0.0009243812728679963, shape=(), dtype=float64) 1999
# slice = train, score = 0.6788594297148575
# np.mean(results), mse, len(results) =  0.6472888888888888 tf.Tensor(0.001105792057400593, shape=(), dtype=float64) 900
# slice = test, score = 0.6472888888888888
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.6192 tf.Tensor(0.0011266203644061123, shape=(), dtype=float64) 100
# slice = key, score = 0.6192
# np.mean(results), mse, len(results) =  0.6786443221610806 tf.Tensor(0.0009249309945336176, shape=(), dtype=float64) 1999
# slice = train, score = 0.6786443221610806
# np.mean(results), mse, len(results) =  0.6481333333333332 tf.Tensor(0.0011070660729526037, shape=(), dtype=float64) 900
# slice = test, score = 0.6481333333333332
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6197 tf.Tensor(0.0011275451775929598, shape=(), dtype=float64) 100
# slice = key, score = 0.6197
# np.mean(results), mse, len(results) =  0.6780590295147574 tf.Tensor(0.0009226634405937278, shape=(), dtype=float64) 1999
# slice = train, score = 0.6780590295147574
# np.mean(results), mse, len(results) =  0.6467888888888889 tf.Tensor(0.0011058729988271156, shape=(), dtype=float64) 900
# slice = test, score = 0.6467888888888889
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.622 tf.Tensor(0.0011282041608807968, shape=(), dtype=float64) 100
# slice = key, score = 0.622
# np.mean(results), mse, len(results) =  0.67895947973987 tf.Tensor(0.0009227733081207852, shape=(), dtype=float64) 1999
# slice = train, score = 0.67895947973987
# np.mean(results), mse, len(results) =  0.6477222222222223 tf.Tensor(0.0011070246494789468, shape=(), dtype=float64) 900
# slice = test, score = 0.6477222222222223
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.6201 tf.Tensor(0.001127823672041309, shape=(), dtype=float64) 100
# slice = key, score = 0.6201
# np.mean(results), mse, len(results) =  0.6785492746373187 tf.Tensor(0.0009211056050423779, shape=(), dtype=float64) 1999
# slice = train, score = 0.6785492746373187
# np.mean(results), mse, len(results) =  0.6474555555555556 tf.Tensor(0.0011068982034155778, shape=(), dtype=float64) 900
# slice = test, score = 0.6474555555555556
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.6209 tf.Tensor(0.0011281365116773783, shape=(), dtype=float64) 100
# slice = key, score = 0.6209
# np.mean(results), mse, len(results) =  0.6794747373686844 tf.Tensor(0.000921536947018831, shape=(), dtype=float64) 1999
# slice = train, score = 0.6794747373686844
# np.mean(results), mse, len(results) =  0.6476 tf.Tensor(0.0011087147941292162, shape=(), dtype=float64) 900
# slice = test, score = 0.6476
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(0.0011265441567810948, shape=(), dtype=float64) 100
# slice = key, score = 0.6203
# np.mean(results), mse, len(results) =  0.6796898449224612 tf.Tensor(0.0009189852295209933, shape=(), dtype=float64) 1999
# slice = train, score = 0.6796898449224612
# np.mean(results), mse, len(results) =  0.6476777777777778 tf.Tensor(0.001106737845603856, shape=(), dtype=float64) 900
# slice = test, score = 0.6476777777777778
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.6198 tf.Tensor(0.0011302854328711556, shape=(), dtype=float64) 100
# slice = key, score = 0.6198
# np.mean(results), mse, len(results) =  0.6798999499749876 tf.Tensor(0.0009193062057795916, shape=(), dtype=float64) 1999
# slice = train, score = 0.6798999499749876
# np.mean(results), mse, len(results) =  0.6477222222222223 tf.Tensor(0.0011074973060491145, shape=(), dtype=float64) 900
# slice = test, score = 0.6477222222222223
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.6181 tf.Tensor(0.0011297682246021647, shape=(), dtype=float64) 100
# slice = key, score = 0.6181
# np.mean(results), mse, len(results) =  0.6790345172586293 tf.Tensor(0.0009183614284418714, shape=(), dtype=float64) 1999
# slice = train, score = 0.6790345172586293
# np.mean(results), mse, len(results) =  0.6469111111111111 tf.Tensor(0.0011078437090790158, shape=(), dtype=float64) 900
# slice = test, score = 0.6469111111111111
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.6206 tf.Tensor(0.0011281732001317045, shape=(), dtype=float64) 100
# slice = key, score = 0.6206
# np.mean(results), mse, len(results) =  0.679559779889945 tf.Tensor(0.0009173174728985949, shape=(), dtype=float64) 1999
# slice = train, score = 0.679559779889945
# np.mean(results), mse, len(results) =  0.6471555555555556 tf.Tensor(0.0011088514245655087, shape=(), dtype=float64) 900
# slice = test, score = 0.6471555555555556
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.6202000000000001 tf.Tensor(0.0011289026691448745, shape=(), dtype=float64) 100
# slice = key, score = 0.6202000000000001
# np.mean(results), mse, len(results) =  0.6803401700850426 tf.Tensor(0.0009171140143343034, shape=(), dtype=float64) 1999
# slice = train, score = 0.6803401700850426
# np.mean(results), mse, len(results) =  0.6473888888888889 tf.Tensor(0.0011091649062468733, shape=(), dtype=float64) 900
# slice = test, score = 0.6473888888888889
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.6222000000000001 tf.Tensor(0.0011278401135256717, shape=(), dtype=float64) 100
# slice = key, score = 0.6222000000000001
# np.mean(results), mse, len(results) =  0.6807503751875937 tf.Tensor(0.0009151858504035794, shape=(), dtype=float64) 1999
# slice = train, score = 0.6807503751875937
# np.mean(results), mse, len(results) =  0.6473444444444445 tf.Tensor(0.0011078730228440657, shape=(), dtype=float64) 900
# slice = test, score = 0.6473444444444445
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.6211 tf.Tensor(0.0011297621964452792, shape=(), dtype=float64) 100
# slice = key, score = 0.6211
# np.mean(results), mse, len(results) =  0.6805352676338169 tf.Tensor(0.0009159107226868004, shape=(), dtype=float64) 1999
# slice = train, score = 0.6805352676338169
# np.mean(results), mse, len(results) =  0.6470222222222222 tf.Tensor(0.0011108127859167673, shape=(), dtype=float64) 900
# slice = test, score = 0.6470222222222222
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.6222000000000001 tf.Tensor(0.0011311921756285372, shape=(), dtype=float64) 100
# slice = key, score = 0.6222000000000001
# np.mean(results), mse, len(results) =  0.6808754377188594 tf.Tensor(0.0009135410778836766, shape=(), dtype=float64) 1999
# slice = train, score = 0.6808754377188594
# np.mean(results), mse, len(results) =  0.647088888888889 tf.Tensor(0.001108658328850641, shape=(), dtype=float64) 900
# slice = test, score = 0.647088888888889
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.6206 tf.Tensor(0.0011302661850476979, shape=(), dtype=float64) 100
# slice = key, score = 0.6206
# np.mean(results), mse, len(results) =  0.6813406703351675 tf.Tensor(0.0009136959346089004, shape=(), dtype=float64) 1999
# slice = train, score = 0.6813406703351675
# np.mean(results), mse, len(results) =  0.6471888888888889 tf.Tensor(0.0011092000373803441, shape=(), dtype=float64) 900
# slice = test, score = 0.6471888888888889
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.6192 tf.Tensor(0.00112910037015093, shape=(), dtype=float64) 100
# slice = key, score = 0.6192
# np.mean(results), mse, len(results) =  0.6801850925462731 tf.Tensor(0.0009144749505034407, shape=(), dtype=float64) 1999
# slice = train, score = 0.6801850925462731
# np.mean(results), mse, len(results) =  0.6467333333333333 tf.Tensor(0.0011104903330757276, shape=(), dtype=float64) 900
# slice = test, score = 0.6467333333333333
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.6189 tf.Tensor(0.001134365433429732, shape=(), dtype=float64) 100
# slice = key, score = 0.6189
# np.mean(results), mse, len(results) =  0.6809454727363682 tf.Tensor(0.0009136411747437496, shape=(), dtype=float64) 1999
# slice = train, score = 0.6809454727363682
# np.mean(results), mse, len(results) =  0.6477555555555555 tf.Tensor(0.0011114903848915988, shape=(), dtype=float64) 900
# slice = test, score = 0.6477555555555555
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.6201 tf.Tensor(0.0011308939959838113, shape=(), dtype=float64) 100
# slice = key, score = 0.6201
# np.mean(results), mse, len(results) =  0.6799799899949975 tf.Tensor(0.000912737484777296, shape=(), dtype=float64) 1999
# slice = train, score = 0.6799799899949975
# np.mean(results), mse, len(results) =  0.6466111111111111 tf.Tensor(0.0011111861826921677, shape=(), dtype=float64) 900
# slice = test, score = 0.6466111111111111
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.6219 tf.Tensor(0.001133128924158655, shape=(), dtype=float64) 100
# slice = key, score = 0.6219
# np.mean(results), mse, len(results) =  0.6801700850425213 tf.Tensor(0.0009127274232636582, shape=(), dtype=float64) 1999
# slice = train, score = 0.6801700850425213
# np.mean(results), mse, len(results) =  0.646888888888889 tf.Tensor(0.001111219723786026, shape=(), dtype=float64) 900
# slice = test, score = 0.646888888888889
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.6201 tf.Tensor(0.001131479687018738, shape=(), dtype=float64) 100
# slice = key, score = 0.6201
# np.mean(results), mse, len(results) =  0.6810205102551276 tf.Tensor(0.0009116554965429743, shape=(), dtype=float64) 1999
# slice = train, score = 0.6810205102551276
# np.mean(results), mse, len(results) =  0.6476666666666666 tf.Tensor(0.0011108084357070002, shape=(), dtype=float64) 900
# slice = test, score = 0.6476666666666666
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.6205999999999999 tf.Tensor(0.0011324001257927107, shape=(), dtype=float64) 100
# slice = key, score = 0.6205999999999999
# np.mean(results), mse, len(results) =  0.6819559779889945 tf.Tensor(0.0009113920882559473, shape=(), dtype=float64) 1999
# slice = train, score = 0.6819559779889945
# np.mean(results), mse, len(results) =  0.6471444444444444 tf.Tensor(0.0011115122457795448, shape=(), dtype=float64) 900
# slice = test, score = 0.6471444444444444
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.6202000000000001 tf.Tensor(0.0011311412284903887, shape=(), dtype=float64) 100
# slice = key, score = 0.6202000000000001
# np.mean(results), mse, len(results) =  0.6817958979489745 tf.Tensor(0.0009105037706864047, shape=(), dtype=float64) 1999
# slice = train, score = 0.6817958979489745
# np.mean(results), mse, len(results) =  0.6471666666666667 tf.Tensor(0.0011107423780879805, shape=(), dtype=float64) 900
# slice = test, score = 0.6471666666666667
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.6197 tf.Tensor(0.0011343731815703102, shape=(), dtype=float64) 100
# slice = key, score = 0.6197
# np.mean(results), mse, len(results) =  0.6818309154577289 tf.Tensor(0.000910172694348317, shape=(), dtype=float64) 1999
# slice = train, score = 0.6818309154577289
# np.mean(results), mse, len(results) =  0.6470888888888889 tf.Tensor(0.0011118925822662445, shape=(), dtype=float64) 900
# slice = test, score = 0.6470888888888889
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.6196 tf.Tensor(0.001133588278456016, shape=(), dtype=float64) 100
# slice = key, score = 0.6196
# np.mean(results), mse, len(results) =  0.6818809404702352 tf.Tensor(0.0009092152889721337, shape=(), dtype=float64) 1999
# slice = train, score = 0.6818809404702352
# np.mean(results), mse, len(results) =  0.6475111111111111 tf.Tensor(0.0011125090855787923, shape=(), dtype=float64) 900
# slice = test, score = 0.6475111111111111
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.6177 tf.Tensor(0.0011347495475688512, shape=(), dtype=float64) 100
# slice = key, score = 0.6177
# np.mean(results), mse, len(results) =  0.6817008504252126 tf.Tensor(0.0009101184916111604, shape=(), dtype=float64) 1999
# slice = train, score = 0.6817008504252126
# np.mean(results), mse, len(results) =  0.6466222222222222 tf.Tensor(0.0011127556812188363, shape=(), dtype=float64) 900
# slice = test, score = 0.6466222222222222
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.6184000000000001 tf.Tensor(0.0011330559745070903, shape=(), dtype=float64) 100
# slice = key, score = 0.6184000000000001
# np.mean(results), mse, len(results) =  0.6817208604302151 tf.Tensor(0.0009070648518971987, shape=(), dtype=float64) 1999
# slice = train, score = 0.6817208604302151
# np.mean(results), mse, len(results) =  0.6465555555555556 tf.Tensor(0.0011114337647880762, shape=(), dtype=float64) 900
# slice = test, score = 0.6465555555555556
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.6185 tf.Tensor(0.0011362899648516237, shape=(), dtype=float64) 100
# slice = key, score = 0.6185
# np.mean(results), mse, len(results) =  0.6828714357178589 tf.Tensor(0.0009093536902205077, shape=(), dtype=float64) 1999
# slice = train, score = 0.6828714357178589
# np.mean(results), mse, len(results) =  0.6483777777777777 tf.Tensor(0.0011128486941574343, shape=(), dtype=float64) 900
# slice = test, score = 0.6483777777777777
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.6187999999999999 tf.Tensor(0.0011343583708485424, shape=(), dtype=float64) 100
# slice = key, score = 0.6187999999999999
# np.mean(results), mse, len(results) =  0.6822511255627814 tf.Tensor(0.0009075153982138984, shape=(), dtype=float64) 1999
# slice = train, score = 0.6822511255627814
# np.mean(results), mse, len(results) =  0.6473666666666666 tf.Tensor(0.0011119142117342745, shape=(), dtype=float64) 900
# slice = test, score = 0.6473666666666666
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.6193 tf.Tensor(0.0011325926632829515, shape=(), dtype=float64) 100
# slice = key, score = 0.6193
# np.mean(results), mse, len(results) =  0.6823611805902952 tf.Tensor(0.0009060831750642191, shape=(), dtype=float64) 1999
# slice = train, score = 0.6823611805902952
# np.mean(results), mse, len(results) =  0.6470777777777778 tf.Tensor(0.0011114785846048389, shape=(), dtype=float64) 900
# slice = test, score = 0.6470777777777778
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.6198999999999999 tf.Tensor(0.0011346773584643953, shape=(), dtype=float64) 100
# slice = key, score = 0.6198999999999999
# np.mean(results), mse, len(results) =  0.6816458229114557 tf.Tensor(0.000906852017169328, shape=(), dtype=float64) 1999
# slice = train, score = 0.6816458229114557
# np.mean(results), mse, len(results) =  0.6465333333333333 tf.Tensor(0.0011128253549697283, shape=(), dtype=float64) 900
# slice = test, score = 0.6465333333333333
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6197 tf.Tensor(0.001132773739087975, shape=(), dtype=float64) 100
# slice = key, score = 0.6197
# np.mean(results), mse, len(results) =  0.6830215107553776 tf.Tensor(0.0009059343651150538, shape=(), dtype=float64) 1999
# slice = train, score = 0.6830215107553776
# np.mean(results), mse, len(results) =  0.6471444444444445 tf.Tensor(0.0011136695345108868, shape=(), dtype=float64) 900
# slice = test, score = 0.6471444444444445
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.6188 tf.Tensor(0.0011344382689365603, shape=(), dtype=float64) 100
# slice = key, score = 0.6188
# np.mean(results), mse, len(results) =  0.6821960980490245 tf.Tensor(0.0009058217481376355, shape=(), dtype=float64) 1999
# slice = train, score = 0.6821960980490245
# np.mean(results), mse, len(results) =  0.6471222222222223 tf.Tensor(0.0011124934866543845, shape=(), dtype=float64) 900
# slice = test, score = 0.6471222222222223
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6192 tf.Tensor(0.0011349672050211175, shape=(), dtype=float64) 100
# slice = key, score = 0.6192
# np.mean(results), mse, len(results) =  0.6826463231615807 tf.Tensor(0.0009056673640222413, shape=(), dtype=float64) 1999
# slice = train, score = 0.6826463231615807
# np.mean(results), mse, len(results) =  0.6478777777777778 tf.Tensor(0.0011142028640543263, shape=(), dtype=float64) 900
# slice = test, score = 0.6478777777777778
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6195 tf.Tensor(0.001133473100847334, shape=(), dtype=float64) 100
# slice = key, score = 0.6195
# np.mean(results), mse, len(results) =  0.6829114557278638 tf.Tensor(0.0009045804052653872, shape=(), dtype=float64) 1999
# slice = train, score = 0.6829114557278638
# np.mean(results), mse, len(results) =  0.6473777777777779 tf.Tensor(0.0011137641418862041, shape=(), dtype=float64) 900
# slice = test, score = 0.6473777777777779
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.6181 tf.Tensor(0.0011358779742994657, shape=(), dtype=float64) 100
# slice = key, score = 0.6181
# np.mean(results), mse, len(results) =  0.6822361180590295 tf.Tensor(0.0009049940350973519, shape=(), dtype=float64) 1999
# slice = train, score = 0.6822361180590295
# np.mean(results), mse, len(results) =  0.6462333333333332 tf.Tensor(0.0011144492789321866, shape=(), dtype=float64) 900
# slice = test, score = 0.6462333333333332
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.6182 tf.Tensor(0.0011372220720651204, shape=(), dtype=float64) 100
# slice = key, score = 0.6182
# np.mean(results), mse, len(results) =  0.6829164582291146 tf.Tensor(0.0009036915902943662, shape=(), dtype=float64) 1999
# slice = train, score = 0.6829164582291146
# np.mean(results), mse, len(results) =  0.6473888888888889 tf.Tensor(0.0011146181373239631, shape=(), dtype=float64) 900
# slice = test, score = 0.6473888888888889
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.6192 tf.Tensor(0.001136582429717752, shape=(), dtype=float64) 100
# slice = key, score = 0.6192
# np.mean(results), mse, len(results) =  0.6826413206603301 tf.Tensor(0.0009036542274258092, shape=(), dtype=float64) 1999
# slice = train, score = 0.6826413206603301
# np.mean(results), mse, len(results) =  0.6475 tf.Tensor(0.0011144911937368048, shape=(), dtype=float64) 900
# slice = test, score = 0.6475
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.6194 tf.Tensor(0.0011359431911195429, shape=(), dtype=float64) 100
# slice = key, score = 0.6194
# np.mean(results), mse, len(results) =  0.6830765382691345 tf.Tensor(0.0009035968013332706, shape=(), dtype=float64) 1999
# slice = train, score = 0.6830765382691345
# np.mean(results), mse, len(results) =  0.6468000000000002 tf.Tensor(0.0011146769275682663, shape=(), dtype=float64) 900
# slice = test, score = 0.6468000000000002
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.6184000000000001 tf.Tensor(0.0011345099921713155, shape=(), dtype=float64) 100
# slice = key, score = 0.6184000000000001
# np.mean(results), mse, len(results) =  0.6829314657328664 tf.Tensor(0.0009031793415879852, shape=(), dtype=float64) 1999
# slice = train, score = 0.6829314657328664
# np.mean(results), mse, len(results) =  0.6460222222222223 tf.Tensor(0.0011152710111989729, shape=(), dtype=float64) 900
# slice = test, score = 0.6460222222222223
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.6187000000000001 tf.Tensor(0.00113669183652854, shape=(), dtype=float64) 100
# slice = key, score = 0.6187000000000001
# np.mean(results), mse, len(results) =  0.6828864432216107 tf.Tensor(0.0009027620686143764, shape=(), dtype=float64) 1999
# slice = train, score = 0.6828864432216107
# np.mean(results), mse, len(results) =  0.6471666666666667 tf.Tensor(0.0011146935058989613, shape=(), dtype=float64) 900
# slice = test, score = 0.6471666666666667
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.6207 tf.Tensor(0.0011343238002616248, shape=(), dtype=float64) 100
# slice = key, score = 0.6207
# np.mean(results), mse, len(results) =  0.6839619809904952 tf.Tensor(0.0009025908431886357, shape=(), dtype=float64) 1999
# slice = train, score = 0.6839619809904952
# np.mean(results), mse, len(results) =  0.6468333333333335 tf.Tensor(0.0011158541861682643, shape=(), dtype=float64) 900
# slice = test, score = 0.6468333333333335
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.6206 tf.Tensor(0.0011369795147108635, shape=(), dtype=float64) 100
# slice = key, score = 0.6206
# np.mean(results), mse, len(results) =  0.6826663331665833 tf.Tensor(0.0009028451160503703, shape=(), dtype=float64) 1999
# slice = train, score = 0.6826663331665833
# np.mean(results), mse, len(results) =  0.6466111111111111 tf.Tensor(0.0011161801649037374, shape=(), dtype=float64) 900
# slice = test, score = 0.6466111111111111
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.6166 tf.Tensor(0.0011366300384140205, shape=(), dtype=float64) 100
# slice = key, score = 0.6166
# np.mean(results), mse, len(results) =  0.6838269134567285 tf.Tensor(0.0009020480151353247, shape=(), dtype=float64) 1999
# slice = train, score = 0.6838269134567285
# np.mean(results), mse, len(results) =  0.6474444444444445 tf.Tensor(0.0011159288140538102, shape=(), dtype=float64) 900
# slice = test, score = 0.6474444444444445
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.6193 tf.Tensor(0.001136099735575894, shape=(), dtype=float64) 100
# slice = key, score = 0.6193
# np.mean(results), mse, len(results) =  0.684072036018009 tf.Tensor(0.0009004914610386052, shape=(), dtype=float64) 1999
# slice = train, score = 0.684072036018009
# np.mean(results), mse, len(results) =  0.6475555555555556 tf.Tensor(0.0011149411558797305, shape=(), dtype=float64) 900
# slice = test, score = 0.6475555555555556
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6186 tf.Tensor(0.0011377679924042588, shape=(), dtype=float64) 100
# slice = key, score = 0.6186
# np.mean(results), mse, len(results) =  0.6832916458229115 tf.Tensor(0.0009007111327413814, shape=(), dtype=float64) 1999
# slice = train, score = 0.6832916458229115
# np.mean(results), mse, len(results) =  0.6470222222222222 tf.Tensor(0.0011164958410009235, shape=(), dtype=float64) 900
# slice = test, score = 0.6470222222222222
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.6186999999999999 tf.Tensor(0.0011394281622532838, shape=(), dtype=float64) 100
# slice = key, score = 0.6186999999999999
# np.mean(results), mse, len(results) =  0.6838469234617308 tf.Tensor(0.0009020468331848268, shape=(), dtype=float64) 1999
# slice = train, score = 0.6838469234617308
# np.mean(results), mse, len(results) =  0.6468555555555556 tf.Tensor(0.0011173244771198196, shape=(), dtype=float64) 900
# slice = test, score = 0.6468555555555556
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.6191 tf.Tensor(0.0011378970331885267, shape=(), dtype=float64) 100
# slice = key, score = 0.6191
# np.mean(results), mse, len(results) =  0.6836718359179589 tf.Tensor(0.0009002812334748897, shape=(), dtype=float64) 1999
# slice = train, score = 0.6836718359179589
# np.mean(results), mse, len(results) =  0.6469444444444444 tf.Tensor(0.0011161916414133897, shape=(), dtype=float64) 900
# slice = test, score = 0.6469444444444444
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.6175999999999999 tf.Tensor(0.001138223710034205, shape=(), dtype=float64) 100
# slice = key, score = 0.6175999999999999
# np.mean(results), mse, len(results) =  0.6834667333666833 tf.Tensor(0.0008991519975172559, shape=(), dtype=float64) 1999
# slice = train, score = 0.6834667333666833
# np.mean(results), mse, len(results) =  0.6463333333333334 tf.Tensor(0.0011166764997092335, shape=(), dtype=float64) 900
# slice = test, score = 0.6463333333333334
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.6183 tf.Tensor(0.001137480184421356, shape=(), dtype=float64) 100
# slice = key, score = 0.6183
# np.mean(results), mse, len(results) =  0.6840570285142571 tf.Tensor(0.0008998501712778483, shape=(), dtype=float64) 1999
# slice = train, score = 0.6840570285142571
# np.mean(results), mse, len(results) =  0.6473555555555556 tf.Tensor(0.0011169012391695973, shape=(), dtype=float64) 900
# slice = test, score = 0.6473555555555556
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6192 tf.Tensor(0.001139510479759867, shape=(), dtype=float64) 100
# slice = key, score = 0.6192
# np.mean(results), mse, len(results) =  0.6836518259129565 tf.Tensor(0.0008997222829223095, shape=(), dtype=float64) 1999
# slice = train, score = 0.6836518259129565
# np.mean(results), mse, len(results) =  0.6470777777777778 tf.Tensor(0.0011177399318774376, shape=(), dtype=float64) 900
# slice = test, score = 0.6470777777777778
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6203999999999998 tf.Tensor(0.0011384408613330957, shape=(), dtype=float64) 100
# slice = key, score = 0.6203999999999998
# np.mean(results), mse, len(results) =  0.6843221610805402 tf.Tensor(0.0008989434165775592, shape=(), dtype=float64) 1999
# slice = train, score = 0.6843221610805402
# np.mean(results), mse, len(results) =  0.6474 tf.Tensor(0.0011173624955250557, shape=(), dtype=float64) 900
# slice = test, score = 0.6474
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6204999999999999 tf.Tensor(0.001137926014457428, shape=(), dtype=float64) 100
# slice = key, score = 0.6204999999999999
# np.mean(results), mse, len(results) =  0.6843871935967984 tf.Tensor(0.000897563166171035, shape=(), dtype=float64) 1999
# slice = train, score = 0.6843871935967984
# np.mean(results), mse, len(results) =  0.6478777777777778 tf.Tensor(0.0011164212798794575, shape=(), dtype=float64) 900
# slice = test, score = 0.6478777777777778
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6193 tf.Tensor(0.0011387154432923232, shape=(), dtype=float64) 100
# slice = key, score = 0.6193
# np.mean(results), mse, len(results) =  0.6842071035517759 tf.Tensor(0.0008971411573055543, shape=(), dtype=float64) 1999
# slice = train, score = 0.6842071035517759
# np.mean(results), mse, len(results) =  0.646888888888889 tf.Tensor(0.0011168411239999973, shape=(), dtype=float64) 900
# slice = test, score = 0.646888888888889
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.6214 tf.Tensor(0.001138784894742845, shape=(), dtype=float64) 100
# slice = key, score = 0.6214
# np.mean(results), mse, len(results) =  0.6846373186593298 tf.Tensor(0.000897380027719598, shape=(), dtype=float64) 1999
# slice = train, score = 0.6846373186593298
# np.mean(results), mse, len(results) =  0.6470111111111111 tf.Tensor(0.0011165194736424938, shape=(), dtype=float64) 900
# slice = test, score = 0.6470111111111111
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.619 tf.Tensor(0.0011397793548898845, shape=(), dtype=float64) 100
# slice = key, score = 0.619
# np.mean(results), mse, len(results) =  0.6853626813406704 tf.Tensor(0.0008971707137819669, shape=(), dtype=float64) 1999
# slice = train, score = 0.6853626813406704
# np.mean(results), mse, len(results) =  0.6480222222222223 tf.Tensor(0.001117732332043278, shape=(), dtype=float64) 900
# slice = test, score = 0.6480222222222223
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.6213000000000001 tf.Tensor(0.0011414276956514047, shape=(), dtype=float64) 100
# slice = key, score = 0.6213000000000001
# np.mean(results), mse, len(results) =  0.6848524262131065 tf.Tensor(0.0008973129781998864, shape=(), dtype=float64) 1999
# slice = train, score = 0.6848524262131065
# np.mean(results), mse, len(results) =  0.6475333333333333 tf.Tensor(0.0011178393853596964, shape=(), dtype=float64) 900
# slice = test, score = 0.6475333333333333
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.6196999999999999 tf.Tensor(0.0011392469901474406, shape=(), dtype=float64) 100
# slice = key, score = 0.6196999999999999
# np.mean(results), mse, len(results) =  0.6852976488244122 tf.Tensor(0.0008961131085712305, shape=(), dtype=float64) 1999
# slice = train, score = 0.6852976488244122
# np.mean(results), mse, len(results) =  0.6472444444444444 tf.Tensor(0.0011168174329518525, shape=(), dtype=float64) 900
# slice = test, score = 0.6472444444444444
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.6175 tf.Tensor(0.0011373557555003078, shape=(), dtype=float64) 100
# slice = key, score = 0.6175
# np.mean(results), mse, len(results) =  0.6850525262631316 tf.Tensor(0.0008955706233319555, shape=(), dtype=float64) 1999
# slice = train, score = 0.6850525262631316
# np.mean(results), mse, len(results) =  0.6467888888888889 tf.Tensor(0.00111821070712736, shape=(), dtype=float64) 900
# slice = test, score = 0.6467888888888889
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.6182000000000001 tf.Tensor(0.0011414217511623661, shape=(), dtype=float64) 100
# slice = key, score = 0.6182000000000001
# np.mean(results), mse, len(results) =  0.684817408704352 tf.Tensor(0.0008959709005594926, shape=(), dtype=float64) 1999
# slice = train, score = 0.684817408704352
# np.mean(results), mse, len(results) =  0.6466222222222222 tf.Tensor(0.0011184067301623507, shape=(), dtype=float64) 900
# slice = test, score = 0.6466222222222222
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.6182000000000001 tf.Tensor(0.001138837771915132, shape=(), dtype=float64) 100
# slice = key, score = 0.6182000000000001
# np.mean(results), mse, len(results) =  0.6851375687843922 tf.Tensor(0.0008948878120538803, shape=(), dtype=float64) 1999
# slice = train, score = 0.6851375687843922
# np.mean(results), mse, len(results) =  0.6478111111111111 tf.Tensor(0.0011175853677122252, shape=(), dtype=float64) 900
# slice = test, score = 0.6478111111111111
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.6179000000000001 tf.Tensor(0.0011409789864578546, shape=(), dtype=float64) 100
# slice = key, score = 0.6179000000000001
# np.mean(results), mse, len(results) =  0.6846823411705855 tf.Tensor(0.0008954859256702226, shape=(), dtype=float64) 1999
# slice = train, score = 0.6846823411705855
# np.mean(results), mse, len(results) =  0.6461444444444444 tf.Tensor(0.0011196479278122822, shape=(), dtype=float64) 900
# slice = test, score = 0.6461444444444444
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.6207 tf.Tensor(0.00113888162670751, shape=(), dtype=float64) 100
# slice = key, score = 0.6207
# np.mean(results), mse, len(results) =  0.684927463731866 tf.Tensor(0.0008945047525403022, shape=(), dtype=float64) 1999
# slice = train, score = 0.684927463731866
# np.mean(results), mse, len(results) =  0.6472111111111111 tf.Tensor(0.0011181562714361784, shape=(), dtype=float64) 900
# slice = test, score = 0.6472111111111111
#
# === Iteration 90000 ===
# np.mean(results), mse, len(results) =  0.6198999999999999 tf.Tensor(0.0011405894675696855, shape=(), dtype=float64) 100
# slice = key, score = 0.6198999999999999
# np.mean(results), mse, len(results) =  0.6853176588294146 tf.Tensor(0.0008939879207380092, shape=(), dtype=float64) 1999
# slice = train, score = 0.6853176588294146
# np.mean(results), mse, len(results) =  0.6473444444444443 tf.Tensor(0.0011184966555207278, shape=(), dtype=float64) 900
# slice = test, score = 0.6473444444444443
#
# === Iteration 91000 ===
# np.mean(results), mse, len(results) =  0.6184 tf.Tensor(0.0011422022172848996, shape=(), dtype=float64) 100
# slice = key, score = 0.6184
# np.mean(results), mse, len(results) =  0.6842521260630317 tf.Tensor(0.0008946730173370929, shape=(), dtype=float64) 1999
# slice = train, score = 0.6842521260630317
# np.mean(results), mse, len(results) =  0.6455888888888889 tf.Tensor(0.0011187610112629175, shape=(), dtype=float64) 900
# slice = test, score = 0.6455888888888889
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.6195999999999999 tf.Tensor(0.0011395861649065836, shape=(), dtype=float64) 100
# slice = key, score = 0.6195999999999999
# np.mean(results), mse, len(results) =  0.6850925462731365 tf.Tensor(0.0008944208256199132, shape=(), dtype=float64) 1999
# slice = train, score = 0.6850925462731365
# np.mean(results), mse, len(results) =  0.6469888888888888 tf.Tensor(0.0011196153018709736, shape=(), dtype=float64) 900
# slice = test, score = 0.6469888888888888
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.6179 tf.Tensor(0.001141214432187756, shape=(), dtype=float64) 100
# slice = key, score = 0.6179
# np.mean(results), mse, len(results) =  0.6851625812906452 tf.Tensor(0.0008935183603896875, shape=(), dtype=float64) 1999
# slice = train, score = 0.6851625812906452
# np.mean(results), mse, len(results) =  0.6473000000000001 tf.Tensor(0.0011186845252263748, shape=(), dtype=float64) 900
# slice = test, score = 0.6473000000000001
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.6169 tf.Tensor(0.0011394443367263266, shape=(), dtype=float64) 100
# slice = key, score = 0.6169
# np.mean(results), mse, len(results) =  0.6852526263131565 tf.Tensor(0.0008929089021252702, shape=(), dtype=float64) 1999
# slice = train, score = 0.6852526263131565
# np.mean(results), mse, len(results) =  0.6466000000000001 tf.Tensor(0.0011184494917101156, shape=(), dtype=float64) 900
# slice = test, score = 0.6466000000000001
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.6195 tf.Tensor(0.001142054971914071, shape=(), dtype=float64) 100
# slice = key, score = 0.6195
# np.mean(results), mse, len(results) =  0.6849324662331165 tf.Tensor(0.0008934148350182692, shape=(), dtype=float64) 1999
# slice = train, score = 0.6849324662331165
# np.mean(results), mse, len(results) =  0.6471111111111111 tf.Tensor(0.0011193538821004996, shape=(), dtype=float64) 900
# slice = test, score = 0.6471111111111111
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.6189999999999999 tf.Tensor(0.0011397358386149093, shape=(), dtype=float64) 100
# slice = key, score = 0.6189999999999999
# np.mean(results), mse, len(results) =  0.6848624312156077 tf.Tensor(0.0008937953393004053, shape=(), dtype=float64) 1999
# slice = train, score = 0.6848624312156077
# np.mean(results), mse, len(results) =  0.6459 tf.Tensor(0.001119995154280319, shape=(), dtype=float64) 900
# slice = test, score = 0.6459
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.617 tf.Tensor(0.0011418458257391759, shape=(), dtype=float64) 100
# slice = key, score = 0.617
# np.mean(results), mse, len(results) =  0.6847923961980991 tf.Tensor(0.0008927324882961066, shape=(), dtype=float64) 1999
# slice = train, score = 0.6847923961980991
# np.mean(results), mse, len(results) =  0.6464555555555557 tf.Tensor(0.0011195093940141983, shape=(), dtype=float64) 900
# slice = test, score = 0.6464555555555557
#
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.6195999999999998 tf.Tensor(0.0011402564868612701, shape=(), dtype=float64) 100
# slice = key, score = 0.6195999999999998
# np.mean(results), mse, len(results) =  0.6862731365682843 tf.Tensor(0.00089270792090782, shape=(), dtype=float64) 1999
# slice = train, score = 0.6862731365682843
# np.mean(results), mse, len(results) =  0.6467111111111112 tf.Tensor(0.0011205154942552074, shape=(), dtype=float64) 900
# slice = test, score = 0.6467111111111112
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.6194999999999999 tf.Tensor(0.001142066727960352, shape=(), dtype=float64) 100
# slice = key, score = 0.6194999999999999
# np.mean(results), mse, len(results) =  0.6856678339169585 tf.Tensor(0.0008926942025145758, shape=(), dtype=float64) 1999
# slice = train, score = 0.6856678339169585
# np.mean(results), mse, len(results) =  0.6473333333333335 tf.Tensor(0.0011207382508065216, shape=(), dtype=float64) 900
# slice = test, score = 0.6473333333333335
# last loss =  tf.Tensor(0.0009355554099762159, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.6857028514257129 tf.Tensor(0.0008923190843819564, shape=(), dtype=float64) 1999
# np.mean(results), mse, len(results) =  0.6471222222222222 tf.Tensor(0.001121067263103889, shape=(), dtype=float64) 900
# (0.6857028514257129, 0.6471222222222222)

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': True,
    'train_popbias': False, 'train_bias': True,
    'verbose': False, 'loss': 'softmax',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": False, # <<< DIFF HERE
    "Winit": "eye",
    "Wfreeze": False,
    "normalize_embs": False,
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (1999, 100)
# self.embed_games.shape =  (24493, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 24493)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (1999, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.3428999999999999 tf.Tensor(0.006794424860178713, shape=(), dtype=float64) 100
# slice = key, score = 0.3428999999999999
# np.mean(results), mse, len(results) =  0.3590695347673837 tf.Tensor(0.006904476766363904, shape=(), dtype=float64) 1999
# slice = train, score = 0.3590695347673837
# np.mean(results), mse, len(results) =  0.3501888888888889 tf.Tensor(0.007022737246161761, shape=(), dtype=float64) 900
# slice = test, score = 0.3501888888888889
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.1757 tf.Tensor(41.20711298999198, shape=(), dtype=float64) 100
# slice = key, score = 0.1757
# np.mean(results), mse, len(results) =  0.2173336668334167 tf.Tensor(45.29601379569538, shape=(), dtype=float64) 1999
# slice = train, score = 0.2173336668334167
# np.mean(results), mse, len(results) =  0.20172222222222225 tf.Tensor(46.28098413746966, shape=(), dtype=float64) 900
# slice = test, score = 0.20172222222222225
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.2926 tf.Tensor(116.25198186434235, shape=(), dtype=float64) 100
# slice = key, score = 0.2926
# np.mean(results), mse, len(results) =  0.33845422711355677 tf.Tensor(117.09674240969784, shape=(), dtype=float64) 1999
# slice = train, score = 0.33845422711355677
# np.mean(results), mse, len(results) =  0.3128222222222222 tf.Tensor(120.06104300893823, shape=(), dtype=float64) 900
# slice = test, score = 0.3128222222222222
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.3469 tf.Tensor(153.9075935546241, shape=(), dtype=float64) 100
# slice = key, score = 0.3469
# np.mean(results), mse, len(results) =  0.39639319659829914 tf.Tensor(152.5711218730352, shape=(), dtype=float64) 1999
# slice = train, score = 0.39639319659829914
# np.mean(results), mse, len(results) =  0.3659555555555556 tf.Tensor(157.27575070784587, shape=(), dtype=float64) 900
# slice = test, score = 0.3659555555555556
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.381 tf.Tensor(187.7880833855886, shape=(), dtype=float64) 100
# slice = key, score = 0.381
# np.mean(results), mse, len(results) =  0.4291295647823912 tf.Tensor(183.551675741595, shape=(), dtype=float64) 1999
# slice = train, score = 0.4291295647823912
# np.mean(results), mse, len(results) =  0.39551111111111115 tf.Tensor(188.3442790930419, shape=(), dtype=float64) 900
# slice = test, score = 0.39551111111111115
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.4115 tf.Tensor(203.9734393859764, shape=(), dtype=float64) 100
# slice = key, score = 0.4115
# np.mean(results), mse, len(results) =  0.4550725362681341 tf.Tensor(199.90937849944865, shape=(), dtype=float64) 1999
# slice = train, score = 0.4550725362681341
# np.mean(results), mse, len(results) =  0.4193888888888889 tf.Tensor(205.04858003531547, shape=(), dtype=float64) 900
# slice = test, score = 0.4193888888888889
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.4338 tf.Tensor(208.23115895449143, shape=(), dtype=float64) 100
# slice = key, score = 0.4338
# np.mean(results), mse, len(results) =  0.47441720860430214 tf.Tensor(208.46876249367563, shape=(), dtype=float64) 1999
# slice = train, score = 0.47441720860430214
# np.mean(results), mse, len(results) =  0.43708888888888886 tf.Tensor(213.42970273602728, shape=(), dtype=float64) 900
# slice = test, score = 0.43708888888888886
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.44800000000000006 tf.Tensor(212.24100840033327, shape=(), dtype=float64) 100
# slice = key, score = 0.44800000000000006
# np.mean(results), mse, len(results) =  0.49053526763381694 tf.Tensor(213.91655843842042, shape=(), dtype=float64) 1999
# slice = train, score = 0.49053526763381694
# np.mean(results), mse, len(results) =  0.4507111111111111 tf.Tensor(217.67830101653811, shape=(), dtype=float64) 900
# slice = test, score = 0.4507111111111111
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.46260000000000007 tf.Tensor(219.72041539077347, shape=(), dtype=float64) 100
# slice = key, score = 0.46260000000000007
# np.mean(results), mse, len(results) =  0.5045972986493247 tf.Tensor(221.99911319155336, shape=(), dtype=float64) 1999
# slice = train, score = 0.5045972986493247
# np.mean(results), mse, len(results) =  0.46372222222222226 tf.Tensor(225.32233126408002, shape=(), dtype=float64) 900
# slice = test, score = 0.46372222222222226
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.47430000000000005 tf.Tensor(234.8052881384764, shape=(), dtype=float64) 100
# slice = key, score = 0.47430000000000005
# np.mean(results), mse, len(results) =  0.5158429214607304 tf.Tensor(237.40007013319158, shape=(), dtype=float64) 1999
# slice = train, score = 0.5158429214607304
# np.mean(results), mse, len(results) =  0.4751444444444444 tf.Tensor(240.4801448333987, shape=(), dtype=float64) 900
# slice = test, score = 0.4751444444444444
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.4854 tf.Tensor(230.6616173987098, shape=(), dtype=float64) 100
# slice = key, score = 0.4854
# np.mean(results), mse, len(results) =  0.5263831915957979 tf.Tensor(233.03241662480139, shape=(), dtype=float64) 1999
# slice = train, score = 0.5263831915957979
# np.mean(results), mse, len(results) =  0.48440000000000005 tf.Tensor(236.1090538826572, shape=(), dtype=float64) 900
# slice = test, score = 0.48440000000000005
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.49229999999999996 tf.Tensor(233.89919102066204, shape=(), dtype=float64) 100
# slice = key, score = 0.49229999999999996
# np.mean(results), mse, len(results) =  0.5348474237118559 tf.Tensor(238.47136046901875, shape=(), dtype=float64) 1999
# slice = train, score = 0.5348474237118559
# np.mean(results), mse, len(results) =  0.49094444444444446 tf.Tensor(241.37139558147112, shape=(), dtype=float64) 900
# slice = test, score = 0.49094444444444446
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.4984 tf.Tensor(232.73318036258755, shape=(), dtype=float64) 100
# slice = key, score = 0.4984
# np.mean(results), mse, len(results) =  0.5426863431715857 tf.Tensor(238.7523032259752, shape=(), dtype=float64) 1999
# slice = train, score = 0.5426863431715857
# np.mean(results), mse, len(results) =  0.49874444444444443 tf.Tensor(241.0297729410604, shape=(), dtype=float64) 900
# slice = test, score = 0.49874444444444443
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.5057 tf.Tensor(239.24250609741412, shape=(), dtype=float64) 100
# slice = key, score = 0.5057
# np.mean(results), mse, len(results) =  0.5492596298149075 tf.Tensor(248.41108341572811, shape=(), dtype=float64) 1999
# slice = train, score = 0.5492596298149075
# np.mean(results), mse, len(results) =  0.5046333333333334 tf.Tensor(250.10954768099376, shape=(), dtype=float64) 900
# slice = test, score = 0.5046333333333334
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.5068 tf.Tensor(248.10588643214666, shape=(), dtype=float64) 100
# slice = key, score = 0.5068
# np.mean(results), mse, len(results) =  0.5558579289644823 tf.Tensor(254.85869658974013, shape=(), dtype=float64) 1999
# slice = train, score = 0.5558579289644823
# np.mean(results), mse, len(results) =  0.5113111111111112 tf.Tensor(256.8741799535765, shape=(), dtype=float64) 900
# slice = test, score = 0.5113111111111112
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.515 tf.Tensor(264.5443392287455, shape=(), dtype=float64) 100
# slice = key, score = 0.515
# np.mean(results), mse, len(results) =  0.5602001000500251 tf.Tensor(271.6215353793502, shape=(), dtype=float64) 1999
# slice = train, score = 0.5602001000500251
# np.mean(results), mse, len(results) =  0.5154 tf.Tensor(275.3231171528339, shape=(), dtype=float64) 900
# slice = test, score = 0.5154
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.5161 tf.Tensor(263.2438254571908, shape=(), dtype=float64) 100
# slice = key, score = 0.5161
# np.mean(results), mse, len(results) =  0.5655727863931965 tf.Tensor(272.37553382791214, shape=(), dtype=float64) 1999
# slice = train, score = 0.5655727863931965
# np.mean(results), mse, len(results) =  0.5211111111111111 tf.Tensor(277.15694086224477, shape=(), dtype=float64) 900
# slice = test, score = 0.5211111111111111
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.525 tf.Tensor(265.6526421665262, shape=(), dtype=float64) 100
# slice = key, score = 0.525
# np.mean(results), mse, len(results) =  0.56991995997999 tf.Tensor(273.1804001475212, shape=(), dtype=float64) 1999
# slice = train, score = 0.56991995997999
# np.mean(results), mse, len(results) =  0.5262111111111112 tf.Tensor(278.06845315579926, shape=(), dtype=float64) 900
# slice = test, score = 0.5262111111111112
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.5261 tf.Tensor(264.53284643795615, shape=(), dtype=float64) 100
# slice = key, score = 0.5261
# np.mean(results), mse, len(results) =  0.5751875937968983 tf.Tensor(276.44659355868504, shape=(), dtype=float64) 1999
# slice = train, score = 0.5751875937968983
# np.mean(results), mse, len(results) =  0.5302444444444445 tf.Tensor(280.55722167193295, shape=(), dtype=float64) 900
# slice = test, score = 0.5302444444444445
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.5318999999999999 tf.Tensor(278.262395545129, shape=(), dtype=float64) 100
# slice = key, score = 0.5318999999999999
# np.mean(results), mse, len(results) =  0.579024512256128 tf.Tensor(292.952606097723, shape=(), dtype=float64) 1999
# slice = train, score = 0.579024512256128
# np.mean(results), mse, len(results) =  0.5346666666666667 tf.Tensor(298.768036691346, shape=(), dtype=float64) 900
# slice = test, score = 0.5346666666666667
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.5305000000000001 tf.Tensor(272.5150677539782, shape=(), dtype=float64) 100
# slice = key, score = 0.5305000000000001
# np.mean(results), mse, len(results) =  0.5826463231615808 tf.Tensor(287.7086057674779, shape=(), dtype=float64) 1999
# slice = train, score = 0.5826463231615808
# np.mean(results), mse, len(results) =  0.5389444444444446 tf.Tensor(292.96833221599786, shape=(), dtype=float64) 900
# slice = test, score = 0.5389444444444446
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.5337 tf.Tensor(290.1302875552711, shape=(), dtype=float64) 100
# slice = key, score = 0.5337
# np.mean(results), mse, len(results) =  0.5861180590295147 tf.Tensor(302.82169640791096, shape=(), dtype=float64) 1999
# slice = train, score = 0.5861180590295147
# np.mean(results), mse, len(results) =  0.5421333333333332 tf.Tensor(308.4614260617811, shape=(), dtype=float64) 900
# slice = test, score = 0.5421333333333332
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.5325 tf.Tensor(290.11698443479816, shape=(), dtype=float64) 100
# slice = key, score = 0.5325
# np.mean(results), mse, len(results) =  0.5887693846923461 tf.Tensor(306.15849688063025, shape=(), dtype=float64) 1999
# slice = train, score = 0.5887693846923461
# np.mean(results), mse, len(results) =  0.5445333333333334 tf.Tensor(311.43713006995586, shape=(), dtype=float64) 900
# slice = test, score = 0.5445333333333334
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.5365 tf.Tensor(312.0143355309197, shape=(), dtype=float64) 100
# slice = key, score = 0.5365
# np.mean(results), mse, len(results) =  0.5909704852426213 tf.Tensor(322.9545463814515, shape=(), dtype=float64) 1999
# slice = train, score = 0.5909704852426213
# np.mean(results), mse, len(results) =  0.5466111111111112 tf.Tensor(328.0591780613646, shape=(), dtype=float64) 900
# slice = test, score = 0.5466111111111112
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.5384 tf.Tensor(312.705727211729, shape=(), dtype=float64) 100
# slice = key, score = 0.5384
# np.mean(results), mse, len(results) =  0.5940320160080039 tf.Tensor(323.7891235681596, shape=(), dtype=float64) 1999
# slice = train, score = 0.5940320160080039
# np.mean(results), mse, len(results) =  0.5490666666666666 tf.Tensor(329.9900099656456, shape=(), dtype=float64) 900
# slice = test, score = 0.5490666666666666
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.5396 tf.Tensor(310.89968040030357, shape=(), dtype=float64) 100
# slice = key, score = 0.5396
# np.mean(results), mse, len(results) =  0.5960780390195098 tf.Tensor(321.4302522188083, shape=(), dtype=float64) 1999
# slice = train, score = 0.5960780390195098
# np.mean(results), mse, len(results) =  0.5523555555555556 tf.Tensor(328.4876707257081, shape=(), dtype=float64) 900
# slice = test, score = 0.5523555555555556
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.5466 tf.Tensor(330.58371388031895, shape=(), dtype=float64) 100
# slice = key, score = 0.5466
# np.mean(results), mse, len(results) =  0.5998549274637319 tf.Tensor(333.4403618324111, shape=(), dtype=float64) 1999
# slice = train, score = 0.5998549274637319
# np.mean(results), mse, len(results) =  0.5545888888888889 tf.Tensor(340.11190990700703, shape=(), dtype=float64) 900
# slice = test, score = 0.5545888888888889
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.5462 tf.Tensor(334.54933603742154, shape=(), dtype=float64) 100
# slice = key, score = 0.5462
# np.mean(results), mse, len(results) =  0.6019459729864932 tf.Tensor(338.92582206457814, shape=(), dtype=float64) 1999
# slice = train, score = 0.6019459729864932
# np.mean(results), mse, len(results) =  0.5584888888888889 tf.Tensor(344.16435586616063, shape=(), dtype=float64) 900
# slice = test, score = 0.5584888888888889
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.5461 tf.Tensor(337.8840396893016, shape=(), dtype=float64) 100
# slice = key, score = 0.5461
# np.mean(results), mse, len(results) =  0.6040270135067534 tf.Tensor(341.70103329759945, shape=(), dtype=float64) 1999
# slice = train, score = 0.6040270135067534
# np.mean(results), mse, len(results) =  0.5587888888888889 tf.Tensor(347.4823017348296, shape=(), dtype=float64) 900
# slice = test, score = 0.5587888888888889
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.5469 tf.Tensor(355.21287912500367, shape=(), dtype=float64) 100
# slice = key, score = 0.5469
# np.mean(results), mse, len(results) =  0.6061530765382691 tf.Tensor(353.0155149879988, shape=(), dtype=float64) 1999
# slice = train, score = 0.6061530765382691
# np.mean(results), mse, len(results) =  0.5614666666666667 tf.Tensor(357.32170414629695, shape=(), dtype=float64) 900
# slice = test, score = 0.5614666666666667
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.5470999999999999 tf.Tensor(355.48775177603096, shape=(), dtype=float64) 100
# slice = key, score = 0.5470999999999999
# np.mean(results), mse, len(results) =  0.6084442221110556 tf.Tensor(354.3395604561594, shape=(), dtype=float64) 1999
# slice = train, score = 0.6084442221110556
# np.mean(results), mse, len(results) =  0.562188888888889 tf.Tensor(358.73565217996645, shape=(), dtype=float64) 900
# slice = test, score = 0.562188888888889
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.5476999999999999 tf.Tensor(380.25355297432367, shape=(), dtype=float64) 100
# slice = key, score = 0.5476999999999999
# np.mean(results), mse, len(results) =  0.6102151075537768 tf.Tensor(374.4071836935728, shape=(), dtype=float64) 1999
# slice = train, score = 0.6102151075537768
# np.mean(results), mse, len(results) =  0.566011111111111 tf.Tensor(379.4241576937683, shape=(), dtype=float64) 900
# slice = test, score = 0.566011111111111
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.5515 tf.Tensor(361.4057987725619, shape=(), dtype=float64) 100
# slice = key, score = 0.5515
# np.mean(results), mse, len(results) =  0.6125412706353177 tf.Tensor(355.7389226242154, shape=(), dtype=float64) 1999
# slice = train, score = 0.6125412706353177
# np.mean(results), mse, len(results) =  0.567811111111111 tf.Tensor(360.37521642015736, shape=(), dtype=float64) 900
# slice = test, score = 0.567811111111111
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.5522 tf.Tensor(357.36883648263034, shape=(), dtype=float64) 100
# slice = key, score = 0.5522
# np.mean(results), mse, len(results) =  0.6148524262131065 tf.Tensor(355.60293849399494, shape=(), dtype=float64) 1999
# slice = train, score = 0.6148524262131065
# np.mean(results), mse, len(results) =  0.5691888888888889 tf.Tensor(359.53932819766305, shape=(), dtype=float64) 900
# slice = test, score = 0.5691888888888889
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.5527000000000001 tf.Tensor(367.60835823105265, shape=(), dtype=float64) 100
# slice = key, score = 0.5527000000000001
# np.mean(results), mse, len(results) =  0.6163481740870436 tf.Tensor(362.2480494549728, shape=(), dtype=float64) 1999
# slice = train, score = 0.6163481740870436
# np.mean(results), mse, len(results) =  0.5718 tf.Tensor(367.73441722141115, shape=(), dtype=float64) 900
# slice = test, score = 0.5718
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.5562 tf.Tensor(368.1881571144068, shape=(), dtype=float64) 100
# slice = key, score = 0.5562
# np.mean(results), mse, len(results) =  0.6176238119059531 tf.Tensor(367.50868570347825, shape=(), dtype=float64) 1999
# slice = train, score = 0.6176238119059531
# np.mean(results), mse, len(results) =  0.5730333333333334 tf.Tensor(371.99253887126986, shape=(), dtype=float64) 900
# slice = test, score = 0.5730333333333334
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.5546 tf.Tensor(375.35466385022096, shape=(), dtype=float64) 100
# slice = key, score = 0.5546
# np.mean(results), mse, len(results) =  0.6190945472736369 tf.Tensor(373.22411316330266, shape=(), dtype=float64) 1999
# slice = train, score = 0.6190945472736369
# np.mean(results), mse, len(results) =  0.5742333333333333 tf.Tensor(377.1274016566756, shape=(), dtype=float64) 900
# slice = test, score = 0.5742333333333333
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.5575000000000001 tf.Tensor(379.3797645966218, shape=(), dtype=float64) 100
# slice = key, score = 0.5575000000000001
# np.mean(results), mse, len(results) =  0.620815407703852 tf.Tensor(377.8568809086803, shape=(), dtype=float64) 1999
# slice = train, score = 0.620815407703852
# np.mean(results), mse, len(results) =  0.5752444444444443 tf.Tensor(383.01719542158213, shape=(), dtype=float64) 900
# slice = test, score = 0.5752444444444443
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.5575 tf.Tensor(382.34851336781156, shape=(), dtype=float64) 100
# slice = key, score = 0.5575
# np.mean(results), mse, len(results) =  0.6224412206103052 tf.Tensor(380.37352866050753, shape=(), dtype=float64) 1999
# slice = train, score = 0.6224412206103052
# np.mean(results), mse, len(results) =  0.5770777777777777 tf.Tensor(385.5772212165578, shape=(), dtype=float64) 900
# slice = test, score = 0.5770777777777777
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.5588000000000001 tf.Tensor(386.3359607818226, shape=(), dtype=float64) 100
# slice = key, score = 0.5588000000000001
# np.mean(results), mse, len(results) =  0.6233666833416709 tf.Tensor(388.58673306674035, shape=(), dtype=float64) 1999
# slice = train, score = 0.6233666833416709
# np.mean(results), mse, len(results) =  0.5774777777777778 tf.Tensor(392.86710363509013, shape=(), dtype=float64) 900
# slice = test, score = 0.5774777777777778
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.5636000000000001 tf.Tensor(388.7396313617434, shape=(), dtype=float64) 100
# slice = key, score = 0.5636000000000001
# np.mean(results), mse, len(results) =  0.6249074537268634 tf.Tensor(388.1502177992955, shape=(), dtype=float64) 1999
# slice = train, score = 0.6249074537268634
# np.mean(results), mse, len(results) =  0.5796000000000001 tf.Tensor(392.54487561665724, shape=(), dtype=float64) 900
# slice = test, score = 0.5796000000000001
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.5602 tf.Tensor(400.4112918422043, shape=(), dtype=float64) 100
# slice = key, score = 0.5602
# np.mean(results), mse, len(results) =  0.6251225612806403 tf.Tensor(398.9847976755642, shape=(), dtype=float64) 1999
# slice = train, score = 0.6251225612806403
# np.mean(results), mse, len(results) =  0.5799666666666667 tf.Tensor(404.8723087690498, shape=(), dtype=float64) 900
# slice = test, score = 0.5799666666666667
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.5596 tf.Tensor(395.97563495306525, shape=(), dtype=float64) 100
# slice = key, score = 0.5596
# np.mean(results), mse, len(results) =  0.6273336668334167 tf.Tensor(399.5779666503636, shape=(), dtype=float64) 1999
# slice = train, score = 0.6273336668334167
# np.mean(results), mse, len(results) =  0.5806444444444445 tf.Tensor(404.594967358639, shape=(), dtype=float64) 900
# slice = test, score = 0.5806444444444445
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.5649 tf.Tensor(409.6459496772327, shape=(), dtype=float64) 100
# slice = key, score = 0.5649
# np.mean(results), mse, len(results) =  0.6282891445722861 tf.Tensor(410.52719705134587, shape=(), dtype=float64) 1999
# slice = train, score = 0.6282891445722861
# np.mean(results), mse, len(results) =  0.5836666666666667 tf.Tensor(416.0043479930355, shape=(), dtype=float64) 900
# slice = test, score = 0.5836666666666667
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.5636 tf.Tensor(409.71310592480546, shape=(), dtype=float64) 100
# slice = key, score = 0.5636
# np.mean(results), mse, len(results) =  0.6298599299649825 tf.Tensor(408.8976902484668, shape=(), dtype=float64) 1999
# slice = train, score = 0.6298599299649825
# np.mean(results), mse, len(results) =  0.5836666666666667 tf.Tensor(412.66608863507383, shape=(), dtype=float64) 900
# slice = test, score = 0.5836666666666667
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.5639 tf.Tensor(414.0602761944175, shape=(), dtype=float64) 100
# slice = key, score = 0.5639
# np.mean(results), mse, len(results) =  0.6300200100050025 tf.Tensor(413.6592526741464, shape=(), dtype=float64) 1999
# slice = train, score = 0.6300200100050025
# np.mean(results), mse, len(results) =  0.5833111111111111 tf.Tensor(419.590284833401, shape=(), dtype=float64) 900
# slice = test, score = 0.5833111111111111
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.5667 tf.Tensor(394.2513283530867, shape=(), dtype=float64) 100
# slice = key, score = 0.5667
# np.mean(results), mse, len(results) =  0.631935967983992 tf.Tensor(401.6402254465587, shape=(), dtype=float64) 1999
# slice = train, score = 0.631935967983992
# np.mean(results), mse, len(results) =  0.5872999999999999 tf.Tensor(405.53226619877216, shape=(), dtype=float64) 900
# slice = test, score = 0.5872999999999999
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.5668000000000001 tf.Tensor(410.0631980785007, shape=(), dtype=float64) 100
# slice = key, score = 0.5668000000000001
# np.mean(results), mse, len(results) =  0.633376688344172 tf.Tensor(407.73018611438124, shape=(), dtype=float64) 1999
# slice = train, score = 0.633376688344172
# np.mean(results), mse, len(results) =  0.5864 tf.Tensor(414.26712444503875, shape=(), dtype=float64) 900
# slice = test, score = 0.5864
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.5701999999999999 tf.Tensor(406.5474640452581, shape=(), dtype=float64) 100
# slice = key, score = 0.5701999999999999
# np.mean(results), mse, len(results) =  0.6341270635317658 tf.Tensor(410.8219370150687, shape=(), dtype=float64) 1999
# slice = train, score = 0.6341270635317658
# np.mean(results), mse, len(results) =  0.5872999999999999 tf.Tensor(414.2608453707977, shape=(), dtype=float64) 900
# slice = test, score = 0.5872999999999999
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.5699 tf.Tensor(417.37302963068595, shape=(), dtype=float64) 100
# slice = key, score = 0.5699
# np.mean(results), mse, len(results) =  0.6354177088544272 tf.Tensor(418.32315663276955, shape=(), dtype=float64) 1999
# slice = train, score = 0.6354177088544272
# np.mean(results), mse, len(results) =  0.5889888888888889 tf.Tensor(422.185682395562, shape=(), dtype=float64) 900
# slice = test, score = 0.5889888888888889
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.5682 tf.Tensor(433.63145540987085, shape=(), dtype=float64) 100
# slice = key, score = 0.5682
# np.mean(results), mse, len(results) =  0.6358629314657328 tf.Tensor(427.61966879503353, shape=(), dtype=float64) 1999
# slice = train, score = 0.6358629314657328
# np.mean(results), mse, len(results) =  0.5900444444444444 tf.Tensor(433.0590218227756, shape=(), dtype=float64) 900
# slice = test, score = 0.5900444444444444
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.5708 tf.Tensor(430.6019136057971, shape=(), dtype=float64) 100
# slice = key, score = 0.5708
# np.mean(results), mse, len(results) =  0.636928464232116 tf.Tensor(426.3441386151139, shape=(), dtype=float64) 1999
# slice = train, score = 0.636928464232116
# np.mean(results), mse, len(results) =  0.5897999999999999 tf.Tensor(432.61742104169605, shape=(), dtype=float64) 900
# slice = test, score = 0.5897999999999999
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.5718999999999999 tf.Tensor(431.87286669079305, shape=(), dtype=float64) 100
# slice = key, score = 0.5718999999999999
# np.mean(results), mse, len(results) =  0.6379339669834918 tf.Tensor(427.7520904672694, shape=(), dtype=float64) 1999
# slice = train, score = 0.6379339669834918
# np.mean(results), mse, len(results) =  0.5903333333333333 tf.Tensor(433.89629936001353, shape=(), dtype=float64) 900
# slice = test, score = 0.5903333333333333
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.5708999999999999 tf.Tensor(434.94745702157303, shape=(), dtype=float64) 100
# slice = key, score = 0.5708999999999999
# np.mean(results), mse, len(results) =  0.638304152076038 tf.Tensor(423.3674195069877, shape=(), dtype=float64) 1999
# slice = train, score = 0.638304152076038
# np.mean(results), mse, len(results) =  0.5909555555555556 tf.Tensor(429.4682864098225, shape=(), dtype=float64) 900
# slice = test, score = 0.5909555555555556
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.5756999999999999 tf.Tensor(451.7313335909418, shape=(), dtype=float64) 100
# slice = key, score = 0.5756999999999999
# np.mean(results), mse, len(results) =  0.6402001000500251 tf.Tensor(442.4844870107778, shape=(), dtype=float64) 1999
# slice = train, score = 0.6402001000500251
# np.mean(results), mse, len(results) =  0.5925333333333334 tf.Tensor(448.74171173441397, shape=(), dtype=float64) 900
# slice = test, score = 0.5925333333333334
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.5752 tf.Tensor(441.8286576666339, shape=(), dtype=float64) 100
# slice = key, score = 0.5752
# np.mean(results), mse, len(results) =  0.64064032016008 tf.Tensor(436.95092307168534, shape=(), dtype=float64) 1999
# slice = train, score = 0.64064032016008
# np.mean(results), mse, len(results) =  0.5930666666666666 tf.Tensor(443.502284530244, shape=(), dtype=float64) 900
# slice = test, score = 0.5930666666666666
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.5753999999999999 tf.Tensor(466.13818238610446, shape=(), dtype=float64) 100
# slice = key, score = 0.5753999999999999
# np.mean(results), mse, len(results) =  0.6410705352676338 tf.Tensor(456.0863189219764, shape=(), dtype=float64) 1999
# slice = train, score = 0.6410705352676338
# np.mean(results), mse, len(results) =  0.594 tf.Tensor(463.07427289174814, shape=(), dtype=float64) 900
# slice = test, score = 0.594
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.5757999999999999 tf.Tensor(465.2912359868212, shape=(), dtype=float64) 100
# slice = key, score = 0.5757999999999999
# np.mean(results), mse, len(results) =  0.6425262631315658 tf.Tensor(456.45396037300964, shape=(), dtype=float64) 1999
# slice = train, score = 0.6425262631315658
# np.mean(results), mse, len(results) =  0.595688888888889 tf.Tensor(462.4941662753442, shape=(), dtype=float64) 900
# slice = test, score = 0.595688888888889
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.5801000000000001 tf.Tensor(455.6388063700171, shape=(), dtype=float64) 100
# slice = key, score = 0.5801000000000001
# np.mean(results), mse, len(results) =  0.6437668834417208 tf.Tensor(449.8160828378191, shape=(), dtype=float64) 1999
# slice = train, score = 0.6437668834417208
# np.mean(results), mse, len(results) =  0.5952222222222221 tf.Tensor(455.9101083105798, shape=(), dtype=float64) 900
# slice = test, score = 0.5952222222222221
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.5774999999999999 tf.Tensor(460.90598085946306, shape=(), dtype=float64) 100
# slice = key, score = 0.5774999999999999
# np.mean(results), mse, len(results) =  0.6445772886443222 tf.Tensor(453.28080740605407, shape=(), dtype=float64) 1999
# slice = train, score = 0.6445772886443222
# np.mean(results), mse, len(results) =  0.5959000000000001 tf.Tensor(459.6680410241512, shape=(), dtype=float64) 900
# slice = test, score = 0.5959000000000001
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.5792 tf.Tensor(465.6466431972924, shape=(), dtype=float64) 100
# slice = key, score = 0.5792
# np.mean(results), mse, len(results) =  0.6450975487743872 tf.Tensor(459.763850846965, shape=(), dtype=float64) 1999
# slice = train, score = 0.6450975487743872
# np.mean(results), mse, len(results) =  0.5975444444444444 tf.Tensor(467.78803301235126, shape=(), dtype=float64) 900
# slice = test, score = 0.5975444444444444
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.5829000000000001 tf.Tensor(467.97982091080223, shape=(), dtype=float64) 100
# slice = key, score = 0.5829000000000001
# np.mean(results), mse, len(results) =  0.6464682341170586 tf.Tensor(459.86109371111365, shape=(), dtype=float64) 1999
# slice = train, score = 0.6464682341170586
# np.mean(results), mse, len(results) =  0.5988888888888889 tf.Tensor(467.71519843121496, shape=(), dtype=float64) 900
# slice = test, score = 0.5988888888888889
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.5795 tf.Tensor(473.86019158639033, shape=(), dtype=float64) 100
# slice = key, score = 0.5795
# np.mean(results), mse, len(results) =  0.6470985492746372 tf.Tensor(456.0375041073097, shape=(), dtype=float64) 1999
# slice = train, score = 0.6470985492746372
# np.mean(results), mse, len(results) =  0.5976444444444445 tf.Tensor(465.20235683781726, shape=(), dtype=float64) 900
# slice = test, score = 0.5976444444444445
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.5822999999999999 tf.Tensor(459.01366614508044, shape=(), dtype=float64) 100
# slice = key, score = 0.5822999999999999
# np.mean(results), mse, len(results) =  0.6476988494247123 tf.Tensor(448.0982108740837, shape=(), dtype=float64) 1999
# slice = train, score = 0.6476988494247123
# np.mean(results), mse, len(results) =  0.5998555555555556 tf.Tensor(454.3029061667135, shape=(), dtype=float64) 900
# slice = test, score = 0.5998555555555556
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.5812 tf.Tensor(472.57140750163205, shape=(), dtype=float64) 100
# slice = key, score = 0.5812
# np.mean(results), mse, len(results) =  0.6480740370185093 tf.Tensor(458.02355911857245, shape=(), dtype=float64) 1999
# slice = train, score = 0.6480740370185093
# np.mean(results), mse, len(results) =  0.6003999999999999 tf.Tensor(464.4532295601014, shape=(), dtype=float64) 900
# slice = test, score = 0.6003999999999999
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.5831000000000001 tf.Tensor(469.02201030434924, shape=(), dtype=float64) 100
# slice = key, score = 0.5831000000000001
# np.mean(results), mse, len(results) =  0.6494897448724362 tf.Tensor(451.9812117291627, shape=(), dtype=float64) 1999
# slice = train, score = 0.6494897448724362
# np.mean(results), mse, len(results) =  0.6008333333333333 tf.Tensor(458.4968589167422, shape=(), dtype=float64) 900
# slice = test, score = 0.6008333333333333
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.5856 tf.Tensor(481.060531621402, shape=(), dtype=float64) 100
# slice = key, score = 0.5856
# np.mean(results), mse, len(results) =  0.6499399699849925 tf.Tensor(465.17540859448286, shape=(), dtype=float64) 1999
# slice = train, score = 0.6499399699849925
# np.mean(results), mse, len(results) =  0.6020222222222221 tf.Tensor(472.82592796026364, shape=(), dtype=float64) 900
# slice = test, score = 0.6020222222222221
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.5844999999999999 tf.Tensor(477.2727593669191, shape=(), dtype=float64) 100
# slice = key, score = 0.5844999999999999
# np.mean(results), mse, len(results) =  0.6509804902451225 tf.Tensor(466.19782256112745, shape=(), dtype=float64) 1999
# slice = train, score = 0.6509804902451225
# np.mean(results), mse, len(results) =  0.6033888888888889 tf.Tensor(472.5942869912018, shape=(), dtype=float64) 900
# slice = test, score = 0.6033888888888889
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.5895 tf.Tensor(482.01120326813697, shape=(), dtype=float64) 100
# slice = key, score = 0.5895
# np.mean(results), mse, len(results) =  0.6516758379189596 tf.Tensor(462.4388598543195, shape=(), dtype=float64) 1999
# slice = train, score = 0.6516758379189596
# np.mean(results), mse, len(results) =  0.6042 tf.Tensor(469.3295917793677, shape=(), dtype=float64) 900
# slice = test, score = 0.6042
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.5882000000000001 tf.Tensor(486.62073338035646, shape=(), dtype=float64) 100
# slice = key, score = 0.5882000000000001
# np.mean(results), mse, len(results) =  0.6524662331165583 tf.Tensor(458.7451378905471, shape=(), dtype=float64) 1999
# slice = train, score = 0.6524662331165583
# np.mean(results), mse, len(results) =  0.6031333333333334 tf.Tensor(465.2800542024613, shape=(), dtype=float64) 900
# slice = test, score = 0.6031333333333334
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.5889 tf.Tensor(500.4523356189431, shape=(), dtype=float64) 100
# slice = key, score = 0.5889
# np.mean(results), mse, len(results) =  0.6529964982491245 tf.Tensor(471.18111634390897, shape=(), dtype=float64) 1999
# slice = train, score = 0.6529964982491245
# np.mean(results), mse, len(results) =  0.6056444444444445 tf.Tensor(478.5237155166452, shape=(), dtype=float64) 900
# slice = test, score = 0.6056444444444445
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.5881 tf.Tensor(489.8567737196417, shape=(), dtype=float64) 100
# slice = key, score = 0.5881
# np.mean(results), mse, len(results) =  0.6545372686343172 tf.Tensor(466.0238088352162, shape=(), dtype=float64) 1999
# slice = train, score = 0.6545372686343172
# np.mean(results), mse, len(results) =  0.6055333333333334 tf.Tensor(473.6189217061777, shape=(), dtype=float64) 900
# slice = test, score = 0.6055333333333334
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.5897000000000001 tf.Tensor(497.5935466100447, shape=(), dtype=float64) 100
# slice = key, score = 0.5897000000000001
# np.mean(results), mse, len(results) =  0.6545322661330665 tf.Tensor(474.7759223988248, shape=(), dtype=float64) 1999
# slice = train, score = 0.6545322661330665
# np.mean(results), mse, len(results) =  0.6064444444444446 tf.Tensor(481.7696620879358, shape=(), dtype=float64) 900
# slice = test, score = 0.6064444444444446
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.5876 tf.Tensor(504.9046739536826, shape=(), dtype=float64) 100
# slice = key, score = 0.5876
# np.mean(results), mse, len(results) =  0.6555327663831915 tf.Tensor(480.6943292148813, shape=(), dtype=float64) 1999
# slice = train, score = 0.6555327663831915
# np.mean(results), mse, len(results) =  0.6074333333333334 tf.Tensor(489.33977033311277, shape=(), dtype=float64) 900
# slice = test, score = 0.6074333333333334
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.5918 tf.Tensor(504.92720593448104, shape=(), dtype=float64) 100
# slice = key, score = 0.5918
# np.mean(results), mse, len(results) =  0.6559879939969985 tf.Tensor(482.8900290902211, shape=(), dtype=float64) 1999
# slice = train, score = 0.6559879939969985
# np.mean(results), mse, len(results) =  0.6087666666666667 tf.Tensor(490.33685258288835, shape=(), dtype=float64) 900
# slice = test, score = 0.6087666666666667
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.5919000000000001 tf.Tensor(514.1698554932988, shape=(), dtype=float64) 100
# slice = key, score = 0.5919000000000001
# np.mean(results), mse, len(results) =  0.6567683841920962 tf.Tensor(487.8705284298462, shape=(), dtype=float64) 1999
# slice = train, score = 0.6567683841920962
# np.mean(results), mse, len(results) =  0.6073666666666668 tf.Tensor(496.4593854770242, shape=(), dtype=float64) 900
# slice = test, score = 0.6073666666666668
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.5899 tf.Tensor(503.0184978107141, shape=(), dtype=float64) 100
# slice = key, score = 0.5899
# np.mean(results), mse, len(results) =  0.6574437218609305 tf.Tensor(481.24113264470486, shape=(), dtype=float64) 1999
# slice = train, score = 0.6574437218609305
# np.mean(results), mse, len(results) =  0.6089222222222221 tf.Tensor(489.6448995017493, shape=(), dtype=float64) 900
# slice = test, score = 0.6089222222222221
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.5905 tf.Tensor(500.2571865954421, shape=(), dtype=float64) 100
# slice = key, score = 0.5905
# np.mean(results), mse, len(results) =  0.6576938469234618 tf.Tensor(475.4531168776738, shape=(), dtype=float64) 1999
# slice = train, score = 0.6576938469234618
# np.mean(results), mse, len(results) =  0.6087444444444444 tf.Tensor(483.8284920075693, shape=(), dtype=float64) 900
# slice = test, score = 0.6087444444444444
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.5905999999999999 tf.Tensor(505.78890446813176, shape=(), dtype=float64) 100
# slice = key, score = 0.5905999999999999
# np.mean(results), mse, len(results) =  0.659239619809905 tf.Tensor(479.4324539761243, shape=(), dtype=float64) 1999
# slice = train, score = 0.659239619809905
# np.mean(results), mse, len(results) =  0.6099555555555555 tf.Tensor(487.0920887798374, shape=(), dtype=float64) 900
# slice = test, score = 0.6099555555555555
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.5941000000000001 tf.Tensor(517.5944733351524, shape=(), dtype=float64) 100
# slice = key, score = 0.5941000000000001
# np.mean(results), mse, len(results) =  0.6588294147073537 tf.Tensor(489.13999869849124, shape=(), dtype=float64) 1999
# slice = train, score = 0.6588294147073537
# np.mean(results), mse, len(results) =  0.6095666666666667 tf.Tensor(496.90814221812013, shape=(), dtype=float64) 900
# slice = test, score = 0.6095666666666667
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.5905000000000001 tf.Tensor(511.0755865461331, shape=(), dtype=float64) 100
# slice = key, score = 0.5905000000000001
# np.mean(results), mse, len(results) =  0.6594297148574286 tf.Tensor(475.5310928969059, shape=(), dtype=float64) 1999
# slice = train, score = 0.6594297148574286
# np.mean(results), mse, len(results) =  0.6103444444444444 tf.Tensor(484.26441452130035, shape=(), dtype=float64) 900
# slice = test, score = 0.6103444444444444
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.5961000000000001 tf.Tensor(522.7270698715216, shape=(), dtype=float64) 100
# slice = key, score = 0.5961000000000001
# np.mean(results), mse, len(results) =  0.6603351675837918 tf.Tensor(488.698904597052, shape=(), dtype=float64) 1999
# slice = train, score = 0.6603351675837918
# np.mean(results), mse, len(results) =  0.6112222222222221 tf.Tensor(499.70247595351725, shape=(), dtype=float64) 900
# slice = test, score = 0.6112222222222221
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.5965999999999999 tf.Tensor(532.5136845933425, shape=(), dtype=float64) 100
# slice = key, score = 0.5965999999999999
# np.mean(results), mse, len(results) =  0.6611455727863932 tf.Tensor(501.5610416469179, shape=(), dtype=float64) 1999
# slice = train, score = 0.6611455727863932
# np.mean(results), mse, len(results) =  0.6118333333333335 tf.Tensor(510.47836412009786, shape=(), dtype=float64) 900
# slice = test, score = 0.6118333333333335
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.5962000000000001 tf.Tensor(535.0427877600407, shape=(), dtype=float64) 100
# slice = key, score = 0.5962000000000001
# np.mean(results), mse, len(results) =  0.6618559279639821 tf.Tensor(496.3798713076038, shape=(), dtype=float64) 1999
# slice = train, score = 0.6618559279639821
# np.mean(results), mse, len(results) =  0.6123333333333333 tf.Tensor(506.8074698972608, shape=(), dtype=float64) 900
# slice = test, score = 0.6123333333333333
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.5975999999999999 tf.Tensor(530.128742413757, shape=(), dtype=float64) 100
# slice = key, score = 0.5975999999999999
# np.mean(results), mse, len(results) =  0.6618909454727363 tf.Tensor(485.81171985459656, shape=(), dtype=float64) 1999
# slice = train, score = 0.6618909454727363
# np.mean(results), mse, len(results) =  0.6133222222222222 tf.Tensor(496.9134334994083, shape=(), dtype=float64) 900
# slice = test, score = 0.6133222222222222
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.5979999999999999 tf.Tensor(533.1508720270834, shape=(), dtype=float64) 100
# slice = key, score = 0.5979999999999999
# np.mean(results), mse, len(results) =  0.6627113556778389 tf.Tensor(500.06856978022506, shape=(), dtype=float64) 1999
# slice = train, score = 0.6627113556778389
# np.mean(results), mse, len(results) =  0.6132777777777777 tf.Tensor(509.4068562081868, shape=(), dtype=float64) 900
# slice = test, score = 0.6132777777777777
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.5972999999999999 tf.Tensor(538.686778284996, shape=(), dtype=float64) 100
# slice = key, score = 0.5972999999999999
# np.mean(results), mse, len(results) =  0.6632516258129065 tf.Tensor(503.7438721378788, shape=(), dtype=float64) 1999
# slice = train, score = 0.6632516258129065
# np.mean(results), mse, len(results) =  0.6148888888888888 tf.Tensor(512.3927651392149, shape=(), dtype=float64) 900
# slice = test, score = 0.6148888888888888
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.5965 tf.Tensor(545.6308142920547, shape=(), dtype=float64) 100
# slice = key, score = 0.5965
# np.mean(results), mse, len(results) =  0.6634067033516758 tf.Tensor(502.6758183938036, shape=(), dtype=float64) 1999
# slice = train, score = 0.6634067033516758
# np.mean(results), mse, len(results) =  0.6141888888888889 tf.Tensor(510.5492507059993, shape=(), dtype=float64) 900
# slice = test, score = 0.6141888888888889
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.5965 tf.Tensor(535.8260080159477, shape=(), dtype=float64) 100
# slice = key, score = 0.5965
# np.mean(results), mse, len(results) =  0.6650875437718861 tf.Tensor(497.44144690999116, shape=(), dtype=float64) 1999
# slice = train, score = 0.6650875437718861
# np.mean(results), mse, len(results) =  0.6143333333333334 tf.Tensor(508.208361010191, shape=(), dtype=float64) 900
# slice = test, score = 0.6143333333333334
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.6006999999999999 tf.Tensor(540.7829745594365, shape=(), dtype=float64) 100
# slice = key, score = 0.6006999999999999
# np.mean(results), mse, len(results) =  0.6652026013006503 tf.Tensor(504.524400239814, shape=(), dtype=float64) 1999
# slice = train, score = 0.6652026013006503
# np.mean(results), mse, len(results) =  0.6152222222222221 tf.Tensor(512.4676656184948, shape=(), dtype=float64) 900
# slice = test, score = 0.6152222222222221
#
# === Iteration 90000 ===
# np.mean(results), mse, len(results) =  0.6003000000000001 tf.Tensor(521.7838702297181, shape=(), dtype=float64) 100
# slice = key, score = 0.6003000000000001
# np.mean(results), mse, len(results) =  0.665767883941971 tf.Tensor(496.0311230605451, shape=(), dtype=float64) 1999
# slice = train, score = 0.665767883941971
# np.mean(results), mse, len(results) =  0.6161888888888888 tf.Tensor(505.0988090345554, shape=(), dtype=float64) 900
# slice = test, score = 0.6161888888888888
#
# === Iteration 91000 ===
# np.mean(results), mse, len(results) =  0.6000000000000001 tf.Tensor(541.2493521116421, shape=(), dtype=float64) 100
# slice = key, score = 0.6000000000000001
# np.mean(results), mse, len(results) =  0.6663231615807904 tf.Tensor(505.458156299208, shape=(), dtype=float64) 1999
# slice = train, score = 0.6663231615807904
# np.mean(results), mse, len(results) =  0.6159777777777777 tf.Tensor(516.0020294977912, shape=(), dtype=float64) 900
# slice = test, score = 0.6159777777777777
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.5983999999999999 tf.Tensor(566.1948277084693, shape=(), dtype=float64) 100
# slice = key, score = 0.5983999999999999
# np.mean(results), mse, len(results) =  0.6666333166583291 tf.Tensor(518.7764334186423, shape=(), dtype=float64) 1999
# slice = train, score = 0.6666333166583291
# np.mean(results), mse, len(results) =  0.6152777777777778 tf.Tensor(528.9500323863062, shape=(), dtype=float64) 900
# slice = test, score = 0.6152777777777778
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.6016999999999999 tf.Tensor(563.1508855045082, shape=(), dtype=float64) 100
# slice = key, score = 0.6016999999999999
# np.mean(results), mse, len(results) =  0.6674687343671836 tf.Tensor(521.2894364244013, shape=(), dtype=float64) 1999
# slice = train, score = 0.6674687343671836
# np.mean(results), mse, len(results) =  0.6153888888888889 tf.Tensor(532.0556974097686, shape=(), dtype=float64) 900
# slice = test, score = 0.6153888888888889
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.6007 tf.Tensor(544.897994605728, shape=(), dtype=float64) 100
# slice = key, score = 0.6007
# np.mean(results), mse, len(results) =  0.6681990995497749 tf.Tensor(507.0512138026894, shape=(), dtype=float64) 1999
# slice = train, score = 0.6681990995497749
# np.mean(results), mse, len(results) =  0.6189888888888889 tf.Tensor(515.230727617421, shape=(), dtype=float64) 900
# slice = test, score = 0.6189888888888889
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.6015 tf.Tensor(541.9913330133189, shape=(), dtype=float64) 100
# slice = key, score = 0.6015
# np.mean(results), mse, len(results) =  0.6685342671335668 tf.Tensor(504.98832777772947, shape=(), dtype=float64) 1999
# slice = train, score = 0.6685342671335668
# np.mean(results), mse, len(results) =  0.6186555555555555 tf.Tensor(513.0970325384487, shape=(), dtype=float64) 900
# slice = test, score = 0.6186555555555555
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.6003999999999999 tf.Tensor(541.405610654323, shape=(), dtype=float64) 100
# slice = key, score = 0.6003999999999999
# np.mean(results), mse, len(results) =  0.6688944472236118 tf.Tensor(511.52796906812466, shape=(), dtype=float64) 1999
# slice = train, score = 0.6688944472236118
# np.mean(results), mse, len(results) =  0.6190666666666668 tf.Tensor(519.1410976359363, shape=(), dtype=float64) 900
# slice = test, score = 0.6190666666666668
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.602 tf.Tensor(568.5520663245356, shape=(), dtype=float64) 100
# slice = key, score = 0.602
# np.mean(results), mse, len(results) =  0.6692796398199099 tf.Tensor(526.2667249013361, shape=(), dtype=float64) 1999
# slice = train, score = 0.6692796398199099
# np.mean(results), mse, len(results) =  0.6178777777777779 tf.Tensor(533.9778632168819, shape=(), dtype=float64) 900
# slice = test, score = 0.6178777777777779
#
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.6016999999999999 tf.Tensor(539.5689958458406, shape=(), dtype=float64) 100
# slice = key, score = 0.6016999999999999
# np.mean(results), mse, len(results) =  0.6706453226613306 tf.Tensor(504.84990291817684, shape=(), dtype=float64) 1999
# slice = train, score = 0.6706453226613306
# np.mean(results), mse, len(results) =  0.6186999999999999 tf.Tensor(511.1943617149423, shape=(), dtype=float64) 900
# slice = test, score = 0.6186999999999999
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.6046 tf.Tensor(536.1399100082859, shape=(), dtype=float64) 100
# slice = key, score = 0.6046
# np.mean(results), mse, len(results) =  0.6713206603301651 tf.Tensor(499.6080706433746, shape=(), dtype=float64) 1999
# slice = train, score = 0.6713206603301651
# np.mean(results), mse, len(results) =  0.6199555555555556 tf.Tensor(506.8212700599283, shape=(), dtype=float64) 900
# slice = test, score = 0.6199555555555556
# last loss =  tf.Tensor(-0.006119552417097086, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.6704102051025513 tf.Tensor(513.0205444750663, shape=(), dtype=float64) 1999
# np.mean(results), mse, len(results) =  0.6194444444444445 tf.Tensor(520.8729059489712, shape=(), dtype=float64) 900
# (0.6704102051025513, 0.6194444444444445)

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': True,
    'train_popbias': True, 'train_bias': True,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": False, # <<< DIFF HERE
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (1999, 100)
# self.embed_games.shape =  (24493, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 24493)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (1999, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.0076 tf.Tensor(37.992577, shape=(), dtype=float32) 100
# slice = key, score = 0.0076
# np.mean(results), mse, len(results) =  0.005427713856928464 tf.Tensor(39.957115, shape=(), dtype=float32) 1999
# slice = train, score = 0.005427713856928464
# np.mean(results), mse, len(results) =  0.005055555555555555 tf.Tensor(40.072792, shape=(), dtype=float32) 900
# slice = test, score = 0.005055555555555555
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.565 tf.Tensor(47.54262, shape=(), dtype=float32) 100
# slice = key, score = 0.565
# np.mean(results), mse, len(results) =  0.6378989494747372 tf.Tensor(47.944195, shape=(), dtype=float32) 1999
# slice = train, score = 0.6378989494747372
# np.mean(results), mse, len(results) =  0.5981222222222221 tf.Tensor(47.915123, shape=(), dtype=float32) 900
# slice = test, score = 0.5981222222222221
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5946 tf.Tensor(67.287445, shape=(), dtype=float32) 100
# slice = key, score = 0.5946
# np.mean(results), mse, len(results) =  0.6725162581290646 tf.Tensor(67.44595, shape=(), dtype=float32) 1999
# slice = train, score = 0.6725162581290646
# np.mean(results), mse, len(results) =  0.6290222222222224 tf.Tensor(67.63256, shape=(), dtype=float32) 900
# slice = test, score = 0.6290222222222224
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.6062999999999998 tf.Tensor(88.04675, shape=(), dtype=float32) 100
# slice = key, score = 0.6062999999999998
# np.mean(results), mse, len(results) =  0.6825862931465733 tf.Tensor(88.39016, shape=(), dtype=float32) 1999
# slice = train, score = 0.6825862931465733
# np.mean(results), mse, len(results) =  0.6388888888888888 tf.Tensor(88.76994, shape=(), dtype=float32) 900
# slice = test, score = 0.6388888888888888
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.607 tf.Tensor(105.604195, shape=(), dtype=float32) 100
# slice = key, score = 0.607
# np.mean(results), mse, len(results) =  0.6891645822911455 tf.Tensor(105.97767, shape=(), dtype=float32) 1999
# slice = train, score = 0.6891645822911455
# np.mean(results), mse, len(results) =  0.6468111111111111 tf.Tensor(106.60412, shape=(), dtype=float32) 900
# slice = test, score = 0.6468111111111111
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6032000000000001 tf.Tensor(126.54829, shape=(), dtype=float32) 100
# slice = key, score = 0.6032000000000001
# np.mean(results), mse, len(results) =  0.6916408204102051 tf.Tensor(126.95886, shape=(), dtype=float32) 1999
# slice = train, score = 0.6916408204102051
# np.mean(results), mse, len(results) =  0.6480888888888889 tf.Tensor(127.8929, shape=(), dtype=float32) 900
# slice = test, score = 0.6480888888888889
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6118 tf.Tensor(140.9158, shape=(), dtype=float32) 100
# slice = key, score = 0.6118
# np.mean(results), mse, len(results) =  0.694727363681841 tf.Tensor(141.82874, shape=(), dtype=float32) 1999
# slice = train, score = 0.694727363681841
# np.mean(results), mse, len(results) =  0.6496888888888889 tf.Tensor(142.51282, shape=(), dtype=float32) 900
# slice = test, score = 0.6496888888888889
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6113000000000001 tf.Tensor(159.37875, shape=(), dtype=float32) 100
# slice = key, score = 0.6113000000000001
# np.mean(results), mse, len(results) =  0.6968184092046024 tf.Tensor(160.0952, shape=(), dtype=float32) 1999
# slice = train, score = 0.6968184092046024
# np.mean(results), mse, len(results) =  0.6497 tf.Tensor(161.49765, shape=(), dtype=float32) 900
# slice = test, score = 0.6497
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.6126999999999999 tf.Tensor(173.90674, shape=(), dtype=float32) 100
# slice = key, score = 0.6126999999999999
# np.mean(results), mse, len(results) =  0.6983841920960481 tf.Tensor(175.17549, shape=(), dtype=float32) 1999
# slice = train, score = 0.6983841920960481
# np.mean(results), mse, len(results) =  0.6513777777777778 tf.Tensor(176.23856, shape=(), dtype=float32) 900
# slice = test, score = 0.6513777777777778
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.6128 tf.Tensor(190.12575, shape=(), dtype=float32) 100
# slice = key, score = 0.6128
# np.mean(results), mse, len(results) =  0.7009504752376187 tf.Tensor(190.07385, shape=(), dtype=float32) 1999
# slice = train, score = 0.7009504752376187
# np.mean(results), mse, len(results) =  0.6521222222222222 tf.Tensor(190.72153, shape=(), dtype=float32) 900
# slice = test, score = 0.6521222222222222
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.6134 tf.Tensor(202.14189, shape=(), dtype=float32) 100
# slice = key, score = 0.6134
# np.mean(results), mse, len(results) =  0.7025462731365684 tf.Tensor(204.25462, shape=(), dtype=float32) 1999
# slice = train, score = 0.7025462731365684
# np.mean(results), mse, len(results) =  0.653411111111111 tf.Tensor(205.15184, shape=(), dtype=float32) 900
# slice = test, score = 0.653411111111111
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.6187 tf.Tensor(223.90079, shape=(), dtype=float32) 100
# slice = key, score = 0.6187
# np.mean(results), mse, len(results) =  0.704152076038019 tf.Tensor(223.39096, shape=(), dtype=float32) 1999
# slice = train, score = 0.704152076038019
# np.mean(results), mse, len(results) =  0.6536333333333334 tf.Tensor(223.75166, shape=(), dtype=float32) 900
# slice = test, score = 0.6536333333333334
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.615 tf.Tensor(229.9507, shape=(), dtype=float32) 100
# slice = key, score = 0.615
# np.mean(results), mse, len(results) =  0.7042871435717858 tf.Tensor(233.26091, shape=(), dtype=float32) 1999
# slice = train, score = 0.7042871435717858
# np.mean(results), mse, len(results) =  0.6527111111111111 tf.Tensor(234.31705, shape=(), dtype=float32) 900
# slice = test, score = 0.6527111111111111
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.6155 tf.Tensor(250.26132, shape=(), dtype=float32) 100
# slice = key, score = 0.6155
# np.mean(results), mse, len(results) =  0.705327663831916 tf.Tensor(250.33151, shape=(), dtype=float32) 1999
# slice = train, score = 0.705327663831916
# np.mean(results), mse, len(results) =  0.6551333333333332 tf.Tensor(250.5071, shape=(), dtype=float32) 900
# slice = test, score = 0.6551333333333332
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.6170999999999999 tf.Tensor(258.7065, shape=(), dtype=float32) 100
# slice = key, score = 0.6170999999999999
# np.mean(results), mse, len(results) =  0.7064532266133066 tf.Tensor(259.3545, shape=(), dtype=float32) 1999
# slice = train, score = 0.7064532266133066
# np.mean(results), mse, len(results) =  0.6540888888888887 tf.Tensor(258.93216, shape=(), dtype=float32) 900
# slice = test, score = 0.6540888888888887
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6155 tf.Tensor(270.58408, shape=(), dtype=float32) 100
# slice = key, score = 0.6155
# np.mean(results), mse, len(results) =  0.7071685842921461 tf.Tensor(274.10748, shape=(), dtype=float32) 1999
# slice = train, score = 0.7071685842921461
# np.mean(results), mse, len(results) =  0.6554777777777778 tf.Tensor(274.3696, shape=(), dtype=float32) 900
# slice = test, score = 0.6554777777777778
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6152000000000001 tf.Tensor(279.13937, shape=(), dtype=float32) 100
# slice = key, score = 0.6152000000000001
# np.mean(results), mse, len(results) =  0.7091945972986493 tf.Tensor(282.73022, shape=(), dtype=float32) 1999
# slice = train, score = 0.7091945972986493
# np.mean(results), mse, len(results) =  0.6532888888888888 tf.Tensor(283.65854, shape=(), dtype=float32) 900
# slice = test, score = 0.6532888888888888
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.616 tf.Tensor(293.51685, shape=(), dtype=float32) 100
# slice = key, score = 0.616
# np.mean(results), mse, len(results) =  0.7102801400700349 tf.Tensor(294.99026, shape=(), dtype=float32) 1999
# slice = train, score = 0.7102801400700349
# np.mean(results), mse, len(results) =  0.6542 tf.Tensor(295.1569, shape=(), dtype=float32) 900
# slice = test, score = 0.6542
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6164999999999999 tf.Tensor(299.47998, shape=(), dtype=float32) 100
# slice = key, score = 0.6164999999999999
# np.mean(results), mse, len(results) =  0.7113056528264132 tf.Tensor(300.52545, shape=(), dtype=float32) 1999
# slice = train, score = 0.7113056528264132
# np.mean(results), mse, len(results) =  0.6561888888888889 tf.Tensor(300.65585, shape=(), dtype=float32) 900
# slice = test, score = 0.6561888888888889
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.6211 tf.Tensor(306.41782, shape=(), dtype=float32) 100
# slice = key, score = 0.6211
# np.mean(results), mse, len(results) =  0.7121810905452727 tf.Tensor(308.77936, shape=(), dtype=float32) 1999
# slice = train, score = 0.7121810905452727
# np.mean(results), mse, len(results) =  0.6565666666666666 tf.Tensor(308.67426, shape=(), dtype=float32) 900
# slice = test, score = 0.6565666666666666
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.6173 tf.Tensor(317.23767, shape=(), dtype=float32) 100
# slice = key, score = 0.6173
# np.mean(results), mse, len(results) =  0.7116808404202101 tf.Tensor(318.07883, shape=(), dtype=float32) 1999
# slice = train, score = 0.7116808404202101
# np.mean(results), mse, len(results) =  0.655911111111111 tf.Tensor(318.62473, shape=(), dtype=float32) 900
# slice = test, score = 0.655911111111111
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.6174000000000001 tf.Tensor(328.41333, shape=(), dtype=float32) 100
# slice = key, score = 0.6174000000000001
# np.mean(results), mse, len(results) =  0.7129164582291145 tf.Tensor(330.15732, shape=(), dtype=float32) 1999
# slice = train, score = 0.7129164582291145
# np.mean(results), mse, len(results) =  0.656288888888889 tf.Tensor(331.0668, shape=(), dtype=float32) 900
# slice = test, score = 0.656288888888889
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.6184 tf.Tensor(334.03165, shape=(), dtype=float32) 100
# slice = key, score = 0.6184
# np.mean(results), mse, len(results) =  0.7140470235117559 tf.Tensor(337.34985, shape=(), dtype=float32) 1999
# slice = train, score = 0.7140470235117559
# np.mean(results), mse, len(results) =  0.6565777777777778 tf.Tensor(337.23755, shape=(), dtype=float32) 900
# slice = test, score = 0.6565777777777778
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.6228 tf.Tensor(338.35455, shape=(), dtype=float32) 100
# slice = key, score = 0.6228
# np.mean(results), mse, len(results) =  0.7144922461230615 tf.Tensor(343.1048, shape=(), dtype=float32) 1999
# slice = train, score = 0.7144922461230615
# np.mean(results), mse, len(results) =  0.6578666666666666 tf.Tensor(343.47736, shape=(), dtype=float32) 900
# slice = test, score = 0.6578666666666666
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.6169000000000001 tf.Tensor(347.6599, shape=(), dtype=float32) 100
# slice = key, score = 0.6169000000000001
# np.mean(results), mse, len(results) =  0.713831915957979 tf.Tensor(350.85165, shape=(), dtype=float32) 1999
# slice = train, score = 0.713831915957979
# np.mean(results), mse, len(results) =  0.6553333333333334 tf.Tensor(351.26044, shape=(), dtype=float32) 900
# slice = test, score = 0.6553333333333334
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.6182000000000001 tf.Tensor(353.32208, shape=(), dtype=float32) 100
# slice = key, score = 0.6182000000000001
# np.mean(results), mse, len(results) =  0.7161780890445222 tf.Tensor(357.91855, shape=(), dtype=float32) 1999
# slice = train, score = 0.7161780890445222
# np.mean(results), mse, len(results) =  0.6552888888888889 tf.Tensor(358.2394, shape=(), dtype=float32) 900
# slice = test, score = 0.6552888888888889
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.6177999999999999 tf.Tensor(364.9484, shape=(), dtype=float32) 100
# slice = key, score = 0.6177999999999999
# np.mean(results), mse, len(results) =  0.7161680840420209 tf.Tensor(366.93735, shape=(), dtype=float32) 1999
# slice = train, score = 0.7161680840420209
# np.mean(results), mse, len(results) =  0.654888888888889 tf.Tensor(367.61343, shape=(), dtype=float32) 900
# slice = test, score = 0.654888888888889
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6184000000000001 tf.Tensor(368.0948, shape=(), dtype=float32) 100
# slice = key, score = 0.6184000000000001
# np.mean(results), mse, len(results) =  0.7160480240120061 tf.Tensor(369.46307, shape=(), dtype=float32) 1999
# slice = train, score = 0.7160480240120061
# np.mean(results), mse, len(results) =  0.6558999999999999 tf.Tensor(371.07373, shape=(), dtype=float32) 900
# slice = test, score = 0.6558999999999999
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.6198 tf.Tensor(374.05026, shape=(), dtype=float32) 100
# slice = key, score = 0.6198
# np.mean(results), mse, len(results) =  0.7169934967483742 tf.Tensor(376.10526, shape=(), dtype=float32) 1999
# slice = train, score = 0.7169934967483742
# np.mean(results), mse, len(results) =  0.6557333333333334 tf.Tensor(377.63577, shape=(), dtype=float32) 900
# slice = test, score = 0.6557333333333334
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.6205 tf.Tensor(383.29883, shape=(), dtype=float32) 100
# slice = key, score = 0.6205
# np.mean(results), mse, len(results) =  0.7173386693346674 tf.Tensor(384.63693, shape=(), dtype=float32) 1999
# slice = train, score = 0.7173386693346674
# np.mean(results), mse, len(results) =  0.6544555555555556 tf.Tensor(385.73422, shape=(), dtype=float32) 900
# slice = test, score = 0.6544555555555556
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.6225999999999999 tf.Tensor(387.242, shape=(), dtype=float32) 100
# slice = key, score = 0.6225999999999999
# np.mean(results), mse, len(results) =  0.7183141570785392 tf.Tensor(390.23004, shape=(), dtype=float32) 1999
# slice = train, score = 0.7183141570785392
# np.mean(results), mse, len(results) =  0.655788888888889 tf.Tensor(391.23233, shape=(), dtype=float32) 900
# slice = test, score = 0.655788888888889
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.6208999999999999 tf.Tensor(394.47107, shape=(), dtype=float32) 100
# slice = key, score = 0.6208999999999999
# np.mean(results), mse, len(results) =  0.71943971985993 tf.Tensor(395.13425, shape=(), dtype=float32) 1999
# slice = train, score = 0.71943971985993
# np.mean(results), mse, len(results) =  0.6566222222222222 tf.Tensor(397.94852, shape=(), dtype=float32) 900
# slice = test, score = 0.6566222222222222
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.622 tf.Tensor(396.23468, shape=(), dtype=float32) 100
# slice = key, score = 0.622
# np.mean(results), mse, len(results) =  0.7192746373186594 tf.Tensor(399.84073, shape=(), dtype=float32) 1999
# slice = train, score = 0.7192746373186594
# np.mean(results), mse, len(results) =  0.6573222222222223 tf.Tensor(401.71954, shape=(), dtype=float32) 900
# slice = test, score = 0.6573222222222223
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.6185 tf.Tensor(406.233, shape=(), dtype=float32) 100
# slice = key, score = 0.6185
# np.mean(results), mse, len(results) =  0.7201050525262631 tf.Tensor(406.1422, shape=(), dtype=float32) 1999
# slice = train, score = 0.7201050525262631
# np.mean(results), mse, len(results) =  0.6564777777777777 tf.Tensor(408.7678, shape=(), dtype=float32) 900
# slice = test, score = 0.6564777777777777
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.617 tf.Tensor(411.75412, shape=(), dtype=float32) 100
# slice = key, score = 0.617
# np.mean(results), mse, len(results) =  0.7199899949974987 tf.Tensor(413.2701, shape=(), dtype=float32) 1999
# slice = train, score = 0.7199899949974987
# np.mean(results), mse, len(results) =  0.6556777777777777 tf.Tensor(415.1033, shape=(), dtype=float32) 900
# slice = test, score = 0.6556777777777777
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.6204999999999999 tf.Tensor(410.1336, shape=(), dtype=float32) 100
# slice = key, score = 0.6204999999999999
# np.mean(results), mse, len(results) =  0.7211855927963983 tf.Tensor(414.91177, shape=(), dtype=float32) 1999
# slice = train, score = 0.7211855927963983
# np.mean(results), mse, len(results) =  0.6565111111111112 tf.Tensor(417.06833, shape=(), dtype=float32) 900
# slice = test, score = 0.6565111111111112
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.6175 tf.Tensor(413.06638, shape=(), dtype=float32) 100
# slice = key, score = 0.6175
# np.mean(results), mse, len(results) =  0.721495747873937 tf.Tensor(415.45743, shape=(), dtype=float32) 1999
# slice = train, score = 0.721495747873937
# np.mean(results), mse, len(results) =  0.6564 tf.Tensor(418.45328, shape=(), dtype=float32) 900
# slice = test, score = 0.6564
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.6211 tf.Tensor(427.34302, shape=(), dtype=float32) 100
# slice = key, score = 0.6211
# np.mean(results), mse, len(results) =  0.7212856428214106 tf.Tensor(428.43906, shape=(), dtype=float32) 1999
# slice = train, score = 0.7212856428214106
# np.mean(results), mse, len(results) =  0.6577111111111111 tf.Tensor(431.9792, shape=(), dtype=float32) 900
# slice = test, score = 0.6577111111111111
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.6179 tf.Tensor(429.68265, shape=(), dtype=float32) 100
# slice = key, score = 0.6179
# np.mean(results), mse, len(results) =  0.7216808404202102 tf.Tensor(433.58154, shape=(), dtype=float32) 1999
# slice = train, score = 0.7216808404202102
# np.mean(results), mse, len(results) =  0.6561 tf.Tensor(437.41406, shape=(), dtype=float32) 900
# slice = test, score = 0.6561
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.6205999999999999 tf.Tensor(434.19443, shape=(), dtype=float32) 100
# slice = key, score = 0.6205999999999999
# np.mean(results), mse, len(results) =  0.7229264632316159 tf.Tensor(436.6184, shape=(), dtype=float32) 1999
# slice = train, score = 0.7229264632316159
# np.mean(results), mse, len(results) =  0.6579444444444446 tf.Tensor(440.10028, shape=(), dtype=float32) 900
# slice = test, score = 0.6579444444444446
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.6153 tf.Tensor(437.96457, shape=(), dtype=float32) 100
# slice = key, score = 0.6153
# np.mean(results), mse, len(results) =  0.7222811405702853 tf.Tensor(442.43652, shape=(), dtype=float32) 1999
# slice = train, score = 0.7222811405702853
# np.mean(results), mse, len(results) =  0.6553666666666665 tf.Tensor(445.99747, shape=(), dtype=float32) 900
# slice = test, score = 0.6553666666666665
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.6233000000000001 tf.Tensor(435.75388, shape=(), dtype=float32) 100
# slice = key, score = 0.6233000000000001
# np.mean(results), mse, len(results) =  0.7235217608804402 tf.Tensor(439.95847, shape=(), dtype=float32) 1999
# slice = train, score = 0.7235217608804402
# np.mean(results), mse, len(results) =  0.6584888888888889 tf.Tensor(443.3516, shape=(), dtype=float32) 900
# slice = test, score = 0.6584888888888889
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.6176 tf.Tensor(446.49664, shape=(), dtype=float32) 100
# slice = key, score = 0.6176
# np.mean(results), mse, len(results) =  0.7233666833416709 tf.Tensor(448.1464, shape=(), dtype=float32) 1999
# slice = train, score = 0.7233666833416709
# np.mean(results), mse, len(results) =  0.6566333333333334 tf.Tensor(451.8589, shape=(), dtype=float32) 900
# slice = test, score = 0.6566333333333334
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.6209 tf.Tensor(443.5456, shape=(), dtype=float32) 100
# slice = key, score = 0.6209
# np.mean(results), mse, len(results) =  0.7240720360180091 tf.Tensor(450.48804, shape=(), dtype=float32) 1999
# slice = train, score = 0.7240720360180091
# np.mean(results), mse, len(results) =  0.6594777777777777 tf.Tensor(455.7383, shape=(), dtype=float32) 900
# slice = test, score = 0.6594777777777777
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.6211 tf.Tensor(449.036, shape=(), dtype=float32) 100
# slice = key, score = 0.6211
# np.mean(results), mse, len(results) =  0.7243671835917959 tf.Tensor(455.22028, shape=(), dtype=float32) 1999
# slice = train, score = 0.7243671835917959
# np.mean(results), mse, len(results) =  0.6574777777777778 tf.Tensor(460.87378, shape=(), dtype=float32) 900
# slice = test, score = 0.6574777777777778
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.6186 tf.Tensor(448.93326, shape=(), dtype=float32) 100
# slice = key, score = 0.6186
# np.mean(results), mse, len(results) =  0.7249474737368685 tf.Tensor(456.4627, shape=(), dtype=float32) 1999
# slice = train, score = 0.7249474737368685
# np.mean(results), mse, len(results) =  0.6570555555555556 tf.Tensor(461.16614, shape=(), dtype=float32) 900
# slice = test, score = 0.6570555555555556
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.6187 tf.Tensor(465.95053, shape=(), dtype=float32) 100
# slice = key, score = 0.6187
# np.mean(results), mse, len(results) =  0.725367683841921 tf.Tensor(466.22412, shape=(), dtype=float32) 1999
# slice = train, score = 0.725367683841921
# np.mean(results), mse, len(results) =  0.6577111111111111 tf.Tensor(471.23407, shape=(), dtype=float32) 900
# slice = test, score = 0.6577111111111111
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(471.88974, shape=(), dtype=float32) 100
# slice = key, score = 0.6203
# np.mean(results), mse, len(results) =  0.7257028514257129 tf.Tensor(473.96246, shape=(), dtype=float32) 1999
# slice = train, score = 0.7257028514257129
# np.mean(results), mse, len(results) =  0.6579111111111112 tf.Tensor(479.23224, shape=(), dtype=float32) 900
# slice = test, score = 0.6579111111111112
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.6177 tf.Tensor(471.74368, shape=(), dtype=float32) 100
# slice = key, score = 0.6177
# np.mean(results), mse, len(results) =  0.7261730865432717 tf.Tensor(474.68912, shape=(), dtype=float32) 1999
# slice = train, score = 0.7261730865432717
# np.mean(results), mse, len(results) =  0.6576444444444446 tf.Tensor(479.59293, shape=(), dtype=float32) 900
# slice = test, score = 0.6576444444444446
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.6201000000000001 tf.Tensor(477.45767, shape=(), dtype=float32) 100
# slice = key, score = 0.6201000000000001
# np.mean(results), mse, len(results) =  0.7260630315157578 tf.Tensor(481.01474, shape=(), dtype=float32) 1999
# slice = train, score = 0.7260630315157578
# np.mean(results), mse, len(results) =  0.6567333333333333 tf.Tensor(485.95578, shape=(), dtype=float32) 900
# slice = test, score = 0.6567333333333333
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.6182 tf.Tensor(476.83917, shape=(), dtype=float32) 100
# slice = key, score = 0.6182
# np.mean(results), mse, len(results) =  0.726463231615808 tf.Tensor(481.0278, shape=(), dtype=float32) 1999
# slice = train, score = 0.726463231615808
# np.mean(results), mse, len(results) =  0.6566444444444445 tf.Tensor(486.51584, shape=(), dtype=float32) 900
# slice = test, score = 0.6566444444444445
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.6195 tf.Tensor(478.5546, shape=(), dtype=float32) 100
# slice = key, score = 0.6195
# np.mean(results), mse, len(results) =  0.7272736368184093 tf.Tensor(482.27707, shape=(), dtype=float32) 1999
# slice = train, score = 0.7272736368184093
# np.mean(results), mse, len(results) =  0.6577000000000001 tf.Tensor(488.3197, shape=(), dtype=float32) 900
# slice = test, score = 0.6577000000000001
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.6166 tf.Tensor(490.148, shape=(), dtype=float32) 100
# slice = key, score = 0.6166
# np.mean(results), mse, len(results) =  0.7269184592296148 tf.Tensor(490.83255, shape=(), dtype=float32) 1999
# slice = train, score = 0.7269184592296148
# np.mean(results), mse, len(results) =  0.6568111111111112 tf.Tensor(497.5145, shape=(), dtype=float32) 900
# slice = test, score = 0.6568111111111112
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.6176999999999999 tf.Tensor(493.33325, shape=(), dtype=float32) 100
# slice = key, score = 0.6176999999999999
# np.mean(results), mse, len(results) =  0.7276538269134567 tf.Tensor(493.6433, shape=(), dtype=float32) 1999
# slice = train, score = 0.7276538269134567
# np.mean(results), mse, len(results) =  0.6581888888888887 tf.Tensor(500.59723, shape=(), dtype=float32) 900
# slice = test, score = 0.6581888888888887
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.6217999999999999 tf.Tensor(494.95593, shape=(), dtype=float32) 100
# slice = key, score = 0.6217999999999999
# np.mean(results), mse, len(results) =  0.7281740870435217 tf.Tensor(498.73404, shape=(), dtype=float32) 1999
# slice = train, score = 0.7281740870435217
# np.mean(results), mse, len(results) =  0.6577222222222223 tf.Tensor(505.22247, shape=(), dtype=float32) 900
# slice = test, score = 0.6577222222222223
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.6153 tf.Tensor(504.87677, shape=(), dtype=float32) 100
# slice = key, score = 0.6153
# np.mean(results), mse, len(results) =  0.727263631815908 tf.Tensor(507.85623, shape=(), dtype=float32) 1999
# slice = train, score = 0.727263631815908
# np.mean(results), mse, len(results) =  0.6571111111111112 tf.Tensor(515.14154, shape=(), dtype=float32) 900
# slice = test, score = 0.6571111111111112
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6182 tf.Tensor(505.59473, shape=(), dtype=float32) 100
# slice = key, score = 0.6182
# np.mean(results), mse, len(results) =  0.7283541770885443 tf.Tensor(509.43024, shape=(), dtype=float32) 1999
# slice = train, score = 0.7283541770885443
# np.mean(results), mse, len(results) =  0.6562111111111112 tf.Tensor(516.1066, shape=(), dtype=float32) 900
# slice = test, score = 0.6562111111111112
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.6192 tf.Tensor(508.76752, shape=(), dtype=float32) 100
# slice = key, score = 0.6192
# np.mean(results), mse, len(results) =  0.7288744372186093 tf.Tensor(511.11136, shape=(), dtype=float32) 1999
# slice = train, score = 0.7288744372186093
# np.mean(results), mse, len(results) =  0.6572111111111111 tf.Tensor(518.09375, shape=(), dtype=float32) 900
# slice = test, score = 0.6572111111111111
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.6228 tf.Tensor(512.5245, shape=(), dtype=float32) 100
# slice = key, score = 0.6228
# np.mean(results), mse, len(results) =  0.7282791395697849 tf.Tensor(514.9339, shape=(), dtype=float32) 1999
# slice = train, score = 0.7282791395697849
# np.mean(results), mse, len(results) =  0.6574888888888889 tf.Tensor(522.12494, shape=(), dtype=float32) 900
# slice = test, score = 0.6574888888888889
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6191 tf.Tensor(510.44125, shape=(), dtype=float32) 100
# slice = key, score = 0.6191
# np.mean(results), mse, len(results) =  0.7290795397698848 tf.Tensor(516.3744, shape=(), dtype=float32) 1999
# slice = train, score = 0.7290795397698848
# np.mean(results), mse, len(results) =  0.6572555555555557 tf.Tensor(524.2288, shape=(), dtype=float32) 900
# slice = test, score = 0.6572555555555557
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(517.5971, shape=(), dtype=float32) 100
# slice = key, score = 0.6203
# np.mean(results), mse, len(results) =  0.7288544272136068 tf.Tensor(518.50214, shape=(), dtype=float32) 1999
# slice = train, score = 0.7288544272136068
# np.mean(results), mse, len(results) =  0.6569111111111111 tf.Tensor(526.9306, shape=(), dtype=float32) 900
# slice = test, score = 0.6569111111111111
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.6211 tf.Tensor(515.90216, shape=(), dtype=float32) 100
# slice = key, score = 0.6211
# np.mean(results), mse, len(results) =  0.7297898949474737 tf.Tensor(522.1568, shape=(), dtype=float32) 1999
# slice = train, score = 0.7297898949474737
# np.mean(results), mse, len(results) =  0.6574777777777778 tf.Tensor(531.06555, shape=(), dtype=float32) 900
# slice = test, score = 0.6574777777777778
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.6202 tf.Tensor(524.94916, shape=(), dtype=float32) 100
# slice = key, score = 0.6202
# np.mean(results), mse, len(results) =  0.7294997498749375 tf.Tensor(528.42084, shape=(), dtype=float32) 1999
# slice = train, score = 0.7294997498749375
# np.mean(results), mse, len(results) =  0.658088888888889 tf.Tensor(536.68933, shape=(), dtype=float32) 900
# slice = test, score = 0.658088888888889
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.6182 tf.Tensor(525.71454, shape=(), dtype=float32) 100
# slice = key, score = 0.6182
# np.mean(results), mse, len(results) =  0.7298849424712356 tf.Tensor(529.7081, shape=(), dtype=float32) 1999
# slice = train, score = 0.7298849424712356
# np.mean(results), mse, len(results) =  0.656211111111111 tf.Tensor(538.14417, shape=(), dtype=float32) 900
# slice = test, score = 0.656211111111111
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.6194 tf.Tensor(529.7703, shape=(), dtype=float32) 100
# slice = key, score = 0.6194
# np.mean(results), mse, len(results) =  0.7306753376688344 tf.Tensor(533.2993, shape=(), dtype=float32) 1999
# slice = train, score = 0.7306753376688344
# np.mean(results), mse, len(results) =  0.6567444444444444 tf.Tensor(542.47363, shape=(), dtype=float32) 900
# slice = test, score = 0.6567444444444444
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.62 tf.Tensor(533.9655, shape=(), dtype=float32) 100
# slice = key, score = 0.62
# np.mean(results), mse, len(results) =  0.730465232616308 tf.Tensor(538.8318, shape=(), dtype=float32) 1999
# slice = train, score = 0.730465232616308
# np.mean(results), mse, len(results) =  0.6576444444444446 tf.Tensor(547.47406, shape=(), dtype=float32) 900
# slice = test, score = 0.6576444444444446
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.6199000000000001 tf.Tensor(530.789, shape=(), dtype=float32) 100
# slice = key, score = 0.6199000000000001
# np.mean(results), mse, len(results) =  0.7312256128064031 tf.Tensor(537.88617, shape=(), dtype=float32) 1999
# slice = train, score = 0.7312256128064031
# np.mean(results), mse, len(results) =  0.6565333333333333 tf.Tensor(547.64514, shape=(), dtype=float32) 900
# slice = test, score = 0.6565333333333333
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.6199999999999999 tf.Tensor(535.81213, shape=(), dtype=float32) 100
# slice = key, score = 0.6199999999999999
# np.mean(results), mse, len(results) =  0.7306503251625812 tf.Tensor(541.166, shape=(), dtype=float32) 1999
# slice = train, score = 0.7306503251625812
# np.mean(results), mse, len(results) =  0.6573777777777778 tf.Tensor(550.3533, shape=(), dtype=float32) 900
# slice = test, score = 0.6573777777777778
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.6207 tf.Tensor(537.9418, shape=(), dtype=float32) 100
# slice = key, score = 0.6207
# np.mean(results), mse, len(results) =  0.7318759379689845 tf.Tensor(542.91833, shape=(), dtype=float32) 1999
# slice = train, score = 0.7318759379689845
# np.mean(results), mse, len(results) =  0.6575444444444444 tf.Tensor(552.0708, shape=(), dtype=float32) 900
# slice = test, score = 0.6575444444444444
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.622 tf.Tensor(548.9803, shape=(), dtype=float32) 100
# slice = key, score = 0.622
# np.mean(results), mse, len(results) =  0.7310605302651326 tf.Tensor(551.76056, shape=(), dtype=float32) 1999
# slice = train, score = 0.7310605302651326
# np.mean(results), mse, len(results) =  0.6561666666666666 tf.Tensor(561.6326, shape=(), dtype=float32) 900
# slice = test, score = 0.6561666666666666
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.6204 tf.Tensor(553.04944, shape=(), dtype=float32) 100
# slice = key, score = 0.6204
# np.mean(results), mse, len(results) =  0.7323811905952976 tf.Tensor(556.166, shape=(), dtype=float32) 1999
# slice = train, score = 0.7323811905952976
# np.mean(results), mse, len(results) =  0.657511111111111 tf.Tensor(564.78046, shape=(), dtype=float32) 900
# slice = test, score = 0.657511111111111
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6238 tf.Tensor(549.87286, shape=(), dtype=float32) 100
# slice = key, score = 0.6238
# np.mean(results), mse, len(results) =  0.7324612306153077 tf.Tensor(558.76306, shape=(), dtype=float32) 1999
# slice = train, score = 0.7324612306153077
# np.mean(results), mse, len(results) =  0.6568444444444445 tf.Tensor(568.72534, shape=(), dtype=float32) 900
# slice = test, score = 0.6568444444444445
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.62 tf.Tensor(558.2168, shape=(), dtype=float32) 100
# slice = key, score = 0.62
# np.mean(results), mse, len(results) =  0.7314207103551776 tf.Tensor(561.03406, shape=(), dtype=float32) 1999
# slice = train, score = 0.7314207103551776
# np.mean(results), mse, len(results) =  0.6576444444444445 tf.Tensor(568.74115, shape=(), dtype=float32) 900
# slice = test, score = 0.6576444444444445
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(560.1028, shape=(), dtype=float32) 100
# slice = key, score = 0.6203
# np.mean(results), mse, len(results) =  0.7317208604302151 tf.Tensor(565.65344, shape=(), dtype=float32) 1999
# slice = train, score = 0.7317208604302151
# np.mean(results), mse, len(results) =  0.6570111111111111 tf.Tensor(574.2375, shape=(), dtype=float32) 900
# slice = test, score = 0.6570111111111111
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.6204000000000001 tf.Tensor(567.1495, shape=(), dtype=float32) 100
# slice = key, score = 0.6204000000000001
# np.mean(results), mse, len(results) =  0.7320810405202601 tf.Tensor(574.38074, shape=(), dtype=float32) 1999
# slice = train, score = 0.7320810405202601
# np.mean(results), mse, len(results) =  0.6567555555555556 tf.Tensor(584.6943, shape=(), dtype=float32) 900
# slice = test, score = 0.6567555555555556
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.6223 tf.Tensor(574.9403, shape=(), dtype=float32) 100
# slice = key, score = 0.6223
# np.mean(results), mse, len(results) =  0.7325962981490746 tf.Tensor(577.3847, shape=(), dtype=float32) 1999
# slice = train, score = 0.7325962981490746
# np.mean(results), mse, len(results) =  0.6575222222222222 tf.Tensor(587.3548, shape=(), dtype=float32) 900
# slice = test, score = 0.6575222222222222
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6201999999999999 tf.Tensor(571.63586, shape=(), dtype=float32) 100
# slice = key, score = 0.6201999999999999
# np.mean(results), mse, len(results) =  0.7318209104552276 tf.Tensor(580.2589, shape=(), dtype=float32) 1999
# slice = train, score = 0.7318209104552276
# np.mean(results), mse, len(results) =  0.6575333333333333 tf.Tensor(588.75134, shape=(), dtype=float32) 900
# slice = test, score = 0.6575333333333333
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6201 tf.Tensor(575.18005, shape=(), dtype=float32) 100
# slice = key, score = 0.6201
# np.mean(results), mse, len(results) =  0.7327663831915959 tf.Tensor(580.802, shape=(), dtype=float32) 1999
# slice = train, score = 0.7327663831915959
# np.mean(results), mse, len(results) =  0.6571666666666667 tf.Tensor(590.7055, shape=(), dtype=float32) 900
# slice = test, score = 0.6571666666666667
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6198 tf.Tensor(583.63104, shape=(), dtype=float32) 100
# slice = key, score = 0.6198
# np.mean(results), mse, len(results) =  0.7323561780890445 tf.Tensor(585.8797, shape=(), dtype=float32) 1999
# slice = train, score = 0.7323561780890445
# np.mean(results), mse, len(results) =  0.6576555555555555 tf.Tensor(595.67365, shape=(), dtype=float32) 900
# slice = test, score = 0.6576555555555555
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6195 tf.Tensor(584.26447, shape=(), dtype=float32) 100
# slice = key, score = 0.6195
# np.mean(results), mse, len(results) =  0.7335317658829414 tf.Tensor(588.6096, shape=(), dtype=float32) 1999
# slice = train, score = 0.7335317658829414
# np.mean(results), mse, len(results) =  0.6560444444444445 tf.Tensor(598.41766, shape=(), dtype=float32) 900
# slice = test, score = 0.6560444444444445
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.6222000000000001 tf.Tensor(593.08997, shape=(), dtype=float32) 100
# slice = key, score = 0.6222000000000001
# np.mean(results), mse, len(results) =  0.7330815407703851 tf.Tensor(597.38354, shape=(), dtype=float32) 1999
# slice = train, score = 0.7330815407703851
# np.mean(results), mse, len(results) =  0.6572111111111111 tf.Tensor(608.31573, shape=(), dtype=float32) 900
# slice = test, score = 0.6572111111111111
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.6241 tf.Tensor(589.1155, shape=(), dtype=float32) 100
# slice = key, score = 0.6241
# np.mean(results), mse, len(results) =  0.7334367183591796 tf.Tensor(594.44666, shape=(), dtype=float32) 1999
# slice = train, score = 0.7334367183591796
# np.mean(results), mse, len(results) =  0.6570777777777778 tf.Tensor(604.6417, shape=(), dtype=float32) 900
# slice = test, score = 0.6570777777777778
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.6210999999999999 tf.Tensor(596.87946, shape=(), dtype=float32) 100
# slice = key, score = 0.6210999999999999
# np.mean(results), mse, len(results) =  0.7336018009004502 tf.Tensor(602.5972, shape=(), dtype=float32) 1999
# slice = train, score = 0.7336018009004502
# np.mean(results), mse, len(results) =  0.6574222222222222 tf.Tensor(613.73584, shape=(), dtype=float32) 900
# slice = test, score = 0.6574222222222222
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.6242 tf.Tensor(600.1268, shape=(), dtype=float32) 100
# slice = key, score = 0.6242
# np.mean(results), mse, len(results) =  0.7335767883941972 tf.Tensor(607.17694, shape=(), dtype=float32) 1999
# slice = train, score = 0.7335767883941972
# np.mean(results), mse, len(results) =  0.6592777777777776 tf.Tensor(618.24744, shape=(), dtype=float32) 900
# slice = test, score = 0.6592777777777776
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.6241 tf.Tensor(611.75696, shape=(), dtype=float32) 100
# slice = key, score = 0.6241
# np.mean(results), mse, len(results) =  0.7348274137068534 tf.Tensor(614.0763, shape=(), dtype=float32) 1999
# slice = train, score = 0.7348274137068534
# np.mean(results), mse, len(results) =  0.6575222222222222 tf.Tensor(624.8064, shape=(), dtype=float32) 900
# slice = test, score = 0.6575222222222222
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.6171 tf.Tensor(610.1543, shape=(), dtype=float32) 100
# slice = key, score = 0.6171
# np.mean(results), mse, len(results) =  0.7329064532266133 tf.Tensor(613.99, shape=(), dtype=float32) 1999
# slice = train, score = 0.7329064532266133
# np.mean(results), mse, len(results) =  0.6573111111111111 tf.Tensor(624.87744, shape=(), dtype=float32) 900
# slice = test, score = 0.6573111111111111
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.6196 tf.Tensor(608.4902, shape=(), dtype=float32) 100
# slice = key, score = 0.6196
# np.mean(results), mse, len(results) =  0.7342571285642823 tf.Tensor(616.4623, shape=(), dtype=float32) 1999
# slice = train, score = 0.7342571285642823
# np.mean(results), mse, len(results) =  0.6566444444444445 tf.Tensor(628.18384, shape=(), dtype=float32) 900
# slice = test, score = 0.6566444444444445
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.6189000000000001 tf.Tensor(619.62103, shape=(), dtype=float32) 100
# slice = key, score = 0.6189000000000001
# np.mean(results), mse, len(results) =  0.7348224112056028 tf.Tensor(623.3894, shape=(), dtype=float32) 1999
# slice = train, score = 0.7348224112056028
# np.mean(results), mse, len(results) =  0.6581222222222222 tf.Tensor(634.7019, shape=(), dtype=float32) 900
# slice = test, score = 0.6581222222222222
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.6263000000000001 tf.Tensor(619.8818, shape=(), dtype=float32) 100
# slice = key, score = 0.6263000000000001
# np.mean(results), mse, len(results) =  0.7354627313656829 tf.Tensor(624.7424, shape=(), dtype=float32) 1999
# slice = train, score = 0.7354627313656829
# np.mean(results), mse, len(results) =  0.6569999999999999 tf.Tensor(636.38635, shape=(), dtype=float32) 900
# slice = test, score = 0.6569999999999999
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.6248 tf.Tensor(623.95856, shape=(), dtype=float32) 100
# slice = key, score = 0.6248
# np.mean(results), mse, len(results) =  0.7352976488244122 tf.Tensor(629.2991, shape=(), dtype=float32) 1999
# slice = train, score = 0.7352976488244122
# np.mean(results), mse, len(results) =  0.6585666666666666 tf.Tensor(640.32605, shape=(), dtype=float32) 900
# slice = test, score = 0.6585666666666666
#
# === Iteration 90000 ===
# np.mean(results), mse, len(results) =  0.6196 tf.Tensor(628.22705, shape=(), dtype=float32) 100
# slice = key, score = 0.6196
# np.mean(results), mse, len(results) =  0.7346673336668333 tf.Tensor(636.1378, shape=(), dtype=float32) 1999
# slice = train, score = 0.7346673336668333
# np.mean(results), mse, len(results) =  0.6564222222222222 tf.Tensor(647.334, shape=(), dtype=float32) 900
# slice = test, score = 0.6564222222222222
#
# === Iteration 91000 ===
# np.mean(results), mse, len(results) =  0.6214 tf.Tensor(630.4782, shape=(), dtype=float32) 100
# slice = key, score = 0.6214
# np.mean(results), mse, len(results) =  0.7351225612806405 tf.Tensor(636.4811, shape=(), dtype=float32) 1999
# slice = train, score = 0.7351225612806405
# np.mean(results), mse, len(results) =  0.6558555555555555 tf.Tensor(647.1709, shape=(), dtype=float32) 900
# slice = test, score = 0.6558555555555555
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.6228999999999999 tf.Tensor(636.62164, shape=(), dtype=float32) 100
# slice = key, score = 0.6228999999999999
# np.mean(results), mse, len(results) =  0.734327163581791 tf.Tensor(643.95746, shape=(), dtype=float32) 1999
# slice = train, score = 0.734327163581791
# np.mean(results), mse, len(results) =  0.6571 tf.Tensor(655.5442, shape=(), dtype=float32) 900
# slice = test, score = 0.6571
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.618 tf.Tensor(639.21594, shape=(), dtype=float32) 100
# slice = key, score = 0.618
# np.mean(results), mse, len(results) =  0.7351275637818909 tf.Tensor(645.5057, shape=(), dtype=float32) 1999
# slice = train, score = 0.7351275637818909
# np.mean(results), mse, len(results) =  0.6575 tf.Tensor(656.4655, shape=(), dtype=float32) 900
# slice = test, score = 0.6575
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.6224 tf.Tensor(647.7228, shape=(), dtype=float32) 100
# slice = key, score = 0.6224
# np.mean(results), mse, len(results) =  0.7363831915957979 tf.Tensor(657.483, shape=(), dtype=float32) 1999
# slice = train, score = 0.7363831915957979
# np.mean(results), mse, len(results) =  0.6584444444444445 tf.Tensor(669.09827, shape=(), dtype=float32) 900
# slice = test, score = 0.6584444444444445
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.6226000000000002 tf.Tensor(648.8613, shape=(), dtype=float32) 100
# slice = key, score = 0.6226000000000002
# np.mean(results), mse, len(results) =  0.7357128564282142 tf.Tensor(653.9669, shape=(), dtype=float32) 1999
# slice = train, score = 0.7357128564282142
# np.mean(results), mse, len(results) =  0.6581333333333332 tf.Tensor(666.2592, shape=(), dtype=float32) 900
# slice = test, score = 0.6581333333333332
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.6229 tf.Tensor(649.22986, shape=(), dtype=float32) 100
# slice = key, score = 0.6229
# np.mean(results), mse, len(results) =  0.7358379189594798 tf.Tensor(657.0078, shape=(), dtype=float32) 1999
# slice = train, score = 0.7358379189594798
# np.mean(results), mse, len(results) =  0.6570888888888888 tf.Tensor(668.3188, shape=(), dtype=float32) 900
# slice = test, score = 0.6570888888888888
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.6232 tf.Tensor(659.9187, shape=(), dtype=float32) 100
# slice = key, score = 0.6232
# np.mean(results), mse, len(results) =  0.736608304152076 tf.Tensor(666.7635, shape=(), dtype=float32) 1999
# slice = train, score = 0.736608304152076
# np.mean(results), mse, len(results) =  0.6582 tf.Tensor(678.7574, shape=(), dtype=float32) 900
# slice = test, score = 0.6582
#
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.6182 tf.Tensor(662.464, shape=(), dtype=float32) 100
# slice = key, score = 0.6182
# np.mean(results), mse, len(results) =  0.7359579789894948 tf.Tensor(667.5237, shape=(), dtype=float32) 1999
# slice = train, score = 0.7359579789894948
# np.mean(results), mse, len(results) =  0.6563000000000001 tf.Tensor(679.0628, shape=(), dtype=float32) 900
# slice = test, score = 0.6563000000000001
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.6205999999999999 tf.Tensor(667.1631, shape=(), dtype=float32) 100
# slice = key, score = 0.6205999999999999
# np.mean(results), mse, len(results) =  0.7352676338169084 tf.Tensor(674.45605, shape=(), dtype=float32) 1999
# slice = train, score = 0.7352676338169084
# np.mean(results), mse, len(results) =  0.6572777777777777 tf.Tensor(686.5978, shape=(), dtype=float32) 900
# slice = test, score = 0.6572777777777777
# last loss =  tf.Tensor(-0.0051078536, shape=(), dtype=float32)
# np.mean(results), mse, len(results) =  0.736128064032016 tf.Tensor(676.85315, shape=(), dtype=float32) 1999
# np.mean(results), mse, len(results) =  0.6564444444444444 tf.Tensor(689.8448, shape=(), dtype=float32) 900
# (0.736128064032016, 0.6564444444444444)

# %% [markdown]
# Popular -> 0.009166666666666667
# AnnCur -> 0.6164111111111111
# key_games=np.arange(100) -> 0.5720444444444445
# K_Random -> 0.6130444444444445
# K_KMeans -> 0.6123999999999999
# K_BisectingKMeans -> 0.5866888888888888
# K_MiniBatchKMeans -> 0.6082333333333333
# K_AgglomerativeClustering -> 0.6150888888888889
# K_SpectralCoclustering -> 0.5847111111111111
# K_SpectralBiclustering -> 0.5804444444444445
# K_SpectralClusteringNN -> 0.6133666666666666
# K_ByMin -> 0.6282444444444444
#
# K_Random + RBE :0.6250
# K_KMeans : 0.6123999999999999 ->  0.6204777777777777
# CoItem : 0.6458777777777778 -> 0.6564444444444444

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': True,
    'train_popbias': True, 'train_bias': True,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": False, # <<< DIFF HERE
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")

# %%
ctx.set_kmeans_games_as_key()

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': True,
    'train_popbias': True, 'train_bias': True,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": False, # <<< DIFF HERE
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (1999, 100)
# self.embed_games.shape =  (24493, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 24493)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (1999, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.0025 tf.Tensor(40.47996, shape=(), dtype=float32) 100
# slice = key, score = 0.0025
# np.mean(results), mse, len(results) =  0.003366683341670836 tf.Tensor(42.613895, shape=(), dtype=float32) 1999
# slice = train, score = 0.003366683341670836
# np.mean(results), mse, len(results) =  0.003588888888888889 tf.Tensor(42.73112, shape=(), dtype=float32) 900
# slice = test, score = 0.003588888888888889
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.5293000000000001 tf.Tensor(53.58917, shape=(), dtype=float32) 100
# slice = key, score = 0.5293000000000001
# np.mean(results), mse, len(results) =  0.6102701350675338 tf.Tensor(54.408394, shape=(), dtype=float32) 1999
# slice = train, score = 0.6102701350675338
# np.mean(results), mse, len(results) =  0.5707111111111111 tf.Tensor(53.78044, shape=(), dtype=float32) 900
# slice = test, score = 0.5707111111111111
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5579999999999999 tf.Tensor(74.768005, shape=(), dtype=float32) 100
# slice = key, score = 0.5579999999999999
# np.mean(results), mse, len(results) =  0.6397698849424713 tf.Tensor(74.95025, shape=(), dtype=float32) 1999
# slice = train, score = 0.6397698849424713
# np.mean(results), mse, len(results) =  0.5951111111111111 tf.Tensor(74.742134, shape=(), dtype=float32) 900
# slice = test, score = 0.5951111111111111
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.5612999999999999 tf.Tensor(96.48806, shape=(), dtype=float32) 100
# slice = key, score = 0.5612999999999999
# np.mean(results), mse, len(results) =  0.6501300650325164 tf.Tensor(96.40117, shape=(), dtype=float32) 1999
# slice = train, score = 0.6501300650325164
# np.mean(results), mse, len(results) =  0.6058555555555555 tf.Tensor(96.04051, shape=(), dtype=float32) 900
# slice = test, score = 0.6058555555555555
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.5675999999999999 tf.Tensor(115.63486, shape=(), dtype=float32) 100
# slice = key, score = 0.5675999999999999
# np.mean(results), mse, len(results) =  0.655567783891946 tf.Tensor(115.35234, shape=(), dtype=float32) 1999
# slice = train, score = 0.655567783891946
# np.mean(results), mse, len(results) =  0.6085777777777778 tf.Tensor(115.13218, shape=(), dtype=float32) 900
# slice = test, score = 0.6085777777777778
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.5681 tf.Tensor(134.59265, shape=(), dtype=float32) 100
# slice = key, score = 0.5681
# np.mean(results), mse, len(results) =  0.6606253126563282 tf.Tensor(133.39743, shape=(), dtype=float32) 1999
# slice = train, score = 0.6606253126563282
# np.mean(results), mse, len(results) =  0.6135777777777778 tf.Tensor(133.31195, shape=(), dtype=float32) 900
# slice = test, score = 0.6135777777777778
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.5713 tf.Tensor(152.00868, shape=(), dtype=float32) 100
# slice = key, score = 0.5713
# np.mean(results), mse, len(results) =  0.6636518259129565 tf.Tensor(152.35144, shape=(), dtype=float32) 1999
# slice = train, score = 0.6636518259129565
# np.mean(results), mse, len(results) =  0.6154555555555556 tf.Tensor(152.15598, shape=(), dtype=float32) 900
# slice = test, score = 0.6154555555555556
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.5737 tf.Tensor(171.0746, shape=(), dtype=float32) 100
# slice = key, score = 0.5737
# np.mean(results), mse, len(results) =  0.6676838419209604 tf.Tensor(169.01685, shape=(), dtype=float32) 1999
# slice = train, score = 0.6676838419209604
# np.mean(results), mse, len(results) =  0.6180555555555556 tf.Tensor(168.82295, shape=(), dtype=float32) 900
# slice = test, score = 0.6180555555555556
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.5681 tf.Tensor(186.52751, shape=(), dtype=float32) 100
# slice = key, score = 0.5681
# np.mean(results), mse, len(results) =  0.6683091545772887 tf.Tensor(184.29369, shape=(), dtype=float32) 1999
# slice = train, score = 0.6683091545772887
# np.mean(results), mse, len(results) =  0.6148555555555555 tf.Tensor(184.99089, shape=(), dtype=float32) 900
# slice = test, score = 0.6148555555555555
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.5678 tf.Tensor(201.74161, shape=(), dtype=float32) 100
# slice = key, score = 0.5678
# np.mean(results), mse, len(results) =  0.671415707853927 tf.Tensor(199.70924, shape=(), dtype=float32) 1999
# slice = train, score = 0.671415707853927
# np.mean(results), mse, len(results) =  0.6169444444444444 tf.Tensor(200.96465, shape=(), dtype=float32) 900
# slice = test, score = 0.6169444444444444
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.5747000000000001 tf.Tensor(221.3858, shape=(), dtype=float32) 100
# slice = key, score = 0.5747000000000001
# np.mean(results), mse, len(results) =  0.6723111555777889 tf.Tensor(217.24043, shape=(), dtype=float32) 1999
# slice = train, score = 0.6723111555777889
# np.mean(results), mse, len(results) =  0.6180777777777777 tf.Tensor(218.48097, shape=(), dtype=float32) 900
# slice = test, score = 0.6180777777777777
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.5721999999999999 tf.Tensor(234.2321, shape=(), dtype=float32) 100
# slice = key, score = 0.5721999999999999
# np.mean(results), mse, len(results) =  0.6736918459229615 tf.Tensor(229.94633, shape=(), dtype=float32) 1999
# slice = train, score = 0.6736918459229615
# np.mean(results), mse, len(results) =  0.6162111111111112 tf.Tensor(230.17896, shape=(), dtype=float32) 900
# slice = test, score = 0.6162111111111112
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.5760000000000001 tf.Tensor(245.7371, shape=(), dtype=float32) 100
# slice = key, score = 0.5760000000000001
# np.mean(results), mse, len(results) =  0.6753026513256627 tf.Tensor(240.23521, shape=(), dtype=float32) 1999
# slice = train, score = 0.6753026513256627
# np.mean(results), mse, len(results) =  0.6183555555555555 tf.Tensor(240.76895, shape=(), dtype=float32) 900
# slice = test, score = 0.6183555555555555
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.5773999999999999 tf.Tensor(260.78082, shape=(), dtype=float32) 100
# slice = key, score = 0.5773999999999999
# np.mean(results), mse, len(results) =  0.6782991495747874 tf.Tensor(255.42764, shape=(), dtype=float32) 1999
# slice = train, score = 0.6782991495747874
# np.mean(results), mse, len(results) =  0.6183555555555555 tf.Tensor(255.56548, shape=(), dtype=float32) 900
# slice = test, score = 0.6183555555555555
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.5773999999999999 tf.Tensor(268.44116, shape=(), dtype=float32) 100
# slice = key, score = 0.5773999999999999
# np.mean(results), mse, len(results) =  0.6781990995497749 tf.Tensor(265.64154, shape=(), dtype=float32) 1999
# slice = train, score = 0.6781990995497749
# np.mean(results), mse, len(results) =  0.6186 tf.Tensor(266.03497, shape=(), dtype=float32) 900
# slice = test, score = 0.6186
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.5738 tf.Tensor(283.85742, shape=(), dtype=float32) 100
# slice = key, score = 0.5738
# np.mean(results), mse, len(results) =  0.6807453726863432 tf.Tensor(278.07755, shape=(), dtype=float32) 1999
# slice = train, score = 0.6807453726863432
# np.mean(results), mse, len(results) =  0.619211111111111 tf.Tensor(277.66727, shape=(), dtype=float32) 900
# slice = test, score = 0.619211111111111
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.5779 tf.Tensor(299.33414, shape=(), dtype=float32) 100
# slice = key, score = 0.5779
# np.mean(results), mse, len(results) =  0.6819159579789895 tf.Tensor(291.23395, shape=(), dtype=float32) 1999
# slice = train, score = 0.6819159579789895
# np.mean(results), mse, len(results) =  0.6207666666666667 tf.Tensor(292.64316, shape=(), dtype=float32) 900
# slice = test, score = 0.6207666666666667
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.5758 tf.Tensor(311.64505, shape=(), dtype=float32) 100
# slice = key, score = 0.5758
# np.mean(results), mse, len(results) =  0.6821760880440221 tf.Tensor(304.8091, shape=(), dtype=float32) 1999
# slice = train, score = 0.6821760880440221
# np.mean(results), mse, len(results) =  0.6185666666666667 tf.Tensor(305.29004, shape=(), dtype=float32) 900
# slice = test, score = 0.6185666666666667
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.5776 tf.Tensor(319.63025, shape=(), dtype=float32) 100
# slice = key, score = 0.5776
# np.mean(results), mse, len(results) =  0.6828014007003502 tf.Tensor(312.60742, shape=(), dtype=float32) 1999
# slice = train, score = 0.6828014007003502
# np.mean(results), mse, len(results) =  0.6186777777777778 tf.Tensor(313.52145, shape=(), dtype=float32) 900
# slice = test, score = 0.6186777777777778
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.5772000000000002 tf.Tensor(333.6008, shape=(), dtype=float32) 100
# slice = key, score = 0.5772000000000002
# np.mean(results), mse, len(results) =  0.6848974487243622 tf.Tensor(323.36813, shape=(), dtype=float32) 1999
# slice = train, score = 0.6848974487243622
# np.mean(results), mse, len(results) =  0.6197555555555555 tf.Tensor(324.72647, shape=(), dtype=float32) 900
# slice = test, score = 0.6197555555555555
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.5791000000000001 tf.Tensor(341.77695, shape=(), dtype=float32) 100
# slice = key, score = 0.5791000000000001
# np.mean(results), mse, len(results) =  0.6835067533766883 tf.Tensor(333.77246, shape=(), dtype=float32) 1999
# slice = train, score = 0.6835067533766883
# np.mean(results), mse, len(results) =  0.6189444444444444 tf.Tensor(335.00748, shape=(), dtype=float32) 900
# slice = test, score = 0.6189444444444444
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.5792 tf.Tensor(346.12442, shape=(), dtype=float32) 100
# slice = key, score = 0.5792
# np.mean(results), mse, len(results) =  0.6856628314157078 tf.Tensor(339.09286, shape=(), dtype=float32) 1999
# slice = train, score = 0.6856628314157078
# np.mean(results), mse, len(results) =  0.6201111111111111 tf.Tensor(339.75128, shape=(), dtype=float32) 900
# slice = test, score = 0.6201111111111111
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.5751 tf.Tensor(359.05716, shape=(), dtype=float32) 100
# slice = key, score = 0.5751
# np.mean(results), mse, len(results) =  0.6869784892446223 tf.Tensor(352.66092, shape=(), dtype=float32) 1999
# slice = train, score = 0.6869784892446223
# np.mean(results), mse, len(results) =  0.6190222222222223 tf.Tensor(353.57922, shape=(), dtype=float32) 900
# slice = test, score = 0.6190222222222223
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.5822999999999999 tf.Tensor(367.89877, shape=(), dtype=float32) 100
# slice = key, score = 0.5822999999999999
# np.mean(results), mse, len(results) =  0.6868784392196099 tf.Tensor(361.3045, shape=(), dtype=float32) 1999
# slice = train, score = 0.6868784392196099
# np.mean(results), mse, len(results) =  0.6209666666666666 tf.Tensor(361.41415, shape=(), dtype=float32) 900
# slice = test, score = 0.6209666666666666
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.5763 tf.Tensor(373.8342, shape=(), dtype=float32) 100
# slice = key, score = 0.5763
# np.mean(results), mse, len(results) =  0.6883341670835418 tf.Tensor(368.73004, shape=(), dtype=float32) 1999
# slice = train, score = 0.6883341670835418
# np.mean(results), mse, len(results) =  0.6210555555555555 tf.Tensor(369.9804, shape=(), dtype=float32) 900
# slice = test, score = 0.6210555555555555
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.5786 tf.Tensor(391.71097, shape=(), dtype=float32) 100
# slice = key, score = 0.5786
# np.mean(results), mse, len(results) =  0.68903951975988 tf.Tensor(379.88217, shape=(), dtype=float32) 1999
# slice = train, score = 0.68903951975988
# np.mean(results), mse, len(results) =  0.6211555555555555 tf.Tensor(380.79126, shape=(), dtype=float32) 900
# slice = test, score = 0.6211555555555555
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.5772 tf.Tensor(391.5254, shape=(), dtype=float32) 100
# slice = key, score = 0.5772
# np.mean(results), mse, len(results) =  0.6888844422211106 tf.Tensor(382.78473, shape=(), dtype=float32) 1999
# slice = train, score = 0.6888844422211106
# np.mean(results), mse, len(results) =  0.6209444444444445 tf.Tensor(383.40518, shape=(), dtype=float32) 900
# slice = test, score = 0.6209444444444445
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.5796000000000001 tf.Tensor(402.30008, shape=(), dtype=float32) 100
# slice = key, score = 0.5796000000000001
# np.mean(results), mse, len(results) =  0.6900300150075037 tf.Tensor(395.17947, shape=(), dtype=float32) 1999
# slice = train, score = 0.6900300150075037
# np.mean(results), mse, len(results) =  0.6188333333333332 tf.Tensor(395.82263, shape=(), dtype=float32) 900
# slice = test, score = 0.6188333333333332
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.5741 tf.Tensor(415.76382, shape=(), dtype=float32) 100
# slice = key, score = 0.5741
# np.mean(results), mse, len(results) =  0.6907103551775888 tf.Tensor(407.23364, shape=(), dtype=float32) 1999
# slice = train, score = 0.6907103551775888
# np.mean(results), mse, len(results) =  0.6188888888888889 tf.Tensor(408.6291, shape=(), dtype=float32) 900
# slice = test, score = 0.6188888888888889
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.5796 tf.Tensor(410.19315, shape=(), dtype=float32) 100
# slice = key, score = 0.5796
# np.mean(results), mse, len(results) =  0.69096048024012 tf.Tensor(402.87415, shape=(), dtype=float32) 1999
# slice = train, score = 0.69096048024012
# np.mean(results), mse, len(results) =  0.6204000000000001 tf.Tensor(403.3944, shape=(), dtype=float32) 900
# slice = test, score = 0.6204000000000001
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.5766 tf.Tensor(424.70935, shape=(), dtype=float32) 100
# slice = key, score = 0.5766
# np.mean(results), mse, len(results) =  0.6922211105552777 tf.Tensor(416.08356, shape=(), dtype=float32) 1999
# slice = train, score = 0.6922211105552777
# np.mean(results), mse, len(results) =  0.6218666666666668 tf.Tensor(416.68454, shape=(), dtype=float32) 900
# slice = test, score = 0.6218666666666668
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.5771000000000001 tf.Tensor(424.4095, shape=(), dtype=float32) 100
# slice = key, score = 0.5771000000000001
# np.mean(results), mse, len(results) =  0.692431215607804 tf.Tensor(417.64578, shape=(), dtype=float32) 1999
# slice = train, score = 0.692431215607804
# np.mean(results), mse, len(results) =  0.6212777777777777 tf.Tensor(419.40958, shape=(), dtype=float32) 900
# slice = test, score = 0.6212777777777777
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.5792 tf.Tensor(433.07776, shape=(), dtype=float32) 100
# slice = key, score = 0.5792
# np.mean(results), mse, len(results) =  0.692911455727864 tf.Tensor(424.2007, shape=(), dtype=float32) 1999
# slice = train, score = 0.692911455727864
# np.mean(results), mse, len(results) =  0.6207111111111111 tf.Tensor(425.15912, shape=(), dtype=float32) 900
# slice = test, score = 0.6207111111111111
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.5796000000000001 tf.Tensor(445.7602, shape=(), dtype=float32) 100
# slice = key, score = 0.5796000000000001
# np.mean(results), mse, len(results) =  0.6944522261130566 tf.Tensor(436.57025, shape=(), dtype=float32) 1999
# slice = train, score = 0.6944522261130566
# np.mean(results), mse, len(results) =  0.6216888888888888 tf.Tensor(438.14706, shape=(), dtype=float32) 900
# slice = test, score = 0.6216888888888888
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.5813 tf.Tensor(449.02054, shape=(), dtype=float32) 100
# slice = key, score = 0.5813
# np.mean(results), mse, len(results) =  0.6949524762381191 tf.Tensor(439.95386, shape=(), dtype=float32) 1999
# slice = train, score = 0.6949524762381191
# np.mean(results), mse, len(results) =  0.6222333333333333 tf.Tensor(440.46475, shape=(), dtype=float32) 900
# slice = test, score = 0.6222333333333333
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.5792 tf.Tensor(454.32025, shape=(), dtype=float32) 100
# slice = key, score = 0.5792
# np.mean(results), mse, len(results) =  0.6937568784392197 tf.Tensor(444.73233, shape=(), dtype=float32) 1999
# slice = train, score = 0.6937568784392197
# np.mean(results), mse, len(results) =  0.6222 tf.Tensor(445.8497, shape=(), dtype=float32) 900
# slice = test, score = 0.6222
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.5829000000000001 tf.Tensor(459.29816, shape=(), dtype=float32) 100
# slice = key, score = 0.5829000000000001
# np.mean(results), mse, len(results) =  0.6949174587293646 tf.Tensor(450.2734, shape=(), dtype=float32) 1999
# slice = train, score = 0.6949174587293646
# np.mean(results), mse, len(results) =  0.6196555555555556 tf.Tensor(451.4737, shape=(), dtype=float32) 900
# slice = test, score = 0.6196555555555556
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.5790000000000001 tf.Tensor(458.1656, shape=(), dtype=float32) 100
# slice = key, score = 0.5790000000000001
# np.mean(results), mse, len(results) =  0.6954177088544271 tf.Tensor(452.47446, shape=(), dtype=float32) 1999
# slice = train, score = 0.6954177088544271
# np.mean(results), mse, len(results) =  0.620488888888889 tf.Tensor(454.07413, shape=(), dtype=float32) 900
# slice = test, score = 0.620488888888889
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.5815 tf.Tensor(466.72287, shape=(), dtype=float32) 100
# slice = key, score = 0.5815
# np.mean(results), mse, len(results) =  0.697208604302151 tf.Tensor(459.42984, shape=(), dtype=float32) 1999
# slice = train, score = 0.697208604302151
# np.mean(results), mse, len(results) =  0.6196666666666666 tf.Tensor(461.17935, shape=(), dtype=float32) 900
# slice = test, score = 0.6196666666666666
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.5789 tf.Tensor(473.96164, shape=(), dtype=float32) 100
# slice = key, score = 0.5789
# np.mean(results), mse, len(results) =  0.6965182591295649 tf.Tensor(466.10785, shape=(), dtype=float32) 1999
# slice = train, score = 0.6965182591295649
# np.mean(results), mse, len(results) =  0.6204111111111111 tf.Tensor(467.74323, shape=(), dtype=float32) 900
# slice = test, score = 0.6204111111111111
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.5771000000000001 tf.Tensor(476.87225, shape=(), dtype=float32) 100
# slice = key, score = 0.5771000000000001
# np.mean(results), mse, len(results) =  0.6968934467233616 tf.Tensor(471.47665, shape=(), dtype=float32) 1999
# slice = train, score = 0.6968934467233616
# np.mean(results), mse, len(results) =  0.6186777777777778 tf.Tensor(473.4681, shape=(), dtype=float32) 900
# slice = test, score = 0.6186777777777778
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.581 tf.Tensor(482.81467, shape=(), dtype=float32) 100
# slice = key, score = 0.581
# np.mean(results), mse, len(results) =  0.6964282141070536 tf.Tensor(478.21033, shape=(), dtype=float32) 1999
# slice = train, score = 0.6964282141070536
# np.mean(results), mse, len(results) =  0.6197222222222222 tf.Tensor(479.00427, shape=(), dtype=float32) 900
# slice = test, score = 0.6197222222222222
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.5776 tf.Tensor(486.60278, shape=(), dtype=float32) 100
# slice = key, score = 0.5776
# np.mean(results), mse, len(results) =  0.6974087043521762 tf.Tensor(478.96954, shape=(), dtype=float32) 1999
# slice = train, score = 0.6974087043521762
# np.mean(results), mse, len(results) =  0.6211 tf.Tensor(480.39993, shape=(), dtype=float32) 900
# slice = test, score = 0.6211
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.5797 tf.Tensor(490.0046, shape=(), dtype=float32) 100
# slice = key, score = 0.5797
# np.mean(results), mse, len(results) =  0.6980790395197599 tf.Tensor(485.4926, shape=(), dtype=float32) 1999
# slice = train, score = 0.6980790395197599
# np.mean(results), mse, len(results) =  0.6209888888888889 tf.Tensor(487.03653, shape=(), dtype=float32) 900
# slice = test, score = 0.6209888888888889
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.5783999999999999 tf.Tensor(490.74582, shape=(), dtype=float32) 100
# slice = key, score = 0.5783999999999999
# np.mean(results), mse, len(results) =  0.6984592296148076 tf.Tensor(486.2818, shape=(), dtype=float32) 1999
# slice = train, score = 0.6984592296148076
# np.mean(results), mse, len(results) =  0.6213111111111111 tf.Tensor(487.3666, shape=(), dtype=float32) 900
# slice = test, score = 0.6213111111111111
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.5795999999999999 tf.Tensor(498.5821, shape=(), dtype=float32) 100
# slice = key, score = 0.5795999999999999
# np.mean(results), mse, len(results) =  0.6991395697848924 tf.Tensor(494.59085, shape=(), dtype=float32) 1999
# slice = train, score = 0.6991395697848924
# np.mean(results), mse, len(results) =  0.6221333333333334 tf.Tensor(495.13043, shape=(), dtype=float32) 900
# slice = test, score = 0.6221333333333334
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.5823 tf.Tensor(499.7658, shape=(), dtype=float32) 100
# slice = key, score = 0.5823
# np.mean(results), mse, len(results) =  0.6992446223111556 tf.Tensor(493.56726, shape=(), dtype=float32) 1999
# slice = train, score = 0.6992446223111556
# np.mean(results), mse, len(results) =  0.6204888888888889 tf.Tensor(495.246, shape=(), dtype=float32) 900
# slice = test, score = 0.6204888888888889
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.5788 tf.Tensor(509.54343, shape=(), dtype=float32) 100
# slice = key, score = 0.5788
# np.mean(results), mse, len(results) =  0.6996748374187094 tf.Tensor(503.27875, shape=(), dtype=float32) 1999
# slice = train, score = 0.6996748374187094
# np.mean(results), mse, len(results) =  0.6206666666666666 tf.Tensor(504.54102, shape=(), dtype=float32) 900
# slice = test, score = 0.6206666666666666
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.5787 tf.Tensor(507.70367, shape=(), dtype=float32) 100
# slice = key, score = 0.5787
# np.mean(results), mse, len(results) =  0.6996348174087044 tf.Tensor(503.81354, shape=(), dtype=float32) 1999
# slice = train, score = 0.6996348174087044
# np.mean(results), mse, len(results) =  0.6206666666666666 tf.Tensor(505.66644, shape=(), dtype=float32) 900
# slice = test, score = 0.6206666666666666
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.5835000000000001 tf.Tensor(517.58844, shape=(), dtype=float32) 100
# slice = key, score = 0.5835000000000001
# np.mean(results), mse, len(results) =  0.7004052026013007 tf.Tensor(510.36685, shape=(), dtype=float32) 1999
# slice = train, score = 0.7004052026013007
# np.mean(results), mse, len(results) =  0.6214555555555556 tf.Tensor(512.1615, shape=(), dtype=float32) 900
# slice = test, score = 0.6214555555555556
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.5780000000000001 tf.Tensor(521.7815, shape=(), dtype=float32) 100
# slice = key, score = 0.5780000000000001
# np.mean(results), mse, len(results) =  0.700975487743872 tf.Tensor(517.05707, shape=(), dtype=float32) 1999
# slice = train, score = 0.700975487743872
# np.mean(results), mse, len(results) =  0.6183111111111111 tf.Tensor(519.7231, shape=(), dtype=float32) 900
# slice = test, score = 0.6183111111111111
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.5817000000000001 tf.Tensor(526.77026, shape=(), dtype=float32) 100
# slice = key, score = 0.5817000000000001
# np.mean(results), mse, len(results) =  0.7014407203601801 tf.Tensor(520.50995, shape=(), dtype=float32) 1999
# slice = train, score = 0.7014407203601801
# np.mean(results), mse, len(results) =  0.6207444444444444 tf.Tensor(521.57886, shape=(), dtype=float32) 900
# slice = test, score = 0.6207444444444444
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.5815 tf.Tensor(535.00684, shape=(), dtype=float32) 100
# slice = key, score = 0.5815
# np.mean(results), mse, len(results) =  0.7002351175587794 tf.Tensor(529.57446, shape=(), dtype=float32) 1999
# slice = train, score = 0.7002351175587794
# np.mean(results), mse, len(results) =  0.6199444444444445 tf.Tensor(531.2622, shape=(), dtype=float32) 900
# slice = test, score = 0.6199444444444445
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.58 tf.Tensor(539.03046, shape=(), dtype=float32) 100
# slice = key, score = 0.58
# np.mean(results), mse, len(results) =  0.7007303651825912 tf.Tensor(531.9024, shape=(), dtype=float32) 1999
# slice = train, score = 0.7007303651825912
# np.mean(results), mse, len(results) =  0.6208 tf.Tensor(533.368, shape=(), dtype=float32) 900
# slice = test, score = 0.6208
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.5781000000000001 tf.Tensor(534.2563, shape=(), dtype=float32) 100
# slice = key, score = 0.5781000000000001
# np.mean(results), mse, len(results) =  0.7014057028514258 tf.Tensor(528.398, shape=(), dtype=float32) 1999
# slice = train, score = 0.7014057028514258
# np.mean(results), mse, len(results) =  0.6205444444444445 tf.Tensor(529.5272, shape=(), dtype=float32) 900
# slice = test, score = 0.6205444444444445
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.5784999999999999 tf.Tensor(539.10474, shape=(), dtype=float32) 100
# slice = key, score = 0.5784999999999999
# np.mean(results), mse, len(results) =  0.7022311155577788 tf.Tensor(532.68243, shape=(), dtype=float32) 1999
# slice = train, score = 0.7022311155577788
# np.mean(results), mse, len(results) =  0.6219666666666667 tf.Tensor(533.61957, shape=(), dtype=float32) 900
# slice = test, score = 0.6219666666666667
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.5811 tf.Tensor(550.1828, shape=(), dtype=float32) 100
# slice = key, score = 0.5811
# np.mean(results), mse, len(results) =  0.7028964482241121 tf.Tensor(546.66235, shape=(), dtype=float32) 1999
# slice = train, score = 0.7028964482241121
# np.mean(results), mse, len(results) =  0.6223333333333334 tf.Tensor(548.8627, shape=(), dtype=float32) 900
# slice = test, score = 0.6223333333333334
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.5787 tf.Tensor(547.67236, shape=(), dtype=float32) 100
# slice = key, score = 0.5787
# np.mean(results), mse, len(results) =  0.7026813406703352 tf.Tensor(542.5485, shape=(), dtype=float32) 1999
# slice = train, score = 0.7026813406703352
# np.mean(results), mse, len(results) =  0.6195888888888889 tf.Tensor(545.1298, shape=(), dtype=float32) 900
# slice = test, score = 0.6195888888888889
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.5826 tf.Tensor(556.9719, shape=(), dtype=float32) 100
# slice = key, score = 0.5826
# np.mean(results), mse, len(results) =  0.7026813406703352 tf.Tensor(550.1332, shape=(), dtype=float32) 1999
# slice = train, score = 0.7026813406703352
# np.mean(results), mse, len(results) =  0.6200555555555555 tf.Tensor(550.63824, shape=(), dtype=float32) 900
# slice = test, score = 0.6200555555555555
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.5799 tf.Tensor(557.5496, shape=(), dtype=float32) 100
# slice = key, score = 0.5799
# np.mean(results), mse, len(results) =  0.7025962981490745 tf.Tensor(553.51013, shape=(), dtype=float32) 1999
# slice = train, score = 0.7025962981490745
# np.mean(results), mse, len(results) =  0.6189666666666668 tf.Tensor(554.521, shape=(), dtype=float32) 900
# slice = test, score = 0.6189666666666668
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.5817 tf.Tensor(558.49225, shape=(), dtype=float32) 100
# slice = key, score = 0.5817
# np.mean(results), mse, len(results) =  0.7037468734367184 tf.Tensor(554.76263, shape=(), dtype=float32) 1999
# slice = train, score = 0.7037468734367184
# np.mean(results), mse, len(results) =  0.620788888888889 tf.Tensor(555.7414, shape=(), dtype=float32) 900
# slice = test, score = 0.620788888888889
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.5825 tf.Tensor(571.2786, shape=(), dtype=float32) 100
# slice = key, score = 0.5825
# np.mean(results), mse, len(results) =  0.7034867433716858 tf.Tensor(565.9838, shape=(), dtype=float32) 1999
# slice = train, score = 0.7034867433716858
# np.mean(results), mse, len(results) =  0.6202555555555556 tf.Tensor(568.0538, shape=(), dtype=float32) 900
# slice = test, score = 0.6202555555555556
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.5796 tf.Tensor(572.1886, shape=(), dtype=float32) 100
# slice = key, score = 0.5796
# np.mean(results), mse, len(results) =  0.704152076038019 tf.Tensor(564.50134, shape=(), dtype=float32) 1999
# slice = train, score = 0.704152076038019
# np.mean(results), mse, len(results) =  0.6200999999999999 tf.Tensor(565.8135, shape=(), dtype=float32) 900
# slice = test, score = 0.6200999999999999
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.5847 tf.Tensor(573.8635, shape=(), dtype=float32) 100
# slice = key, score = 0.5847
# np.mean(results), mse, len(results) =  0.7045822911455728 tf.Tensor(567.8912, shape=(), dtype=float32) 1999
# slice = train, score = 0.7045822911455728
# np.mean(results), mse, len(results) =  0.6197 tf.Tensor(570.4045, shape=(), dtype=float32) 900
# slice = test, score = 0.6197
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.5811000000000002 tf.Tensor(575.56366, shape=(), dtype=float32) 100
# slice = key, score = 0.5811000000000002
# np.mean(results), mse, len(results) =  0.7032116058029015 tf.Tensor(573.3898, shape=(), dtype=float32) 1999
# slice = train, score = 0.7032116058029015
# np.mean(results), mse, len(results) =  0.6204666666666667 tf.Tensor(574.9925, shape=(), dtype=float32) 900
# slice = test, score = 0.6204666666666667
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.5827000000000001 tf.Tensor(579.91205, shape=(), dtype=float32) 100
# slice = key, score = 0.5827000000000001
# np.mean(results), mse, len(results) =  0.7047323661830915 tf.Tensor(577.9549, shape=(), dtype=float32) 1999
# slice = train, score = 0.7047323661830915
# np.mean(results), mse, len(results) =  0.6209777777777777 tf.Tensor(580.04376, shape=(), dtype=float32) 900
# slice = test, score = 0.6209777777777777
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.5823 tf.Tensor(583.75586, shape=(), dtype=float32) 100
# slice = key, score = 0.5823
# np.mean(results), mse, len(results) =  0.7045422711355679 tf.Tensor(581.7002, shape=(), dtype=float32) 1999
# slice = train, score = 0.7045422711355679
# np.mean(results), mse, len(results) =  0.6205999999999999 tf.Tensor(582.73676, shape=(), dtype=float32) 900
# slice = test, score = 0.6205999999999999
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.5848 tf.Tensor(583.82153, shape=(), dtype=float32) 100
# slice = key, score = 0.5848
# np.mean(results), mse, len(results) =  0.704672336168084 tf.Tensor(580.98706, shape=(), dtype=float32) 1999
# slice = train, score = 0.704672336168084
# np.mean(results), mse, len(results) =  0.6213222222222223 tf.Tensor(584.18585, shape=(), dtype=float32) 900
# slice = test, score = 0.6213222222222223
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.5837 tf.Tensor(591.2662, shape=(), dtype=float32) 100
# slice = key, score = 0.5837
# np.mean(results), mse, len(results) =  0.7059579789894947 tf.Tensor(587.96326, shape=(), dtype=float32) 1999
# slice = train, score = 0.7059579789894947
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(589.3949, shape=(), dtype=float32) 900
# slice = test, score = 0.6203
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.5821999999999999 tf.Tensor(594.9399, shape=(), dtype=float32) 100
# slice = key, score = 0.5821999999999999
# np.mean(results), mse, len(results) =  0.7057878939469734 tf.Tensor(593.78235, shape=(), dtype=float32) 1999
# slice = train, score = 0.7057878939469734
# np.mean(results), mse, len(results) =  0.6205888888888889 tf.Tensor(595.25586, shape=(), dtype=float32) 900
# slice = test, score = 0.6205888888888889
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.582 tf.Tensor(597.5911, shape=(), dtype=float32) 100
# slice = key, score = 0.582
# np.mean(results), mse, len(results) =  0.7056128064032016 tf.Tensor(593.09656, shape=(), dtype=float32) 1999
# slice = train, score = 0.7056128064032016
# np.mean(results), mse, len(results) =  0.6212888888888889 tf.Tensor(594.52313, shape=(), dtype=float32) 900
# slice = test, score = 0.6212888888888889
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.5821000000000001 tf.Tensor(603.9533, shape=(), dtype=float32) 100
# slice = key, score = 0.5821000000000001
# np.mean(results), mse, len(results) =  0.7061130565282642 tf.Tensor(601.63055, shape=(), dtype=float32) 1999
# slice = train, score = 0.7061130565282642
# np.mean(results), mse, len(results) =  0.6218555555555556 tf.Tensor(603.31824, shape=(), dtype=float32) 900
# slice = test, score = 0.6218555555555556
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.5849 tf.Tensor(605.64764, shape=(), dtype=float32) 100
# slice = key, score = 0.5849
# np.mean(results), mse, len(results) =  0.7060580290145072 tf.Tensor(604.3763, shape=(), dtype=float32) 1999
# slice = train, score = 0.7060580290145072
# np.mean(results), mse, len(results) =  0.6208444444444444 tf.Tensor(604.3136, shape=(), dtype=float32) 900
# slice = test, score = 0.6208444444444444
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.5858 tf.Tensor(612.04114, shape=(), dtype=float32) 100
# slice = key, score = 0.5858
# np.mean(results), mse, len(results) =  0.7063531765882941 tf.Tensor(610.7434, shape=(), dtype=float32) 1999
# slice = train, score = 0.7063531765882941
# np.mean(results), mse, len(results) =  0.6204777777777777 tf.Tensor(611.9855, shape=(), dtype=float32) 900
# slice = test, score = 0.6204777777777777
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.5843 tf.Tensor(612.11755, shape=(), dtype=float32) 100
# slice = key, score = 0.5843
# np.mean(results), mse, len(results) =  0.7061380690345173 tf.Tensor(614.0599, shape=(), dtype=float32) 1999
# slice = train, score = 0.7061380690345173
# np.mean(results), mse, len(results) =  0.6191000000000001 tf.Tensor(615.5358, shape=(), dtype=float32) 900
# slice = test, score = 0.6191000000000001
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.5797 tf.Tensor(617.2759, shape=(), dtype=float32) 100
# slice = key, score = 0.5797
# np.mean(results), mse, len(results) =  0.7065782891445722 tf.Tensor(614.1276, shape=(), dtype=float32) 1999
# slice = train, score = 0.7065782891445722
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(615.4593, shape=(), dtype=float32) 900
# slice = test, score = 0.6203
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.5790000000000001 tf.Tensor(627.8861, shape=(), dtype=float32) 100
# slice = key, score = 0.5790000000000001
# np.mean(results), mse, len(results) =  0.7064432216108053 tf.Tensor(625.9401, shape=(), dtype=float32) 1999
# slice = train, score = 0.7064432216108053
# np.mean(results), mse, len(results) =  0.6197666666666666 tf.Tensor(625.1894, shape=(), dtype=float32) 900
# slice = test, score = 0.6197666666666666
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.5782 tf.Tensor(632.02136, shape=(), dtype=float32) 100
# slice = key, score = 0.5782
# np.mean(results), mse, len(results) =  0.7077088544272137 tf.Tensor(628.515, shape=(), dtype=float32) 1999
# slice = train, score = 0.7077088544272137
# np.mean(results), mse, len(results) =  0.6203222222222222 tf.Tensor(629.736, shape=(), dtype=float32) 900
# slice = test, score = 0.6203222222222222
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.5791000000000001 tf.Tensor(630.08295, shape=(), dtype=float32) 100
# slice = key, score = 0.5791000000000001
# np.mean(results), mse, len(results) =  0.706543271635818 tf.Tensor(626.7014, shape=(), dtype=float32) 1999
# slice = train, score = 0.706543271635818
# np.mean(results), mse, len(results) =  0.6204222222222222 tf.Tensor(627.3614, shape=(), dtype=float32) 900
# slice = test, score = 0.6204222222222222
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.5806 tf.Tensor(633.0791, shape=(), dtype=float32) 100
# slice = key, score = 0.5806
# np.mean(results), mse, len(results) =  0.7089794897448725 tf.Tensor(629.3941, shape=(), dtype=float32) 1999
# slice = train, score = 0.7089794897448725
# np.mean(results), mse, len(results) =  0.6212222222222222 tf.Tensor(629.67175, shape=(), dtype=float32) 900
# slice = test, score = 0.6212222222222222
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.5788 tf.Tensor(639.22363, shape=(), dtype=float32) 100
# slice = key, score = 0.5788
# np.mean(results), mse, len(results) =  0.7077388694347173 tf.Tensor(635.04785, shape=(), dtype=float32) 1999
# slice = train, score = 0.7077388694347173
# np.mean(results), mse, len(results) =  0.6207444444444445 tf.Tensor(635.1792, shape=(), dtype=float32) 900
# slice = test, score = 0.6207444444444445
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.5802 tf.Tensor(640.0644, shape=(), dtype=float32) 100
# slice = key, score = 0.5802
# np.mean(results), mse, len(results) =  0.707383691845923 tf.Tensor(641.9021, shape=(), dtype=float32) 1999
# slice = train, score = 0.707383691845923
# np.mean(results), mse, len(results) =  0.620311111111111 tf.Tensor(642.54816, shape=(), dtype=float32) 900
# slice = test, score = 0.620311111111111
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.5763 tf.Tensor(643.13336, shape=(), dtype=float32) 100
# slice = key, score = 0.5763
# np.mean(results), mse, len(results) =  0.7083141570785393 tf.Tensor(641.0187, shape=(), dtype=float32) 1999
# slice = train, score = 0.7083141570785393
# np.mean(results), mse, len(results) =  0.6206111111111111 tf.Tensor(642.4789, shape=(), dtype=float32) 900
# slice = test, score = 0.6206111111111111
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.5803 tf.Tensor(645.46643, shape=(), dtype=float32) 100
# slice = key, score = 0.5803
# np.mean(results), mse, len(results) =  0.7085142571285642 tf.Tensor(648.38104, shape=(), dtype=float32) 1999
# slice = train, score = 0.7085142571285642
# np.mean(results), mse, len(results) =  0.6210666666666667 tf.Tensor(649.2332, shape=(), dtype=float32) 900
# slice = test, score = 0.6210666666666667
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.5857000000000001 tf.Tensor(657.7955, shape=(), dtype=float32) 100
# slice = key, score = 0.5857000000000001
# np.mean(results), mse, len(results) =  0.7079089544772387 tf.Tensor(660.3966, shape=(), dtype=float32) 1999
# slice = train, score = 0.7079089544772387
# np.mean(results), mse, len(results) =  0.621588888888889 tf.Tensor(661.75494, shape=(), dtype=float32) 900
# slice = test, score = 0.621588888888889
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.5814 tf.Tensor(653.6942, shape=(), dtype=float32) 100
# slice = key, score = 0.5814
# np.mean(results), mse, len(results) =  0.7085292646323162 tf.Tensor(651.4743, shape=(), dtype=float32) 1999
# slice = train, score = 0.7085292646323162
# np.mean(results), mse, len(results) =  0.6205666666666667 tf.Tensor(651.0328, shape=(), dtype=float32) 900
# slice = test, score = 0.6205666666666667
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.5781000000000001 tf.Tensor(668.3799, shape=(), dtype=float32) 100
# slice = key, score = 0.5781000000000001
# np.mean(results), mse, len(results) =  0.7089294647323662 tf.Tensor(665.34515, shape=(), dtype=float32) 1999
# slice = train, score = 0.7089294647323662
# np.mean(results), mse, len(results) =  0.6192777777777778 tf.Tensor(666.079, shape=(), dtype=float32) 900
# slice = test, score = 0.6192777777777778
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.5809000000000001 tf.Tensor(671.5302, shape=(), dtype=float32) 100
# slice = key, score = 0.5809000000000001
# np.mean(results), mse, len(results) =  0.7092546273136568 tf.Tensor(670.35425, shape=(), dtype=float32) 1999
# slice = train, score = 0.7092546273136568
# np.mean(results), mse, len(results) =  0.6210555555555556 tf.Tensor(671.7873, shape=(), dtype=float32) 900
# slice = test, score = 0.6210555555555556
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.5794 tf.Tensor(669.42645, shape=(), dtype=float32) 100
# slice = key, score = 0.5794
# np.mean(results), mse, len(results) =  0.7088494247123563 tf.Tensor(670.20654, shape=(), dtype=float32) 1999
# slice = train, score = 0.7088494247123563
# np.mean(results), mse, len(results) =  0.6207666666666667 tf.Tensor(670.72217, shape=(), dtype=float32) 900
# slice = test, score = 0.6207666666666667
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.5805 tf.Tensor(668.6336, shape=(), dtype=float32) 100
# slice = key, score = 0.5805
# np.mean(results), mse, len(results) =  0.709344672336168 tf.Tensor(668.5194, shape=(), dtype=float32) 1999
# slice = train, score = 0.709344672336168
# np.mean(results), mse, len(results) =  0.6205888888888889 tf.Tensor(669.88477, shape=(), dtype=float32) 900
# slice = test, score = 0.6205888888888889
# === Iteration 90000 ===
# np.mean(results), mse, len(results) =  0.5825 tf.Tensor(681.743, shape=(), dtype=float32) 100
# slice = key, score = 0.5825
# np.mean(results), mse, len(results) =  0.71016008004002 tf.Tensor(678.0829, shape=(), dtype=float32) 1999
# slice = train, score = 0.71016008004002
# np.mean(results), mse, len(results) =  0.6212000000000001 tf.Tensor(678.90533, shape=(), dtype=float32) 900
# slice = test, score = 0.6212000000000001
#
# === Iteration 91000 ===
# np.mean(results), mse, len(results) =  0.5823 tf.Tensor(683.2457, shape=(), dtype=float32) 100
# slice = key, score = 0.5823
# np.mean(results), mse, len(results) =  0.7105152576288145 tf.Tensor(681.07, shape=(), dtype=float32) 1999
# slice = train, score = 0.7105152576288145
# np.mean(results), mse, len(results) =  0.6209111111111112 tf.Tensor(680.5882, shape=(), dtype=float32) 900
# slice = test, score = 0.6209111111111112
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.5756 tf.Tensor(689.6585, shape=(), dtype=float32) 100
# slice = key, score = 0.5756
# np.mean(results), mse, len(results) =  0.7105102551275637 tf.Tensor(688.2615, shape=(), dtype=float32) 1999
# slice = train, score = 0.7105102551275637
# np.mean(results), mse, len(results) =  0.6191888888888889 tf.Tensor(689.17523, shape=(), dtype=float32) 900
# slice = test, score = 0.6191888888888889
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.5826 tf.Tensor(696.86444, shape=(), dtype=float32) 100
# slice = key, score = 0.5826
# np.mean(results), mse, len(results) =  0.7095547773886944 tf.Tensor(696.76575, shape=(), dtype=float32) 1999
# slice = train, score = 0.7095547773886944
# np.mean(results), mse, len(results) =  0.6183777777777779 tf.Tensor(697.5443, shape=(), dtype=float32) 900
# slice = test, score = 0.6183777777777779
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.5824 tf.Tensor(694.82806, shape=(), dtype=float32) 100
# slice = key, score = 0.5824
# np.mean(results), mse, len(results) =  0.7105652826413207 tf.Tensor(694.88605, shape=(), dtype=float32) 1999
# slice = train, score = 0.7105652826413207
# np.mean(results), mse, len(results) =  0.6187333333333335 tf.Tensor(695.80096, shape=(), dtype=float32) 900
# slice = test, score = 0.6187333333333335
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.5794 tf.Tensor(697.5405, shape=(), dtype=float32) 100
# slice = key, score = 0.5794
# np.mean(results), mse, len(results) =  0.7107503751875938 tf.Tensor(698.94507, shape=(), dtype=float32) 1999
# slice = train, score = 0.7107503751875938
# np.mean(results), mse, len(results) =  0.6207777777777777 tf.Tensor(699.66064, shape=(), dtype=float32) 900
# slice = test, score = 0.6207777777777777
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.5783 tf.Tensor(702.0385, shape=(), dtype=float32) 100
# slice = key, score = 0.5783
# np.mean(results), mse, len(results) =  0.7106253126563281 tf.Tensor(701.8171, shape=(), dtype=float32) 1999
# slice = train, score = 0.7106253126563281
# np.mean(results), mse, len(results) =  0.6211 tf.Tensor(703.5699, shape=(), dtype=float32) 900
# slice = test, score = 0.6211
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.581 tf.Tensor(712.85693, shape=(), dtype=float32) 100
# slice = key, score = 0.581
# np.mean(results), mse, len(results) =  0.7107103551775888 tf.Tensor(705.6696, shape=(), dtype=float32) 1999
# slice = train, score = 0.7107103551775888
# np.mean(results), mse, len(results) =  0.619288888888889 tf.Tensor(707.2001, shape=(), dtype=float32) 900
# slice = test, score = 0.619288888888889
#
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.5802 tf.Tensor(719.42944, shape=(), dtype=float32) 100
# slice = key, score = 0.5802
# np.mean(results), mse, len(results) =  0.7105802901450725 tf.Tensor(714.4549, shape=(), dtype=float32) 1999
# slice = train, score = 0.7105802901450725
# np.mean(results), mse, len(results) =  0.6196333333333334 tf.Tensor(716.20557, shape=(), dtype=float32) 900
# slice = test, score = 0.6196333333333334
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.5794 tf.Tensor(720.35657, shape=(), dtype=float32) 100
# slice = key, score = 0.5794
# np.mean(results), mse, len(results) =  0.7115307653826913 tf.Tensor(719.0427, shape=(), dtype=float32) 1999
# slice = train, score = 0.7115307653826913
# np.mean(results), mse, len(results) =  0.6199111111111112 tf.Tensor(720.35095, shape=(), dtype=float32) 900
# slice = test, score = 0.6199111111111112
# last loss =  tf.Tensor(-0.0051725227, shape=(), dtype=float32)
# np.mean(results), mse, len(results) =  0.7101850925462732 tf.Tensor(731.0358, shape=(), dtype=float32) 1999
# np.mean(results), mse, len(results) =  0.6191444444444445 tf.Tensor(731.1729, shape=(), dtype=float32) 900
# (0.7101850925462732, 0.6191444444444445)

# %%
ctx.key_games = np.random.choice(np.arange(ctx.games_count), ctx.key_size, replace=False)

# %%
N = 100000
m = CBKnnV0(ctx, fit_kwargs={
    'c': 0,
    'train_matrix': True,
    'train_dssm': True,
    'train_vbias': True,
    'train_popbias': True, 'train_bias': True,
    'verbose': False, 'loss': 'softmax_signed',
    'loss_batch': 128, 'loss_q': 0.99,
    # 'dssm_l2': 5e-5,
    'activation': 'elu',
    'n': N,
    # 'ubatch': 1500,
    'score_verbose': 1000,
    'trainable_items': False,
    "TEinit": "anncur",
    "use_keys_in_train": False, # <<< DIFF HERE
    "learning_rate": 0.0005
})

m.fit()
m.get_score("train"), m.get_score("test")
# Out:
# self.embed_users['train'].shape =  (1999, 100)
# self.embed_games.shape =  (24493, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 24493)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (1999, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.0029000000000000002 tf.Tensor(38.31489, shape=(), dtype=float32) 100
# slice = key, score = 0.0029000000000000002
# np.mean(results), mse, len(results) =  0.005142571285642822 tf.Tensor(37.841095, shape=(), dtype=float32) 1999
# slice = train, score = 0.005142571285642822
# np.mean(results), mse, len(results) =  0.0037333333333333337 tf.Tensor(37.865456, shape=(), dtype=float32) 900
# slice = test, score = 0.0037333333333333337
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.5466000000000001 tf.Tensor(51.295834, shape=(), dtype=float32) 100
# slice = key, score = 0.5466000000000001
# np.mean(results), mse, len(results) =  0.6161480740370185 tf.Tensor(53.055893, shape=(), dtype=float32) 1999
# slice = train, score = 0.6161480740370185
# np.mean(results), mse, len(results) =  0.5730555555555555 tf.Tensor(53.265755, shape=(), dtype=float32) 900
# slice = test, score = 0.5730555555555555
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5746 tf.Tensor(72.67692, shape=(), dtype=float32) 100
# slice = key, score = 0.5746
# np.mean(results), mse, len(results) =  0.6468784392196097 tf.Tensor(74.443, shape=(), dtype=float32) 1999
# slice = train, score = 0.6468784392196097
# np.mean(results), mse, len(results) =  0.6011555555555556 tf.Tensor(74.68854, shape=(), dtype=float32) 900
# slice = test, score = 0.6011555555555556
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.5852 tf.Tensor(94.415436, shape=(), dtype=float32) 100
# slice = key, score = 0.5852
# np.mean(results), mse, len(results) =  0.6573536768384192 tf.Tensor(96.217834, shape=(), dtype=float32) 1999
# slice = train, score = 0.6573536768384192
# np.mean(results), mse, len(results) =  0.6107222222222222 tf.Tensor(96.82078, shape=(), dtype=float32) 900
# slice = test, score = 0.6107222222222222
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.5871 tf.Tensor(115.53131, shape=(), dtype=float32) 100
# slice = key, score = 0.5871
# np.mean(results), mse, len(results) =  0.6637718859429715 tf.Tensor(117.33133, shape=(), dtype=float32) 1999
# slice = train, score = 0.6637718859429715
# np.mean(results), mse, len(results) =  0.6128 tf.Tensor(118.32285, shape=(), dtype=float32) 900
# slice = test, score = 0.6128
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.5897000000000001 tf.Tensor(135.51602, shape=(), dtype=float32) 100
# slice = key, score = 0.5897000000000001
# np.mean(results), mse, len(results) =  0.6677538769384693 tf.Tensor(137.80699, shape=(), dtype=float32) 1999
# slice = train, score = 0.6677538769384693
# np.mean(results), mse, len(results) =  0.6144555555555555 tf.Tensor(138.86089, shape=(), dtype=float32) 900
# slice = test, score = 0.6144555555555555
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.5989 tf.Tensor(153.00684, shape=(), dtype=float32) 100
# slice = key, score = 0.5989
# np.mean(results), mse, len(results) =  0.6731815907953977 tf.Tensor(155.92157, shape=(), dtype=float32) 1999
# slice = train, score = 0.6731815907953977
# np.mean(results), mse, len(results) =  0.6178333333333332 tf.Tensor(157.23227, shape=(), dtype=float32) 900
# slice = test, score = 0.6178333333333332
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.5921 tf.Tensor(169.03706, shape=(), dtype=float32) 100
# slice = key, score = 0.5921
# np.mean(results), mse, len(results) =  0.6749574787393697 tf.Tensor(172.92326, shape=(), dtype=float32) 1999
# slice = train, score = 0.6749574787393697
# np.mean(results), mse, len(results) =  0.6168111111111112 tf.Tensor(174.61946, shape=(), dtype=float32) 900
# slice = test, score = 0.6168111111111112
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.5934000000000001 tf.Tensor(188.65756, shape=(), dtype=float32) 100
# slice = key, score = 0.5934000000000001
# np.mean(results), mse, len(results) =  0.6779489744872436 tf.Tensor(190.43488, shape=(), dtype=float32) 1999
# slice = train, score = 0.6779489744872436
# np.mean(results), mse, len(results) =  0.6186555555555555 tf.Tensor(191.5736, shape=(), dtype=float32) 900
# slice = test, score = 0.6186555555555555
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.5926000000000001 tf.Tensor(203.36227, shape=(), dtype=float32) 100
# slice = key, score = 0.5926000000000001
# np.mean(results), mse, len(results) =  0.678304152076038 tf.Tensor(204.18268, shape=(), dtype=float32) 1999
# slice = train, score = 0.678304152076038
# np.mean(results), mse, len(results) =  0.6191555555555556 tf.Tensor(206.51407, shape=(), dtype=float32) 900
# slice = test, score = 0.6191555555555556
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.5981000000000001 tf.Tensor(216.21275, shape=(), dtype=float32) 100
# slice = key, score = 0.5981000000000001
# np.mean(results), mse, len(results) =  0.6803401700850426 tf.Tensor(219.6277, shape=(), dtype=float32) 1999
# slice = train, score = 0.6803401700850426
# np.mean(results), mse, len(results) =  0.6189888888888889 tf.Tensor(222.18898, shape=(), dtype=float32) 900
# slice = test, score = 0.6189888888888889
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.5946000000000001 tf.Tensor(231.79863, shape=(), dtype=float32) 100
# slice = key, score = 0.5946000000000001
# np.mean(results), mse, len(results) =  0.6821160580290145 tf.Tensor(235.13744, shape=(), dtype=float32) 1999
# slice = train, score = 0.6821160580290145
# np.mean(results), mse, len(results) =  0.6217666666666666 tf.Tensor(237.82777, shape=(), dtype=float32) 900
# slice = test, score = 0.6217666666666666
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.5937 tf.Tensor(243.55502, shape=(), dtype=float32) 100
# slice = key, score = 0.5937
# np.mean(results), mse, len(results) =  0.6844272136068035 tf.Tensor(247.14418, shape=(), dtype=float32) 1999
# slice = train, score = 0.6844272136068035
# np.mean(results), mse, len(results) =  0.6211888888888888 tf.Tensor(249.12077, shape=(), dtype=float32) 900
# slice = test, score = 0.6211888888888888
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.5957000000000001 tf.Tensor(257.5348, shape=(), dtype=float32) 100
# slice = key, score = 0.5957000000000001
# np.mean(results), mse, len(results) =  0.6850225112556277 tf.Tensor(260.61337, shape=(), dtype=float32) 1999
# slice = train, score = 0.6850225112556277
# np.mean(results), mse, len(results) =  0.6214 tf.Tensor(262.32715, shape=(), dtype=float32) 900
# slice = test, score = 0.6214
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.5963 tf.Tensor(268.1763, shape=(), dtype=float32) 100
# slice = key, score = 0.5963
# np.mean(results), mse, len(results) =  0.6869334667333666 tf.Tensor(271.45035, shape=(), dtype=float32) 1999
# slice = train, score = 0.6869334667333666
# np.mean(results), mse, len(results) =  0.6220666666666665 tf.Tensor(274.22897, shape=(), dtype=float32) 900
# slice = test, score = 0.6220666666666665
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.5915 tf.Tensor(278.70688, shape=(), dtype=float32) 100
# slice = key, score = 0.5915
# np.mean(results), mse, len(results) =  0.6882141070535268 tf.Tensor(283.78772, shape=(), dtype=float32) 1999
# slice = train, score = 0.6882141070535268
# np.mean(results), mse, len(results) =  0.6238222222222223 tf.Tensor(286.7364, shape=(), dtype=float32) 900
# slice = test, score = 0.6238222222222223
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.6008000000000001 tf.Tensor(291.46405, shape=(), dtype=float32) 100
# slice = key, score = 0.6008000000000001
# np.mean(results), mse, len(results) =  0.6891845922961481 tf.Tensor(294.50818, shape=(), dtype=float32) 1999
# slice = train, score = 0.6891845922961481
# np.mean(results), mse, len(results) =  0.6228222222222223 tf.Tensor(298.33755, shape=(), dtype=float32) 900
# slice = test, score = 0.6228222222222223
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.5986 tf.Tensor(297.10608, shape=(), dtype=float32) 100
# slice = key, score = 0.5986
# np.mean(results), mse, len(results) =  0.6902851425712856 tf.Tensor(303.21515, shape=(), dtype=float32) 1999
# slice = train, score = 0.6902851425712856
# np.mean(results), mse, len(results) =  0.6231333333333333 tf.Tensor(307.59198, shape=(), dtype=float32) 900
# slice = test, score = 0.6231333333333333
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6007000000000001 tf.Tensor(310.74814, shape=(), dtype=float32) 100
# slice = key, score = 0.6007000000000001
# np.mean(results), mse, len(results) =  0.6909854927463732 tf.Tensor(315.59665, shape=(), dtype=float32) 1999
# slice = train, score = 0.6909854927463732
# np.mean(results), mse, len(results) =  0.6236555555555555 tf.Tensor(320.10052, shape=(), dtype=float32) 900
# slice = test, score = 0.6236555555555555
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.598 tf.Tensor(319.99103, shape=(), dtype=float32) 100
# slice = key, score = 0.598
# np.mean(results), mse, len(results) =  0.6919959979989995 tf.Tensor(325.6205, shape=(), dtype=float32) 1999
# slice = train, score = 0.6919959979989995
# np.mean(results), mse, len(results) =  0.6222111111111112 tf.Tensor(330.26843, shape=(), dtype=float32) 900
# slice = test, score = 0.6222111111111112
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.5932 tf.Tensor(330.1853, shape=(), dtype=float32) 100
# slice = key, score = 0.5932
# np.mean(results), mse, len(results) =  0.6924012006003002 tf.Tensor(334.11005, shape=(), dtype=float32) 1999
# slice = train, score = 0.6924012006003002
# np.mean(results), mse, len(results) =  0.6217555555555555 tf.Tensor(339.55258, shape=(), dtype=float32) 900
# slice = test, score = 0.6217555555555555
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.5974 tf.Tensor(329.55414, shape=(), dtype=float32) 100
# slice = key, score = 0.5974
# np.mean(results), mse, len(results) =  0.6930115057528764 tf.Tensor(337.73785, shape=(), dtype=float32) 1999
# slice = train, score = 0.6930115057528764
# np.mean(results), mse, len(results) =  0.6236777777777777 tf.Tensor(342.25284, shape=(), dtype=float32) 900
# slice = test, score = 0.6236777777777777
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.5992000000000001 tf.Tensor(339.55212, shape=(), dtype=float32) 100
# slice = key, score = 0.5992000000000001
# np.mean(results), mse, len(results) =  0.694392196098049 tf.Tensor(347.96072, shape=(), dtype=float32) 1999
# slice = train, score = 0.694392196098049
# np.mean(results), mse, len(results) =  0.6224 tf.Tensor(353.4459, shape=(), dtype=float32) 900
# slice = test, score = 0.6224
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.5969 tf.Tensor(351.84885, shape=(), dtype=float32) 100
# slice = key, score = 0.5969
# np.mean(results), mse, len(results) =  0.6945522761380689 tf.Tensor(356.78296, shape=(), dtype=float32) 1999
# slice = train, score = 0.6945522761380689
# np.mean(results), mse, len(results) =  0.6227888888888888 tf.Tensor(362.68744, shape=(), dtype=float32) 900
# slice = test, score = 0.6227888888888888
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.5985 tf.Tensor(355.6144, shape=(), dtype=float32) 100
# slice = key, score = 0.5985
# np.mean(results), mse, len(results) =  0.6961630815407703 tf.Tensor(364.33978, shape=(), dtype=float32) 1999
# slice = train, score = 0.6961630815407703
# np.mean(results), mse, len(results) =  0.6237444444444444 tf.Tensor(368.58984, shape=(), dtype=float32) 900
# slice = test, score = 0.6237444444444444
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.5973000000000002 tf.Tensor(363.7288, shape=(), dtype=float32) 100
# slice = key, score = 0.5973000000000002
# np.mean(results), mse, len(results) =  0.6968584292146073 tf.Tensor(372.26443, shape=(), dtype=float32) 1999
# slice = train, score = 0.6968584292146073
# np.mean(results), mse, len(results) =  0.6227333333333332 tf.Tensor(377.97552, shape=(), dtype=float32) 900
# slice = test, score = 0.6227333333333332
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.5955999999999999 tf.Tensor(365.85416, shape=(), dtype=float32) 100
# slice = key, score = 0.5955999999999999
# np.mean(results), mse, len(results) =  0.6971985992996499 tf.Tensor(373.0473, shape=(), dtype=float32) 1999
# slice = train, score = 0.6971985992996499
# np.mean(results), mse, len(results) =  0.6224888888888889 tf.Tensor(380.26498, shape=(), dtype=float32) 900
# slice = test, score = 0.6224888888888889
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6008 tf.Tensor(372.46814, shape=(), dtype=float32) 100
# slice = key, score = 0.6008
# np.mean(results), mse, len(results) =  0.6980990495247624 tf.Tensor(378.57083, shape=(), dtype=float32) 1999
# slice = train, score = 0.6980990495247624
# np.mean(results), mse, len(results) =  0.6238333333333334 tf.Tensor(383.79016, shape=(), dtype=float32) 900
# slice = test, score = 0.6238333333333334
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.598 tf.Tensor(389.34348, shape=(), dtype=float32) 100
# slice = key, score = 0.598
# np.mean(results), mse, len(results) =  0.6984592296148076 tf.Tensor(393.3084, shape=(), dtype=float32) 1999
# slice = train, score = 0.6984592296148076
# np.mean(results), mse, len(results) =  0.6238777777777778 tf.Tensor(398.197, shape=(), dtype=float32) 900
# slice = test, score = 0.6238777777777778
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.6003 tf.Tensor(388.90027, shape=(), dtype=float32) 100
# slice = key, score = 0.6003
# np.mean(results), mse, len(results) =  0.6994647323661831 tf.Tensor(394.62967, shape=(), dtype=float32) 1999
# slice = train, score = 0.6994647323661831
# np.mean(results), mse, len(results) =  0.6231222222222221 tf.Tensor(400.3588, shape=(), dtype=float32) 900
# slice = test, score = 0.6231222222222221
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.5956000000000001 tf.Tensor(402.19598, shape=(), dtype=float32) 100
# slice = key, score = 0.5956000000000001
# np.mean(results), mse, len(results) =  0.7004652326163081 tf.Tensor(406.87015, shape=(), dtype=float32) 1999
# slice = train, score = 0.7004652326163081
# np.mean(results), mse, len(results) =  0.6228555555555556 tf.Tensor(413.48285, shape=(), dtype=float32) 900
# slice = test, score = 0.6228555555555556
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.5982999999999999 tf.Tensor(404.54608, shape=(), dtype=float32) 100
# slice = key, score = 0.5982999999999999
# np.mean(results), mse, len(results) =  0.6999849924962481 tf.Tensor(409.2368, shape=(), dtype=float32) 1999
# slice = train, score = 0.6999849924962481
# np.mean(results), mse, len(results) =  0.6243666666666667 tf.Tensor(415.25107, shape=(), dtype=float32) 900
# slice = test, score = 0.6243666666666667
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.5988 tf.Tensor(404.69724, shape=(), dtype=float32) 100
# slice = key, score = 0.5988
# np.mean(results), mse, len(results) =  0.7002851425712856 tf.Tensor(412.9996, shape=(), dtype=float32) 1999
# slice = train, score = 0.7002851425712856
# np.mean(results), mse, len(results) =  0.6237222222222223 tf.Tensor(419.58795, shape=(), dtype=float32) 900
# slice = test, score = 0.6237222222222223
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.5892000000000001 tf.Tensor(412.2223, shape=(), dtype=float32) 100
# slice = key, score = 0.5892000000000001
# np.mean(results), mse, len(results) =  0.7018159079539769 tf.Tensor(418.07166, shape=(), dtype=float32) 1999
# slice = train, score = 0.7018159079539769
# np.mean(results), mse, len(results) =  0.6230777777777777 tf.Tensor(424.47766, shape=(), dtype=float32) 900
# slice = test, score = 0.6230777777777777
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.5974 tf.Tensor(421.2193, shape=(), dtype=float32) 100
# slice = key, score = 0.5974
# np.mean(results), mse, len(results) =  0.7015957978989494 tf.Tensor(427.40485, shape=(), dtype=float32) 1999
# slice = train, score = 0.7015957978989494
# np.mean(results), mse, len(results) =  0.6239 tf.Tensor(433.34784, shape=(), dtype=float32) 900
# slice = test, score = 0.6239
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.5969 tf.Tensor(425.78943, shape=(), dtype=float32) 100
# slice = key, score = 0.5969
# np.mean(results), mse, len(results) =  0.7021210605302651 tf.Tensor(431.59137, shape=(), dtype=float32) 1999
# slice = train, score = 0.7021210605302651
# np.mean(results), mse, len(results) =  0.6236666666666666 tf.Tensor(438.43817, shape=(), dtype=float32) 900
# slice = test, score = 0.6236666666666666
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.5973 tf.Tensor(425.03436, shape=(), dtype=float32) 100
# slice = key, score = 0.5973
# np.mean(results), mse, len(results) =  0.704112056028014 tf.Tensor(432.186, shape=(), dtype=float32) 1999
# slice = train, score = 0.704112056028014
# np.mean(results), mse, len(results) =  0.6254111111111111 tf.Tensor(438.95386, shape=(), dtype=float32) 900
# slice = test, score = 0.6254111111111111
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.5961 tf.Tensor(437.49792, shape=(), dtype=float32) 100
# slice = key, score = 0.5961
# np.mean(results), mse, len(results) =  0.7033016508254127 tf.Tensor(441.19547, shape=(), dtype=float32) 1999
# slice = train, score = 0.7033016508254127
# np.mean(results), mse, len(results) =  0.6231333333333334 tf.Tensor(448.3536, shape=(), dtype=float32) 900
# slice = test, score = 0.6231333333333334
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.5943 tf.Tensor(443.49838, shape=(), dtype=float32) 100
# slice = key, score = 0.5943
# np.mean(results), mse, len(results) =  0.7041420710355177 tf.Tensor(448.03815, shape=(), dtype=float32) 1999
# slice = train, score = 0.7041420710355177
# np.mean(results), mse, len(results) =  0.6240555555555556 tf.Tensor(454.8092, shape=(), dtype=float32) 900
# slice = test, score = 0.6240555555555556
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.5952000000000001 tf.Tensor(449.2005, shape=(), dtype=float32) 100
# slice = key, score = 0.5952000000000001
# np.mean(results), mse, len(results) =  0.7036568284142072 tf.Tensor(451.87326, shape=(), dtype=float32) 1999
# slice = train, score = 0.7036568284142072
# np.mean(results), mse, len(results) =  0.6233000000000001 tf.Tensor(458.52914, shape=(), dtype=float32) 900
# slice = test, score = 0.6233000000000001
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.5942000000000001 tf.Tensor(452.93558, shape=(), dtype=float32) 100
# slice = key, score = 0.5942000000000001
# np.mean(results), mse, len(results) =  0.703471735867934 tf.Tensor(456.82068, shape=(), dtype=float32) 1999
# slice = train, score = 0.703471735867934
# np.mean(results), mse, len(results) =  0.622922222222222 tf.Tensor(464.0835, shape=(), dtype=float32) 900
# slice = test, score = 0.622922222222222
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.6014999999999999 tf.Tensor(457.9872, shape=(), dtype=float32) 100
# slice = key, score = 0.6014999999999999
# np.mean(results), mse, len(results) =  0.7063081540770384 tf.Tensor(463.51547, shape=(), dtype=float32) 1999
# slice = train, score = 0.7063081540770384
# np.mean(results), mse, len(results) =  0.6250222222222223 tf.Tensor(469.912, shape=(), dtype=float32) 900
# slice = test, score = 0.6250222222222223
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.5956 tf.Tensor(466.80145, shape=(), dtype=float32) 100
# slice = key, score = 0.5956
# np.mean(results), mse, len(results) =  0.7053226613306653 tf.Tensor(468.68228, shape=(), dtype=float32) 1999
# slice = train, score = 0.7053226613306653
# np.mean(results), mse, len(results) =  0.6250111111111111 tf.Tensor(476.50204, shape=(), dtype=float32) 900
# slice = test, score = 0.6250111111111111
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.5999 tf.Tensor(471.70297, shape=(), dtype=float32) 100
# slice = key, score = 0.5999
# np.mean(results), mse, len(results) =  0.705207603801901 tf.Tensor(477.5338, shape=(), dtype=float32) 1999
# slice = train, score = 0.705207603801901
# np.mean(results), mse, len(results) =  0.6243777777777778 tf.Tensor(485.27557, shape=(), dtype=float32) 900
# slice = test, score = 0.6243777777777778
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.596 tf.Tensor(474.33582, shape=(), dtype=float32) 100
# slice = key, score = 0.596
# np.mean(results), mse, len(results) =  0.7062231115557779 tf.Tensor(477.82468, shape=(), dtype=float32) 1999
# slice = train, score = 0.7062231115557779
# np.mean(results), mse, len(results) =  0.6246555555555556 tf.Tensor(486.6591, shape=(), dtype=float32) 900
# slice = test, score = 0.6246555555555556
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.5946 tf.Tensor(474.9135, shape=(), dtype=float32) 100
# slice = key, score = 0.5946
# np.mean(results), mse, len(results) =  0.7065882941470736 tf.Tensor(478.02023, shape=(), dtype=float32) 1999
# slice = train, score = 0.7065882941470736
# np.mean(results), mse, len(results) =  0.6232666666666667 tf.Tensor(485.45508, shape=(), dtype=float32) 900
# slice = test, score = 0.6232666666666667
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.5948 tf.Tensor(480.51935, shape=(), dtype=float32) 100
# slice = key, score = 0.5948
# np.mean(results), mse, len(results) =  0.7062381190595297 tf.Tensor(486.72763, shape=(), dtype=float32) 1999
# slice = train, score = 0.7062381190595297
# np.mean(results), mse, len(results) =  0.6217666666666667 tf.Tensor(494.45288, shape=(), dtype=float32) 900
# slice = test, score = 0.6217666666666667
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.5942000000000001 tf.Tensor(487.95572, shape=(), dtype=float32) 100
# slice = key, score = 0.5942000000000001
# np.mean(results), mse, len(results) =  0.7076138069034518 tf.Tensor(489.15692, shape=(), dtype=float32) 1999
# slice = train, score = 0.7076138069034518
# np.mean(results), mse, len(results) =  0.6225 tf.Tensor(497.5497, shape=(), dtype=float32) 900
# slice = test, score = 0.6225
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.5949 tf.Tensor(491.6003, shape=(), dtype=float32) 100
# slice = key, score = 0.5949
# np.mean(results), mse, len(results) =  0.7077238619309655 tf.Tensor(494.7427, shape=(), dtype=float32) 1999
# slice = train, score = 0.7077238619309655
# np.mean(results), mse, len(results) =  0.6235888888888889 tf.Tensor(503.38812, shape=(), dtype=float32) 900
# slice = test, score = 0.6235888888888889
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.5941999999999998 tf.Tensor(493.59476, shape=(), dtype=float32) 100
# slice = key, score = 0.5941999999999998
# np.mean(results), mse, len(results) =  0.7081240620310155 tf.Tensor(496.56677, shape=(), dtype=float32) 1999
# slice = train, score = 0.7081240620310155
# np.mean(results), mse, len(results) =  0.6246000000000002 tf.Tensor(505.2944, shape=(), dtype=float32) 900
# slice = test, score = 0.6246000000000002
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.5929 tf.Tensor(503.98883, shape=(), dtype=float32) 100
# slice = key, score = 0.5929
# np.mean(results), mse, len(results) =  0.7097098549274637 tf.Tensor(508.66168, shape=(), dtype=float32) 1999
# slice = train, score = 0.7097098549274637
# np.mean(results), mse, len(results) =  0.6228666666666666 tf.Tensor(518.20984, shape=(), dtype=float32) 900
# slice = test, score = 0.6228666666666666
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.5943 tf.Tensor(507.84497, shape=(), dtype=float32) 100
# slice = key, score = 0.5943
# np.mean(results), mse, len(results) =  0.7082141070535268 tf.Tensor(509.8853, shape=(), dtype=float32) 1999
# slice = train, score = 0.7082141070535268
# np.mean(results), mse, len(results) =  0.6215 tf.Tensor(517.4809, shape=(), dtype=float32) 900
# slice = test, score = 0.6215
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.5977 tf.Tensor(510.63174, shape=(), dtype=float32) 100
# slice = key, score = 0.5977
# np.mean(results), mse, len(results) =  0.708784392196098 tf.Tensor(517.5887, shape=(), dtype=float32) 1999
# slice = train, score = 0.708784392196098
# np.mean(results), mse, len(results) =  0.6235111111111111 tf.Tensor(526.492, shape=(), dtype=float32) 900
# slice = test, score = 0.6235111111111111
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.592 tf.Tensor(515.6737, shape=(), dtype=float32) 100
# slice = key, score = 0.592
# np.mean(results), mse, len(results) =  0.7090245122561282 tf.Tensor(522.4199, shape=(), dtype=float32) 1999
# slice = train, score = 0.7090245122561282
# np.mean(results), mse, len(results) =  0.6226333333333334 tf.Tensor(529.9929, shape=(), dtype=float32) 900
# slice = test, score = 0.6226333333333334
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.5921 tf.Tensor(520.27045, shape=(), dtype=float32) 100
# slice = key, score = 0.5921
# np.mean(results), mse, len(results) =  0.7091945972986493 tf.Tensor(524.4802, shape=(), dtype=float32) 1999
# slice = train, score = 0.7091945972986493
# np.mean(results), mse, len(results) =  0.6224888888888889 tf.Tensor(533.34485, shape=(), dtype=float32) 900
# slice = test, score = 0.6224888888888889
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.5968 tf.Tensor(527.9664, shape=(), dtype=float32) 100
# slice = key, score = 0.5968
# np.mean(results), mse, len(results) =  0.7095697848924462 tf.Tensor(531.3875, shape=(), dtype=float32) 1999
# slice = train, score = 0.7095697848924462
# np.mean(results), mse, len(results) =  0.6234666666666667 tf.Tensor(541.15, shape=(), dtype=float32) 900
# slice = test, score = 0.6234666666666667
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.5957 tf.Tensor(532.022, shape=(), dtype=float32) 100
# slice = key, score = 0.5957
# np.mean(results), mse, len(results) =  0.7101950975487743 tf.Tensor(535.8775, shape=(), dtype=float32) 1999
# slice = train, score = 0.7101950975487743
# np.mean(results), mse, len(results) =  0.6218777777777779 tf.Tensor(545.3727, shape=(), dtype=float32) 900
# slice = test, score = 0.6218777777777779
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.5926999999999999 tf.Tensor(537.7481, shape=(), dtype=float32) 100
# slice = key, score = 0.5926999999999999
# np.mean(results), mse, len(results) =  0.709144572286143 tf.Tensor(539.824, shape=(), dtype=float32) 1999
# slice = train, score = 0.709144572286143
# np.mean(results), mse, len(results) =  0.6219666666666667 tf.Tensor(550.64795, shape=(), dtype=float32) 900
# slice = test, score = 0.6219666666666667
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.5985 tf.Tensor(541.64813, shape=(), dtype=float32) 100
# slice = key, score = 0.5985
# np.mean(results), mse, len(results) =  0.7100650325162582 tf.Tensor(543.7328, shape=(), dtype=float32) 1999
# slice = train, score = 0.7100650325162582
# np.mean(results), mse, len(results) =  0.6214888888888888 tf.Tensor(554.3544, shape=(), dtype=float32) 900
# slice = test, score = 0.6214888888888888
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.5967 tf.Tensor(551.77124, shape=(), dtype=float32) 100
# slice = key, score = 0.5967
# np.mean(results), mse, len(results) =  0.7101500750375188 tf.Tensor(554.2842, shape=(), dtype=float32) 1999
# slice = train, score = 0.7101500750375188
# np.mean(results), mse, len(results) =  0.6234 tf.Tensor(564.71686, shape=(), dtype=float32) 900
# slice = test, score = 0.6234
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.5982999999999999 tf.Tensor(548.74023, shape=(), dtype=float32) 100
# slice = key, score = 0.5982999999999999
# np.mean(results), mse, len(results) =  0.7107453726863432 tf.Tensor(554.5731, shape=(), dtype=float32) 1999
# slice = train, score = 0.7107453726863432
# np.mean(results), mse, len(results) =  0.6226777777777778 tf.Tensor(563.1467, shape=(), dtype=float32) 900
# slice = test, score = 0.6226777777777778
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.5967 tf.Tensor(559.26154, shape=(), dtype=float32) 100
# slice = key, score = 0.5967
# np.mean(results), mse, len(results) =  0.7113806903451727 tf.Tensor(561.4346, shape=(), dtype=float32) 1999
# slice = train, score = 0.7113806903451727
# np.mean(results), mse, len(results) =  0.6233111111111111 tf.Tensor(571.9671, shape=(), dtype=float32) 900
# slice = test, score = 0.6233111111111111
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.5941000000000001 tf.Tensor(562.9446, shape=(), dtype=float32) 100
# slice = key, score = 0.5941000000000001
# np.mean(results), mse, len(results) =  0.7116008004002001 tf.Tensor(564.0417, shape=(), dtype=float32) 1999
# slice = train, score = 0.7116008004002001
# np.mean(results), mse, len(results) =  0.6232888888888888 tf.Tensor(573.17334, shape=(), dtype=float32) 900
# slice = test, score = 0.6232888888888888
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.5963999999999999 tf.Tensor(571.11566, shape=(), dtype=float32) 100
# slice = key, score = 0.5963999999999999
# np.mean(results), mse, len(results) =  0.7125562781390696 tf.Tensor(573.53674, shape=(), dtype=float32) 1999
# slice = train, score = 0.7125562781390696
# np.mean(results), mse, len(results) =  0.6220666666666667 tf.Tensor(584.9739, shape=(), dtype=float32) 900
# slice = test, score = 0.6220666666666667
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.5946999999999999 tf.Tensor(571.39453, shape=(), dtype=float32) 100
# slice = key, score = 0.5946999999999999
# np.mean(results), mse, len(results) =  0.7127013506753377 tf.Tensor(574.1222, shape=(), dtype=float32) 1999
# slice = train, score = 0.7127013506753377
# np.mean(results), mse, len(results) =  0.6215777777777778 tf.Tensor(585.5951, shape=(), dtype=float32) 900
# slice = test, score = 0.6215777777777778
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.5991000000000001 tf.Tensor(576.58746, shape=(), dtype=float32) 100
# slice = key, score = 0.5991000000000001
# np.mean(results), mse, len(results) =  0.7132466233116559 tf.Tensor(578.36975, shape=(), dtype=float32) 1999
# slice = train, score = 0.7132466233116559
# np.mean(results), mse, len(results) =  0.6238777777777778 tf.Tensor(590.1741, shape=(), dtype=float32) 900
# slice = test, score = 0.6238777777777778
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.5972 tf.Tensor(578.57684, shape=(), dtype=float32) 100
# slice = key, score = 0.5972
# np.mean(results), mse, len(results) =  0.7121110555277639 tf.Tensor(583.14105, shape=(), dtype=float32) 1999
# slice = train, score = 0.7121110555277639
# np.mean(results), mse, len(results) =  0.6209888888888889 tf.Tensor(594.251, shape=(), dtype=float32) 900
# slice = test, score = 0.6209888888888889
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.5933 tf.Tensor(588.608, shape=(), dtype=float32) 100
# slice = key, score = 0.5933
# np.mean(results), mse, len(results) =  0.7125012506253127 tf.Tensor(593.51184, shape=(), dtype=float32) 1999
# slice = train, score = 0.7125012506253127
# np.mean(results), mse, len(results) =  0.6222666666666666 tf.Tensor(604.16583, shape=(), dtype=float32) 900
# slice = test, score = 0.6222666666666666
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.5974999999999999 tf.Tensor(587.61786, shape=(), dtype=float32) 100
# slice = key, score = 0.5974999999999999
# np.mean(results), mse, len(results) =  0.7128714357178589 tf.Tensor(592.3592, shape=(), dtype=float32) 1999
# slice = train, score = 0.7128714357178589
# np.mean(results), mse, len(results) =  0.621488888888889 tf.Tensor(602.16956, shape=(), dtype=float32) 900
# slice = test, score = 0.621488888888889
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.5968999999999999 tf.Tensor(601.51306, shape=(), dtype=float32) 100
# slice = key, score = 0.5968999999999999
# np.mean(results), mse, len(results) =  0.7136568284142071 tf.Tensor(604.8426, shape=(), dtype=float32) 1999
# slice = train, score = 0.7136568284142071
# np.mean(results), mse, len(results) =  0.6227222222222223 tf.Tensor(617.6094, shape=(), dtype=float32) 900
# slice = test, score = 0.6227222222222223
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.5945 tf.Tensor(602.2777, shape=(), dtype=float32) 100
# slice = key, score = 0.5945
# np.mean(results), mse, len(results) =  0.7132066033016509 tf.Tensor(607.01117, shape=(), dtype=float32) 1999
# slice = train, score = 0.7132066033016509
# np.mean(results), mse, len(results) =  0.6206111111111111 tf.Tensor(618.0953, shape=(), dtype=float32) 900
# slice = test, score = 0.6206111111111111
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.5946000000000001 tf.Tensor(610.39453, shape=(), dtype=float32) 100
# slice = key, score = 0.5946000000000001
# np.mean(results), mse, len(results) =  0.713216608304152 tf.Tensor(612.2182, shape=(), dtype=float32) 1999
# slice = train, score = 0.713216608304152
# np.mean(results), mse, len(results) =  0.6216222222222223 tf.Tensor(622.8133, shape=(), dtype=float32) 900
# slice = test, score = 0.6216222222222223
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.5980000000000001 tf.Tensor(614.19836, shape=(), dtype=float32) 100
# slice = key, score = 0.5980000000000001
# np.mean(results), mse, len(results) =  0.7132866433216609 tf.Tensor(612.3218, shape=(), dtype=float32) 1999
# slice = train, score = 0.7132866433216609
# np.mean(results), mse, len(results) =  0.6213222222222223 tf.Tensor(622.3957, shape=(), dtype=float32) 900
# slice = test, score = 0.6213222222222223
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.5941000000000001 tf.Tensor(618.7115, shape=(), dtype=float32) 100
# slice = key, score = 0.5941000000000001
# np.mean(results), mse, len(results) =  0.714767383691846 tf.Tensor(622.99506, shape=(), dtype=float32) 1999
# slice = train, score = 0.714767383691846
# np.mean(results), mse, len(results) =  0.6217333333333332 tf.Tensor(633.7224, shape=(), dtype=float32) 900
# slice = test, score = 0.6217333333333332
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.5968000000000001 tf.Tensor(622.3473, shape=(), dtype=float32) 100
# slice = key, score = 0.5968000000000001
# np.mean(results), mse, len(results) =  0.713631815907954 tf.Tensor(628.43604, shape=(), dtype=float32) 1999
# slice = train, score = 0.713631815907954
# np.mean(results), mse, len(results) =  0.6217111111111111 tf.Tensor(640.34406, shape=(), dtype=float32) 900
# slice = test, score = 0.6217111111111111
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.5991 tf.Tensor(633.569, shape=(), dtype=float32) 100
# slice = key, score = 0.5991
# np.mean(results), mse, len(results) =  0.7144672336168084 tf.Tensor(638.56604, shape=(), dtype=float32) 1999
# slice = train, score = 0.7144672336168084
# np.mean(results), mse, len(results) =  0.6224000000000001 tf.Tensor(650.9321, shape=(), dtype=float32) 900
# slice = test, score = 0.6224000000000001
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.5955 tf.Tensor(635.7594, shape=(), dtype=float32) 100
# slice = key, score = 0.5955
# np.mean(results), mse, len(results) =  0.7146923461730866 tf.Tensor(638.9584, shape=(), dtype=float32) 1999
# slice = train, score = 0.7146923461730866
# np.mean(results), mse, len(results) =  0.6214222222222222 tf.Tensor(650.99084, shape=(), dtype=float32) 900
# slice = test, score = 0.6214222222222222
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.5921 tf.Tensor(642.4417, shape=(), dtype=float32) 100
# slice = key, score = 0.5921
# np.mean(results), mse, len(results) =  0.7145422711355677 tf.Tensor(646.046, shape=(), dtype=float32) 1999
# slice = train, score = 0.7145422711355677
# np.mean(results), mse, len(results) =  0.6210555555555556 tf.Tensor(657.7204, shape=(), dtype=float32) 900
# slice = test, score = 0.6210555555555556
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.5962000000000001 tf.Tensor(649.9835, shape=(), dtype=float32) 100
# slice = key, score = 0.5962000000000001
# np.mean(results), mse, len(results) =  0.7148174087043522 tf.Tensor(653.1859, shape=(), dtype=float32) 1999
# slice = train, score = 0.7148174087043522
# np.mean(results), mse, len(results) =  0.6209444444444443 tf.Tensor(667.3639, shape=(), dtype=float32) 900
# slice = test, score = 0.6209444444444443
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.5929999999999999 tf.Tensor(655.8189, shape=(), dtype=float32) 100
# slice = key, score = 0.5929999999999999
# np.mean(results), mse, len(results) =  0.7140970485242621 tf.Tensor(659.9561, shape=(), dtype=float32) 1999
# slice = train, score = 0.7140970485242621
# np.mean(results), mse, len(results) =  0.620488888888889 tf.Tensor(672.98944, shape=(), dtype=float32) 900
# slice = test, score = 0.620488888888889
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.5954 tf.Tensor(663.89966, shape=(), dtype=float32) 100
# slice = key, score = 0.5954
# np.mean(results), mse, len(results) =  0.715287643821911 tf.Tensor(666.9482, shape=(), dtype=float32) 1999
# slice = train, score = 0.715287643821911
# np.mean(results), mse, len(results) =  0.6205777777777778 tf.Tensor(680.88947, shape=(), dtype=float32) 900
# slice = test, score = 0.6205777777777778
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.5941 tf.Tensor(671.2728, shape=(), dtype=float32) 100
# slice = key, score = 0.5941
# np.mean(results), mse, len(results) =  0.7157628814407204 tf.Tensor(673.2887, shape=(), dtype=float32) 1999
# slice = train, score = 0.7157628814407204
# np.mean(results), mse, len(results) =  0.620311111111111 tf.Tensor(685.9978, shape=(), dtype=float32) 900
# slice = test, score = 0.620311111111111
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.5924 tf.Tensor(665.49927, shape=(), dtype=float32) 100
# slice = key, score = 0.5924
# np.mean(results), mse, len(results) =  0.7160330165082541 tf.Tensor(670.57806, shape=(), dtype=float32) 1999
# slice = train, score = 0.7160330165082541
# np.mean(results), mse, len(results) =  0.6206333333333333 tf.Tensor(682.64264, shape=(), dtype=float32) 900
# slice = test, score = 0.6206333333333333
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.5965 tf.Tensor(676.076, shape=(), dtype=float32) 100
# slice = key, score = 0.5965
# np.mean(results), mse, len(results) =  0.7156028014007003 tf.Tensor(679.36127, shape=(), dtype=float32) 1999
# slice = train, score = 0.7156028014007003
# np.mean(results), mse, len(results) =  0.6214666666666666 tf.Tensor(692.7967, shape=(), dtype=float32) 900
# slice = test, score = 0.6214666666666666
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.5984999999999999 tf.Tensor(681.56415, shape=(), dtype=float32) 100
# slice = key, score = 0.5984999999999999
# np.mean(results), mse, len(results) =  0.715687843921961 tf.Tensor(686.75745, shape=(), dtype=float32) 1999
# slice = train, score = 0.715687843921961
# np.mean(results), mse, len(results) =  0.6207666666666667 tf.Tensor(701.34766, shape=(), dtype=float32) 900
# slice = test, score = 0.6207666666666667
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.5925 tf.Tensor(692.0284, shape=(), dtype=float32) 100
# slice = key, score = 0.5925
# np.mean(results), mse, len(results) =  0.7161030515257629 tf.Tensor(700.2983, shape=(), dtype=float32) 1999
# slice = train, score = 0.7161030515257629
# np.mean(results), mse, len(results) =  0.6196 tf.Tensor(712.79626, shape=(), dtype=float32) 900
# slice = test, score = 0.6196
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.595 tf.Tensor(695.4514, shape=(), dtype=float32) 100
# slice = key, score = 0.595
# np.mean(results), mse, len(results) =  0.716703351675838 tf.Tensor(697.51605, shape=(), dtype=float32) 1999
# slice = train, score = 0.716703351675838
# np.mean(results), mse, len(results) =  0.6221666666666668 tf.Tensor(711.37036, shape=(), dtype=float32) 900
# slice = test, score = 0.6221666666666668
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.5974 tf.Tensor(694.23517, shape=(), dtype=float32) 100
# slice = key, score = 0.5974
# np.mean(results), mse, len(results) =  0.715832916458229 tf.Tensor(703.74426, shape=(), dtype=float32) 1999
# slice = train, score = 0.715832916458229
# np.mean(results), mse, len(results) =  0.6219444444444444 tf.Tensor(716.9773, shape=(), dtype=float32) 900
# slice = test, score = 0.6219444444444444
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.5948 tf.Tensor(711.43335, shape=(), dtype=float32) 100
# slice = key, score = 0.5948
# np.mean(results), mse, len(results) =  0.716648324162081 tf.Tensor(712.8313, shape=(), dtype=float32) 1999
# slice = train, score = 0.716648324162081
# np.mean(results), mse, len(results) =  0.6206666666666667 tf.Tensor(726.3211, shape=(), dtype=float32) 900
# slice = test, score = 0.6206666666666667
#
# === Iteration 90000 ===
# np.mean(results), mse, len(results) =  0.5905 tf.Tensor(715.8165, shape=(), dtype=float32) 100
# slice = key, score = 0.5905
# np.mean(results), mse, len(results) =  0.716848424212106 tf.Tensor(719.65967, shape=(), dtype=float32) 1999
# slice = train, score = 0.716848424212106
# np.mean(results), mse, len(results) =  0.6205888888888889 tf.Tensor(733.64453, shape=(), dtype=float32) 900
# slice = test, score = 0.6205888888888889
#
# === Iteration 91000 ===
# np.mean(results), mse, len(results) =  0.5949 tf.Tensor(721.32605, shape=(), dtype=float32) 100
# slice = key, score = 0.5949
# np.mean(results), mse, len(results) =  0.7173486743371686 tf.Tensor(724.20526, shape=(), dtype=float32) 1999
# slice = train, score = 0.7173486743371686
# np.mean(results), mse, len(results) =  0.6201555555555557 tf.Tensor(737.41943, shape=(), dtype=float32) 900
# slice = test, score = 0.6201555555555557
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.5925 tf.Tensor(734.70447, shape=(), dtype=float32) 100
# slice = key, score = 0.5925
# np.mean(results), mse, len(results) =  0.7170535267633817 tf.Tensor(734.5184, shape=(), dtype=float32) 1999
# slice = train, score = 0.7170535267633817
# np.mean(results), mse, len(results) =  0.6208777777777778 tf.Tensor(748.4055, shape=(), dtype=float32) 900
# slice = test, score = 0.6208777777777778
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.5941000000000001 tf.Tensor(731.46094, shape=(), dtype=float32) 100
# slice = key, score = 0.5941000000000001
# np.mean(results), mse, len(results) =  0.7175387693846924 tf.Tensor(739.2626, shape=(), dtype=float32) 1999
# slice = train, score = 0.7175387693846924
# np.mean(results), mse, len(results) =  0.6210555555555556 tf.Tensor(753.65515, shape=(), dtype=float32) 900
# slice = test, score = 0.6210555555555556
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.5965 tf.Tensor(743.0676, shape=(), dtype=float32) 100
# slice = key, score = 0.5965
# np.mean(results), mse, len(results) =  0.717128564282141 tf.Tensor(746.034, shape=(), dtype=float32) 1999
# slice = train, score = 0.717128564282141
# np.mean(results), mse, len(results) =  0.6211555555555555 tf.Tensor(759.42053, shape=(), dtype=float32) 900
# slice = test, score = 0.6211555555555555
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.5921 tf.Tensor(737.67053, shape=(), dtype=float32) 100
# slice = key, score = 0.5921
# np.mean(results), mse, len(results) =  0.7170085042521261 tf.Tensor(746.54016, shape=(), dtype=float32) 1999
# slice = train, score = 0.7170085042521261
# np.mean(results), mse, len(results) =  0.6197111111111111 tf.Tensor(760.4921, shape=(), dtype=float32) 900
# slice = test, score = 0.6197111111111111
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.5934999999999999 tf.Tensor(745.2564, shape=(), dtype=float32) 100
# slice = key, score = 0.5934999999999999
# np.mean(results), mse, len(results) =  0.7176938469234617 tf.Tensor(751.87714, shape=(), dtype=float32) 1999
# slice = train, score = 0.7176938469234617
# np.mean(results), mse, len(results) =  0.6201444444444444 tf.Tensor(766.43353, shape=(), dtype=float32) 900
# slice = test, score = 0.6201444444444444
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.5918000000000001 tf.Tensor(747.7972, shape=(), dtype=float32) 100
# slice = key, score = 0.5918000000000001
# np.mean(results), mse, len(results) =  0.7175737868934466 tf.Tensor(755.16235, shape=(), dtype=float32) 1999
# slice = train, score = 0.7175737868934466
# np.mean(results), mse, len(results) =  0.6203 tf.Tensor(769.4989, shape=(), dtype=float32) 900
# slice = test, score = 0.6203
#
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.5912 tf.Tensor(761.1667, shape=(), dtype=float32) 100
# slice = key, score = 0.5912
# np.mean(results), mse, len(results) =  0.7180040020010005 tf.Tensor(770.5084, shape=(), dtype=float32) 1999
# slice = train, score = 0.7180040020010005
# np.mean(results), mse, len(results) =  0.6204000000000001 tf.Tensor(786.5403, shape=(), dtype=float32) 900
# slice = test, score = 0.6204000000000001
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.5937 tf.Tensor(776.4879, shape=(), dtype=float32) 100
# slice = key, score = 0.5937
# np.mean(results), mse, len(results) =  0.7179489744872435 tf.Tensor(778.27875, shape=(), dtype=float32) 1999
# slice = train, score = 0.7179489744872435
# np.mean(results), mse, len(results) =  0.6197111111111111 tf.Tensor(793.81177, shape=(), dtype=float32) 900
# slice = test, score = 0.6197111111111111
# last loss =  tf.Tensor(-0.005206227, shape=(), dtype=float32)
# np.mean(results), mse, len(results) =  0.7183041520760379 tf.Tensor(779.3127, shape=(), dtype=float32) 1999
# np.mean(results), mse, len(results) =  0.6200999999999999 tf.Tensor(794.8707, shape=(), dtype=float32) 900
# (0.7183041520760379, 0.6200999999999999)
