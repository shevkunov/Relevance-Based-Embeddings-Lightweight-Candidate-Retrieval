# %% [markdown]
# ### setup

# %%
# !pip install -U sentence-transformers
# !pip install datasets
# !pip install tensorflow_ranking

# %%
import pickle
import numpy as np
import os
import tqdm
import torch
import gc

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

from importlib import reload
from matplotlib import pyplot as plt

import matrix_approx_zeshel

matrix_approx_zeshel = reload(matrix_approx_zeshel)

# !ls  | grep matrix_approx_zeshel
# Out:
# 2024-03-26 02:43:52.791853: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-26 02:43:53.209295: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-26 02:43:53.211362: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-26 02:43:55.019319: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# matrix_approx_zeshel.py

# %%
import collections
import pickle
import numpy as np
import tqdm
import os
import gc

import matplotlib.pyplot as plt


def load(limit, raw_path = "stand/log.local.logtime2.txt", path = "log.local.logtime2.bin", key_games = None, seed = 17, det_attempts = 0, key_size = 100):
    readvector = lambda s : np.array(list(map(float, s.strip()[1:-2].split(","))))
    requests = list()
    docembs = collections.defaultdict(dict)

    if os.path.isfile(path):
        with open(path, "rb") as f:
            flimit, frequests, fdocembs = pickle.load(f)
            if flimit == limit:
                requests, docembs = frequests, fdocembs
            else:
                print(f"WARN: buffered limit is different, {flimit} != {limit}, reloading...")

    if not requests:
        with open(raw_path) as f:
            req = list()
            reqid = None
            models = list()
            prevreqmodel = None
            reqmodel = dict()
            prevmodelid = -1
            bannermodelid = -1
            for i, line in tqdm.tqdm_notebook(enumerate(f)):
                if line.startswith("Model = 6;"):
                    prevreqmodel = reqmodel
                    reqmodel = dict()

                if line.startswith("Model = "):
                    spl = line.split(" ")
                    prevmodelid = int(spl[2][:-1])
                    bannermodelid = max(bannermodelid , prevmodelid)
                    reqmodel[prevmodelid] = readvector(spl[3])
                elif line.startswith("dbid"):
                    spl = line.split(" ")
                    dbid = int(spl[1][:-1])
                    docembs[bannermodelid][dbid] = readvector(spl[2])
                elif line.startswith("seed"):
                    if len(requests) >= limit:
                        break
                    if req:
                        requests.append((reqid, prevreqmodel, sorted(req)))
                        req = list()
                    reqid = "$_" + (line.split()[1] + "_" + line.split()[3])
                else:
                    req.append(
                        (int(line.split()[0]), float(line.split()[1]))
                    )
        
        with open(path, "wb") as f:
            pickle.dump((limit, requests, docembs), f)

    games_count = len(requests[0][2])
    assert games_count == 16514
    requests = [r for r in requests if len(r[2]) == games_count]
    
    print([(i, len(docembs[i].keys())) for i in docembs])  # should be equal
    docblocks = {
        mid : np.array([x[1] for x in sorted(list(docembs[mid].items()))])
        for mid in docembs
    }
    
    class EvalContext:
        def __init__(self, games_count = games_count, key_size = key_size, train_size = 0.7, key_games = None, seed = 17, det_attempts = 0):
            self.games_count = games_count
            
            self.key_size = key_size
            self.key_games = (
                np.random.choice(np.arange(games_count), key_size, replace=False)
                if key_games is None else
                key_games
            )

            self.requests = requests
            np.random.seed(seed)
            np.random.shuffle(self.requests)
            
            self.try_det_attempts(det_attempts)

            self.key_reqs = self.requests[:key_size + 1]
            self.key_reqs_idx = np.arange(key_size + 1)

            self.train_split = int(len(self.requests) * train_size)

            assert key_size + 1 < self.train_split

            self.train_reqs = self.requests[key_size + 1: self.train_split]
            self.test_reqs = self.requests[self.train_split:]

            self.slices = ["key", "train", "test"]
            print(len(self.key_reqs), len(self.train_reqs), len(self.test_reqs))

            self.docblocks = docblocks
            self.relevs = dict()
            
        def get_top_games(self):
            if not hasattr(self, "top_games"):
                embed_games = np.array([
                    np.array([r[2][g_i][1] for r in self.get_requests("train")])
                    for g_i in range(self.games_count)
                ])

                self.embed_games_mean = embed_games.mean(axis=1)
                self.top_games_all = (-self.embed_games_mean).argsort()
                self.top_games = self.top_games_all[:len(self.key_games)]

            return self.top_games
        
        def set_top_games_as_key(self):
            self.key_games = self.get_top_games()
            return self
        
        def get_kmeans_games(self, all_from_labels=True):
            X = self.get_relevs("train").T

            k_func = (
                (lambda C : euclidean_distances(X, C.cluster_centers_).argmin(axis=0))
                if not all_from_labels else
                (lambda C : from_labels(X, C.labels_))
            )
            K_KMeans = k_func(
                KMeans(n_clusters=self.key_size, random_state=0).fit(X)  #, n_init="auto").fit(X)
            )

            return K_KMeans

        def set_kmeans_games_as_key(self, *args, **kwargs):
            self.key_games = self.get_kmeans_games(*args, **kwargs)
            return self

        def try_det_attempts(self, det_attempts, model_id = 6):
            def get_det(r, r_i_array):
                kr = np.array([
                    r[r_i][1][model_id][:self.key_size]
                    for r_i in r_i_array[:self.key_size]
                ])
                return np.abs(np.linalg.det(kr[:kr.shape[1], :]))

            best_i_array = np.arange(len(self.requests))

            for _ in range(det_attempts):
                # print("try update key_reqs...")
                
                r_i_array = np.arange(len(self.requests))
                np.random.shuffle(r_i_array)
                
                n, o = get_det(self.requests, r_i_array), get_det(self.requests, best_i_array)
                # print(n, o)
                if n > o:
                    best_i_array = r_i_array
                    # print("updated!")

            print("Best det = ", get_det(self.requests, best_i_array))
            
            new_requests = [
                self.requests[i]
                for i in best_i_array
            ]
            
            del self.requests
            gc.collect()

            self.requests = new_requests
            print(get_det(self.requests, np.arange(len(self.requests))))

        def get_relevs(self, t = "train"):
            if t not in self.relevs:
                self.relevs[t] = np.array([
                    np.array([g_i[1] for g_i in r[2]])
                    for r in self.get_requests(t)
                ])
                
            return self.relevs[t]

        def get_requests(self, t = "train"):
            if t == "train":
                return self.train_reqs
            elif t == "key":
                return self.key_reqs
            elif t == "test":
                return self.test_reqs
            else:
                assert False

    return EvalContext(key_games = key_games, seed = seed, det_attempts = det_attempts)

# %%
def load_ment_to_ent_scores(directory = "yugioh", shuffle_rows = 0, full = True):
    data = list()

    for file in os.listdir(directory):
        path = f"{directory}/{file}"
        print(f"Loading file {path}")
        with open(path, "rb") as f:
            data.append(
                pickle.load(f)
            )
    data = sorted(data, key = lambda x: x["arg_dict"]["n_ment_start"])

    for i in range(len(data) - 1):
        if full:
            assert data[i]["arg_dict"]["n_ment_start"] + data[i]["arg_dict"]["n_ment"] == data[i + 1]["arg_dict"]["n_ment_start"]
        else:
            assert data[i]["arg_dict"]["n_ment_start"] + data[i]["arg_dict"]["n_ment"] <= data[i + 1]["arg_dict"]["n_ment_start"]
        
    ment_to_ent_scores = list(map(lambda x: x["ment_to_ent_scores"], data))
    ment_to_ent_scores = np.vstack(ment_to_ent_scores)
    print("Loaded shape = ", ment_to_ent_scores.shape)
    
    if shuffle_rows:
        print(f"Shuffling... (seed = {shuffle_rows})")
        np.random.seed(shuffle_rows)
        np.random.shuffle(ment_to_ent_scores)
    
    return ment_to_ent_scores

# %%
from sklearn.cluster import KMeans
import numpy as np
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import euclidean_distances


def from_labels(X, labels):
    K = list()
    for i in range(100):
        sl_i = np.arange(X.shape[0])[labels == i]
        sl = X[labels == i]
        
        if len(sl_i) == 0:
            # bug-mode
            while True:
                chosen = np.random.choice(np.arange(X.shape[0])[labels < i], size=1)[0]
                if chosen not in K:
                    K.append(chosen)
                    break
            continue
            
        center = sl.mean(axis=0).reshape(1, -1)
        best = euclidean_distances(sl, center).argmin()
        K.append(sl_i[best])
        assert labels[K[-1]] == i
    return K

class EvalContextRelevs:
    def __init__(self, relevs, key_size = 100, train_size = 0.7, key_games = None, seed = 17, shuffle=False, det_attempts = 0):
        self.relevs = np.array(relevs)
        self.reqs_count = self.relevs.shape[0]
        self.games_count = self.relevs.shape[1]
        
        self.key_size = key_size
        self.key_games = (
            np.random.choice(np.arange(self.games_count), key_size, replace=False)
            if key_games is None else
            key_games
        )
        np.random.seed(seed)
        if shuffle:
            np.random.shuffle(self.relevs)

        self.try_det_attempts(det_attempts)
        self.train_split = int(self.reqs_count * train_size)

        assert key_size + 1 < self.train_split


        self.key_relevs = self.relevs[:key_size]
        self.train_relevs = self.relevs[key_size + 1: self.train_split]
        self.test_relevs = self.relevs[self.train_split:]

        self.slices = ["key", "train", "test"]
        print(len(self.key_relevs), len(self.train_relevs), len(self.test_relevs))

    def get_top_games(self):
        return self.relevs.mean(axis=0).argsort()[:self.key_size]

    def set_top_games_as_key(self):
        self.key_games = self.get_top_games()
        return self

    def get_kmeans_games(self, all_from_labels=True):
        X = self.get_relevs("train").T

        k_func = (
            (lambda C : euclidean_distances(X, C.cluster_centers_).argmin(axis=0))
            if not all_from_labels else
            (lambda C : from_labels(X, C.labels_))
        )
        K_KMeans = k_func(
            KMeans(n_clusters=self.key_size, random_state=0).fit(X)  #, n_init="auto").fit(X)
        )
        
        return K_KMeans
    
    def set_kmeans_games_as_key(self, *args, **kwargs):
        self.key_games = self.get_kmeans_games(*args, **kwargs)
        return self
    

    def try_det_attempts(self, det_attempts):
        def get_det(r):
            kr = r[:self.key_size, self.key_games] - r.mean()
            return np.abs(np.linalg.det(kr))

        best_i_array = np.arange(len(self.relevs))

        for i in range(det_attempts):

            r_i_array = np.arange(len(self.relevs))
            np.random.shuffle(r_i_array)

            n, o = get_det(self.relevs[r_i_array, :]), get_det(self.relevs[best_i_array, :])
            
            # print(f"try update key_reqs ({o} vs {n}...")
            if n > o:
                best_i_array = r_i_array
                print(f"updated det ({i}, {o} -> {n})")

        print("Best det = ", get_det(self.relevs[best_i_array, :]))

        self.relevs = self.relevs[best_i_array, :]
        print("Current de = ", get_det(self.relevs))
        
    def get_relevs(self, t = "train"):
        if t == "train":
            return self.train_relevs
        elif t == "key":
            return self.key_relevs
        elif t == "test":
            return self.test_relevs
        else:
            assert False
            
    def get_requests(self, t = "train"):
        if t == "train":
            return self.train_reqs
        elif t == "key":
            return self.key_reqs
        elif t == "test":
            return self.test_reqs
        else:
            assert False

# %%
import tensorflow as tf
import copy
import tensorflow_ranking as tfr

class Popular:
    def __init__(self, ctx):
        self.ctx = ctx
        self.game_avg_scores = {
            t : self.get_user_scores(t).mean(axis = 0)
            for t in self.ctx.slices
        }
        self.trus_top = dict()
        
    def get_user_scores(self, t):
        return self.ctx.get_relevs(t)
    
    def get_user_embs(self, t):
        assert False
    
    def get_game_embs(self):
        assert False

    def fit(self, t = "train"):
        self.top_logits = self.game_avg_scores[t]
        self.top = np.argsort(-self.top_logits)

    def recommend(self, t):
        return [self.top_logits for _ in self.get_user_scores(t)]
    
    def get_score(self, t, topsize = 100):    
        recs = self.recommend(t)
        
        if isinstance(recs, list):
            recs = np.array(recs)
        
        mse = np.mean((recs - self.get_user_scores(t)) ** 2)
        
        if isinstance(recs, tf.Tensor):
            recs = tf.argsort(-recs, axis=1)[:, :topsize].numpy()
        else:
            recs = np.argsort(-recs, axis=1)[:, :topsize]
        
        if (t, topsize) not in self.trus_top:
            trus = self.get_user_scores(t)
            trus = np.argsort(-trus, axis=1)[:, :topsize]
            self.trus_top[(t, topsize)] = trus
            
        trus = self.trus_top[(t, topsize)]

        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
            
        results = [
            ev(rec, tru) / float(topsize)
            for rec, tru in zip(recs,trus)
        ]

        print("np.mean(results), mse, len(results) = ",
              np.mean(results), mse, len(results))

        return np.mean(results)
    
import tensorflow as tf
import copy
import tensorflow_ranking as tfr

DEFAULT_FIT_KWARGS = {
    "learning_rate": 0.001,
    "n": 500,
    "c": 5000,
    "matrix_l2": 0,
    "dssm_l2": 0,
    "train_popbias": False,
    "train_bias": False,
    "train_vbias": False,
    "verbose": True,
    "train_matrix": True,
    "train_dssm": False,
    "loss": "mse",
    "ubatch": 1e9,
    "activation": "relu",
    "score_verbose": 0,
    "trainable_items": False,
    "use_keys_in_train": False,
    "Winit": "glorot0.01",
    "Wfreeze": False,
    "TEinit": "legacy",
    "normalize_embs": True,
    "save_callback": None
}

class CBKnnV0(Popular):
    def __init__(self, ctx, fit_kwargs = dict()):
        super().__init__(ctx)
        
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(fit_kwargs)
        self.fit_kwargs = p
        
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(self.fit_kwargs)
        
        self.embed_users = {
            t : np.array([
                    np.array([r_i[i] for i in sorted(ctx.key_games)])
                    for r_i in ctx.get_relevs(t)
                ])
            for t in ctx.slices
        }
        self.embed_users_mean = {
            t : self.embed_users[t].mean(axis = 0)
            for t in ctx.slices
        }
        # embed_users = embed_users - embed_users_mean
        print("self.embed_users['train'].shape = ", self.embed_users['train'].shape )
        
        self.embed_games = np.array([
            np.array([r[g_i] for r in ctx.get_relevs("key")])
            for g_i in range(ctx.games_count)
        ])
        
        self.embed_games_mean = self.embed_games.mean(axis = 0)
        
        # embed_games = embed_games - embed_games_mean
        print("self.embed_games.shape = ", self.embed_games.shape)
        
        
        if self.fit_kwargs["trainable_items"]:
            if self.fit_kwargs["TEinit"] == "legacy":
                value = self.embed_games
            elif self.fit_kwargs["TEinit"] == "anncur":
                key_cols_idx = np.array(sorted(ctx.key_games))
                value = (
                    np.linalg.pinv(ctx.get_relevs("train")[:, key_cols_idx])
                    @ ctx.get_relevs("train")
                ).T
                print(type(value))
            else:
                assert False, "unknown TEinit: " + str(self.fit_kwargs["TEinit"])
                
            self.trainable_games = tf.Variable(
                tf.convert_to_tensor(value, dtype=tf.float32),
                trainable=True
            )
        else:
            if self.fit_kwargs["TEinit"] == "anncur":
                key_cols_idx = np.array(sorted(ctx.key_games))
                self.embed_games = (
                    np.linalg.pinv(ctx.get_relevs("train")[:, key_cols_idx])
                    @ ctx.get_relevs("train")
                ).T
                print("ANNCur init")
            
        
        self.games_top_key = self.embed_games.mean(axis = 1)
        
        self.games2users = np.array([
            self.embed_games[g_i]
            for g_i in ctx.key_games
        ])
        print("self.games2users.shape = ", self.games2users.shape)
        
        self.core_users_scores = ctx.get_relevs("key")
        print("self.core_users_scores.shape = ", self.core_users_scores.shape)
        
        self.core_users_embs = self.embed_users["key"]
        print("self.core_users_embs.shape = ", self.core_users_embs.shape)
        
        self.ge_users = (
            (self.embed_users["train"].T / self.embed_users["train"].mean(axis=1)).T @ self.games2users
        )
        # ge_users = embed_users @ games2users
        print("self.ge_users.shape = ", self.ge_users.shape)
        
        self.slice2best = {
            t : 0
            for t in ctx.slices
        }
    
    def __repr__(self):
        return "CbKnn(" + str(self.fit_kwargs) + ")"
        
    # inherited   
    # def get_user_scores(self, t):
    
    def get_user_embs(self, t):
        if self.fit_kwargs["normalize_embs"]:
            return (self.embed_users[t] - self.embed_users_mean["train"]) / self.embed_users[t].std(axis=0)
        else:
            return self.embed_users[t]
    
    def get_game_embs(self):
        if not self.fit_kwargs["trainable_items"]:
            if self.fit_kwargs["normalize_embs"]:
                return (self.embed_games - self.embed_games.mean(axis=0)) / self.embed_games.std(axis=0)
            else:
                return self.embed_games 
        else:
            return self.trainable_games

    def fit(self, **kwargs):
        p = copy.copy(DEFAULT_FIT_KWARGS)
        p.update(self.fit_kwargs)
        p.update(kwargs)

        self.p = p
        self.train_bias = p["train_bias"]
        self.train_vbias = p["train_vbias"]
        self.train_popbias = p["train_popbias"]
        self.train_matrix = p["train_matrix"]
        self.train_dssm = p["train_dssm"]
        self.loss = p["loss"]

        if p["use_keys_in_train"]:
            train_user_scores = np.vstack([
                self.get_user_scores("key"),
                self.get_user_scores("train")
            ])
            train_user_embs = np.vstack([
                self.get_user_embs("key"),
                self.get_user_embs("train")
            ])
        else:
            train_user_scores = self.get_user_scores("train")
            train_user_embs = self.get_user_embs("train")

        game_embs = self.get_game_embs()
        
        
        
        if self.p["Winit"] == "glorot0.01":
            initializer = tf.keras.initializers.GlorotUniform()
            values = initializer(shape=(train_user_embs.shape[1], game_embs.shape[1]))
            values = values / 100.  
        elif self.p["Winit"] == "glorot":
            initializer = tf.keras.initializers.GlorotUniform()
            values = initializer(shape=(train_user_embs.shape[1], game_embs.shape[1]))
        elif self.p["Winit"] == "eye":
            values = np.eye(train_user_embs.shape[1], game_embs.shape[1])
        else:
            assert False, "init is not known:" + str(self.p["init"])
            
        self.W = tf.Variable(values, trainable = True) 
        self.pb = tf.Variable(1., trainable = True) 
        self.b = tf.Variable(0., trainable = True) 
        
        if p["verbose"]:
            print("self.W = ", self.W)
            print("0-loss = ", tf.reduce_mean((train_user_scores - 0) ** 2))
    
        opt =  tf.keras.optimizers.Adam(learning_rate=p["learning_rate"])

        if self.train_dssm:
            self.train_dssm = True

            dim = game_embs.shape[1]
            self.g_dssm = tf.keras.Sequential([
                tf.keras.layers.Dense(dim, activation=p["activation"]),
                tf.keras.layers.Dense(dim, activation=None)
            ])
            self.g_dssm(game_embs)
            
            # dim = train_user_embs.shape[1]
            self.u_dssm = tf.keras.Sequential([
                tf.keras.layers.Dense(dim, activation=p["activation"]),
                tf.keras.layers.Dense(dim, activation=None)
            ])
            self.u_dssm(train_user_embs)
            
        if self.train_vbias:
            self.vb = tf.Variable(
                np.zeros_like(self.game_avg_scores["train"], dtype=np.float32),
                trainable = True
            ) 
        
        
        for i in range(p["n"]):
            def loss():
                def get_logits_scores(loss_batch = 1e9):
                    game_slice = None
                    
                    ubatch = p["ubatch"]
                    if ubatch >= train_user_scores.shape[0]:
                        train_user_embs_ = train_user_embs
                        scores_ = train_user_scores
                    else:
                        u_slice = np.random.choice(np.arange(train_user_scores.shape[0]), ubatch, replace = True)
                        train_user_embs_ = train_user_embs[u_slice]
                        scores_ = train_user_scores[u_slice]
                    
                    if loss_batch >= game_embs.shape[0]:
                        game_embs_ = game_embs
                        scores_ = scores_
                    else:
                        game_slice = np.random.choice(np.arange(game_embs.shape[0]), loss_batch, replace = True)
                        game_embs_ = (
                            game_embs[game_slice]
                            if isinstance(game_embs, np.ndarray) else
                            tf.gather(game_embs, game_slice)
                        )
                        scores_ = scores_[:, game_slice]
                        
                    
                    logits = 0
                    
                    if self.train_matrix:
                        logits += train_user_embs_ @ self.W @ tf.transpose(game_embs_)

                    if self.train_dssm:
                        logits += self.u_dssm(train_user_embs_) @ tf.transpose(self.g_dssm(game_embs_))
                    
                    if self.train_popbias:
                        if loss_batch >= game_embs.shape[0]:
                            logits += self.pb * self.game_avg_scores["train"]
                        else:
                            logits += self.pb * self.game_avg_scores["train"][game_slice]
                        
                    if self.train_vbias:
                        if loss_batch >= game_embs.shape[0]:
                            logits += self.vb
                        else:
                            logits += tf.gather(self.vb, game_slice)
                        
                    if self.train_bias:
                        logits += self.b
                        
                    return logits, scores_
                        
                if self.loss == "mse":
                    logits, scores = get_logits_scores(
                        loss_batch = (1e9 if "loss_batch" not in p else p["loss_batch"]))
                    v = tf.reduce_mean((scores - logits) ** 2)
                elif self.loss == "qmse":
                    logits, scores = get_logits_scores(
                        loss_batch = (1e9 if "loss_batch" not in p else p["loss_batch"]))
                    q_mean = scores.mean(axis=1)
                    v = tf.reduce_mean(((scores.T - q_mean).T - logits) ** 2)
                elif self.loss == "ApproxNDCGLoss":
                    while True:
                        logits, scores = get_logits_scores(
                            loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))

                        v = tfr.keras.losses.ApproxNDCGLoss()(
                            scores.astype(np.float32),
                            logits
                        )
                    
                        if not tf.math.is_nan(v).numpy().any():
                            break
                        else:
                            if p["verbose"]:
                                print("nanloss ignored")
                elif self.loss == "softmax":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        tf.nn.softmax(logits, axis=1),
                        0
                    ))
                elif self.loss == "softmax_signed":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    sf = tf.nn.softmax(logits, axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        sf,
                        -sf
                    ))
                elif self.loss == "softmax_weighted":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    v = -tf.reduce_mean(tf.where(
                        (scores.T >= qs.T).T,
                        tf.nn.softmax(logits, axis=1),
                        0
                    ) * scores)
                elif self.loss == "sigmoid_top_100":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    mask = np.argsort(-scores, axis=1) < 100
                    v = -tf.reduce_sum(
                        tf.math.log_sigmoid((2 * mask - 1) * logits)
                    )
                elif self.loss == "KL100":
                    logits, scores = get_logits_scores(
                        loss_batch = (64 if "loss_batch" not in p else p["loss_batch"]))
                    
                    
                    qs = np.quantile(scores, p["loss_q"], axis=1)
                    mask = np.argsort(-scores, axis=1) < 100
                    v = tf.keras.losses.KLDivergence()((scores.T >= qs.T).T, logits)
                else:
                    assert False
                    
                if self.p["c"]:
                    v += tf.reduce_mean(self.W * self.W) * p["c"]
                    
                if self.p["dssm_l2"]:
                    for weights_ in [self.u_dssm.weights, self.g_dssm.weights]:
                        for weight_ in weights_:
                            v += tf.reduce_sum(weight_ * weight_) * self.p["dssm_l2"]
                
                if self.p["matrix_l2"]:
                    v += tf.reduce_sum(self.W * self.W) * self.p["matrix_l2"]
                
                if p["verbose"]:
                    print(v.numpy())
                
                return v

            weights = list()
            
            if self.train_matrix and (not self.p["Wfreeze"]):
                weights += [self.W]

            if self.train_dssm:
                weights += self.u_dssm.weights
                weights += self.g_dssm.weights
            
            if self.train_popbias:
                weights += [self.pb]

            if self.train_vbias:
                weights += [self.vb]   
                
            if self.train_bias:
                weights += [self.b]   
                
            
            if self.p["trainable_items"]:
                weights += [self.trainable_games]
                
                
            opt.minimize(loss, weights)
            
            if p["score_verbose"] and (i % p["score_verbose"] == 0):
                print(f"\n=== Iteration {i} ===")
                score = dict()
                for sl in self.ctx.slices:
                    score[sl] = self.get_score(sl)
                    print(f"slice = {sl}, score = {score[sl]}")
                    
                if score["train"] > self.slice2best["train"]:
                    self.slice2best = score
                    if p["save_callback"] is not None:
                        p["save_callback"](self)
                
        print("last loss = ", loss())

    def recommend(self, t):
        logits = 0
                    
        if self.train_matrix:
            logits += self.get_user_embs(t) @ self.W @ tf.transpose(self.get_game_embs())

        if self.train_dssm:
            logits += self.u_dssm(self.get_user_embs(t)) @ tf.transpose(self.g_dssm(self.get_game_embs()))

        if self.train_popbias:
            logits += self.pb * self.game_avg_scores["train"]       
            
        if self.train_vbias:
            logits += self.vb
            
        if self.train_bias:
            logits += self.b
            
        return logits
    
    # inherited
    # def get_score(self, t, topsize = 100):
    
class DssmKnn(CBKnnV0):
    def __init__(self, ctx, modelid, fit_kwargs=dict()):
        super().__init__(ctx, fit_kwargs=fit_kwargs)
        self.modelid = modelid
        self.embed_games = ctx.docblocks[modelid]
        
    def __repr__(self):
        return "DssmKnn(" + str(self.modelid) + "," + str(self.fit_kwargs) + ")"
        
    def get_user_embs(self, t):
        return np.array([r[1][self.modelid] for r in self.ctx.get_requests(t)])
    
    def get_game_embs(self):
        return self.embed_games
    
def ev(mds, logs=None):
    for i in range(len(mds)):
        print("\n\n\n=======")
        print("model = ", mds[i])
        mds[i].fit()
        tr, te = mds[i].get_score("train"), mds[i].get_score("test")
        print(tr, te)
        if logs is not None:
            logs.append((
                repr(mds[i]),
                tr,
                te
            ))
            
class DssmKnn(CBKnnV0):
    def __init__(self, ctx, modelid, fit_kwargs=dict()):
        super().__init__(ctx, fit_kwargs=fit_kwargs)
        self.modelid = modelid
        self.embed_games = ctx.docblocks[modelid]
        
    def __repr__(self):
        return "DssmKnn(" + str(self.modelid) + "," + str(self.fit_kwargs) + ")"
        
    def get_user_embs(self, t):
        return np.array([r[1][self.modelid] for r in self.ctx.get_requests(t)])
    
    def get_game_embs(self):
        return self.embed_games
    
def ev(mds, logs=None):
    for i in range(len(mds)):
        print("\n\n\n=======")
        print("model = ", mds[i])
        mds[i].fit()
        tr, te = mds[i].get_score("train"), mds[i].get_score("test")
        print(tr, te)
        if logs is not None:
            logs.append((
                repr(mds[i]),
                tr,
                te
            ))
            
class AnnCUR(Popular):
    def __init__(self, ctx, oracle=False, key_games=None, name=None):
        super().__init__(ctx)
        self.oracle = oracle
        self.ctx = ctx
        self.name = name

        self.key_cols_idx = np.array(sorted(ctx.key_games if key_games is None else key_games))
        rows_idx = np.arange(ctx.get_relevs("train").shape[0])
        
        self.cur = matrix_approx_zeshel.CURApprox(
            rows=torch.from_numpy(ctx.get_relevs("train")),
            cols=torch.from_numpy(ctx.get_relevs("train")[:, self.key_cols_idx]),
            row_idxs=rows_idx,
            col_idxs=self.key_cols_idx,
            approx_preference="rows",
            A=(torch.from_numpy(ctx.get_relevs("train")) if oracle else None)
        )        
        
    def __repr__(self):
        if self.name is None:
            return f"AnnCur({id(self)})"
        else:
            return f"AnnCur({self.name} - {id(self)})"
        
    def get_user_scores(self, t):
        return self.ctx.get_relevs(t)
    
    def get_user_embs(self, t):
        assert False
    
    def get_game_embs(self):
        return self.cur.latent_cols.T

    def fit(self, t = "train"):
        self.top_logits = self.game_avg_scores[t]
        self.top = np.argsort(-self.top_logits)

    def recommend(self, t):
        key_relevs = torch.from_numpy(self.ctx.get_relevs(t)[:, self.key_cols_idx])
        return self.cur.get_complete_row(key_relevs)
    
    def get_score(self, t, topsize = 100):       
        recs = np.array(self.recommend(t))
        trus = self.get_user_scores(t)

        mse = np.mean((recs - trus) ** 2)

        recs = np.argsort(-recs, axis=1)[:, :topsize]
        trus = np.argsort(-trus, axis=1)[:, :topsize]

        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
            
        results = [
            ev(rec, tru) / float(topsize)
            for rec, tru in zip(recs,trus)
        ]

        print("np.mean(results), mse, len(results) = ",
              np.mean(results), mse, len(results))

        return np.mean(results)

# %%
def coitem_algorithm(n_support, candidate_items, target_items, min_item_rel_norm=1e-5, eps=1e-6):
    support_items = []
    support_items_scores = []
    n_c, n_q = candidate_items.shape
    n_t = target_items.shape[0]

    candidate_item_squared_norms = (candidate_items ** 2).sum(axis=1)
    min_item_norm = min_item_rel_norm * np.sqrt(candidate_item_squared_norms.mean())
    
    candidate_coitems = candidate_items.dot(
        target_items.T.dot(target_items)
    )
    orthonormed_support_items = np.zeros((n_support, n_q))
    remaining_items = np.ones(candidate_items.shape[0], dtype="bool")
    for t in tqdm.tqdm_notebook(range(n_support)):
        scores = (candidate_coitems * candidate_items).sum(axis=1)
        remaining_items &= (candidate_item_squared_norms >= min_item_norm ** 2)
        scores[remaining_items] /= candidate_item_squared_norms[remaining_items]
        scores[~remaining_items] = 0
        
        new_item_id = np.argmax(scores)
        assert remaining_items[new_item_id]
        support_items.append(new_item_id)
        support_items_scores.append(scores[new_item_id] / (n_t * n_q))
        remaining_items[new_item_id] = False
        
        new_item = candidate_items[new_item_id].copy()
        new_item -= orthonormed_support_items[:t].T.dot(
            orthonormed_support_items[:t].dot(new_item)
        )
        assert np.allclose((new_item ** 2).sum(), candidate_item_squared_norms[new_item_id], atol=eps)
        new_item /= np.sqrt((new_item ** 2).sum())
        orthonormed_support_items[t] = new_item
        new_coitem = candidate_coitems[new_item_id] / np.sqrt(candidate_item_squared_norms[new_item_id])
        
        coefs = (candidate_items * new_item).sum(axis=1)
        candidate_item_squared_norms -= coefs ** 2
        assert np.all(candidate_item_squared_norms[remaining_items] > -eps)
        
        candidate_coitems -= coefs.reshape((-1, 1)).dot(new_coitem.reshape((1, -1)))
        cocoefs = (candidate_coitems * new_item).sum(axis=1, keepdims=True)
        candidate_coitems -= cocoefs.dot(new_item.reshape((1, -1)))
    return np.array(support_items, dtype=np.int64), np.array(support_items_scores)

# %% [markdown]
# # Preparate

# %%
def do(ctx, name, coitem=True, kmeans=True, top=True, random=True):
    if coitem:
        t = ctx.get_relevs("train").T
        t = (t - t.mean()) / t.std()  # like in other comparisons with RBE
        ctx.key_games = list(coitem_algorithm(ctx.key_size, t, t, 1e-8, eps=1e9)[0])

        ma = AnnCUR(ctx, key_games=ctx.key_games)

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")

        GE = ma.get_game_embs()
        QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

        fname = f"./GE_QE_AnnCURxCoItem_{name}_{str(round(te, 4))[2:]}.npz"
        np.savez_compressed(fname, QE=QE.numpy(), GE=GE.numpy())
        print(fname)
        
    if kmeans:
        ctx.set_kmeans_games_as_key()
        ma = AnnCUR(ctx, key_games=ctx.key_games)

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")

        GE = ma.get_game_embs()
        QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

        fname = f"./GE_QE_AnnCURxKMeans_{name}_{str(round(te, 4))[2:]}.npz"
        np.savez_compressed(fname, QE=QE.numpy(), GE=GE.numpy())
        print(fname)
        
    if top:
        ctx.set_top_games_as_key()
        ma = AnnCUR(ctx, key_games=ctx.key_games)

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")

        GE = ma.get_game_embs()
        QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

        fname = f"./GE_QE_AnnCURxTop_{name}_{str(round(te, 4))[2:]}.npz"
        np.savez_compressed(fname, QE=QE.numpy(), GE=GE.numpy())
        print(fname)
        
    if random:
        ctx.key_games = np.random.choice(np.arange(ctx.games_count), ctx.key_size, replace=False)
        ma = AnnCUR(ctx, key_games=ctx.key_games)

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")

        GE = ma.get_game_embs()
        QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

        fname = f"./GE_QE_AnnCURxRandom_{name}_{str(round(te, 4))[2:]}.npz"
        np.savez_compressed(fname, QE=QE.numpy(), GE=GE.numpy())
        print(fname)

# %%
m_ = None
def do_RBE(ctx, name, coitem=True, kmeans=True, top=True, random=True, N = 100000, LR = 0.0005):
    def get_save_callback(t, fname):
        def save_callback(m):
            global m_
            m_ = m
            GE_ = m.get_game_embs()
            GE = np.hstack([
                GE_,
                m.g_dssm(GE_),
                m.vb.numpy().reshape((-1, 1)) ,  # Vertical bias
                ctx.get_relevs("train").mean(axis=0).reshape((-1, 1))  # popbias
            ])

            R_All = ctx.get_relevs(t)
            QE_ = m.get_user_embs(t)
            QE = np.hstack([
                QE_ @ m.W,
                m.u_dssm(QE_),
                np.ones((R_All.shape[0], 1)),
                np.ones((R_All.shape[0], 1)) * m.pb
            ])
            
            l, r = fname.split(".npz")
            
            train_score = m.get_score("train")
            score = m.get_score(t)
            fname_ = l + f"_{str(round(train_score, 4))}_{str(round(score, 4))}.npz" + r
            print(f"Saving {fname_} ...")
            np.savez_compressed(fname_, QE=QE, GE=GE)
        return save_callback
            
    if coitem:
        t = ctx.get_relevs("train").T
        t = (t - t.mean()) / t.std()  # like in other comparisons with RBE
        ctx.key_games = list(coitem_algorithm(100, t, t, 1e-8, eps=1e9)[0])

        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': True,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExCoItem_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if kmeans:
        ctx.set_kmeans_games_as_key()
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': True,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExKMeans_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if top:
        ctx.set_top_games_as_key()
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': True,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExTop_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if random:
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': True,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "save_callback": get_save_callback("test", f"./GE_QE_{name}_RBExRandom.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)

# %%
def get_Rp_basic(GE, A, R, QE_i, L):
    Ae = GE[A]

    u = np.linalg.pinv(Ae.T @ Ae) @ Ae.T @ R
    assert u.shape == QE_i.shape
    Rp = GE @ (u * L + QE_i * (1 - L))
    
    return Rp


def do_AXN(ctx, loaded, get_Rp, Z="test", STRIP = 0.05, Ls=np.linspace(0, 1, 11), Ks=[25], T_TS_s = [(200, 100)], not_deduplicate = False):
    # q = ctx.get_requests(Z)
    R_All = ctx.get_relevs(Z)

    GE, QE = loaded["GE"], loaded["QE"]

    best = 0
    best_arg = None

    for randomFirst in [False]:
        for K in Ks:
            for L in Ls:
                for T, TS in T_TS_s:
                    results = list()


                    As = list()
                    for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                        A = (
                            ctx.key_games[:K]
                            if randomFirst else
                            (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                        )
                        Rt = R_All[i]
                        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                        for _ in range(T // K - 1):
                            Rp = get_Rp(GE, A, Rt[A], QE[i], L)

                            An = list(A)
                            for ai in Rp.argsort()[::-1]:
                                if not_deduplicate or (ai not in An):
                                    An.append(ai)
                                if len(An) == len(A) + K:
                                    break
                            A = np.array(An)

                        assert len(A) == T
                        As.append(A)


                        A = sorted([
                            (-Rt[ai], ai)
                            for ai in A
                        ])[:TS]
                        A = [ai for _, ai in A]

                        pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                        results.append(ev(pred_top, gt_top) / float(TS))

                    if np.mean(results) > best:
                        best = np.mean(results)
                        best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                        best_arg_d = {
                            "K": K,
                            "L": L,
                            "randomFirst": randomFirst,
                            "score": np.mean(results)
                        }
                    print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)} best = {best}")

    return best_arg

# %% [markdown]
# ## RecSys LT

# %%
L = 14000
N = 1000
DA = 50

# %%
ctx = load(L, raw_path = "stand/log.local.logtime2.txt",
           path="log14k.local.logtime2.true.bin", seed=17, det_attempts=DA, key_size=100)
# Out:
# [(6, 16514), (7, 16514), (8, 16514), (9, 16514)]
# Best det =  1.6287490192850564e-119
# 1.6287490192850564e-119
# 101 9637 4174

# %%
gc.collect()
# Out:
# 27841

# %%
ctx.get_relevs("train").shape, ctx.get_relevs("test").shape
# Out:
# ((9637, 16514), (4174, 16514))

# %%
do(ctx, "RecSysLT_14K_")
# Out:
# /tmp/ipykernel_424313/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.6734201514994292 0.1291294201564882 9637
# np.mean(results), mse, len(results) =  0.6675491135601341 0.13430078473879134 4174
# ./GE_QE_AnnCURxCoItem_RecSysLT_14K__6675.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: ConvergenceWarning: Number of distinct clusters (96) found smaller than n_clusters (100). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# np.mean(results), mse, len(results) =  0.6382287018781778 0.15647997174538925 9637
# np.mean(results), mse, len(results) =  0.6324460948730235 0.16203423558897245 4174
# ./GE_QE_AnnCURxKMeans_RecSysLT_14K__6324.npz
# np.mean(results), mse, len(results) =  0.6836764553284217 0.26223135035114564 9637
# np.mean(results), mse, len(results) =  0.6797412553905127 0.2764254850146344 4174
# ./GE_QE_AnnCURxTop_RecSysLT_14K__6797.npz
# np.mean(results), mse, len(results) =  0.6065341911383211 0.17200277466507363 9637
# np.mean(results), mse, len(results) =  0.6004312410158121 0.17851134678182262 4174
# ./GE_QE_AnnCURxRandom_RecSysLT_14K__6004.npz

# %%
# !ls | grep "GE.*RecSysLT_14K_"
# Out:
# GE_QE_AnnCURxCoItem_RecSysLT_14K__6675.npz
# GE_QE_AnnCURxKMeans_RecSysLT_14K__6324.npz
# GE_QE_AnnCURxRandom_RecSysLT_14K__6004.npz
# GE_QE_AnnCURxTop_RecSysLT_14K__6797.npz

# %%
gc.collect()
# Out:
# 0

# %%
Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6871_0.6758.npz ...


Saving ./GE_QE_RBExTop_RecSysLT_14K__0.6998_0.689.npz ...

# %%
do_RBE(ctx, "RecSysLT_14K_", N=300000, kmeans=False, random=False)
# Out:
# /tmp/ipykernel_424313/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# self.embed_users['train'].shape =  (9637, 100)
# self.embed_games.shape =  (16514, 101)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (101, 16514)
# self.core_users_embs.shape =  (101, 100)
# self.ge_users.shape =  (9637, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.10811881188118813 tf.Tensor(58.54532605750945, shape=(), dtype=float64) 101
# slice = key, score = 0.10811881188118813
# np.mean(results), mse, len(results) =  0.09761336515513128 tf.Tensor(59.71204169844864, shape=(), dtype=float64) 9637
# slice = train, score = 0.09761336515513128
# np.mean(results), mse, len(results) =  0.09918782942022042 tf.Tensor(59.40196169569517, shape=(), dtype=float64) 4174
# slice = test, score = 0.09918782942022042
# np.mean(results), mse, len(results) =  0.09761336515513128 tf.Tensor(59.71204169844864, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.09918782942022042 tf.Tensor(59.40196169569517, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.0976_0.0992.npz ...
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.5245544554455447 tf.Tensor(147.52260929766194, shape=(), dtype=float64) 101
# slice = key, score = 0.5245544554455447
# np.mean(results), mse, len(results) =  0.5154788834699595 tf.Tensor(134.25672744232975, shape=(), dtype=float64) 9637
# slice = train, score = 0.5154788834699595
# np.mean(results), mse, len(results) =  0.5134115955917585 tf.Tensor(133.23762757193197, shape=(), dtype=float64) 4174
# slice = test, score = 0.5134115955917585
# np.mean(results), mse, len(results) =  0.5154788834699595 tf.Tensor(134.25672744232975, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5134115955917585 tf.Tensor(133.23762757193197, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.5155_0.5134.npz ...
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5752475247524753 tf.Tensor(216.59786976148993, shape=(), dtype=float64) 101
# slice = key, score = 0.5752475247524753
# np.mean(results), mse, len(results) =  0.5687029158451801 tf.Tensor(200.82031802111243, shape=(), dtype=float64) 9637
# slice = train, score = 0.5687029158451801
# np.mean(results), mse, len(results) =  0.5650143747005271 tf.Tensor(198.31130361311628, shape=(), dtype=float64) 4174
# slice = test, score = 0.5650143747005271
# np.mean(results), mse, len(results) =  0.5687029158451801 tf.Tensor(200.82031802111243, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5650143747005271 tf.Tensor(198.31130361311628, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.5687_0.565.npz ...
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.5900000000000001 tf.Tensor(315.3342442986398, shape=(), dtype=float64) 101
# slice = key, score = 0.5900000000000001
# np.mean(results), mse, len(results) =  0.578918750648542 tf.Tensor(293.68556505970656, shape=(), dtype=float64) 9637
# slice = train, score = 0.578918750648542
# np.mean(results), mse, len(results) =  0.5752707235265931 tf.Tensor(290.92872939756637, shape=(), dtype=float64) 4174
# slice = test, score = 0.5752707235265931
# np.mean(results), mse, len(results) =  0.578918750648542 tf.Tensor(293.68556505970656, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5752707235265931 tf.Tensor(290.92872939756637, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.5789_0.5753.npz ...
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.5989108910891089 tf.Tensor(385.60686281250304, shape=(), dtype=float64) 101
# slice = key, score = 0.5989108910891089
# np.mean(results), mse, len(results) =  0.5932956314205666 tf.Tensor(360.72351985697816, shape=(), dtype=float64) 9637
# slice = train, score = 0.5932956314205666
# np.mean(results), mse, len(results) =  0.5888164829899377 tf.Tensor(357.8099933007001, shape=(), dtype=float64) 4174
# slice = test, score = 0.5888164829899377
# np.mean(results), mse, len(results) =  0.5932956314205666 tf.Tensor(360.72351985697816, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5888164829899377 tf.Tensor(357.8099933007001, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.5933_0.5888.npz ...
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6013861386138614 tf.Tensor(471.4155226793207, shape=(), dtype=float64) 101
# slice = key, score = 0.6013861386138614
# np.mean(results), mse, len(results) =  0.6068745460205457 tf.Tensor(442.8888134194145, shape=(), dtype=float64) 9637
# slice = train, score = 0.6068745460205457
# np.mean(results), mse, len(results) =  0.6033804504072833 tf.Tensor(438.7046486267754, shape=(), dtype=float64) 4174
# slice = test, score = 0.6033804504072833
# np.mean(results), mse, len(results) =  0.6068745460205457 tf.Tensor(442.8888134194145, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6033804504072833 tf.Tensor(438.7046486267754, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6069_0.6034.npz ...
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6135643564356436 tf.Tensor(580.0098992763322, shape=(), dtype=float64) 101
# slice = key, score = 0.6135643564356436
# np.mean(results), mse, len(results) =  0.614028224551209 tf.Tensor(540.507905390016, shape=(), dtype=float64) 9637
# slice = train, score = 0.614028224551209
# np.mean(results), mse, len(results) =  0.6089937709631049 tf.Tensor(535.9837725599533, shape=(), dtype=float64) 4174
# slice = test, score = 0.6089937709631049
# np.mean(results), mse, len(results) =  0.614028224551209 tf.Tensor(540.507905390016, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6089937709631049 tf.Tensor(535.9837725599533, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.614_0.609.npz ...
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6298019801980198 tf.Tensor(619.6706344912495, shape=(), dtype=float64) 101
# slice = key, score = 0.6298019801980198
# np.mean(results), mse, len(results) =  0.6226159593234408 tf.Tensor(584.7287030888584, shape=(), dtype=float64) 9637
# slice = train, score = 0.6226159593234408
# np.mean(results), mse, len(results) =  0.617184954480115 tf.Tensor(579.3525079177706, shape=(), dtype=float64) 4174
# slice = test, score = 0.617184954480115
# np.mean(results), mse, len(results) =  0.6226159593234408 tf.Tensor(584.7287030888584, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.617184954480115 tf.Tensor(579.3525079177706, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6226_0.6172.npz ...
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.6118811881188119 tf.Tensor(702.7362785319297, shape=(), dtype=float64) 101
# slice = key, score = 0.6118811881188119
# np.mean(results), mse, len(results) =  0.6006319394002283 tf.Tensor(660.5217384576349, shape=(), dtype=float64) 9637
# slice = train, score = 0.6006319394002283
# np.mean(results), mse, len(results) =  0.5933732630570195 tf.Tensor(656.2030948851182, shape=(), dtype=float64) 4174
# slice = test, score = 0.5933732630570195
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.6184158415841584 tf.Tensor(788.9711586932394, shape=(), dtype=float64) 101
# slice = key, score = 0.6184158415841584
# np.mean(results), mse, len(results) =  0.6192715575386532 tf.Tensor(741.9080271410362, shape=(), dtype=float64) 9637
# slice = train, score = 0.6192715575386532
# np.mean(results), mse, len(results) =  0.6124844274077624 tf.Tensor(735.6379631168309, shape=(), dtype=float64) 4174
# slice = test, score = 0.6124844274077624
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.632970297029703 tf.Tensor(924.6597891873815, shape=(), dtype=float64) 101
# slice = key, score = 0.632970297029703
# np.mean(results), mse, len(results) =  0.625778769326554 tf.Tensor(873.8524231904537, shape=(), dtype=float64) 9637
# slice = train, score = 0.625778769326554
# np.mean(results), mse, len(results) =  0.6193651173933875 tf.Tensor(866.2996498097327, shape=(), dtype=float64) 4174
# slice = test, score = 0.6193651173933875
# np.mean(results), mse, len(results) =  0.625778769326554 tf.Tensor(873.8524231904537, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6193651173933875 tf.Tensor(866.2996498097327, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6258_0.6194.npz ...
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.6312871287128713 tf.Tensor(943.9972841521018, shape=(), dtype=float64) 101
# slice = key, score = 0.6312871287128713
# np.mean(results), mse, len(results) =  0.6314122652277679 tf.Tensor(889.5349139412847, shape=(), dtype=float64) 9637
# slice = train, score = 0.6314122652277679
# np.mean(results), mse, len(results) =  0.6255246765692383 tf.Tensor(885.267905648902, shape=(), dtype=float64) 4174
# slice = test, score = 0.6255246765692383
# np.mean(results), mse, len(results) =  0.6314122652277679 tf.Tensor(889.5349139412847, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.
shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6605797795879252 tf.Tensor(3999.6830868004868, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6678_0.6606.npz ...
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6606930693069308 tf.Tensor(4310.940106740518, shape=(), dtype=float64) 101
# slice = key, score = 0.6606930693069308
# np.mean(results), mse, len(results) =  0.6649994811663381 tf.Tensor(4162.961682185187, shape=(), dtype=float64) 9637
# slice = train, score = 0.6649994811663381
# np.mean(results), mse, len(results) =  0.6570987062769525 tf.Tensor(4157.494349326966, shape=(), dtype=float64) 4174
# slice = test, score = 0.6570987062769525
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.6646534653465348 tf.Tensor(4311.778788086244, shape=(), dtype=float64) 101
# slice = key, score = 0.6646534653465348
# ...
# slice = test, score = 0.6868926689027313
# np.mean(results), mse, len(results) =  0.6989322403237521 tf.Tensor(7475.828699720711, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6868926689027313 tf.Tensor(7497.864384247492, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExTop_RecSysLT_14K__0.6989_0.6869.npz ...
#
# === Iteration 271000 ===
# np.mean(results), mse, len(results) =  0.6927722772277226 tf.Tensor(7564.575797443746, shape=(), dtype=float64) 101
# slice = key, score = 0.6927722772277226
# np.mean(results), mse, len(results) =  0.6964158970634015 tf.Tensor(7384.796924319638, shape=(), dtype=float64) 9637
# slice = train, score = 0.6964158970634015
# np.mean(results), mse, len(results) =  0.6855126976521322 tf.Tensor(7395.8925209848485, shape=(), dtype=float64) 4174
# slice = test, score = 0.6855126976521322
#
# === Iteration 272000 ===
# np.mean(results), mse, len(results) =  0.6945544554455446 tf.Tensor(7682.9271799231965, shape=(), dtype=float64) 101
# slice = key, score = 0.6945544554455446
# np.mean(results), mse, len(results) =  0.6953782297395453 tf.Tensor(7550.3001706695695, shape=(), dtype=float64) 9637
# slice = train, score = 0.6953782297395453
# np.mean(results), mse, len(results) =  0.6844465740297078 tf.Tensor(7559.8039992615, shape=(), dtype=float64) 4174
# slice = test, score = 0.6844465740297078
#
# === Iteration 273000 ===
# np.mean(results), mse, len(results) =  0.6966336633663368 tf.Tensor(7797.874933743472, shape=(), dtype=float64) 101
# slice = key, score = 0.6966336633663368
# np.mean(results), mse, len(results) =  0.699740583169036 tf.Tensor(7619.753537106483, shape=(), dtype=float64) 9637
# slice = train, score = 0.699740583169036
# np.mean(results), mse, len(results) =  0.687371825586967 tf.Tensor(7637.905055606239, shape=(), dtype=float64) 4174
# slice = test, score = 0.687371825586967
# np.mean(results), mse, len(results) =  0.699740583169036 tf.Tensor(7619.753537106483, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.687371825586967 tf.Tensor(7637.905055606239, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExTop_RecSysLT_14K__0.6997_0.6874.npz ...
#
# === Iteration 274000 ===
# np.mean(results), mse, len(results) =  0.6967326732673268 tf.Tensor(7698.914820308014, shape=(), dtype=float64) 101
# slice = key, score = 0.6967326732673268
# np.mean(results), mse, len(results) =  0.6961118605375116 tf.Tensor(7559.016018420751, shape=(), dtype=float64) 9637
# slice = train, score = 0.6961118605375116
# np.mean(results), mse, len(results) =  0.6830785816962147 tf.Tensor(7574.619400289229, shape=(), dtype=float64) 4174
# slice = test, score = 0.6830785816962147
#
# === Iteration 275000 ===
# np.mean(results), mse, len(results) =  0.6964356435643566 tf.Tensor(7740.456703163017, shape=(), dtype=float64) 101
# slice = key, score = 0.6964356435643566
# np.mean(results), mse, len(results) =  0.6982463422226834 tf.Tensor(7547.7490386594645, shape=(), dtype=float64) 9637
# slice = train, score = 0.6982463422226834
# np.mean(results), mse, len(results) =  0.6860781025395303 tf.Tensor(7564.919753425667, shape=(), dtype=float64) 4174
# slice = test, score = 0.6860781025395303
#
# === Iteration 276000 ===
# np.mean(results), mse, len(results) =  0.6937623762376238 tf.Tensor(7719.440215884841, shape=(), dtype=float64) 101
# slice = key, score = 0.6937623762376238
# np.mean(results), mse, len(results) =  0.695864895714434 tf.Tensor(7576.574842655431, shape=(), dtype=float64) 9637
# slice = train, score = 0.695864895714434
# np.mean(results), mse, len(results) =  0.6835265931959751 tf.Tensor(7587.814894636779, shape=(), dtype=float64) 4174
# slice = test, score = 0.6835265931959751
#
# === Iteration 277000 ===
# np.mean(results), mse, len(results) =  0.6930693069306932 tf.Tensor(7789.724665057731, shape=(), dtype=float64) 101
# slice = key, score = 0.6930693069306932
# np.mean(results), mse, len(results) =  0.6965321158036732 tf.Tensor(7602.251505815221, shape=(), dtype=float64) 9637
# slice = train, score = 0.6965321158036732
# np.mean(results), mse, len(results) =  0.684760421657882 tf.Tensor(7622.944565535239, shape=(), dtype=float64) 4174
# slice = test, score = 0.684760421657882
#
# === Iteration 278000 ===
# np.mean(results), mse, len(results) =  0.6911881188118812 tf.Tensor(7805.76578252299, shape=(), dtype=float64) 101
# slice = key, score = 0.6911881188118812
# np.mean(results), mse, len(results) =  0.6930476289301649 tf.Tensor(7652.810653719861, shape=(), dtype=float64) 9637
# slice = train, score = 0.6930476289301649
# np.mean(results), mse, len(results) =  0.6817585050311451 tf.Tensor(7663.10398180448, shape=(), dtype=float64) 4174
# slice = test, score = 0.6817585050311451
#
# === Iteration 279000 ===
# np.mean(results), mse, len(results) =  0.6979207920792078 tf.Tensor(7849.36785441331, shape=(), dtype=float64) 101
# slice = key, score = 0.6979207920792078
# np.mean(results), mse, len(results) =  0.6997582235135416 tf.Tensor(7705.068700986856, shape=(), dtype=float64) 9637
# slice = train, score = 0.6997582235135416
# np.mean(results), mse, len(results) =  0.6890249161475803 tf.Tensor(7724.207658066923, shape=(), dtype=float64) 4174
# slice = test, score = 0.6890249161475803
# np.mean(results), mse, len(results) =  0.6997582235135416 tf.Tensor(7705.068700986856, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6890249161475803 tf.Tensor(7724.207658066923, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExTop_RecSysLT_14K__0.6998_0.689.npz ...
#
# === Iteration 280000 ===
# np.mean(results), mse, len(results) =  0.6886138613861384 tf.Tensor(7996.14041734623, shape=(), dtype=float64) 101
# slice = key, score = 0.6886138613861384
# np.mean(results), mse, len(results) =  0.6934232645014008 tf.Tensor(7812.356628888407, shape=(), dtype=float64) 9637
# slice = train, score = 0.6934232645014008
# np.mean(results), mse, len(results) =  0.6827934834690944 tf.Tensor(7827.923863949516, shape=(), dtype=float64) 4174
# slice = test, score = 0.6827934834690944
#
# === Iteration 281000 ===
# np.mean(results), mse, len(results) =  0.6912871287128713 tf.Tensor(7866.597303652976, shape=(), dtype=float64) 101
# slice = key, score = 0.6912871287128713
# np.mean(results), mse, len(results) =  0.696130538549341 tf.Tensor(7761.200593764735, shape=(), dtype=float64) 9637
# slice = train, score = 0.696130538549341
# np.mean(results), mse, len(results) =  0.6841015812170579 tf.Tensor(7776.9850996905125, shape=(), dtype=float64) 4174
# slice = test, score = 0.6841015812170579
#
# === Iteration 282000 ===
# np.mean(results), mse, len(results) =  0.6923762376237623 tf.Tensor(7817.407141385487, shape=(), dtype=float64) 101
# slice = key, score = 0.6923762376237623
# np.mean(results), mse, len(results) =  0.6960838435197676 tf.Tensor(7671.106145945433, shape=(), dtype=float64) 9637
# slice = train, score = 0.6960838435197676
# np.mean(results), mse, len(results) =  0.6835529468136081 tf.Tensor(7684.879286860279, shape=(), dtype=float64) 4174
# slice = test, score = 0.6835529468136081
#
# === Iteration 283000 ===
# np.mean(results), mse, len(results) =  0.6906930693069308 tf.Tensor(7923.497961952723, shape=(), dtype=float64) 101
# slice = key, score = 0.6906930693069308
# np.mean(results), mse, len(results) =  0.6966607865518315 tf.Tensor(7772.266115416828, shape=(), dtype=float64) 9637
# slice = train, score = 0.6966607865518315
# np.mean(results), mse, len(results) =  0.685737901293723 tf.Tensor(7796.742610656656, shape=(), dtype=float64) 4174
# slice = test, score = 0.685737901293723
#
# === Iteration 284000 ===
# np.mean(results), mse, len(results) =  0.6920792079207922 tf.Tensor(7953.083363295525, shape=(), dtype=float64) 101
# slice = key, score = 0.6920792079207922
# np.mean(results), mse, len(results) =  0.6992227871744319 tf.Tensor(7818.0860351224865, shape=(), dtype=float64) 9637
# slice = train, score = 0.6992227871744319
# np.mean(results), mse, len(results) =  0.6876521322472448 tf.Tensor(7843.635376319709, shape=(), dtype=float64) 4174
# slice = test, score = 0.6876521322472448
#
# === Iteration 285000 ===
# np.mean(results), mse, len(results) =  0.6923762376237623 tf.Tensor(7956.356082505755, shape=(), dtype=float64) 101
# slice = key, score = 0.6923762376237623
# np.mean(results), mse, len(results) =  0.6965850368371899 tf.Tensor(7814.613242069694, shape=(), dtype=float64) 9637
# slice = train, score = 0.6965850368371899
# np.mean(results), mse, len(results) =  0.6859343555342597 tf.Tensor(7829.842014816711, shape=(), dtype=float64) 4174
# slice = test, score = 0.6859343555342597
#
# === Iteration 286000 ===
# np.mean(results), mse, len(results) =  0.6943564356435646 tf.Tensor(8063.921025025224, shape=(), dtype=float64) 101
# slice = key, score = 0.6943564356435646
# np.mean(results), mse, len(results) =  0.6984051053232333 tf.Tensor(7935.516354316039, shape=(), dtype=float64) 9637
# slice = train, score = 0.6984051053232333
# np.mean(results), mse, len(results) =  0.686729755630091 tf.Tensor(7964.753610345597, shape=(), dtype=float64) 4174
# slice = test, score = 0.686729755630091
#
# === Iteration 287000 ===
# np.mean(results), mse, len(results) =  0.6968316831683171 tf.Tensor(8043.3063880980835, shape=(), dtype=float64) 101
# slice = key, score = 0.6968316831683171
# np.mean(results), mse, len(results) =  0.7004576112898204 tf.Tensor(7881.790016573855, shape=(), dtype=float64) 9637
# slice = train, score = 0.7004576112898204
# np.mean(results), mse, len(results) =  0.6876641111643507 tf.Tensor(7901.626070892033, shape=(), dtype=float64) 4174
# slice = test, score = 0.6876641111643507
# np.mean(results), mse, len(results) =  0.7004576112898204 tf.Tensor(7881.790016573855, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6876641111643507 tf.Tensor(7901.626070892033, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExTop_RecSysLT_14K__0.7005_0.6877.npz ...
#
# === Iteration 288000 ===
# np.mean(results), mse, len(results) =  0.6984158415841584 tf.Tensor(8083.1560929059615, shape=(), dtype=float64) 101
# slice = key, score = 0.6984158415841584
# np.mean(results), mse, len(results) =  0.6966628618864792 tf.Tensor(7923.592317528593, shape=(), dtype=float64) 9637
# slice = train, score = 0.6966628618864792
# np.mean(results), mse, len(results) =  0.6853761379971252 tf.Tensor(7944.706463381969, shape=(), dtype=float64) 4174
# slice = test, score = 0.6853761379971252
#
# === Iteration 289000 ===
# np.mean(results), mse, len(results) =  0.6926732673267327 tf.Tensor(8025.877996959023, shape=(), dtype=float64) 101
# slice = key, score = 0.6926732673267327
# np.mean(results), mse, len(results) =  0.696087994189063 tf.Tensor(7876.106910698298, shape=(), dtype=float64) 9637
# slice = train, score = 0.696087994189063
# np.mean(results), mse, len(results) =  0.6839027311931001 tf.Tensor(7903.8139365176, shape=(), dtype=float64) 4174
# slice = test, score = 0.6839027311931001
#
# === Iteration 290000 ===
# np.mean(results), mse, len(results) =  0.6964356435643565 tf.Tensor(8218.141005196216, shape=(), dtype=float64) 101
# slice = key, score = 0.6964356435643565
# np.mean(results), mse, len(results) =  0.6972024488948844 tf.Tensor(8053.660757328638, shape=(), dtype=float64) 9637
# slice = train, score = 0.6972024488948844
# np.mean(results), mse, len(results) =  0.685656444657403 tf.Tensor(8082.279918761926, shape=(), dtype=float64) 4174
# slice = test, score = 0.685656444657403
#
# === Iteration 291000 ===
# np.mean(results), mse, len(results) =  0.6952475247524752 tf.Tensor(8150.443885786876, shape=(), dtype=float64) 101
# slice = key, score = 0.6952475247524752
# np.mean(results), mse, len(results) =  0.6964584414236796 tf.Tensor(8000.03681253155, shape=(), dtype=float64) 9637
# slice = train, score = 0.6964584414236796
# np.mean(results), mse, len(results) =  0.6831887877335889 tf.Tensor(8030.78274224557, shape=(), dtype=float64) 4174
# slice = test, score = 0.6831887877335889
#
# === Iteration 292000 ===
# np.mean(results), mse, len(results) =  0.6962376237623761 tf.Tensor(8146.864144487541, shape=(), dtype=float64) 101
# slice = key, score = 0.6962376237623761
# np.mean(results), mse, len(results) =  0.6963992943862197 tf.Tensor(7974.427389707417, shape=(), dtype=float64) 9637
# slice = train, score = 0.6963992943862197
# np.mean(results), mse, len(results) =  0.68626018207954 tf.Tensor(7996.239254929405, shape=(), dtype=float64) 4174
# slice = test, score = 0.68626018207954
#
# === Iteration 293000 ===
# np.mean(results), mse, len(results) =  0.6931683168316832 tf.Tensor(8262.432495933846, shape=(), dtype=float64) 101
# slice = key, score = 0.6931683168316832
# np.mean(results), mse, len(results) =  0.698551416415897 tf.Tensor(8115.324367149024, shape=(), dtype=float64) 9637
# slice = train, score = 0.698551416415897
# np.mean(results), mse, len(results) =  0.6887685673215141 tf.Tensor(8138.639990192941, shape=(), dtype=float64) 4174
# slice = test, score = 0.6887685673215141
#
# === Iteration 294000 ===
# np.mean(results), mse, len(results) =  0.6981188118811882 tf.Tensor(8194.034564038013, shape=(), dtype=float64) 101
# slice = key, score = 0.6981188118811882
# np.mean(results), mse, len(results) =  0.6982338902147971 tf.Tensor(8050.583749846544, shape=(), dtype=float64) 9637
# slice = train, score = 0.6982338902147971
# np.mean(results), mse, len(results) =  0.6862386200287495 tf.Tensor(8077.105993596134, shape=(), dtype=float64) 4174
# slice = test, score = 0.6862386200287495
#
# === Iteration 295000 ===
# np.mean(results), mse, len(results) =  0.6936633663366337 tf.Tensor(8208.92107143979, shape=(), dtype=float64) 101
# slice = key, score = 0.6936633663366337
# np.mean(results), mse, len(results) =  0.6964833454394521 tf.Tensor(8065.913215541227, shape=(), dtype=float64) 9637
# slice = train, score = 0.6964833454394521
# np.mean(results), mse, len(results) =  0.6856540488739818 tf.Tensor(8085.033474761253, shape=(), dtype=float64) 4174
# slice = test, score = 0.6856540488739818
#
# === Iteration 296000 ===
# np.mean(results), mse, len(results) =  0.6923762376237624 tf.Tensor(8264.728966403873, shape=(), dtype=float64) 101
# slice = key, score = 0.6923762376237624
# np.mean(results), mse, len(results) =  0.6949413717962021 tf.Tensor(8101.191324027891, shape=(), dtype=float64) 9637
# slice = train, score = 0.6949413717962021
# np.mean(results), mse, len(results) =  0.6845280306660279 tf.Tensor(8126.4059046797765, shape=(), dtype=float64) 4174
# slice = test, score = 0.6845280306660279
#
# === Iteration 297000 ===
# np.mean(results), mse, len(results) =  0.6954455445544555 tf.Tensor(8184.059217260258, shape=(), dtype=float64) 101
# slice = key, score = 0.6954455445544555
# np.mean(results), mse, len(results) =  0.6975666701255577 tf.Tensor(8057.636860265272, shape=(), dtype=float64) 9637
# slice = train, score = 0.6975666701255577
# np.mean(results), mse, len(results) =  0.6855486344034498 tf.Tensor(8079.78852497004, shape=(), dtype=float64) 4174
# slice = test, score = 0.6855486344034498
#
# === Iteration 298000 ===
# np.mean(results), mse, len(results) =  0.6922772277227721 tf.Tensor(8312.32078472549, shape=(), dtype=float64) 101
# slice = key, score = 0.6922772277227721
# np.mean(results), mse, len(results) =  0.6944847981737056 tf.Tensor(8161.477152011875, shape=(), dtype=float64) 9637
# slice = train, score = 0.6944847981737056
# np.mean(results), mse, len(results) =  0.6830881648298994 tf.Tensor(8196.981863972758, shape=(), dtype=float64) 4174
# slice = test, score = 0.6830881648298994
#
# === Iteration 299000 ===
# np.mean(results), mse, len(results) =  0.6916831683168319 tf.Tensor(8431.499457056349, shape=(), dtype=float64) 101
# slice = key, score = 0.6916831683168319
# np.mean(results), mse, len(results) =  0.6967334232645014 tf.Tensor(8299.780527786344, shape=(), dtype=float64) 9637
# slice = train, score = 0.6967334232645014
# np.mean(results), mse, len(results) =  0.6845112601820794 tf.Tensor(8328.948685084173, shape=(), dtype=float64) 4174
# slice = test, score = 0.6845112601820794
# last loss =  tf.Tensor(-0.0059603358267692405, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.6953232333713811 tf.Tensor(8236.696357199355, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6834547196933397 tf.Tensor(8249.440377996953, shape=(), dtype=float64) 4174
# 0.6953232333713811 0.6834547196933397

# %%
do_RBE(ctx, "RecSysLT_14K_", N=300000)
# Out:
# /tmp/ipykernel_424313/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# self.embed_users['train'].shape =  (9637, 100)
# self.embed_games.shape =  (16514, 101)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (101, 16514)
# self.core_users_embs.shape =  (101, 100)
# self.ge_users.shape =  (9637, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.10356435643564357 tf.Tensor(50.3199373546101, shape=(), dtype=float64) 101
# slice = key, score = 0.10356435643564357
# np.mean(results), mse, len(results) =  0.10633080834284529 tf.Tensor(49.611613613711434, shape=(), dtype=float64) 9637
# slice = train, score = 0.10633080834284529
# np.mean(results), mse, len(results) =  0.10707474844274079 tf.Tensor(50.524043835650566, shape=(), dtype=float64) 4174
# slice = test, score = 0.10707474844274079
# np.mean(results), mse, len(results) =  0.10633080834284529 tf.Tensor(49.611613613711434, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.10707474844274079 tf.Tensor(50.524043835650566, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.1063_0.1071.npz ...
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.5240594059405941 tf.Tensor(157.9814951350711, shape=(), dtype=float64) 101
# slice = key, score = 0.5240594059405941
# np.mean(results), mse, len(results) =  0.5158015980076787 tf.Tensor(146.71042110103926, shape=(), dtype=float64) 9637
# slice = train, score = 0.5158015980076787
# np.mean(results), mse, len(results) =  0.5152898897939626 tf.Tensor(144.7581861638098, shape=(), dtype=float64) 4174
# slice = test, score = 0.5152898897939626
# np.mean(results), mse, len(results) =  0.5158015980076787 tf.Tensor(146.71042110103926, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5152898897939626 tf.Tensor(144.7581861638098, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.5158_0.5153.npz ...
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5583168316831684 tf.Tensor(269.0113955983858, shape=(), dtype=float64) 101
# slice = key, score = 0.5583168316831684
# np.mean(results), mse, len(results) =  0.5542233060080938 tf.Tensor(249.3334980016413, shape=(), dtype=float64) 9637
# slice = train, score = 0.5542233060080938
# np.mean(results), mse, len(results) =  0.5508481073310972 tf.Tensor(249.30174645856934, shape=(), dtype=float64) 4174
# slice = test, score = 0.5508481073310972
# np.mean(results), mse, len(results) =  0.5542233060080938 tf.Tensor(249.3334980016413, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5508481073310972 tf.Tensor(249.30174645856934, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.5542_0.5508.npz ...
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.5895049504950496 tf.Tensor(341.3595047382128, shape=(), dtype=float64) 101
# slice = key, score = 0.5895049504950496
# np.mean(results), mse, len(results) =  0.5803642212306734 tf.Tensor(317.6447352999149, shape=(), dtype=float64) 9637
# slice = train, score = 0.5803642212306734
# np.mean(results), mse, len(results) =  0.5760924772400575 tf.Tensor(314.62902160124287, shape=(), dtype=float64) 4174
# slice = test, score = 0.5760924772400575
# np.mean(results), mse, len(results) =  0.5803642212306734 tf.Tensor(317.6447352999149, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5760924772400575 tf.Tensor(314.62902160124287, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.5804_0.5761.npz ...
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.595049504950495 tf.Tensor(421.1471225851203, shape=(), dtype=float64) 101
# slice = key, score = 0.595049504950495
# np.mean(results), mse, len(results) =  0.5922195704057278 tf.Tensor(391.12337641104415, shape=(), dtype=float64) 9637
# slice = train, score = 0.5922195704057278
# np.mean(results), mse, len(results) =  0.5875011978917106 tf.Tensor(388.2204921874898, shape=(), dtype=float64) 4174
# slice = test, score = 0.5875011978917106
# np.mean(results), mse, len(results) =  0.5922195704057278 tf.Tensor(391.12337641104415, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5875011978917106 tf.Tensor(388.2204921874898, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.5922_0.5875.npz ...
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.6039603960396039 tf.Tensor(507.758506511824, shape=(), dtype=float64) 101
# slice = key, score = 0.6039603960396039
# np.mean(results), mse, len(results) =  0.6011435093908893 tf.Tensor(478.5052841038304, shape=(), dtype=float64) 9637
# slice = train, score = 0.6011435093908893
# np.mean(results), mse, len(results) =  0.5965165309056061 tf.Tensor(473.5045778132219, shape=(), dtype=float64) 4174
# slice = test, score = 0.5965165309056061
# np.mean(results), mse, len(results) =  0.6011435093908893 tf.Tensor(478.5052841038304, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.5965165309056061 tf.Tensor(473.5045778132219, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6011_0.5965.npz ...
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.6215841584158416 tf.Tensor(549.8817636559086, shape=(), dtype=float64) 101
# slice = key, score = 0.6215841584158416
# np.mean(results), mse, len(results) =  0.612830756459479 tf.Tensor(509.90183351172175, shape=(), dtype=float64) 9637
# slice = train, score = 0.612830756459479
# np.mean(results), mse, len(results) =  0.6061188308576905 tf.Tensor(506.7765862010775, shape=(), dtype=float64) 4174
# slice = test, score = 0.6061188308576905
# np.mean(results), mse, len(results) =  0.612830756459479 tf.Tensor(509.90183351172175, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6061188308576905 tf.Tensor(506.7765862010775, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6128_0.6061.npz ...
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.6175247524752475 tf.Tensor(664.7670599775764, shape=(), dtype=float64) 101
# slice = key, score = 0.6175247524752475
# np.mean(results), mse, len(results) =  0.6139099304762893 tf.Tensor(611.8403909358046, shape=(), dtype=float64) 9637
# slice = train, score = 0.6139099304762893
# np.mean(results), mse, len(results) =  0.6064686152371827 tf.Tensor(609.3552847354671, shape=(), dtype=float64) 4174
# slice = test, score = 0.6064686152371827
# np.mean(results), mse, len(results) =  0.6139099304762893 tf.Tensor(611.8403909358046, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6064686152371827 tf.Tensor(609.3552847354671, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6139_0.6065.npz ...
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.6089108910891088 tf.Tensor(739.7299972432501, shape=(), dtype=float64) 101
# slice = key, score = 0.6089108910891088
# np.mean(results), mse, len(results) =  0.6036837189996888 tf.Tensor(691.3847638728458, shape=(), dtype=float64) 9637
# slice = train, score = 0.6036837189996888
# np.mean(results), mse, len(results) =  0.598512218495448 tf.Tensor(689.0301124930079, shape=(), dtype=float64) 4174
# slice = test, score = 0.598512218495448
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.6198019801980198 tf.Tensor(822.3819627261022, shape=(), dtype=float64) 101
# slice = key, score = 0.6198019801980198
# np.mean(results), mse, len(results) =  0.6157248106257134 tf.Tensor(771.7533926202005, shape=(), dtype=float64) 9637
# slice = train, score = 0.6157248106257134
# np.mean(results), mse, len(results) =  0.6098897939626259 tf.Tensor(767.3901299731832, shape=(), dtype=float64) 4174
# slice = test, score = 0.6098897939626259
# np.mean(results), mse, len(results) =  0.6157248106257134 tf.Tensor(771.7533926202005, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6098897939626259 tf.Tensor(767.3901299731832, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6157_0.6099.npz ...
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0
shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6521514135122185 tf.Tensor(3209.7008125556076, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6605_0.6522.npz ...
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6620792079207921 tf.Tensor(3335.355497426938, shape=(), dtype=float64) 101
# slice = key, score = 0.6620792079207921
# np.mean(results), mse, len(results) =  0.6632894054166234 tf.Tensor(3225.119674157325, shape=(), dtype=float64) 9637
# slice = train, score = 0.6632894054166234
# np.mean(results), mse, len(results) =  0.6550431241015812 tf.Tensor(3217.991397197261, shape=(), dtype=float64) 4174
# slice = test, score = 0.6550431241015812
# np.mean(results), mse, len(results) =  0.6632894054166234 tf.Tensor(3225.119674157325, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6550431241015812 tf.Tensor(3217.991397197261, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6633_0.655.npz ...
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.6618811881188118 tf.Tensor(3421.5347136833666, shape=(), dtype=float64) 101
# slice = key, score = 0.6618811881188118
# np.mean(results), mse, len(results) =  0.6568880356957558 tf.Tensor(3300.4439677666273, shape=(), dtype=float64) 9637
# slice = train, score = 0.6568880356957558
# np.mean(results), mse, len(results) =  0.6483445136559656 tf.Tensor(3289.2233155261592, shape=(), dtype=float64) 4174
# slice = test, score = 0.6483445136559656
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.662970297029703 tf.Tensor(3422.2381925215846, shape=(), dtype=float64) 101
# slice = key, score = 0.662970297029703
# np.mean(results), mse, len(results) =  0.6604690256303829 tf.Tensor(3307.3449741729632, shape=(), dtype=float64) 9637
# slice = train, score = 0.6604690256303829
# np.mean(results), mse, len(results) =  0.6523550551030187 tf.Tensor(3298.2703813982325, shape=(), dtype=float64) 4174
# slice = test, score = 0.6523550551030187
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6620792079207921 tf.Tensor(3486.7203343853826, shape=(), dtype=float64) 101
# slice = key, score = 0.6620792079207921
# np.mean(results), mse, len(results) =  0.663804088409256 tf.Tensor(3335.7513570239767, shape=(), dtype=float64) 9637
# slice = train, score = 0.663804088409256
# np.mean(results), mse, len(results) =  0.6558097747963585 tf.Tensor(3329.8128050522955, shape=(), dtype=float64) 4174
# slice = test, score = 0.6558097747963585
# np.mean(results), mse, len(results) =  0.663804088409256 tf.Tensor(3335.7513570239767, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6558097747963585 tf.Tensor(3329.8128050522955, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6638_0.6558.npz ...
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6630693069306931 tf.Tensor(3561.445787229684, shape=(), dtype=float64) 101
# slice = key, score = 0.6630693069306931
# np.mean(results), mse, len(results) =  0.6606661824219155 tf.Tensor(3435.87770722846, shape=(), dtype=float64) 9637
# slice = train, score = 0.6606661824219155
# np.mean(results), mse, len(results) =  0.6545471969333972 tf.Tensor(3428.1001443395203, shape=(), dtype=float64) 4174
# slice = test, score = 0.6545471969333972
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.657920792079208 tf.Tensor(3517.552178076762, shape=(), dtype=float64) 101
# slice = key, score = 0.657920792079208
# np.mean(results), mse, len(results) =  0.6618532738404067 tf.Tensor(3414.6808889200292, shape=(), dtype=float64) 9637
# slice = train, score = 0.6618532738404067
# np.mean(results), mse, len(results) =  0.6549616674652611 tf.Tensor(3408.1827157383077, shape=(), dtype=float64) 4174
# slice = test, score = 0.6549616674652611
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0
shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6570987062769524 tf.Tensor(3929.6425419498355, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6647_0.6571.npz ...
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6599009900990098 tf.Tensor(4133.991684623805, shape=(), dtype=float64) 101
# slice = key, score = 0.6599009900990098
# np.mean(results), mse, len(results) =  0.6621728753761543 tf.Tensor(4000.916132828892, shape=(), dtype=float64) 9637
# slice = train, score = 0.6621728753761543
# np.mean(results), mse, len(results) =  0.6545136559655007 tf.Tensor(3994.0851799090733, shape=(), dtype=float64) 4174
# slice = test, score = 0.6545136559655007
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6641584158415842 tf.Tensor(4109.803002824172, shape=(), dtype=float64) 101
# slice = key, score = 0.6641584158415842
# np.mean(results), mse, len(results) =  0.667268859603611 tf.Tensor(4002.0788362528856, shape=(), dtype=float64) 9637
# slice = train, score = 0.667268859603611
# np.mean(results), mse, len(results) =  0.6594106372783901 tf.Tensor(3984.8209861730766, shape=(), dtype=float64) 4174
# slice = test, score = 0.6594106372783901
# np.mean(results), mse, len(results) =  0.667268859603611 tf.Tensor(4002.0788362528856, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6594106372783901 tf.Tensor(3984.8209861730766, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6673_0.6594.npz ...
#
# ...
# slice = key, score = 0.6785148514851486
# np.mean(results), mse, len(results) =  0.6787226315243332 tf.Tensor(5876.447952758349, shape=(), dtype=float64) 9637
# slice = train, score = 0.6787226315243332
# np.mean(results), mse, len(results) =  0.6697891710589362 tf.Tensor(5881.613038515445, shape=(), dtype=float64) 4174
# slice = test, score = 0.6697891710589362
# np.mean(results), mse, len(results) =  0.6787226315243332 tf.Tensor(5876.447952758349, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6697891710589362 tf.Tensor(5881.613038515445, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6787_0.6698.npz ...
#
# === Iteration 142000 ===
# np.mean(results), mse, len(results) =  0.6687128712871288 tf.Tensor(6215.227069436179, shape=(), dtype=float64) 101
# slice = key, score = 0.6687128712871288
# np.mean(results), mse, len(results) =  0.67423575801598 tf.Tensor(6005.301953889734, shape=(), dtype=float64) 9637
# slice = train, score = 0.67423575801598
# np.mean(results), mse, len(results) =  0.6665117393387637 tf.Tensor(6008.302733832134, shape=(), dtype=float64) 4174
# slice = test, score = 0.6665117393387637
#
# === Iteration 143000 ===
# np.mean(results), mse, len(results) =  0.6739603960396039 tf.Tensor(6208.296438886187, shape=(), dtype=float64) 101
# slice = key, score = 0.6739603960396039
# np.mean(results), mse, len(results) =  0.6759147037459791 tf.Tensor(6015.213570419676, shape=(), dtype=float64) 9637
# slice = train, score = 0.6759147037459791
# np.mean(results), mse, len(results) =  0.6670316243411596 tf.Tensor(6010.320853917277, shape=(), dtype=float64) 4174
# slice = test, score = 0.6670316243411596
#
# === Iteration 144000 ===
# np.mean(results), mse, len(results) =  0.6710891089108909 tf.Tensor(6327.992039301373, shape=(), dtype=float64) 101
# slice = key, score = 0.6710891089108909
# np.mean(results), mse, len(results) =  0.673111964304244 tf.Tensor(6102.678139846782, shape=(), dtype=float64) 9637
# slice = train, score = 0.673111964304244
# np.mean(results), mse, len(results) =  0.6632103497843794 tf.Tensor(6099.824283062805, shape=(), dtype=float64) 4174
# slice = test, score = 0.6632103497843794
#
# === Iteration 145000 ===
# np.mean(results), mse, len(results) =  0.6758415841584158 tf.Tensor(6343.991886716908, shape=(), dtype=float64) 101
# slice = key, score = 0.6758415841584158
# np.mean(results), mse, len(results) =  0.6739514371692436 tf.Tensor(6095.679936426296, shape=(), dtype=float64) 9637
# slice = train, score = 0.6739514371692436
# np.mean(results), mse, len(results) =  0.6654048873981792 tf.Tensor(6101.650879326754, shape=(), dtype=float64) 4174
# slice = test, score = 0.6654048873981792
#
# === Iteration 146000 ===
# np.mean(results), mse, len(results) =  0.6741584158415842 tf.Tensor(6417.305088927981, shape=(), dtype=float64) 101
# slice = key, score = 0.6741584158415842
# np.mean(results), mse, len(results) =  0.6741133132717652 tf.Tensor(6144.139027024151, shape=(), dtype=float64) 9637
# slice = train, score = 0.6741133132717652
# np.mean(results), mse, len(results) =  0.6639770004791566 tf.Tensor(6152.036871197188, shape=(), dtype=float64) 4174
# slice = test, score = 0.6639770004791566
#
# === Iteration 147000 ===
# np.mean(results), mse, len(results) =  0.6738613861386139 tf.Tensor(6318.283382395506, shape=(), dtype=float64) 101
# slice = key, score = 0.6738613861386139
# np.mean(results), mse, len(results) =  0.6782120992009962 tf.Tensor(6080.669365636808, shape=(), dtype=float64) 9637
# slice = train, score = 0.6782120992009962
# np.mean(results), mse, len(results) =  0.6693627216099665 tf.Tensor(6087.459502103633, shape=(), dtype=float64) 4174
# slice = test, score = 0.6693627216099665
#
# === Iteration 148000 ===
# np.mean(results), mse, len(results) =  0.6737623762376236 tf.Tensor(6432.046342289807, shape=(), dtype=float64) 101
# slice = key, score = 0.6737623762376236
# np.mean(results), mse, len(results) =  0.6770021791013802 tf.Tensor(6181.242698058064, shape=(), dtype=float64) 9637
# slice = train, score = 0.6770021791013802
# np.mean(results), mse, len(results) =  0.6664278869190225 tf.Tensor(6182.734489683201, shape=(), dtype=float64) 4174
# slice = test, score = 0.6664278869190225
#
# === Iteration 149000 ===
# np.mean(results), mse, len(results) =  0.6778217821782179 tf.Tensor(6532.162693989767, shape=(), dtype=float64) 101
# slice = key, score = 0.6778217821782179
# np.mean(results), mse, len(results) =  0.6760610148386427 tf.Tensor(6277.203716783207, shape=(), dtype=float64) 9637
# slice = train, score = 0.6760610148386427
# np.mean(results), mse, len(results) =  0.6687350263536176 tf.Tensor(6276.324558868857, shape=(), dtype=float64) 4174
# slice = test, score = 0.6687350263536176
#
# === Iteration 150000 ===
# np.mean(results), mse, len(results) =  0.6730693069306931 tf.Tensor(6454.998206173192, shape=(), dtype=float64) 101
# slice = key, score = 0.6730693069306931
# np.mean(results), mse, len(results) =  0.6730725329459375 tf.Tensor(6219.458461310655, shape=(), dtype=float64) 9637
# slice = train, score = 0.6730725329459375
# np.mean(results), mse, len(results) =  0.6643938667944419 tf.Tensor(6215.175228660769, shape=(), dtype=float64) 4174
# slice = test, score = 0.6643938667944419
#
# === Iteration 151000 ===
# np.mean(results), mse, len(results) =  0.6674257425742576 tf.Tensor(6627.3670753237175, shape=(), dtype=float64) 101
# slice = key, score = 0.6674257425742576
# np.mean(results), mse, len(results) =  0.6722029677285462 tf.Tensor(6359.436049476368, shape=(), dtype=float64) 9637
# slice = train, score = 0.6722029677285462
# np.mean(results), mse, len(results) =  0.662922855773838 tf.Tensor(6363.994658774335, shape=(), dtype=float64) 4174
# slice = test, score = 0.662922855773838
#
# === Iteration 152000 ===
# np.mean(results), mse, len(results) =  0.6759405940594059 tf.Tensor(6531.9436538495, shape=(), dtype=float64) 101
# slice = key, score = 0.6759405940594059
# np.mean(results), mse, len(results) =  0.6757185846217703 tf.Tensor(6277.229523649158, shape=(), dtype=float64) 9637
# slice = train, score = 0.6757185846217703
# np.mean(results), mse, len(results) =  0.6655797795879252 tf.Tensor(6281.646572787696, shape=(), dtype=float64) 4174
# slice = test, score = 0.6655797795879252
#
# === Iteration 153000 ===
# np.mean(results), mse, len(results) =  0.6732673267326733 tf.Tensor(6561.542044822081, shape=(), dtype=float64) 101
# slice = key, score = 0.6732673267326733
# np.mean(results), mse, len(results) =  0.6763733527031234 tf.Tensor(6330.414898178983, shape=(), dtype=float64) 9637
# slice = train, score = 0.6763733527031234
# np.mean(results), mse, len(results) =  0.6670052707235266 tf.Tensor(6336.179537045808, shape=(), dtype=float64) 4174
# slice = test, score = 0.6670052707235266
#
# === Iteration 154000 ===
# np.mean(results), mse, len(results) =  0.6751485148514851 tf.Tensor(6508.761126146754, shape=(), dtype=float64) 101
# slice = key, score = 0.6751485148514851
# np.mean(results), mse, len(results) =  0.6769897270934939 tf.Tensor(6277.655822814767, shape=(), dtype=float64) 9637
# slice = train, score = 0.6769897270934939
# np.mean(results), mse, len(results) =  0.6682175371346432 tf.Tensor(6280.017092395932, shape=(), dtype=float64) 4174
# slice = test, score = 0.6682175371346432
#
# === Iteration 155000 ===
# np.mean(results), mse, len(results) =  0.6672277227722774 tf.Tensor(6606.422613851704, shape=(), dtype=float64) 101
# slice = key, score = 0.6672277227722774
# np.mean(results), mse, len(results) =  0.6701815917816747 tf.Tensor(6388.391068769043, shape=(), dtype=float64) 9637
# slice = train, score = 0.6701815917816747
# np.mean(results), mse, len(results) =  0.6602827024436992 tf.Tensor(6389.975422430742, shape=(), dtype=float64) 4174
# slice = test, score = 0.6602827024436992
#
# === Iteration 156000 ===
# np.mean(results), mse, len(results) =  0.6713861386138615 tf.Tensor(6642.552335122467, shape=(), dtype=float64) 101
# slice = key, score = 0.6713861386138615
# np.mean(results), mse, len(results) =  0.6736930580056035 tf.Tensor(6399.936041317476, shape=(), dtype=float64) 9637
# slice = train, score = 0.6736930580056035
# np.mean(results), mse, len(results) =  0.6658792525155727 tf.Tensor(6403.916227675222, shape=(), dtype=float64) 4174
# slice = test, score = 0.6658792525155727
#
# === Iteration 157000 ===
# np.mean(results), mse, len(results) =  0.6780198019801981 tf.Tensor(6744.377202011191, shape=(), dtype=float64) 101
# slice = key, score = 0.6780198019801981
# np.mean(results), mse, len(results) =  0.676865207014631 tf.Tensor(6500.502240794723, shape=(), dtype=float64) 9637
# slice = train, score = 0.676865207014631
# np.mean(results), mse, len(results) =  0.6677455678006708 tf.Tensor(6502.79936539011, shape=(), dtype=float64) 4174
# slice = test, score = 0.6677455678006708
#
# === Iteration 158000 ===
# np.mean(results), mse, len(results) =  0.6730693069306932 tf.Tensor(6801.5719769187, shape=(), dtype=float64) 101
# slice = key, score = 0.6730693069306932
# np.mean(results), mse, len(results) =  0.6757932966690878 tf.Tensor(6577.424551417549, shape=(), dtype=float64) 9637
# slice = train, score = 0.6757932966690878
# np.mean(results), mse, len(results) =  0.6660733109726882 tf.Tensor(6575.3427556421475, shape=(), dtype=float64) 4174
# slice = test, score = 0.6660733109726882
#
# === Iteration 159000 ===
# np.mean(results), mse, len(results) =  0.6767326732673267 tf.Tensor(6815.015878139691, shape=(), dtype=float64) 101
# slice = key, score = 0.6767326732673267
# np.mean(results), mse, len(results) =  0.6780429594272076 tf.Tensor(6549.388281118513, shape=(), dtype=float64) 9637
# slice = train, score = 0.6780429594272076
# np.mean(results), mse, len(results) =  0.6693052228078581 tf.Tensor(6561.021744611982, shape=(), dtype=float64) 4174
# slice = test, score = 0.6693052228078581
#
# === Iteration 160000 ===
# np.mean(results), mse, len(results) =  0.6743564356435645 tf.Tensor(6808.820471374661, shape=(), dtype=float64) 101
# slice = key, score = 0.6743564356435645
# np.mean(results), mse, len(results) =  0.6758866867282349 tf.Tensor(6599.537974983314, shape=(), dtype=float64) 9637
# slice = train, score = 0.6758866867282349
# np.mean(results), mse, len(results) =  0.6668207954000959 tf.Tensor(6596.644112160683, shape=(), dtype=float64) 4174
# slice = test, score = 0.6668207954000959
#
# === Iteration 161000 ===
# np.mean(results), mse, len(results) =  0.6713861386138614 tf.Tensor(6986.2704745207175, shape=(), dtype=float64) 101
# slice = key, score = 0.6713861386138614
# np.mean(results), mse, len(results) =  0.6698951956002904 tf.Tensor(6738.069219220932, shape=(), dtype=float64) 9637
# slice = train, score = 0.6698951956002904
# np.mean(results), mse, len(results) =  0.6613991375179684 tf.Tensor(6741.60540555131, shape=(), dtype=float64) 4174
# slice = test, score = 0.6613991375179684
#
# === Iteration 162000 ===
# np.mean(results), mse, len(results) =  0.6734653465346534 tf.Tensor(6820.8411011266735, shape=(), dtype=float64) 101
# slice = key, score = 0.6734653465346534
# np.mean(results), mse, len(results) =  0.677529314101899 tf.Tensor(6589.892408005145, shape=(), dtype=float64) 9637
# slice = train, score = 0.677529314101899
# np.mean(results), mse, len(results) =  0.6678485864877816 tf.Tensor(6599.382480985796, shape=(), dtype=float64) 4174
# slice = test, score = 0.6678485864877816
#
# === Iteration 163000 ===
# np.mean(results), mse, len(results) =  0.6688118811881187 tf.Tensor(6923.762962145862, shape=(), dtype=float64) 101
# slice = key, score = 0.6688118811881187
# np.mean(results), mse, len(results) =  0.6772491439244579 tf.Tensor(6653.752407770468, shape=(), dtype=float64) 9637
# slice = train, score = 0.6772491439244579
# np.mean(results), mse, len(results) =  0.6677407762338283 tf.Tensor(6665.453229085843, shape=(), dtype=float64) 4174
# slice = test, score = 0.6677407762338283
#
# === Iteration 164000 ===
# np.mean(results), mse, len(results) =  0.678118811881188 tf.Tensor(6954.404911914884, shape=(), dtype=float64) 101
# slice = key, score = 0.678118811881188
# np.mean(results), mse, len(results) =  0.680187817785618 tf.Tensor(6686.657389212742, shape=(), dtype=float64) 9637
# slice = train, score = 0.680187817785618
# np.mean(results), mse, len(results) =  0.6709008145663631 tf.Tensor(6694.82882998711, shape=(), dtype=float64) 4174
# slice = test, score = 0.6709008145663631
# np.mean(results), mse, len(results) =  0.680187817785618 tf.Tensor(6686.657389212742, shape=(), dtype=float64) 9637
# np.mean(results), mse, len(results) =  0.6709008145663631 tf.Tensor(6694.82882998711, shape=(), dtype=float64) 4174
# Saving ./GE_QE_RBExCoItem_RecSysLT_14K__0.6802_0.6709.npz ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/npyio.py:719, in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     718     with zipf.open(fname, 'w', force_zip64=True) as fid:
# --> 719         format.write_array(fid, val,
#     720                            allow_pickle=allow_pickle,
#     721                            pickle_kwargs=pickle_kwargs)
#     723 zipf.close()
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/format.py:727, in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     724 for chunk in numpy.nditer(
#     725         array, flags=['external_loop', 'buffered', 'zerosize_ok'],
#     726         buffersize=buffersize, order='C'):
# --> 727     fp.write(chunk.tobytes('C'))
#
# File ~/anaconda3/lib/python3.11/zipfile.py:1169, in _ZipWriteFile.write(self, data)
#    1168     self._compress_size += len(data)
# -> 1169 self._fileobj.write(data)
#    1170 return nbytes
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 do_RBE(ctx, "RecSysLT_14K_", N=300000)
#
# Cell In[22], line 58, in do_RBE(ctx, name, coitem, kmeans, top, random, N, LR)
#      36 ctx.key_games = list(coitem_algorithm(100, t, t, 1e-8, eps=1e9)[0])
#      38 ma = CBKnnV0(ctx, fit_kwargs={
#      39     'c': 0,
#      40     'train_matrix': True,
#    (...)
#      55     "save_callback": get_save_callback("test", f"./GE_QE_RBExCoItem_{name}.npz")
#      56 })
# ---> 58 ma.fit()
#      59 tr, te = ma.get_score("train"), ma.get_score("test")
#      60 print(tr, te)
#
# Cell In[5], line 452, in CBKnnV0.fit(self, **kwargs)
#     450             self.slice2best = score
#     451             if p["save_callback"] is not None:
# --> 452                 p["save_callback"](self)
#     454 print("last loss = ", loss())
#
# Cell In[22], line 30, in do_RBE.<locals>.get_save_callback.<locals>.save_callback(m)
#      28 fname_ = l + f"_{str(round(train_score, 4))}_{str(round(score, 4))}.npz" + r
#      29 print(f"Saving {fname_} ...")
# ---> 30 np.savez_compressed(fname_, QE=QE, GE=GE)
#
# File <__array_function__ internals>:200, in savez_compressed(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/npyio.py:686, in savez_compressed(file, *args, **kwds)
#     623 @array_function_dispatch(_savez_compressed_dispatcher)
#     624 def savez_compressed(file, *args, **kwds):
#     625     """
#     626     Save several arrays into a single file in compressed ``.npz`` format.
#     627
#    (...)
#     684
#     685     """
# --> 686     _savez(file, args, kwds, True)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/npyio.py:718, in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     716     val = np.asanyarray(val)
#     717     # always force zip64, gh-10776
# --> 718     with zipf.open(fname, 'w', force_zip64=True) as fid:
#     719         format.write_array(fid, val,
#     720                            allow_pickle=allow_pickle,
#     721                            pickle_kwargs=pickle_kwargs)
#     723 zipf.close()
#
# File ~/anaconda3/lib/python3.11/zipfile.py:1181, in _ZipWriteFile.close(self)
#    1179     buf = self._compressor.flush()
#    1180     self._compress_size += len(buf)
# -> 1181     self._fileobj.write(buf)
#    1182     self._zinfo.compress_size = self._compress_size
#    1183 else:
#
# OSError: [Errno 28] No space left on device

# %%
GE_QE_s = [
    "GE_QE_AnnCURxCoItem_RecSysLT_Round10_6565.npz",
    "GE_QE_AnnCURxKMeans_RecSysLT_Round10_613.npz",
    "GE_QE_AnnCURxRandom_RecSysLT_Round10_5842.npz",
    "GGE_QE_AnnCURxTop_RecSysLT_Round10_6695.npz"
]

# %%
res = dict()
for GE_QE_i in GE_QE_s:
    loaded = np.load('./' + GE_QE_i)
    res["GE_QE_i"] = do_AXN(ctx, loaded, get_Rp_basic)
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:26<00:00,  3.88it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.8504807692307692
# 100%|█████████████████████████████████████████| 104/104 [00:30<00:00,  3.43it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.8435576923076922
# 100%|█████████████████████████████████████████| 104/104 [00:25<00:00,  4.12it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.8377884615384615
# 100%|█████████████████████████████████████████| 104/104 [00:28<00:00,  3.68it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.8274038461538461
# 100%|█████████████████████████████████████████| 104/104 [00:26<00:00,  3.89it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.8152884615384615
# 100%|█████████████████████████████████████████| 104/104 [00:28<00:00,  3.67it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.8003846153846155
# 100%|█████████████████████████████████████████| 104/104 [00:30<00:00,  3.41it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7865384615384615
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.74it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7679807692307692
# 100%|█████████████████████████████████████████| 104/104 [00:26<00:00,  3.93it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7578846153846153
# 100%|█████████████████████████████████████████| 104/104 [00:29<00:00,  3.58it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.74
# 100%|█████████████████████████████████████████| 104/104 [00:31<00:00,  3.31it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7264423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:31<00:00,  3.29it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.8147115384615383
# 100%|█████████████████████████████████████████| 104/104 [00:24<00:00,  4.22it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.8203846153846153
# 100%|█████████████████████████████████████████| 104/104 [00:26<00:00,  3.91it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.8196153846153847
# 100%|█████████████████████████████████████████| 104/104 [00:23<00:00,  4.43it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.8154807692307693
# 100%|█████████████████████████████████████████| 104/104 [00:33<00:00,  3.13it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.8025961538461538
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.81it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.79125
# 100%|█████████████████████████████████████████| 104/104 [00:24<00:00,  4.22it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7774038461538461
# 100%|█████████████████████████████████████████| 104/104 [00:23<00:00,  4.36it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7583653846153846
# 100%|█████████████████████████████████████████| 104/104 [00:29<00:00,  3.49it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7489423076923079
# 100%|█████████████████████████████████████████| 104/104 [00:26<00:00,  3.91it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7329807692307693
# 100%|█████████████████████████████████████████| 104/104 [00:30<00:00,  3.40it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7194230769230768
# 100%|█████████████████████████████████████████| 104/104 [00:32<00:00,  3.22it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.795
# 100%|█████████████████████████████████████████| 104/104 [00:29<00:00,  3.48it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.8040384615384616
# 100%|█████████████████████████████████████████| 104/104 [00:28<00:00,  3.64it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.8093269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.73it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.8044230769230769
# 100%|█████████████████████████████████████████| 104/104 [00:25<00:00,  4.16it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7976923076923078
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.76it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7817307692307692
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.72it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7722115384615384
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.85it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7647115384615385
# 100%|█████████████████████████████████████████| 104/104 [00:26<00:00,  3.94it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.745
# 100%|█████████████████████████████████████████| 104/104 [00:29<00:00,  3.58it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7331730769230771
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.73it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.720576923076923
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 res = dict()
#       2 for GE_QE_i in GE_QE_s:
# ----> 3     loaded = np.load('./' + GE_QE_i)
#       4     res["GE_QE_i"] = do_AXN(ctx, loaded, get_Rp_basic)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './GGE_QE_AnnCURxTop_RecSysLT_Round10_6695.npz'

# %%
GE_QE_s[-1] = "GE_QE_AnnCURxTop_RecSysLT_Round10_6695.npz"

# %%
res = dict()
for GE_QE_i in GE_QE_s[-1:]:
    loaded = np.load('./' + GE_QE_i)
    res["GE_QE_i"] = do_AXN(ctx, loaded, get_Rp_basic)
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:30<00:00,  3.42it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.8509615384615384
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.72it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.8435576923076924
# 100%|█████████████████████████████████████████| 104/104 [00:24<00:00,  4.32it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.8430769230769232
# 100%|█████████████████████████████████████████| 104/104 [00:31<00:00,  3.34it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.8350000000000001
#  95%|███████████████████████████████████████▉  | 99/104 [00:28<00:01,  3.50it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 4
#       2 for GE_QE_i in GE_QE_s[-1:]:
#       3     loaded = np.load('./' + GE_QE_i)
# ----> 4     res["GE_QE_i"] = do_AXN(ctx, loaded, get_Rp_basic)
#
# Cell In[28], line 38, in do_AXN(ctx, loaded, get_Rp, Z, STRIP, Ls)
#      35 ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_))))
#      37 for _ in range(T // K - 1):
# ---> 38     Rp = get_Rp(GE, A, Rt[A], QE[i], L)
#      40     An = list(A)
#      41     for ai in Rp.argsort()[::-1]:
#
# Cell In[28], line 4, in get_Rp_basic(GE, A, R, QE_i, L)
#       1 def get_Rp_basic(GE, A, R, QE_i, L):
#       2     Ae = GE[A]
# ----> 4     u = np.linalg.pinv(Ae.T @ Ae) @ Ae.T @ R
#       5     assert u.shape == QE_i.shape
#       6     Rp = GE @ (u * L + QE_i * (1 - L))
#
# File <__array_function__ internals>:200, in pinv(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:1983, in pinv(a, rcond, hermitian)
#    1981     return wrap(res)
#    1982 a = a.conjugate()
# -> 1983 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    1985 # discard small singular values
#    1986 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File <__array_function__ internals>:200, in svd(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:1642, in svd(a, full_matrices, compute_uv, hermitian)
#    1639         gufunc = _umath_linalg.svd_n_s
#    1641 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1642 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1643 u = u.astype(result_t, copy=False)
#    1644 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
res
# Out:
# {'GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.7226',
#  'GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.6807999999999998',
#  'GE_QE_AnnCURxTop_yugioh_Round10_2429.npz': 'K = 25, L = 0.3, rndFirst = False np.mean(results) = 0.38',
#  'GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.6146'}

# %% [raw]
# AnnCURxTop    : 0.8509615384615384 -> 0.8509615384615384
# AnnCURxCoItem : 0.8504807692307692 -> 0.8504807692307692
# AnnCURxKMeans : 0.8147115384615383 ->  0.8147115384615383
# AnnCURxRandom : 0.795 -> 0.8093269230769231 (L = 0.2)

# %% [markdown]
# ## RecSys PairWise

# %%
L = 7000
N = 1000
DA = 50


ctx = load(L, raw_path = "//dev/null/stand/log.local.txt",
           path="log.local.bin.old", seed=17, det_attempts=DA, key_size=50)
print("LOADED")
# Out:
# [(6, 16514), (7, 16514), (8, 16514), (9, 16514)]
# Best det =  1.4692355991364834e-44
# 1.4692355991364834e-44
# 51 4694 2034
# LOADED

# %%
do(ctx, "RecSysLT_Key50_")
# Out:
# /tmp/ipykernel_965688/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/50 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.6523753728163613 0.4232415359177667 4694
# np.mean(results), mse, len(results) =  0.6526745329400198 0.5435502971951501 2034
# ./GE_QE_AnnCURxCoItem_RecSysLT_Key50__6527.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151: ConvergenceWarning: Number of distinct clusters (42) found smaller than n_clusters (50). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# np.mean(results), mse, len(results) =  0.7216744780570942 1.1133082210796557 4694
# np.mean(results), mse, len(results) =  0.7174188790560472 1.0786282255946333 2034
# ./GE_QE_AnnCURxKMeans_RecSysLT_Key50__7174.npz
# np.mean(results), mse, len(results) =  0.7695398380911803 0.5488957119002489 4694
# np.mean(results), mse, len(results) =  0.7671976401179941 0.5850987156264035 2034
# ./GE_QE_AnnCURxTop_RecSysLT_Key50__7672.npz
# np.mean(results), mse, len(results) =  0.6617895185342991 2.169721236214458 4694
# np.mean(results), mse, len(results) =  0.6611553588987217 1.918897574185812 2034
# ./GE_QE_AnnCURxRandom_RecSysLT_Key50__6612.npz

# %%
do_RBE(ctx, "RecSysLT_Key50_")
# Out:
# /tmp/ipykernel_965688/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# self.embed_users['train'].shape =  (4694, 100)
# self.embed_games.shape =  (16514, 51)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (51, 16514)
# self.core_users_embs.shape =  (51, 100)
# self.ge_users.shape =  (4694, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.19137254901960785 tf.Tensor(41.028397650803306, shape=(), dtype=float64) 51
# slice = key, score = 0.19137254901960785
# np.mean(results), mse, len(results) =  0.281011930123562 tf.Tensor(27.50619103581194, shape=(), dtype=float64) 4694
# slice = train, score = 0.281011930123562
# np.mean(results), mse, len(results) =  0.21592428711897738 tf.Tensor(28.28270321926398, shape=(), dtype=float64) 2034
# slice = test, score = 0.21592428711897738
# np.mean(results), mse, len(results) =  0.21592428711897738 tf.Tensor(28.28270321926398, shape=(), dtype=float64) 2034
# Saving ./GE_QE_RBExCoItem_RecSysLT_Key50__0.2159.npz ...
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.5949019607843137 tf.Tensor(1677.6607772657735, shape=(), dtype=float64) 51
# slice = key, score = 0.5949019607843137
# np.mean(results), mse, len(results) =  0.6488666382616105 tf.Tensor(465.6891393702023, shape=(), dtype=float64) 4694
# slice = train, score = 0.6488666382616105
# np.mean(results), mse, len(results) =  0.6377728613569321 tf.Tensor(464.24744297043935, shape=(), dtype=float64) 2034
# slice = test, score = 0.6377728613569321
# np.mean(results), mse, len(results) =  0.6377728613569321 tf.Tensor(464.24744297043935, shape=(), dtype=float64) 2034
# Saving ./GE_QE_RBExCoItem_RecSysLT_Key50__0.6378.npz ...
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5966666666666666 tf.Tensor(2819.984925828771, shape=(), dtype=float64) 51
# slice = key, score = 0.5966666666666666
# np.mean(results), mse, len(results) =  0.649936088623775 tf.Tensor(691.2069184574874, shape=(), dtype=float64) 4694
# slice = train, score = 0.649936088623775
# np.mean(results), mse, len(results) =  0.6407669616519174 tf.Tensor(711.3632189573245, shape=(), dtype=float64) 2034
# slice = test, score = 0.6407669616519174
# np.mean(results), mse, len(results) =  0.6407669616519174 tf.Tensor(711.3632189573245, shape=(), dtype=float64) 2034
# Saving ./GE_QE_RBExCoItem_RecSysLT_Key50__0.6408.npz ...
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0
#
# === Iteration 89000 ===
# np.mean(results), mse, len(results) =  0.7296078431372548 tf.Tensor(50974.93055396655, shape=(), dtype=float64) 51
# slice = key, score = 0.7296078431372548
# np.mean(results), mse, len(results) =  0.7588112484022156 tf.Tensor(26601.92191084327, shape=(), dtype=float64) 4694
# slice = train, score = 0.7588112484022156
# np.mean(results), mse, len(results) =  0.7511799410029499 tf.Tensor(28026.470808825394, shape=(), dtype=float64) 2034
# slice = test, score = 0.7511799410029499
#
# === Iteration 90000 ===
# np.mean(results), mse, len(results) =  0.7186274509803922 tf.Tensor(62266.72893248605, shape=(), dtype=float64) 51
# slice = key, score = 0.7186274509803922
# np.mean(results), mse, len(results) =  0.7547145291861952 tf.Tensor(32877.828710958995, shape=(), dtype=float64) 4694
# slice = train, score = 0.7547145291861952
# np.mean(results), mse, len(results) =  0.7459488692232055 tf.Tensor(34660.703392957774, shape=(), dtype=float64) 2034
# slice = test, score = 0.7459488692232055
#
# === Iteration 91000 ===
# np.mean(results), mse, len(results) =  0.7237254901960783 tf.Tensor(62451.379427483946, shape=(), dtype=float64) 51
# slice = key, score = 0.7237254901960783
# np.mean(results), mse, len(results) =  0.759663400085215 tf.Tensor(32641.66788618964, shape=(), dtype=float64) 4694
# slice = train, score = 0.759663400085215
# np.mean(results), mse, len(results) =  0.7539478859390364 tf.Tensor(34407.080870661775, shape=(), dtype=float64) 2034
# slice = test, score = 0.7539478859390364
#
# === Iteration 92000 ===
# np.mean(results), mse, len(results) =  0.7215686274509805 tf.Tensor(68084.5946737445, shape=(), dtype=float64) 51
# slice = key, score = 0.7215686274509805
# np.mean(results), mse, len(results) =  0.7580549637835535 tf.Tensor(33624.27834830784, shape=(), dtype=float64) 4694
# slice = train, score = 0.7580549637835535
# np.mean(results), mse, len(results) =  0.7503244837758112 tf.Tensor(35702.523993574854, shape=(), dtype=float64) 2034
# slice = test, score = 0.7503244837758112
#
# === Iteration 93000 ===
# np.mean(results), mse, len(results) =  0.7249019607843136 tf.Tensor(64760.17857495792, shape=(), dtype=float64) 51
# slice = key, score = 0.7249019607843136
# np.mean(results), mse, len(results) =  0.757988922028121 tf.Tensor(33356.629384177075, shape=(), dtype=float64) 4694
# slice = train, score = 0.757988922028121
# np.mean(results), mse, len(results) =  0.7548672566371681 tf.Tensor(34912.85252218531, shape=(), dtype=float64) 2034
# slice = test, score = 0.7548672566371681
#
# === Iteration 94000 ===
# np.mean(results), mse, len(results) =  0.7254901960784312 tf.Tensor(58194.136455205626, shape=(), dtype=float64) 51
# slice = key, score = 0.7254901960784312
# np.mean(results), mse, len(results) =  0.7614060502769493 tf.Tensor(29969.527799389492, shape=(), dtype=float64) 4694
# slice = train, score = 0.7614060502769493
# np.mean(results), mse, len(results) =  0.7534808259587021 tf.Tensor(31406.462294202884, shape=(), dtype=float64) 2034
# slice = test, score = 0.7534808259587021
#
# === Iteration 95000 ===
# np.mean(results), mse, len(results) =  0.7176470588235293 tf.Tensor(63810.15824150093, shape=(), dtype=float64) 51
# slice = key, score = 0.7176470588235293
# np.mean(results), mse, len(results) =  0.7582296548785684 tf.Tensor(32222.19847699427, shape=(), dtype=float64) 4694
# slice = train, score = 0.7582296548785684
# np.mean(results), mse, len(results) =  0.7505948869223206 tf.Tensor(33728.33065100441, shape=(), dtype=float64) 2034
# slice = test, score = 0.7505948869223206
#
# === Iteration 96000 ===
# np.mean(results), mse, len(results) =  0.7211764705882352 tf.Tensor(67612.9369991916, shape=(), dtype=float64) 51
# slice = key, score = 0.7211764705882352
# np.mean(results), mse, len(results) =  0.764090328078398 tf.Tensor(33516.70932263621, shape=(), dtype=float64) 4694
# slice = train, score = 0.764090328078398
# np.mean(results), mse, len(results) =  0.758048180924287 tf.Tensor(35120.762864891934, shape=(), dtype=float64) 2034
# slice = test, score = 0.758048180924287
# np.mean(results), mse, len(results) =  0.758048180924287 tf.Tensor(35120.762864891934, shape=(), dtype=float64) 2034
# Saving ./GE_QE_RecSysLT_Key50__RBExRandom_0.758.npz ...
#
# === Iteration 97000 ===
# np.mean(results), mse, len(results) =  0.7137254901960782 tf.Tensor(68768.12690583715, shape=(), dtype=float64) 51
# slice = key, score = 0.7137254901960782
# np.mean(results), mse, len(results) =  0.7597976139752876 tf.Tensor(32487.437538667178, shape=(), dtype=float64) 4694
# slice = train, score = 0.7597976139752876
# np.mean(results), mse, len(results) =  0.7494788593903638 tf.Tensor(34368.040042317705, shape=(), dtype=float64) 2034
# slice = test, score = 0.7494788593903638
# === Iteration 98000 ===
# np.mean(results), mse, len(results) =  0.7170588235294117 tf.Tensor(70231.3952952414, shape=(), dtype=float64) 51
# slice = key, score = 0.7170588235294117
# np.mean(results), mse, len(results) =  0.7592458457605454 tf.Tensor(36390.9648993698, shape=(), dtype=float64) 4694
# slice = train, score = 0.7592458457605454
# np.mean(results), mse, len(results) =  0.7510766961651918 tf.Tensor(38083.529275474975, shape=(), dtype=float64) 2034
# slice = test, score = 0.7510766961651918
#
# === Iteration 99000 ===
# np.mean(results), mse, len(results) =  0.703529411764706 tf.Tensor(76204.88118972903, shape=(), dtype=float64) 51
# slice = key, score = 0.703529411764706
# np.mean(results), mse, len(results) =  0.7614806135492117 tf.Tensor(35584.69502805213, shape=(), dtype=float64) 4694
# slice = train, score = 0.7614806135492117
# np.mean(results), mse, len(results) =  0.7551081612586037 tf.Tensor(37548.16732348121, shape=(), dtype=float64) 2034
# slice = test, score = 0.7551081612586037
# last loss =  tf.Tensor(-0.006965085489698506, shape=(), dtype=float64)
# np.mean(results), mse, len(results) =  0.7585726459309757 tf.Tensor(38487.325032432265, shape=(), dtype=float64) 4694
# np.mean(results), mse, len(results) =  0.7523254670599804 tf.Tensor(40483.531637729124, shape=(), dtype=float64) 2034
# 0.7585726459309757 0.7523254670599804

# %%
# !ls | grep "GE.*RecSys_"
# Out:
# GE_QE_AnnCURxCoItem_RecSys_Round10_7197.npz
# GE_QE_AnnCURxKMeans_RecSys_Round10_7156.npz
# GE_QE_AnnCURxRandom_RecSys_Round10_6743.npz
# GE_QE_AnnCURxTop_RecSys_Round10_7623.npz

# %%
GE_QE_s = [
    "GE_QE_AnnCURxCoItem_RecSys_Round10_7197.npz",
    "GE_QE_AnnCURxKMeans_RecSys_Round10_7156.npz",
    "GE_QE_AnnCURxRandom_RecSys_Round10_6743.npz",
    "GE_QE_AnnCURxTop_RecSys_Round10_7623.npz"
]

# %%
res = dict()
for GE_QE_i in GE_QE_s:
    loaded = np.load('./' + GE_QE_i)
    res[GE_QE_i] = do_AXN(ctx, loaded, get_Rp_basic, Ls = np.linspace(0, 0.3, 4))
# Out:
# 100%|█████████████████████████████████████████| 101/101 [00:14<00:00,  6.84it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.8829702970297029
# 100%|█████████████████████████████████████████| 101/101 [00:13<00:00,  7.34it/s]
# K = 25, L = 0.09999999999999999, TS = 100, rndFirst = False np.mean(results) = 0.7820792079207922
# 100%|█████████████████████████████████████████| 101/101 [00:15<00:00,  6.66it/s]
# K = 25, L = 0.19999999999999998, TS = 100, rndFirst = False np.mean(results) = 0.7712871287128713
# 100%|█████████████████████████████████████████| 101/101 [00:08<00:00, 11.33it/s]
# K = 25, L = 0.3, TS = 100, rndFirst = False np.mean(results) = 0.765148514851485
# 100%|█████████████████████████████████████████| 101/101 [00:12<00:00,  8.28it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.9028712871287127
# 100%|█████████████████████████████████████████| 101/101 [00:11<00:00,  8.64it/s]
# K = 25, L = 0.09999999999999999, TS = 100, rndFirst = False np.mean(results) = 0.8363366336633664
# 100%|█████████████████████████████████████████| 101/101 [00:14<00:00,  7.11it/s]
# K = 25, L = 0.19999999999999998, TS = 100, rndFirst = False np.mean(results) = 0.8099999999999997
# 100%|█████████████████████████████████████████| 101/101 [00:13<00:00,  7.69it/s]
# K = 25, L = 0.3, TS = 100, rndFirst = False np.mean(results) = 0.7928712871287129
# 100%|█████████████████████████████████████████| 101/101 [00:09<00:00, 10.22it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.8820792079207923
# 100%|█████████████████████████████████████████| 101/101 [00:09<00:00, 10.53it/s]
# K = 25, L = 0.09999999999999999, TS = 100, rndFirst = False np.mean(results) = 0.8212871287128714
# 100%|█████████████████████████████████████████| 101/101 [00:09<00:00, 10.32it/s]
# K = 25, L = 0.19999999999999998, TS = 100, rndFirst = False np.mean(results) = 0.8040594059405939
# 100%|█████████████████████████████████████████| 101/101 [00:23<00:00,  4.33it/s]
# K = 25, L = 0.3, TS = 100, rndFirst = False np.mean(results) = 0.7918811881188119
# 100%|█████████████████████████████████████████| 101/101 [00:12<00:00,  8.11it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.9113861386138613
# 100%|█████████████████████████████████████████| 101/101 [00:11<00:00,  8.97it/s]
# K = 25, L = 0.09999999999999999, TS = 100, rndFirst = False np.mean(results) = 0.858019801980198
# 100%|█████████████████████████████████████████| 101/101 [00:08<00:00, 12.04it/s]
# K = 25, L = 0.19999999999999998, TS = 100, rndFirst = False np.mean(results) = 0.8446534653465346
# 100%|█████████████████████████████████████████| 101/101 [00:12<00:00,  7.85it/s]
# K = 25, L = 0.3, TS = 100, rndFirst = False np.mean(results) = 0.8324752475247525

# %%
res
# Out:
# {'GE_QE_AnnCURxCoItem_RecSys_Round10_7197.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.8829702970297029',
#  'GE_QE_AnnCURxKMeans_RecSys_Round10_7156.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.9028712871287127',
#  'GE_QE_AnnCURxRandom_RecSys_Round10_6743.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.8820792079207923',
#  'GE_QE_AnnCURxTop_RecSys_Round10_7623.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.9113861386138613'}

# %%
AnnCURxTop_RecSys : 0.9113861386138613 -> 0.9113861386138613
AnnCURxCoItem_RecSys : 0.8829702970297029 -> 0.8829702970297029
AnnCURxKMeans_RecSys : 0.9028712871287127 -> 0.9028712871287127
AnnCURxRandom_RecSys : 0.8820792079207923 -> 0.8820792079207923

# %% [markdown]
# # ZESHEL

# %%
DATASETS = ["yugioh", "pro_wrestling", "star_trek", "doctor_who", "military"]

# %%
del ctx

# %%
gc.collect()
# Out:
# 13

# %%
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100,
        key_size=50
    )

    print("LOADED")
    
    do(ctx, f"{dataset}_Key50")
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (0, 1070604160.0 -> 4473067008.0)
# updated det (3, 4473067008.0 -> 6631089664.0)
# updated det (4, 6631089664.0 -> 69104549888.0)
# updated det (7, 69104549888.0 -> 1087518670848.0)
# updated det (8, 1087518670848.0 -> 6136270422016.0)
# updated det (23, 6136270422016.0 -> 92915267272704.0)
# updated det (64, 92915267272704.0 -> 2.671569730849997e+16)
# Best det =  2.6715697e+16
# Current de =  2.6715697e+16
# 50 2310 1013
# LOADED
# /tmp/ipykernel_965688/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/50 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.4890909090909091 0.1677604 2310
# np.mean(results), mse, len(results) =  0.46759131293188555 0.17839523 1013
# ./GE_QE_AnnCURxCoItem_yugioh_Key50_4676.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.5116883116883116 0.15658054 2310
# np.mean(results), mse, len(results) =  0.47646594274432374 0.17567557 1013
# ./GE_QE_AnnCURxKMeans_yugioh_Key50_4765.npz
# np.mean(results), mse, len(results) =  0.19060173160173158 0.5339509 2310
# np.mean(results), mse, len(results) =  0.17184600197433364 0.583463 1013
# ./GE_QE_AnnCURxTop_yugioh_Key50_1718.npz
# np.mean(results), mse, len(results) =  0.3823809523809524 0.2344571 2310
# np.mean(results), mse, len(results) =  0.35992102665350445 0.23845425 1013
# ./GE_QE_AnnCURxRandom_yugioh_Key50_3599.npz
#
#
#
# DATASET =  pro_wrestling
# Loading file pro_wrestling/ment_to_ent_scores_n_m_392_n_e_10133_all_layers_False1000.pkl
# Loading file pro_wrestling/ment_to_ent_scores_n_m_500_n_e_10133_all_layers_False0.pkl
# Loading file pro_wrestling/ment_to_ent_scores_n_m_500_n_e_10133_all_layers_False500.pkl
# Loaded shape =  (1392, 10133)
# Shuffling... (seed = 42)
# updated det (1, 4.841407345916176e-21 -> 3.5873110644062884e-20)
# updated det (2, 3.5873110644062884e-20 -> 9.893018914768882e-18)
# Best det =  9.893019e-18
# Current de =  9.893019e-18
# 50 923 418
# LOADED
# /tmp/ipykernel_965688/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/50 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.5073131094257854 0.051342487 923
# np.mean(results), mse, len(results) =  0.4599282296650718 0.060922384 418
# ./GE_QE_AnnCURxCoItem_pro_wrestling_Key50_4599.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.5401733477789815 0.047523793 923
# np.mean(results), mse, len(results) =  0.457822966507177 0.07269988 418
# ./GE_QE_AnnCURxKMeans_pro_wrestling_Key50_4578.npz
# np.mean(results), mse, len(results) =  0.32398699891657634 0.08484664 923
# np.mean(results), mse, len(results) =  0.2674641148325359 0.10492295 418
# ./GE_QE_AnnCURxTop_pro_wrestling_Key50_2675.npz
# np.mean(results), mse, len(results) =  0.40925243770314196 0.06813641 923
# np.mean(results), mse, len(results) =  0.3641866028708134 0.07277191 418
# ./GE_QE_AnnCURxRandom_pro_wrestling_Key50_3642.npz
#
#
#
# DATASET =  star_trek
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_27_n_e_34430_all_layers_False4200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False0.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False4000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False600.pkl
# Loaded shape =  (4227, 34430)
# Shuffling... (seed = 42)
# updated det (0, 3.857743303828021e-29 -> 2.5609309256158758e-25)
# updated det (5, 2.5609309256158758e-25 -> 1.0526703302627315e-21)
# updated det (7, 1.0526703302627315e-21 -> 8.25326160861389e-21)
# updated det (34, 8.25326160861389e-21 -> 1.0576089620267782e-19)
# Best det =  1.05760896e-19
# Current de =  1.05760896e-19
# 50 2907 1269
# LOADED
# /tmp/ipykernel_965688/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/50 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.3035947712418301 0.034577847 2907
# np.mean(results), mse, len(results) =  0.28781717888100866 0.03929038 1269
# ./GE_QE_AnnCURxCoItem_star_trek_Key50_2878.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.30089783281733745 0.034295987 2907
# np.mean(results), mse, len(results) =  0.281591804570528 0.040041447 1269
# ./GE_QE_AnnCURxKMeans_star_trek_Key50_2816.npz
# np.mean(results), mse, len(results) =  0.11484692122463021 0.05505639 2907
# np.mean(results), mse, len(results) =  0.09764381402679274 0.06140218 1269
# ./GE_QE_AnnCURxTop_star_trek_Key50_0976.npz
# np.mean(results), mse, len(results) =  0.21029239766081873 0.043371186 2907
# np.mean(results), mse, len(results) =  0.1997084318360914 0.050314326 1269
# ./GE_QE_AnnCURxRandom_star_trek_Key50_1997.npz
#
#
#
# DATASET =  doctor_who
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3400.pkl
# Loaded shape =  (4000, 40281)
# Shuffling... (seed = 42)
# updated det (0, 3.096521238682978e-28 -> 6.068098321899648e-22)
# updated det (2, 6.068098321899648e-22 -> 8.576490712853047e-22)
# updated det (15, 8.576490712853047e-22 -> 7.655394364230028e-20)
# updated det (29, 7.655394364230028e-20 -> 4.090701778192178e-19)
# updated det (97, 4.090701778192178e-19 -> 5.483558124445719e-19)
# Best det =  5.483558e-19
# Current de =  5.483558e-19
# 50 2749 1200
# LOADED
# /tmp/ipykernel_965688/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/50 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.25746453255729357 0.031882875 2749
# np.mean(results), mse, len(results) =  0.23674166666666668 0.037577916 1200
# ./GE_QE_AnnCURxCoItem_doctor_who_Key50_2367.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.2543906875227356 0.031526588 2749
# np.mean(results), mse, len(results) =  0.2224 0.039588615 1200
# ./GE_QE_AnnCURxKMeans_doctor_who_Key50_2224.npz
# np.mean(results), mse, len(results) =  0.12200072753728629 0.04265844 2749
# np.mean(results), mse, len(results) =  0.10493333333333335 0.046505626 1200
# ./GE_QE_AnnCURxTop_doctor_who_Key50_1049.npz
# np.mean(results), mse, len(results) =  0.1589523463077483 0.038649622 2749
# np.mean(results), mse, len(results) =  0.1435666666666667 0.042760633 1200
# ./GE_QE_AnnCURxRandom_doctor_who_Key50_1436.npz
#
#
#
# DATASET =  military
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False2200.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0500.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0400.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1800.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False2000.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1600.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0600.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1200.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0900.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0200.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1000.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False2300.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1400.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1100.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1500.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0700.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0000.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0300.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0100.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0800.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1700.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1900.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1300.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False2100.pkl
# Loaded shape =  (2400, 104520)
# Shuffling... (seed = 42)
# updated det (0, 3.976604782060966e-41 -> 2.716871093796099e-39)
# updated det (1, 2.716871093796099e-39 -> 1.0321454415575588e-38)
# updated det (8, 1.0321454415575588e-38 -> 5.119265028305966e-38)
# updated det (9, 5.119265028305966e-38 -> 5.9026737818910757e-36)
# updated det (10, 5.9026737818910757e-36 -> 4.283146929381246e-34)
# Best det =  4.283147e-34
# Current de =  4.283147e-34
# 50 1629 720
# LOADED
# /tmp/ipykernel_965688/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/50 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.32493554327808466 0.007821261 1629
# np.mean(results), mse, len(results) =  0.29459722222222223 0.011325857 720
# ./GE_QE_AnnCURxCoItem_military_Key50_2946.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.33092081031307546 0.0076574874 1629
# np.mean(results), mse, len(results) =  0.28447222222222224 0.009860543 720
# ./GE_QE_AnnCURxKMeans_military_Key50_2845.npz
# np.mean(results), mse, len(results) =  0.19683855125844074 0.01133361 1629
# np.mean(results), mse, len(results) =  0.17355555555555557 0.0139393 720
# ./GE_QE_AnnCURxTop_military_Key50_1736.npz
# np.mean(results), mse, len(results) =  0.24073050951503988 0.009288687 1629
# np.mean(results), mse, len(results) =  0.22306944444444446 0.011516683 720
# ./GE_QE_AnnCURxRandom_military_Key50_2231.npz

# %%
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100,
        key_size=50
    )

    print("LOADED")
    
    do_RBE(ctx, f"{dataset}_Key50")
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (0, 1070604160.0 -> 4473067008.0)
# updated det (3, 4473067008.0 -> 6631089664.0)
# updated det (4, 6631089664.0 -> 69104549888.0)
# updated det (7, 69104549888.0 -> 1087518670848.0)
# updated det (8, 1087518670848.0 -> 6136270422016.0)
# updated det (23, 6136270422016.0 -> 92915267272704.0)
# updated det (64, 92915267272704.0 -> 2.671569730849997e+16)
# Best det =  2.6715697e+16
# Current de =  2.6715697e+16
# 50 2310 1013
# LOADED
# /tmp/ipykernel_965688/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# self.embed_users['train'].shape =  (2310, 100)
# self.embed_games.shape =  (10031, 50)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (50, 10031)
# self.core_users_embs.shape =  (50, 100)
# self.ge_users.shape =  (2310, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.0384 tf.Tensor(39.533638, shape=(), dtype=float32) 50
# slice = key, score = 0.0384
# np.mean(results), mse, len(results) =  0.04012121212121213 tf.Tensor(42.28699, shape=(), dtype=float32) 2310
# slice = train, score = 0.04012121212121213
# np.mean(results), mse, len(results) =  0.03675222112537019 tf.Tensor(42.036404, shape=(), dtype=float32) 1013
# slice = test, score = 0.03675222112537019
# np.mean(results), mse, len(results) =  0.03675222112537019 tf.Tensor(42.036404, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.0368.npz ...
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.545 tf.Tensor(85.60582, shape=(), dtype=float32) 50
# slice = key, score = 0.545
# np.mean(results), mse, len(results) =  0.566978354978355 tf.Tensor(80.9343, shape=(), dtype=float32) 2310
# slice = train, score = 0.566978354978355
# np.mean(results), mse, len(results) =  0.5352517275419546 tf.Tensor(81.21486, shape=(), dtype=float32) 1013
# slice = test, score = 0.5352517275419546
# np.mean(results), mse, len(results) =  0.5352517275419546 tf.Tensor(81.21486, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5353.npz ...
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5684 tf.Tensor(130.86649, shape=(), dtype=float32) 50
# slice = key, score = 0.5684
# np.mean(results), mse, len(results) =  0.5918138528138528 tf.Tensor(125.290375, shape=(), dtype=float32) 2310
# slice = train, score = 0.5918138528138528
# np.mean(results), mse, len(results) =  0.5537216189536032 tf.Tensor(125.681, shape=(), dtype=float32) 1013
# slice = test, score = 0.5537216189536032
# np.mean(results), mse, len(results) =  0.5537216189536032 tf.Tensor(125.681, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5537.npz ...
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.5651999999999999 tf.Tensor(189.61006, shape=(), dtype=float32) 50
# slice = key, score = 0.5651999999999999
# np.mean(results), mse, len(results) =  0.5997012987012986 tf.Tensor(180.94269, shape=(), dtype=float32) 2310
# slice = train, score = 0.5997012987012986
# np.mean(results), mse, len(results) =  0.5575518262586376 tf.Tensor(181.83174, shape=(), dtype=float32) 1013
# slice = test, score = 0.5575518262586376
# np.mean(results), mse, len(results) =  0.5575518262586376 tf.Tensor(181.83174, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5576.npz ...
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.5806 tf.Tensor(244.0216, shape=(), dtype=float32) 50
# slice = key, score = 0.5806
# np.mean(results), mse, len(results) =  0.6061774891774891 tf.Tensor(237.26451, shape=(), dtype=float32) 2310
# slice = train, score = 0.6061774891774891
# np.mean(results), mse, len(results) =  0.5610661401776901 tf.Tensor(237.90735, shape=(), dtype=float32) 1013
# slice = test, score = 0.5610661401776901
# np.mean(results), mse, len(results) =  0.5610661401776901 tf.Tensor(237.90735, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5611.npz ...
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.5848 tf.Tensor(317.495, shape=(), dtype=float32) 50
# slice = key, score = 0.5848
# np.mean(results), mse, len(results) =  0.611952380952381 tf.Tensor(307.18024, shape=(), dtype=float32) 2310
# slice = train, score = 0.611952380952381
# np.mean(results), mse, len(results) =  0.5659230009871669 tf.Tensor(306.915, shape=(), dtype=float32) 1013
# slice = test, score = 0.5659230009871669
# np.mean(results), mse, len(results) =  0.5659230009871669 tf.Tensor(306.915, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5659.npz ...
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.5864 tf.Tensor(399.52576, shape=(), dtype=float32) 50
# slice = key, score = 0.5864
# np.mean(results), mse, len(results) =  0.6128917748917749 tf.Tensor(387.59286, shape=(), dtype=float32) 2310
# slice = train, score = 0.6128917748917749
# np.mean(results), mse, len(results) =  0.5656762092793682 tf.Tensor(388.8342, shape=(), dtype=float32) 1013
# slice = test, score = 0.5656762092793682
# np.mean(results), mse, len(results) =  0.5656762092793682 tf.Tensor(388.8342, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5657.npz ...
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.5834000000000001 tf.Tensor(476.33914, shape=(), dtype=float32) 50
# slice = key, score = 0.5834000000000001
# np.mean(results), mse, len(results) =  0.616 tf.Tensor(462.8576, shape=(), dtype=float32) 2310
# slice = train, score = 0.616
# np.mean(results), mse, len(results) =  0.5669101678183612 tf.Tensor(463.7366, shape=(), dtype=float32) 1013
# slice = test, score = 0.5669101678183612
# np.mean(results), mse, len(results) =  0.5669101678183612 tf.Tensor(463.7366, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5669.npz ...
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.5904 tf.Tensor(559.84265, shape=(), dtype=float32) 50
# slice = key, score = 0.5904
# np.mean(results), mse, len(results) =  0.6181645021645021 tf.Tensor(543.8574, shape=(), dtype=float32) 2310
# slice = train, score = 0.6181645021645021
# np.mean(results), mse, len(results) =  0.5686969397828233 tf.Tensor(544.41846, shape=(), dtype=float32) 1013
# slice = test, score = 0.5686969397828233
# np.mean(results), mse, len(results) =  0.5686969397828233 tf.Tensor(544.41846, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5687.npz ...
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.5932 tf.Tensor(626.20996, shape=(), dtype=float32) 50
# slice = key, score = 0.5932
# np.mean(results), mse, len(results) =  0.6206666666666667 tf.Tensor(611.6155, shape=(), dtype=float32) 2310
# slice = train, score = 0.6206666666666667
# np.mean(results), mse, len(results) =  0.5692398815399803 tf.Tensor(611.555, shape=(), dtype=float32) 1013
# slice = test, score = 0.5692398815399803
# np.mean(results), mse, len(results) =  0.5692398815399803 tf.Tensor(611.555, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5692.npz ...
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.5938 tf.Tensor(711.1294, shape=(), dtype=float32) 50
# slice = key, score = 0.5938
# np.mean(results), mse, len(results) =  0.6241948051948052 tf.Tensor(697.4632, shape=(), dtype=float32) 2310
# slice = train, score = 0.6241948051948052
# np.mean(results), mse, len(results) =  0.5705034550839091 tf.Tensor(696.75775, shape=(), dtype=float32) 1013
# slice = test, score = 0.5705034550839091
# np.mean(results), mse, len(results) =  0.5705034550839091 tf.Tensor(696.75775, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5705.npz ...
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.5990000000000001 tf.Tensor(801.45807, shape=(), dtype=float32) 50
# slice = key, score = 0.5990000000000001
# np.mean(results), mse, len(results) =  0.6248701298701299 tf.Tensor(789.4938, shape=(), dtype=float32) 2310
# slice = train, score = 0.6248701298701299
# np.mean(results), mse, len(results) =  0.5717472852912143 tf.Tensor(789.1822, shape=(), dtype=float32) 1013
# slice = test, score = 0.5717472852912143
# np.mean(results), mse, len(results) =  0.5717472852912143 tf.Tensor(789.1822, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5717.npz ...
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.5962000000000001 tf.Tensor(907.0528, shape=(), dtype=float32) 50
# slice = key, score = 0.5962000000000001
# np.mean(results), mse, len(results) =  0.6257402597402597 tf.Tensor(887.49396, shape=(), dtype=float32) 2310
# slice = train, score = 0.6257402597402597
# np.mean(results), mse, len(results) =  0.5722309970384994 tf.Tensor(888.29047, shape=(), dtype=float32) 1013
# slice = test, score = 0.5722309970384994
# np.mean(results), mse, len(results) =  0.5722309970384994 tf.Tensor(888.29047, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5722.npz ...
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.6036 tf.Tensor(989.88354, shape=(), dtype=float32) 50
# slice = key, score = 0.6036
# np.mean(results), mse, len(results) =  0.6279480519480519 tf.Tensor(972.1143, shape=(), dtype=float32) 2310
# slice = train, score = 0.6279480519480519
# np.mean(results), mse, len(results) =  0.5737907206317868 tf.Tensor(970.0473, shape=(), dtype=float32) 1013
# slice = test, score = 0.5737907206317868
# np.mean(results), mse, len(results) =  0.5737907206317868 tf.Tensor(970.0473, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5738.npz ...
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.6053999999999999 tf.Tensor(1101.2938, shape=(), dtype=float32) 50
# slice = key, score = 0.6053999999999999
# np.mean(results), mse, len(results) =  0.6293766233766235 tf.Tensor(1085.7264, shape=(), dtype=float32) 2310
# slice = train, score = 0.6293766233766235
# np.mean(results), mse, len(results) =  0.5749555774925963 tf.Tensor(1085.0858, shape=(), dtype=float32) 1013
# slice = test, score = 0.5749555774925963
# np.mean(results), mse, len(results) =  0.5749555774925963 tf.Tensor(1085.0858, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.575.npz ...
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.6012000000000001 tf.Tensor(1221.1875, shape=(), dtype=float32) 50
# slice = key, score = 0.6012000000000001
# np.mean(results), mse, len(results) =  0.6301948051948052 tf.Tensor(1194.2065, shape=(), dtype=float32) 2310
# slice = train, score = 0.6301948051948052
# np.mean(results), mse, len(results) =  0.5739387956564659 tf.Tensor(1196.3445, shape=(), dtype=float32) 1013
# slice = test, score = 0.5739387956564659
# np.mean(results), mse, len(results) =  0.5739387956564659 tf.Tensor(1196.3445, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5739.npz ...
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.606 tf.Tensor(1298.7903, shape=(), dtype=float32) 50
# slice = key, score = 0.606
# np.mean(results), mse, len(results) =  0.6325800865800867 tf.Tensor(1278.9037, shape=(), dtype=float32) 2310
# slice = train, score = 0.6325800865800867
# np.mean(results), mse, len(results) =  0.5755478775913129 tf.Tensor(1279.8457, shape=(), dtype=float32) 1013
# slice = test, score = 0.5755478775913129
# np.mean(results), mse, len(results) =  0.5755478775913129 tf.Tensor(1279.8457, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5755.npz ...
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.6053999999999999 tf.Tensor(1387.5487, shape=(), dtype=float32) 50
# slice = key, score = 0.6053999999999999
# np.mean(results), mse, len(results) =  0.6316103896103896 tf.Tensor(1363.5548, shape=(), dtype=float32) 2310
# slice = train, score = 0.6316103896103896
# np.mean(results), mse, len(results) =  0.5752912142152024 tf.Tensor(1364.5133, shape=(), dtype=float32) 1013
# slice = test, score = 0.5752912142152024
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.6042000000000001 tf.Tensor(1491.4664, shape=(), dtype=float32) 50
# slice = key, score = 0.6042000000000001
# np.mean(results), mse, len(results) =  0.6323419913419913 tf.Tensor(1469.3115, shape=(), dtype=float32) 2310
# slice = train, score = 0.6323419913419913
# np.mean(results), mse, len(results) =  0.5753701875616979 tf.Tensor(1467.8121, shape=(), dtype=float32) 1013
# slice = test, score = 0.5753701875616979
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.6096 tf.Tensor(1611.7251, shape=(), dtype=float32) 50
# slice = key, score = 0.6096
# np.mean(results), mse, len(results) =  0.6372164502164503 tf.Tensor(1573.3439, shape=(), dtype=float32) 2310
# slice = train, score = 0.6372164502164503
# np.mean(results), mse, len(results) =  0.5782033563672261 tf.Tensor(1572.8856, shape=(), dtype=float32) 1013
# slice = test, score = 0.5782033563672261
# np.mean(results), mse, len(results) =  0.5782033563672261 tf.Tensor(1572.8856, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5782.npz ...
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.6078 tf.Tensor(1711.0422, shape=(), dtype=float32) 50
# slice = key, score = 0.6078
# np.mean(results), mse, len(results) =  0.6360519480519481 tf.Tensor(1680.005, shape=(), dtype=float32) 2310
# slice = train, score = 0.6360519480519481
# np.mean(results), mse, len(results) =  0.5791806515301087 tf.Tensor(1681.2163, shape=(), dtype=float32) 1013
# slice = test, score = 0.5791806515301087
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.6093999999999999 tf.Tensor(1838.9492, shape=(), dtype=float32) 50
# slice = key, score = 0.6093999999999999
# np.mean(results), mse, len(results) =  0.638900432900433 tf.Tensor(1801.5562, shape=(), dtype=float32) 2310
# slice = train, score = 0.638900432900433
# np.mean(results), mse, len(results) =  0.5773445212240869 tf.Tensor(1802.9586, shape=(), dtype=float32) 1013
# slice = test, score = 0.5773445212240869
# np.mean(results), mse, len(results) =  0.5773445212240869 tf.Tensor(1802.9586, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5773.npz ...
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.6086 tf.Tensor(1890.025, shape=(), dtype=float32) 50
# slice = key, score = 0.6086
# np.mean(results), mse, len(results) =  0.6382467532467532 tf.Tensor(1869.4061, shape=(), dtype=float32) 2310
# slice = train, score = 0.6382467532467532
# np.mean(results), mse, len(results) =  0.5778578479763079 tf.Tensor(1868.0731, shape=(), dtype=float32) 1013
# slice = test, score = 0.5778578479763079
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.6088 tf.Tensor(2003.0435, shape=(), dtype=float32) 50
# slice = key, score = 0.6088
# np.mean(results), mse, len(results) =  0.6388484848484849 tf.Tensor(1981.6919, shape=(), dtype=float32) 2310
# slice = train, score = 0.6388484848484849
# np.mean(results), mse, len(results) =  0.5776406712734452 tf.Tensor(1981.6901, shape=(), dtype=float32) 1013
# slice = test, score = 0.5776406712734452
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.6106 tf.Tensor(2106.8884, shape=(), dtype=float32) 50
# slice = key, score = 0.6106
# np.mean(results), mse, len(results) =  0.640948051948052 tf.Tensor(2071.8337, shape=(), dtype=float32) 2310
# slice = train, score = 0.640948051948052
# np.mean(results), mse, len(results) =  0.5780552813425469 tf.Tensor(2074.5068, shape=(), dtype=float32) 1013
# slice = test, score = 0.5780552813425469
# np.mean(results), mse, len(results) =  0.5780552813425469 tf.Tensor(2074.5068, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5781.npz ...
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.6078 tf.Tensor(2227.8657, shape=(), dtype=float32) 50
# slice = key, score = 0.6078
# np.mean(results), mse, len(results) =  0.641991341991342 tf.Tensor(2187.9956, shape=(), dtype=float32) 2310
# slice = train, score = 0.641991341991342
# np.mean(results), mse, len(results) =  0.5788943731490621 tf.Tensor(2184.5933, shape=(), dtype=float32) 1013
# slice = test, score = 0.5788943731490621
# np.mean(results), mse, len(results) =  0.5788943731490621 tf.Tensor(2184.5933, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5789.npz ...
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.6145999999999999 tf.Tensor(2338.6318, shape=(), dtype=float32) 50
# slice = key, score = 0.6145999999999999
# np.mean(results), mse, len(results) =  0.6419264069264069 tf.Tensor(2310.414, shape=(), dtype=float32) 2310
# slice = train, score = 0.6419264069264069
# np.mean(results), mse, len(results) =  0.5789634748272459 tf.Tensor(2305.6711, shape=(), dtype=float32) 1013
# slice = test, score = 0.5789634748272459
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.6082000000000001 tf.Tensor(2468.2231, shape=(), dtype=float32) 50
# slice = key, score = 0.6082000000000001
# np.mean(results), mse, len(results) =  0.643017316017316 tf.Tensor(2421.5564, shape=(), dtype=float32) 2310
# slice = train, score = 0.643017316017316
# np.mean(results), mse, len(results) =  0.5792991115498518 tf.Tensor(2417.5852, shape=(), dtype=float32) 1013
# slice = test, score = 0.5792991115498518
# np.mean(results), mse, len(results) =  0.5792991115498518 tf.Tensor(2417.5852, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5793.npz ...
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.6207999999999999 tf.Tensor(2550.3965, shape=(), dtype=float32) 50
# slice = key, score = 0.6207999999999999
# np.mean(results), mse, len(results) =  0.6449393939393939 tf.Tensor(2521.327, shape=(), dtype=float32) 2310
# slice = train, score = 0.6449393939393939
# np.mean(results), mse, len(results) =  0.5786870681145114 tf.Tensor(2522.3394, shape=(), dtype=float32) 1013
# slice = test, score = 0.5786870681145114
# np.mean(results), mse, len(results) =  0.5786870681145114 tf.Tensor(2522.3394, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5787.npz ...
#
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.6168 tf.Tensor(2645.0369, shape=(), dtype=float32) 50
# slice = key, score = 0.6168
# np.mean(results), mse, len(results) =  0.6419783549783551 tf.Tensor(2610.803, shape=(), dtype=float32) 2310
# slice = train, score = 0.6419783549783551
# np.mean(results), mse, len(results) =  0.5777295162882528 tf.Tensor(2611.815, shape=(), dtype=float32) 1013
# slice = test, score = 0.5777295162882528
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.6166 tf.Tensor(2730.9287, shape=(), dtype=float32) 50
# slice = key, score = 0.6166
# np.mean(results), mse, len(results) =  0.6444112554112554 tf.Tensor(2688.4226, shape=(), dtype=float32) 2310
# slice = train, score = 0.6444112554112554
# np.mean(results), mse, len(results) =  0.5802665350444225 tf.Tensor(2690.3857, shape=(), dtype=float32) 1013
# slice = test, score = 0.5802665350444225
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.6164 tf.Tensor(2861.1072, shape=(), dtype=float32) 50
# slice = key, score = 0.6164
# np.mean(results), mse, len(results) =  0.6452467532467533 tf.Tensor(2798.0833, shape=(), dtype=float32) 2310
# slice = train, score = 0.6452467532467533
# np.mean(results), mse, len(results) =  0.5800592300098716 tf.Tensor(2797.857, shape=(), dtype=float32) 1013
# slice = test, score = 0.5800592300098716
# np.mean(results), mse, len(results) =  0.5800592300098716 tf.Tensor(2797.857, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5801.npz ...
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.6148 tf.Tensor(2931.8154, shape=(), dtype=float32) 50
# slice = key, score = 0.6148
# np.mean(results), mse, len(results) =  0.6460606060606061 tf.Tensor(2886.885, shape=(), dtype=float32) 2310
# slice = train, score = 0.6460606060606061
# np.mean(results), mse, len(results) =  0.5809279368213228 tf.Tensor(2885.516, shape=(), dtype=float32) 1013
# slice = test, score = 0.5809279368213228
# np.mean(results), mse, len(results) =  0.5809279368213228 tf.Tensor(2885.516, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5809.npz ...
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.6174 tf.Tensor(3068.8523, shape=(), dtype=float32) 50
# slice = key, score = 0.6174
# np.mean(results), mse, len(results) =  0.648012987012987 tf.Tensor(3016.9067, shape=(), dtype=float32) 2310
# slice = train, score = 0.648012987012987
# np.mean(results), mse, len(results) =  0.5825962487660414 tf.Tensor(3014.0056, shape=(), dtype=float32) 1013
# slice = test, score = 0.5825962487660414
# np.mean(results), mse, len(results) =  0.5825962487660414 tf.Tensor(3014.0056, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5826.npz ...
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.6198 tf.Tensor(3133.7073, shape=(), dtype=float32) 50
# slice = key, score = 0.6198
# np.mean(results), mse, len(results) =  0.6472510822510823 tf.Tensor(3084.7002, shape=(), dtype=float32) 2310
# slice = train, score = 0.6472510822510823
# np.mean(results), mse, len(results) =  0.5809772951628825 tf.Tensor(3076.1125, shape=(), dtype=float32) 1013
# slice = test, score = 0.5809772951628825
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.6158 tf.Tensor(3286.1836, shape=(), dtype=float32) 50
# slice = key, score = 0.6158
# np.mean(results), mse, len(results) =  0.645978354978355 tf.Tensor(3231.478, shape=(), dtype=float32) 2310
# slice = train, score = 0.645978354978355
# np.mean(results), mse, len(results) =  0.5794274432379073 tf.Tensor(3233.0557, shape=(), dtype=float32) 1013
# slice = test, score = 0.5794274432379073
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.6238 tf.Tensor(3390.1875, shape=(), dtype=float32) 50
# slice = key, score = 0.6238
# np.mean(results), mse, len(results) =  0.6483116883116883 tf.Tensor(3315.417, shape=(), dtype=float32) 2310
# slice = train, score = 0.6483116883116883
# np.mean(results), mse, len(results) =  0.5809970384995063 tf.Tensor(3311.0405, shape=(), dtype=float32) 1013
# slice = test, score = 0.5809970384995063
# np.mean(results), mse, len(results) =  0.5809970384995063 tf.Tensor(3311.0405, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.581.npz ...
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.623 tf.Tensor(3501.1772, shape=(), dtype=float32) 50
# slice = key, score = 0.623
# np.mean(results), mse, len(results) =  0.6481341991341991 tf.Tensor(3433.2083, shape=(), dtype=float32) 2310
# slice = train, score = 0.6481341991341991
# np.mean(results), mse, len(results) =  0.5803652517275419 tf.Tensor(3424.7935, shape=(), dtype=float32) 1013
# slice = test, score = 0.5803652517275419
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.6228000000000001 tf.Tensor(3552.5278, shape=(), dtype=float32) 50
# slice = key, score = 0.6228000000000001
# np.mean(results), mse, len(results) =  0.6487056277056277 tf.Tensor(3501.37, shape=(), dtype=float32) 2310
# slice = train, score = 0.6487056277056277
# np.mean(results), mse, len(results) =  0.5807305034550839 tf.Tensor(3491.22, shape=(), dtype=float32) 1013
# slice = test, score = 0.5807305034550839
# np.mean(results), mse, len(results) =  0.5807305034550839 tf.Tensor(3491.22, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5807.npz ...
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.6194 tf.Tensor(3691.8032, shape=(), dtype=float32) 50
# slice = key, score = 0.6194
# np.mean(results), mse, len(results) =  0.6494978354978356 tf.Tensor(3628.195, shape=(), dtype=float32) 2310
# slice = train, score = 0.6494978354978356
# np.mean(results), mse, len(results) =  0.5800296150049358 tf.Tensor(3621.4197, shape=(), dtype=float32) 1013
# slice = test, score = 0.5800296150049358
# np.mean(results), mse, len(results) =  0.5800296150049358 tf.Tensor(3621.4197, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.58.npz ...
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.622 tf.Tensor(3759.792, shape=(), dtype=float32) 50
# slice = key, score = 0.622
# np.mean(results), mse, len(results) =  0.6518008658008657 tf.Tensor(3695.1091, shape=(), dtype=float32) 2310
# slice = train, score = 0.6518008658008657
# np.mean(results), mse, len(results) =  0.5818163869693979 tf.Tensor(3684.3015, shape=(), dtype=float32) 1013
# slice = test, score = 0.5818163869693979
# np.mean(results), mse, len(results) =  0.5818163869693979 tf.Tensor(3684.3015, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5818.npz ...
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.6202000000000001 tf.Tensor(3828.5679, shape=(), dtype=float32) 50
# slice = key, score = 0.6202000000000001
# np.mean(results), mse, len(results) =  0.6515974025974026 tf.Tensor(3780.7593, shape=(), dtype=float32) 2310
# slice = train, score = 0.6515974025974026
# np.mean(results), mse, len(results) =  0.5818953603158934 tf.Tensor(3772.8162, shape=(), dtype=float32) 1013
# slice = test, score = 0.5818953603158934
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.6268 tf.Tensor(3948.811, shape=(), dtype=float32) 50
# slice = key, score = 0.6268
# np.mean(results), mse, len(results) =  0.6507186147186147 tf.Tensor(3915.7004, shape=(), dtype=float32) 2310
# slice = train, score = 0.6507186147186147
# np.mean(results), mse, len(results) =  0.5829812438302073 tf.Tensor(3908.134, shape=(), dtype=float32) 1013
# slice = test, score = 0.5829812438302073
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.6282 tf.Tensor(4057.5608, shape=(), dtype=float32) 50
# slice = key, score = 0.6282
# np.mean(results), mse, len(results) =  0.6524458874458875 tf.Tensor(4010.3916, shape=(), dtype=float32) 2310
# slice = train, score = 0.6524458874458875
# np.mean(results), mse, len(results) =  0.582497532082922 tf.Tensor(4000.5845, shape=(), dtype=float32) 1013
# slice = test, score = 0.582497532082922
# np.mean(results), mse, len(results) =  0.582497532082922 tf.Tensor(4000.5845, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5825.npz ...
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.626 tf.Tensor(4156.766, shape=(), dtype=float32) 50
# slice = key, score = 0.626
# np.mean(results), mse, len(results) =  0.6512164502164501 tf.Tensor(4094.5781, shape=(), dtype=float32) 2310
# slice = train, score = 0.6512164502164501
# np.mean(results), mse, len(results) =  0.5822803553800594 tf.Tensor(4085.6401, shape=(), dtype=float32) 1013
# slice = test, score = 0.5822803553800594
#
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.6198 tf.Tensor(4248.2124, shape=(), dtype=float32) 50
# slice = key, score = 0.6198
# np.mean(results), mse, len(results) =  0.6522424242424243 tf.Tensor(4193.3237, shape=(), dtype=float32) 2310
# slice = train, score = 0.6522424242424243
# np.mean(results), mse, len(results) =  0.5824580454096742 tf.Tensor(4191.07, shape=(), dtype=float32) 1013
# slice = test, score = 0.5824580454096742
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.6215999999999999 tf.Tensor(4346.4893, shape=(), dtype=float32) 50
# slice = key, score = 0.6215999999999999
# np.mean(results), mse, len(results) =  0.6528528138528138 tf.Tensor(4326.7695, shape=(), dtype=float32) 2310
# slice = train, score = 0.6528528138528138
# np.mean(results), mse, len(results) =  0.5812635735439289 tf.Tensor(4315.0156, shape=(), dtype=float32) 1013
# slice = test, score = 0.5812635735439289
# np.mean(results), mse, len(results) =  0.5812635735439289 tf.Tensor(4315.0156, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5813.npz ...
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.6231999999999999 tf.Tensor(4479.878, shape=(), dtype=float32) 50
# slice = key, score = 0.6231999999999999
# np.mean(results), mse, len(results) =  0.6538874458874459 tf.Tensor(4429.2886, shape=(), dtype=float32) 2310
# slice = train, score = 0.6538874458874459
# np.mean(results), mse, len(results) =  0.5813820335636724 tf.Tensor(4407.59, shape=(), dtype=float32) 1013
# slice = test, score = 0.5813820335636724
# np.mean(results), mse, len(results) =  0.5813820335636724 tf.Tensor(4407.59, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5814.npz ...
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.6265999999999999 tf.Tensor(4593.9995, shape=(), dtype=float32) 50
# slice = key, score = 0.6265999999999999
# np.mean(results), mse, len(results) =  0.6550909090909091 tf.Tensor(4549.8047, shape=(), dtype=float32) 2310
# slice = train, score = 0.6550909090909091
# np.mean(results), mse, len(results) =  0.5830799605133267 tf.Tensor(4529.4707, shape=(), dtype=float32) 1013
# slice = test, score = 0.5830799605133267
# np.mean(results), mse, len(results) =  0.5830799605133267 tf.Tensor(4529.4707, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5831.npz ...
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.623 tf.Tensor(4703.1636, shape=(), dtype=float32) 50
# slice = key, score = 0.623
# np.mean(results), mse, len(results) =  0.6531168831168831 tf.Tensor(4642.2104, shape=(), dtype=float32) 2310
# slice = train, score = 0.6531168831168831
# np.mean(results), mse, len(results) =  0.5817867719644619 tf.Tensor(4628.219, shape=(), dtype=float32) 1013
# slice = test, score = 0.5817867719644619
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.6262 tf.Tensor(4780.767, shape=(), dtype=float32) 50
# slice = key, score = 0.6262
# np.mean(results), mse, len(results) =  0.6532554112554112 tf.Tensor(4729.5986, shape=(), dtype=float32) 2310
# slice = train, score = 0.6532554112554112
# np.mean(results), mse, len(results) =  0.5806910167818361 tf.Tensor(4716.5977, shape=(), dtype=float32) 1013
# slice = test, score = 0.5806910167818361
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.6264 tf.Tensor(4839.454, shape=(), dtype=float32) 50
# slice = key, score = 0.6264
# np.mean(results), mse, len(results) =  0.6557402597402597 tf.Tensor(4796.1465, shape=(), dtype=float32) 2310
# slice = train, score = 0.6557402597402597
# np.mean(results), mse, len(results) =  0.5836327739387956 tf.Tensor(4785.3545, shape=(), dtype=float32) 1013
# slice = test, score = 0.5836327739387956
# np.mean(results), mse, len(results) =  0.5836327739387956 tf.Tensor(4785.3545, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5836.npz ...
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.633 tf.Tensor(4963.991, shape=(), dtype=float32) 50
# slice = key, score = 0.633
# np.mean(results), mse, len(results) =  0.6547792207792208 tf.Tensor(4908.593, shape=(), dtype=float32) 2310
# slice = train, score = 0.6547792207792208
# np.mean(results), mse, len(results) =  0.5822112537018757 tf.Tensor(4891.3433, shape=(), dtype=float32) 1013
# slice = test, score = 0.5822112537018757
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.6284 tf.Tensor(5091.24, shape=(), dtype=float32) 50
# slice = key, score = 0.6284
# np.mean(results), mse, len(results) =  0.6534935064935065 tf.Tensor(5040.586, shape=(), dtype=float32) 2310
# slice = train, score = 0.6534935064935065
# np.mean(results), mse, len(results) =  0.5809674234945705 tf.Tensor(5027.754, shape=(), dtype=float32) 1013
# slice = test, score = 0.5809674234945705
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.6247999999999999 tf.Tensor(5151.4395, shape=(), dtype=float32) 50
# slice = key, score = 0.6247999999999999
# np.mean(results), mse, len(results) =  0.6556103896103896 tf.Tensor(5074.394, shape=(), dtype=float32) 2310
# slice = train, score = 0.6556103896103896
# np.mean(results), mse, len(results) =  0.5821322803553801 tf.Tensor(5062.7144, shape=(), dtype=float32) 1013
# slice = test, score = 0.5821322803553801
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.625 tf.Tensor(5281.825, shape=(), dtype=float32) 50
# slice = key, score = 0.625
# np.mean(results), mse, len(results) =  0.6555497835497837 tf.Tensor(5219.281, shape=(), dtype=float32) 2310
# slice = train, score = 0.6555497835497837
# np.mean(results), mse, len(results) =  0.5816584402764068 tf.Tensor(5206.154, shape=(), dtype=float32) 1013
# slice = test, score = 0.5816584402764068
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6259999999999999 tf.Tensor(5375.685, shape=(), dtype=float32) 50
# slice = key, score = 0.6259999999999999
# np.mean(results), mse, len(results) =  0.6568051948051948 tf.Tensor(5294.0728, shape=(), dtype=float32) 2310
# slice = train, score = 0.6568051948051948
# np.mean(results), mse, len(results) =  0.5839190523198421 tf.Tensor(5270.524, shape=(), dtype=float32) 1013
# slice = test, score = 0.5839190523198421
# np.mean(results), mse, len(results) =  0.5839190523198421 tf.Tensor(5270.524, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5839.npz ...
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.6296 tf.Tensor(5435.6113, shape=(), dtype=float32) 50
# slice = key, score = 0.6296
# np.mean(results), mse, len(results) =  0.6566277056277056 tf.Tensor(5382.383, shape=(), dtype=float32) 2310
# slice = train, score = 0.6566277056277056
# np.mean(results), mse, len(results) =  0.5836327739387956 tf.Tensor(5365.3003, shape=(), dtype=float32) 1013
# slice = test, score = 0.5836327739387956
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.6342 tf.Tensor(5575.0493, shape=(), dtype=float32) 50
# slice = key, score = 0.6342
# np.mean(results), mse, len(results) =  0.6581774891774891 tf.Tensor(5486.1167, shape=(), dtype=float32) 2310
# slice = train, score = 0.6581774891774891
# np.mean(results), mse, len(results) =  0.583928923988154 tf.Tensor(5469.589, shape=(), dtype=float32) 1013
# slice = test, score = 0.583928923988154
# np.mean(results), mse, len(results) =  0.583928923988154 tf.Tensor(5469.589, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5839.npz ...
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6275999999999999 tf.Tensor(5678.107, shape=(), dtype=float32) 50
# slice = key, score = 0.6275999999999999
# np.mean(results), mse, len(results) =  0.6558008658008657 tf.Tensor(5604.1313, shape=(), dtype=float32) 2310
# slice = train, score = 0.6558008658008657
# np.mean(results), mse, len(results) =  0.5815399802566635 tf.Tensor(5589.256, shape=(), dtype=float32) 1013
# slice = test, score = 0.5815399802566635
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6322000000000001 tf.Tensor(5791.0557, shape=(), dtype=float32) 50
# slice = key, score = 0.6322000000000001
# np.mean(results), mse, len(results) =  0.656883116883117 tf.Tensor(5693.637, shape=(), dtype=float32) 2310
# slice = train, score = 0.656883116883117
# np.mean(results), mse, len(results) =  0.5831391905231984 tf.Tensor(5678.7837, shape=(), dtype=float32) 1013
# slice = test, score = 0.5831391905231984
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.6302 tf.Tensor(5907.458, shape=(), dtype=float32) 50
# slice = key, score = 0.6302
# np.mean(results), mse, len(results) =  0.6570476190476191 tf.Tensor(5829.387, shape=(), dtype=float32) 2310
# slice = train, score = 0.6570476190476191
# np.mean(results), mse, len(results) =  0.5820138203356368 tf.Tensor(5813.9326, shape=(), dtype=float32) 1013
# slice = test, score = 0.5820138203356368
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.6271999999999999 tf.Tensor(5941.928, shape=(), dtype=float32) 50
# slice = key, score = 0.6271999999999999
# np.mean(results), mse, len(results) =  0.6591341991341991 tf.Tensor(5867.0586, shape=(), dtype=float32) 2310
# slice = train, score = 0.6591341991341991
# np.mean(results), mse, len(results) =  0.5831589338598223 tf.Tensor(5847.2217, shape=(), dtype=float32) 1013
# slice = test, score = 0.5831589338598223
# np.mean(results), mse, len(results) =  0.5831589338598223 tf.Tensor(5847.2217, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5832.npz ...
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.6286 tf.Tensor(6074.69, shape=(), dtype=float32) 50
# slice = key, score = 0.6286
# np.mean(results), mse, len(results) =  0.6612380952380953 tf.Tensor(5985.423, shape=(), dtype=float32) 2310
# slice = train, score = 0.6612380952380953
# np.mean(results), mse, len(results) =  0.5847877591312933 tf.Tensor(5964.501, shape=(), dtype=float32) 1013
# slice = test, score = 0.5847877591312933
# np.mean(results), mse, len(results) =  0.5847877591312933 tf.Tensor(5964.501, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5848.npz ...
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.638 tf.Tensor(6260.196, shape=(), dtype=float32) 50
# slice = key, score = 0.638
# np.mean(results), mse, len(results) =  0.6585627705627706 tf.Tensor(6152.349, shape=(), dtype=float32) 2310
# slice = train, score = 0.6585627705627706
# np.mean(results), mse, len(results) =  0.5822507403751234 tf.Tensor(6133.932, shape=(), dtype=float32) 1013
# slice = test, score = 0.5822507403751234
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.632 tf.Tensor(6303.9185, shape=(), dtype=float32) 50
# slice = key, score = 0.632
# np.mean(results), mse, len(results) =  0.6602467532467533 tf.Tensor(6209.3726, shape=(), dtype=float32) 2310
# slice = train, score = 0.6602467532467533
# np.mean(results), mse, len(results) =  0.5835143139190524 tf.Tensor(6196.883, shape=(), dtype=float32) 1013
# slice = test, score = 0.5835143139190524
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.6272 tf.Tensor(6412.258, shape=(), dtype=float32) 50
# slice = key, score = 0.6272
# np.mean(results), mse, len(results) =  0.659965367965368 tf.Tensor(6303.7446, shape=(), dtype=float32) 2310
# slice = train, score = 0.659965367965368
# np.mean(results), mse, len(results) =  0.5834254689042448 tf.Tensor(6295.421, shape=(), dtype=float32) 1013
# slice = test, score = 0.5834254689042448
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.63 tf.Tensor(6490.6533, shape=(), dtype=float32) 50
# slice = key, score = 0.63
# np.mean(results), mse, len(results) =  0.6607229437229437 tf.Tensor(6432.9297, shape=(), dtype=float32) 2310
# slice = train, score = 0.6607229437229437
# np.mean(results), mse, len(results) =  0.5842349457058243 tf.Tensor(6410.9224, shape=(), dtype=float32) 1013
# slice = test, score = 0.5842349457058243
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.6314000000000001 tf.Tensor(6542.501, shape=(), dtype=float32) 50
# slice = key, score = 0.6314000000000001
# np.mean(results), mse, len(results) =  0.6611385281385281 tf.Tensor(6450.4814, shape=(), dtype=float32) 2310
# slice = train, score = 0.6611385281385281
# np.mean(results), mse, len(results) =  0.5834846989141165 tf.Tensor(6438.7817, shape=(), dtype=float32) 1013
# slice = test, score = 0.5834846989141165
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.6277999999999999 tf.Tensor(6676.4263, shape=(), dtype=float32) 50
# slice = key, score = 0.6277999999999999
# np.mean(results), mse, len(results) =  0.6596060606060606 tf.Tensor(6614.175, shape=(), dtype=float32) 2310
# slice = train, score = 0.6596060606060606
# np.mean(results), mse, len(results) =  0.5837314906219152 tf.Tensor(6600.9707, shape=(), dtype=float32) 1013
# slice = test, score = 0.5837314906219152
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.6322000000000001 tf.Tensor(6816.8037, shape=(), dtype=float32) 50
# slice = key, score = 0.6322000000000001
# np.mean(results), mse, len(results) =  0.6602424242424242 tf.Tensor(6713.6406, shape=(), dtype=float32) 2310
# slice = train, score = 0.6602424242424242
# np.mean(results), mse, len(results) =  0.5841757156959526 tf.Tensor(6697.798, shape=(), dtype=float32) 1013
# slice = test, score = 0.5841757156959526
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6332 tf.Tensor(6875.753, shape=(), dtype=float32) 50
# slice = key, score = 0.6332
# np.mean(results), mse, len(results) =  0.6603982683982684 tf.Tensor(6820.86, shape=(), dtype=float32) 2310
# slice = train, score = 0.6603982683982684
# np.mean(results), mse, len(results) =  0.5839782823297137 tf.Tensor(6813.864, shape=(), dtype=float32) 1013
# slice = test, score = 0.5839782823297137
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.6358 tf.Tensor(6999.081, shape=(), dtype=float32) 50
# slice = key, score = 0.6358
# np.mean(results), mse, len(results) =  0.6626666666666666 tf.Tensor(6900.365, shape=(), dtype=float32) 2310
# slice = train, score = 0.6626666666666666
# np.mean(results), mse, len(results) =  0.5842250740375122 tf.Tensor(6879.004, shape=(), dtype=float32) 1013
# slice = test, score = 0.5842250740375122
# np.mean(results), mse, len(results) =  0.5842250740375122 tf.Tensor(6879.004, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5842.npz ...
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.634 tf.Tensor(7121.951, shape=(), dtype=float32) 50
# slice = key, score = 0.634
# np.mean(results), mse, len(results) =  0.6633463203463204 tf.Tensor(6999.2656, shape=(), dtype=float32) 2310
# slice = train, score = 0.6633463203463204
# np.mean(results), mse, len(results) =  0.5848371174728529 tf.Tensor(6985.106, shape=(), dtype=float32) 1013
# slice = test, score = 0.5848371174728529
# np.mean(results), mse, len(results) =  0.5848371174728529 tf.Tensor(6985.106, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5848.npz ...
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.633 tf.Tensor(7248.6606, shape=(), dtype=float32) 50
# slice = key, score = 0.633
# np.mean(results), mse, len(results) =  0.6621731601731602 tf.Tensor(7128.3926, shape=(), dtype=float32) 2310
# slice = train, score = 0.6621731601731602
# np.mean(results), mse, len(results) =  0.5842546890424481 tf.Tensor(7097.621, shape=(), dtype=float32) 1013
# slice = test, score = 0.5842546890424481
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.6348 tf.Tensor(7340.605, shape=(), dtype=float32) 50
# slice = key, score = 0.6348
# np.mean(results), mse, len(results) =  0.6615974025974026 tf.Tensor(7246.431, shape=(), dtype=float32) 2310
# slice = train, score = 0.6615974025974026
# np.mean(results), mse, len(results) =  0.5834846989141165 tf.Tensor(7219.6987, shape=(), dtype=float32) 1013
# slice = test, score = 0.5834846989141165
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6272 tf.Tensor(7455.7915, shape=(), dtype=float32) 50
# slice = key, score = 0.6272
# np.mean(results), mse, len(results) =  0.6618225108225108 tf.Tensor(7334.147, shape=(), dtype=float32) 2310
# slice = train, score = 0.6618225108225108
# np.mean(results), mse, len(results) =  0.5827739387956565 tf.Tensor(7304.566, shape=(), dtype=float32) 1013
# slice = test, score = 0.5827739387956565
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6364 tf.Tensor(7530.7417, shape=(), dtype=float32) 50
# slice = key, score = 0.6364
# np.mean(results), mse, len(results) =  0.6633852813852814 tf.Tensor(7443.759, shape=(), dtype=float32) 2310
# slice = train, score = 0.6633852813852814
# np.mean(results), mse, len(results) =  0.5845804540967424 tf.Tensor(7416.59, shape=(), dtype=float32) 1013
# slice = test, score = 0.5845804540967424
# np.mean(results), mse, len(results) =  0.5845804540967424 tf.Tensor(7416.59, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5846.npz ...
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6339999999999999 tf.Tensor(7661.1777, shape=(), dtype=float32) 50
# slice = key, score = 0.6339999999999999
# np.mean(results), mse, len(results) =  0.660891774891775 tf.Tensor(7504.2705, shape=(), dtype=float32) 2310
# slice = train, score = 0.660891774891775
# np.mean(results), mse, len(results) =  0.5832971372161897 tf.Tensor(7475.919, shape=(), dtype=float32) 1013
# slice = test, score = 0.5832971372161897
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6352 tf.Tensor(7680.404, shape=(), dtype=float32) 50
# slice = key, score = 0.6352
# np.mean(results), mse, len(results) =  0.6640259740259741 tf.Tensor(7560.909, shape=(), dtype=float32) 2310
# slice = train, score = 0.6640259740259741
# np.mean(results), mse, len(results) =  0.5838993089832182 tf.Tensor(7542.32, shape=(), dtype=float32) 1013
# slice = test, score = 0.5838993089832182
# np.mean(results), mse, len(results) =  0.5838993089832182 tf.Tensor(7542.32, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5839.npz ...
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.6328 tf.Tensor(7716.1807, shape=(), dtype=float32) 50
# slice = key, score = 0.6328
# np.mean(results), mse, len(results) =  0.6643506493506494 tf.Tensor(7613.66, shape=(), dtype=float32) 2310
# slice = train, score = 0.6643506493506494
# np.mean(results), mse, len(results) =  0.5847976307996051 tf.Tensor(7593.2046, shape=(), dtype=float32) 1013
# slice = test, score = 0.5847976307996051
# np.mean(results), mse, len(results) =  0.5847976307996051 tf.Tensor(7593.2046, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5848.npz ...
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.6318 tf.Tensor(7929.831, shape=(), dtype=float32) 50
# slice = key, score = 0.6318
# np.mean(results), mse, len(results) =  0.6632597402597402 tf.Tensor(7779.5396, shape=(), dtype=float32) 2310
# slice = train, score = 0.6632597402597402
# np.mean(results), mse, len(results) =  0.5849358341559723 tf.Tensor(7772.3486, shape=(), dtype=float32) 1013
# slice = test, score = 0.5849358341559723
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.6358 tf.Tensor(8023.0864, shape=(), dtype=float32) 50
# slice = key, score = 0.6358
# np.mean(results), mse, len(results) =  0.664077922077922 tf.Tensor(7885.527, shape=(), dtype=float32) 2310
# slice = train, score = 0.664077922077922
# np.mean(results), mse, len(results) =  0.5831391905231984 tf.Tensor(7878.5156, shape=(), dtype=float32) 1013
# slice = test, score = 0.5831391905231984
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.6386000000000001 tf.Tensor(8101.171, shape=(), dtype=float32) 50
# slice = key, score = 0.6386000000000001
# np.mean(results), mse, len(results) =  0.6658354978354978 tf.Tensor(7950.2695, shape=(), dtype=float32) 2310
# slice = train, score = 0.6658354978354978
# np.mean(results), mse, len(results) =  0.5846791707798618 tf.Tensor(7938.2466, shape=(), dtype=float32) 1013
# slice = test, score = 0.5846791707798618
# np.mean(results), mse, len(results) =  0.5846791707798618 tf.Tensor(7938.2466, shape=(), dtype=float32) 1013
# Saving ./GE_QE_RBExCoItem_yugioh_Key50_0.5847.npz ...
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.633 tf.Tensor(8213.882, shape=(), dtype=float32) 50
# slice = key, score = 0.633
# np.mean(results), mse, len(results) =  0.6649783549783549 tf.Tensor(8046.8345, shape=(), dtype=float32) 2310
# slice = train, score = 0.6649783549783549
# np.mean(results), mse, len(results) =  0.5856071076011846 tf.Tensor(8030.206, shape=(), dtype=float32) 1013
# slice = test, score = 0.5856071076011846
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.635 tf.Tensor(8248.212, shape=(), dtype=float32) 50
# slice = key, score = 0.635
# np.mean(results), mse, len(results) =  0.6649134199134198 tf.Tensor(8105.286, shape=(), dtype=float32) 2310
# slice = train, score = 0.6649134199134198
# np.mean(results), mse, len(results) =  0.5843139190523199 tf.Tensor(8087.9785, shape=(), dtype=float32) 1013
# slice = test, score = 0.5843139190523199
#
# === Iteration 86000 ===
# ...
# slice = train, score = 0.63931744312026
# np.mean(results), mse, len(results) =  0.463732057416268 tf.Tensor(3602.0645, shape=(), dtype=float32) 418
# slice = test, score = 0.463732057416268
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.5898 tf.Tensor(3771.3618, shape=(), dtype=float32) 50
# slice = key, score = 0.5898
# np.mean(results), mse, len(results) =  0.6408125677139762 tf.Tensor(3624.6199, shape=(), dtype=float32) 923
# slice = train, score = 0.6408125677139762
# np.mean(results), mse, len(results) =  0.46688995215311 tf.Tensor(3675.4045, shape=(), dtype=float32) 418
# slice = test, score = 0.46688995215311
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.596 tf.Tensor(3706.506, shape=(), dtype=float32) 50
# slice = key, score = 0.596
# np.mean(results), mse, len(results) =  0.6430010834236186 tf.Tensor(3632.5076, shape=(), dtype=float32) 923
# slice = train, score = 0.6430010834236186
# np.mean(results), mse, len(results) =  0.4668181818181818 tf.Tensor(3727.8782, shape=(), dtype=float32) 418
# slice = test, score = 0.4668181818181818
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.5916000000000001 tf.Tensor(3909.5789, shape=(), dtype=float32) 50
# slice = key, score = 0.5916000000000001
# np.mean(results), mse, len(results) =  0.6425027085590466 tf.Tensor(3763.3303, shape=(), dtype=float32) 923
# slice = train, score = 0.6425027085590466
# np.mean(results), mse, len(results) =  0.46710526315789475 tf.Tensor(3838.7478, shape=(), dtype=float32) 418
# slice = test, score = 0.46710526315789475
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.599 tf.Tensor(3854.119, shape=(), dtype=float32) 50
# slice = key, score = 0.599
# np.mean(results), mse, len(results) =  0.6449945828819069 tf.Tensor(3764.0916, shape=(), dtype=float32) 923
# slice = train, score = 0.6449945828819069
# np.mean(results), mse, len(results) =  0.46894736842105267 tf.Tensor(3826.9492, shape=(), dtype=float32) 418
# slice = test, score = 0.46894736842105267
# np.mean(results), mse, len(results) =  0.46894736842105267 tf.Tensor(3826.9492, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExKMeans_pro_wrestling_Key50_0.4689.npz ...
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.5919999999999999 tf.Tensor(4070.69, shape=(), dtype=float32) 50
# slice = key, score = 0.5919999999999999
# np.mean(results), mse, len(results) =  0.6431744312026002 tf.Tensor(3955.5364, shape=(), dtype=float32) 923
# slice = train, score = 0.6431744312026002
# np.mean(results), mse, len(results) =  0.46624401913875596 tf.Tensor(4021.3262, shape=(), dtype=float32) 418
# slice = test, score = 0.46624401913875596
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.5938 tf.Tensor(4056.796, shape=(), dtype=float32) 50
# slice = key, score = 0.5938
# np.mean(results), mse, len(results) =  0.6448320693391116 tf.Tensor(3972.1572, shape=(), dtype=float32) 923
# slice = train, score = 0.6448320693391116
# np.mean(results), mse, len(results) =  0.4677751196172249 tf.Tensor(4026.924, shape=(), dtype=float32) 418
# slice = test, score = 0.4677751196172249
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.5880000000000001 tf.Tensor(4170.887, shape=(), dtype=float32) 50
# slice = key, score = 0.5880000000000001
# np.mean(results), mse, len(results) =  0.6427843986998916 tf.Tensor(4081.9, shape=(), dtype=float32) 923
# slice = train, score = 0.6427843986998916
# np.mean(results), mse, len(results) =  0.46626794258373205 tf.Tensor(4149.3267, shape=(), dtype=float32) 418
# slice = test, score = 0.46626794258373205
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.5918 tf.Tensor(4464.747, shape=(), dtype=float32) 50
# slice = key, score = 0.5918
# np.mean(results), mse, len(results) =  0.641462621885157 tf.Tensor(4275.147, shape=(), dtype=float32) 923
# slice = train, score = 0.641462621885157
# np.mean(results), mse, len(results) =  0.46514354066985647 tf.Tensor(4342.0903, shape=(), dtype=float32) 418
# slice = test, score = 0.46514354066985647
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.5948 tf.Tensor(4483.2446, shape=(), dtype=float32) 50
# slice = key, score = 0.5948
# np.mean(results), mse, len(results) =  0.6500325027085591 tf.Tensor(4278.294, shape=(), dtype=float32) 923
# slice = train, score = 0.6500325027085591
# np.mean(results), mse, len(results) =  0.46641148325358844 tf.Tensor(4351.0303, shape=(), dtype=float32) 418
# slice = test, score = 0.46641148325358844
# np.mean(results), mse, len(results) =  0.46641148325358844 tf.Tensor(4351.0303, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExKMeans_pro_wrestling_Key50_0.4664.npz ...
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.5968 tf.Tensor(4605.063, shape=(), dtype=float32) 50
# slice = key, score = 0.5968
# np.mean(results), mse, len(results) =  0.6469989165763814 tf.Tensor(4464.1094, shape=(), dtype=float32) 923
# slice = train, score = 0.6469989165763814
# np.mean(results), mse, len(results) =  0.4663397129186603 tf.Tensor(4529.991, shape=(), dtype=float32) 418
# slice = test, score = 0.4663397129186603
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.6000000000000001 tf.Tensor(4569.763, shape=(), dtype=float32) 50
# slice = key, score = 0.6000000000000001
# np.mean(results), mse, len(results) =  0.6496641386782233 tf.Tensor(4391.794, shape=(), dtype=float32) 923
# slice = train, score = 0.6496641386782233
# np.mean(results), mse, len(results) =  0.46667464114832535 tf.Tensor(4463.2627, shape=(), dtype=float32) 418
# slice = test, score = 0.46667464114832535
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.591 tf.Tensor(4828.8574, shape=(), dtype=float32) 50
# slice = key, score = 0.591
# np.mean(results), mse, len(results) =  0.6456879739978332 tf.Tensor(4583.8345, shape=(), dtype=float32) 923
# slice = train, score = 0.6456879739978332
# np.mean(results), mse, len(results) =  0.46571770334928225 tf.Tensor(4683.884, shape=(), dtype=float32) 418
# slice = test, score = 0.46571770334928225
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.5998 tf.Tensor(4835.3555, shape=(), dtype=float32) 50
# slice = key, score = 0.5998
# np.mean(results), mse, len(results) =  0.6467172264355364 tf.Tensor(4702.079, shape=(), dtype=float32) 923
# slice = train, score = 0.6467172264355364
# np.mean(results), mse, len(results) =  0.46653110047846885 tf.Tensor(4783.117, shape=(), dtype=float32) 418
# slice = test, score = 0.46653110047846885
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.5958 tf.Tensor(4944.057, shape=(), dtype=float32) 50
# slice = key, score = 0.5958
# np.mean(results), mse, len(results) =  0.6490465872156013 tf.Tensor(4759.6133, shape=(), dtype=float32) 923
# slice = train, score = 0.6490465872156013
# np.mean(results), mse, len(results) =  0.46514354066985647 tf.Tensor(4811.259, shape=(), dtype=float32) 418
# slice = test, score = 0.46514354066985647
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.5964 tf.Tensor(5147.195, shape=(), dtype=float32) 50
# slice = key, score = 0.5964
# np.mean(results), mse, len(results) =  0.6467930660888408 tf.Tensor(4935.9277, shape=(), dtype=float32) 923
# slice = train, score = 0.6467930660888408
# np.mean(results), mse, len(results) =  0.46866028708133967 tf.Tensor(4985.162, shape=(), dtype=float32) 418
# slice = test, score = 0.46866028708133967
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.6012000000000001 tf.Tensor(5265.9385, shape=(), dtype=float32) 50
# slice = key, score = 0.6012000000000001
# np.mean(results), mse, len(results) =  0.6445828819068257 tf.Tensor(5005.328, shape=(), dtype=float32) 923
# slice = train, score = 0.6445828819068257
# np.mean(results), mse, len(results) =  0.4676315789473684 tf.Tensor(5093.4717, shape=(), dtype=float32) 418
# slice = test, score = 0.4676315789473684
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6004 tf.Tensor(5065.5103, shape=(), dtype=float32) 50
# slice = key, score = 0.6004
# np.mean(results), mse, len(results) =  0.6513542795232936 tf.Tensor(4862.2764, shape=(), dtype=float32) 923
# slice = train, score = 0.6513542795232936
# np.mean(results), mse, len(results) =  0.464066985645933 tf.Tensor(4949.3145, shape=(), dtype=float32) 418
# slice = test, score = 0.464066985645933
# np.mean(results), mse, len(results) =  0.464066985645933 tf.Tensor(4949.3145, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExKMeans_pro_wrestling_Key50_0.4641.npz ...
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.6038 tf.Tensor(5291.9375, shape=(), dtype=float32) 50
# slice = key, score = 0.6038
# np.mean(results), mse, len(results) =  0.6469447453954498 tf.Tensor(5143.9785, shape=(), dtype=float32) 923
# slice = train, score = 0.6469447453954498
# np.mean(results), mse, len(results) =  0.4672966507177033 tf.Tensor(5225.9517, shape=(), dtype=float32) 418
# slice = test, score = 0.4672966507177033
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.597 tf.Tensor(5362.1226, shape=(), dtype=float32) 50
# slice = key, score = 0.597
# np.mean(results), mse, len(results) =  0.6487540628385698 tf.Tensor(5181.775, shape=(), dtype=float32) 923
# slice = train, score = 0.6487540628385698
# np.mean(results), mse, len(results) =  0.4671770334928229 tf.Tensor(5285.2266, shape=(), dtype=float32) 418
# slice = test, score = 0.4671770334928229
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.5993999999999999 tf.Tensor(5471.1885, shape=(), dtype=float32) 50
# slice = key, score = 0.5993999999999999
# np.mean(results), mse, len(results) =  0.647854821235103 tf.Tensor(5257.4956, shape=(), dtype=float32) 923
# slice = train, score = 0.647854821235103
# np.mean(results), mse, len(results) =  0.46466507177033495 tf.Tensor(5364.6113, shape=(), dtype=float32) 418
# slice = test, score = 0.46466507177033495
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.5979999999999999 tf.Tensor(5527.155, shape=(), dtype=float32) 50
# slice = key, score = 0.5979999999999999
# np.mean(results), mse, len(results) =  0.648569880823402 tf.Tensor(5300.5747, shape=(), dtype=float32) 923
# slice = train, score = 0.648569880823402
# np.mean(results), mse, len(results) =  0.46791866028708134 tf.Tensor(5396.2603, shape=(), dtype=float32) 418
# slice = test, score = 0.46791866028708134
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.5988 tf.Tensor(5587.1577, shape=(), dtype=float32) 50
# slice = key, score = 0.5988
# np.mean(results), mse, len(results) =  0.6445503791982665 tf.Tensor(5427.233, shape=(), dtype=float32) 923
# slice = train, score = 0.6445503791982665
# np.mean(results), mse, len(results) =  0.4664354066985646 tf.Tensor(5545.736, shape=(), dtype=float32) 418
# slice = test, score = 0.4664354066985646
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6012 tf.Tensor(5810.8906, shape=(), dtype=float32) 50
# slice = key, score = 0.6012
# np.mean(results), mse, len(results) =  0.6480931744312026 tf.Tensor(5591.4727, shape=(), dtype=float32) 923
# slice = train, score = 0.6480931744312026
# np.mean(results), mse, len(results) =  0.4656459330143541 tf.Tensor(5642.398, shape=(), dtype=float32) 418
# slice = test, score = 0.4656459330143541
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6102000000000001 tf.Tensor(5774.807, shape=(), dtype=float32) 50
# slice = key, score = 0.6102000000000001
# np.mean(results), mse, len(results) =  0.6537378114842902 tf.Tensor(5585.4595, shape=(), dtype=float32) 923
# slice = train, score = 0.6537378114842902
# np.mean(results), mse, len(results) =  0.46698564593301434 tf.Tensor(5675.6885, shape=(), dtype=float32) 418
# slice = test, score = 0.46698564593301434
# np.mean(results), mse, len(results) =  0.46698564593301434 tf.Tensor(5675.6885, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExKMeans_pro_wrestling_Key50_0.467.npz ...
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6032 tf.Tensor(5875.8237, shape=(), dtype=float32) 50
# slice = key, score = 0.6032
# np.mean(results), mse, len(results) =  0.6517551462621886 tf.Tensor(5639.4756, shape=(), dtype=float32) 923
# slice = train, score = 0.6517551462621886
# np.mean(results), mse, len(results) =  0.4673684210526316 tf.Tensor(5736.963, shape=(), dtype=float32) 418
# slice = test, score = 0.4673684210526316
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.5982 tf.Tensor(6053.115, shape=(), dtype=float32) 50
# slice = key, score = 0.5982
# np.mean(results), mse, len(results) =  0.6490682556879739 tf.Tensor(5850.8755, shape=(), dtype=float32) 923
# slice = train, score = 0.6490682556879739
# np.mean(results), mse, len(results) =  0.46641148325358844 tf.Tensor(5937.2705, shape=(), dtype=float32) 418
# slice = test, score = 0.46641148325358844
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.6027999999999999 tf.Tensor(6038.493, shape=(), dtype=float32) 50
# slice = key, score = 0.6027999999999999
# np.mean(results), mse, len(results) =  0.6528819068255687 tf.Tensor(5817.2915, shape=(), dtype=float32) 923
# slice = train, score = 0.6528819068255687
# np.mean(results), mse, len(results) =  0.4680622009569378 tf.Tensor(5864.631, shape=(), dtype=float32) 418
# slice = test, score = 0.4680622009569378
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.6016 tf.Tensor(6163.765, shape=(), dtype=float32) 50
# slice = key, score = 0.6016
# np.mean(results), mse, len(results) =  0.6495449620801733 tf.Tensor(5960.366, shape=(), dtype=float32) 923
# slice = train, score = 0.6495449620801733
# np.mean(results), mse, len(results) =  0.4677751196172249 tf.Tensor(6013.401, shape=(), dtype=float32) 418
# slice = test, score = 0.4677751196172249
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.6044 tf.Tensor(6213.7583, shape=(), dtype=float32) 50
# slice = key, score = 0.6044
# np.mean(results), mse, len(results) =  0.6527302275189599 tf.Tensor(5955.62, shape=(), dtype=float32) 923
# slice = train, score = 0.6527302275189599
# np.mean(results), mse, len(results) =  0.4668181818181818 tf.Tensor(6016.432, shape=(), dtype=float32) 418
# slice = test, score = 0.4668181818181818
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.6016 tf.Tensor(6298.9146, shape=(), dtype=float32) 50
# slice = key, score = 0.6016
# np.mean(results), mse, len(results) =  0.652361863488624 tf.Tensor(6046.318, shape=(), dtype=float32) 923
# slice = train, score = 0.652361863488624
# np.mean(results), mse, len(results) =  0.46655502392344494 tf.Tensor(6113.061, shape=(), dtype=float32) 418
# slice = test, score = 0.46655502392344494
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.6032 tf.Tensor(6348.7847, shape=(), dtype=float32) 50
# slice = key, score = 0.6032
# np.mean(results), mse, len(results) =  0.6554279523293608 tf.Tensor(6123.0317, shape=(), dtype=float32) 923
# slice = train, score = 0.6554279523293608
# np.mean(results), mse, len(results) =  0.46684210526315784 tf.Tensor(6185.747, shape=(), dtype=float32) 418
# slice = test, score = 0.46684210526315784
# np.mean(results), mse, len(results) =  0.46684210526315784 tf.Tensor(6185.747, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExKMeans_pro_wrestling_Key50_0.4668.npz ...
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.5980000000000001 tf.Tensor(6401.4155, shape=(), dtype=float32) 50
# slice = key, score = 0.5980000000000001
# np.mean(results), mse, len(results) =  0.6523401950162514 tf.Tensor(6199.286, shape=(), dtype=float32) 923
# slice = train, score = 0.6523401950162514
# np.mean(results), mse, len(results) =  0.46641148325358844 tf.Tensor(6279.6323, shape=(), dtype=float32) 418
# slice = test, score = 0.46641148325358844
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.6044 tf.Tensor(6793.8345, shape=(), dtype=float32) 50
# slice = key, score = 0.6044
# np.mean(results), mse, len(results) =  0.6519284940411701 tf.Tensor(6472.1167, shape=(), dtype=float32) 923
# slice = train, score = 0.6519284940411701
# np.mean(results), mse, len(results) =  0.4672488038277512 tf.Tensor(6607.2065, shape=(), dtype=float32) 418
# slice = test, score = 0.4672488038277512

# %%
ress = dict()
for dataset in DATASETS[:1]:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100
    )

    print("LOADED")
    
    
    GE_QE_s = [f for f in os.listdir("./") if "GE_QE_Ann" in f and "yugioh" in f]
    
    ress[dataset] = res = dict()
    
    for GE_QE_i in GE_QE_s:
        print("GE_QE_i = ", GE_QE_i)
        loaded = np.load('./' + GE_QE_i)
        ress[dataset][GE_QE_i] = do_AXN(ctx, loaded, get_Rp_basic, Ls = np.linspace(0, 0.3, 4))
    
    del ctx
    gc.collect()

# %%
ress = dict()
for dataset in DATASETS[:1]:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100
    )

    print("LOADED")
    
    
    GE_QE_s = [f for f in os.listdir("./") if "GE_QE_Ann" in f and "yugioh" in f]
    
    ress[dataset] = res = dict()
    
    for GE_QE_i in GE_QE_s:
        print("GE_QE_i = ", GE_QE_i)
        loaded = np.load('./' + GE_QE_i)
        ress[dataset][GE_QE_i] = do_AXN(ctx, loaded, get_Rp_basic, Ls = np.linspace(0, 0.3, 4))
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (4, 6.137885635798218e+30 -> 2.524378507319208e+32)
# updated det (8, 2.524378507319208e+32 -> 5.48097506735188e+34)
# updated det (11, 5.48097506735188e+34 -> 4.6749692824069873e+36)
# Best det =  4.6749693e+36
# Current de =  4.6749693e+36
# 100 2260 1013
# LOADED
# GE_QE_i =  GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 17.00it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7226 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 11.45it/s]
# K = 25, L = 0.09999999999999999, TS = 100, rndFirst = False np.mean(results) = 0.588 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:07<00:00,  6.45it/s]
# K = 25, L = 0.19999999999999998, TS = 100, rndFirst = False np.mean(results) = 0.5718 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:06<00:00,  7.18it/s]
# K = 25, L = 0.3, TS = 100, rndFirst = False np.mean(results) = 0.55 best = 0.7226
# GE_QE_i =  GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz
# 100%|███████████████████████████████████████████| 50/50 [00:06<00:00,  7.61it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.6807999999999998 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:07<00:00,  6.79it/s]
# K = 25, L = 0.09999999999999999, TS = 100, rndFirst = False np.mean(results) = 0.5726 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:09<00:00,  5.20it/s]
# K = 25, L = 0.19999999999999998, TS = 100, rndFirst = False np.mean(results) = 0.5686 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:07<00:00,  6.40it/s]
# K = 25, L = 0.3, TS = 100, rndFirst = False np.mean(results) = 0.5604 best = 0.6807999999999998
# GE_QE_i =  GE_QE_AnnCURxTop_yugioh_Round10_2429.npz
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 12.51it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.36099999999999993 best = 0.36099999999999993
# 100%|███████████████████████████████████████████| 50/50 [00:07<00:00,  6.52it/s]
# K = 25, L = 0.09999999999999999, TS = 100, rndFirst = False np.mean(results) = 0.335 best = 0.36099999999999993
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.64it/s]
# K = 25, L = 0.19999999999999998, TS = 100, rndFirst = False np.mean(results) = 0.3588 best = 0.36099999999999993
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 10.61it/s]
# K = 25, L = 0.3, TS = 100, rndFirst = False np.mean(results) = 0.38 best = 0.38
# GE_QE_i =  GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 10.97it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.6146 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 11.43it/s]
# K = 25, L = 0.09999999999999999, TS = 100, rndFirst = False np.mean(results) = 0.5218 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 10.70it/s]
# K = 25, L = 0.19999999999999998, TS = 100, rndFirst = False np.mean(results) = 0.5067999999999999 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 11.97it/s]
# K = 25, L = 0.3, TS = 100, rndFirst = False np.mean(results) = 0.5132000000000001 best = 0.6146

# %%
ress
# Out:
# {'yugioh': {'GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.7226',
#   'GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.6807999999999998',
#   'GE_QE_AnnCURxTop_yugioh_Round10_2429.npz': 'K = 25, L = 0.3, rndFirst = False np.mean(results) = 0.38',
#   'GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.6146'}}

# %%
ress = dict()
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100
    )

    print("LOADED")
    
    
    GE_QE_s = [
        f for f in os.listdir("./")
        if ("GE_QE_Ann" in f) and (dataset in f)
    ]
    
    ress[dataset] = res = dict()
    
    for GE_QE_i in GE_QE_s:
        print("GE_QE_i = ", GE_QE_i)
        loaded = np.load('./' + GE_QE_i)
        ress[dataset][GE_QE_i] = do_AXN(ctx, loaded, get_Rp_basic)
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (4, 6.137885635798218e+30 -> 2.524378507319208e+32)
# updated det (8, 2.524378507319208e+32 -> 5.48097506735188e+34)
# updated det (11, 5.48097506735188e+34 -> 4.6749692824069873e+36)
# Best det =  4.6749693e+36
# Current de =  4.6749693e+36
# 100 2260 1013
# LOADED
# GE_QE_i =  GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 12.69it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7226 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:06<00:00,  7.16it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.588 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:07<00:00,  6.79it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.5718 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.07it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.55 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 10.35it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.5207999999999999 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.13it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.5008 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.86it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.4854 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 11.55it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.47379999999999994 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.12it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.44920000000000004 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.30it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.43060000000000004 best = 0.7226
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 11.91it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.4215999999999999 best = 0.7226
# GE_QE_i =  GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 17.37it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.6807999999999998 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 14.62it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.5726 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:01<00:00, 25.62it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.5686 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 12.00it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.5604 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 16.60it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.5456 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 10.17it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.5236 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:07<00:00,  6.98it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.5004 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 10.41it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.48120000000000007 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 11.55it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.4678 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:06<00:00,  7.72it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.4542 best = 0.6807999999999998
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 10.09it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.4396 best = 0.6807999999999998
# GE_QE_i =  GE_QE_AnnCURxTop_yugioh_Round10_2429.npz
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 13.01it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.36099999999999993 best = 0.36099999999999993
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 14.76it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.335 best = 0.36099999999999993
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 14.69it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.3588 best = 0.36099999999999993
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 12.92it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.38 best = 0.38
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 20.52it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.3874 best = 0.3874
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 14.44it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.3724 best = 0.3874
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 17.24it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.37579999999999997 best = 0.3874
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 14.03it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.36419999999999997 best = 0.3874
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 13.85it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.36160000000000003 best = 0.3874
# 100%|███████████████████████████████████████████| 50/50 [00:04<00:00, 11.94it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.3546 best = 0.3874
# 100%|███████████████████████████████████████████| 50/50 [00:05<00:00,  9.89it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.353 best = 0.3874
# GE_QE_i =  GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 14.41it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.6146 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 16.10it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.5218 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 19.09it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.5067999999999999 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 17.33it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.5132000000000001 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 14.45it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.495 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 24.35it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.47619999999999996 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 14.41it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.4708 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 20.87it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.46 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 20.58it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.4341999999999999 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:01<00:00, 26.12it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.43080000000000007 best = 0.6146
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 23.12it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.41919999999999996 best = 0.6146
#
#
#
# DATASET =  pro_wrestling
# Loading file pro_wrestling/ment_to_ent_scores_n_m_392_n_e_10133_all_layers_False1000.pkl
# Loading file pro_wrestling/ment_to_ent_scores_n_m_500_n_e_10133_all_layers_False0.pkl
# Loading file pro_wrestling/ment_to_ent_scores_n_m_500_n_e_10133_all_layers_False500.pkl
# Loaded shape =  (1392, 10133)
# Shuffling... (seed = 42)
# updated det (1, 5.124810435461604e-33 -> 1.0217253487036523e-31)
# updated det (2, 1.0217253487036523e-31 -> 1.2030961336739456e-31)
# updated det (11, 1.2030961336739456e-31 -> 7.606045638566237e-29)
# updated det (60, 7.606045638566237e-29 -> 3.735096148850118e-27)
# Best det =  3.735096e-27
# Current de =  3.735096e-27
# 100 873 418
# LOADED
# GE_QE_i =  GE_QE_AnnCURxKMeans_pro_wrestling_Round10_4834.npz
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 28.14it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.616 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 21.95it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.47800000000000004 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 19.24it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.45499999999999996 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.68it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.4365 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  9.07it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.4069999999999999 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  9.51it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.40049999999999997 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.18it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.37 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 13.67it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.366 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 10.12it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.35400000000000004 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 15.77it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.34450000000000003 best = 0.616
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 13.83it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.3335 best = 0.616
# GE_QE_i =  GE_QE_AnnCURxRandom_pro_wrestling_Round10_4279.npz
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.20it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.5724999999999999 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  9.56it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.4565 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  7.60it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.441 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  7.49it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.4295000000000001 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  7.98it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.4035 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  9.14it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.39499999999999996 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 14.56it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.39100000000000007 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 13.40it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.38099999999999995 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 11.48it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.36250000000000004 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 11.56it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.34450000000000003 best = 0.5724999999999999
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  9.99it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.3335 best = 0.5724999999999999
# GE_QE_i =  GE_QE_AnnCURxTop_pro_wrestling_Round10_3002.npz
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.35it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.43499999999999994 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  9.84it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.384 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 11.96it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.40499999999999997 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 11.22it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.38900000000000007 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 10.17it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.39200000000000007 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.79it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.3885 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 17.93it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.385 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.05it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.38250000000000006 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.35it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.368 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:03<00:00,  6.46it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.35750000000000004 best = 0.43499999999999994
# 100%|███████████████████████████████████████████| 20/20 [00:03<00:00,  6.63it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.3495 best = 0.43499999999999994
# GE_QE_i =  GE_QE_AnnCURxCoItem_pro_wrestling_Round10_5119.npz
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 11
/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.2247222222222222 best = 0.44722222222222224
# 100%|███████████████████████████████████████████| 36/36 [00:09<00:00,  3.88it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.2125 best = 0.44722222222222224
# 100%|███████████████████████████████████████████| 36/36 [00:06<00:00,  5.25it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.2011111111111111 best = 0.44722222222222224
# 100%|███████████████████████████████████████████| 36/36 [00:08<00:00,  4.49it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.19972222222222222 best = 0.44722222222222224
# GE_QE_i =  GE_QE_AnnCURxRandom_military_Round10_2454.npz
# 100%|███████████████████████████████████████████| 36/36 [00:12<00:00,  2.77it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.3350000000000001 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:08<00:00,  4.18it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.2791666666666667 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:08<00:00,  4.41it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.26583333333333337 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:09<00:00,  3.75it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.26972222222222225 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:11<00:00,  3.12it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.2555555555555556 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:10<00:00,  3.35it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.24888888888888885 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:10<00:00,  3.48it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.2347222222222223 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:11<00:00,  3.10it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.2288888888888889 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:07<00:00,  4.71it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.22055555555555556 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:11<00:00,  3.14it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.205 best = 0.3350000000000001
# 100%|███████████████████████████████████████████| 36/36 [00:13<00:00,  2.64it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.19944444444444442 best = 0.3350000000000001

# %%
ress
# Out:
# {'yugioh': {'GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.7226',
#   'GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.6807999999999998',
#   'GE_QE_AnnCURxTop_yugioh_Round10_2429.npz': 'K = 25, L = 0.4, rndFirst = False np.mean(results) = 0.3874',
#   'GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.6146'},
#  'pro_wrestling': {'GE_QE_AnnCURxKMeans_pro_wrestling_Round10_4834.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.616',
#   'GE_QE_AnnCURxRandom_pro_wrestling_Round10_4279.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.5724999999999999',
#   'GE_QE_AnnCURxTop_pro_wrestling_Round10_3002.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.43499999999999994',
#   'GE_QE_AnnCURxCoItem_pro_wrestling_Round10_5119.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.6635'},
#  'star_trek': {'GE_QE_AnnCURxCoItem_star_trek_Round10_3677.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.5087301587301587',
#   'GE_QE_AnnCURxTop_star_trek_Round10_1154.npz': 'K = 25, L = 0.4, rndFirst = False np.mean(results) = 0.20047619047619045',
#   'GE_QE_AnnCURxRandom_star_trek_Round10_2287.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.31174603174603177',
#   'GE_QE_AnnCURxKMeans_star_trek_Round10_3101.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.43444444444444436'},
#  'doctor_who': {'GE_QE_AnnCURxTop_doctor_who_Round10_1197.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.16849999999999998',
#   'GE_QE_AnnCURxKMeans_doctor_who_Round10_2489.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.3093333333333333',
#   'GE_QE_AnnCURxRandom_doctor_who_Round10_1919.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.23450000000000001',
#   'GE_QE_AnnCURxCoItem_doctor_who_Round10_296.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.3543333333333333'},
#  'military': {'GE_QE_AnnCURxKMeans_military_Round10_2963.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.4066666666666667',
#   'GE_QE_AnnCURxTop_military_Round10_1907.npz': 'K = 25, L = 0.5, rndFirst = False np.mean(results) = 0.2711111111111111',
#   'GE_QE_AnnCURxCoItem_military_Round10_3357.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.44722222222222224',
#   'GE_QE_AnnCURxRandom_military_Round10_2454.npz': 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.3350000000000001'}}

# %%
ress = dict()
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100
    )

    print("LOADED")
    
    
    GE_QE_s = [
        f for f in os.listdir("./")
        if ("GE_QE_Ann" in f) and (dataset in f)
    ]
    
    ress[dataset] = res = dict()
    
    for GE_QE_i in GE_QE_s:
        print("GE_QE_i = ", GE_QE_i)
        loaded = np.load('./' + GE_QE_i)
        ress[dataset][GE_QE_i] = do_AXN(ctx, loaded, get_Rp_basic, STRIP=0.1, Ks=[10, 25, 50])
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (4, 6.137885635798218e+30 -> 2.524378507319208e+32)
# updated det (8, 2.524378507319208e+32 -> 5.48097506735188e+34)
# updated det (11, 5.48097506735188e+34 -> 4.6749692824069873e+36)
# Best det =  4.6749693e+36
# Current de =  4.6749693e+36
# 100 2260 1013
# LOADED
# GE_QE_i =  GE_QE_AnnCURxCoItem_yugioh_Round10_5617.np
/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.25166666666666665 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:13<00:00,  5.21it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.2213888888888889 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:12<00:00,  5.60it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.2336111111111111 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:12<00:00,  5.67it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.24944444444444447 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:14<00:00,  5.14it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.25486111111111115 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:12<00:00,  5.91it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.25833333333333336 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:11<00:00,  6.33it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.25000000000000006 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:13<00:00,  5.36it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.2372222222222222 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:13<00:00,  5.21it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.2379166666666667 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:13<00:00,  5.31it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.23430555555555557 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:14<00:00,  5.12it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.22722222222222221 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:07<00:00, 10.04it/s]
# K = 50, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.25166666666666665 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:06<00:00, 10.56it/s]
# K = 50, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.21902777777777777 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:09<00:00,  7.98it/s]
# K = 50, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.22750000000000004 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:08<00:00,  8.87it/s]
# K = 50, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.23041666666666671 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:11<00:00,  6.14it/s]
# K = 50, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.23291666666666672 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:08<00:00,  8.13it/s]
# K = 50, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.22749999999999998 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:07<00:00,  9.32it/s]
# K = 50, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.21958333333333332 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:07<00:00, 10.01it/s]
# K = 50, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.20944444444444443 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:06<00:00, 10.36it/s]
# K = 50, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.20305555555555554 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:08<00:00,  8.39it/s]
# K = 50, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.19736111111111113 best = 0.28430555555555553
# 100%|███████████████████████████████████████████| 72/72 [00:09<00:00,  7.72it/s]
# K = 50, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.19263888888888892 best = 0.28430555555555553
# GE_QE_i =  GE_QE_AnnCURxCoItem_military_Round10_3357.npz
# 100%|███████████████████████████████████████████| 72/72 [00:45<00:00,  1.60it/s]
# K = 10, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.42541666666666667 best = 0.42541666666666667
# 100%|███████████████████████████████████████████| 72/72 [00:41<00:00,  1.73it/s]
# K = 10, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.35347222222222224 best = 0.42541666666666667
# 100%|███████████████████████████████████████████| 72/72 [00:45<00:00,  1.57it/s]
# K = 10, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.34361111111111114 best = 0.42541666666666667
# 100%|███████████████████████████████████████████| 72/72 [00:35<00:00,  2.02it/s]
# K = 10, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.33444444444444443 best = 0.42541666666666667
# 100%|███████████████████████████████████████████| 72/72 [00:34<00:00,  2.09it/s]
# K = 10, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.3209722222222222 best = 0.42541666666666667
#  50%|█████████████████████▌                     | 36/72 [00:17<00:19,  1.82it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
ress
# Out:
# {'yugioh': {'GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.7172277227722772',
#   'GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.6592079207920792',
#   'GE_QE_AnnCURxTop_yugioh_Round10_2429.npz': 'K = 10, L = 0.8, rndFirst = False np.mean(results) = 0.4597029702970298',
#   'GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.6263366336633663'},
#  'pro_wrestling': {'GE_QE_AnnCURxKMeans_pro_wrestling_Round10_4834.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.6531707317073171',
#   'GE_QE_AnnCURxRandom_pro_wrestling_Round10_4279.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.5895121951219512',
#   'GE_QE_AnnCURxTop_pro_wrestling_Round10_3002.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.44536585365853665',
#   'GE_QE_AnnCURxCoItem_pro_wrestling_Round10_5119.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.6909756097560975'},
#  'star_trek': {'GE_QE_AnnCURxCoItem_star_trek_Round10_3677.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.504920634920635',
#   'GE_QE_AnnCURxTop_star_trek_Round10_1154.npz': 'K = 10, L = 0.8, rndFirst = False np.mean(results) = 0.2507142857142857',
#   'GE_QE_AnnCURxRandom_star_trek_Round10_2287.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.3146825396825397',
#   'GE_QE_AnnCURxKMeans_star_trek_Round10_3101.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.4226190476190476'},
#  'doctor_who': {'GE_QE_AnnCURxTop_doctor_who_Round10_1197.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.15808333333333333',
#   'GE_QE_AnnCURxKMeans_doctor_who_Round10_2489.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.3155833333333334',
#   'GE_QE_AnnCURxRandom_doctor_who_Round10_1919.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.24891666666666665',
#   'GE_QE_AnnCURxCoItem_doctor_who_Round10_296.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.38225000000000003'},
#  'military': {'GE_QE_AnnCURxKMeans_military_Round10_2963.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.38861111111111113',
#   'GE_QE_AnnCURxTop_military_Round10_1907.npz': 'K = 10, L = 0.7000000000000001, rndFirst = False np.mean(results) = 0.28430555555555553',
#   'GE_QE_AnnCURxCoItem_military_Round10_3357.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.42541666666666667',
#   'GE_QE_AnnCURxRandom_military_Round10_2454.npz': 'K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.3156944444444445'}}

# %%
import json

for key in ress.keys():
    print()
    print(f"================== {key} ==================")
    print(json.dumps(ress[key], indent=""))
# Out:
# ================== yugioh ==================
# {
# "GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.7172277227722772",
# "GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.6592079207920792",
# "GE_QE_AnnCURxTop_yugioh_Round10_2429.npz": "K = 10, L = 0.8, rndFirst = False np.mean(results) = 0.4597029702970298",
# "GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.6263366336633663"
# }
#
# ================== pro_wrestling ==================
# {
# "GE_QE_AnnCURxKMeans_pro_wrestling_Round10_4834.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.6531707317073171",
# "GE_QE_AnnCURxRandom_pro_wrestling_Round10_4279.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.5895121951219512",
# "GE_QE_AnnCURxTop_pro_wrestling_Round10_3002.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.44536585365853665",
# "GE_QE_AnnCURxCoItem_pro_wrestling_Round10_5119.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.6909756097560975"
# }
#
# ================== star_trek ==================
# {
# "GE_QE_AnnCURxCoItem_star_trek_Round10_3677.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.504920634920635",
# "GE_QE_AnnCURxTop_star_trek_Round10_1154.npz": "K = 10, L = 0.8, rndFirst = False np.mean(results) = 0.2507142857142857",
# "GE_QE_AnnCURxRandom_star_trek_Round10_2287.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.3146825396825397",
# "GE_QE_AnnCURxKMeans_star_trek_Round10_3101.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.4226190476190476"
# }
#
# ================== doctor_who ==================
# {
# "GE_QE_AnnCURxTop_doctor_who_Round10_1197.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.15808333333333333",
# "GE_QE_AnnCURxKMeans_doctor_who_Round10_2489.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.3155833333333334",
# "GE_QE_AnnCURxRandom_doctor_who_Round10_1919.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.24891666666666665",
# "GE_QE_AnnCURxCoItem_doctor_who_Round10_296.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.38225000000000003"
# }
#
# ================== military ==================
# {
# "GE_QE_AnnCURxKMeans_military_Round10_2963.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.38861111111111113",
# "GE_QE_AnnCURxTop_military_Round10_1907.npz": "K = 10, L = 0.7000000000000001, rndFirst = False np.mean(results) = 0.28430555555555553",
# "GE_QE_AnnCURxCoItem_military_Round10_3357.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.42541666666666667",
# "GE_QE_AnnCURxRandom_military_Round10_2454.npz": "K = 10, L = 0.0, rndFirst = False np.mean(results) = 0.3156944444444445"
# }

# %%
ress = dict()
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100
    )

    print("LOADED")
    
    
    GE_QE_s = [
        f for f in os.listdir("./")
        if ("GE_QE_Ann" in f) and (dataset in f)
    ]
    
    ress[dataset] = res = dict()
    
    for GE_QE_i in GE_QE_s:
        print("GE_QE_i = ", GE_QE_i)
        loaded = np.load('./' + GE_QE_i)
        ress[dataset][GE_QE_i] = do_AXN(ctx, loaded, get_Rp_basic, STRIP=0.1, Ks=[5])
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (4, 6.137885635798218e+30 -> 2.524378507319208e+32)
# updated det (8, 2.524378507319208e+32 -> 5.48097506735188e+34)
# updated det (11, 5.48097506735188e+34 -> 4.6749692824069873e+36)
# Best det =  4.6749693e+36
# Current de =  4.6749693e+36
# 100 2260 1013
# LOADED
# GE_QE_i =  GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz
# 100%|█████████████████████████████████████████| 101/101 [00:44<00:00,  2.26it/s]
# K = 5, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7172277227722772 best = 0.7172277227722772
# 100%|█████████████████████████████████████████| 101/101 [00:48<00:00,  2.07it/s]
# K = 5, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0
/s]
# K = 5, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.45780487804878045 best = 0.45780487804878045
# 100%|███████████████████████████████████████████| 41/41 [00:22<00:00,  1.85it/s]
# K = 5, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.45195121951219513 best = 0.45780487804878045
# GE_QE_i =  GE_QE_AnnCURxCoItem_pro_wrestling_Round10_5119.npz
# 100%|███████████████████████████████████████████| 41/41 [00:24<00:00,  1.64it/s]
# K = 5, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.6909756097560975 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:18<00:00,  2.21it/s]
# K = 5, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.5585365853658536 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:21<00:00,  1.90it/s]
# K = 5, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.5487804878048781 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:19<00:00,  2.15it/s]
# K = 5, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.5421951219512195 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:17<00:00,  2.41it/s]
# K = 5, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.528780487804878 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:19<00:00,  2.07it/s]
# K = 5, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.5107317073170731 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:21<00:00,  1.94it/s]
# K = 5, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.49829268292682927 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:18<00:00,  2.27it/s]
# K = 5, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.48756097560975614 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:18<00:00,  2.20it/s]
# K = 5, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.48243902439024383 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:18<00:00,  2.24it/s]
# K = 5, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.464390243902439 best = 0.6909756097560975
# 100%|███████████████████████████████████████████| 41/41 [00:19<00:00,  2.06it/s]
# K = 5, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.455609756097561 best = 0.6909756097560975
#
#
#
# DATASET =  star_trek
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_27_n_e_34430_all_layers_False4200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False0.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False4000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False600.pkl
# Loaded shape =  (4227, 34430)
# Shuffling... (seed = 42)
# updated det (0, 1.2314701061114986e-33 -> 2.964262348140887e-30)
# updated det (3, 2.964262348140887e-30 -> 8.32734456022628e-28)
# updated det (5, 8.32734456022628e-28 -> 3.501918032693322e-27)
# updated det (7, 3.501918032693322e-27 -> 1.781987943310876e-26)
# updated det (11, 1.781987943310876e-26 -> 3.658797620704755e-24)
# Best det =  3.6587976e-24
# Current de =  3.6587976e-24
# 100 2857 1269
# LOADED
# GE_QE_i =  GE_QE_AnnCURxCoItem_star_trek_Round10_3677.npz
# 100%|█████████████████████████████████████████| 126/126 [01:33<00:00,  1.35it/s]
# K = 5, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.504920634920635 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:05<00:00,  1.92it/s]
# K = 5, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.412936507936508 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:10<00:00,  1.77it/s]
# K = 5, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.4135714285714286 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:03<00:00,  2.00it/s]
# K = 5, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.4092857142857143 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:02<00:00,  2.03it/s]
# K = 5, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.3991269841269841 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:03<00:00,  2.00it/s]
# K = 5, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.390952380952381 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:01<00:00,  2.05it/s]
# K = 5, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.381031746031746 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:12<00:00,  1.74it/s]
# K = 5, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.36880952380952386 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:16<00:00,  1.65it/s]
# K = 5, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.3624603174603174 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:23<00:00,  1.51it/s]
# K = 5, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.3537301587301588 best = 0.504920634920635
# 100%|█████████████████████████████████████████| 126/126 [01:18<00:00,  1.61it/s]
# K = 5, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.345 best = 0.504920634920635
# GE_QE_i =  GE_QE_AnnCURxTop_star_trek_Round10_1154.npz
# 100%|█████████████████████████████████████████| 126/126 [01:58<00:00,  1.07it/s]
# K = 5, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.1629365079365079 best = 0.1629365079365079
# 100%|█████████████████████████████████████████| 126/126 [02:17<00:00,  1.09s/it]
# K = 5, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.1682539682539683 best = 0.1682539682539683
# 100%|█████████████████████████████████████████| 126/126 [01:42<00:00,  1.22it/s]
# K = 5, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.20404761904761903 best = 0.20404761904761903
# 100%|█████████████████████████████████████████| 126/126 [01:59<00:00,  1.05it/s]
# K = 5, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.23238095238095233 best = 0.23238095238095233
# 100%|█████████████████████████████████████████| 126/126 [01:44<00:00,  1.21it/s]
# K = 5, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.2532539682539683 best = 0.2532539682539683
# 100%|█████████████████████████████████████████| 126/126 [01:48<00:00,  1.16it/s]
# K = 5, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.2688888888888889 best = 0.2688888888888889
# 100%|█████████████████████████████████████████| 126/126 [01:37<00:00,  1.29it/s]
# K = 5, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.2754761904761905 best = 0.2754761904761905
# 100%|█████████████████████████████████████████| 126/126 [01:27<00:00,  1.44it/s]
# K = 5, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.27984126984127 best = 0.27984126984127
# 100%|█████████████████████████████████████████| 126/126 [01:17<00:00,  1.63it/s]
# K = 5, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.2795238095238095 best = 0.27984126984127
# 100%|█████████████████████████████████████████| 126/126 [01:18<00:00,  1.61it/s]
# K = 5, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.2857936507936507 best = 0.2857936507936507
# 100%|█████████████████████████████████████████| 126/126 [01:13<00:00,  1.72it/s]
# K = 5, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.28412698412698406 best = 0.2857936507936507
# GE_QE_i =  GE_QE_AnnCURxRandom_star_trek_Round10_2287.npz
# 100%|█████████████████████████████████████████| 126/126 [01:31<00:00,  1.38it/s]
# K = 5, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.3146825396825397 best = 0.3146825396825397
# 100%|█████████████████████████████████████████| 126/126 [01:15<00:00,  1.66it/s]
# K = 5, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.27761904761904765 best = 0.3146825396825397
# 100%|█████████████████████████████████████████| 126/126 [01:14<00:00,  1.70it/s]
# K = 5, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.30269841269841263 best = 0.3146825396825397
# 100%|█████████████████████████████████████████| 126/126 [01:03<00:00,  1.99it/s]
# K = 5, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.31460317460317455 best = 0.3146825396825397
# 100%|█████████████████████████████████████████| 126/126 [01:01<00:00,  2.05it/s]
# K = 5, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.32492063492063494 best = 0.32492063492063494
# 100%|█████████████████████████████████████████| 126/126 [00:55<00:00,  2.29it/s]
# K = 5, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.32396825396825396 best = 0.32492063492063494
# 100%|█████████████████████████████████████████| 126/126 [00:59<00:00,  2.13it/s]
# K = 5, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.3211111111111112 best = 0.32492063492063494
# 100%|█████████████████████████████████████████| 126/126 [01:01<00:00,  2.04it/s]
# K = 5, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.32047619047619047 best = 0.32492063492063494
# 100%|█████████████████████████████████████████| 126/126 [01:04<00:00,  1.97it/s]
# K = 5, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.3170634920634921 best = 0.32492063492063494
# 100%|█████████████████████████████████████████| 126/126 [01:02<00:00,  2.00it/s]
# K = 5, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.30682539682539683 best = 0.32492063492063494
# 100%|█████████████████████████████████████████| 126/126 [00:59<00:00,  2.11it/s]
# K = 5, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.3034920634920636 best = 0.32492063492063494
# GE_QE_i =  GE_QE_AnnCURxKMeans_star_trek_Round10_3101.npz
# 100%|█████████████████████████████████████████| 126/126 [00:57<00:00,  2.19it/s]
# K = 5, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.4226190476190476 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:02<00:00,  2.03it/s]
# K = 5, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.36166666666666675 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:19<00:00,  1.58it/s]
# K = 5, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.37531746031746027 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:07<00:00,  1.88it/s]
# K = 5, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.38055555555555565 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:11<00:00,  1.75it/s]
# K = 5, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.38182539682539685 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:10<00:00,  1.79it/s]
# K = 5, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.3773809523809523 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:10<00:00,  1.79it/s]
# K = 5, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.3752380952380952 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:35<00:00,  1.32it/s]
# K = 5, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.37047619047619046 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:34<00:00,  1.33it/s]
# K = 5, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.36722222222222217 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:29<00:00,  1.41it/s]
# K = 5, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.3608730158730159 best = 0.4226190476190476
# 100%|█████████████████████████████████████████| 126/126 [01:40<00:00,  1.26it/s]
# K = 5, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.34992063492063497 best = 0.4226190476190476
#
#
#
# DATASET =  doctor_who
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3400.pkl
# Loaded shape =  (4000, 40281)
# Shuffling... (seed = 42)
# updated det (0, 1.6579042391119776e-40 -> 2.8819492909776643e-28)
# updated det (19, 2.8819492909776643e-28 -> 6.565585313937484e-27)
# updated det (41, 6.565585313937484e-27 -> 2.5486225384528903e-26)
# Best det =  2.5486225e-26
# Current de =  2.5486225e-26
# 100 2699 1200
# LOADED
# GE_QE_i =  GE_QE_AnnCURxTop_doctor_who_Round10_1197.npz
# 100%|█████████████████████████████████████████| 120/120 [01:41<00:00,  1.19it/s]
# K = 5, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.15808333333333333 best = 0.15808333333333333
# 100%|█████████████████████████████████████████| 120/120 [01:26<00:00,  1.39it/s]
# K = 5, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.14175 best = 0.15808333333333333
# 100%|█████████████████████████████████████████| 120/120 [01:08<00:00,  1.74it/s]
# K = 5, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0
best = 0.3156944444444445
# 100%|███████████████████████████████████████████| 72/72 [01:10<00:00,  1.02it/s]
# K = 5, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.30083333333333334 best = 0.3156944444444445
# 100%|███████████████████████████████████████████| 72/72 [01:10<00:00,  1.03it/s]
# K = 5, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.3055555555555556 best = 0.3156944444444445
# 100%|███████████████████████████████████████████| 72/72 [01:09<00:00,  1.03it/s]
# K = 5, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.30680555555555555 best = 0.3156944444444445
# 100%|███████████████████████████████████████████| 72/72 [01:06<00:00,  1.08it/s]
# K = 5, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.30416666666666664 best = 0.3156944444444445
# 100%|███████████████████████████████████████████| 72/72 [01:09<00:00,  1.04it/s]
# K = 5, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.30527777777777776 best = 0.3156944444444445
# 100%|███████████████████████████████████████████| 72/72 [01:11<00:00,  1.01it/s]
# K = 5, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.3030555555555556 best = 0.3156944444444445
# 100%|███████████████████████████████████████████| 72/72 [01:06<00:00,  1.09it/s]
# K = 5, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.30194444444444446 best = 0.3156944444444445

# %%
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100
    )

    print("LOADED")
    
    do(ctx, f"{dataset}_Round10")
    
    del ctx
    gc.collect()
# Out:
# DATASET =  yugioh
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_374_n_e_10031_all_layers_False3000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2500.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False1000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False2000.pkl
# Loading file yugioh/ment_to_ent_scores_n_m_500_n_e_10031_all_layers_False500.pkl
# Loaded shape =  (3374, 10031)
# Shuffling... (seed = 42)
# updated det (4, 6.137885635798218e+30 -> 2.524378507319208e+32)
# updated det (8, 2.524378507319208e+32 -> 5.48097506735188e+34)
# updated det (11, 5.48097506735188e+34 -> 4.6749692824069873e+36)
# Best det =  4.6749693e+36
# Current de =  4.6749693e+36
# 100 2260 1013
# LOADED
# /tmp/ipykernel_179949/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.5840796460176991 0.12217492 2260
# np.mean(results), mse, len(results) =  0.5617472852912143 0.146082 1013
# ./GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.5256504424778761 0.14459947 2260
# np.mean(results), mse, len(results) =  0.5016584402764067 0.16814187 1013
# ./GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz
# np.mean(results), mse, len(results) =  0.2658362831858407 0.4409106 2260
# np.mean(results), mse, len(results) =  0.24294175715695954 0.5916703 1013
# ./GE_QE_AnnCURxTop_yugioh_Round10_2429.npz
# np.mean(results), mse, len(results) =  0.4978008849557522 0.17288575 2260
# np.mean(results), mse, len(results) =  0.47210266535044426 0.1962339 1013
# ./GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz
#
#
#
# DATASET =  pro_wrestling
# Loading file pro_wrestling/ment_to_ent_scores_n_m_392_n_e_10133_all_layers_False1000.pkl
# Loading file pro_wrestling/ment_to_ent_scores_n_m_500_n_e_10133_all_layers_False0.pkl
# Loading file pro_wrestling/ment_to_ent_scores_n_m_500_n_e_10133_all_layers_False500.pkl
# Loaded shape =  (1392, 10133)
# Shuffling... (seed = 42)
# updated det (1, 5.124810435461604e-33 -> 1.0217253487036523e-31)
# updated det (2, 1.0217253487036523e-31 -> 1.2030961336739456e-31)
# updated det (11, 1.2030961336739456e-31 -> 7.606045638566237e-29)
# updated det (60, 7.606045638566237e-29 -> 3.735096148850118e-27)
# Best det =  3.735096e-27
# Current de =  3.735096e-27
# 100 873 418
# LOADED
# /tmp/ipykernel_179949/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.5841122565864835 0.040122893 873
# np.mean(results), mse, len(results) =  0.5118899521531101 0.059953026 418
# ./GE_QE_AnnCURxCoItem_pro_wrestling_Round10_5119.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.5501832760595647 0.044102278 873
# np.mean(results), mse, len(results) =  0.48344497607655507 0.06791056 418
# ./GE_QE_AnnCURxKMeans_pro_wrestling_Round10_4834.npz
# np.mean(results), mse, len(results) =  0.3916609392898053 0.073244475 873
# np.mean(results), mse, len(results) =  0.30023923444976075 0.10590687 418
# ./GE_QE_AnnCURxTop_pro_wrestling_Round10_3002.npz
# np.mean(results), mse, len(results) =  0.4952233676975945 0.054602623 873
# np.mean(results), mse, len(results) =  0.42791866028708136 0.08077693 418
# ./GE_QE_AnnCURxRandom_pro_wrestling_Round10_4279.npz
#
#
#
# DATASET =  star_trek
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_27_n_e_34430_all_layers_False4200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False0.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1600.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False1200.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3800.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False2400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False4000.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False3400.pkl
# Loading file star_trek/ment_to_ent_scores_n_m_200_n_e_34430_all_layers_False600.pkl
# Loaded shape =  (4227, 34430)
# Shuffling... (seed = 42)
# updated det (0, 1.2314701061114986e-33 -> 2.964262348140887e-30)
# updated det (3, 2.964262348140887e-30 -> 8.32734456022628e-28)
# updated det (5, 8.32734456022628e-28 -> 3.501918032693322e-27)
# updated det (7, 3.501918032693322e-27 -> 1.781987943310876e-26)
# updated det (11, 1.781987943310876e-26 -> 3.658797620704755e-24)
# Best det =  3.6587976e-24
# Current de =  3.6587976e-24
# 100 2857 1269
# LOADED
# /tmp/ipykernel_179949/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.3931256562828141 0.028124528 2857
# np.mean(results), mse, len(results) =  0.3677304964539007 0.033124365 1269
# ./GE_QE_AnnCURxCoItem_star_trek_Round10_3677.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.33541127056352815 0.031438205 2857
# np.mean(results), mse, len(results) =  0.3101103230890465 0.03898697 1269
# ./GE_QE_AnnCURxKMeans_star_trek_Round10_3101.npz
# np.mean(results), mse, len(results) =  0.14063703185159257 0.052849207 2857
# np.mean(results), mse, len(results) =  0.11537431048069348 0.06451296 1269
# ./GE_QE_AnnCURxTop_star_trek_Round10_1154.npz
# np.mean(results), mse, len(results) =  0.2557367868393419 0.04027265 2857
# np.mean(results), mse, len(results) =  0.228715524034673 0.045980364 1269
# ./GE_QE_AnnCURxRandom_star_trek_Round10_2287.npz
#
#
#
# DATASET =  doctor_who
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2400.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False2800.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False0600.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1200.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False1000.pkl
# Loading file doctor_who/ment_to_ent_scores_n_m_200_n_e_40281_all_layers_False3400.pkl
# Loaded shape =  (4000, 40281)
# Shuffling... (seed = 42)
# updated det (0, 1.6579042391119776e-40 -> 2.8819492909776643e-28)
# updated det (19, 2.8819492909776643e-28 -> 6.565585313937484e-27)
# updated det (41, 6.565585313937484e-27 -> 2.5486225384528903e-26)
# Best det =  2.5486225e-26
# Current de =  2.5486225e-26
# 100 2699 1200
# LOADED
# /tmp/ipykernel_179949/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.3232567617636162 0.02828088 2699
# np.mean(results), mse, len(results) =  0.295975 0.034267616 1200
# ./GE_QE_AnnCURxCoItem_doctor_who_Round10_296.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.2754057058169692 0.030440249 2699
# np.mean(results), mse, len(results) =  0.2489333333333333 0.035814602 1200
# ./GE_QE_AnnCURxKMeans_doctor_who_Round10_2489.npz
# np.mean(results), mse, len(results) =  0.15399036680251946 0.040425096 2699
# np.mean(results), mse, len(results) =  0.11970000000000001 0.048677813 1200
# ./GE_QE_AnnCURxTop_doctor_who_Round10_1197.npz
# np.mean(results), mse, len(results) =  0.21482030381622821 0.03565335 2699
# np.mean(results), mse, len(results) =  0.19189166666666665 0.04078683 1200
# ./GE_QE_AnnCURxRandom_doctor_who_Round10_1919.npz
#
#
#
# DATASET =  military
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False2200.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0500.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0400.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1800.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False2000.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1600.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0600.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1200.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0900.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0200.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1000.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False2300.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1400.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1100.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1500.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0700.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0000.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0300.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0100.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False0800.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1700.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1900.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False1300.pkl
# Loading file military/ment_to_ent_scores_n_m_100_n_e_104520_all_layers_False2100.pkl
# Loaded shape =  (2400, 104520)
# Shuffling... (seed = 42)
# Best det =  0.0
# Current de =  0.0
# 100 1579 720
# LOADED
# /tmp/ipykernel_179949/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# np.mean(results), mse, len(results) =  0.4010132995566814 0.006683798 1579
# np.mean(results), mse, len(results) =  0.3356944444444444 0.011730117 720
# ./GE_QE_AnnCURxCoItem_military_Round10_3357.npz
# /home/shevkunov/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# np.mean(results), mse, len(results) =  0.35898036732108934 0.007244896 1579
# np.mean(results), mse, len(results) =  0.29630555555555554 0.010896302 720
# ./GE_QE_AnnCURxKMeans_military_Round10_2963.npz
# np.mean(results), mse, len(results) =  0.24730842305256492 0.010067298 1579
# np.mean(results), mse, len(results) =  0.1907222222222222 0.016318377 720
# ./GE_QE_AnnCURxTop_military_Round10_1907.npz
# np.mean(results), mse, len(results) =  0.2969411019632679 0.008513261 1579
# np.mean(results), mse, len(results) =  0.24543055555555554 0.013691998 720
# ./GE_QE_AnnCURxRandom_military_Round10_2454.npz

# %%
# !ls | grep "GE_QE.*RecSys.*npz"
# Out:
# GE_QE_AnnCURxCoItem_RecSysLT_Round10_6565.npz
# GE_QE_AnnCURxCoItem_RecSys_Round10_7197.npz
# GE_QE_AnnCURxKMeans_RecSysLT_Round10_613.npz
# GE_QE_AnnCURxKMeans_RecSys_Round10_7156.npz
# GE_QE_AnnCURxRandom_RecSysLT_Round10_5842.npz
# GE_QE_AnnCURxRandom_RecSys_Round10_6743.npz
# GE_QE_AnnCURxTop_RecSysLT_Round10_6695.npz
# GE_QE_AnnCURxTop_RecSys_Round10_7623.npz

# %%
# !ls | grep "GE_QE.*npz"
# Out:
# GE_QE_AnnCURxCoItem_doctor_who_Round10_296.npz
# GE_QE_AnnCURxCoItem_military_Round10_3357.npz
# GE_QE_AnnCURxCoItem_pro_wrestling_Round10_5119.npz
# GE_QE_AnnCURxCoItem_RecSysLT_Round10_6565.npz
# GE_QE_AnnCURxCoItem_RecSys_Round10_7197.npz
# GE_QE_AnnCURxCoItem_star_trek_Round10_3677.npz
# GE_QE_AnnCURxCoItem_yugioh_Round10_5617.npz
# GE_QE_AnnCURxKMeans_doctor_who_Round10_2489.npz
# GE_QE_AnnCURxKMeans_military_Round10_2963.npz
# GE_QE_AnnCURxKMeans_pro_wrestling_Round10_4834.npz
# GE_QE_AnnCURxKMeans_RecSysLT_Round10_613.npz
# GE_QE_AnnCURxKMeans_RecSys_Round10_7156.npz
# GE_QE_AnnCURxKMeans_star_trek_Round10_3101.npz
# GE_QE_AnnCURxKMeans_yugioh_Round10_5017.npz
# GE_QE_AnnCURxRandom_doctor_who_Round10_1919.npz
# GE_QE_AnnCURxRandom_military_Round10_2454.npz
# GE_QE_AnnCURxRandom_pro_wrestling_Round10_4279.npz
# GE_QE_AnnCURxRandom_RecSysLT_Round10_5842.npz
# GE_QE_AnnCURxRandom_RecSys_Round10_6743.npz
# GE_QE_AnnCURxRandom_star_trek_Round10_2287.npz
# GE_QE_AnnCURxRandom_yugioh_Round10_4721.npz
# GE_QE_AnnCURxTop_doctor_who_Round10_1197.npz
# GE_QE_AnnCURxTop_military_Round10_1907.npz
# GE_QE_AnnCURxTop_pro_wrestling_Round10_3002.npz
# GE_QE_AnnCURxTop_RecSysLT_Round10_6695.npz
# GE_QE_AnnCURxTop_RecSys_Round10_7623.npz
# GE_QE_AnnCURxTop_star_trek_Round10_1154.npz
# GE_QE_AnnCURxTop_yugioh_Round10_2429.npz

# %% [markdown]
# # RBE

# %%
#tbd - make

# %%
m_ = None
def do(ctx, name, coitem=True, kmeans=True, top=True, random=True, N = 100000, LR = 0.0005):
    def get_save_callback(t, fname):
        def save_callback(m):
            global m_
            m_ = m
            GE_ = m.get_game_embs()
            GE = np.hstack([
                GE_,
                m.g_dssm(GE_),
                m.vb.numpy().reshape((-1, 1)) ,  # Vertical bias
                ctx.get_relevs("train").mean(axis=0).reshape((-1, 1))  # popbias
            ])

            R_All = ctx.get_relevs(t)
            QE_ = m.get_user_embs(t)
            QE = np.hstack([
                QE_ @ m.W,
                m.u_dssm(QE_),
                np.ones((R_All.shape[0], 1)),
                np.ones((R_All.shape[0], 1)) * m.pb
            ])
            
            l, r = fname.split(".npz")
            score = m.get_score(t)
            fname_ = l + f"_{str(round(score, 4))}.npz" + r
            print(f"Saving {fname_} ...")
            np.savez_compressed(fname_, QE=QE, GE=GE)
        return save_callback
            
    if coitem:
        t = ctx.get_relevs("train").T
        t = (t - t.mean()) / t.std()  # like in other comparisons with RBE
        ctx.key_games = list(coitem_algorithm(100, t, t, 1e-8, eps=1e9)[0])

        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': True,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExCoItem_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if kmeans:
        ctx.set_kmeans_games_as_key()
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': True,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExKMeans_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if top:
        ctx.set_top_games_as_key()
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': True,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "save_callback": get_save_callback("test", f"./GE_QE_RBExTop_{name}.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)
        
    if random:
        ma = CBKnnV0(ctx, fit_kwargs={
            'c': 0,
            'train_matrix': True,
            'train_dssm': True,
            'train_vbias': True,
            'train_popbias': True, 'train_bias': True,
            'verbose': False, 'loss': 'softmax_signed',
            'loss_batch': 128, 'loss_q': 0.99,
            # 'dssm_l2': 5e-5,
            'activation': 'elu',
            'n': N,
            # 'ubatch': 1500,
            'score_verbose': 1000,
            'trainable_items': False,
            "TEinit": "anncur",
            "use_keys_in_train": True, # <<< DIFF HERE
            "learning_rate": LR,
            "save_callback": get_save_callback("test", f"./GE_QE_{name}_RBExRandom.npz")
        })

        ma.fit()
        tr, te = ma.get_score("train"), ma.get_score("test")
        print(tr, te)

# %%
DATASETS = ["pro_wrestling", "yugioh", "star_trek", "doctor_who", "military"]

# %%
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100
    )

    print("LOADED")
    
    do(ctx, f"{dataset}_Round10")
    
    del ctx
    gc.collect()
# Out:
# DATASET =  pro_wrestling
# Loading file pro_wrestling/ment_to_ent_scores_n_m_392_n_e_10133_all_layers_False1000.pkl
# Loading file pro_wrestling/ment_to_ent_scores_n_m_500_n_e_10133_all_layers_False0.pkl
# Loading file pro_wrestling/ment_to_ent_scores_n_m_500_n_e_10133_all_layers_False500.pkl
# Loaded shape =  (1392, 10133)
# Shuffling... (seed = 42)
# updated det (1, 5.124810435461604e-33 -> 1.0217253487036523e-31)
# updated det (2, 1.0217253487036523e-31 -> 1.2030961336739456e-31)
# updated det (11, 1.2030961336739456e-31 -> 7.606045638566237e-29)
# updated det (60, 7.606045638566237e-29 -> 3.735096148850118e-27)
# Best det =  3.735096e-27
# Current de =  3.735096e-27
# 100 873 418
# LOADED
# /tmp/ipykernel_179949/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# self.embed_users['train'].shape =  (873, 100)
# self.embed_games.shape =  (10133, 100)
# ANNCur init
# self.games2users.shape =  (100, 100)
# self.core_users_scores.shape =  (100, 10133)
# self.core_users_embs.shape =  (100, 100)
# self.ge_users.shape =  (873, 100)
#
# === Iteration 0 ===
# np.mean(results), mse, len(results) =  0.0347 tf.Tensor(38.846825, shape=(), dtype=float32) 100
# slice = key, score = 0.0347
# np.mean(results), mse, len(results) =  0.04063001145475372 tf.Tensor(38.683475, shape=(), dtype=float32) 873
# slice = train, score = 0.04063001145475372
# np.mean(results), mse, len(results) =  0.038875598086124404 tf.Tensor(39.605145, shape=(), dtype=float32) 418
# slice = test, score = 0.038875598086124404
# np.mean(results), mse, len(results) =  0.038875598086124404 tf.Tensor(39.605145, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.0389.npz ...
#
# === Iteration 1000 ===
# np.mean(results), mse, len(results) =  0.5015 tf.Tensor(96.93215, shape=(), dtype=float32) 100
# slice = key, score = 0.5015
# np.mean(results), mse, len(results) =  0.5389003436426116 tf.Tensor(92.05851, shape=(), dtype=float32) 873
# slice = train, score = 0.5389003436426116
# np.mean(results), mse, len(results) =  0.48076555023923456 tf.Tensor(97.09166, shape=(), dtype=float32) 418
# slice = test, score = 0.48076555023923456
# np.mean(results), mse, len(results) =  0.48076555023923456 tf.Tensor(97.09166, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.4808.npz ...
#
# === Iteration 2000 ===
# np.mean(results), mse, len(results) =  0.5195 tf.Tensor(142.35309, shape=(), dtype=float32) 100
# slice = key, score = 0.5195
# np.mean(results), mse, len(results) =  0.5645475372279495 tf.Tensor(136.88872, shape=(), dtype=float32) 873
# slice = train, score = 0.5645475372279495
# np.mean(results), mse, len(results) =  0.49669856459330153 tf.Tensor(145.02092, shape=(), dtype=float32) 418
# slice = test, score = 0.49669856459330153
# np.mean(results), mse, len(results) =  0.49669856459330153 tf.Tensor(145.02092, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.4967.npz ...
#
# === Iteration 3000 ===
# np.mean(results), mse, len(results) =  0.5289 tf.Tensor(206.9756, shape=(), dtype=float32) 100
# slice = key, score = 0.5289
# np.mean(results), mse, len(results) =  0.5762084765177549 tf.Tensor(201.60971, shape=(), dtype=float32) 873
# slice = train, score = 0.5762084765177549
# np.mean(results), mse, len(results) =  0.5030622009569378 tf.Tensor(215.00694, shape=(), dtype=float32) 418
# slice = test, score = 0.5030622009569378
# np.mean(results), mse, len(results) =  0.5030622009569378 tf.Tensor(215.00694, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5031.npz ...
#
# === Iteration 4000 ===
# np.mean(results), mse, len(results) =  0.5373 tf.Tensor(263.45178, shape=(), dtype=float32) 100
# slice = key, score = 0.5373
# np.mean(results), mse, len(results) =  0.5840206185567011 tf.Tensor(255.65762, shape=(), dtype=float32) 873
# slice = train, score = 0.5840206185567011
# np.mean(results), mse, len(results) =  0.5067703349282296 tf.Tensor(271.4969, shape=(), dtype=float32) 418
# slice = test, score = 0.5067703349282296
# np.mean(results), mse, len(results) =  0.5067703349282296 tf.Tensor(271.4969, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5068.npz ...
#
# === Iteration 5000 ===
# np.mean(results), mse, len(results) =  0.5398999999999999 tf.Tensor(329.34546, shape=(), dtype=float32) 100
# slice = key, score = 0.5398999999999999
# np.mean(results), mse, len(results) =  0.5889690721649484 tf.Tensor(317.70044, shape=(), dtype=float32) 873
# slice = train, score = 0.5889690721649484
# np.mean(results), mse, len(results) =  0.5064354066985646 tf.Tensor(338.48425, shape=(), dtype=float32) 418
# slice = test, score = 0.5064354066985646
# np.mean(results), mse, len(results) =  0.5064354066985646 tf.Tensor(338.48425, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5064.npz ...
#
# === Iteration 6000 ===
# np.mean(results), mse, len(results) =  0.5456 tf.Tensor(405.20834, shape=(), dtype=float32) 100
# slice = key, score = 0.5456
# np.mean(results), mse, len(results) =  0.5934707903780068 tf.Tensor(393.81946, shape=(), dtype=float32) 873
# slice = train, score = 0.5934707903780068
# np.mean(results), mse, len(results) =  0.5111722488038278 tf.Tensor(412.44724, shape=(), dtype=float32) 418
# slice = test, score = 0.5111722488038278
# np.mean(results), mse, len(results) =  0.5111722488038278 tf.Tensor(412.44724, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5112.npz ...
#
# === Iteration 7000 ===
# np.mean(results), mse, len(results) =  0.5516 tf.Tensor(474.23166, shape=(), dtype=float32) 100
# slice = key, score = 0.5516
# np.mean(results), mse, len(results) =  0.5967353951890035 tf.Tensor(466.5146, shape=(), dtype=float32) 873
# slice = train, score = 0.5967353951890035
# np.mean(results), mse, len(results) =  0.5099521531100478 tf.Tensor(492.04938, shape=(), dtype=float32) 418
# slice = test, score = 0.5099521531100478
# np.mean(results), mse, len(results) =  0.5099521531100478 tf.Tensor(492.04938, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.51.npz ...
#
# === Iteration 8000 ===
# np.mean(results), mse, len(results) =  0.5522 tf.Tensor(555.3138, shape=(), dtype=float32) 100
# slice = key, score = 0.5522
# np.mean(results), mse, len(results) =  0.6022107674684994 tf.Tensor(537.08264, shape=(), dtype=float32) 873
# slice = train, score = 0.6022107674684994
# np.mean(results), mse, len(results) =  0.5154066985645933 tf.Tensor(564.1883, shape=(), dtype=float32) 418
# slice = test, score = 0.5154066985645933
# np.mean(results), mse, len(results) =  0.5154066985645933 tf.Tensor(564.1883, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5154.npz ...
#
# === Iteration 9000 ===
# np.mean(results), mse, len(results) =  0.5561 tf.Tensor(615.63544, shape=(), dtype=float32) 100
# slice = key, score = 0.5561
# np.mean(results), mse, len(results) =  0.6057388316151202 tf.Tensor(605.39667, shape=(), dtype=float32) 873
# slice = train, score = 0.6057388316151202
# np.mean(results), mse, len(results) =  0.519976076555024 tf.Tensor(626.72754, shape=(), dtype=float32) 418
# slice = test, score = 0.519976076555024
# np.mean(results), mse, len(results) =  0.519976076555024 tf.Tensor(626.72754, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.52.npz ...
#
# === Iteration 10000 ===
# np.mean(results), mse, len(results) =  0.5549 tf.Tensor(691.2402, shape=(), dtype=float32) 100
# slice = key, score = 0.5549
# np.mean(results), mse, len(results) =  0.6047995418098511 tf.Tensor(680.3917, shape=(), dtype=float32) 873
# slice = train, score = 0.6047995418098511
# np.mean(results), mse, len(results) =  0.5135645933014354 tf.Tensor(711.7663, shape=(), dtype=float32) 418
# slice = test, score = 0.5135645933014354
#
# === Iteration 11000 ===
# np.mean(results), mse, len(results) =  0.5573 tf.Tensor(783.8204, shape=(), dtype=float32) 100
# slice = key, score = 0.5573
# np.mean(results), mse, len(results) =  0.6061970217640321 tf.Tensor(767.68365, shape=(), dtype=float32) 873
# slice = train, score = 0.6061970217640321
# np.mean(results), mse, len(results) =  0.5128468899521531 tf.Tensor(811.7668, shape=(), dtype=float32) 418
# slice = test, score = 0.5128468899521531
# np.mean(results), mse, len(results) =  0.5128468899521531 tf.Tensor(811.7668, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5128.npz ...
#
# === Iteration 12000 ===
# np.mean(results), mse, len(results) =  0.5652000000000001 tf.Tensor(843.6094, shape=(), dtype=float32) 100
# slice = key, score = 0.5652000000000001
# np.mean(results), mse, len(results) =  0.6143184421534936 tf.Tensor(832.2398, shape=(), dtype=float32) 873
# slice = train, score = 0.6143184421534936
# np.mean(results), mse, len(results) =  0.5213157894736842 tf.Tensor(865.1825, shape=(), dtype=float32) 418
# slice = test, score = 0.5213157894736842
# np.mean(results), mse, len(results) =  0.5213157894736842 tf.Tensor(865.1825, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5213.npz ...
#
# === Iteration 13000 ===
# np.mean(results), mse, len(results) =  0.5649 tf.Tensor(934.2052, shape=(), dtype=float32) 100
# slice = key, score = 0.5649
# np.mean(results), mse, len(results) =  0.6090148911798398 tf.Tensor(921.9965, shape=(), dtype=float32) 873
# slice = train, score = 0.6090148911798398
# np.mean(results), mse, len(results) =  0.5154545454545454 tf.Tensor(972.0343, shape=(), dtype=float32) 418
# slice = test, score = 0.5154545454545454
#
# === Iteration 14000 ===
# np.mean(results), mse, len(results) =  0.5649000000000001 tf.Tensor(1024.5127, shape=(), dtype=float32) 100
# slice = key, score = 0.5649000000000001
# np.mean(results), mse, len(results) =  0.6130011454753722 tf.Tensor(1000.46484, shape=(), dtype=float32) 873
# slice = train, score = 0.6130011454753722
# np.mean(results), mse, len(results) =  0.5164114832535885 tf.Tensor(1061.1006, shape=(), dtype=float32) 418
# slice = test, score = 0.5164114832535885
#
# === Iteration 15000 ===
# np.mean(results), mse, len(results) =  0.5654000000000001 tf.Tensor(1105.9341, shape=(), dtype=float32) 100
# slice = key, score = 0.5654000000000001
# np.mean(results), mse, len(results) =  0.6127835051546392 tf.Tensor(1107.9373, shape=(), dtype=float32) 873
# slice = train, score = 0.6127835051546392
# np.mean(results), mse, len(results) =  0.5146172248803829 tf.Tensor(1159.4252, shape=(), dtype=float32) 418
# slice = test, score = 0.5146172248803829
#
# === Iteration 16000 ===
# np.mean(results), mse, len(results) =  0.5735 tf.Tensor(1203.3303, shape=(), dtype=float32) 100
# slice = key, score = 0.5735
# np.mean(results), mse, len(results) =  0.6193928980526919 tf.Tensor(1176.5588, shape=(), dtype=float32) 873
# slice = train, score = 0.6193928980526919
# np.mean(results), mse, len(results) =  0.5197129186602871 tf.Tensor(1232.9316, shape=(), dtype=float32) 418
# slice = test, score = 0.5197129186602871
# np.mean(results), mse, len(results) =  0.5197129186602871 tf.Tensor(1232.9316, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5197.npz ...
#
# === Iteration 17000 ===
# np.mean(results), mse, len(results) =  0.5685 tf.Tensor(1313.4779, shape=(), dtype=float32) 100
# slice = key, score = 0.5685
# np.mean(results), mse, len(results) =  0.616368843069874 tf.Tensor(1278.055, shape=(), dtype=float32) 873
# slice = train, score = 0.616368843069874
# np.mean(results), mse, len(results) =  0.5173684210526316 tf.Tensor(1343.4307, shape=(), dtype=float32) 418
# slice = test, score = 0.5173684210526316
#
# === Iteration 18000 ===
# np.mean(results), mse, len(results) =  0.569 tf.Tensor(1386.0294, shape=(), dtype=float32) 100
# slice = key, score = 0.569
# np.mean(results), mse, len(results) =  0.6168384879725086 tf.Tensor(1348.5697, shape=(), dtype=float32) 873
# slice = train, score = 0.6168384879725086
# np.mean(results), mse, len(results) =  0.5179186602870813 tf.Tensor(1414.9247, shape=(), dtype=float32) 418
# slice = test, score = 0.5179186602870813
#
# === Iteration 19000 ===
# np.mean(results), mse, len(results) =  0.5758 tf.Tensor(1489.126, shape=(), dtype=float32) 100
# slice = key, score = 0.5758
# np.mean(results), mse, len(results) =  0.6195074455899198 tf.Tensor(1456.9535, shape=(), dtype=float32) 873
# slice = train, score = 0.6195074455899198
# np.mean(results), mse, len(results) =  0.5183732057416268 tf.Tensor(1533.108, shape=(), dtype=float32) 418
# slice = test, score = 0.5183732057416268
# np.mean(results), mse, len(results) =  0.5183732057416268 tf.Tensor(1533.108, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5184.npz ...
#
# === Iteration 20000 ===
# np.mean(results), mse, len(results) =  0.5744 tf.Tensor(1558.5356, shape=(), dtype=float32) 100
# slice = key, score = 0.5744
# np.mean(results), mse, len(results) =  0.6228293241695304 tf.Tensor(1517.0394, shape=(), dtype=float32) 873
# slice = train, score = 0.6228293241695304
# np.mean(results), mse, len(results) =  0.5216028708133971 tf.Tensor(1590.7854, shape=(), dtype=float32) 418
# slice = test, score = 0.5216028708133971
# np.mean(results), mse, len(results) =  0.5216028708133971 tf.Tensor(1590.7854, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5216.npz ...
#
# === Iteration 21000 ===
# np.mean(results), mse, len(results) =  0.5770000000000001 tf.Tensor(1610.2789, shape=(), dtype=float32) 100
# slice = key, score = 0.5770000000000001
# np.mean(results), mse, len(results) =  0.6234364261168385 tf.Tensor(1578.676, shape=(), dtype=float32) 873
# slice = train, score = 0.6234364261168385
# np.mean(results), mse, len(results) =  0.5226076555023923 tf.Tensor(1647.6815, shape=(), dtype=float32) 418
# slice = test, score = 0.5226076555023923
# np.mean(results), mse, len(results) =  0.5226076555023923 tf.Tensor(1647.6815, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5226.npz ...
#
# === Iteration 22000 ===
# np.mean(results), mse, len(results) =  0.5797000000000001 tf.Tensor(1737.6727, shape=(), dtype=float32) 100
# slice = key, score = 0.5797000000000001
# np.mean(results), mse, len(results) =  0.6231156930126003 tf.Tensor(1706.4813, shape=(), dtype=float32) 873
# slice = train, score = 0.6231156930126003
# np.mean(results), mse, len(results) =  0.5205023923444976 tf.Tensor(1771.451, shape=(), dtype=float32) 418
# slice = test, score = 0.5205023923444976
#
# === Iteration 23000 ===
# np.mean(results), mse, len(results) =  0.5783 tf.Tensor(1846.9075, shape=(), dtype=float32) 100
# slice = key, score = 0.5783
# np.mean(results), mse, len(results) =  0.6251088201603666 tf.Tensor(1803.0972, shape=(), dtype=float32) 873
# slice = train, score = 0.6251088201603666
# np.mean(results), mse, len(results) =  0.5203349282296651 tf.Tensor(1868.7311, shape=(), dtype=float32) 418
# slice = test, score = 0.5203349282296651
# np.mean(results), mse, len(results) =  0.5203349282296651 tf.Tensor(1868.7311, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5203.npz ...
#
# === Iteration 24000 ===
# np.mean(results), mse, len(results) =  0.5783 tf.Tensor(1943.1277, shape=(), dtype=float32) 100
# slice = key, score = 0.5783
# np.mean(results), mse, len(results) =  0.6240091638029782 tf.Tensor(1880.4014, shape=(), dtype=float32) 873
# slice = train, score = 0.6240091638029782
# np.mean(results), mse, len(results) =  0.5205263157894737 tf.Tensor(1965.993, shape=(), dtype=float32) 418
# slice = test, score = 0.5205263157894737
#
# === Iteration 25000 ===
# np.mean(results), mse, len(results) =  0.5835 tf.Tensor(2023.0515, shape=(), dtype=float32) 100
# slice = key, score = 0.5835
# np.mean(results), mse, len(results) =  0.625589919816724 tf.Tensor(1983.2068, shape=(), dtype=float32) 873
# slice = train, score = 0.625589919816724
# np.mean(results), mse, len(results) =  0.5185167464114833 tf.Tensor(2063.8274, shape=(), dtype=float32) 418
# slice = test, score = 0.5185167464114833
# np.mean(results), mse, len(results) =  0.5185167464114833 tf.Tensor(2063.8274, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5185.npz ...
#
# === Iteration 26000 ===
# np.mean(results), mse, len(results) =  0.5827 tf.Tensor(2042.1304, shape=(), dtype=float32) 100
# slice = key, score = 0.5827
# np.mean(results), mse, len(results) =  0.6293241695303551 tf.Tensor(2020.0359, shape=(), dtype=float32) 873
# slice = train, score = 0.6293241695303551
# np.mean(results), mse, len(results) =  0.5204306220095695 tf.Tensor(2095.6619, shape=(), dtype=float32) 418
# slice = test, score = 0.5204306220095695
# np.mean(results), mse, len(results) =  0.5204306220095695 tf.Tensor(2095.6619, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5204.npz ...
#
# === Iteration 27000 ===
# np.mean(results), mse, len(results) =  0.5827 tf.Tensor(2139.612, shape=(), dtype=float32) 100
# slice = key, score = 0.5827
# np.mean(results), mse, len(results) =  0.630229095074456 tf.Tensor(2095.3086, shape=(), dtype=float32) 873
# slice = train, score = 0.630229095074456
# np.mean(results), mse, len(results) =  0.5222966507177034 tf.Tensor(2191.9976, shape=(), dtype=float32) 418
# slice = test, score = 0.5222966507177034
# np.mean(results), mse, len(results) =  0.5222966507177034 tf.Tensor(2191.9976, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5223.npz ...
#
# === Iteration 28000 ===
# np.mean(results), mse, len(results) =  0.5856 tf.Tensor(2237.3884, shape=(), dtype=float32) 100
# slice = key, score = 0.5856
# np.mean(results), mse, len(results) =  0.6269873997709049 tf.Tensor(2188.5117, shape=(), dtype=float32) 873
# slice = train, score = 0.6269873997709049
# np.mean(results), mse, len(results) =  0.5163157894736842 tf.Tensor(2302.5498, shape=(), dtype=float32) 418
# slice = test, score = 0.5163157894736842
# === Iteration 29000 ===
# np.mean(results), mse, len(results) =  0.5889 tf.Tensor(2286.8896, shape=(), dtype=float32) 100
# slice = key, score = 0.5889
# np.mean(results), mse, len(results) =  0.6352233676975946 tf.Tensor(2235.478, shape=(), dtype=float32) 873
# slice = train, score = 0.6352233676975946
# np.mean(results), mse, len(results) =  0.5233014354066986 tf.Tensor(2325.4065, shape=(), dtype=float32) 418
# slice = test, score = 0.5233014354066986
# np.mean(results), mse, len(results) =  0.5233014354066986 tf.Tensor(2325.4065, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5233.npz ...
#
# === Iteration 30000 ===
# np.mean(results), mse, len(results) =  0.5827 tf.Tensor(2464.0854, shape=(), dtype=float32) 100
# slice = key, score = 0.5827
# np.mean(results), mse, len(results) =  0.6302520045819016 tf.Tensor(2370.8584, shape=(), dtype=float32) 873
# slice = train, score = 0.6302520045819016
# np.mean(results), mse, len(results) =  0.5185406698564593 tf.Tensor(2486.8125, shape=(), dtype=float32) 418
# slice = test, score = 0.5185406698564593
#
# === Iteration 31000 ===
# np.mean(results), mse, len(results) =  0.5874 tf.Tensor(2486.6755, shape=(), dtype=float32) 100
# slice = key, score = 0.5874
# np.mean(results), mse, len(results) =  0.6337915234822451 tf.Tensor(2431.9055, shape=(), dtype=float32) 873
# slice = train, score = 0.6337915234822451
# np.mean(results), mse, len(results) =  0.5228468899521531 tf.Tensor(2528.5474, shape=(), dtype=float32) 418
# slice = test, score = 0.5228468899521531
#
# === Iteration 32000 ===
# np.mean(results), mse, len(results) =  0.5911 tf.Tensor(2547.272, shape=(), dtype=float32) 100
# slice = key, score = 0.5911
# np.mean(results), mse, len(results) =  0.634410080183276 tf.Tensor(2478.7732, shape=(), dtype=float32) 873
# slice = train, score = 0.634410080183276
# np.mean(results), mse, len(results) =  0.5238755980861245 tf.Tensor(2575.6174, shape=(), dtype=float32) 418
# slice = test, score = 0.5238755980861245
#
# === Iteration 33000 ===
# np.mean(results), mse, len(results) =  0.5867 tf.Tensor(2756.485, shape=(), dtype=float32) 100
# slice = key, score = 0.5867
# np.mean(results), mse, len(results) =  0.6305727376861398 tf.Tensor(2680.3484, shape=(), dtype=float32) 873
# slice = train, score = 0.6305727376861398
# np.mean(results), mse, len(results) =  0.5219377990430623 tf.Tensor(2783.1028, shape=(), dtype=float32) 418
# slice = test, score = 0.5219377990430623
#
# === Iteration 34000 ===
# np.mean(results), mse, len(results) =  0.5885 tf.Tensor(2741.266, shape=(), dtype=float32) 100
# slice = key, score = 0.5885
# np.mean(results), mse, len(results) =  0.6332875143184422 tf.Tensor(2696.5554, shape=(), dtype=float32) 873
# slice = train, score = 0.6332875143184422
# np.mean(results), mse, len(results) =  0.5185885167464115 tf.Tensor(2797.6077, shape=(), dtype=float32) 418
# slice = test, score = 0.5185885167464115
#
# === Iteration 35000 ===
# np.mean(results), mse, len(results) =  0.5880000000000001 tf.Tensor(2842.0427, shape=(), dtype=float32) 100
# slice = key, score = 0.5880000000000001
# np.mean(results), mse, len(results) =  0.6322680412371134 tf.Tensor(2763.113, shape=(), dtype=float32) 873
# slice = train, score = 0.6322680412371134
# np.mean(results), mse, len(results) =  0.5190669856459331 tf.Tensor(2884.8633, shape=(), dtype=float32) 418
# slice = test, score = 0.5190669856459331
#
# === Iteration 36000 ===
# np.mean(results), mse, len(results) =  0.5896000000000001 tf.Tensor(2920.024, shape=(), dtype=float32) 100
# slice = key, score = 0.5896000000000001
# np.mean(results), mse, len(results) =  0.6381901489117984 tf.Tensor(2823.297, shape=(), dtype=float32) 873
# slice = train, score = 0.6381901489117984
# np.mean(results), mse, len(results) =  0.5219138755980861 tf.Tensor(2932.3872, shape=(), dtype=float32) 418
# slice = test, score = 0.5219138755980861
# np.mean(results), mse, len(results) =  0.5219138755980861 tf.Tensor(2932.3872, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5219.npz ...
#
# === Iteration 37000 ===
# np.mean(results), mse, len(results) =  0.5943999999999999 tf.Tensor(2997.1387, shape=(), dtype=float32) 100
# slice = key, score = 0.5943999999999999
# np.mean(results), mse, len(results) =  0.6402405498281787 tf.Tensor(2907.0056, shape=(), dtype=float32) 873
# slice = train, score = 0.6402405498281787
# np.mean(results), mse, len(results) =  0.5228708133971292 tf.Tensor(3026.0154, shape=(), dtype=float32) 418
# slice = test, score = 0.5228708133971292
# np.mean(results), mse, len(results) =  0.5228708133971292 tf.Tensor(3026.0154, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5229.npz ...
#
# === Iteration 38000 ===
# np.mean(results), mse, len(results) =  0.5897 tf.Tensor(3130.4167, shape=(), dtype=float32) 100
# slice = key, score = 0.5897
# np.mean(results), mse, len(results) =  0.6369644902634592 tf.Tensor(3035.5178, shape=(), dtype=float32) 873
# slice = train, score = 0.6369644902634592
# np.mean(results), mse, len(results) =  0.5231339712918661 tf.Tensor(3138.1597, shape=(), dtype=float32) 418
# slice = test, score = 0.5231339712918661
#
# === Iteration 39000 ===
# np.mean(results), mse, len(results) =  0.5932 tf.Tensor(3170.1147, shape=(), dtype=float32) 100
# slice = key, score = 0.5932
# np.mean(results), mse, len(results) =  0.6405269186712487 tf.Tensor(3069.8054, shape=(), dtype=float32) 873
# slice = train, score = 0.6405269186712487
# np.mean(results), mse, len(results) =  0.5219138755980861 tf.Tensor(3189.4827, shape=(), dtype=float32) 418
# slice = test, score = 0.5219138755980861
# np.mean(results), mse, len(results) =  0.5219138755980861 tf.Tensor(3189.4827, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5219.npz ...
#
# === Iteration 40000 ===
# np.mean(results), mse, len(results) =  0.5892000000000001 tf.Tensor(3304.463, shape=(), dtype=float32) 100
# slice = key, score = 0.5892000000000001
# np.mean(results), mse, len(results) =  0.6403665521191294 tf.Tensor(3191.0823, shape=(), dtype=float32) 873
# slice = train, score = 0.6403665521191294
# np.mean(results), mse, len(results) =  0.5231100478468899 tf.Tensor(3306.3577, shape=(), dtype=float32) 418
# slice = test, score = 0.5231100478468899
#
# === Iteration 41000 ===
# np.mean(results), mse, len(results) =  0.5872 tf.Tensor(3411.112, shape=(), dtype=float32) 100
# slice = key, score = 0.5872
# np.mean(results), mse, len(results) =  0.6363802978235968 tf.Tensor(3300.5586, shape=(), dtype=float32) 873
# slice = train, score = 0.6363802978235968
# np.mean(results), mse, len(results) =  0.5222966507177034 tf.Tensor(3427.7627, shape=(), dtype=float32) 418
# slice = test, score = 0.5222966507177034
#
# === Iteration 42000 ===
# np.mean(results), mse, len(results) =  0.5922 tf.Tensor(3532.4456, shape=(), dtype=float32) 100
# slice = key, score = 0.5922
# np.mean(results), mse, len(results) =  0.6410194730813288 tf.Tensor(3410.153, shape=(), dtype=float32) 873
# slice = train, score = 0.6410194730813288
# np.mean(results), mse, len(results) =  0.5204306220095694 tf.Tensor(3548.9849, shape=(), dtype=float32) 418
# slice = test, score = 0.5204306220095694
# np.mean(results), mse, len(results) =  0.5204306220095694 tf.Tensor(3548.9849, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5204.npz ...
#
# === Iteration 43000 ===
# np.mean(results), mse, len(results) =  0.5956 tf.Tensor(3538.9265, shape=(), dtype=float32) 100
# slice = key, score = 0.5956
# np.mean(results), mse, len(results) =  0.6413058419243987 tf.Tensor(3444.8074, shape=(), dtype=float32) 873
# slice = train, score = 0.6413058419243987
# np.mean(results), mse, len(results) =  0.5217224880382775 tf.Tensor(3581.1956, shape=(), dtype=float32) 418
# slice = test, score = 0.5217224880382775
# np.mean(results), mse, len(results) =  0.5217224880382775 tf.Tensor(3581.1956, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5217.npz ...
#
# === Iteration 44000 ===
# np.mean(results), mse, len(results) =  0.5954999999999999 tf.Tensor(3687.536, shape=(), dtype=float32) 100
# slice = key, score = 0.5954999999999999
# np.mean(results), mse, len(results) =  0.6396792668957618 tf.Tensor(3537.6846, shape=(), dtype=float32) 873
# slice = train, score = 0.6396792668957618
# np.mean(results), mse, len(results) =  0.5240191387559809 tf.Tensor(3659.4016, shape=(), dtype=float32) 418
# slice = test, score = 0.5240191387559809
# === Iteration 45000 ===
# np.mean(results), mse, len(results) =  0.5937 tf.Tensor(3710.824, shape=(), dtype=float32) 100
# slice = key, score = 0.5937
# np.mean(results), mse, len(results) =  0.6434135166093929 tf.Tensor(3603.2373, shape=(), dtype=float32) 873
# slice = train, score = 0.6434135166093929
# np.mean(results), mse, len(results) =  0.5258851674641148 tf.Tensor(3747.2686, shape=(), dtype=float32) 418
# slice = test, score = 0.5258851674641148
# np.mean(results), mse, len(results) =  0.5258851674641148 tf.Tensor(3747.2686, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5259.npz ...
#
# === Iteration 46000 ===
# np.mean(results), mse, len(results) =  0.6002000000000001 tf.Tensor(3771.4104, shape=(), dtype=float32) 100
# slice = key, score = 0.6002000000000001
# np.mean(results), mse, len(results) =  0.6455555555555554 tf.Tensor(3689.6235, shape=(), dtype=float32) 873
# slice = train, score = 0.6455555555555554
# np.mean(results), mse, len(results) =  0.5267224880382776 tf.Tensor(3809.1223, shape=(), dtype=float32) 418
# slice = test, score = 0.5267224880382776
# np.mean(results), mse, len(results) =  0.5267224880382776 tf.Tensor(3809.1223, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5267.npz ...
#
# === Iteration 47000 ===
# np.mean(results), mse, len(results) =  0.5945999999999999 tf.Tensor(4007.9805, shape=(), dtype=float32) 100
# slice = key, score = 0.5945999999999999
# np.mean(results), mse, len(results) =  0.6434936998854525 tf.Tensor(3854.1091, shape=(), dtype=float32) 873
# slice = train, score = 0.6434936998854525
# np.mean(results), mse, len(results) =  0.5232535885167464 tf.Tensor(3988.8706, shape=(), dtype=float32) 418
# slice = test, score = 0.5232535885167464
#
# === Iteration 48000 ===
# np.mean(results), mse, len(results) =  0.5982999999999999 tf.Tensor(3987.2905, shape=(), dtype=float32) 100
# slice = key, score = 0.5982999999999999
# np.mean(results), mse, len(results) =  0.6446620847651775 tf.Tensor(3894.589, shape=(), dtype=float32) 873
# slice = train, score = 0.6446620847651775
# np.mean(results), mse, len(results) =  0.526866028708134 tf.Tensor(4005.7446, shape=(), dtype=float32) 418
# slice = test, score = 0.526866028708134
#
# === Iteration 49000 ===
# np.mean(results), mse, len(results) =  0.6003000000000001 tf.Tensor(4047.726, shape=(), dtype=float32) 100
# slice = key, score = 0.6003000000000001
# np.mean(results), mse, len(results) =  0.6467239404352807 tf.Tensor(3919.2917, shape=(), dtype=float32) 873
# slice = train, score = 0.6467239404352807
# np.mean(results), mse, len(results) =  0.5239234449760766 tf.Tensor(4042.9944, shape=(), dtype=float32) 418
# slice = test, score = 0.5239234449760766
# np.mean(results), mse, len(results) =  0.5239234449760766 tf.Tensor(4042.9944, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5239.npz ...
#
# === Iteration 50000 ===
# np.mean(results), mse, len(results) =  0.6004999999999999 tf.Tensor(4214.31, shape=(), dtype=float32) 100
# slice = key, score = 0.6004999999999999
# np.mean(results), mse, len(results) =  0.6426116838487973 tf.Tensor(4084.6052, shape=(), dtype=float32) 873
# slice = train, score = 0.6426116838487973
# np.mean(results), mse, len(results) =  0.5207894736842105 tf.Tensor(4205.5493, shape=(), dtype=float32) 418
# slice = test, score = 0.5207894736842105
#
# === Iteration 51000 ===
# np.mean(results), mse, len(results) =  0.6019000000000001 tf.Tensor(4237.395, shape=(), dtype=float32) 100
# slice = key, score = 0.6019000000000001
# np.mean(results), mse, len(results) =  0.6455555555555554 tf.Tensor(4138.8696, shape=(), dtype=float32) 873
# slice = train, score = 0.6455555555555554
# np.mean(results), mse, len(results) =  0.5233492822966507 tf.Tensor(4277.268, shape=(), dtype=float32) 418
# slice = test, score = 0.5233492822966507
#
# === Iteration 52000 ===
# np.mean(results), mse, len(results) =  0.5950000000000001 tf.Tensor(4423.646, shape=(), dtype=float32) 100
# slice = key, score = 0.5950000000000001
# np.mean(results), mse, len(results) =  0.6437915234822451 tf.Tensor(4260.4126, shape=(), dtype=float32) 873
# slice = train, score = 0.6437915234822451
# np.mean(results), mse, len(results) =  0.5198325358851674 tf.Tensor(4427.847, shape=(), dtype=float32) 418
# slice = test, score = 0.5198325358851674
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.5992999999999999 tf.Tensor(4436.3184, shape=(), dtype=float32) 100
# slice = key, score = 0.5992999999999999
# np.mean(results), mse, len(results) =  0.6464261168384879 tf.Tensor(4280.649, shape=(), dtype=float32) 873
# slice = train, score = 0.6464261168384879
# np.mean(results), mse, len(results) =  0.5210287081339713 tf.Tensor(4445.677, shape=(), dtype=float32) 418
# slice = test, score = 0.5210287081339713
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.6047 tf.Tensor(4467.6187, shape=(), dtype=float32) 100
# slice = key, score = 0.6047
# np.mean(results), mse, len(results) =  0.6499427262313862 tf.Tensor(4355.0493, shape=(), dtype=float32) 873
# slice = train, score = 0.6499427262313862
# np.mean(results), mse, len(results) =  0.5248564593301435 tf.Tensor(4477.756, shape=(), dtype=float32) 418
# slice = test, score = 0.5248564593301435
# np.mean(results), mse, len(results) =  0.5248564593301435 tf.Tensor(4477.756, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5249.npz ...
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.6023999999999999 tf.Tensor(4520.9653, shape=(), dtype=float32) 100
# slice = key, score = 0.6023999999999999
# np.mean(results), mse, len(results) =  0.6481099656357387 tf.Tensor(4414.4634, shape=(), dtype=float32) 873
# slice = train, score = 0.6481099656357387
# np.mean(results), mse, len(results) =  0.5240909090909092 tf.Tensor(4554.3594, shape=(), dtype=float32) 418
# slice = test, score = 0.5240909090909092
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.6063000000000001 tf.Tensor(4634.625, shape=(), dtype=float32) 100
# slice = key, score = 0.6063000000000001
# np.mean(results), mse, len(results) =  0.6486139747995419 tf.Tensor(4451.8145, shape=(), dtype=float32) 873
# slice = train, score = 0.6486139747995419
# np.mean(results), mse, len(results) =  0.5235645933014355 tf.Tensor(4648.985, shape=(), dtype=float32) 418
# slice = test, score = 0.5235645933014355
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.6008 tf.Tensor(4775.289, shape=(), dtype=float32) 100
# slice = key, score = 0.6008
# np.mean(results), mse, len(results) =  0.6465406643757159 tf.Tensor(4646.366, shape=(), dtype=float32) 873
# slice = train, score = 0.6465406643757159
# np.mean(results), mse, len(results) =  0.5224401913875598 tf.Tensor(4768.2812, shape=(), dtype=float32) 418
# slice = test, score = 0.5224401913875598
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.6021 tf.Tensor(4843.52, shape=(), dtype=float32) 100
# slice = key, score = 0.6021
# np.mean(results), mse, len(results) =  0.6523138602520047 tf.Tensor(4715.3594, shape=(), dtype=float32) 873
# slice = train, score = 0.6523138602520047
# np.mean(results), mse, len(results) =  0.5248325358851674 tf.Tensor(4840.4624, shape=(), dtype=float32) 418
# slice = test, score = 0.5248325358851674
# np.mean(results), mse, len(results) =  0.5248325358851674 tf.Tensor(4840.4624, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5248.npz ...
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.6001000000000001 tf.Tensor(4972.584, shape=(), dtype=float32) 100
# slice = key, score = 0.6001000000000001
# np.mean(results), mse, len(results) =  0.6482817869415808 tf.Tensor(4845.4434, shape=(), dtype=float32) 873
# slice = train, score = 0.6482817869415808
# np.mean(results), mse, len(results) =  0.5238277511961723 tf.Tensor(4991.8794, shape=(), dtype=float32) 418
# slice = test, score = 0.5238277511961723
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.6043999999999998 tf.Tensor(5032.968, shape=(), dtype=float32) 100
# slice = key, score = 0.6043999999999998
# np.mean(results), mse, len(results) =  0.6490950744558993 tf.Tensor(4939.299, shape=(), dtype=float32) 873
# slice = train, score = 0.6490950744558993
# np.mean(results), mse, len(results) =  0.5238755980861245 tf.Tensor(5101.7207, shape=(), dtype=float32) 418
# slice = test, score = 0.5238755980861245
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.6090999999999999 tf.Tensor(5093.119, shape=(), dtype=float32) 100
# slice = key, score = 0.6090999999999999
# np.mean(results), mse, len(results) =  0.6516380297823596 tf.Tensor(4988.4985, shape=(), dtype=float32) 873
# slice = train, score = 0.6516380297823596
# np.mean(results), mse, len(results) =  0.5225837320574163 tf.Tensor(5170.108, shape=(), dtype=float32) 418
# slice = test, score = 0.5225837320574163
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.6086999999999999 tf.Tensor(5176.2812, shape=(), dtype=float32) 100
# slice = key, score = 0.6086999999999999
# np.mean(results), mse, len(results) =  0.6495647193585338 tf.Tensor(5089.7905, shape=(), dtype=float32) 873
# slice = train, score = 0.6495647193585338
# np.mean(results), mse, len(results) =  0.5274162679425837 tf.Tensor(5223.9556, shape=(), dtype=float32) 418
# slice = test, score = 0.5274162679425837
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.6114999999999999 tf.Tensor(5254.8125, shape=(), dtype=float32) 100
# slice = key, score = 0.6114999999999999
# np.mean(results), mse, len(results) =  0.6542382588774341 tf.Tensor(5155.5366, shape=(), dtype=float32) 873
# slice = train, score = 0.6542382588774341
# np.mean(results), mse, len(results) =  0.5237799043062201 tf.Tensor(5290.752, shape=(), dtype=float32) 418
# slice = test, score = 0.5237799043062201
# np.mean(results), mse, len(results) =  0.5237799043062201 tf.Tensor(5290.752, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5238.npz ...
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.6087 tf.Tensor(5473.646, shape=(), dtype=float32) 100
# slice = key, score = 0.6087
# np.mean(results), mse, len(results) =  0.6541122565864833 tf.Tensor(5314.899, shape=(), dtype=float32) 873
# slice = train, score = 0.6541122565864833
# np.mean(results), mse, len(results) =  0.5242344497607655 tf.Tensor(5504.3965, shape=(), dtype=float32) 418
# slice = test, score = 0.5242344497607655
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.6099 tf.Tensor(5597.184, shape=(), dtype=float32) 100
# slice = key, score = 0.6099
# np.mean(results), mse, len(results) =  0.6529782359679266 tf.Tensor(5455.7217, shape=(), dtype=float32) 873
# slice = train, score = 0.6529782359679266
# np.mean(results), mse, len(results) =  0.5261004784688996 tf.Tensor(5622.8804, shape=(), dtype=float32) 418
# slice = test, score = 0.5261004784688996
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.6130000000000001 tf.Tensor(5487.764, shape=(), dtype=float32) 100
# slice = key, score = 0.6130000000000001
# np.mean(results), mse, len(results) =  0.6564146620847652 tf.Tensor(5386.554, shape=(), dtype=float32) 873
# slice = train, score = 0.6564146620847652
# np.mean(results), mse, len(results) =  0.5269377990430621 tf.Tensor(5559.4795, shape=(), dtype=float32) 418
# slice = test, score = 0.5269377990430621
# np.mean(results), mse, len(results) =  0.5269377990430621 tf.Tensor(5559.4795, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5269.npz ...
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.6088 tf.Tensor(5560.013, shape=(), dtype=float32) 100
# slice = key, score = 0.6088
# np.mean(results), mse, len(results) =  0.6523940435280642 tf.Tensor(5437.0957, shape=(), dtype=float32) 873
# slice = train, score = 0.6523940435280642
# np.mean(results), mse, len(results) =  0.5208133971291866 tf.Tensor(5640.7705, shape=(), dtype=float32) 418
# slice = test, score = 0.5208133971291866
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.6079000000000001 tf.Tensor(5803.319, shape=(), dtype=float32) 100
# slice = key, score = 0.6079000000000001
# np.mean(results), mse, len(results) =  0.6550630011454756 tf.Tensor(5662.7827, shape=(), dtype=float32) 873
# slice = train, score = 0.6550630011454756
# np.mean(results), mse, len(results) =  0.521555023923445 tf.Tensor(5885.83, shape=(), dtype=float32) 418
# slice = test, score = 0.521555023923445
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.6093 tf.Tensor(5998.5356, shape=(), dtype=float32) 100
# slice = key, score = 0.6093
# np.mean(results), mse, len(results) =  0.6537800687285223 tf.Tensor(5866.603, shape=(), dtype=float32) 873
# slice = train, score = 0.6537800687285223
# np.mean(results), mse, len(results) =  0.5232775119617225 tf.Tensor(6091.6973, shape=(), dtype=float32) 418
# slice = test, score = 0.5232775119617225
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.6075 tf.Tensor(5963.809, shape=(), dtype=float32) 100
# slice = key, score = 0.6075
# np.mean(results), mse, len(results) =  0.6539747995418099 tf.Tensor(5883.9, shape=(), dtype=float32) 873
# slice = train, score = 0.6539747995418099
# np.mean(results), mse, len(results) =  0.5241387559808613 tf.Tensor(6087.781, shape=(), dtype=float32) 418
# slice = test, score = 0.5241387559808613
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.6117 tf.Tensor(6028.49, shape=(), dtype=float32) 100
# slice = key, score = 0.6117
# np.mean(results), mse, len(results) =  0.6574570446735396 tf.Tensor(5885.6255, shape=(), dtype=float32) 873
# slice = train, score = 0.6574570446735396
# np.mean(results), mse, len(results) =  0.5222727272727273 tf.Tensor(6102.626, shape=(), dtype=float32) 418
# slice = test, score = 0.5222727272727273
# np.mean(results), mse, len(results) =  0.5222727272727273 tf.Tensor(6102.626, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5223.npz ...
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.6116999999999999 tf.Tensor(6257.4043, shape=(), dtype=float32) 100
# slice = key, score = 0.6116999999999999
# np.mean(results), mse, len(results) =  0.6527605956471936 tf.Tensor(6152.392, shape=(), dtype=float32) 873
# slice = train, score = 0.6527605956471936
# np.mean(results), mse, len(results) =  0.5247846889952154 tf.Tensor(6347.26, shape=(), dtype=float32) 418
# slice = test, score = 0.5247846889952154
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.6078000000000001 tf.Tensor(6296.409, shape=(), dtype=float32) 100
# slice = key, score = 0.6078000000000001
# np.mean(results), mse, len(results) =  0.654639175257732 tf.Tensor(6169.4263, shape=(), dtype=float32) 873
# slice = train, score = 0.654639175257732
# np.mean(results), mse, len(results) =  0.5227990430622009 tf.Tensor(6431.0176, shape=(), dtype=float32) 418
# slice = test, score = 0.5227990430622009
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.6155999999999999 tf.Tensor(6375.261, shape=(), dtype=float32) 100
# slice = key, score = 0.6155999999999999
# np.mean(results), mse, len(results) =  0.6569530355097365 tf.Tensor(6198.0903, shape=(), dtype=float32) 873
# slice = train, score = 0.6569530355097365
# np.mean(results), mse, len(results) =  0.5250478468899522 tf.Tensor(6396.7666, shape=(), dtype=float32) 418
# slice = test, score = 0.5250478468899522
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.6109 tf.Tensor(6412.5986, shape=(), dtype=float32) 100
# slice = key, score = 0.6109
# np.mean(results), mse, len(results) =  0.6525429553264606 tf.Tensor(6243.028, shape=(), dtype=float32) 873
# slice = train, score = 0.6525429553264606
# np.mean(results), mse, len(results) =  0.524377990430622 tf.Tensor(6438.051, shape=(), dtype=float32) 418
# slice = test, score = 0.524377990430622
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.6162 tf.Tensor(6556.1406, shape=(), dtype=float32) 100
# slice = key, score = 0.6162
# np.mean(results), mse, len(results) =  0.65524627720504 tf.Tensor(6457.7305, shape=(), dtype=float32) 873
# slice = train, score = 0.65524627720504
# np.mean(results), mse, len(results) =  0.5250239234449761 tf.Tensor(6639.55, shape=(), dtype=float32) 418
# slice = test, score = 0.5250239234449761
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.6154999999999999 tf.Tensor(6744.9507, shape=(), dtype=float32) 100
# slice = key, score = 0.6154999999999999
# np.mean(results), mse, len(results) =  0.6558762886597939 tf.Tensor(6599.708, shape=(), dtype=float32) 873
# slice = train, score = 0.6558762886597939
# np.mean(results), mse, len(results) =  0.5238755980861245 tf.Tensor(6819.1064, shape=(), dtype=float32) 418
# slice = test, score = 0.5238755980861245
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.6117999999999999 tf.Tensor(6918.9062, shape=(), dtype=float32) 100
# slice = key, score = 0.6117999999999999
# np.mean(results), mse, len(results) =  0.6590950744558993 tf.Tensor(6738.9233, shape=(), dtype=float32) 873
# slice = train, score = 0.6590950744558993
# np.mean(results), mse, len(results) =  0.5255502392344498 tf.Tensor(6922.1226, shape=(), dtype=float32) 418
# slice = test, score = 0.5255502392344498
# np.mean(results), mse, len(results) =  0.5255502392344498 tf.Tensor(6922.1226, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5256.npz ...
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.6112 tf.Tensor(6931.2607, shape=(), dtype=float32) 100
# slice = key, score = 0.6112
# np.mean(results), mse, len(results) =  0.6555441008018327 tf.Tensor(6779.287, shape=(), dtype=float32) 873
# slice = train, score = 0.6555441008018327
# np.mean(results), mse, len(results) =  0.5237559808612441 tf.Tensor(7024.013, shape=(), dtype=float32) 418
# slice = test, score = 0.5237559808612441
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.6159 tf.Tensor(7005.668, shape=(), dtype=float32) 100
# slice = key, score = 0.6159
# np.mean(results), mse, len(results) =  0.6587170675830469 tf.Tensor(6837.1973, shape=(), dtype=float32) 873
# slice = train, score = 0.6587170675830469
# np.mean(results), mse, len(results) =  0.5244019138755981 tf.Tensor(7037.4473, shape=(), dtype=float32) 418
# slice = test, score = 0.5244019138755981
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.6147999999999999 tf.Tensor(7170.531, shape=(), dtype=float32) 100
# slice = key, score = 0.6147999999999999
# np.mean(results), mse, len(results) =  0.6566208476517755 tf.Tensor(7044.8853, shape=(), dtype=float32) 873
# slice = train, score = 0.6566208476517755
# np.mean(results), mse, len(results) =  0.5224401913875598 tf.Tensor(7360.1714, shape=(), dtype=float32) 418
# slice = test, score = 0.5224401913875598
#
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.6123000000000001 tf.Tensor(7091.189, shape=(), dtype=float32) 100
# slice = key, score = 0.6123000000000001
# np.mean(results), mse, len(results) =  0.6597709049255441 tf.Tensor(6924.88, shape=(), dtype=float32) 873
# slice = train, score = 0.6597709049255441
# np.mean(results), mse, len(results) =  0.524066985645933 tf.Tensor(7186.91, shape=(), dtype=float32) 418
# slice = test, score = 0.524066985645933
# np.mean(results), mse, len(results) =  0.524066985645933 tf.Tensor(7186.91, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.5241.npz ...
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.6152000000000001 tf.Tensor(7338.6865, shape=(), dtype=float32) 100
# slice = key, score = 0.6152000000000001
# np.mean(results), mse, len(results) =  0.6580297823596793 tf.Tensor(7189.5386, shape=(), dtype=float32) 873
# slice = train, score = 0.6580297823596793
# np.mean(results), mse, len(results) =  0.5220813397129186 tf.Tensor(7430.7725, shape=(), dtype=float32) 418
# slice = test, score = 0.5220813397129186
#
# === Iteration 84000 ===
# np.mean(results), mse, len(results) =  0.6118 tf.Tensor(7417.831, shape=(), dtype=float32) 100
# slice = key, score = 0.6118
# np.mean(results), mse, len(results) =  0.6584077892325314 tf.Tensor(7273.745, shape=(), dtype=float32) 873
# slice = train, score = 0.6584077892325314
# np.mean(results), mse, len(results) =  0.5196889952153111 tf.Tensor(7563.2705, shape=(), dtype=float32) 418
# slice = test, score = 0.5196889952153111
#
# === Iteration 85000 ===
# np.mean(results), mse, len(results) =  0.6155 tf.Tensor(7479.665, shape=(), dtype=float32) 100
# slice = key, score = 0.6155
# np.mean(results), mse, len(results) =  0.6589690721649484 tf.Tensor(7288.0635, shape=(), dtype=float32) 873
# slice = train, score = 0.6589690721649484
# np.mean(results), mse, len(results) =  0.5229904306220096 tf.Tensor(7531.6987, shape=(), dtype=float32) 418
# slice = test, score = 0.5229904306220096
#
# === Iteration 86000 ===
# np.mean(results), mse, len(results) =  0.6114999999999999 tf.Tensor(7648.2676, shape=(), dtype=float32) 100
# slice = key, score = 0.6114999999999999
# np.mean(results), mse, len(results) =  0.655303550973654 tf.Tensor(7500.6, shape=(), dtype=float32) 873
# slice = train, score = 0.655303550973654
# np.mean(results), mse, len(results) =  0.525645933014354 tf.Tensor(7705.941, shape=(), dtype=float32) 418
# slice = test, score = 0.525645933014354
#
# === Iteration 87000 ===
# np.mean(results), mse, len(results) =  0.6156999999999999 tf.Tensor(7580.561, shape=(), dtype=float32) 100
# slice = key, score = 0.6156999999999999
# np.mean(results), mse, len(results) =  0.661225658648339 tf.Tensor(7496.0796, shape=(), dtype=float32) 873
# slice = train, score = 0.661225658648339
# np.mean(results), mse, len(results) =  0.5239712918660288 tf.Tensor(7705.9326, shape=(), dtype=float32) 418
# slice = test, score = 0.5239712918660288
# np.mean(results), mse, len(results) =  0.5239712918660288 tf.Tensor(7705.9326, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExCoItem_pro_wrestling_Round10_0.524.npz ...
#
# === Iteration 88000 ===
# np.mean(results), mse, len(results) =  0.6127999999999999 tf.Tensor(7798.3584, shape=(), dtype=float32) 100
# slice = key, score = 0.6127999999999999
# np.mean(results), mse, len(results) =  0.655143184421535 tf.Tensor(7733.337, shape=(), dtype=float32) 873
# ...
# slice = test, score = 0.30956937799043066
#
# === Iteration 53000 ===
# np.mean(results), mse, len(results) =  0.5392 tf.Tensor(3153.2654, shape=(), dtype=float32) 100
# slice = key, score = 0.5392
# np.mean(results), mse, len(results) =  0.5985796105383734 tf.Tensor(2947.1572, shape=(), dtype=float32) 873
# slice = train, score = 0.5985796105383734
# np.mean(results), mse, len(results) =  0.30593301435406706 tf.Tensor(3043.0186, shape=(), dtype=float32) 418
# slice = test, score = 0.30593301435406706
# np.mean(results), mse, len(results) =  0.30593301435406706 tf.Tensor(3043.0186, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3059.npz ...
#
# === Iteration 54000 ===
# np.mean(results), mse, len(results) =  0.5369999999999999 tf.Tensor(3288.1775, shape=(), dtype=float32) 100
# slice = key, score = 0.5369999999999999
# np.mean(results), mse, len(results) =  0.5946849942726232 tf.Tensor(3017.077, shape=(), dtype=float32) 873
# slice = train, score = 0.5946849942726232
# np.mean(results), mse, len(results) =  0.311866028708134 tf.Tensor(3132.0613, shape=(), dtype=float32) 418
# slice = test, score = 0.311866028708134
#
# === Iteration 55000 ===
# np.mean(results), mse, len(results) =  0.5422 tf.Tensor(3341.6501, shape=(), dtype=float32) 100
# slice = key, score = 0.5422
# np.mean(results), mse, len(results) =  0.6020274914089346 tf.Tensor(3080.2122, shape=(), dtype=float32) 873
# slice = train, score = 0.6020274914089346
# np.mean(results), mse, len(results) =  0.312511961722488 tf.Tensor(3176.2507, shape=(), dtype=float32) 418
# slice = test, score = 0.312511961722488
# np.mean(results), mse, len(results) =  0.312511961722488 tf.Tensor(3176.2507, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3125.npz ...
#
# === Iteration 56000 ===
# np.mean(results), mse, len(results) =  0.5429999999999999 tf.Tensor(3479.7034, shape=(), dtype=float32) 100
# slice = key, score = 0.5429999999999999
# np.mean(results), mse, len(results) =  0.6043298969072164 tf.Tensor(3203.8862, shape=(), dtype=float32) 873
# slice = train, score = 0.6043298969072164
# np.mean(results), mse, len(results) =  0.3130622009569378 tf.Tensor(3277.118, shape=(), dtype=float32) 418
# slice = test, score = 0.3130622009569378
# np.mean(results), mse, len(results) =  0.3130622009569378 tf.Tensor(3277.118, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3131.npz ...
#
# === Iteration 57000 ===
# np.mean(results), mse, len(results) =  0.5413999999999999 tf.Tensor(3472.065, shape=(), dtype=float32) 100
# slice = key, score = 0.5413999999999999
# np.mean(results), mse, len(results) =  0.6005956471935853 tf.Tensor(3214.3638, shape=(), dtype=float32) 873
# slice = train, score = 0.6005956471935853
# np.mean(results), mse, len(results) =  0.3067464114832536 tf.Tensor(3316.1086, shape=(), dtype=float32) 418
# slice = test, score = 0.3067464114832536
#
# === Iteration 58000 ===
# np.mean(results), mse, len(results) =  0.5393 tf.Tensor(3527.9736, shape=(), dtype=float32) 100
# slice = key, score = 0.5393
# np.mean(results), mse, len(results) =  0.6043184421534937 tf.Tensor(3311.1753, shape=(), dtype=float32) 873
# slice = train, score = 0.6043184421534937
# np.mean(results), mse, len(results) =  0.31081339712918665 tf.Tensor(3408.524, shape=(), dtype=float32) 418
# slice = test, score = 0.31081339712918665
#
# === Iteration 59000 ===
# np.mean(results), mse, len(results) =  0.5389 tf.Tensor(3703.002, shape=(), dtype=float32) 100
# slice = key, score = 0.5389
# np.mean(results), mse, len(results) =  0.602794959908362 tf.Tensor(3366.2744, shape=(), dtype=float32) 873
# slice = train, score = 0.602794959908362
# np.mean(results), mse, len(results) =  0.3092822966507177 tf.Tensor(3463.4802, shape=(), dtype=float32) 418
# slice = test, score = 0.3092822966507177
#
# === Iteration 60000 ===
# np.mean(results), mse, len(results) =  0.5428000000000001 tf.Tensor(3668.0947, shape=(), dtype=float32) 100
# slice = key, score = 0.5428000000000001
# np.mean(results), mse, len(results) =  0.6034135166093929 tf.Tensor(3384.1333, shape=(), dtype=float32) 873
# slice = train, score = 0.6034135166093929
# np.mean(results), mse, len(results) =  0.30715311004784684 tf.Tensor(3459.2615, shape=(), dtype=float32) 418
# slice = test, score = 0.30715311004784684
#
# === Iteration 61000 ===
# np.mean(results), mse, len(results) =  0.5397000000000001 tf.Tensor(3856.8838, shape=(), dtype=float32) 100
# slice = key, score = 0.5397000000000001
# np.mean(results), mse, len(results) =  0.6056701030927835 tf.Tensor(3566.1372, shape=(), dtype=float32) 873
# slice = train, score = 0.6056701030927835
# np.mean(results), mse, len(results) =  0.3091866028708134 tf.Tensor(3698.291, shape=(), dtype=float32) 418
# slice = test, score = 0.3091866028708134
# np.mean(results), mse, len(results) =  0.3091866028708134 tf.Tensor(3698.291, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3092.npz ...
#
# === Iteration 62000 ===
# np.mean(results), mse, len(results) =  0.5463 tf.Tensor(3870.683, shape=(), dtype=float32) 100
# slice = key, score = 0.5463
# np.mean(results), mse, len(results) =  0.6049255441008019 tf.Tensor(3617.8115, shape=(), dtype=float32) 873
# slice = train, score = 0.6049255441008019
# np.mean(results), mse, len(results) =  0.30868421052631584 tf.Tensor(3723.5916, shape=(), dtype=float32) 418
# slice = test, score = 0.30868421052631584
#
# === Iteration 63000 ===
# np.mean(results), mse, len(results) =  0.54 tf.Tensor(4041.128, shape=(), dtype=float32) 100
# slice = key, score = 0.54
# np.mean(results), mse, len(results) =  0.6041466208476518 tf.Tensor(3740.3274, shape=(), dtype=float32) 873
# slice = train, score = 0.6041466208476518
# np.mean(results), mse, len(results) =  0.3066746411483254 tf.Tensor(3835.761, shape=(), dtype=float32) 418
# slice = test, score = 0.3066746411483254
#
# === Iteration 64000 ===
# np.mean(results), mse, len(results) =  0.5423 tf.Tensor(4038.7822, shape=(), dtype=float32) 100
# slice = key, score = 0.5423
# np.mean(results), mse, len(results) =  0.6040091638029783 tf.Tensor(3687.1418, shape=(), dtype=float32) 873
# slice = train, score = 0.6040091638029783
# np.mean(results), mse, len(results) =  0.3137320574162679 tf.Tensor(3766.0002, shape=(), dtype=float32) 418
# slice = test, score = 0.3137320574162679
#
# === Iteration 65000 ===
# np.mean(results), mse, len(results) =  0.5449999999999999 tf.Tensor(3862.5256, shape=(), dtype=float32) 100
# slice = key, score = 0.5449999999999999
# np.mean(results), mse, len(results) =  0.6074226804123711 tf.Tensor(3596.4949, shape=(), dtype=float32) 873
# slice = train, score = 0.6074226804123711
# np.mean(results), mse, len(results) =  0.3087799043062201 tf.Tensor(3714.9763, shape=(), dtype=float32) 418
# slice = test, score = 0.3087799043062201
# np.mean(results), mse, len(results) =  0.3087799043062201 tf.Tensor(3714.9763, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3088.npz ...
#
# === Iteration 66000 ===
# np.mean(results), mse, len(results) =  0.5457 tf.Tensor(4151.6064, shape=(), dtype=float32) 100
# slice = key, score = 0.5457
# np.mean(results), mse, len(results) =  0.6054410080183276 tf.Tensor(3803.5496, shape=(), dtype=float32) 873
# slice = train, score = 0.6054410080183276
# np.mean(results), mse, len(results) =  0.31332535885167456 tf.Tensor(3921.9827, shape=(), dtype=float32) 418
# slice = test, score = 0.31332535885167456
#
# === Iteration 67000 ===
# np.mean(results), mse, len(results) =  0.5435000000000001 tf.Tensor(4157.6426, shape=(), dtype=float32) 100
# slice = key, score = 0.5435000000000001
# np.mean(results), mse, len(results) =  0.60475372279496 tf.Tensor(3830.0808, shape=(), dtype=float32) 873
# slice = train, score = 0.60475372279496
# np.mean(results), mse, len(results) =  0.30923444976076553 tf.Tensor(3930.3252, shape=(), dtype=float32) 418
# slice = test, score = 0.30923444976076553
#
# === Iteration 68000 ===
# np.mean(results), mse, len(results) =  0.5465 tf.Tensor(4290.0864, shape=(), dtype=float32) 100
# slice = key, score = 0.5465
# np.mean(results), mse, len(results) =  0.6067583046964491 tf.Tensor(3925.4287, shape=(), dtype=float32) 873
# slice = train, score = 0.6067583046964491
# np.mean(results), mse, len(results) =  0.31516746411483254 tf.Tensor(4073.3745, shape=(), dtype=float32) 418
# slice = test, score = 0.31516746411483254
#
# === Iteration 69000 ===
# np.mean(results), mse, len(results) =  0.5475999999999999 tf.Tensor(4407.868, shape=(), dtype=float32) 100
# slice = key, score = 0.5475999999999999
# np.mean(results), mse, len(results) =  0.6086254295532646 tf.Tensor(4044.7292, shape=(), dtype=float32) 873
# slice = train, score = 0.6086254295532646
# np.mean(results), mse, len(results) =  0.3155741626794259 tf.Tensor(4135.205, shape=(), dtype=float32) 418
# slice = test, score = 0.3155741626794259
# np.mean(results), mse, len(results) =  0.3155741626794259 tf.Tensor(4135.205, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3156.npz ...
#
# === Iteration 70000 ===
# np.mean(results), mse, len(results) =  0.5498000000000001 tf.Tensor(4602.308, shape=(), dtype=float32) 100
# slice = key, score = 0.5498000000000001
# np.mean(results), mse, len(results) =  0.6078923253150058 tf.Tensor(4196.703, shape=(), dtype=float32) 873
# slice = train, score = 0.6078923253150058
# np.mean(results), mse, len(results) =  0.31284688995215304 tf.Tensor(4277.909, shape=(), dtype=float32) 418
# slice = test, score = 0.31284688995215304
#
# === Iteration 71000 ===
# np.mean(results), mse, len(results) =  0.5509999999999999 tf.Tensor(4553.932, shape=(), dtype=float32) 100
# slice = key, score = 0.5509999999999999
# np.mean(results), mse, len(results) =  0.6080756013745705 tf.Tensor(4176.146, shape=(), dtype=float32) 873
# slice = train, score = 0.6080756013745705
# np.mean(results), mse, len(results) =  0.3138038277511962 tf.Tensor(4289.2104, shape=(), dtype=float32) 418
# slice = test, score = 0.3138038277511962
#
# === Iteration 72000 ===
# np.mean(results), mse, len(results) =  0.5512 tf.Tensor(4514.4736, shape=(), dtype=float32) 100
# slice = key, score = 0.5512
# np.mean(results), mse, len(results) =  0.6097365406643757 tf.Tensor(4172.4014, shape=(), dtype=float32) 873
# slice = train, score = 0.6097365406643757
# np.mean(results), mse, len(results) =  0.3113157894736842 tf.Tensor(4226.626, shape=(), dtype=float32) 418
# slice = test, score = 0.3113157894736842
# np.mean(results), mse, len(results) =  0.3113157894736842 tf.Tensor(4226.626, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3113.npz ...
#
# === Iteration 73000 ===
# np.mean(results), mse, len(results) =  0.5499 tf.Tensor(4655.8145, shape=(), dtype=float32) 100
# slice = key, score = 0.5499
# np.mean(results), mse, len(results) =  0.6076059564719359 tf.Tensor(4259.3247, shape=(), dtype=float32) 873
# slice = train, score = 0.6076059564719359
# np.mean(results), mse, len(results) =  0.3101913875598087 tf.Tensor(4378.5947, shape=(), dtype=float32) 418
# slice = test, score = 0.3101913875598087
#
# === Iteration 74000 ===
# np.mean(results), mse, len(results) =  0.5438000000000001 tf.Tensor(4939.3477, shape=(), dtype=float32) 100
# slice = key, score = 0.5438000000000001
# np.mean(results), mse, len(results) =  0.6027605956471936 tf.Tensor(4528.3374, shape=(), dtype=float32) 873
# slice = train, score = 0.6027605956471936
# np.mean(results), mse, len(results) =  0.3144976076555024 tf.Tensor(4654.66, shape=(), dtype=float32) 418
# slice = test, score = 0.3144976076555024
#
# === Iteration 75000 ===
# np.mean(results), mse, len(results) =  0.5489 tf.Tensor(4868.389, shape=(), dtype=float32) 100
# slice = key, score = 0.5489
# np.mean(results), mse, len(results) =  0.6062428407789232 tf.Tensor(4449.4204, shape=(), dtype=float32) 873
# slice = train, score = 0.6062428407789232
# np.mean(results), mse, len(results) =  0.31555023923444975 tf.Tensor(4544.723, shape=(), dtype=float32) 418
# slice = test, score = 0.31555023923444975
#
# === Iteration 76000 ===
# np.mean(results), mse, len(results) =  0.5489999999999999 tf.Tensor(4773.824, shape=(), dtype=float32) 100
# slice = key, score = 0.5489999999999999
# np.mean(results), mse, len(results) =  0.6089690721649483 tf.Tensor(4405.923, shape=(), dtype=float32) 873
# slice = train, score = 0.6089690721649483
# np.mean(results), mse, len(results) =  0.3080382775119617 tf.Tensor(4574.5103, shape=(), dtype=float32) 418
# slice = test, score = 0.3080382775119617
#
# === Iteration 77000 ===
# np.mean(results), mse, len(results) =  0.5508000000000001 tf.Tensor(4790.838, shape=(), dtype=float32) 100
# slice = key, score = 0.5508000000000001
# np.mean(results), mse, len(results) =  0.6128636884306987 tf.Tensor(4487.1245, shape=(), dtype=float32) 873
# slice = train, score = 0.6128636884306987
# np.mean(results), mse, len(results) =  0.30770334928229665 tf.Tensor(4636.769, shape=(), dtype=float32) 418
# slice = test, score = 0.30770334928229665
# np.mean(results), mse, len(results) =  0.30770334928229665 tf.Tensor(4636.769, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3077.npz ...
#
# === Iteration 78000 ===
# np.mean(results), mse, len(results) =  0.5510999999999999 tf.Tensor(5008.536, shape=(), dtype=float32) 100
# slice = key, score = 0.5510999999999999
# np.mean(results), mse, len(results) =  0.615189003436426 tf.Tensor(4600.546, shape=(), dtype=float32) 873
# slice = train, score = 0.615189003436426
# np.mean(results), mse, len(results) =  0.3055980861244019 tf.Tensor(4808.6743, shape=(), dtype=float32) 418
# slice = test, score = 0.3055980861244019
# np.mean(results), mse, len(results) =  0.3055980861244019 tf.Tensor(4808.6743, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3056.npz ...
#
# === Iteration 79000 ===
# np.mean(results), mse, len(results) =  0.5478000000000001 tf.Tensor(5209.666, shape=(), dtype=float32) 100
# slice = key, score = 0.5478000000000001
# np.mean(results), mse, len(results) =  0.6070332187857962 tf.Tensor(4820.219, shape=(), dtype=float32) 873
# slice = train, score = 0.6070332187857962
# np.mean(results), mse, len(results) =  0.31019138755980863 tf.Tensor(4976.035, shape=(), dtype=float32) 418
# slice = test, score = 0.31019138755980863
#
# === Iteration 80000 ===
# np.mean(results), mse, len(results) =  0.5489999999999999 tf.Tensor(5168.7183, shape=(), dtype=float32) 100
# slice = key, score = 0.5489999999999999
# np.mean(results), mse, len(results) =  0.6103780068728523 tf.Tensor(4768.007, shape=(), dtype=float32) 873
# slice = train, score = 0.6103780068728523
# np.mean(results), mse, len(results) =  0.30897129186602873 tf.Tensor(4927.0747, shape=(), dtype=float32) 418
# slice = test, score = 0.30897129186602873
#
# === Iteration 81000 ===
# np.mean(results), mse, len(results) =  0.5544 tf.Tensor(5169.083, shape=(), dtype=float32) 100
# slice = key, score = 0.5544
# np.mean(results), mse, len(results) =  0.6151431844215349 tf.Tensor(4798.9243, shape=(), dtype=float32) 873
# slice = train, score = 0.6151431844215349
# np.mean(results), mse, len(results) =  0.3083732057416268 tf.Tensor(4966.155, shape=(), dtype=float32) 418
# slice = test, score = 0.3083732057416268
# === Iteration 82000 ===
# np.mean(results), mse, len(results) =  0.5555 tf.Tensor(5350.5923, shape=(), dtype=float32) 100
# slice = key, score = 0.5555
# np.mean(results), mse, len(results) =  0.6156357388316152 tf.Tensor(4952.994, shape=(), dtype=float32) 873
# slice = train, score = 0.6156357388316152
# np.mean(results), mse, len(results) =  0.3040909090909091 tf.Tensor(5174.693, shape=(), dtype=float32) 418
# slice = test, score = 0.3040909090909091
# np.mean(results), mse, len(results) =  0.3040909090909091 tf.Tensor(5174.693, shape=(), dtype=float32) 418
# Saving ./GE_QE_RBExTop_pro_wrestling_Round10_0.3041.npz ...
#
# === Iteration 83000 ===
# np.mean(results), mse, len(results) =  0.5486000000000001 tf.Tensor(5319.2505, shape=(), dtype=float32) 100
# slice = key, score = 0.5486000000000001
# np.mean(results), mse, len(results) =  0.609335624284078 tf.Tensor(4944.1753, shape=(), dtype=float32) 873
# slice = train, score = 0.609335624284078
# np.mean(results), mse, len(results) =  0.311866028708134 tf.Tensor(5070.3296, shape=(), dtype=float32) 418
# slice = test, score = 0.311866028708134

# %%
# !ls | grep "GE_QE_RBE"
# Out:
# GE_QE_RBExCoItem_doctor_who_Round10_0.0261.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2567.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2672.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2766.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2818.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2831.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2832.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2835.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2854.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2876.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2879.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2908.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2911.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2913.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2915.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2932.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2945.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2946.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2947.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.294.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.295.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2961.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2966.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2972.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.2978.npz
# GE_QE_RBExCoItem_doctor_who_Round10_0.298.npz
# GE_QE_RBExCoItem_military_Round10_0.0259.npz
# GE_QE_RBExCoItem_military_Round10_0.2152.npz
# GE_QE_RBExCoItem_military_Round10_0.2383.npz
# GE_QE_RBExCoItem_military_Round10_0.2564.npz
# GE_QE_RBExCoItem_military_Round10_0.2606.npz
# GE_QE_RBExCoItem_military_Round10_0.2723.npz
# GE_QE_RBExCoItem_military_Round10_0.2836.npz
# GE_QE_RBExCoItem_military_Round10_0.2896.npz
# GE_QE_RBExCoItem_military_Round10_0.2907.npz
# GE_QE_RBExCoItem_military_Round10_0.2914.npz
# GE_QE_RBExCoItem_military_Round10_0.2948.npz
# GE_QE_RBExCoItem_military_Round10_0.2978.npz
# GE_QE_RBExCoItem_military_Round10_0.2989.npz
# GE_QE_RBExCoItem_military_Round10_0.299.npz
# GE_QE_RBExCoItem_military_Round10_0.3033.npz
# GE_QE_RBExCoItem_military_Round10_0.3034.npz
# GE_QE_RBExCoItem_military_Round10_0.306.npz
# GE_QE_RBExCoItem_military_Round10_0.3078.npz
# GE_QE_RBExCoItem_military_Round10_0.3118.npz
# GE_QE_RBExCoItem_military_Round10_0.3124.npz
# GE_QE_RBExCoItem_military_Round10_0.3127.npz
# GE_QE_RBExTop_yugioh_Round10_0.2699.npz
# GE_QE_RBExTop_yugioh_Round10_0.2711.npz
# GE_QE_RBExTop_yugioh_Round10_0.2712.npz
# GE_QE_RBExTop_yugioh_Round10_0.2715.npz
# GE_QE_RBExTop_yugioh_Round10_0.2719.npz
# GE_QE_RBExTop_yugioh_Round10_0.2731.npz
# GE_QE_RBExTop_yugioh_Round10_0.2744.npz
# GE_QE_RBExTop_yugioh_Round10_0.2763.npz
# GE_QE_RBExTop_yugioh_Round10_0.2778.npz
# GE_QE_RBExTop_yugioh_Round10_0.2779.npz
# GE_QE_RBExTop_yugioh_Round10_0.2782.npz
# GE_QE_RBExTop_yugioh_Round10_0.2786.npz
# GE_QE_RBExTop_yugioh_Round10_0.2787.npz
# GE_QE_RBExTop_yugioh_Round10_0.2791.npz
# GE_QE_RBExTop_yugioh_Round10_0.2794.npz
# GE_QE_RBExTop_yugioh_Round10_0.2799.npz
# GE_QE_RBExTop_yugioh_Round10_0.27.npz
# GE_QE_RBExTop_yugioh_Round10_0.2801.npz
# GE_QE_RBExTop_yugioh_Round10_0.2804.npz
# GE_QE_RBExTop_yugioh_Round10_0.2813.npz
# GE_QE_RBExTop_yugioh_Round10_0.2816.npz
# GE_QE_RBExTop_yugioh_Round10_0.2824.npz
# GE_QE_RBExTop_yugioh_Round10_0.2825.npz
# GE_QE_RBExTop_yugioh_Round10_0.2831.npz
# GE_QE_RBExTop_yugioh_Round10_0.2844.npz
# GE_QE_RBExTop_yugioh_Round10_0.2852.npz
# GE_QE_RBExTop_yugioh_Round10_0.2879.npz

# %%
QE_ = m_.get_user_embs("test")
R_All = ctx.get_relevs("test")
QE = np.hstack([
    QE_ @ m_.W,
    m_.u_dssm(QE_),
    np.ones((R_All.shape[0], 1)),
    np.ones((R_All.shape[0], 1)) * m_.pb
])

# %%
for dataset in DATASETS:
    
    print ("\n\n\nDATASET = ", dataset)
    
    ctx = EvalContextRelevs(
        load_ment_to_ent_scores(dataset, shuffle_rows=42, full=dataset),
        det_attempts=100
    )

    print("LOADED")
    
    do(ctx, f"{dataset}_Round10")
    
    del ctx
    gc.collect()

# %%
t = ctx.get_relevs("train").T
t = (t - t.mean()) / t.std()  # like in other comparisons with RBE
ctx.key_games = list(coitem_algorithm(100, t, t, 1e-8, eps=1e9)[0])

print("KEY_SET")

ma = AnnCUR(ctx, key_games=ctx.key_games)

ma.fit()
ma.get_score("train"), ma.get_score("test")
# Out:
# /tmp/ipykernel_358619/4274979955.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm.tqdm_notebook(range(n_support)):
#   0%|          | 0/100 [00:00<?, ?it/s]
# KEY_SET
# np.mean(results), mse, len(results) =  0.7277067183462532 0.17279571845624642 4644
# np.mean(results), mse, len(results) =  0.7196509341199606 0.27000474140976904 2034
# (0.7277067183462532, 0.7196509341199606)

# %%
GE = ma.get_game_embs()
QE = torch.from_numpy(ma.ctx.get_relevs("test")[:, ma.key_cols_idx])

np.savez_compressed("./GE_QE_AnnCURxCoItem_RecSys_pairwise.npz", QE=QE.numpy(), GE=GE.numpy())

# %%
loaded = np.load('./GE_QE_AnnCURxCoItem_RecSys_pairwise.npz')
loaded["GE"], loaded["QE"]
# Out:
# (array([[-6.99894281e-07,  2.28082557e-07, -7.68262684e-07, ...,
#           7.21491372e-06, -9.86397304e-06,  2.38271599e-04],
#         [ 4.48866242e-06, -7.16671929e-07, -1.00057667e-06, ...,
#           3.12123734e-05,  1.01422295e-04,  7.46128584e-04],
#         [-6.79450750e-07, -3.54730573e-07, -5.77115023e-07, ...,
#           1.04192418e-05, -2.64107717e-07,  3.02313833e-04],
#         ...,
#         [ 8.76051060e-06, -6.40698277e-05, -5.49386342e-05, ...,
#          -2.15575740e-04, -4.94313477e-05,  2.64700002e-02],
#         [-1.79433635e-05,  4.32205534e-05,  3.56475006e-05, ...,
#          -1.74609501e-05,  2.82109294e-04,  1.29137913e-03],
#         [-4.59748938e-05,  5.35147263e-05, -2.80591650e-06, ...,
#           6.00601974e-05,  4.03257544e-04,  6.37227699e-03]]),
#  array([[ 0.72265023,  0.3253895 ,  1.09422529, ...,  0.72851855,
#           0.46345094,  1.75333095],
#         [ 2.5486567 ,  0.75778222,  0.54785085, ..., 11.48628902,
#          13.26927948,  8.32145691],
#         [ 0.77662414,  0.92330813,  1.21224713, ...,  2.02225709,
#           2.65401125,  2.52606583],
#         ...,
#         [ 0.29024124,  0.07037913,  0.10343634, ...,  0.99263561,
#           0.0933512 ,  2.39482069],
#         [ 0.45950434,  0.98658496,  1.91601408, ...,  1.99642324,
#           0.72606015,  0.83288705],
#         [ 0.67305052,  8.04861546,  7.50738096, ...,  1.84654892,
#           2.09724665,  4.20241165]]))

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(500, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                    for _ in range(T // K - 1):
                        Rp = get_Rp(GE, A, Rt[A], QE[i], L)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True or (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 101/101 [00:07<00:00, 12.80it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.06683168316831684
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.06683168316831684'

# %%
first_of = K
hits = list()
for i in range(len(As)):
    first = As[i][first_of:first_of+K]
    for of_ in range(first_of+K, T, K):
        current = As[i][of_:of_+25]
        hits.append(len(set(current).intersection(set(first))))
        
np.mean(hits), len(hits), T//K
# Out:
# (3.0792079207920793, 1818, 20)

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(200, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                    for _ in range(T // K - 1):
                        Rp = get_Rp(GE, A, Rt[A], QE[i], L)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True or (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 101/101 [00:02<00:00, 36.27it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.38000000000000017
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.38000000000000017'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(100, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                    for _ in range(T // K - 1):
                        Rp = get_Rp(GE, A, Rt[A], QE[i], L)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if False or (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 74.62it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.38495049504950496
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.38495049504950496'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in np.linspace(0, 1, 11):
            for T, TS in [(100, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                    for _ in range(T // K - 1):
                        Rp = get_Rp(GE, A, Rt[A], QE[i], L)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if False or (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 80.30it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7128712871287128
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 76.14it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.4641584158415842
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 81.24it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.42831683168316836
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 81.47it/s]
# K = 25, L = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.4138613861386139
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 74.83it/s]
# K = 25, L = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.4035643564356436
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 79.48it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.3968316831683169
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 77.59it/s]
# K = 25, L = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.39297029702970304
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 81.29it/s]
# K = 25, L = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.3901980198019803
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 75.22it/s]
# K = 25, L = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.3894059405940595
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 70.82it/s]
# K = 25, L = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.3865346534653466
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 73.58it/s]
# K = 25, L = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.38495049504950496
# 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.7128712871287128'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in np.linspace(0, 0.1, 11):
            for T, TS in [(100, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                    for _ in range(T // K - 1):
                        Rp = get_Rp(GE, A, Rt[A], QE[i], L)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if False or (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 101/101 [00:02<00:00, 41.11it/s]
# K = 25, L = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7128712871287128
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 66.79it/s]
# K = 25, L = 0.01, TS = 100, rndFirst = False np.mean(results) = 0.608019801980198
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 58.21it/s]
# K = 25, L = 0.02, TS = 100, rndFirst = False np.mean(results) = 0.5601980198019804
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 76.35it/s]
# K = 25, L = 0.03, TS = 100, rndFirst = False np.mean(results) = 0.5326732673267327
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 75.74it/s]
# K = 25, L = 0.04, TS = 100, rndFirst = False np.mean(results) = 0.5136633663366338
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 78.40it/s]
# K = 25, L = 0.05, TS = 100, rndFirst = False np.mean(results) = 0.5002970297029702
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 71.02it/s]
# K = 25, L = 0.06, TS = 100, rndFirst = False np.mean(results) = 0.49059405940594064
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 75.63it/s]
# K = 25, L = 0.07, TS = 100, rndFirst = False np.mean(results) = 0.4788118811881188
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 74.25it/s]
# K = 25, L = 0.08, TS = 100, rndFirst = False np.mean(results) = 0.47178217821782176
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 63.33it/s]
# K = 25, L = 0.09, TS = 100, rndFirst = False np.mean(results) = 0.46801980198019805
# 100%|█████████████████████████████████████████| 101/101 [00:01<00:00, 64.23it/s]
# K = 25, L = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.4641584158415842
# 'K = 25, L = 0.0, rndFirst = False np.mean(results) = 0.7128712871287128'

# %%
loaded = np.load('./GE_QE_AnnCURxCoItem.npz')
loaded["GE"], loaded["QE"]
# Out:
# (array([[ 0.00474047, -0.00134592,  0.00105135, ..., -0.01403404,
#          -0.06027953,  0.03029055],
#         [ 0.00304035,  0.00348719,  0.00059625, ..., -0.02397177,
#           0.02368937, -0.00214129],
#         [-0.00171048, -0.00074191, -0.00312175, ..., -0.02022368,
#          -0.04254626,  0.0015299 ],
#         ...,
#         [-0.00149242, -0.00083971,  0.00127875, ...,  0.30800236,
#           0.01279671,  0.31648819],
#         [ 0.00138912, -0.00338582, -0.00446363, ...,  0.21003374,
#          -0.00506344,  0.06520486],
#         [-0.00499681,  0.0055155 ,  0.00054058, ...,  0.34524469,
#           0.0484674 ,  0.09927237]]),
#  array([[ 6.1222043 ,  3.87819266,  5.50115252, ...,  4.24813557,
#           4.1863637 ,  5.0663023 ],
#         [11.11496925,  7.97319746,  8.55467796, ...,  6.13713265,
#           6.86200666,  7.77079678],
#         [10.17910194,  8.9642086 , 10.32344437, ...,  5.2055912 ,
#           6.34264612,  5.86023664],
#         ...,
#         [ 8.3173008 ,  7.88316393, 11.69620609, ...,  7.03994036,
#           7.38770294,  8.24322033],
#         [ 1.39372718,  1.92910755,  1.38398719, ...,  1.71773374,
#           1.46544504,  2.00904965],
#         [ 5.48430872,  6.39034843,  7.32582378, ...,  5.26679134,
#           5.70696259,  6.32572317]]))

# %%
import numpy as np


def get_Rp(GE, A, R, QE_i, L):
    Ae = GE[A]

    u = np.linalg.pinv(Ae.T @ Ae) @ Ae.T @ R
    assert u.shape == QE_i.shape
    Rp = GE @ (u * L + QE_i * (1 - L))
    
    return Rp

from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(500, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                    for _ in range(T // K - 1):
                        Rp = get_Rp(GE, A, Rt[A], QE[i], L)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            #if True and (ai not in An):
                            An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 101/101 [00:10<00:00, 10.07it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.06683168316831684
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.06683168316831684'

# %%
first_of = K
hits = list()
for i in range(len(As)):
    first = As[i][first_of:first_of+K]
    for of_ in range(first_of+K, T, K):
        current = As[i][of_:of_+25]
        hits.append(len(set(current).intersection(set(first))))
        
np.mean(hits), len(hits), T//K
# Out:
# (17.59188034188034, 1872, 20)

# %%
hits
# Out:
# [23,
#  22,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  4,
#  4,
#  4,
#  5,
#  4,
#  0,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  17,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  9,
#  9,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  22,
#  21,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  19,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  17,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  17,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  13,
#  13,
#  0,
#  13,
#  13,
#  14,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  12,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  16,
#  14,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  18,
#  18,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  22,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  15,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  13,
#  7,
#  13,
#  13,
#  13,
#  13,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  0,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  7,
#  7,
#  7,
#  2,
#  4,
#  10,
#  9,
#  10,
#  10,
#  11,
#  10,
#  10,
#  10,
#  10,
#  9,
#  10,
#  10,
#  10,
#  18,
#  18,
#  18,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  18,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  15,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  15,
#  16,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  17,
#  17,
#  17,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  17,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  10,
#  8,
#  0,
#  0,
#  7,
#  10,
#  11,
#  12,
#  12,
#  12,
#  12,
#  13,
#  11,
#  13,
#  12,
#  11,
#  11,
#  13,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  23,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  18,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  15,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  23,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  21,
#  21,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  ...]

# %%
import numpy as np


def get_Rp(GE, A, R, QE_i, L):
    Ae = GE[A]

    u = np.linalg.pinv(Ae.T @ Ae) @ Ae.T @ R
    assert u.shape == QE_i.shape
    Rp = GE @ (u * L + QE_i * (1 - L))
    
    return Rp

# %%
loaded = np.load('./GE_QE_DSSM8_at_100k.npz')
loaded["GE"], loaded["QE"]
# Out:
# (array([[ 2.97130000e-02, -3.27346000e-02, -3.46989000e-02, ...,
#          -7.82296479e-01, -4.97554149e-03,  5.33902600e+00],
#         [ 2.02651000e-02,  7.19004000e-02,  2.23142000e-03, ...,
#           1.61782712e-01, -2.00821459e-02,  5.53517628e+00],
#         [-1.20589000e-02,  1.87944000e-02,  4.56247000e-02, ...,
#          -1.30174786e-01, -1.23924620e-01,  5.32502247e+00],
#         ...,
#         [-2.35462000e-02,  1.20831000e-02, -4.17760000e-02, ...,
#          -1.03709483e+00, -3.64314020e-02,  5.77182733e+00],
#         [ 1.51869000e-03,  1.35546000e-01, -1.71226000e-02, ...,
#          -8.92335832e-01, -3.33648175e-03,  5.12969962e+00],
#         [ 2.19628000e-02,  1.30364000e-01, -2.18127000e-02, ...,
#          -4.20807838e-01, -2.88077407e-02,  5.08200507e+00]]),
#  array([[-0.8176709 , -0.47645564,  1.50424184, ..., -1.13001204,
#           1.        , 13.40936565],
#         [-0.68234849, -0.7408109 ,  1.5917183 , ..., -0.94634646,
#           1.        , 13.40936565],
#         [-0.56474965, -0.21809959,  1.237253  , ..., -0.90443921,
#           1.        , 13.40936565],
#         ...,
#         [-0.5590198 , -0.24946145,  1.46250865, ..., -0.65064222,
#           1.        , 13.40936565],
#         [-0.64050375, -0.50367074,  1.70687349, ..., -1.73308659,
#           1.        , 13.40936565],
#         [-1.02605701, -0.69466274,  1.63870798, ..., -0.83750767,
#           1.        , 13.40936565]]))

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [0.2]:
            for T, TS in [(500, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                    for _ in range(T // K - 1):
                        Rp = get_Rp(GE, A, Rt[A], QE[i], L)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.81it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.8960576923076923
# 'K = 25, L = 0.2, rndFirst = False np.mean(results) = 0.8960576923076923'

# %%
first_of = 18*K
hits = list()
for i in range(len(As)):
    first = As[i][first_of:first_of+K]
    for of_ in range(first_of+K, T, K):
        current = As[i][of_:of_+25]
        hits.append(len(set(current).intersection(set(first))))

# %%
np.mean(hits), len(hits)
# Out:
# (0.0, 104)

# %%
As[0][-50:]
# Out:
# array([  585, 12260, 15191,  9395,  2354,  6938, 13644,  2023, 14955,
#          384,  8178,  8164,  9807,  8660,   484, 14362, 12230,  8931,
#        12834, 13491, 16289, 14568, 14113,   883, 16508,  9127,  1485,
#        15243, 13757,  3698, 16497,  9419, 15351, 13654,  4116, 15864,
#         4727,  1140,  2285, 14844, 15522, 13979,  5764,  7331, 16004,
#         6086, 13556, 10202,  6585, 10757])

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(500, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                    for _ in range(T // K - 1):
                        Rp = get_Rp(GE, A, Rt[A], QE[i], L)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:27<00:00,  3.73it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.8254807692307693
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.8254807692307693'

# %%
first_of = 18*K
hits = list()
for i in range(len(As)):
    first = As[i][first_of:first_of+K]
    for of_ in range(first_of+K, T, K):
        current = As[i][of_:of_+25]
        hits.append(len(set(current).intersection(set(first))))
        
np.mean(hits), len(hits), T//K
# Out:
# (0.0, 104, 20)

# %%
first
# Out:
# array([12617,  7448, 13282, 10950,  6536,  6421, 10730, 12642,  2271,
#         6072,  6670,  2945,  2354,  9318,  6223,  7032, 11479, 10513,
#        11782,  3450,  1819,  3286,  1209,  1817,  3433])

# %% [markdown]
# # Momentum

# %%
import numpy as np


def get_Rp_last(GE, A, R, QE_i, L, u_last, m=0.5):
    Ae = GE[A]

    u = np.linalg.pinv(Ae.T @ Ae) @ Ae.T @ R
    assert u.shape == QE_i.shape

    if u_last is not None:
        u = (u * (1 - m) + u_last * m)

    Rp = GE @ (u * L + QE_i * (1 - L))
    
    return Rp, u

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(500, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = None
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.5)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:24<00:00,  4.29it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.8231730769230767
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.8231730769230767'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(500, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = QE[i]
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.5)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:24<00:00,  4.23it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.8463461538461539
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.8463461538461539'

# %%
first_of = 18*K
hits = list()
for i in range(len(As)):
    first = As[i][first_of:first_of+K]
    for of_ in range(first_of+K, T, K):
        current = As[i][of_:of_+25]
        hits.append(len(set(current).intersection(set(first))))
        
np.mean(hits), len(hits), T//K
# Out:
# (0.0, 104, 20)

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(500, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = QE[i]
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.8)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:22<00:00,  4.57it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.8648076923076923
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.8648076923076923'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(500, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = QE[i]
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=1)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:24<00:00,  4.23it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.893846153846154
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.893846153846154'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [0.2]:
            for T, TS in [(200, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = QE[i]
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.29it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.720096153846154
# 'K = 25, L = 0.2, rndFirst = False np.mean(results) = 0.720096153846154'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [0.2]:
            for T, TS in [(200, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = QE[i]
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.5)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 14.17it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7191346153846154
# 'K = 25, L = 0.2, rndFirst = False np.mean(results) = 0.7191346153846154'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [0.2]:
            for T, TS in [(200, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = None
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.5)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:06<00:00, 15.57it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7196153846153847
# 'K = 25, L = 0.2, rndFirst = False np.mean(results) = 0.7196153846153847'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [0.2]:
            for T, TS in [(200, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = None
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.25)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:06<00:00, 15.30it/s]
# K = 25, L = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7185576923076922
# 'K = 25, L = 0.2, rndFirst = False np.mean(results) = 0.7185576923076922'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [0.5]:
            for T, TS in [(200, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = None
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.5)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:06<00:00, 16.33it/s]
# K = 25, L = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7146153846153845
# 'K = 25, L = 0.5, rndFirst = False np.mean(results) = 0.7146153846153845'

# %%
import numpy as np


def get_Rp_last(GE, A, R, QE_i, L, u_last, m=0.5):
    Ae = GE[A]

    u = np.linalg.pinv(Ae.T @ Ae) @ Ae.T @ R
    assert u.shape == QE_i.shape

    if u_last is not None:
        u = (u * (1 - m) + u_last * m)

    u = u * L + QE_i * (1 - L)
    Rp = GE @ u
    
    return Rp, u

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(200, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = QE[i]
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.9)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.29it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.7204807692307692
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.7204807692307692'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for K in [25]:
        for L in [1]:
            for T, TS in [(200, 100)]:
                results = list()


                As = list()
                for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                    A = (
                        ctx.key_games[:K]
                        if randomFirst else
                        (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                    )
                    Rt = R_All[i]
                    ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 
                    
                    u_last = QE[i]
                    for _ in range(T // K - 1):
                        Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=0.95)
                        
                        An = list(A)
                        for ai in Rp.argsort()[::-1]:
                            if True and (ai not in An):
                                An.append(ai)
                            if len(An) == len(A) + K:
                                break
                        A = np.array(An)
                        
                    assert len(A) == T
                    As.append(A)

                            
                    A = sorted([
                        (-Rt[ai], ai)
                        for ai in A
                    ])[:TS]
                    A = [ai for _, ai in A]

                    pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                    results.append(ev(pred_top, gt_top) / float(TS))

                if np.mean(results) > best:
                    best = np.mean(results)
                    best_arg = f"K = {K}, L = {L}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                    best_arg_d = {
                        "K": K,
                        "L": L,
                        "randomFirst": randomFirst,
                        "score": np.mean(results)
                    }
                print(f"K = {K}, L = {L}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")
                
best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.50it/s]
# K = 25, L = 1, TS = 100, rndFirst = False np.mean(results) = 0.7202884615384615
# 'K = 25, L = 1, rndFirst = False np.mean(results) = 0.7202884615384615'

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for m in np.linspace(0, 1, 11):
        for K in [25]:
            for L in np.linspace(0, 1, 11):
                for T, TS in [(200, 100)]:
                    results = list()


                    As = list()
                    for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                        A = (
                            ctx.key_games[:K]
                            if randomFirst else
                            (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                        )
                        Rt = R_All[i]
                        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                        u_last = QE[i]
                        for _ in range(T // K - 1):
                            Rp, u_last = get_Rp_last(GE, A, Rt[A], QE[i], L, u_last, m=m)

                            An = list(A)
                            for ai in Rp.argsort()[::-1]:
                                if True and (ai not in An):
                                    An.append(ai)
                                if len(An) == len(A) + K:
                                    break
                            A = np.array(An)

                        assert len(A) == T
                        As.append(A)


                        A = sorted([
                            (-Rt[ai], ai)
                            for ai in A
                        ])[:TS]
                        A = [ai for _, ai in A]

                        pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                        results.append(ev(pred_top, gt_top) / float(TS))

                    if np.mean(results) > best:
                        best = np.mean(results)
                        best_arg = f"K = {K}, L = {L}, m = {m}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                        best_arg_d = {
                            "K": K,
                            "L": L,
                            "randomFirst": randomFirst,
                            "score": np.mean(results),
                            "m": m
                        }
                    print(f"K = {K}, L = {L}, m = {m}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")

best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.71it/s]
# K = 25, L = 0.0, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00,  9.91it/s]
# K = 25, L = 0.1, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7189423076923076
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 10.44it/s]
# K = 25, L = 0.2, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.720096153846154
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00,  9.76it/s]
# K = 25, L = 0.30000000000000004, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7176923076923077
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00,  9.51it/s]
# K = 25, L = 0.4, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7197115384615385
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 10.77it/s]
# K = 25, L = 0.5, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7096153846153848
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 10.64it/s]
# K = 25, L = 0.6000000000000001, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7032692307692309
# 100%|█████████████████████████████████████████| 104/104 [00:13<00:00,  7.89it/s]
# K = 25, L = 0.7000000000000001, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.6913461538461539
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 10.59it/s]
# K = 25, L = 0.8, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.6700961538461538
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 11.11it/s]
# K = 25, L = 0.9, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.6192307692307693
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 14.16it/s]
# K = 25, L = 1.0, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.46365384615384614
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.69it/s]
# K = 25, L = 0.0, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:12<00:00,  8.47it/s]
# K = 25, L = 0.1, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.7183653846153846
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.27it/s]
# K = 25, L = 0.2, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.7199038461538462
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 11.87it/s]
# K = 25, L = 0.30000000000000004, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.7183653846153846
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 11.57it/s]
# K = 25, L = 0.4, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.7184615384615385
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.41it/s]
# K = 25, L = 0.5, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.7105769230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.50it/s]
# K = 25, L = 0.6000000000000001, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.7081730769230768
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.17it/s]
# K = 25, L = 0.7000000000000001, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.6993269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.37it/s]
# K = 25, L = 0.8, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.6817307692307693
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.54it/s]
# K = 25, L = 0.9, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.6425
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.72it/s]
# K = 25, L = 1.0, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.5198076923076923
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.22it/s]
# K = 25, L = 0.0, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 11.53it/s]
# K = 25, L = 0.1, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7178846153846153
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00,  9.82it/s]
# K = 25, L = 0.2, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7192307692307693
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.30it/s]
# K = 25, L = 0.30000000000000004, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7168269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.70it/s]
# K = 25, L = 0.4, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7197115384615385
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.58it/s]
# K = 25, L = 0.5, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7143269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.74it/s]
# K = 25, L = 0.6000000000000001, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7092307692307691
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.89it/s]
# K = 25, L = 0.7000000000000001, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.7038461538461538
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00, 10.26it/s]
# K = 25, L = 0.8, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.6909615384615383
# 100%|█████████████████████████████████████████| 104/104 [00:11<00:00,  8.97it/s]
# K = 25, L = 0.9, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.6643269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.38it/s]
# K = 25, L = 1.0, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.5566346153846153
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.76it/s]
# K = 25, L = 0.0, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 11.54it/s]
# K = 25, L = 0.1, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7183653846153847
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.80it/s]
# K = 25, L = 0.2, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7196153846153847
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.22it/s]
# K = 25, L = 0.30000000000000004, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.720576923076923
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 10.50it/s]
# K = 25, L = 0.4, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7186538461538462
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.73it/s]
# K = 25, L = 0.5, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7148076923076924
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.35it/s]
# K = 25, L = 0.6000000000000001, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7108653846153845
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.57it/s]
# K = 25, L = 0.7000000000000001, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7032692307692308
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.49it/s]
# K = 25, L = 0.8, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7000961538461539
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.61it/s]
# K = 25, L = 0.9, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.6773076923076923
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.73it/s]
# K = 25, L = 1.0, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.5889423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 11.33it/s]
# K = 25, L = 0.0, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 11.65it/s]
# K = 25, L = 0.1, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7179807692307691
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.14it/s]
# K = 25, L = 0.2, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7192307692307692
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.84it/s]
# K = 25, L = 0.30000000000000004, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7193269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:11<00:00,  9.05it/s]
# K = 25, L = 0.4, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7183653846153846
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.30it/s]
# K = 25, L = 0.5, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.72
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.37it/s]
# K = 25, L = 0.6000000000000001, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7132692307692309
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 11.65it/s]
# K = 25, L = 0.7000000000000001, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7095192307692307
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.28it/s]
# K = 25, L = 0.8, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7018269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.56it/s]
# K = 25, L = 0.9, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.6891346153846153
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.49it/s]
# K = 25, L = 1.0, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.6220192307692307
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.27it/s]
# K = 25, L = 0.0, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.91it/s]
# K = 25, L = 0.1, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7176923076923077
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.66it/s]
# K = 25, L = 0.2, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7192307692307692
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.53it/s]
# K = 25, L = 0.30000000000000004, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7189423076923076
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 11.36it/s]
# K = 25, L = 0.4, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7200961538461539
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.04it/s]
# K = 25, L = 0.5, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7188461538461538
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.45it/s]
# K = 25, L = 0.6000000000000001, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7151923076923078
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.99it/s]
# K = 25, L = 0.7000000000000001, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7116346153846153
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.53it/s]
# K = 25, L = 0.8, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7087500000000001
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.62it/s]
# K = 25, L = 0.9, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.6967307692307692
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.18it/s]
# K = 25, L = 1.0, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.643846153846154
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00, 10.28it/s]
# K = 25, L = 0.0, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.35it/s]
# K = 25, L = 0.1, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7178846153846153
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.81it/s]
# K = 25, L = 0.2, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7189423076923076
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.68it/s]
# K = 25, L = 0.30000000000000004, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7185576923076924
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.53it/s]
# K = 25, L = 0.4, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7196153846153847
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.74it/s]
# K = 25, L = 0.5, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7193269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.50it/s]
# K = 25, L = 0.6000000000000001, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7165384615384615
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.89it/s]
# K = 25, L = 0.7000000000000001, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7185576923076924
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 10.59it/s]
# K = 25, L = 0.8, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7118269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.47it/s]
# K = 25, L = 0.9, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7091346153846154
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.76it/s]
# K = 25, L = 1.0, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.6604807692307693
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.69it/s]
# K = 25, L = 0.0, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.64it/s]
# K = 25, L = 0.1, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7180769230769231
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.74it/s]
# K = 25, L = 0.2, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7179807692307691
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 11.75it/s]
# K = 25, L = 0.30000000000000004, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7186538461538461
# 100%|█████████████████████████████████████████| 104/104 [00:11<00:00,  8.93it/s]
# K = 25, L = 0.4, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.71875
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00, 10.17it/s]
# K = 25, L = 0.5, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7189423076923078
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 10.72it/s]
# K = 25, L = 0.6000000000000001, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7185576923076924
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.76it/s]
# K = 25, L = 0.7000000000000001, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7180769230769232
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.85it/s]
# K = 25, L = 0.8, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.717403846153846
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.74it/s]
# K = 25, L = 0.9, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7108653846153847
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.75it/s]
# K = 25, L = 1.0, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.6909615384615384
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00, 10.01it/s]
# K = 25, L = 0.0, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:10<00:00,  9.89it/s]
# K = 25, L = 0.1, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7178846153846153
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.48it/s]
# K = 25, L = 0.2, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7173076923076922
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.92it/s]
# K = 25, L = 0.30000000000000004, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7191346153846153
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.56it/s]
# K = 25, L = 0.4, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7183653846153846
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.89it/s]
# K = 25, L = 0.5, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7196153846153847
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.49it/s]
# K = 25, L = 0.6000000000000001, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7185576923076922
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 11.34it/s]
# K = 25, L = 0.7000000000000001, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7197115384615386
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.12it/s]
# K = 25, L = 0.8, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7189423076923078
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.39it/s]
# K = 25, L = 0.9, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7173076923076922
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.28it/s]
# K = 25, L = 1.0, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7089423076923076
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.97it/s]
# K = 25, L = 0.0, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.83it/s]
# K = 25, L = 0.1, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7171153846153846
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 14.00it/s]
# K = 25, L = 0.2, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7177884615384615
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 11.13it/s]
# K = 25, L = 0.30000000000000004, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7179807692307691
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.51it/s]
# K = 25, L = 0.4, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7178846153846153
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.57it/s]
# K = 25, L = 0.5, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7194230769230768
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.37it/s]
# K = 25, L = 0.6000000000000001, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7192307692307691
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.56it/s]
# K = 25, L = 0.7000000000000001, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7195192307692307
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 14.08it/s]
# K = 25, L = 0.8, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.72
# 100%|█████████████████████████████████████████| 104/104 [00:11<00:00,  9.18it/s]
# K = 25, L = 0.9, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7192307692307692
# 100%|█████████████████████████████████████████| 104/104 [00:14<00:00,  7.10it/s]
# K = 25, L = 1.0, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.7204807692307692
# 100%|█████████████████████████████████████████| 104/104 [00:11<00:00,  9.43it/s]
# K = 25, L = 0.0, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.50it/s]
# K = 25, L = 0.1, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.96it/s]
# K = 25, L = 0.2, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.32it/s]
# K = 25, L = 0.30000000000000004, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.52it/s]
# K = 25, L = 0.4, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.59it/s]
# K = 25, L = 0.5, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:09<00:00, 11.51it/s]
# K = 25, L = 0.6000000000000001, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:08<00:00, 12.24it/s]
# K = 25, L = 0.7000000000000001, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.46it/s]
# K = 25, L = 0.8, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.48it/s]
# K = 25, L = 0.9, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:07<00:00, 13.17it/s]
# K = 25, L = 1.0, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 'K = 25, L = 0.30000000000000004, m = 0.30000000000000004, rndFirst = False np.mean(results) = 0.720576923076923'

# %%
# Out:
# array([15.028804  , 17.60270343, 15.44045345, ..., 15.56038531,
#        16.02630586, 14.44371887])

# %%
import numpy as np


def get_Rp_best(GE, A, R, QE_i, L, u_last, m=0.5):
    u = (GE[A].T @ (R  / R.sum()).T
    u = u_last * m + u * (1 - m)
    return GE @ u, u
    
    u_mx = GE[A[R.argmax()]]
    u_mn = GE[A[R.argmin()]]
    u = u_last * m + (u_mx - u_mn) * (1 - m)
    return GE @ u, u

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]
#GE = (GE.T / (GE ** 2).sum(axis=1) ** 0.5).T
#QE = (QE.T / (QE ** 2).sum(axis=1) ** 0.5).T
#doesnt work

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for m in np.linspace(0, 1, 11):
        for K in [25]:
            for L in [0]:
                for T, TS in [(200, 100)]:
                    results = list()


                    As = list()
                    for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                        A = (
                            ctx.key_games[:K]
                            if randomFirst else
                            (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                        )
                        Rt = R_All[i]
                        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                        u_last = QE[i]
                        for _ in range(T // K - 1):
                            Rp, u_last = get_Rp_best(GE, A, Rt[A], QE[i], L, u_last, m=m)

                            An = list(A)
                            for ai in Rp.argsort()[::-1]:
                                if True and (ai not in An):
                                    An.append(ai)
                                if len(An) == len(A) + K:
                                    break
                            A = np.array(An)

                        assert len(A) == T
                        As.append(A)


                        A = sorted([
                            (-Rt[ai], ai)
                            for ai in A
                        ])[:TS]
                        A = [ai for _, ai in A]

                        pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                        results.append(ev(pred_top, gt_top) / float(TS))

                    if np.mean(results) > best:
                        best = np.mean(results)
                        best_arg = f"K = {K}, L = {L}, m = {m}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                        best_arg_d = {
                            "K": K,
                            "L": L,
                            "randomFirst": randomFirst,
                            "score": np.mean(results),
                            "m": m
                        }
                    print(f"K = {K}, L = {L}, m = {m}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")

best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 54.37it/s]
# K = 25, L = 0, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.3382692307692308
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 55.36it/s]
# K = 25, L = 0, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.3452884615384615
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 56.05it/s]
# K = 25, L = 0, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.3553846153846154
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 56.20it/s]
# K = 25, L = 0, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.36605769230769225
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 55.49it/s]
# K = 25, L = 0, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.3798076923076923
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 55.34it/s]
# K = 25, L = 0, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.39490384615384616
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 57.17it/s]
# K = 25, L = 0, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.41442307692307695
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 56.60it/s]
# K = 25, L = 0, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.4418269230769231
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 55.57it/s]
# K = 25, L = 0, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.4887500000000001
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 55.73it/s]
# K = 25, L = 0, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.5708653846153846
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 54.65it/s]
# K = 25, L = 0, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 'K = 25, L = 0, m = 1.0, rndFirst = False np.mean(results) = 0.7164423076923077'

# %%
import numpy as np


def get_Rp_rnd(GE, A, R, QE_i, L, u_last, m=0.5):
    u = QE_i + np.random.rand(GE.shape[1]) * m
    return GE @ u, u

# %%
from sklearn.linear_model import Ridge

Z = "test"
q = ctx.get_requests(Z)
R_All = ctx.get_relevs(Z)

GE, QE = loaded["GE"], loaded["QE"]
#GE = (GE.T / (GE ** 2).sum(axis=1) ** 0.5).T
#QE = (QE.T / (QE ** 2).sum(axis=1) ** 0.5).T
#doesnt work

best = 0
best_arg = None

STRIP = 0.05

for randomFirst in [False]:
    for m in np.linspace(0, 1, 11):
        for K in [25]:
            for L in [0]:
                for T, TS in [(200, 100)]:
                    results = list()


                    As = list()
                    for i in tqdm.tqdm(range(int(STRIP * R_All.shape[0]))):
                        A = (
                            ctx.key_games[:K]
                            if randomFirst else
                            (GE @ QE[i]).argsort()[::-1][:K]  # try best by DE
                        )
                        Rt = R_All[i]
                        ev = lambda rec_, real_ : len((set(rec_).intersection(set(real_)))) 

                        u_last = QE[i]
                        for _ in range(T // K - 1):
                            Rp, u_last = get_Rp_rnd(GE, A, Rt[A], QE[i], L, u_last, m=m)

                            An = list(A)
                            for ai in Rp.argsort()[::-1]:
                                if True and (ai not in An):
                                    An.append(ai)
                                if len(An) == len(A) + K:
                                    break
                            A = np.array(An)

                        assert len(A) == T
                        As.append(A)


                        A = sorted([
                            (-Rt[ai], ai)
                            for ai in A
                        ])[:TS]
                        A = [ai for _, ai in A]

                        pred_top, gt_top = A, Rt.argsort()[::-1][:TS]
                        results.append(ev(pred_top, gt_top) / float(TS))

                    if np.mean(results) > best:
                        best = np.mean(results)
                        best_arg = f"K = {K}, L = {L}, m = {m}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}"
                        best_arg_d = {
                            "K": K,
                            "L": L,
                            "randomFirst": randomFirst,
                            "score": np.mean(results),
                            "m": m
                        }
                    print(f"K = {K}, L = {L}, m = {m}, TS = {TS}, rndFirst = {randomFirst} np.mean(results) = {np.mean(results)}")

best_arg
# Out:
# 100%|█████████████████████████████████████████| 104/104 [00:02<00:00, 50.28it/s]
# K = 25, L = 0, m = 0.0, TS = 100, rndFirst = False np.mean(results) = 0.7164423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 59.55it/s]
# K = 25, L = 0, m = 0.1, TS = 100, rndFirst = False np.mean(results) = 0.7152884615384614
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 66.25it/s]
# K = 25, L = 0, m = 0.2, TS = 100, rndFirst = False np.mean(results) = 0.714423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 53.63it/s]
# K = 25, L = 0, m = 0.30000000000000004, TS = 100, rndFirst = False np.mean(results) = 0.7152884615384614
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 63.54it/s]
# K = 25, L = 0, m = 0.4, TS = 100, rndFirst = False np.mean(results) = 0.7126923076923077
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 62.86it/s]
# K = 25, L = 0, m = 0.5, TS = 100, rndFirst = False np.mean(results) = 0.7114423076923077
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 62.15it/s]
# K = 25, L = 0, m = 0.6000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7107692307692306
# 100%|█████████████████████████████████████████| 104/104 [00:02<00:00, 37.88it/s]
# K = 25, L = 0, m = 0.7000000000000001, TS = 100, rndFirst = False np.mean(results) = 0.7056730769230769
# 100%|█████████████████████████████████████████| 104/104 [00:01<00:00, 56.73it/s]
# K = 25, L = 0, m = 0.8, TS = 100, rndFirst = False np.mean(results) = 0.7076923076923077
# 100%|█████████████████████████████████████████| 104/104 [00:02<00:00, 48.97it/s]
# K = 25, L = 0, m = 0.9, TS = 100, rndFirst = False np.mean(results) = 0.708076923076923
# 100%|█████████████████████████████████████████| 104/104 [00:02<00:00, 50.61it/s]
# K = 25, L = 0, m = 1.0, TS = 100, rndFirst = False np.mean(results) = 0.7087500000000001
# 'K = 25, L = 0, m = 0.0, rndFirst = False np.mean(results) = 0.7164423076923077'
